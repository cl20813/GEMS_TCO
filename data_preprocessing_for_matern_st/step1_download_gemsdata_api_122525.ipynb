# %%
import sys
import os

# Add the directory containing smoothspace.py to sys.path
# sys.path.append(r'c:\\Users\\joonw\\TCO\\GEMS_TCO')
# sys.path.append(r'c:\\Users\\joonw\\TCO')
import sys
gems_tco_path = "/Users/joonwonlee/Documents/GEMS_TCO-1/src"
sys.path.append(gems_tco_path)
from GEMS_TCO import download_data
from GEMS_TCO import configuration as config

# %% [markdown]
# Input:
#
# year: int
# month int
# days = list of integers (range from 1-31)
#
# Example code below:

# %%
dayslist = list(range(29,30))
instance = download_data.Download_file(year=2022, month=7, days = dayslist, ouptut_folder= config.mac_data_load_path )

instance.run()
# Out:
# Failed to download 20220729_1145.nc, status code: 404
# Failed to download 20220729_0045.nc, status code: 404
# Failed to download 20220729_0145.nc, status code: 404
# Failed to download 20220729_0245.nc, status code: 404
# Failed to download 20220729_0345.nc, status code: 404
# Failed to download 20220729_0445.nc, status code: 404
# Failed to download 20220729_0545.nc, status code: 404
# Failed to download 20220729_0645.nc, status code: 404
# Failed to download 20220729_0745.nc, status code: 404

# %% [markdown]
# error test in 2024 11 (weird there is no 11/31 )

# %%
dayslist = list(range(31,32))
instance = download_data.Download_file(year=2024, month=11, days = dayslist )

instance.run()

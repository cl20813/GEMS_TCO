# %%
import sys
import os

# Add the directory containing smoothspace.py to sys.path
# sys.path.append(r'c:\\Users\\joonw\\TCO\\GEMS_TCO')
# sys.path.append(r'c:\\Users\\joonw\\TCO')
import sys
gems_tco_path = "/Users/joonwonlee/Documents/GEMS_TCO-1/src"
sys.path.append(gems_tco_path)
from GEMS_TCO import download_data
from GEMS_TCO import configuration as config

# %% [markdown]
# Input:
#
# year: int
# month int
# days = list of integers (range from 1-31)
#
# Example code below:

# %%
dayslist = list(range(9,21))
instance = download_data.Download_file(year=2022, month=8, days = dayslist, ouptut_folder= config.mac_data_load_path )

instance.run()
# Out:
# Failed 20220809_1145.nc: status 400
# Downloading 20220809_0045.nc: 583438it [01:04, 8981.39it/s]
# Downloaded 20220809_0045.nc
# Downloading 20220809_0145.nc: 580694it [00:57, 10074.07it/s]
# Downloaded 20220809_0145.nc
# Downloading 20220809_0245.nc: 558563it [01:36, 5775.26it/s]
# Downloaded 20220809_0245.nc
# Downloading 20220809_0345.nc: 561261it [01:06, 8385.34it/s]
# Downloaded 20220809_0345.nc
# Downloading 20220809_0445.nc: 565622it [00:58, 9719.91it/s]
# Downloaded 20220809_0445.nc
# Downloading 20220809_0545.nc: 568326it [01:11, 7906.18it/s]
# Downloaded 20220809_0545.nc
# Downloading 20220809_0645.nc: 570441it [01:05, 8734.16it/s]
# Downloaded 20220809_0645.nc
# Downloading 20220809_0745.nc: 572505it [01:17, 7430.89it/s]
# Downloaded 20220809_0745.nc
# Failed 20220810_1145.nc: status 400
# Downloading 20220810_0045.nc: 583868it [01:55, 5054.24it/s]
# Downloaded 20220810_0045.nc
# Downloading 20220810_0145.nc: 581526it [00:59, 9805.40it/s]
# Downloaded 20220810_0145.nc
# Downloading 20220810_0245.nc: 559003it [01:33, 5970.83it/s]
# Downloaded 20220810_0245.nc
# Downloading 20220810_0345.nc: 561011it [01:00, 9216.45it/s]
# Downloaded 20220810_0345.nc
# Downloading 20220810_0445.nc: 564744it [01:01, 9129.21it/s]
# Downloaded 20220810_0445.nc
# Downloading 20220810_0545.nc: 566623it [01:08, 8287.13it/s]
# Downloaded 20220810_0545.nc
# Downloading 20220810_0645.nc: 568177it [00:56, 10061.84it/s]
# Downloaded 20220810_0645.nc
# Downloading 20220810_0745.nc: 569737it [00:59, 9598.82it/s]
# Downloaded 20220810_0745.nc
# Failed 20220811_1145.nc: status 400
# Downloading 20220811_0045.nc: 579878it [00:56, 10322.52it/s]
# Downloaded 20220811_0045.nc
# Downloading 20220811_0145.nc: 577620it [00:58, 9911.08it/s]
# Downloaded 20220811_0145.nc
# Downloading 20220811_0245.nc: 553221it [00:53, 10284.54it/s]
# Downloaded 20220811_0245.nc
# Downloading 20220811_0345.nc: 555549it [01:08, 8077.91it/s]
# Downloaded 20220811_0345.nc
# Downloading 20220811_0445.nc: 558720it [01:21, 6868.90it/s]
# Downloaded 20220811_0445.nc
# Downloading 20220811_0545.nc: 560745it [01:07, 8250.08it/s]
# Downloaded 20220811_0545.nc
# Downloading 20220811_0645.nc: 562601it [01:12, 7726.39it/s]
# Downloaded 20220811_0645.nc
# Downloading 20220811_0745.nc: 564545it [01:02, 9057.13it/s]
# Downloaded 20220811_0745.nc
# Failed 20220812_1145.nc: status 400
# Downloading 20220812_0045.nc: 578755it [01:32, 6277.65it/s]
# Downloaded 20220812_0045.nc
# Downloading 20220812_0145.nc: 576769it [00:59, 9737.12it/s]
# Downloaded 20220812_0145.nc
# Downloading 20220812_0245.nc: 553110it [01:05, 8406.45it/s]
# Downloaded 20220812_0245.nc
# Downloading 20220812_0345.nc: 555925it [01:16, 7278.11it/s]
# Downloaded 20220812_0345.nc
# Downloading 20220812_0445.nc: 559689it [00:55, 10100.51it/s]
# Downloaded 20220812_0445.nc
# Downloading 20220812_0545.nc: 562046it [00:55, 10058.91it/s]
# Downloaded 20220812_0545.nc
# Downloading 20220812_0645.nc: 564561it [00:58, 9707.32it/s]
# Downloaded 20220812_0645.nc
# Downloading 20220812_0745.nc: 567260it [01:03, 8965.75it/s]
# Downloaded 20220812_0745.nc
# Failed 20220813_1145.nc: status 400
# Downloading 20220813_0045.nc: 583274it [00:59, 9883.59it/s]
# Downloaded 20220813_0045.nc
# Downloading 20220813_0145.nc: 580650it [01:03, 9149.81it/s]
# Downloaded 20220813_0145.nc
# Downloading 20220813_0245.nc: 556939it [01:37, 5729.92it/s]
# Downloaded 20220813_0245.nc
# Downloading 20220813_0345.nc: 560124it [01:54, 4889.23it/s]
# Downloaded 20220813_0345.nc
# Downloading 20220813_0445.nc: 564845it [01:08, 8218.91it/s]
# Downloaded 20220813_0445.nc
# Downloading 20220813_0545.nc: 567474it [00:58, 9683.38it/s]
# Downloaded 20220813_0545.nc
# Downloading 20220813_0645.nc: 569321it [00:57, 9964.79it/s]
# Downloaded 20220813_0645.nc
# Downloading 20220813_0745.nc: 570938it [01:04, 8884.36it/s]
# Downloaded 20220813_0745.nc
# Failed 20220814_1145.nc: status 400
# Downloading 20220814_0045.nc: 584661it [00:58, 9978.37it/s]
# Downloaded 20220814_0045.nc
# Downloading 20220814_0145.nc: 582212it [00:56, 10375.05it/s]
# Downloaded 20220814_0145.nc
# Downloading 20220814_0245.nc: 560879it [02:07, 4390.85it/s]
# Downloaded 20220814_0245.nc
# Downloading 20220814_0345.nc: 563356it [01:19, 7103.41it/s]
# Downloaded 20220814_0345.nc
# Downloading 20220814_0445.nc: 567131it [01:22, 6913.73it/s]
# Downloaded 20220814_0445.nc
# Downloading 20220814_0545.nc: 569287it [00:56, 10080.71it/s]
# Downloaded 20220814_0545.nc
# Downloading 20220814_0645.nc: 571515it [00:58, 9696.58it/s]
# Downloaded 20220814_0645.nc
# Downloading 20220814_0745.nc: 572699it [00:56, 10086.40it/s]
# Downloaded 20220814_0745.nc
# Failed 20220815_1145.nc: status 400
# Downloading 20220815_0045.nc: 584566it [00:59, 9765.97it/s]
# Downloaded 20220815_0045.nc
# Downloading 20220815_0145.nc: 581783it [00:58, 9960.33it/s]
# Downloaded 20220815_0145.nc
# Downloading 20220815_0245.nc: 560766it [00:57, 9714.91it/s]
# Downloaded 20220815_0245.nc
# Downloading 20220815_0345.nc: 563201it [01:05, 8533.77it/s]
# Downloaded 20220815_0345.nc
# Downloading 20220815_0445.nc: 566876it [01:10, 8009.09it/s]
# Downloaded 20220815_0445.nc
# Downloading 20220815_0545.nc: 569505it [00:54, 10522.09it/s]
# Downloaded 20220815_0545.nc
# Downloading 20220815_0645.nc: 572209it [00:58, 9778.39it/s]
# Downloaded 20220815_0645.nc
# Downloading 20220815_0745.nc: 574337it [00:58, 9900.58it/s]
# Downloaded 20220815_0745.nc
# Failed 20220816_1145.nc: status 400
# Downloading 20220816_0045.nc: 586932it [01:09, 8461.30it/s]
# Downloaded 20220816_0045.nc
# Downloading 20220816_0145.nc: 584192it [01:13, 7895.60it/s]
# Downloaded 20220816_0145.nc
# Downloading 20220816_0245.nc: 561640it [01:02, 9013.74it/s]
# Downloaded 20220816_0245.nc
# Downloading 20220816_0345.nc: 564390it [00:58, 9685.56it/s]
# Downloaded 20220816_0345.nc
# Downloading 20220816_0445.nc: 568300it [00:56, 9975.70it/s]
# Downloaded 20220816_0445.nc
# Downloading 20220816_0545.nc: 570919it [01:14, 7653.74it/s]
# Downloaded 20220816_0545.nc
# Downloading 20220816_0645.nc: 573397it [01:14, 7665.63it/s]
# Downloaded 20220816_0645.nc
# Downloading 20220816_0745.nc: 575028it [00:53, 10843.88it/s]
# Downloaded 20220816_0745.nc
# Failed 20220817_1145.nc: status 400
# Downloading 20220817_0045.nc: 585283it [01:08, 8500.08it/s]
# Downloaded 20220817_0045.nc
# Downloading 20220817_0145.nc: 583030it [01:37, 5975.13it/s]
# Downloaded 20220817_0145.nc
# Downloading 20220817_0245.nc: 564101it [01:01, 9149.17it/s]
# Downloaded 20220817_0245.nc
# Downloading 20220817_0345.nc: 567066it [01:04, 8836.37it/s]
# Downloaded 20220817_0345.nc
# Downloading 20220817_0445.nc: 571000it [01:07, 8399.31it/s]
# Downloaded 20220817_0445.nc
# Downloading 20220817_0545.nc: 573445it [01:03, 9006.61it/s]
# Downloaded 20220817_0545.nc
# Downloading 20220817_0645.nc: 575452it [01:04, 8971.87it/s]
# Downloaded 20220817_0645.nc
# Downloading 20220817_0745.nc: 576520it [01:10, 8187.45it/s]
# Downloaded 20220817_0745.nc
# Failed 20220818_1145.nc: status 400
# Downloading 20220818_0045.nc: 585202it [01:09, 8464.63it/s]
# Downloaded 20220818_0045.nc
# Downloading 20220818_0145.nc: 583694it [01:04, 9039.80it/s]
# Downloaded 20220818_0145.nc
# Downloading 20220818_0245.nc: 562688it [01:11, 7831.62it/s]
# Downloaded 20220818_0245.nc
# Downloading 20220818_0345.nc: 565750it [01:12, 7798.43it/s]
# Downloaded 20220818_0345.nc
# Downloading 20220818_0445.nc: 569493it [01:03, 8972.49it/s]
# Downloaded 20220818_0445.nc
# Downloading 20220818_0545.nc: 571754it [01:01, 9296.89it/s]
# Downloaded 20220818_0545.nc
# Downloading 20220818_0645.nc: 573573it [01:26, 6630.30it/s]
# Downloaded 20220818_0645.nc
# Downloading 20220818_0745.nc: 575332it [01:08, 8365.52it/s]
# Downloaded 20220818_0745.nc
# Failed 20220819_1145.nc: status 400
# Downloading 20220819_0045.nc: 579938it [01:17, 7490.96it/s]
# Downloaded 20220819_0045.nc
# Downloading 20220819_0145.nc: 577220it [01:08, 8444.00it/s]
# Downloaded 20220819_0145.nc
# Downloading 20220819_0245.nc: 557731it [01:14, 7495.86it/s]
# Downloaded 20220819_0245.nc
# Downloading 20220819_0345.nc: 560713it [01:11, 7827.41it/s]
# Downloaded 20220819_0345.nc
# Downloading 20220819_0445.nc: 564543it [01:02, 8976.43it/s]
# Downloaded 20220819_0445.nc
# Downloading 20220819_0545.nc: 566950it [01:13, 7719.37it/s]
# Downloaded 20220819_0545.nc
# Downloading 20220819_0645.nc: 568615it [01:07, 8471.48it/s]
# Downloaded 20220819_0645.nc
# Downloading 20220819_0745.nc: 569921it [00:59, 9656.13it/s]
# Downloaded 20220819_0745.nc
# Failed 20220820_1145.nc: status 400
# Downloading 20220820_0045.nc: 581150it [01:23, 6987.43it/s]
# Downloaded 20220820_0045.nc
# Downloading 20220820_0145.nc: 579431it [01:07, 8635.18it/s]
# Downloaded 20220820_0145.nc
# Downloading 20220820_0245.nc: 557909it [01:14, 7448.93it/s]
# Downloaded 20220820_0245.nc
# Downloading 20220820_0345.nc: 559908it [01:07, 8278.10it/s]
# Downloaded 20220820_0345.nc
# Downloading 20220820_0445.nc: 563343it [01:08, 8180.77it/s]
# Downloaded 20220820_0445.nc
# Downloading 20220820_0545.nc: 565375it [00:59, 9427.70it/s]
# Downloaded 20220820_0545.nc
# Downloading 20220820_0645.nc: 566870it [00:57, 9863.31it/s]
# Downloaded 20220820_0645.nc
# Downloading 20220820_0745.nc: 568939it [01:01, 9319.15it/s]
# Downloaded 20220820_0745.nc

# %%
dayslist = list(range(1,2))
instance = download_data.Download_file(year=2025, month=8, days = dayslist, ouptut_folder= config.mac_data_load_path )

instance.run()

# %% [markdown]
# error test in 2024 11 (weird there is no 11/31 )

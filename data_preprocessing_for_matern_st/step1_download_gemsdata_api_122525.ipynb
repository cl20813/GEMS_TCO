# %%
import sys
import os

# Add the directory containing smoothspace.py to sys.path
# sys.path.append(r'c:\\Users\\joonw\\TCO\\GEMS_TCO')
# sys.path.append(r'c:\\Users\\joonw\\TCO')
import sys
gems_tco_path = "/Users/joonwonlee/Documents/GEMS_TCO-1/src"
sys.path.append(gems_tco_path)
from GEMS_TCO import download_data
from GEMS_TCO import configuration as config

# %% [markdown]
# Input:
#
# year: int
# month int
# days = list of integers (range from 1-31)
#
# Example code below:

# %%
dayslist = list(range(24,25))
instance = download_data.Download_file(year=2025, month=7, days = dayslist, ouptut_folder= config.mac_data_load_path )

instance.run()
# Out:
# Failed to download 20250724_1145.nc, status code: 404
# Downloading 20250724_0045.nc: 578681it [01:00, 9616.18it/s]
# Downloaded 20250724_0045.nc
# Downloading 20250724_0145.nc: 577407it [00:46, 12445.50it/s]
# Downloaded 20250724_0145.nc
# Failed to download 20250724_0245.nc, status code: 404
# Downloading 20250724_0345.nc: 579268it [00:51, 11161.01it/s]
# Downloaded 20250724_0345.nc
# Downloading 20250724_0445.nc: 562113it [01:01, 9188.57it/s]
# Downloaded 20250724_0445.nc
# Downloading 20250724_0545.nc: 563362it [00:42, 13410.86it/s]
# Downloaded 20250724_0545.nc
# Downloading 20250724_0645.nc: 564985it [00:46, 12125.91it/s]
# Downloaded 20250724_0645.nc
# Downloading 20250724_0745.nc: 566293it [00:48, 11743.57it/s]
# Downloaded 20250724_0745.nc

# %% [markdown]
# error test in 2024 11 (weird there is no 11/31 )

# %%
dayslist = list(range(31,32))
instance = download_data.Download_file(year=2024, month=11, days = dayslist )

instance.run()

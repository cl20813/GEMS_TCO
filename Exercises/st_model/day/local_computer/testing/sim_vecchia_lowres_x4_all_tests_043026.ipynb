# %% [markdown]
# # Low-Resolution Vecchia Conditioning Sweep
#
# Same spatial domain and true parameters, but lat/lon grid resolution is coarsened by 4x. This tests whether earlier allocation conclusions were driven by dense current-time spatial information.

# %%
import os
import sys
import time
import io
import contextlib
from pathlib import Path

import numpy as np
import pandas as pd
import torch
import torch.fft
import matplotlib.pyplot as plt

AMAREL_SRC = "/home/jl2815/tco"
LOCAL_SRC = "/Users/joonwonlee/Documents/GEMS_TCO-1/src"
_src = AMAREL_SRC if os.path.exists(AMAREL_SRC) else LOCAL_SRC
sys.path.insert(0, _src)

from GEMS_TCO import kernels_vecchia
from GEMS_TCO import kernels_vecchia_advec_band
from GEMS_TCO import orderings as _orderings

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DTYPE = torch.float64

# Low-resolution stress test: same domain, 4x coarser in both lat/lon.
DELTA_LAT = 0.044 * 4
DELTA_LON = 0.063 * 4
T_STEPS = 8

print("DEVICE:", DEVICE)
print("SRC:", _src)
print("Grid resolution:", DELTA_LAT, DELTA_LON)
# Out:
# DEVICE: cpu
# SRC: /Users/joonwonlee/Documents/GEMS_TCO-1/src
# Grid resolution: 0.176 0.252

# %% [markdown]
# ## Settings And Model Groups

# %%
LAT_RANGE = (-3.0, 2.0)
LON_RANGE = (121.0, 131.0)
MC_NUM_ITERS = 10
SEED = 42

SMOOTH = 0.5
MM_COND_NUMBER = 100
NHEADS = 0
DAILY_STRIDE = 2
NO_LAG2_DAILY_STRIDE = T_STEPS + 1

LBFGS_STEPS = 5
LBFGS_EVAL = 20
LBFGS_HIST = 10
INIT_NOISE = 0.7
SUPPRESS_FIT_PRINTS = True

RUN_ONE_SHOT_GODAMBE = True
HESSIAN_EPS = 1e-4
SCORE_EPS = 1e-5
H_RIDGE_SCALE = 1e-6
GODAMBE_J_METHOD = "block"
GODAMBE_BLOCK_LAT_WIDTH = 0.50
GODAMBE_BLOCK_LON_WIDTH = 0.50
GODAMBE_BLOCK_TIME_WIDTH = 2.0

TRUE_DICT = {
    "sigmasq": 10.0,
    "range_lat": 0.30,
    "range_lon": 0.40,
    "range_time": 2.0,
    "advec_lat": 0.08,
    "advec_lon": -0.126,
    "nugget": 2.5,
}

def total_conditioning(a, b=0, c=0, uses_lag1=True, uses_lag2=True, n_advec=0):
    total = int(a)
    if uses_lag1:
        total += int(1 + b + n_advec)
    if uses_lag2:
        total += int(1 + c)
    return total

def std_spec(name, a, b, c, group, allocation, daily_stride=DAILY_STRIDE, uses_lag2=True):
    return {
        "name": name,
        "group": group,
        "kernel": "std",
        "limit_A": int(a),
        "limit_B": int(b),
        "limit_C": int(c),
        "daily_stride": int(daily_stride),
        "uses_lag2": bool(uses_lag2),
        "lag1_ratio_actual": float(b / a) if a else np.nan,
        "lag2_ratio_actual": float(c / a) if (a and uses_lag2) else 0.0,
        "total_conditioning": total_conditioning(a, b, c, uses_lag1=True, uses_lag2=uses_lag2),
        "allocation": allocation,
        "description": f"t: {a}; t-1: same loc + {b}" + (f"; t-2: same loc + {c}" if uses_lag2 else "; no t-2"),
    }

def advec_spec(name, a, b_local, c, group, allocation, cell_offsets=(2, 3)):
    return {
        "name": name,
        "group": group,
        "kernel": "advec_band",
        "limit_A": int(a),
        "limit_B": int(b_local),
        "limit_C": int(c),
        "daily_stride": DAILY_STRIDE,
        "uses_lag2": True,
        "advec_cell_offsets": tuple(cell_offsets),
        "lon_resolution": DELTA_LON,
        "lag1_ratio_actual": float((b_local + len(cell_offsets)) / a) if a else np.nan,
        "lag2_ratio_actual": float(c / a) if a else np.nan,
        "total_conditioning": total_conditioning(a, b_local, c, uses_lag1=True, uses_lag2=True, n_advec=len(cell_offsets)),
        "allocation": allocation,
        "description": f"t: {a}; t-1: same loc + {b_local} local + upstream {cell_offsets}; t-2: same loc + {c}",
    }

EXPERIMENT_GROUPS = {
    "lag1_budget": [
        std_spec("Lag1_Realloc_B04_A12", 12, 4, 0, "lag1_budget", "lag1 realloc", daily_stride=NO_LAG2_DAILY_STRIDE, uses_lag2=False),
        std_spec("Lag1_Realloc_B05_A11", 11, 5, 0, "lag1_budget", "lag1 realloc", daily_stride=NO_LAG2_DAILY_STRIDE, uses_lag2=False),
        std_spec("Lag1_Realloc_B06_A10", 10, 6, 0, "lag1_budget", "lag1 realloc", daily_stride=NO_LAG2_DAILY_STRIDE, uses_lag2=False),
        std_spec("Lag1_Realloc_B07_A09", 9, 7, 0, "lag1_budget", "lag1 realloc", daily_stride=NO_LAG2_DAILY_STRIDE, uses_lag2=False),
        std_spec("Lag1_Full_B08_A08", 8, 8, 0, "lag1_budget", "lag1 full", daily_stride=NO_LAG2_DAILY_STRIDE, uses_lag2=False),
    ],
    "full8_current_realloc": [
        std_spec("FullLag_A08_B08_C08", 8, 8, 8, "full8_current_realloc", "8/8/8"),
        std_spec("RatioBudget_A11_B08_C05", 11, 8, 5, "full8_current_realloc", "x/0.75x/0.5x matched-total"),
        std_spec("CurrentRealloc_A12_B07_C05", 12, 7, 5, "full8_current_realloc", "more-current, reduced t-1/t-2"),
    ],
    "lag2_half_quarter": [
        std_spec("HalfLag2_A12_B09_C06", 12, 9, 6, "lag2_half_quarter", "x/0.75x/0.5x"),
        std_spec("QuarterRealloc_A15_B09_C03", 15, 9, 3, "lag2_half_quarter", "t-2 quarter, reallocate to current"),
    ],
    "lag2_half_none": [
        std_spec("HalfLag2_A12_B09_C06", 12, 9, 6, "lag2_half_none", "t-1 0.75x, t-2 0.5x"),
        std_spec("NoLag2_A19_B09_C00", 19, 9, 0, "lag2_half_none", "no t-2, reallocate to current", daily_stride=NO_LAG2_DAILY_STRIDE, uses_lag2=False),
    ],
    "advec_band_small": [
        std_spec("BaseLocal_A06_B04_C02", 6, 4, 2, "advec_band_small", "local baseline"),
        advec_spec("AdvecBand_A06_B02p23_C02", 6, 2, 2, "advec_band_small", "replace two lag1 local with upstream band"),
    ],
    "advec_band_large": [
        std_spec("BaseLocal_A12_B08_C06", 12, 8, 6, "advec_band_large", "local baseline"),
        advec_spec("AdvecBand_A12_B06p23_C06", 12, 6, 6, "advec_band_large", "replace two lag1 local with upstream band"),
    ],
    "full20_ratio": [
        std_spec("FullLag_A20_B20_C20", 20, 20, 20, "full20_ratio", "20/20/20"),
        std_spec("RatioBudget_A27_B20_C13", 27, 20, 13, "full20_ratio", "x/0.75x/0.5x matched-total"),
    ],
}

# Run all groups by default. To make a fast focused run, replace this list.
ACTIVE_GROUPS = [
    "lag1_budget",
    "full8_current_realloc",
    "lag2_half_quarter",
    "lag2_half_none",
    "advec_band_small",
    "advec_band_large",
    "full20_ratio",
]

MODEL_SPECS = {}
for group_name in ACTIVE_GROUPS:
    for spec in EXPERIMENT_GROUPS[group_name]:
        key = f"{group_name}::{spec['name']}"
        MODEL_SPECS[key] = spec

spec_df = pd.DataFrame(MODEL_SPECS).T
print("Active groups:", ACTIVE_GROUPS)
print("Number of model fits per MC iteration:", len(MODEL_SPECS))
display(spec_df[["group", "kernel", "limit_A", "limit_B", "limit_C", "daily_stride", "uses_lag2", "allocation", "lag1_ratio_actual", "lag2_ratio_actual", "total_conditioning", "description"]])
# Out:
# Active groups: ['lag1_budget', 'full8_current_realloc', 'lag2_half_quarter', 'lag2_half_none', 'advec_band_small', 'advec_band_large', 'full20_ratio']
# Number of model fits per MC iteration: 18
#                                                                    group  \
# lag1_budget::Lag1_Realloc_B04_A12                            lag1_budget
# lag1_budget::Lag1_Realloc_B05_A11                            lag1_budget
# lag1_budget::Lag1_Realloc_B06_A10                            lag1_budget
# lag1_budget::Lag1_Realloc_B07_A09                            lag1_budget
# lag1_budget::Lag1_Full_B08_A08                               lag1_budget
# full8_current_realloc::FullLag_A08_B08_C08         full8_current_realloc
# full8_current_realloc::RatioBudget_A11_B08_C05     full8_current_realloc
# full8_current_realloc::CurrentRealloc_A12_B07_C05  full8_current_realloc
# lag2_half_quarter::HalfLag2_A12_B09_C06                lag2_half_quarter
# lag2_half_quarter::QuarterRealloc_A15_B09_C03          lag2_half_quarter
# lag2_half_none::HalfLag2_A12_B09_C06                      lag2_half_none
# lag2_half_none::NoLag2_A19_B09_C00                        lag2_half_none
# advec_band_small::BaseLocal_A06_B04_C02                 advec_band_small
# advec_band_small::AdvecBand_A06_B02p23_C02              advec_band_small
# advec_band_large::BaseLocal_A12_B08_C06                 advec_band_large
# advec_band_large::AdvecBand_A12_B06p23_C06              advec_band_large
# full20_ratio::FullLag_A20_B20_C20                           full20_ratio
# full20_ratio::RatioBudget_A27_B20_C13                       full20_ratio
#
#                                                        kernel limit_A limit_B  \
# lag1_budget::Lag1_Realloc_B04_A12                         std      12       4
# lag1_budget::Lag1_Realloc_B05_A11                         std      11       5
# lag1_budget::Lag1_Realloc_B06_A10                         std      10       6
# lag1_budget::Lag1_Realloc_B07_A09                         std       9       7
# lag1_budget::Lag1_Full_B08_A08                            std       8       8
# full8_current_realloc::FullLag_A08_B08_C08                std       8       8
# full8_current_realloc::RatioBudget_A11_B08_C05            std      11       8
# full8_current_realloc::CurrentRealloc_A12_B07_C05         std      12       7
# lag2_half_quarter::HalfLag2_A12_B09_C06                   std      12       9
# lag2_half_quarter::QuarterRealloc_A15_B09_C03             std      15       9
# lag2_half_none::HalfLag2_A12_B09_C06                      std      12       9
# lag2_half_none::NoLag2_A19_B09_C00                        std      19       9
# advec_band_small::BaseLocal_A06_B04_C02                   std       6       4
# advec_band_small::AdvecBand_A06_B02p23_C02         advec_band       6       2
# advec_band_large::BaseLocal_A12_B08_C06                   std      12       8
# advec_band_large::AdvecBand_A12_B06p23_C06         advec_band      12       6
# full20_ratio::FullLag_A20_B20_C20                         std      20      20
# full20_ratio::RatioBudget_A27_B20_C13                     std      27      20
#
#                                                   limit_C daily_stride  \
# lag1_budget::Lag1_Realloc_B04_A12                       0            9
# lag1_budget::Lag1_Realloc_B05_A11                       0            9
# lag1_budget::Lag1_Realloc_B06_A10                       0            9
# lag1_budget::Lag1_Realloc_B07_A09                       0            9
# lag1_budget::Lag1_Full_B08_A08                          0            9
# full8_current_realloc::FullLag_A08_B08_C08              8            2
# full8_current_realloc::RatioBudget_A11_B08_C05          5            2
# full8_current_realloc::CurrentRealloc_A12_B07_C05       5            2
# lag2_half_quarter::HalfLag2_A12_B09_C06                 6            2
# lag2_half_quarter::QuarterRealloc_A15_B09_C03           3            2
# lag2_half_none::HalfLag2_A12_B09_C06                    6            2
# lag2_half_none::NoLag2_A19_B09_C00                      0            9
# advec_band_small::BaseLocal_A06_B04_C02                 2            2
# advec_band_small::AdvecBand_A06_B02p23_C02              2            2
# advec_band_large::BaseLocal_A12_B08_C06                 6            2
# advec_band_large::AdvecBand_A12_B06p23_C06              6            2
# full20_ratio::FullLag_A20_B20_C20                      20            2
# full20_ratio::RatioBudget_A27_B20_C13                  13            2
#
#                                                   uses_lag2  \
# lag1_budget::Lag1_Realloc_B04_A12                     False
# lag1_budget::Lag1_Realloc_B05_A11                     False
# lag1_budget::Lag1_Realloc_B06_A10                     False
# lag1_budget::Lag1_Realloc_B07_A09                     False
# lag1_budget::Lag1_Full_B08_A08                        False
# full8_current_realloc::FullLag_A08_B08_C08             True
# full8_current_realloc::RatioBudget_A11_B08_C05         True
# full8_current_realloc::CurrentRealloc_A12_B07_C05      True
# lag2_half_quarter::HalfLag2_A12_B09_C06                True
# lag2_half_quarter::QuarterRealloc_A15_B09_C03          True
# lag2_half_none::HalfLag2_A12_B09_C06                   True
# lag2_half_none::NoLag2_A19_B09_C00                    False
# advec_band_small::BaseLocal_A06_B04_C02                True
# advec_band_small::AdvecBand_A06_B02p23_C02             True
# advec_band_large::BaseLocal_A12_B08_C06                True
# advec_band_large::AdvecBand_A12_B06p23_C06             True
# full20_ratio::FullLag_A20_B20_C20                      True
# full20_ratio::RatioBudget_A27_B20_C13                  True
#
#                                                                                   allocation  \
# lag1_budget::Lag1_Realloc_B04_A12                                               lag1 realloc
# lag1_budget::Lag1_Realloc_B05_A11                                               lag1 realloc
# lag1_budget::Lag1_Realloc_B06_A10                                               lag1 realloc
# lag1_budget::Lag1_Realloc_B07_A09                                               lag1 realloc
# lag1_budget::Lag1_Full_B08_A08                                                     lag1 full
# full8_current_realloc::FullLag_A08_B08_C08                                             8/8/8
# full8_current_realloc::RatioBudget_A11_B08_C05                    x/0.75x/0.5x matched-total
# full8_current_realloc::CurrentRealloc_A12_B07_C05              more-current, reduced t-1/t-2
# lag2_half_quarter::HalfLag2_A12_B09_C06                                         x/0.75x/0.5x
# lag2_half_quarter::QuarterRealloc_A15_B09_C03             t-2 quarter, reallocate to current
# lag2_half_none::HalfLag2_A12_B09_C06                                     t-1 0.75x, t-2 0.5x
# lag2_half_none::NoLag2_A19_B09_C00                             no t-2, reallocate to current
# advec_band_small::BaseLocal_A06_B04_C02                                       local baseline
# advec_band_small::AdvecBand_A06_B02p23_C02         replace two lag1 local with upstream band
# advec_band_large::BaseLocal_A12_B08_C06                                       local baseline
# advec_band_large::AdvecBand_A12_B06p23_C06         replace two lag1 local with upstream band
# full20_ratio::FullLag_A20_B20_C20                                                   20/20/20
# full20_ratio::RatioBudget_A27_B20_C13                             x/0.75x/0.5x matched-total
#
#                                                   lag1_ratio_actual  \
# lag1_budget::Lag1_Realloc_B04_A12                          0.333333
# lag1_budget::Lag1_Realloc_B05_A11                          0.454545
# lag1_budget::Lag1_Realloc_B06_A10                               0.6
# lag1_budget::Lag1_Realloc_B07_A09                          0.777778
# lag1_budget::Lag1_Full_B08_A08                                  1.0
# full8_current_realloc::FullLag_A08_B08_C08                      1.0
# full8_current_realloc::RatioBudget_A11_B08_C05             0.727273
# full8_current_realloc::CurrentRealloc_A12_B07_C05          0.583333
# lag2_half_quarter::HalfLag2_A12_B09_C06                        0.75
# lag2_half_quarter::QuarterRealloc_A15_B09_C03                   0.6
# lag2_half_none::HalfLag2_A12_B09_C06                           0.75
# lag2_half_none::NoLag2_A19_B09_C00                         0.473684
# advec_band_small::BaseLocal_A06_B04_C02                    0.666667
# advec_band_small::AdvecBand_A06_B02p23_C02                 0.666667
# advec_band_large::BaseLocal_A12_B08_C06                    0.666667
# advec_band_large::AdvecBand_A12_B06p23_C06                 0.666667
# full20_ratio::FullLag_A20_B20_C20                               1.0
# full20_ratio::RatioBudget_A27_B20_C13                      0.740741
#
#                                                   lag2_ratio_actual  \
# lag1_budget::Lag1_Realloc_B04_A12                               0.0
# lag1_budget::Lag1_Realloc_B05_A11                               0.0
# lag1_budget::Lag1_Realloc_B06_A10                               0.0
# lag1_budget::Lag1_Realloc_B07_A09                               0.0
# lag1_budget::Lag1_Full_B08_A08                                  0.0
# full8_current_realloc::FullLag_A08_B08_C08                      1.0
# full8_current_realloc::RatioBudget_A11_B08_C05             0.454545
# full8_current_realloc::CurrentRealloc_A12_B07_C05          0.416667
# lag2_half_quarter::HalfLag2_A12_B09_C06                         0.5
# lag2_half_quarter::QuarterRealloc_A15_B09_C03                   0.2
# lag2_half_none::HalfLag2_A12_B09_C06                            0.5
# lag2_half_none::NoLag2_A19_B09_C00                              0.0
# advec_band_small::BaseLocal_A06_B04_C02                    0.333333
# advec_band_small::AdvecBand_A06_B02p23_C02                 0.333333
# advec_band_large::BaseLocal_A12_B08_C06                         0.5
# advec_band_large::AdvecBand_A12_B06p23_C06                      0.5
# full20_ratio::FullLag_A20_B20_C20                               1.0
# full20_ratio::RatioBudget_A27_B20_C13                      0.481481
#
#                                                   total_conditioning  \
# lag1_budget::Lag1_Realloc_B04_A12                                 17
# lag1_budget::Lag1_Realloc_B05_A11                                 17
# lag1_budget::Lag1_Realloc_B06_A10                                 17
# lag1_budget::Lag1_Realloc_B07_A09                                 17
# lag1_budget::Lag1_Full_B08_A08                                    17
# full8_current_realloc::FullLag_A08_B08_C08                        26
# full8_current_realloc::RatioBudget_A11_B08_C05                    26
# full8_current_realloc::CurrentRealloc_A12_B07_C05                 26
# lag2_half_quarter::HalfLag2_A12_B09_C06                           29
# lag2_half_quarter::QuarterRealloc_A15_B09_C03                     29
# lag2_half_none::HalfLag2_A12_B09_C06                              29
# lag2_half_none::NoLag2_A19_B09_C00                                29
# advec_band_small::BaseLocal_A06_B04_C02                           14
# advec_band_small::AdvecBand_A06_B02p23_C02                        14
# advec_band_large::BaseLocal_A12_B08_C06                           28
# advec_band_large::AdvecBand_A12_B06p23_C06                        28
# full20_ratio::FullLag_A20_B20_C20                                 62
# full20_ratio::RatioBudget_A27_B20_C13                             62
#
#                                                                                          description
# lag1_budget::Lag1_Realloc_B04_A12                                   t: 12; t-1: same loc + 4; no t-2
# lag1_budget::Lag1_Realloc_B05_A11                                   t: 11; t-1: same loc + 5; no t-2
# lag1_budget::Lag1_Realloc_B06_A10                                   t: 10; t-1: same loc + 6; no t-2
# lag1_budget::Lag1_Realloc_B07_A09                                    t: 9; t-1: same loc + 7; no t-2
# lag1_budget::Lag1_Full_B08_A08                                       t: 8; t-1: same loc + 8; no t-2
# full8_current_realloc::FullLag_A08_B08_C08                t: 8; t-1: same loc + 8; t-2: same loc + 8
# full8_current_realloc::RatioBudget_A11_B08_C05           t: 11; t-1: same loc + 8; t-2: same loc + 5
# full8_current_realloc::CurrentRealloc_A12_B07_C05        t: 12; t-1: same loc + 7; t-2: same loc + 5
# lag2_half_quarter::HalfLag2_A12_B09_C06                  t: 12; t-1: same loc + 9; t-2: same loc + 6
# lag2_half_quarter::QuarterRealloc_A15_B09_C03            t: 15; t-1: same loc + 9; t-2: same loc + 3
# lag2_half_none::HalfLag2_A12_B09_C06                     t: 12; t-1: same loc + 9; t-2: same loc + 6
# lag2_half_none::NoLag2_A19_B09_C00                                  t: 19; t-1: same loc + 9; no t-2
# advec_band_small::BaseLocal_A06_B04_C02                   t: 6; t-1: same loc + 4; t-2: same loc + 2
# advec_band_small::AdvecBand_A06_B02p23_C02         t: 6; t-1: same loc + 2 local + upstream (2, 3...
# advec_band_large::BaseLocal_A12_B08_C06                  t: 12; t-1: same loc + 8; t-2: same loc + 6
# advec_band_large::AdvecBand_A12_B06p23_C06         t: 12; t-1: same loc + 6 local + upstream (2, ...
# full20_ratio::FullLag_A20_B20_C20                      t: 20; t-1: same loc + 20; t-2: same loc + 20
# full20_ratio::RatioBudget_A27_B20_C13                  t: 27; t-1: same loc + 20; t-2: same loc + 13

# %% [markdown]
# ## Simulation Helpers

# %%
P_LABELS = ["sigmasq", "range_lat", "range_lon", "range_time", "advec_lat", "advec_lon", "nugget"]
P_COLS = ["sigmasq_est", "range_lat_est", "range_lon_est", "range_t_est", "advec_lat_est", "advec_lon_est", "nugget_est"]
SPATIAL_KEYS = ["sigmasq", "range_lat", "range_lon"]
ADVECTION_KEYS = ["advec_lat", "advec_lon"]

def transform_log_phi_to_physical(p):
    phi1, phi2, phi3, phi4 = (torch.exp(p[i]) for i in range(4))
    rlon = 1.0 / phi2
    return torch.stack([
        phi1 / phi2,
        rlon / torch.sqrt(phi3),
        rlon,
        rlon / torch.sqrt(phi4),
        p[4],
        p[5],
        torch.exp(p[6]),
    ])

def get_covariance_on_grid(lx, ly, lt, params):
    params = torch.clamp(params, min=-15.0, max=15.0)
    phi1, phi2, phi3, phi4 = (torch.exp(params[i]) for i in range(4))
    u_lat = lx - params[4] * lt
    u_lon = ly - params[5] * lt
    dist = torch.sqrt(u_lat.pow(2) * phi3 + u_lon.pow(2) + lt.pow(2) * phi4 + 1e-8)
    return (phi1 / phi2) * torch.exp(-dist * phi2)

def build_target_grid(lat_range, lon_range):
    lat0, lat1 = float(min(lat_range)), float(max(lat_range))
    lon0, lon1 = float(min(lon_range)), float(max(lon_range))
    n_lat = int(np.floor((lat1 - lat0) / DELTA_LAT + 1e-9)) + 1
    n_lon = int(np.floor((lon1 - lon0) / DELTA_LON + 1e-9)) + 1
    lats = lat0 + torch.arange(n_lat, device=DEVICE, dtype=DTYPE) * DELTA_LAT
    lons = lon0 + torch.arange(n_lon, device=DEVICE, dtype=DTYPE) * DELTA_LON
    lats = torch.round(lats * 10000) / 10000
    lons = torch.round(lons * 10000) / 10000
    g_lat, g_lon = torch.meshgrid(lats, lons, indexing="ij")
    grid_coords = torch.stack([g_lat.flatten(), g_lon.flatten()], dim=1)
    return lats, lons, grid_coords

def grid_resolution_report(lats, lons):
    lat_d = torch.diff(lats).detach().cpu().numpy()
    lon_d = torch.diff(lons).detach().cpu().numpy()
    return {
        "lat_min_step": float(lat_d.min()) if len(lat_d) else np.nan,
        "lat_max_step": float(lat_d.max()) if len(lat_d) else np.nan,
        "lon_min_step": float(lon_d.min()) if len(lon_d) else np.nan,
        "lon_max_step": float(lon_d.max()) if len(lon_d) else np.nan,
        "lat_first_last": (float(lats[0]), float(lats[-1])),
        "lon_first_last": (float(lons[0]), float(lons[-1])),
    }

def generate_field_values(n_lat, n_lon, t_steps, params):
    cpu = torch.device("cpu")
    f32 = torch.float32
    px, py, pt = 2 * n_lat, 2 * n_lon, 2 * t_steps
    lx = torch.arange(px, device=cpu, dtype=f32) * DELTA_LAT
    lx[px // 2:] -= px * DELTA_LAT
    ly = torch.arange(py, device=cpu, dtype=f32) * DELTA_LON
    ly[py // 2:] -= py * DELTA_LON
    lt = torch.arange(pt, device=cpu, dtype=f32)
    lt[pt // 2:] -= pt
    params_cpu = params.cpu().float()
    Lx, Ly, Lt = torch.meshgrid(lx, ly, lt, indexing="ij")
    C = get_covariance_on_grid(Lx, Ly, Lt, params_cpu)
    S = torch.fft.fftn(C)
    S.real = torch.clamp(S.real, min=0)
    noise = torch.fft.fftn(torch.randn(px, py, pt, device=cpu, dtype=f32))
    field = torch.fft.ifftn(torch.sqrt(S.real) * noise).real[:n_lat, :n_lon, :t_steps]
    return field.to(device=DEVICE, dtype=DTYPE)

def assemble_reg_map(field, grid_coords, true_params, t_offset=21.0):
    nugget_std = torch.sqrt(torch.exp(true_params[6]))
    n_grid = grid_coords.shape[0]
    field_flat = field.reshape(n_grid, field.shape[-1])
    reg_map = {}
    for t_idx in range(field.shape[-1]):
        key = f"t{t_idx}"
        t_val = float(t_offset + t_idx)
        dummy = torch.zeros(7, device=DEVICE, dtype=DTYPE)
        if t_idx > 0:
            dummy[t_idx - 1] = 1.0
        rows = torch.zeros((n_grid, 11), device=DEVICE, dtype=DTYPE)
        rows[:, :2] = grid_coords
        rows[:, 2] = field_flat[:, t_idx] + torch.randn(n_grid, device=DEVICE, dtype=DTYPE) * nugget_std
        rows[:, 3] = t_val
        rows[:, 4:] = dummy.unsqueeze(0).expand(n_grid, -1)
        reg_map[key] = rows.detach()
    return reg_map

def compute_grid_ordering(grid_coords, mm_cond_number):
    coords_np = grid_coords.detach().cpu().numpy()
    ord_mm = _orderings.maxmin_cpp(coords_np)
    nns = _orderings.find_nns_l2(locs=coords_np[ord_mm], max_nn=mm_cond_number)
    return ord_mm, nns

def true_to_log_params(true_dict):
    phi2 = 1.0 / true_dict["range_lon"]
    phi1 = true_dict["sigmasq"] * phi2
    phi3 = (true_dict["range_lon"] / true_dict["range_lat"]) ** 2
    phi4 = (true_dict["range_lon"] / true_dict["range_time"]) ** 2
    return [np.log(phi1), np.log(phi2), np.log(phi3), np.log(phi4), true_dict["advec_lat"], true_dict["advec_lon"], np.log(true_dict["nugget"])]

def backmap_params(out_params):
    p = [x.item() if isinstance(x, torch.Tensor) else float(x) for x in out_params[:7]]
    phi2 = np.exp(p[1])
    phi3 = np.exp(p[2])
    phi4 = np.exp(p[3])
    rlon = 1.0 / phi2
    return {
        "sigmasq": np.exp(p[0]) / phi2,
        "range_lat": rlon / phi3 ** 0.5,
        "range_lon": rlon,
        "range_time": rlon / phi4 ** 0.5,
        "advec_lat": p[4],
        "advec_lon": p[5],
        "nugget": np.exp(p[6]),
    }

def rmsre_for_keys(est, true_dict, keys, zero_thresh=0.01):
    vals = []
    for key in keys:
        tv = true_dict[key]
        ev = est[key]
        if abs(tv) >= zero_thresh:
            vals.append(((ev - tv) / abs(tv)) ** 2)
        else:
            vals.append(abs(ev - tv) ** 2)
    return float(np.sqrt(np.mean(vals)))

def relative_se_summary(se_by_key, denom_dict, keys, zero_thresh=0.01):
    vals = []
    for key in keys:
        denom = abs(denom_dict[key])
        if denom >= zero_thresh:
            vals.append((se_by_key[key] / denom) ** 2)
        else:
            vals.append(se_by_key[key] ** 2)
    return float(np.sqrt(np.mean(vals)))

def calculate_metrics(out_params, true_dict):
    est = backmap_params(out_params)
    return {
        "overall_rmsre": rmsre_for_keys(est, true_dict, P_LABELS),
        "spatial_rmsre": rmsre_for_keys(est, true_dict, SPATIAL_KEYS),
        "range_time_re": abs(est["range_time"] - true_dict["range_time"]) / abs(true_dict["range_time"]),
        "advec_rmsre": rmsre_for_keys(est, true_dict, ADVECTION_KEYS),
        "nugget_re": abs(est["nugget"] - true_dict["nugget"]) / abs(true_dict["nugget"]),
        "est": est,
    }

def make_random_init(rng, true_log, init_noise):
    noisy = list(true_log)
    for i in [0, 1, 2, 3, 6]:
        noisy[i] = true_log[i] + rng.uniform(-init_noise, init_noise)
    for i in [4, 5]:
        scale = max(abs(true_log[i]), 0.05)
        noisy[i] = true_log[i] + rng.uniform(-2 * scale, 2 * scale)
    return noisy

# %% [markdown]
# ## Optional Godambe Helpers

# %%
def finite_diff_hessian(nll_fn, p, eps=HESSIAN_EPS):
    n = p.shape[0]
    H = torch.zeros(n, n, device=p.device, dtype=p.dtype)
    for i in range(n):
        p_p = p.detach().clone(); p_m = p.detach().clone()
        p_p[i] += eps; p_m[i] -= eps
        p_p.requires_grad_(True); p_m.requires_grad_(True)
        g_p = torch.autograd.grad(nll_fn(p_p), p_p)[0].detach()
        g_m = torch.autograd.grad(nll_fn(p_m), p_m)[0].detach()
        H[i] = (g_p - g_m) / (2.0 * eps)
    return (H + H.T) / 2.0

def vecchia_per_unit_target_coords(model):
    chunks = []
    if model.Heads_data is not None and model.Heads_data.shape[0] > 0:
        chunks.append(model.Heads_data[:, [0, 1, 3]].to(dtype=DTYPE))
    for X_b in [model.X_A, model.X_AB, model.X_ABC]:
        if X_b is not None and X_b.shape[0] > 0:
            chunks.append(X_b[:, -1, :].to(dtype=DTYPE))
    if not chunks:
        return torch.empty((0, 3), device=DEVICE, dtype=DTYPE)
    return torch.cat(chunks, dim=0)

def make_block_ids(target_coords):
    lat = target_coords[:, 0]
    lon = target_coords[:, 1]
    tim = target_coords[:, 2]
    lat_id = torch.floor((lat - lat.min()) / GODAMBE_BLOCK_LAT_WIDTH).to(torch.long)
    lon_id = torch.floor((lon - lon.min()) / GODAMBE_BLOCK_LON_WIDTH).to(torch.long)
    if GODAMBE_BLOCK_TIME_WIDTH is None or GODAMBE_BLOCK_TIME_WIDTH <= 0:
        time_id = torch.zeros_like(lat_id)
    else:
        time_id = torch.floor((tim - tim.min()) / GODAMBE_BLOCK_TIME_WIDTH).to(torch.long)
    n_lon = int(lon_id.max().item()) + 1 if lon_id.numel() else 1
    n_time = int(time_id.max().item()) + 1 if time_id.numel() else 1
    raw_id = (lat_id * n_lon + lon_id) * n_time + time_id
    _, block_id = torch.unique(raw_id, sorted=True, return_inverse=True)
    return block_id

def score_cov_per_unit_centered(score_mat):
    n_units = score_mat.shape[1]
    score_mean = score_mat.mean(dim=1)
    score_centered = score_mat - score_mean.unsqueeze(1)
    if n_units > 1:
        return score_centered @ score_centered.T / (n_units * (n_units - 1))
    return score_mat @ score_mat.T / max(n_units ** 2, 1)

def score_cov_block_cluster(score_mat, target_coords):
    n_units = score_mat.shape[1]
    scores = score_mat.T.contiguous()
    block_id = make_block_ids(target_coords)
    n_blocks = int(block_id.max().item()) + 1 if block_id.numel() else 0
    block_scores = torch.zeros((n_blocks, scores.shape[1]), device=DEVICE, dtype=DTYPE)
    block_scores.index_add_(0, block_id, scores)
    if n_blocks > 1:
        centered = block_scores - block_scores.mean(dim=0, keepdim=True)
        J = centered.T @ centered * (n_blocks / (n_blocks - 1)) / (n_units ** 2)
    else:
        J = block_scores.T @ block_scores / max(n_units ** 2, 1)
    return J, n_blocks

def compute_vecchia_godambe(model, raw_params):
    p_hat = torch.tensor(raw_params[:7], device=DEVICE, dtype=DTYPE, requires_grad=True)

    def nll(p):
        return model.vecchia_batched_likelihood(p)

    H = finite_diff_hessian(nll, p_hat)
    eig = torch.linalg.eigvalsh(H).detach()
    h_abs_min = torch.clamp(torch.min(torch.abs(eig)), min=1e-12)
    h_cond = float((torch.max(torch.abs(eig)) / h_abs_min).detach().cpu())
    beta_hat = model.get_gls_beta(p_hat).detach()

    def per_unit_losses(p):
        return model.vecchia_per_unit_nll_terms(p, beta_hat)

    cols = []
    for k in range(p_hat.shape[0]):
        pp = p_hat.detach().clone(); pm = p_hat.detach().clone()
        pp[k] += SCORE_EPS; pm[k] -= SCORE_EPS
        with torch.no_grad():
            cols.append((per_unit_losses(pp) - per_unit_losses(pm)) / (2.0 * SCORE_EPS))
    score_mat = torch.stack(cols)
    n_units = score_mat.shape[1]
    target_coords = vecchia_per_unit_target_coords(model)
    if target_coords.shape[0] != n_units:
        raise RuntimeError(f"target/score mismatch: targets={target_coords.shape[0]}, scores={n_units}")

    score_mean = score_mat.mean(dim=1)
    p_grad = p_hat.detach().clone().requires_grad_(True)
    profile_grad = torch.autograd.grad(nll(p_grad), p_grad)[0].detach()
    score_grad_diff = profile_grad - score_mean

    J_uncentered = score_mat @ score_mat.T / (n_units ** 2)
    J_centered = score_cov_per_unit_centered(score_mat)
    J_block, n_blocks = score_cov_block_cluster(score_mat, target_coords)
    if GODAMBE_J_METHOD == "block":
        J_main = J_block
    elif GODAMBE_J_METHOD == "per_unit_centered":
        J_main = J_centered
    elif GODAMBE_J_METHOD == "per_unit_uncentered":
        J_main = J_uncentered
    else:
        raise ValueError(f"Unknown GODAMBE_J_METHOD={GODAMBE_J_METHOD!r}")

    eye = torch.eye(H.shape[0], device=DEVICE, dtype=DTYPE)
    h_scale = torch.clamp(torch.mean(torch.abs(torch.diag(H))), min=1.0)
    H_inv = torch.linalg.pinv(H + eye * h_scale * H_RIDGE_SCALE)
    Jac = torch.autograd.functional.jacobian(transform_log_phi_to_physical, p_hat)

    def summarize_J(J):
        G_raw = H_inv @ J @ H_inv
        G_phys = Jac @ G_raw @ Jac.T
        se = torch.sqrt(torch.clamp(torch.diag(G_phys), min=0.0)).detach().cpu().numpy()
        se_by_key = dict(zip(P_LABELS, [float(x) for x in se]))
        return se_by_key, {
            "spatial": relative_se_summary(se_by_key, TRUE_DICT, SPATIAL_KEYS),
            "overall": relative_se_summary(se_by_key, TRUE_DICT, P_LABELS),
            "advec": relative_se_summary(se_by_key, TRUE_DICT, ADVECTION_KEYS),
            "nugget": se_by_key["nugget"] / abs(TRUE_DICT["nugget"]),
        }

    se_main, rel_main = summarize_J(J_main)
    se_block, rel_block = summarize_J(J_block)
    se_centered, rel_centered = summarize_J(J_centered)
    se_uncentered, rel_uncentered = summarize_J(J_uncentered)
    return {
        "gim_j_method": GODAMBE_J_METHOD,
        "gim_n_units": int(n_units),
        "gim_n_blocks": int(n_blocks),
        "gim_h_cond_abs": h_cond,
        "gim_score_mean_max_abs": float(torch.max(torch.abs(score_mean)).detach().cpu()),
        "gim_profile_grad_max_abs": float(torch.max(torch.abs(profile_grad)).detach().cpu()),
        "gim_score_profile_diff_max_abs": float(torch.max(torch.abs(score_grad_diff)).detach().cpu()),
        "gim_spatial_rel_se": rel_main["spatial"],
        "gim_overall_rel_se": rel_main["overall"],
        "gim_advec_rel_se": rel_main["advec"],
        "gim_nugget_rel_se": rel_main["nugget"],
        "gim_spatial_rel_se_block": rel_block["spatial"],
        "gim_spatial_rel_se_perunit_centered": rel_centered["spatial"],
        "gim_spatial_rel_se_uncentered": rel_uncentered["spatial"],
        **{f"gim_se_{k}": v for k, v in se_main.items()},
    }

# %% [markdown]
# ## Fit And Monte Carlo

# %%
def fit_vecchia_spec(model_key, spec, reg_map_ord, nns_grid, ordered_grid_coords_np, initial_vals, compute_godambe=False):
    params = [torch.tensor([val], device=DEVICE, dtype=DTYPE, requires_grad=True) for val in initial_vals]
    daily_stride = int(spec.get("daily_stride", DAILY_STRIDE))
    if spec["kernel"] == "std":
        model = kernels_vecchia.fit_vecchia_lbfgs(
            smooth=SMOOTH,
            input_map=reg_map_ord,
            nns_map=nns_grid,
            mm_cond_number=MM_COND_NUMBER,
            nheads=NHEADS,
            limit_A=spec["limit_A"],
            limit_B=spec["limit_B"],
            limit_C=spec["limit_C"],
            daily_stride=daily_stride,
        )
    elif spec["kernel"] == "advec_band":
        model = kernels_vecchia_advec_band.fit_vecchia_lbfgs_advec_band(
            smooth=SMOOTH,
            input_map=reg_map_ord,
            nns_map=nns_grid,
            mm_cond_number=MM_COND_NUMBER,
            nheads=NHEADS,
            limit_A=spec["limit_A"],
            limit_B=spec["limit_B"],
            limit_C=spec["limit_C"],
            daily_stride=daily_stride,
            spatial_coords=ordered_grid_coords_np,
            lon_resolution=spec.get("lon_resolution", DELTA_LON),
            advec_cell_offsets=spec.get("advec_cell_offsets", (2, 3)),
        )
    else:
        raise ValueError(f"Unknown kernel: {spec['kernel']}")

    t0 = time.time()
    if SUPPRESS_FIT_PRINTS:
        with contextlib.redirect_stdout(io.StringIO()):
            model.precompute_conditioning_sets()
    else:
        model.precompute_conditioning_sets()
    precompute_s = time.time() - t0

    optimizer = model.set_optimizer(params, lr=1.0, max_iter=LBFGS_EVAL, history_size=LBFGS_HIST)
    t1 = time.time()
    if SUPPRESS_FIT_PRINTS:
        with contextlib.redirect_stdout(io.StringIO()):
            out, n_iter = model.fit_vecc_lbfgs(params, optimizer, max_steps=LBFGS_STEPS, grad_tol=1e-5)
    else:
        out, n_iter = model.fit_vecc_lbfgs(params, optimizer, max_steps=LBFGS_STEPS, grad_tol=1e-5)
    fit_s = time.time() - t1

    metrics = calculate_metrics(out, TRUE_DICT)
    godambe = {}
    gim_s = 0.0
    if compute_godambe:
        t2 = time.time()
        godambe = compute_vecchia_godambe(model, [float(x) for x in out[:7]])
        gim_s = time.time() - t2
    return out, float(out[-1]), int(n_iter), precompute_s, fit_s, gim_s, metrics, godambe

def run_experiment(num_iters=MC_NUM_ITERS, seed=SEED, compute_godambe=False, save_csv=True, csv_name=None):
    rng = np.random.default_rng(seed)
    torch.manual_seed(seed)
    true_log = true_to_log_params(TRUE_DICT)
    true_params = torch.tensor(true_log, device=DEVICE, dtype=DTYPE)
    lats_grid, lons_grid, grid_coords = build_target_grid(LAT_RANGE, LON_RANGE)
    n_lat, n_lon = len(lats_grid), len(lons_grid)
    print(f"Grid: {n_lat} x {n_lon} x {T_STEPS} = {n_lat * n_lon * T_STEPS:,} rows")
    print("Actual resolution:", grid_resolution_report(lats_grid, lons_grid))
    print("Model specs:")
    display(pd.DataFrame(MODEL_SPECS).T[["group", "kernel", "limit_A", "limit_B", "limit_C", "daily_stride", "uses_lag2", "allocation", "total_conditioning", "description"]])
    ord_grid, nns_grid = compute_grid_ordering(grid_coords, MM_COND_NUMBER)
    ordered_grid_coords_np = grid_coords[ord_grid].detach().cpu().numpy()
    print("Ordering done")

    records = []
    for it in range(num_iters):
        print(f"\n=== Iteration {it + 1}/{num_iters} ===")
        initial_vals = make_random_init(rng, true_log, INIT_NOISE)
        field = generate_field_values(n_lat, n_lon, T_STEPS, true_params)
        reg_map = assemble_reg_map(field, grid_coords, true_params)
        del field
        reg_map_ord = {k: v[ord_grid] for k, v in reg_map.items()}
        for model_key, spec in MODEL_SPECS.items():
            try:
                print(f"{model_key}: fitting", end="")
                out, loss, n_iter, pre_s, fit_s, gim_s, metrics, godambe = fit_vecchia_spec(
                    model_key, spec, reg_map_ord, nns_grid, ordered_grid_coords_np, initial_vals, compute_godambe=compute_godambe
                )
                est = metrics.pop("est")
                row = {
                    "iter": it + 1,
                    "model_key": model_key,
                    "model": spec["name"],
                    "group": spec["group"],
                    "kernel": spec["kernel"],
                    "allocation": spec["allocation"],
                    "limit_A": spec["limit_A"],
                    "limit_B": spec["limit_B"],
                    "limit_C": spec["limit_C"],
                    "daily_stride": spec.get("daily_stride", DAILY_STRIDE),
                    "uses_lag2": spec.get("uses_lag2", True),
                    "advec_cell_offsets": ",".join(map(str, spec.get("advec_cell_offsets", ()))),
                    "lag1_ratio_actual": spec["lag1_ratio_actual"],
                    "lag2_ratio_actual": spec["lag2_ratio_actual"],
                    "total_conditioning": spec["total_conditioning"],
                    "loss": round(loss, 6),
                    "overall_rmsre": round(metrics["overall_rmsre"], 6),
                    "spatial_rmsre": round(metrics["spatial_rmsre"], 6),
                    "range_time_re": round(metrics["range_time_re"], 6),
                    "advec_rmsre": round(metrics["advec_rmsre"], 6),
                    "nugget_re": round(metrics["nugget_re"], 6),
                    "precompute_s": round(pre_s, 3),
                    "fit_s": round(fit_s, 3),
                    "gim_s": round(gim_s, 3),
                    "total_s": round(pre_s + fit_s + gim_s, 3),
                    "fit_iter": n_iter,
                }
                row.update({
                    "sigmasq_est": round(est["sigmasq"], 6),
                    "range_lat_est": round(est["range_lat"], 6),
                    "range_lon_est": round(est["range_lon"], 6),
                    "range_t_est": round(est["range_time"], 6),
                    "advec_lat_est": round(est["advec_lat"], 6),
                    "advec_lon_est": round(est["advec_lon"], 6),
                    "nugget_est": round(est["nugget"], 6),
                })
                row.update(godambe)
                records.append(row)
                print(f" | loss={loss:.4f} spatial={metrics['spatial_rmsre']:.4f} overall={metrics['overall_rmsre']:.4f} time={pre_s + fit_s + gim_s:.1f}s")
            except Exception as exc:
                print(f" | FAILED: {type(exc).__name__}: {exc}")
                records.append({"iter": it + 1, "model_key": model_key, "model": spec.get("name", model_key), "group": spec.get("group"), "error": repr(exc)})
        if DEVICE.type == "cuda":
            torch.cuda.empty_cache()

    df = pd.DataFrame(records)
    if save_csv:
        out_dir = Path("log")
        out_dir.mkdir(exist_ok=True)
        if csv_name is None:
            csv_name = "sim_vecchia_lowres_x4_all_tests_results.csv"
        out_path = out_dir / csv_name
        df.to_csv(out_path, index=False)
        print("Saved:", out_path)
    return df

# %% [markdown]
# ## Optional One-Shot Godambe

# %%
if RUN_ONE_SHOT_GODAMBE:
    df_godambe = run_experiment(
        num_iters=1,
        seed=SEED,
        compute_godambe=True,
        save_csv=True,
        csv_name="sim_vecchia_lowres_x4_all_tests_godambe_043026_results.csv",
    )
    display(df_godambe.sort_values(["group", "gim_spatial_rel_se"]))
else:
    df_godambe = pd.DataFrame()
    print("Skipping one-shot Godambe. Set RUN_ONE_SHOT_GODAMBE=True to run it.")
# Out:
# Grid: 29 x 40 x 8 = 9,280 rows
# Actual resolution: {'lat_min_step': 0.1759999999999997, 'lat_max_step': 0.17600000000000016, 'lon_min_step': 0.25199999999998113, 'lon_max_step': 0.25200000000000955, 'lat_first_last': (-3.0, 1.928), 'lon_first_last': (121.0, 130.828)}
# Model specs:
#                                                                    group  \
# lag1_budget::Lag1_Realloc_B04_A12                            lag1_budget
# lag1_budget::Lag1_Realloc_B05_A11                            lag1_budget
# lag1_budget::Lag1_Realloc_B06_A10                            lag1_budget
# lag1_budget::Lag1_Realloc_B07_A09                            lag1_budget
# lag1_budget::Lag1_Full_B08_A08                               lag1_budget
# full8_current_realloc::FullLag_A08_B08_C08         full8_current_realloc
# full8_current_realloc::RatioBudget_A11_B08_C05     full8_current_realloc
# full8_current_realloc::CurrentRealloc_A12_B07_C05  full8_current_realloc
# lag2_half_quarter::HalfLag2_A12_B09_C06                lag2_half_quarter
# lag2_half_quarter::QuarterRealloc_A15_B09_C03          lag2_half_quarter
# lag2_half_none::HalfLag2_A12_B09_C06                      lag2_half_none
# lag2_half_none::NoLag2_A19_B09_C00                        lag2_half_none
# advec_band_small::BaseLocal_A06_B04_C02                 advec_band_small
# advec_band_small::AdvecBand_A06_B02p23_C02              advec_band_small
# advec_band_large::BaseLocal_A12_B08_C06                 advec_band_large
# advec_band_large::AdvecBand_A12_B06p23_C06              advec_band_large
# full20_ratio::FullLag_A20_B20_C20                           full20_ratio
# full20_ratio::RatioBudget_A27_B20_C13                       full20_ratio
#
#                                                        kernel limit_A limit_B  \
# lag1_budget::Lag1_Realloc_B04_A12                         std      12       4
# lag1_budget::Lag1_Realloc_B05_A11                         std      11       5
# lag1_budget::Lag1_Realloc_B06_A10                         std      10       6
# lag1_budget::Lag1_Realloc_B07_A09                         std       9       7
# lag1_budget::Lag1_Full_B08_A08                            std       8       8
# full8_current_realloc::FullLag_A08_B08_C08                std       8       8
# full8_current_realloc::RatioBudget_A11_B08_C05            std      11       8
# full8_current_realloc::CurrentRealloc_A12_B07_C05         std      12       7
# lag2_half_quarter::HalfLag2_A12_B09_C06                   std      12       9
# lag2_half_quarter::QuarterRealloc_A15_B09_C03             std      15       9
# lag2_half_none::HalfLag2_A12_B09_C06                      std      12       9
# lag2_half_none::NoLag2_A19_B09_C00                        std      19       9
# advec_band_small::BaseLocal_A06_B04_C02                   std       6       4
# advec_band_small::AdvecBand_A06_B02p23_C02         advec_band       6       2
# advec_band_large::BaseLocal_A12_B08_C06                   std      12       8
# advec_band_large::AdvecBand_A12_B06p23_C06         advec_band      12       6
# full20_ratio::FullLag_A20_B20_C20                         std      20      20
# full20_ratio::RatioBudget_A27_B20_C13                     std      27      20
#
#                                                   limit_C daily_stride  \
# lag1_budget::Lag1_Realloc_B04_A12                       0            9
# lag1_budget::Lag1_Realloc_B05_A11                       0            9
# lag1_budget::Lag1_Realloc_B06_A10                       0            9
# lag1_budget::Lag1_Realloc_B07_A09                       0            9
# lag1_budget::Lag1_Full_B08_A08                          0            9
# full8_current_realloc::FullLag_A08_B08_C08              8            2
# full8_current_realloc::RatioBudget_A11_B08_C05          5            2
# full8_current_realloc::CurrentRealloc_A12_B07_C05       5            2
# lag2_half_quarter::HalfLag2_A12_B09_C06                 6            2
# lag2_half_quarter::QuarterRealloc_A15_B09_C03           3            2
# lag2_half_none::HalfLag2_A12_B09_C06                    6            2
# lag2_half_none::NoLag2_A19_B09_C00                      0            9
# advec_band_small::BaseLocal_A06_B04_C02                 2            2
# advec_band_small::AdvecBand_A06_B02p23_C02              2            2
# advec_band_large::BaseLocal_A12_B08_C06                 6            2
# advec_band_large::AdvecBand_A12_B06p23_C06              6            2
# full20_ratio::FullLag_A20_B20_C20                      20            2
# full20_ratio::RatioBudget_A27_B20_C13                  13            2
#
#                                                   uses_lag2  \
# lag1_budget::Lag1_Realloc_B04_A12                     False
# lag1_budget::Lag1_Realloc_B05_A11                     False
# lag1_budget::Lag1_Realloc_B06_A10                     False
# lag1_budget::Lag1_Realloc_B07_A09                     False
# lag1_budget::Lag1_Full_B08_A08                        False
# full8_current_realloc::FullLag_A08_B08_C08             True
# full8_current_realloc::RatioBudget_A11_B08_C05         True
# full8_current_realloc::CurrentRealloc_A12_B07_C05      True
# lag2_half_quarter::HalfLag2_A12_B09_C06                True
# lag2_half_quarter::QuarterRealloc_A15_B09_C03          True
# lag2_half_none::HalfLag2_A12_B09_C06                   True
# lag2_half_none::NoLag2_A19_B09_C00                    False
# advec_band_small::BaseLocal_A06_B04_C02                True
# advec_band_small::AdvecBand_A06_B02p23_C02             True
# advec_band_large::BaseLocal_A12_B08_C06                True
# advec_band_large::AdvecBand_A12_B06p23_C06             True
# full20_ratio::FullLag_A20_B20_C20                      True
# full20_ratio::RatioBudget_A27_B20_C13                  True
#
#                                                                                   allocation  \
# lag1_budget::Lag1_Realloc_B04_A12                                               lag1 realloc
# lag1_budget::Lag1_Realloc_B05_A11                                               lag1 realloc
# lag1_budget::Lag1_Realloc_B06_A10                                               lag1 realloc
# lag1_budget::Lag1_Realloc_B07_A09                                               lag1 realloc
# lag1_budget::Lag1_Full_B08_A08                                                     lag1 full
# full8_current_realloc::FullLag_A08_B08_C08                                             8/8/8
# full8_current_realloc::RatioBudget_A11_B08_C05                    x/0.75x/0.5x matched-total
# full8_current_realloc::CurrentRealloc_A12_B07_C05              more-current, reduced t-1/t-2
# lag2_half_quarter::HalfLag2_A12_B09_C06                                         x/0.75x/0.5x
# lag2_half_quarter::QuarterRealloc_A15_B09_C03             t-2 quarter, reallocate to current
# lag2_half_none::HalfLag2_A12_B09_C06                                     t-1 0.75x, t-2 0.5x
# lag2_half_none::NoLag2_A19_B09_C00                             no t-2, reallocate to current
# advec_band_small::BaseLocal_A06_B04_C02                                       local baseline
# advec_band_small::AdvecBand_A06_B02p23_C02         replace two lag1 local with upstream band
# advec_band_large::BaseLocal_A12_B08_C06                                       local baseline
# advec_band_large::AdvecBand_A12_B06p23_C06         replace two lag1 local with upstream band
# full20_ratio::FullLag_A20_B20_C20                                                   20/20/20
# full20_ratio::RatioBudget_A27_B20_C13                             x/0.75x/0.5x matched-total
#
#                                                   total_conditioning  \
# lag1_budget::Lag1_Realloc_B04_A12                                 17
# lag1_budget::Lag1_Realloc_B05_A11                                 17
# lag1_budget::Lag1_Realloc_B06_A10                                 17
# lag1_budget::Lag1_Realloc_B07_A09                                 17
# lag1_budget::Lag1_Full_B08_A08                                    17
# full8_current_realloc::FullLag_A08_B08_C08                        26
# full8_current_realloc::RatioBudget_A11_B08_C05                    26
# full8_current_realloc::CurrentRealloc_A12_B07_C05                 26
# lag2_half_quarter::HalfLag2_A12_B09_C06                           29
# lag2_half_quarter::QuarterRealloc_A15_B09_C03                     29
# lag2_half_none::HalfLag2_A12_B09_C06                              29
# lag2_half_none::NoLag2_A19_B09_C00                                29
# advec_band_small::BaseLocal_A06_B04_C02                           14
# advec_band_small::AdvecBand_A06_B02p23_C02                        14
# advec_band_large::BaseLocal_A12_B08_C06                           28
# advec_band_large::AdvecBand_A12_B06p23_C06                        28
# full20_ratio::FullLag_A20_B20_C20                                 62
# full20_ratio::RatioBudget_A27_B20_C13                             62
#
#                                                                                          description
# lag1_budget::Lag1_Realloc_B04_A12                                   t: 12; t-1: same loc + 4; no t-2
# lag1_budget::Lag1_Realloc_B05_A11                                   t: 11; t-1: same loc + 5; no t-2
# lag1_budget::Lag1_Realloc_B06_A10                                   t: 10; t-1: same loc + 6; no t-2
# lag1_budget::Lag1_Realloc_B07_A09                                    t: 9; t-1: same loc + 7; no t-2
# lag1_budget::Lag1_Full_B08_A08                                       t: 8; t-1: same loc + 8; no t-2
# full8_current_realloc::FullLag_A08_B08_C08                t: 8; t-1: same loc + 8; t-2: same loc + 8
# full8_current_realloc::RatioBudget_A11_B08_C05           t: 11; t-1: same loc + 8; t-2: same loc + 5
# full8_current_realloc::CurrentRealloc_A12_B07_C05        t: 12; t-1: same loc + 7; t-2: same loc + 5
# lag2_half_quarter::HalfLag2_A12_B09_C06                  t: 12; t-1: same loc + 9; t-2: same loc + 6
# lag2_half_quarter::QuarterRealloc_A15_B09_C03            t: 15; t-1: same loc + 9; t-2: same loc + 3
# lag2_half_none::HalfLag2_A12_B09_C06                     t: 12; t-1: same loc + 9; t-2: same loc + 6
# lag2_half_none::NoLag2_A19_B09_C00                                  t: 19; t-1: same loc + 9; no t-2
# advec_band_small::BaseLocal_A06_B04_C02                   t: 6; t-1: same loc + 4; t-2: same loc + 2
# advec_band_small::AdvecBand_A06_B02p23_C02         t: 6; t-1: same loc + 2 local + upstream (2, 3...
# advec_band_large::BaseLocal_A12_B08_C06                  t: 12; t-1: same loc + 8; t-2: same loc + 6
# advec_band_large::AdvecBand_A12_B06p23_C06         t: 12; t-1: same loc + 6 local + upstream (2, ...
# full20_ratio::FullLag_A20_B20_C20                      t: 20; t-1: same loc + 20; t-2: same loc + 20
# full20_ratio::RatioBudget_A27_B20_C13                  t: 27; t-1: same loc + 20; t-2: same loc + 13
# Ordering done
#
# === Iteration 1/1 ===
# lag1_budget::Lag1_Realloc_B04_A12: fitting | loss=1.6008 spatial=0.1180 overall=0.2378 time=5.0s
# lag1_budget::Lag1_Realloc_B05_A11: fitting | loss=1.6030 spatial=0.1629 overall=0.2474 time=4.7s
# lag1_budget::Lag1_Realloc_B06_A10: fitting | loss=1.6018 spatial=0.1067 overall=0.1865 time=5.1s
# lag1_budget::Lag1_Realloc_B07_A09: fitting | loss=1.6006 spatial=0.1367 overall=0.2137 time=4.3s
# lag1_budget::Lag1_Full_B08_A08: fitting | loss=1.6066 spatial=0.0874 overall=0.1226 time=4.5s
# full8_current_realloc::FullLag_A08_B08_C08: fitting | loss=1.5997 spatial=0.0865 overall=0.1712 time=9.1s
# full8_current_realloc::RatioBudget_A11_B08_C05: fitting | loss=1.5989 spatial=0.1113 overall=0.1813 time=9.2s
# full8_current_realloc::CurrentRealloc_A12_B07_C05: fitting | loss=1.6069 spatial=0.0873 overall=0.1576 time=10.8s
# lag2_half_quarter::HalfLag2_A12_B09_C06: fitting | loss=1.5985 spatial=0.0411 overall=0.0982 time=11.3s
# lag2_half_quarter::QuarterRealloc_A15_B09_C03: fitting | loss=1.6029 spatial=0.2255 overall=0.3588 time=15.2s
# lag2_half_none::HalfLag2_A12_B09_C06: fitting | loss=1.5985 spatial=0.0411 overall=0.0982 time=10.7s
# lag2_half_none::NoLag2_A19_B09_C00: fitting | loss=1.6001 spatial=0.1207 overall=0.2225 time=10.1s
# advec_band_small::BaseLocal_A06_B04_C02: fitting | loss=1.6053 spatial=0.1150 overall=0.2299 time=3.8s
# advec_band_small::AdvecBand_A06_B02p23_C02: fitting | loss=1.6144 spatial=0.1125 overall=0.1994 time=4.2s
# advec_band_large::BaseLocal_A12_B08_C06: fitting | loss=1.6008 spatial=0.0474 overall=0.0992 time=10.8s
# advec_band_large::AdvecBand_A12_B06p23_C06: fitting | loss=1.6057 spatial=0.0469 overall=0.0798 time=9.7s
# full20_ratio::FullLag_A20_B20_C20: fitting | loss=1.5996 spatial=0.0951 overall=0.2145 time=35.0s
# full20_ratio::RatioBudget_A27_B20_C13: fitting | loss=1.5931 spatial=0.0892 overall=0.1788 time=34.3s
# Saved: log/sim_vecchia_lowres_x4_all_tests_godambe_043026_results.csv
#     iter                                          model_key  \
# 15     1         advec_band_large::AdvecBand_A12_B06p23_C06
# 14     1            advec_band_large::BaseLocal_A12_B08_C06
# 13     1         advec_band_small::AdvecBand_A06_B02p23_C02
# 12     1            advec_band_small::BaseLocal_A06_B04_C02
# 17     1              full20_ratio::RatioBudget_A27_B20_C13
# 16     1                  full20_ratio::FullLag_A20_B20_C20
# 5      1         full8_current_realloc::FullLag_A08_B08_C08
# 6      1     full8_current_realloc::RatioBudget_A11_B08_C05
# 7      1  full8_current_realloc::CurrentRealloc_A12_B07_C05
# 3      1                  lag1_budget::Lag1_Realloc_B07_A09
# 4      1                     lag1_budget::Lag1_Full_B08_A08
# 2      1                  lag1_budget::Lag1_Realloc_B06_A10
# 1      1                  lag1_budget::Lag1_Realloc_B05_A11
# 0      1                  lag1_budget::Lag1_Realloc_B04_A12
# 11     1                 lag2_half_none::NoLag2_A19_B09_C00
# 10     1               lag2_half_none::HalfLag2_A12_B09_C06
# 9      1      lag2_half_quarter::QuarterRealloc_A15_B09_C03
# 8      1            lag2_half_quarter::HalfLag2_A12_B09_C06
#
#                          model                  group      kernel  \
# 15    AdvecBand_A12_B06p23_C06       advec_band_large  advec_band
# 14       BaseLocal_A12_B08_C06       advec_band_large         std
# 13    AdvecBand_A06_B02p23_C02       advec_band_small  advec_band
# 12       BaseLocal_A06_B04_C02       advec_band_small         std
# 17     RatioBudget_A27_B20_C13           full20_ratio         std
# 16         FullLag_A20_B20_C20           full20_ratio         std
# 5          FullLag_A08_B08_C08  full8_current_realloc         std
# 6      RatioBudget_A11_B08_C05  full8_current_realloc         std
# 7   CurrentRealloc_A12_B07_C05  full8_current_realloc         std
# 3         Lag1_Realloc_B07_A09            lag1_budget         std
# 4            Lag1_Full_B08_A08            lag1_budget         std
# 2         Lag1_Realloc_B06_A10            lag1_budget         std
# 1         Lag1_Realloc_B05_A11            lag1_budget         std
# 0         Lag1_Realloc_B04_A12            lag1_budget         std
# 11          NoLag2_A19_B09_C00         lag2_half_none         std
# 10        HalfLag2_A12_B09_C06         lag2_half_none         std
# 9   QuarterRealloc_A15_B09_C03      lag2_half_quarter         std
# 8         HalfLag2_A12_B09_C06      lag2_half_quarter         std
#
#                                    allocation  limit_A  limit_B  limit_C  \
# 15  replace two lag1 local with upstream band       12        6        6
# 14                             local baseline       12        8        6
# 13  replace two lag1 local with upstream band        6        2        2
# 12                             local baseline        6        4        2
# 17                 x/0.75x/0.5x matched-total       27       20       13
# 16                                   20/20/20       20       20       20
# 5                                       8/8/8        8        8        8
# 6                  x/0.75x/0.5x matched-total       11        8        5
# 7               more-current, reduced t-1/t-2       12        7        5
# 3                                lag1 realloc        9        7        0
# 4                                   lag1 full        8        8        0
# 2                                lag1 realloc       10        6        0
# 1                                lag1 realloc       11        5        0
# 0                                lag1 realloc       12        4        0
# 11              no t-2, reallocate to current       19        9        0
# 10                        t-1 0.75x, t-2 0.5x       12        9        6
# 9          t-2 quarter, reallocate to current       15        9        3
# 8                                x/0.75x/0.5x       12        9        6
#
#     daily_stride  ...  gim_spatial_rel_se_block  \
# 15             2  ...                  0.092321
# 14             2  ...                  0.102820
# 13             2  ...                  0.078324
# 12             2  ...                  0.085923
# 17             2  ...                  0.090247
# 16             2  ...                  0.096455
# 5              2  ...                  0.090782
# 6              2  ...                  0.092434
# 7              2  ...                  0.096931
# 3              9  ...                  0.073189
# 4              9  ...                  0.082622
# 2              9  ...                  0.082638
# 1              9  ...                  0.083439
# 0              9  ...                  0.086193
# 11             9  ...                  0.082653
# 10             2  ...                  0.096564
# 9              2  ...                  0.082263
# 8              2  ...                  0.096564
#
#    gim_spatial_rel_se_perunit_centered  gim_spatial_rel_se_uncentered  \
# 15                            0.057816                       0.057813
# 14                            0.062718                       0.062714
# 13                            0.053124                       0.053121
# 12                            0.054619                       0.054616
# 17                            0.054739                       0.054736
# 16                            0.051035                       0.051032
# 5                             0.054896                       0.054893
# 6                             0.056800                       0.056797
# 7                             0.057965                       0.057962
# 3                             0.052785                       0.052782
# 4                             0.059931                       0.059928
# 2                             0.056261                       0.056258
# 1                             0.057736                       0.057733
# 0                             0.057000                       0.056997
# 11                            0.057248                       0.057245
# 10                            0.058178                       0.058175
# 9                             0.048857                       0.048854
# 8                             0.058178                       0.058175
#
#     gim_se_sigmasq  gim_se_range_lat  gim_se_range_lon  gim_se_range_time  \
# 15        0.646962          0.033500          0.037766           0.249714
# 14        0.700363          0.037344          0.042550           0.275313
# 13        0.666400          0.025762          0.032468           0.199486
# 12        0.714566          0.028264          0.036146           0.198583
# 17        0.726674          0.031525          0.036022           0.192429
# 16        0.711217          0.033513          0.040740           0.244754
# 5         0.712505          0.032265          0.035956           0.226201
# 6         0.733101          0.032662          0.036670           0.218232
# 7         0.740676          0.034316          0.039226           0.234560
# 3         0.669355          0.023671          0.029295           0.175451
# 4         0.652601          0.028679          0.033661           0.229003
# 2         0.637203          0.028874          0.033854           0.211884
# 1         0.778047          0.027931          0.031406           0.194147
# 0         0.744308          0.028489          0.035167           0.197482
# 11        0.699263          0.027156          0.034435           0.180524
# 10        0.676501          0.034120          0.040913           0.257397
# 9         0.861285          0.024182          0.031966           0.158610
# 8         0.676501          0.034120          0.040913           0.257397
#
#     gim_se_advec_lat  gim_se_advec_lon  gim_se_nugget
# 15          0.013479          0.015149       0.450947
# 14          0.013653          0.015492       0.483703
# 13          0.011270          0.017836       0.503573
# 12          0.010791          0.016405       0.561255
# 17          0.011250          0.015238       0.537602
# 16          0.012665          0.015001       0.544765
# 5           0.014737          0.018558       0.519927
# 6           0.014602          0.014794       0.596889
# 7           0.013248          0.014039       0.571255
# 3           0.013274          0.015223       0.525704
# 4           0.012884          0.018474       0.500579
# 2           0.012335          0.014231       0.508081
# 1           0.012672          0.014508       0.658275
# 0           0.011712          0.014258       0.593681
# 11          0.011613          0.015114       0.586253
# 10          0.013043          0.015636       0.481062
# 9           0.011907          0.013843       0.764059
# 8           0.013043          0.015636       0.481062
#
# [18 rows x 54 columns]

# %% [markdown]
# ## Monte Carlo Sweep

# %%
df_mc = run_experiment(
    num_iters=MC_NUM_ITERS,
    seed=SEED,
    compute_godambe=False,
    save_csv=True,
    csv_name="sim_vecchia_lowres_x4_all_tests_mc_043026_results.csv",
)
df_mc.head()
# Out:
# Grid: 29 x 40 x 8 = 9,280 rows
# Actual resolution: {'lat_min_step': 0.1759999999999997, 'lat_max_step': 0.17600000000000016, 'lon_min_step': 0.25199999999998113, 'lon_max_step': 0.25200000000000955, 'lat_first_last': (-3.0, 1.928), 'lon_first_last': (121.0, 130.828)}
# Model specs:
#                                                                    group  \
# lag1_budget::Lag1_Realloc_B04_A12                            lag1_budget
# lag1_budget::Lag1_Realloc_B05_A11                            lag1_budget
# lag1_budget::Lag1_Realloc_B06_A10                            lag1_budget
# lag1_budget::Lag1_Realloc_B07_A09                            lag1_budget
# lag1_budget::Lag1_Full_B08_A08                               lag1_budget
# full8_current_realloc::FullLag_A08_B08_C08         full8_current_realloc
# full8_current_realloc::RatioBudget_A11_B08_C05     full8_current_realloc
# full8_current_realloc::CurrentRealloc_A12_B07_C05  full8_current_realloc
# lag2_half_quarter::HalfLag2_A12_B09_C06                lag2_half_quarter
# lag2_half_quarter::QuarterRealloc_A15_B09_C03          lag2_half_quarter
# lag2_half_none::HalfLag2_A12_B09_C06                      lag2_half_none
# lag2_half_none::NoLag2_A19_B09_C00                        lag2_half_none
# advec_band_small::BaseLocal_A06_B04_C02                 advec_band_small
# advec_band_small::AdvecBand_A06_B02p23_C02              advec_band_small
# advec_band_large::BaseLocal_A12_B08_C06                 advec_band_large
# advec_band_large::AdvecBand_A12_B06p23_C06              advec_band_large
# full20_ratio::FullLag_A20_B20_C20                           full20_ratio
# full20_ratio::RatioBudget_A27_B20_C13                       full20_ratio
#
#                                                        kernel limit_A limit_B  \
# lag1_budget::Lag1_Realloc_B04_A12                         std      12       4
# lag1_budget::Lag1_Realloc_B05_A11                         std      11       5
# lag1_budget::Lag1_Realloc_B06_A10                         std      10       6
# lag1_budget::Lag1_Realloc_B07_A09                         std       9       7
# lag1_budget::Lag1_Full_B08_A08                            std       8       8
# full8_current_realloc::FullLag_A08_B08_C08                std       8       8
# full8_current_realloc::RatioBudget_A11_B08_C05            std      11       8
# full8_current_realloc::CurrentRealloc_A12_B07_C05         std      12       7
# lag2_half_quarter::HalfLag2_A12_B09_C06                   std      12       9
# lag2_half_quarter::QuarterRealloc_A15_B09_C03             std      15       9
# lag2_half_none::HalfLag2_A12_B09_C06                      std      12       9
# lag2_half_none::NoLag2_A19_B09_C00                        std      19       9
# advec_band_small::BaseLocal_A06_B04_C02                   std       6       4
# advec_band_small::AdvecBand_A06_B02p23_C02         advec_band       6       2
# advec_band_large::BaseLocal_A12_B08_C06                   std      12       8
# advec_band_large::AdvecBand_A12_B06p23_C06         advec_band      12       6
# full20_ratio::FullLag_A20_B20_C20                         std      20      20
# full20_ratio::RatioBudget_A27_B20_C13                     std      27      20
#
#                                                   limit_C daily_stride  \
# lag1_budget::Lag1_Realloc_B04_A12                       0            9
# lag1_budget::Lag1_Realloc_B05_A11                       0            9
# lag1_budget::Lag1_Realloc_B06_A10                       0            9
# lag1_budget::Lag1_Realloc_B07_A09                       0            9
# lag1_budget::Lag1_Full_B08_A08                          0            9
# full8_current_realloc::FullLag_A08_B08_C08              8            2
# full8_current_realloc::RatioBudget_A11_B08_C05          5            2
# full8_current_realloc::CurrentRealloc_A12_B07_C05       5            2
# lag2_half_quarter::HalfLag2_A12_B09_C06                 6            2
# lag2_half_quarter::QuarterRealloc_A15_B09_C03           3            2
# lag2_half_none::HalfLag2_A12_B09_C06                    6            2
# lag2_half_none::NoLag2_A19_B09_C00                      0            9
# advec_band_small::BaseLocal_A06_B04_C02                 2            2
# advec_band_small::AdvecBand_A06_B02p23_C02              2            2
# advec_band_large::BaseLocal_A12_B08_C06                 6            2
# advec_band_large::AdvecBand_A12_B06p23_C06              6            2
# full20_ratio::FullLag_A20_B20_C20                      20            2
# full20_ratio::RatioBudget_A27_B20_C13                  13            2
#
#                                                   uses_lag2  \
# lag1_budget::Lag1_Realloc_B04_A12                     False
# lag1_budget::Lag1_Realloc_B05_A11                     False
# lag1_budget::Lag1_Realloc_B06_A10                     False
# lag1_budget::Lag1_Realloc_B07_A09                     False
# lag1_budget::Lag1_Full_B08_A08                        False
# full8_current_realloc::FullLag_A08_B08_C08             True
# full8_current_realloc::RatioBudget_A11_B08_C05         True
# full8_current_realloc::CurrentRealloc_A12_B07_C05      True
# lag2_half_quarter::HalfLag2_A12_B09_C06                True
# lag2_half_quarter::QuarterRealloc_A15_B09_C03          True
# lag2_half_none::HalfLag2_A12_B09_C06                   True
# lag2_half_none::NoLag2_A19_B09_C00                    False
# advec_band_small::BaseLocal_A06_B04_C02                True
# advec_band_small::AdvecBand_A06_B02p23_C02             True
# advec_band_large::BaseLocal_A12_B08_C06                True
# advec_band_large::AdvecBand_A12_B06p23_C06             True
# full20_ratio::FullLag_A20_B20_C20                      True
# full20_ratio::RatioBudget_A27_B20_C13                  True
#
#                                                                                   allocation  \
# lag1_budget::Lag1_Realloc_B04_A12                                               lag1 realloc
# lag1_budget::Lag1_Realloc_B05_A11                                               lag1 realloc
# lag1_budget::Lag1_Realloc_B06_A10                                               lag1 realloc
# lag1_budget::Lag1_Realloc_B07_A09                                               lag1 realloc
# lag1_budget::Lag1_Full_B08_A08                                                     lag1 full
# full8_current_realloc::FullLag_A08_B08_C08                                             8/8/8
# full8_current_realloc::RatioBudget_A11_B08_C05                    x/0.75x/0.5x matched-total
# full8_current_realloc::CurrentRealloc_A12_B07_C05              more-current, reduced t-1/t-2
# lag2_half_quarter::HalfLag2_A12_B09_C06                                         x/0.75x/0.5x
# lag2_half_quarter::QuarterRealloc_A15_B09_C03             t-2 quarter, reallocate to current
# lag2_half_none::HalfLag2_A12_B09_C06                                     t-1 0.75x, t-2 0.5x
# lag2_half_none::NoLag2_A19_B09_C00                             no t-2, reallocate to current
# advec_band_small::BaseLocal_A06_B04_C02                                       local baseline
# advec_band_small::AdvecBand_A06_B02p23_C02         replace two lag1 local with upstream band
# advec_band_large::BaseLocal_A12_B08_C06                                       local baseline
# advec_band_large::AdvecBand_A12_B06p23_C06         replace two lag1 local with upstream band
# full20_ratio::FullLag_A20_B20_C20                                                   20/20/20
# full20_ratio::RatioBudget_A27_B20_C13                             x/0.75x/0.5x matched-total
#
#                                                   total_conditioning  \
# lag1_budget::Lag1_Realloc_B04_A12                                 17
# lag1_budget::Lag1_Realloc_B05_A11                                 17
# lag1_budget::Lag1_Realloc_B06_A10                                 17
# lag1_budget::Lag1_Realloc_B07_A09                                 17
# lag1_budget::Lag1_Full_B08_A08                                    17
# full8_current_realloc::FullLag_A08_B08_C08                        26
# full8_current_realloc::RatioBudget_A11_B08_C05                    26
# full8_current_realloc::CurrentRealloc_A12_B07_C05                 26
# lag2_half_quarter::HalfLag2_A12_B09_C06                           29
# lag2_half_quarter::QuarterRealloc_A15_B09_C03                     29
# lag2_half_none::HalfLag2_A12_B09_C06                              29
# lag2_half_none::NoLag2_A19_B09_C00                                29
# advec_band_small::BaseLocal_A06_B04_C02                           14
# advec_band_small::AdvecBand_A06_B02p23_C02                        14
# advec_band_large::BaseLocal_A12_B08_C06                           28
# advec_band_large::AdvecBand_A12_B06p23_C06                        28
# full20_ratio::FullLag_A20_B20_C20                                 62
# full20_ratio::RatioBudget_A27_B20_C13                             62
#
#                                                                                          description
# lag1_budget::Lag1_Realloc_B04_A12                                   t: 12; t-1: same loc + 4; no t-2
# lag1_budget::Lag1_Realloc_B05_A11                                   t: 11; t-1: same loc + 5; no t-2
# lag1_budget::Lag1_Realloc_B06_A10                                   t: 10; t-1: same loc + 6; no t-2
# lag1_budget::Lag1_Realloc_B07_A09                                    t: 9; t-1: same loc + 7; no t-2
# lag1_budget::Lag1_Full_B08_A08                                       t: 8; t-1: same loc + 8; no t-2
# full8_current_realloc::FullLag_A08_B08_C08                t: 8; t-1: same loc + 8; t-2: same loc + 8
# full8_current_realloc::RatioBudget_A11_B08_C05           t: 11; t-1: same loc + 8; t-2: same loc + 5
# full8_current_realloc::CurrentRealloc_A12_B07_C05        t: 12; t-1: same loc + 7; t-2: same loc + 5
# lag2_half_quarter::HalfLag2_A12_B09_C06                  t: 12; t-1: same loc + 9; t-2: same loc + 6
# lag2_half_quarter::QuarterRealloc_A15_B09_C03            t: 15; t-1: same loc + 9; t-2: same loc + 3
# lag2_half_none::HalfLag2_A12_B09_C06                     t: 12; t-1: same loc + 9; t-2: same loc + 6
# lag2_half_none::NoLag2_A19_B09_C00                                  t: 19; t-1: same loc + 9; no t-2
# advec_band_small::BaseLocal_A06_B04_C02                   t: 6; t-1: same loc + 4; t-2: same loc + 2
# advec_band_small::AdvecBand_A06_B02p23_C02         t: 6; t-1: same loc + 2 local + upstream (2, 3...
# advec_band_large::BaseLocal_A12_B08_C06                  t: 12; t-1: same loc + 8; t-2: same loc + 6
# advec_band_large::AdvecBand_A12_B06p23_C06         t: 12; t-1: same loc + 6 local + upstream (2, ...
# full20_ratio::FullLag_A20_B20_C20                      t: 20; t-1: same loc + 20; t-2: same loc + 20
# full20_ratio::RatioBudget_A27_B20_C13                  t: 27; t-1: same loc + 20; t-2: same loc + 13
# Ordering done
#
# === Iteration 1/10 ===
# lag1_budget::Lag1_Realloc_B04_A12: fitting | loss=1.6008 spatial=0.1180 overall=0.2378 time=3.4s
# lag1_budget::Lag1_Realloc_B05_A11: fitting | loss=1.6030 spatial=0.1629 overall=0.2474 time=3.3s
# lag1_budget::Lag1_Realloc_B06_A10: fitting | loss=1.6018 spatial=0.1067 overall=0.1865 time=3.8s
# lag1_budget::Lag1_Realloc_B07_A09: fitting | loss=1.6006 spatial=0.1367 overall=0.2137 time=2.9s
# lag1_budget::Lag1_Full_B08_A08: fitting | loss=1.6066 spatial=0.0874 overall=0.1226 time=3.2s
# full8_current_realloc::FullLag_A08_B08_C08: fitting | loss=1.5997 spatial=0.0865 overall=0.1712 time=5.8s
# full8_current_realloc::RatioBudget_A11_B08_C05: fitting | loss=1.5989 spatial=0.1113 overall=0.1813 time=5.6s
# full8_current_realloc::CurrentRealloc_A12_B07_C05: fitting | loss=1.6069 spatial=0.0873 overall=0.1576 time=7.9s
# lag2_half_quarter::HalfLag2_A12_B09_C06: fitting | loss=1.5985 spatial=0.0411 overall=0.0982 time=8.5s
# lag2_half_quarter::QuarterRealloc_A15_B09_C03: fitting | loss=1.6029 spatial=0.2255 overall=0.3588 time=10.4s
# lag2_half_none::HalfLag2_A12_B09_C06: fitting | loss=1.5985 spatial=0.0411 overall=0.0982 time=7.7s
# lag2_half_none::NoLag2_A19_B09_C00: fitting | loss=1.6001 spatial=0.1207 overall=0.2225 time=7.1s
# advec_band_small::BaseLocal_A06_B04_C02: fitting | loss=1.6053 spatial=0.1150 overall=0.2299 time=3.5s
# advec_band_small::AdvecBand_A06_B02p23_C02: fitting | loss=1.6144 spatial=0.1125 overall=0.1994 time=3.8s
# advec_band_large::BaseLocal_A12_B08_C06: fitting | loss=1.6008 spatial=0.0474 overall=0.0992 time=7.1s
# advec_band_large::AdvecBand_A12_B06p23_C06: fitting | loss=1.6057 spatial=0.0469 overall=0.0798 time=6.3s
# full20_ratio::FullLag_A20_B20_C20: fitting | loss=1.5996 spatial=0.0951 overall=0.2145 time=26.3s
# full20_ratio::RatioBudget_A27_B20_C13: fitting | loss=1.5931 spatial=0.0892 overall=0.1788 time=21.7s
#
# === Iteration 2/10 ===
# lag1_budget::Lag1_Realloc_B04_A12: fitting | loss=1.5944 spatial=0.0455 overall=0.0794 time=4.0s
# lag1_budget::Lag1_Realloc_B05_A11: fitting | loss=1.5955 spatial=0.0500 overall=0.1593 time=2.2s
# lag1_budget::Lag1_Realloc_B06_A10: fitting | loss=1.5914 spatial=0.0532 overall=0.0887 time=2.7s
# lag1_budget::Lag1_Realloc_B07_A09: fitting | loss=1.6044 spatial=0.0187 overall=0.1564 time=3.1s
# lag1_budget::Lag1_Full_B08_A08: fitting | loss=1.6079 spatial=0.1019 overall=0.1359 time=3.3s
# full8_current_realloc::FullLag_A08_B08_C08: fitting | loss=1.6036 spatial=0.1137 overall=0.1633 time=5.4s
# full8_current_realloc::RatioBudget_A11_B08_C05: fitting | loss=1.5968 spatial=0.0462 overall=0.1731 time=5.8s
# full8_current_realloc::CurrentRealloc_A12_B07_C05: fitting | loss=1.6830 spatial=0.0789 overall=0.1803 time=3.9s
# lag2_half_quarter::HalfLag2_A12_B09_C06: fitting | loss=1.6013 spatial=0.0479 overall=0.0831 time=7.5s
# lag2_half_quarter::QuarterRealloc_A15_B09_C03: fitting | loss=1.5893 spatial=0.0479 overall=0.0850 time=7.0s
# lag2_half_none::HalfLag2_A12_B09_C06: fitting | loss=1.6013 spatial=0.0479 overall=0.0831 time=7.5s
# lag2_half_none::NoLag2_A19_B09_C00: fitting | loss=1.5804 spatial=0.0504 overall=0.1009 time=5.5s
# advec_band_small::BaseLocal_A06_B04_C02: fitting | loss=1.6012 spatial=0.0094 overall=0.0899 time=2.0s
# advec_band_small::AdvecBand_A06_B02p23_C02: fitting | loss=1.6937 spatial=0.0131 overall=0.1554 time=1.7s
# advec_band_large::BaseLocal_A12_B08_C06: fitting | loss=1.5990 spatial=0.0487 overall=0.0922 time=6.4s
# advec_band_large::AdvecBand_A12_B06p23_C06: fitting | loss=1.6043 spatial=0.0539 overall=0.1134 time=6.1s
# full20_ratio::FullLag_A20_B20_C20: fitting | loss=1.5796 spatial=0.0402 overall=0.1147 time=22.0s
# full20_ratio::RatioBudget_A27_B20_C13: fitting | loss=1.5951 spatial=0.0594 overall=0.1856 time=21.0s
#
# === Iteration 3/10 ===
# lag1_budget::Lag1_Realloc_B04_A12: fitting | loss=1.5982 spatial=0.0588 overall=0.1142 time=3.6s
# lag1_budget::Lag1_Realloc_B05_A11: fitting | loss=1.5899 spatial=0.1458 overall=0.1215 time=2.7s
# lag1_budget::Lag1_Realloc_B06_A10: fitting | loss=1.5956 spatial=0.0771 overall=0.1211 time=3.1s
# lag1_budget::Lag1_Realloc_B07_A09: fitting | loss=1.5962 spatial=0.1183 overall=0.1154 time=3.3s
# lag1_budget::Lag1_Full_B08_A08: fitting | loss=1.6087 spatial=0.0509 overall=0.1200 time=3.0s
# full8_current_realloc::FullLag_A08_B08_C08: fitting | loss=1.6124 spatial=0.0938 overall=0.1551 time=6.4s
# full8_current_realloc::RatioBudget_A11_B08_C05: fitting | loss=1.5975 spatial=0.0870 overall=0.1103 time=5.6s
# full8_current_realloc::CurrentRealloc_A12_B07_C05: fitting | loss=1.5964 spatial=0.0742 overall=0.0724 time=6.4s
# lag2_half_quarter::HalfLag2_A12_B09_C06: fitting | loss=1.5969 spatial=0.0570 overall=0.1279 time=7.5s
# lag2_half_quarter::QuarterRealloc_A15_B09_C03: fitting | loss=1.5942 spatial=0.1610 overall=0.1905 time=7.4s
# lag2_half_none::HalfLag2_A12_B09_C06: fitting | loss=1.5969 spatial=0.0570 overall=0.1279 time=7.5s
# lag2_half_none::NoLag2_A19_B09_C00: fitting | loss=1.5961 spatial=0.0857 overall=0.1671 time=7.7s
# advec_band_small::BaseLocal_A06_B04_C02: fitting | loss=1.6148 spatial=0.0870 overall=0.1642 time=1.9s
# advec_band_small::AdvecBand_A06_B02p23_C02: fitting | loss=1.6134 spatial=0.0830 overall=0.1700 time=2.5s
# advec_band_large::BaseLocal_A12_B08_C06: fitting | loss=1.5996 spatial=0.0701 overall=0.1225 time=5.9s
# advec_band_large::AdvecBand_A12_B06p23_C06: fitting | loss=1.6031 spatial=0.0601 overall=0.1225 time=7.2s
# full20_ratio::FullLag_A20_B20_C20: fitting | loss=1.6087 spatial=0.1286 overall=0.2012 time=24.1s
# full20_ratio::RatioBudget_A27_B20_C13: fitting | loss=1.5926 spatial=0.0883 overall=0.0911 time=26.6s
#
# === Iteration 4/10 ===
# lag1_budget::Lag1_Realloc_B04_A12: fitting | loss=1.5898 spatial=0.0927 overall=0.1062 time=3.6s
# lag1_budget::Lag1_Realloc_B05_A11: fitting | loss=1.5859 spatial=0.0993 overall=0.1151 time=3.1s
# lag1_budget::Lag1_Realloc_B06_A10: fitting | loss=1.5817 spatial=0.0581 overall=0.0927 time=3.8s
# lag1_budget::Lag1_Realloc_B07_A09: fitting | loss=1.5965 spatial=0.0705 overall=0.1374 time=3.2s
# lag1_budget::Lag1_Full_B08_A08: fitting | loss=1.5903 spatial=0.0857 overall=0.0759 time=3.1s
# full8_current_realloc::FullLag_A08_B08_C08: fitting | loss=1.5847 spatial=0.1240 overall=0.1320 time=7.2s
# full8_current_realloc::RatioBudget_A11_B08_C05: fitting | loss=1.5824 spatial=0.1308 overall=0.1591 time=6.3s
# full8_current_realloc::CurrentRealloc_A12_B07_C05: fitting | loss=1.5862 spatial=0.0822 overall=0.1367 time=5.7s
# lag2_half_quarter::HalfLag2_A12_B09_C06: fitting | loss=1.5754 spatial=0.0441 overall=0.1011 time=6.9s
# lag2_half_quarter::QuarterRealloc_A15_B09_C03: fitting | loss=1.5790 spatial=0.1004 overall=0.1225 time=6.9s
# lag2_half_none::HalfLag2_A12_B09_C06: fitting | loss=1.5754 spatial=0.0441 overall=0.1011 time=6.8s
# lag2_half_none::NoLag2_A19_B09_C00: fitting | loss=1.5870 spatial=0.0782 overall=0.0697 time=8.4s
# advec_band_small::BaseLocal_A06_B04_C02: fitting | loss=1.5906 spatial=0.1308 overall=0.1878 time=2.3s
# advec_band_small::AdvecBand_A06_B02p23_C02: fitting | loss=1.6039 spatial=0.1430 overall=0.2106 time=3.0s
# advec_band_large::BaseLocal_A12_B08_C06: fitting | loss=1.5737 spatial=0.0940 overall=0.1667 time=5.5s
# advec_band_large::AdvecBand_A12_B06p23_C06: fitting | loss=1.5855 spatial=0.1075 overall=0.1625 time=6.5s
# full20_ratio::FullLag_A20_B20_C20: fitting | loss=1.5870 spatial=0.0433 overall=0.0826 time=23.2s
# full20_ratio::RatioBudget_A27_B20_C13: fitting | loss=1.5872 spatial=0.0694 overall=0.1375 time=19.7s
#
# === Iteration 5/10 ===
# lag1_budget::Lag1_Realloc_B04_A12: fitting | loss=1.5955 spatial=0.0909 overall=0.1158 time=2.8s
# lag1_budget::Lag1_Realloc_B05_A11: fitting | loss=1.5830 spatial=0.0833 overall=0.1185 time=2.4s
# lag1_budget::Lag1_Realloc_B06_A10: fitting | loss=1.5895 spatial=0.0955 overall=0.0743 time=2.6s
# lag1_budget::Lag1_Realloc_B07_A09: fitting | loss=1.5928 spatial=0.1019 overall=0.1528 time=3.0s
# lag1_budget::Lag1_Full_B08_A08: fitting | loss=1.6116 spatial=0.0914 overall=0.1008 time=3.0s
# full8_current_realloc::FullLag_A08_B08_C08: fitting | loss=1.6102 spatial=0.1303 overall=0.1337 time=6.4s
# full8_current_realloc::RatioBudget_A11_B08_C05: fitting | loss=1.5886 spatial=0.1206 overall=0.2083 time=5.0s
# full8_current_realloc::CurrentRealloc_A12_B07_C05: fitting | loss=1.5958 spatial=0.1658 overall=0.2252 time=6.9s
# lag2_half_quarter::HalfLag2_A12_B09_C06: fitting | loss=1.5998 spatial=0.0803 overall=0.0856 time=6.5s
# lag2_half_quarter::QuarterRealloc_A15_B09_C03: fitting | loss=1.6008 spatial=0.1290 overall=0.1275 time=6.9s
# lag2_half_none::HalfLag2_A12_B09_C06: fitting | loss=1.5998 spatial=0.0803 overall=0.0856 time=6.5s
# lag2_half_none::NoLag2_A19_B09_C00: fitting | loss=1.5988 spatial=0.1148 overall=0.0949 time=7.2s
# advec_band_small::BaseLocal_A06_B04_C02: fitting | loss=1.5977 spatial=0.1320 overall=0.1406 time=1.9s
# advec_band_small::AdvecBand_A06_B02p23_C02: fitting | loss=1.6007 spatial=0.1373 overall=0.1691 time=2.5s
# advec_band_large::BaseLocal_A12_B08_C06: fitting | loss=1.5968 spatial=0.0852 overall=0.1114 time=7.0s
# advec_band_large::AdvecBand_A12_B06p23_C06: fitting | loss=1.5974 spatial=0.1024 overall=0.1497 time=7.2s
# full20_ratio::FullLag_A20_B20_C20: fitting | loss=1.6137 spatial=0.1132 overall=0.1642 time=22.5s
# full20_ratio::RatioBudget_A27_B20_C13: fitting | loss=1.5980 spatial=0.0552 overall=0.1260 time=23.8s
#
# === Iteration 6/10 ===
# lag1_budget::Lag1_Realloc_B04_A12: fitting | loss=1.5799 spatial=0.0960 overall=0.1145 time=3.4s
# lag1_budget::Lag1_Realloc_B05_A11: fitting | loss=1.5915 spatial=0.0839 overall=0.0806 time=3.0s
# lag1_budget::Lag1_Realloc_B06_A10: fitting | loss=1.5857 spatial=0.1227 overall=0.1103 time=3.9s
# lag1_budget::Lag1_Realloc_B07_A09: fitting | loss=1.6021 spatial=0.0674 overall=0.1675 time=3.4s
# lag1_budget::Lag1_Full_B08_A08: fitting | loss=1.6064 spatial=0.1162 overall=0.2048 time=2.8s
# full8_current_realloc::FullLag_A08_B08_C08: fitting | loss=1.6022 spatial=0.0217 overall=0.1003 time=5.4s
# full8_current_realloc::RatioBudget_A11_B08_C05: fitting | loss=1.5892 spatial=0.0706 overall=0.1202 time=4.1s
# full8_current_realloc::CurrentRealloc_A12_B07_C05: fitting | loss=1.5913 spatial=0.0767 overall=0.1275 time=5.7s
# lag2_half_quarter::HalfLag2_A12_B09_C06: fitting | loss=1.5895 spatial=0.0817 overall=0.0917 time=6.4s
# lag2_half_quarter::QuarterRealloc_A15_B09_C03: fitting | loss=1.5891 spatial=0.0698 overall=0.1983 time=7.9s
# lag2_half_none::HalfLag2_A12_B09_C06: fitting | loss=1.5895 spatial=0.0817 overall=0.0917 time=6.4s
# lag2_half_none::NoLag2_A19_B09_C00: fitting | loss=1.5982 spatial=0.1786 overall=0.1977 time=9.0s
# advec_band_small::BaseLocal_A06_B04_C02: fitting | loss=1.6055 spatial=0.0719 overall=0.1508 time=1.6s
# advec_band_small::AdvecBand_A06_B02p23_C02: fitting | loss=1.6137 spatial=0.0722 overall=0.1683 time=2.7s
# advec_band_large::BaseLocal_A12_B08_C06: fitting | loss=1.5876 spatial=0.0590 overall=0.1159 time=6.6s
# advec_band_large::AdvecBand_A12_B06p23_C06: fitting | loss=1.5889 spatial=0.0676 overall=0.1088 time=4.9s
# full20_ratio::FullLag_A20_B20_C20: fitting | loss=1.5722 spatial=0.1019 overall=0.1314 time=21.2s
# full20_ratio::RatioBudget_A27_B20_C13: fitting | loss=1.5823 spatial=0.1116 overall=0.1534 time=23.5s
#
# === Iteration 7/10 ===
# lag1_budget::Lag1_Realloc_B04_A12: fitting | loss=1.5865 spatial=0.0384 overall=0.0522 time=3.2s
# lag1_budget::Lag1_Realloc_B05_A11: fitting | loss=1.6014 spatial=0.0792 overall=0.1109 time=3.4s
# lag1_budget::Lag1_Realloc_B06_A10: fitting | loss=1.6023 spatial=0.0395 overall=0.1121 time=3.0s
# lag1_budget::Lag1_Realloc_B07_A09: fitting | loss=1.5948 spatial=0.0667 overall=0.1199 time=2.9s
# lag1_budget::Lag1_Full_B08_A08: fitting | loss=1.5930 spatial=0.1045 overall=0.1964 time=3.1s
# full8_current_realloc::FullLag_A08_B08_C08: fitting | loss=1.5855 spatial=0.1034 overall=0.2037 time=5.3s
# full8_current_realloc::RatioBudget_A11_B08_C05: fitting | loss=1.5991 spatial=0.0583 overall=0.0941 time=5.8s
# full8_current_realloc::CurrentRealloc_A12_B07_C05: fitting | loss=1.6036 spatial=0.0475 overall=0.0725 time=5.5s
# lag2_half_quarter::HalfLag2_A12_B09_C06: fitting | loss=1.5961 spatial=0.0536 overall=0.1148 time=7.7s
# lag2_half_quarter::QuarterRealloc_A15_B09_C03: fitting | loss=1.5862 spatial=0.1180 overall=0.1649 time=8.3s
# lag2_half_none::HalfLag2_A12_B09_C06: fitting | loss=1.5961 spatial=0.0536 overall=0.1148 time=7.7s
# lag2_half_none::NoLag2_A19_B09_C00: fitting | loss=1.5933 spatial=0.0505 overall=0.0676 time=7.9s
# advec_band_small::BaseLocal_A06_B04_C02: fitting | loss=1.6104 spatial=0.0934 overall=0.1147 time=2.3s
# advec_band_small::AdvecBand_A06_B02p23_C02: fitting | loss=1.6216 spatial=0.0932 overall=0.1086 time=2.3s
# advec_band_large::BaseLocal_A12_B08_C06: fitting | loss=1.5908 spatial=0.0392 overall=0.1276 time=7.9s
# advec_band_large::AdvecBand_A12_B06p23_C06: fitting | loss=1.5980 spatial=0.0296 overall=0.0704 time=8.2s
# full20_ratio::FullLag_A20_B20_C20: fitting | loss=1.5908 spatial=0.0734 overall=0.1456 time=22.6s
# full20_ratio::RatioBudget_A27_B20_C13: fitting | loss=1.5983 spatial=0.0642 overall=0.1027 time=18.9s
#
# === Iteration 8/10 ===
# lag1_budget::Lag1_Realloc_B04_A12: fitting | loss=1.6131 spatial=0.1734 overall=0.1364 time=3.2s
# lag1_budget::Lag1_Realloc_B05_A11: fitting | loss=1.6105 spatial=0.1278 overall=0.1047 time=3.3s
# lag1_budget::Lag1_Realloc_B06_A10: fitting | loss=1.6198 spatial=0.1524 overall=0.1457 time=3.3s
# lag1_budget::Lag1_Realloc_B07_A09: fitting | loss=1.6222 spatial=0.0811 overall=0.0926 time=2.0s
# lag1_budget::Lag1_Full_B08_A08: fitting | loss=1.6292 spatial=0.0622 overall=0.0645 time=2.5s
# full8_current_realloc::FullLag_A08_B08_C08: fitting | loss=1.6238 spatial=0.0820 overall=0.1440 time=5.5s
# full8_current_realloc::RatioBudget_A11_B08_C05: fitting | loss=1.6138 spatial=0.0936 overall=0.1365 time=5.3s
# full8_current_realloc::CurrentRealloc_A12_B07_C05: fitting | loss=1.6124 spatial=0.1084 overall=0.1147 time=5.0s
# lag2_half_quarter::HalfLag2_A12_B09_C06: fitting | loss=1.6201 spatial=0.1073 overall=0.1056 time=6.9s
# lag2_half_quarter::QuarterRealloc_A15_B09_C03: fitting | loss=1.6047 spatial=0.0974 overall=0.0916 time=6.6s
# lag2_half_none::HalfLag2_A12_B09_C06: fitting | loss=1.6201 spatial=0.1073 overall=0.1056 time=6.9s
# lag2_half_none::NoLag2_A19_B09_C00: fitting | loss=1.6070 spatial=0.1730 overall=0.1545 time=9.1s
# advec_band_small::BaseLocal_A06_B04_C02: fitting | loss=1.6180 spatial=0.1561 overall=0.1293 time=2.4s
# advec_band_small::AdvecBand_A06_B02p23_C02: fitting | loss=1.6212 spatial=0.1187 overall=0.1018 time=2.5s
# advec_band_large::BaseLocal_A12_B08_C06: fitting | loss=1.6153 spatial=0.0942 overall=0.1127 time=6.4s
# advec_band_large::AdvecBand_A12_B06p23_C06: fitting | loss=1.6177 spatial=0.0929 overall=0.1034 time=6.4s
# full20_ratio::FullLag_A20_B20_C20: fitting | loss=1.6247 spatial=0.1308 overall=0.1793 time=23.8s
# full20_ratio::RatioBudget_A27_B20_C13: fitting | loss=1.6155 spatial=0.1249 overall=0.0987 time=22.2s
#
# === Iteration 9/10 ===
# lag1_budget::Lag1_Realloc_B04_A12: fitting | loss=1.5874 spatial=0.1846 overall=0.1994 time=3.0s
# lag1_budget::Lag1_Realloc_B05_A11: fitting | loss=1.5736 spatial=0.0469 overall=0.0803 time=3.0s
# lag1_budget::Lag1_Realloc_B06_A10: fitting | loss=1.5792 spatial=0.0786 overall=0.1210 time=3.2s
# lag1_budget::Lag1_Realloc_B07_A09: fitting | loss=1.6007 spatial=0.0769 overall=0.0863 time=3.3s
# lag1_budget::Lag1_Full_B08_A08: fitting | loss=1.5860 spatial=0.1017 overall=0.1522 time=3.2s
# full8_current_realloc::FullLag_A08_B08_C08: fitting | loss=1.5905 spatial=0.0717 overall=0.1557 time=4.8s
# full8_current_realloc::RatioBudget_A11_B08_C05: fitting | loss=1.5826 spatial=0.1172 overall=0.1288 time=5.2s
# full8_current_realloc::CurrentRealloc_A12_B07_C05: fitting | loss=1.5914 spatial=0.2128 overall=0.2406 time=5.8s
# lag2_half_quarter::HalfLag2_A12_B09_C06: fitting | loss=1.5944 spatial=0.0746 overall=0.1517 time=5.8s
# lag2_half_quarter::QuarterRealloc_A15_B09_C03: fitting | loss=1.5791 spatial=0.1159 overall=0.1807 time=7.9s
# lag2_half_none::HalfLag2_A12_B09_C06: fitting | loss=1.5944 spatial=0.0746 overall=0.1517 time=6.0s
# lag2_half_none::NoLag2_A19_B09_C00: fitting | loss=1.5802 spatial=0.0874 overall=0.1449 time=8.2s
# advec_band_small::BaseLocal_A06_B04_C02: fitting | loss=1.5967 spatial=0.1379 overall=0.1692 time=2.5s
# advec_band_small::AdvecBand_A06_B02p23_C02: fitting | loss=1.5978 spatial=0.1061 overall=0.1328 time=2.5s
# advec_band_large::BaseLocal_A12_B08_C06: fitting | loss=1.5941 spatial=0.0921 overall=0.1205 time=7.0s
# advec_band_large::AdvecBand_A12_B06p23_C06: fitting | loss=1.5931 spatial=0.1157 overall=0.1407 time=7.4s
# full20_ratio::FullLag_A20_B20_C20: fitting | loss=1.5761 spatial=0.1358 overall=0.1912 time=24.0s
# full20_ratio::RatioBudget_A27_B20_C13: fitting | loss=1.5717 spatial=0.1217 overall=0.1526 time=23.7s
#
# === Iteration 10/10 ===
# lag1_budget::Lag1_Realloc_B04_A12: fitting | loss=1.5826 spatial=0.1459 overall=0.1443 time=3.3s
# lag1_budget::Lag1_Realloc_B05_A11: fitting | loss=1.5940 spatial=0.0780 overall=0.0727 time=3.0s
# lag1_budget::Lag1_Realloc_B06_A10: fitting | loss=1.5871 spatial=0.1231 overall=0.1450 time=2.7s
# lag1_budget::Lag1_Realloc_B07_A09: fitting | loss=1.6072 spatial=0.1533 overall=0.1955 time=2.3s
# lag1_budget::Lag1_Full_B08_A08: fitting | loss=1.5929 spatial=0.0432 overall=0.0728 time=3.2s
# full8_current_realloc::FullLag_A08_B08_C08: fitting | loss=1.6062 spatial=0.0588 overall=0.0604 time=5.9s
# full8_current_realloc::RatioBudget_A11_B08_C05: fitting | loss=1.6083 spatial=0.1332 overall=0.1318 time=5.7s
# full8_current_realloc::CurrentRealloc_A12_B07_C05: fitting | loss=1.6015 spatial=0.1065 overall=0.1168 time=6.8s
# lag2_half_quarter::HalfLag2_A12_B09_C06: fitting | loss=1.5941 spatial=0.0997 overall=0.0939 time=8.0s
# lag2_half_quarter::QuarterRealloc_A15_B09_C03: fitting | loss=1.5942 spatial=0.2180 overall=0.2059 time=6.8s
# lag2_half_none::HalfLag2_A12_B09_C06: fitting | loss=1.5941 spatial=0.0997 overall=0.0939 time=8.0s
# lag2_half_none::NoLag2_A19_B09_C00: fitting | loss=1.5873 spatial=0.3103 overall=0.2713 time=7.1s
# advec_band_small::BaseLocal_A06_B04_C02: fitting | loss=1.6114 spatial=0.0906 overall=0.1039 time=2.3s
# advec_band_small::AdvecBand_A06_B02p23_C02: fitting | loss=1.6167 spatial=0.0738 overall=0.0913 time=2.3s
# advec_band_large::BaseLocal_A12_B08_C06: fitting | loss=1.5912 spatial=0.0929 overall=0.0874 time=7.3s
# advec_band_large::AdvecBand_A12_B06p23_C06: fitting | loss=1.5958 spatial=0.0501 overall=0.0836 time=5.1s
# full20_ratio::FullLag_A20_B20_C20: fitting | loss=1.6065 spatial=0.0875 overall=0.0903 time=23.1s
# full20_ratio::RatioBudget_A27_B20_C13: fitting | loss=1.6047 spatial=0.0991 overall=0.1155 time=25.8s
# Saved: log/sim_vecchia_lowres_x4_all_tests_mc_043026_results.csv
#    iter                          model_key                 model        group  \
# 0     1  lag1_budget::Lag1_Realloc_B04_A12  Lag1_Realloc_B04_A12  lag1_budget
# 1     1  lag1_budget::Lag1_Realloc_B05_A11  Lag1_Realloc_B05_A11  lag1_budget
# 2     1  lag1_budget::Lag1_Realloc_B06_A10  Lag1_Realloc_B06_A10  lag1_budget
# 3     1  lag1_budget::Lag1_Realloc_B07_A09  Lag1_Realloc_B07_A09  lag1_budget
# 4     1     lag1_budget::Lag1_Full_B08_A08     Lag1_Full_B08_A08  lag1_budget
#
#   kernel    allocation  limit_A  limit_B  limit_C  daily_stride  ...  gim_s  \
# 0    std  lag1 realloc       12        4        0             9  ...    0.0
# 1    std  lag1 realloc       11        5        0             9  ...    0.0
# 2    std  lag1 realloc       10        6        0             9  ...    0.0
# 3    std  lag1 realloc        9        7        0             9  ...    0.0
# 4    std     lag1 full        8        8        0             9  ...    0.0
#
#   total_s  fit_iter  sigmasq_est  range_lat_est  range_lon_est  range_t_est  \
# 0   3.416         4    10.550953       0.260322       0.341683     1.618440
# 1   3.298         4    10.748658       0.247658       0.316508     1.610220
# 2   3.766         3    10.705862       0.276653       0.339223     1.757042
# 3   2.945         1    10.637351       0.248019       0.340733     1.675006
# 4   3.163         1     9.458528       0.281741       0.348927     1.804886
#
#    advec_lat_est  advec_lon_est  nugget_est
# 0       0.112551      -0.133612    1.536634
# 1       0.103874      -0.136376    1.340712
# 2       0.096565      -0.143729    1.591569
# 3       0.083310      -0.147087    1.361538
# 4       0.099661      -0.136648    2.318054
#
# [5 rows x 33 columns]

# %%
def p90_p10(x):
    return np.percentile(x, 90) - np.percentile(x, 10)

def summarize_mc(df):
    metric_cols = ["loss", "overall_rmsre", "spatial_rmsre", "range_time_re", "advec_rmsre", "nugget_re", "total_s"]
    rows = []
    ok = df.dropna(subset=["loss"])
    for (group, model), sub in ok.groupby(["group", "model"], sort=False):
        row = {
            "group": group,
            "model": model,
            "kernel": sub["kernel"].iloc[0],
            "allocation": sub["allocation"].iloc[0],
            "limit_A": int(sub["limit_A"].iloc[0]),
            "limit_B": int(sub["limit_B"].iloc[0]),
            "limit_C": int(sub["limit_C"].iloc[0]),
            "daily_stride": int(sub["daily_stride"].iloc[0]),
            "uses_lag2": bool(sub["uses_lag2"].iloc[0]),
            "total_conditioning": int(sub["total_conditioning"].iloc[0]),
            "n": len(sub),
        }
        for col in metric_cols:
            vals = sub[col].dropna().to_numpy()
            row[f"{col}_mean"] = np.mean(vals)
            row[f"{col}_median"] = np.median(vals)
            row[f"{col}_p90_p10"] = p90_p10(vals)
        rows.append(row)
    return pd.DataFrame(rows)

def parameter_re_summary(df):
    true = {
        "sigmasq": TRUE_DICT["sigmasq"],
        "range_lat": TRUE_DICT["range_lat"],
        "range_lon": TRUE_DICT["range_lon"],
        "range_time": TRUE_DICT["range_time"],
        "advec_lat": TRUE_DICT["advec_lat"],
        "advec_lon": TRUE_DICT["advec_lon"],
        "nugget": TRUE_DICT["nugget"],
    }
    est_cols = {
        "sigmasq": "sigmasq_est",
        "range_lat": "range_lat_est",
        "range_lon": "range_lon_est",
        "range_time": "range_t_est",
        "advec_lat": "advec_lat_est",
        "advec_lon": "advec_lon_est",
        "nugget": "nugget_est",
    }
    rows = []
    ok = df.dropna(subset=["loss"])
    for (group, model), sub in ok.groupby(["group", "model"], sort=False):
        for par, col in est_cols.items():
            tv = true[par]
            vals = (sub[col] - tv).abs() / abs(tv) if abs(tv) >= 0.01 else (sub[col] - tv).abs()
            rows.append({
                "group": group,
                "model": model,
                "parameter": par,
                "mean_re": vals.mean(),
                "median_re": vals.median(),
                "p90_p10_re": p90_p10(vals.to_numpy()),
            })
    return pd.DataFrame(rows)

mc_summary = summarize_mc(df_mc)
param_summary = parameter_re_summary(df_mc)
display(mc_summary.sort_values(["group", "overall_rmsre_mean"]))
display(param_summary.sort_values(["group", "parameter", "mean_re"]))
# Out:
#                     group                       model      kernel  \
# 15       advec_band_large    AdvecBand_A12_B06p23_C06  advec_band
# 14       advec_band_large       BaseLocal_A12_B08_C06         std
# 12       advec_band_small       BaseLocal_A06_B04_C02         std
# 13       advec_band_small    AdvecBand_A06_B02p23_C02  advec_band
# 17           full20_ratio     RatioBudget_A27_B20_C13         std
# 16           full20_ratio         FullLag_A20_B20_C20         std
# 5   full8_current_realloc         FullLag_A08_B08_C08         std
# 6   full8_current_realloc     RatioBudget_A11_B08_C05         std
# 7   full8_current_realloc  CurrentRealloc_A12_B07_C05         std
# 2             lag1_budget        Lag1_Realloc_B06_A10         std
# 1             lag1_budget        Lag1_Realloc_B05_A11         std
# 4             lag1_budget           Lag1_Full_B08_A08         std
# 0             lag1_budget        Lag1_Realloc_B04_A12         std
# 3             lag1_budget        Lag1_Realloc_B07_A09         std
# 10         lag2_half_none        HalfLag2_A12_B09_C06         std
# 11         lag2_half_none          NoLag2_A19_B09_C00         std
# 8       lag2_half_quarter        HalfLag2_A12_B09_C06         std
# 9       lag2_half_quarter  QuarterRealloc_A15_B09_C03         std
#
#                                    allocation  limit_A  limit_B  limit_C  \
# 15  replace two lag1 local with upstream band       12        6        6
# 14                             local baseline       12        8        6
# 12                             local baseline        6        4        2
# 13  replace two lag1 local with upstream band        6        2        2
# 17                 x/0.75x/0.5x matched-total       27       20       13
# 16                                   20/20/20       20       20       20
# 5                                       8/8/8        8        8        8
# 6                  x/0.75x/0.5x matched-total       11        8        5
# 7               more-current, reduced t-1/t-2       12        7        5
# 2                                lag1 realloc       10        6        0
# 1                                lag1 realloc       11        5        0
# 4                                   lag1 full        8        8        0
# 0                                lag1 realloc       12        4        0
# 3                                lag1 realloc        9        7        0
# 10                        t-1 0.75x, t-2 0.5x       12        9        6
# 11              no t-2, reallocate to current       19        9        0
# 8                                x/0.75x/0.5x       12        9        6
# 9          t-2 quarter, reallocate to current       15        9        3
#
#     daily_stride  uses_lag2  total_conditioning  ...  range_time_re_p90_p10  \
# 15             2       True                  28  ...               0.085031
# 14             2       True                  28  ...               0.112039
# 12             2       True                  14  ...               0.133429
# 13             2       True                  14  ...               0.183084
# 17             2       True                  62  ...               0.141096
# 16             2       True                  62  ...               0.194112
# 5              2       True                  26  ...               0.118813
# 6              2       True                  26  ...               0.216644
# 7              2       True                  26  ...               0.130312
# 2              9      False                  17  ...               0.132360
# 1              9      False                  17  ...               0.146686
# 4              9      False                  17  ...               0.182094
# 0              9      False                  17  ...               0.163477
# 3              9      False                  17  ...               0.159244
# 10             2       True                  29  ...               0.099870
# 11             9      False                  29  ...               0.200909
# 8              2       True                  29  ...               0.099870
# 9              2       True                  29  ...               0.269208
#
#     advec_rmsre_mean  advec_rmsre_median  advec_rmsre_p90_p10  nugget_re_mean  \
# 15          0.142634            0.143101             0.109398        0.142427
# 14          0.146031            0.155443             0.111234        0.137474
# 12          0.147659            0.151244             0.190346        0.221572
# 13          0.170413            0.168789             0.204293        0.213114
# 17          0.177400            0.202167             0.171173        0.116246
# 16          0.167988            0.135972             0.170181        0.208143
# 5           0.146340            0.144993             0.208560        0.182911
# 6           0.157143            0.119729             0.145686        0.175242
# 7           0.160949            0.152250             0.172668        0.174075
# 2           0.126488            0.128508             0.164320        0.147549
# 1           0.126202            0.117970             0.186556        0.118565
# 4           0.146169            0.138616             0.131873        0.138010
# 0           0.123170            0.127431             0.161829        0.168850
# 3           0.161042            0.122827             0.184289        0.167559
# 10          0.140818            0.133027             0.069482        0.105510
# 11          0.118256            0.114526             0.191105        0.206376
# 8           0.140818            0.133027             0.069482        0.105510
# 9           0.160790            0.159460             0.204555        0.210538
#
#     nugget_re_median  nugget_re_p90_p10  total_s_mean  total_s_median  \
# 15          0.115945           0.167793        6.5179          6.4260
# 14          0.104600           0.224274        6.7177          6.8040
# 12          0.211165           0.309091        2.2568          2.2625
# 13          0.199613           0.243822        2.5683          2.4935
# 17          0.101525           0.173129       22.6910         22.8680
# 16          0.209699           0.301509       23.2872         23.1565
# 5           0.158127           0.263353        5.8064          5.6275
# 6           0.198067           0.221010        5.4352          5.6020
# 7           0.168434           0.255928        5.9580          5.7740
# 2           0.124582           0.226371        3.2154          3.1805
# 1           0.076216           0.209326        2.9455          3.0045
# 4           0.088747           0.283300        3.0354          3.0840
# 0           0.156832           0.190706        3.3530          3.3435
# 3           0.159778           0.240216        2.9453          3.0680
# 10          0.096641           0.179079        7.0891          7.1705
# 11          0.192230           0.315952        7.7269          7.8135
# 8           0.096641           0.179079        7.1651          7.2145
# 9           0.145046           0.332934        7.6155          7.1955
#
#     total_s_p90_p10
# 15           2.3422
# 14           1.4721
# 12           0.7735
# 13           0.8720
# 17           6.3245
# 16           2.3208
# 5            1.1679
# 6            0.9921
# 7            2.0717
# 2            1.0933
# 1            0.9487
# 4            0.3888
# 0            0.7290
# 3            1.0157
# 10           1.4334
# 11           2.1046
# 8            1.7367
# 9            1.6436
#
# [18 rows x 32 columns]
#                  group                       model   parameter   mean_re  \
# 102   advec_band_large       BaseLocal_A12_B08_C06   advec_lat  0.136843
# 109   advec_band_large    AdvecBand_A12_B06p23_C06   advec_lat  0.147923
# 110   advec_band_large    AdvecBand_A12_B06p23_C06   advec_lon  0.119544
# 103   advec_band_large       BaseLocal_A12_B08_C06   advec_lon  0.129625
# 104   advec_band_large       BaseLocal_A12_B08_C06      nugget  0.137474
# ..                 ...                         ...         ...       ...
# 65   lag2_half_quarter  QuarterRealloc_A15_B09_C03   range_lon  0.152818
# 59   lag2_half_quarter        HalfLag2_A12_B09_C06  range_time  0.059602
# 66   lag2_half_quarter  QuarterRealloc_A15_B09_C03  range_time  0.158989
# 56   lag2_half_quarter        HalfLag2_A12_B09_C06     sigmasq  0.058993
# 63   lag2_half_quarter  QuarterRealloc_A15_B09_C03     sigmasq  0.075078
#
#      median_re  p90_p10_re
# 102   0.128019    0.203556
# 109   0.145894    0.181306
# 110   0.111440    0.117435
# 103   0.124147    0.128808
# 104   0.104600    0.224273
# ..         ...         ...
# 65    0.126786    0.160393
# 59    0.057700    0.099870
# 66    0.134272    0.269207
# 56    0.056678    0.063333
# 63    0.068431    0.084450
#
# [126 rows x 6 columns]

# %%
for group, sub in mc_summary.groupby("group", sort=False):
    fig, axes = plt.subplots(1, 3, figsize=(15, 4))
    x = np.arange(len(sub))
    labels = sub["model"].to_list()

    axes[0].bar(x - 0.18, sub["spatial_rmsre_mean"], width=0.36, label="spatial")
    axes[0].bar(x + 0.18, sub["overall_rmsre_mean"], width=0.36, label="overall")
    axes[0].set_title(f"{group}: RMSRE")
    axes[0].set_xticks(x, labels, rotation=25, ha="right")
    axes[0].legend()

    axes[1].bar(x - 0.18, sub["advec_rmsre_mean"], width=0.36, label="advec")
    axes[1].bar(x + 0.18, sub["nugget_re_mean"], width=0.36, label="nugget")
    axes[1].set_title("Advection / nugget")
    axes[1].set_xticks(x, labels, rotation=25, ha="right")
    axes[1].legend()

    axes[2].bar(x - 0.18, sub["loss_mean"], width=0.36, label="loss")
    axes[2].bar(x + 0.18, sub["total_s_mean"] / max(sub["total_s_mean"].max(), 1), width=0.36, label="scaled time")
    axes[2].set_title("Loss and runtime")
    axes[2].set_xticks(x, labels, rotation=25, ha="right")
    axes[2].legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Focused Runs

# %%
# To focus on a subset, edit ACTIVE_GROUPS in the settings cell and rerun from there.
# Suggested focused groups:
#   ["lag2_half_none"]
#   ["full8_current_realloc"]
#   ["advec_band_small", "advec_band_large"]
print("Current active groups:", ACTIVE_GROUPS)
# Out:
# Current active groups: ['lag1_budget', 'full8_current_realloc', 'lag2_half_quarter', 'lag2_half_none', 'advec_band_small', 'advec_band_large', 'full20_ratio']

# %% [markdown]
# ## Interpretation
#
# If coarse spatial resolution makes `NoLag2` or current-heavy reallocations less attractive, that supports the idea that the previous gains were driven by very dense current-time spatial information. If current-heavy/no-lag2 models still win, then second-lag local neighbors may be less important than expected even when current spatial information is sparser.

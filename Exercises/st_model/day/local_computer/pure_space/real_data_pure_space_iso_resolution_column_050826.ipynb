# %% [markdown]
# # Pure-space isotropic Column Vecchia: resolution sensitivity by hour
#
# This notebook removes the temporal covariance entirely and fits each time slot independently using a pure-space isotropic Column Vecchia model.
#
# Resolution thinning:
#
# - `x8`: keep regular-grid rows `0, 8, 16, ...`
# - `x4`: keep `0, 4, 8, ...`
# - `x2`: keep `0, 2, 4, ...`
# - `x1`: keep all rows
#
# Estimated full-fit parameters:
#
# - `sigmasq`
# - `range` (single isotropic spatial range)
# - `nugget`
#
# Additional profile checks:
#
# - `sigma_only_x1_anchor`: fix `range` and `nugget` at the same hour's full `x1` estimate, re-estimate only `sigmasq` at each resolution.
# - `range_only_x1_anchor`: fix `sigmasq` and `nugget` at the same hour's full `x1` estimate, re-estimate only `range` at each resolution.

# %%
import gc
import sys
import time
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch

LOCAL_SRC = '/Users/joonwonlee/Documents/GEMS_TCO-1/src'
AMAREL_SRC = '/home/jl2815/tco'
SRC = AMAREL_SRC if Path(AMAREL_SRC).exists() else LOCAL_SRC
if SRC not in sys.path:
    sys.path.insert(0, SRC)

from GEMS_TCO import configuration as config
from GEMS_TCO.data_loader import load_data_dynamic_processed
from GEMS_TCO.kernels_space_iso_050826 import ColumnSpaceIsoTrendVecchiaFit

DEVICE = torch.device('cpu')
DTYPE = torch.float64
ROUND_DECIMALS = 4

pd.set_option('display.max_columns', 120)
pd.set_option('display.width', 180)
print('SRC:', SRC)
print('device:', DEVICE)
# Out:
# SRC: /Users/joonwonlee/Documents/GEMS_TCO-1/src
# device: cpu

# %%
# Experiment config
YEAR = '2024'
MONTH = 7
DAY_IDX = 2                 # 0-based: 2 -> 2024-07-03
HOUR_IDX_LIST = list(range(8))
LAT_RANGE = [-3, 2]
LON_RANGE = [121, 131]

RESOLUTION_STRIDES = [8, 4, 2, 1]
FIT_SMOOTHS = [0.5]
MEAN_DESIGN = 'latlon'      # hourly pure-space: intercept + lat + lon detrending

COLUMN_SPEC = {
    'model': 'ColumnSpaceIso_Up2_Right3_M10_realloc',
    'head_right_cols': 0,
    'above_count': 2,
    'right_col_count': 3,
    'per_time_conditioning_count': 10,
    'target_chunk_size': 512,
}

LBFGS_LR = 1.0
LBFGS_STEPS_FULL = 8
LBFGS_STEPS_PARTIAL = 8
LBFGS_EVAL = 20
LBFGS_HIST = 10
GRAD_TOL = 1e-5

INIT_ISO = {
    'sigmasq': 13.0,
    'range': 0.25,
    'nugget': 2.5,
}
P_LABELS = ['sigmasq', 'range', 'nugget']
P_IDX = {'sigmasq': 0, 'range': 1, 'nugget': 2}

RUN_FULL = True
RUN_PARTIAL = True

PURE_SPACE_DIR = Path('/Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space')
OUT_DIR = PURE_SPACE_DIR / 'log'
OUT_DIR.mkdir(parents=True, exist_ok=True)
OUT_PREFIX = 'real_pure_space_iso_column_resolution_050826'

print('day:', f'{YEAR}{MONTH:02d}{DAY_IDX + 1:02d}')
print('hours:', HOUR_IDX_LIST)
print('strides:', RESOLUTION_STRIDES)
print('column:', COLUMN_SPEC)
print('init:', INIT_ISO)
# Out:
# day: 20240703
# hours: [0, 1, 2, 3, 4, 5, 6, 7]
# strides: [8, 4, 2, 1]
# column: {'model': 'ColumnSpaceIso_Up2_Right3_M10_realloc', 'head_right_cols': 0, 'above_count': 2, 'right_col_count': 3, 'per_time_conditioning_count': 10, 'target_chunk_size': 512}
# init: {'sigmasq': 13.0, 'range': 0.25, 'nugget': 2.5}

# %%
def phys_to_log_iso(d):
    return [np.log(d['sigmasq']), np.log(d['range']), np.log(d['nugget'])]


def backmap_iso(raw):
    return {
        'sigmasq': float(np.exp(raw[0])),
        'range': float(np.exp(raw[1])),
        'nugget': float(np.exp(raw[2])),
    }


def make_full_params(init=INIT_ISO):
    return [torch.tensor([v], device=DEVICE, dtype=DTYPE, requires_grad=True) for v in phys_to_log_iso(init)]


def count_valid(input_map):
    return int(sum(((~torch.isnan(v[:, 2])) & (~torch.isnan(v[:, 0])) & (~torch.isnan(v[:, 1]))).sum().item() for v in input_map.values()))


def space_diag(model):
    groups = getattr(model, 'Batched_Groups', []) or []
    if not groups:
        return {'n_batches': 0, 'n_tails': 0, 'mean_m': 0.0, 'max_m': 0, 'largest_batch_n': 0}
    ns = np.asarray([int(g['target_idx'].shape[0]) for g in groups], dtype=np.int64)
    ms = np.asarray([int(g['max_m']) for g in groups], dtype=np.int64)
    return {
        'n_batches': int(len(groups)),
        'n_tails': int(ns.sum()),
        'mean_m': float(ms.mean()),
        'max_m': int(ms.max()),
        'largest_batch_n': int(ns.max()),
    }


def round_df(df, digits=ROUND_DECIMALS):
    out = df.copy()
    num_cols = out.select_dtypes(include=[np.number]).columns
    out[num_cols] = out[num_cols].round(digits)
    return out


def empty_cache():
    gc.collect()
    if DEVICE.type == 'cuda':
        torch.cuda.empty_cache()


def resolution_label(stride):
    return f'x{int(stride)}'

# %%
loader = load_data_dynamic_processed(config.mac_data_load_path)
df_map, _, _, monthly_mean = loader.load_maxmin_ordered_data_bymonthyear(
    lat_lon_resolution=[1, 1],
    mm_cond_number=10,
    years_=[YEAR],
    months_=[MONTH],
    lat_range=LAT_RANGE,
    lon_range=LON_RANGE,
    is_whittle=True,
)
month_keys = sorted(df_map.keys())
day_keys = month_keys[DAY_IDX * 8:(DAY_IDX + 1) * 8]
if len(day_keys) != 8:
    raise ValueError(f'Day {DAY_IDX} has {len(day_keys)} slices, expected 8')

first_df = df_map[day_keys[0]].reset_index(drop=True)
grid_order = (
    first_df
    .assign(_orig_idx=np.arange(len(first_df)))
    .sort_values(['Longitude', 'Latitude', '_orig_idx'], kind='mergesort')['_orig_idx']
    .to_numpy(dtype=np.int64)
)
grid_coords_full = first_df.iloc[grid_order][['Latitude', 'Longitude']].to_numpy(dtype=np.float64)

print('monthly_mean:', round(monthly_mean, 4))
print('day keys:', day_keys[0], '...', day_keys[-1])
print('full grid:', grid_coords_full.shape)
print('unique lat/lon:', len(np.unique(np.round(grid_coords_full[:,0], 6))), len(np.unique(np.round(grid_coords_full[:,1], 6))))
# Out:
# --- Global Monthly Mean for 2024-7: 257.9726 ---
# monthly_mean: 257.9726
# day keys: 2024_07_y24m07day03_hm00:53 ... 2024_07_y24m07day03_hm07:48
# full grid: (18126, 2)
# unique lat/lon: 114 159

# %%
def load_hour_map(hour_idx):
    key = day_keys[int(hour_idx)]
    hour_df_map = {key: df_map[key]}
    hour_map, _ = loader.load_working_data(
        hour_df_map,
        monthly_mean=monthly_mean,
        idx_for_datamap=[0, 1],
        ord_mm=grid_order,
        dtype=DTYPE,
        keep_ori=True,
    )
    return {k: v.to(DEVICE) for k, v in hour_map.items()}, key


def thin_hour_map(hour_map, stride):
    n_full = grid_coords_full.shape[0]
    thin_idx = np.arange(0, n_full, int(stride), dtype=np.int64)
    thin_map = {k: v[thin_idx].contiguous() for k, v in hour_map.items()}
    thin_grid = np.ascontiguousarray(grid_coords_full[thin_idx])
    return thin_map, thin_grid, thin_idx


def build_model(input_map, grid_coords, smooth):
    return ColumnSpaceIsoTrendVecchiaFit(
        smooth=smooth,
        input_map=input_map,
        grid_coords=grid_coords,
        head_right_cols=COLUMN_SPEC['head_right_cols'],
        above_count=COLUMN_SPEC['above_count'],
        right_col_count=COLUMN_SPEC['right_col_count'],
        per_time_conditioning_count=COLUMN_SPEC['per_time_conditioning_count'],
        target_chunk_size=COLUMN_SPEC['target_chunk_size'],
        mean_design=MEAN_DESIGN,
    )


def make_base_row(hour_idx, time_key, stride, smooth, fit_type, n_grid, n_valid, pre_s, fit_s, loss, fit_iter, est, diag):
    row = {
        'date_str': f'{YEAR}{MONTH:02d}{DAY_IDX + 1:02d}',
        'day_idx': DAY_IDX,
        'hour_idx': int(hour_idx),
        'time_key': str(time_key),
        'resolution_stride': int(stride),
        'resolution_label': resolution_label(stride),
        'smooth': float(smooth),
        'mean_design': MEAN_DESIGN,
        'fit_type': fit_type,
        'model': COLUMN_SPEC['model'],
        'kernel': 'column_space_iso_tonly_realloc',
        'coord_mode': 'regular-grid every-k thinning; covariance on Source_Latitude/Source_Longitude',
        'loss': float(loss),
        'fit_iter_raw': int(fit_iter),
        'fit_steps_reported': int(fit_iter) + 1,
        'precompute_s': float(pre_s),
        'fit_s': float(fit_s),
        'total_s': float(pre_s + fit_s),
        'n_grid': int(n_grid),
        'n_valid': int(n_valid),
        'valid_fraction': float(n_valid / n_grid) if n_grid else np.nan,
        **{f'est_{p}': est[p] for p in P_LABELS},
        **diag,
        'total_conditioning_nominal': COLUMN_SPEC['per_time_conditioning_count'],
        'head_right_cols': COLUMN_SPEC['head_right_cols'],
        'above_count': COLUMN_SPEC['above_count'],
        'right_col_count': COLUMN_SPEC['right_col_count'],
        'per_time_conditioning_count': COLUMN_SPEC['per_time_conditioning_count'],
    }
    return row

# %%
def fit_full_iso(hour_idx, stride, smooth):
    hour_map, time_key = load_hour_map(hour_idx)
    thin_map, thin_grid, _ = thin_hour_map(hour_map, stride)
    n_grid = int(thin_grid.shape[0])
    n_valid = count_valid(thin_map)
    print('\n' + '=' * 90)
    print(f'FULL ISO | hour={hour_idx + 1} | {time_key} | {resolution_label(stride)} | n_grid={n_grid:,} | n_valid={n_valid:,}')

    model = build_model(thin_map, thin_grid, smooth)
    t_pre = time.time()
    model.precompute_conditioning_sets()
    pre_s = time.time() - t_pre
    diag = space_diag(model)

    params = make_full_params()
    opt = model.set_optimizer(params, lr=LBFGS_LR, max_iter=LBFGS_EVAL, max_eval=LBFGS_EVAL, history_size=LBFGS_HIST)
    t_fit = time.time()
    out, fit_iter = model.fit_vecc_lbfgs(params, opt, max_steps=LBFGS_STEPS_FULL, grad_tol=GRAD_TOL)
    fit_s = time.time() - t_fit
    est = backmap_iso(out[:3])
    row = make_base_row(hour_idx, time_key, stride, smooth, 'full', n_grid, n_valid, pre_s, fit_s, out[-1], fit_iter, est, diag)
    print('RESULT:', {k: round(v, 4) if isinstance(v, float) else v for k, v in row.items() if k in ['resolution_label','loss','est_sigmasq','est_range','est_nugget','total_s']})

    del model, params, opt, hour_map, thin_map
    empty_cache()
    return row


def fit_partial_iso(hour_idx, stride, smooth, anchor, fit_type):
    if fit_type == 'sigma_only_x1_anchor':
        free_name = 'sigmasq'
        fixed_names = ['range', 'nugget']
    elif fit_type == 'range_only_x1_anchor':
        free_name = 'range'
        fixed_names = ['sigmasq', 'nugget']
    else:
        raise ValueError(f'unknown fit_type={fit_type}')

    hour_map, time_key = load_hour_map(hour_idx)
    thin_map, thin_grid, _ = thin_hour_map(hour_map, stride)
    n_grid = int(thin_grid.shape[0])
    n_valid = count_valid(thin_map)
    print('\n' + '=' * 90)
    print(f'{fit_type} | hour={hour_idx + 1} | {time_key} | {resolution_label(stride)} | anchor=x1')

    model = build_model(thin_map, thin_grid, smooth)
    t_pre = time.time()
    model.precompute_conditioning_sets()
    pre_s = time.time() - t_pre
    diag = space_diag(model)

    fixed_log = {p: torch.tensor(np.log(anchor[p]), device=DEVICE, dtype=DTYPE) for p in P_LABELS}
    free_param = torch.tensor([np.log(anchor[free_name])], device=DEVICE, dtype=DTYPE, requires_grad=True)
    opt = model.set_optimizer([free_param], lr=LBFGS_LR, max_iter=LBFGS_EVAL, max_eval=LBFGS_EVAL, history_size=LBFGS_HIST)

    def assemble_params():
        pieces = []
        for p in P_LABELS:
            if p == free_name:
                pieces.append(free_param.reshape(()))
            else:
                pieces.append(fixed_log[p].reshape(()))
        return torch.stack(pieces)

    print('--- Starting partial Pure-Space Iso L-BFGS ---')
    t_fit = time.time()
    last_iter = 0
    loss = None
    for i in range(LBFGS_STEPS_PARTIAL):
        last_iter = i
        def closure():
            opt.zero_grad()
            l = model.vecchia_batched_likelihood(assemble_params())
            l.backward()
            return l
        loss = opt.step(closure)
        grad = abs(float(free_param.grad.detach().item())) if free_param.grad is not None else 0.0
        print(f'--- Step {i + 1}/{LBFGS_STEPS_PARTIAL} / Loss: {float(loss.detach().item()):.6f} / {free_name} Grad: {grad:.2e} ---')
        if grad < GRAD_TOL:
            break
    fit_s = time.time() - t_fit

    final_log = [float(x.detach().cpu().item()) for x in assemble_params()]
    est = backmap_iso(final_log)
    row = make_base_row(hour_idx, time_key, stride, smooth, fit_type, n_grid, n_valid, pre_s, fit_s, float(loss.detach().cpu().item()), last_iter, est, diag)
    row.update({
        'free_parameter': free_name,
        'fixed_parameters': ','.join(fixed_names),
        'anchor_resolution_label': 'x1',
        **{f'anchor_{p}': anchor[p] for p in P_LABELS},
    })
    print('RESULT:', {k: round(v, 4) if isinstance(v, float) else v for k, v in row.items() if k in ['resolution_label','loss','est_sigmasq','est_range','est_nugget','total_s']})

    del model, opt, free_param, hour_map, thin_map
    empty_cache()
    return row

# %%
full_rows = []
if RUN_FULL:
    for smooth in FIT_SMOOTHS:
        for hour_idx in HOUR_IDX_LIST:
            for stride in RESOLUTION_STRIDES:
                full_rows.append(fit_full_iso(hour_idx, stride, smooth))
                full_df_tmp = round_df(pd.DataFrame(full_rows))
                full_df_tmp.to_csv(OUT_DIR / f'{OUT_PREFIX}_full.csv', index=False, float_format=f'%.{ROUND_DECIMALS}f')

full_df = pd.DataFrame(full_rows)
full_path = OUT_DIR / f'{OUT_PREFIX}_full.csv'
round_df(full_df).to_csv(full_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
print('Saved full fits:', full_path)
display(round_df(full_df))
# Out:
# ==========================================================================================
# FULL ISO | hour=1 | 2024_07_y24m07day03_hm00:53 | x8 | n_grid=2,266 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.615286 / Max Grad: 4.72e-06 ---
# Converged: max_grad 4.72e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 8.667717064022419, 'range': 0.4971358724820147, 'nugget': 4.41637874011564}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6153, 'total_s': 0.2031, 'est_sigmasq': 8.6677, 'est_range': 0.4971, 'est_nugget': 4.4164}
#
# ==========================================================================================
# FULL ISO | hour=1 | 2024_07_y24m07day03_hm00:53 | x4 | n_grid=4,532 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.504023 / Max Grad: 4.08e-06 ---
# Converged: max_grad 4.08e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 9.059985496252311, 'range': 0.38745149034578036, 'nugget': 3.4295332559520677}
# RESULT: {'resolution_label': 'x4', 'loss': 1.504, 'total_s': 0.4282, 'est_sigmasq': 9.06, 'est_range': 0.3875, 'est_nugget': 3.4295}
#
# ==========================================================================================
# FULL ISO | hour=1 | 2024_07_y24m07day03_hm00:53 | x2 | n_grid=9,063 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.542962 / Max Grad: 1.52e-06 ---
# Converged: max_grad 1.52e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 10.054234979643752, 'range': 0.29334610253906124, 'nugget': 4.226993678245988}
# RESULT: {'resolution_label': 'x2', 'loss': 1.543, 'total_s': 0.8881, 'est_sigmasq': 10.0542, 'est_range': 0.2933, 'est_nugget': 4.227}
#
# ==========================================================================================
# FULL ISO | hour=1 | 2024_07_y24m07day03_hm00:53 | x1 | n_grid=18,126 | n_valid=18,067
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18067, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.411121 / Max Grad: 1.71e-06 ---
# Converged: max_grad 1.71e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 10.221319459524755, 'range': 0.24721506242884986, 'nugget': 3.0519666734040785}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4111, 'total_s': 1.978, 'est_sigmasq': 10.2213, 'est_range': 0.2472, 'est_nugget': 3.052}
#
# ==========================================================================================
# FULL ISO | hour=2 | 2024_07_y24m07day03_hm01:53 | x8 | n_grid=2,266 | n_valid=2,208
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2208, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.651183 / Max Grad: 9.22e-06 ---
# Converged: max_grad 9.22e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 11.09356326405403, 'range': 0.41649773684579805, 'nugget': 3.857154856911249}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6512, 'total_s': 0.1921, 'est_sigmasq': 11.0936, 'est_range': 0.4165, 'est_nugget': 3.8572}
#
# ==========================================================================================
# FULL ISO | hour=2 | 2024_07_y24m07day03_hm01:53 | x4 | n_grid=4,532 | n_valid=4,422
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4422, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.526349 / Max Grad: 3.32e-06 ---
# Converged: max_grad 3.32e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.25816556658958, 'range': 0.35443503230530066, 'nugget': 2.6059260366365176}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5263, 'total_s': 0.4463, 'est_sigmasq': 12.2582, 'est_range': 0.3544, 'est_nugget': 2.6059}
#
# ==========================================================================================
# FULL ISO | hour=2 | 2024_07_y24m07day03_hm01:53 | x2 | n_grid=9,063 | n_valid=8,840
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=8840, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.418071 / Max Grad: 5.94e-06 ---
# Converged: max_grad 5.94e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.020398772018845, 'range': 0.28608363274925436, 'nugget': 2.245303636858044}
# RESULT: {'resolution_label': 'x2', 'loss': 1.4181, 'total_s': 0.7686, 'est_sigmasq': 12.0204, 'est_range': 0.2861, 'est_nugget': 2.2453}
#
# ==========================================================================================
# FULL ISO | hour=2 | 2024_07_y24m07day03_hm01:53 | x1 | n_grid=18,126 | n_valid=17,670
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.7s. grid=114x159, heads=0, tails=17670, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.358708 / Max Grad: 5.41e-06 ---
# Converged: max_grad 5.41e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 11.910981146543515, 'range': 0.22525076759027143, 'nugget': 1.9942502867895966}
# RESULT: {'resolution_label': 'x1', 'loss': 1.3587, 'total_s': 1.6925, 'est_sigmasq': 11.911, 'est_range': 0.2253, 'est_nugget': 1.9943}
#
# ==========================================================================================
# FULL ISO | hour=3 | 2024_07_y24m07day03_hm02:53 | x8 | n_grid=2,266 | n_valid=2,082
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2082, m mean/med/max=8.6/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.704486 / Max Grad: 5.90e-07 ---
# Converged: max_grad 5.90e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.614006952477299, 'range': 0.459345780635971, 'nugget': 4.4169083943852865}
# RESULT: {'resolution_label': 'x8', 'loss': 1.7045, 'total_s': 0.1664, 'est_sigmasq': 12.614, 'est_range': 0.4593, 'est_nugget': 4.4169}
#
# ==========================================================================================
# FULL ISO | hour=3 | 2024_07_y24m07day03_hm02:53 | x4 | n_grid=4,532 | n_valid=4,176
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4176, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.607528 / Max Grad: 3.60e-07 ---
# Converged: max_grad 3.60e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.013783460034958, 'range': 0.37720482186940063, 'nugget': 3.7523460181171737}
# RESULT: {'resolution_label': 'x4', 'loss': 1.6075, 'total_s': 0.3598, 'est_sigmasq': 13.0138, 'est_range': 0.3772, 'est_nugget': 3.7523}
#
# ==========================================================================================
# FULL ISO | hour=3 | 2024_07_y24m07day03_hm02:53 | x2 | n_grid=9,063 | n_valid=8,353
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=8353, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.462931 / Max Grad: 9.59e-06 ---
# Converged: max_grad 9.59e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.077164523194332, 'range': 0.24584416019703054, 'nugget': 1.812358598627265}
# RESULT: {'resolution_label': 'x2', 'loss': 1.4629, 'total_s': 0.6085, 'est_sigmasq': 14.0772, 'est_range': 0.2458, 'est_nugget': 1.8124}
#
# ==========================================================================================
# FULL ISO | hour=3 | 2024_07_y24m07day03_hm02:53 | x1 | n_grid=18,126 | n_valid=16,698
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.7s. grid=114x159, heads=0, tails=16698, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.363488 / Max Grad: 1.08e-06 ---
# Converged: max_grad 1.08e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.61356663415897, 'range': 0.2205532522379307, 'nugget': 1.3965595333038436}
# RESULT: {'resolution_label': 'x1', 'loss': 1.3635, 'total_s': 1.5749, 'est_sigmasq': 14.6136, 'est_range': 0.2206, 'est_nugget': 1.3966}
#
# ==========================================================================================
# FULL ISO | hour=4 | 2024_07_y24m07day03_hm03:53 | x8 | n_grid=2,266 | n_valid=2,114
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2114, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.741702 / Max Grad: 9.00e-06 ---
# Converged: max_grad 9.00e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.566004487038581, 'range': 0.40141590571358376, 'nugget': 3.9968163585837972}
# RESULT: {'resolution_label': 'x8', 'loss': 1.7417, 'total_s': 0.1429, 'est_sigmasq': 14.566, 'est_range': 0.4014, 'est_nugget': 3.9968}
#
# ==========================================================================================
# FULL ISO | hour=4 | 2024_07_y24m07day03_hm03:53 | x4 | n_grid=4,532 | n_valid=4,217
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4217, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.639991 / Max Grad: 3.89e-06 ---
# Converged: max_grad 3.89e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.00919558194194, 'range': 0.35063138650383585, 'nugget': 3.4103295675111367}
# RESULT: {'resolution_label': 'x4', 'loss': 1.64, 'total_s': 0.3179, 'est_sigmasq': 15.0092, 'est_range': 0.3506, 'est_nugget': 3.4103}
#
# ==========================================================================================
# FULL ISO | hour=4 | 2024_07_y24m07day03_hm03:53 | x2 | n_grid=9,063 | n_valid=8,428
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=8428, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.484565 / Max Grad: 5.37e-06 ---
# Converged: max_grad 5.37e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 16.02110973052242, 'range': 0.23081310054262996, 'nugget': 1.3284430190573178}
# RESULT: {'resolution_label': 'x2', 'loss': 1.4846, 'total_s': 0.7419, 'est_sigmasq': 16.0211, 'est_range': 0.2308, 'est_nugget': 1.3284}
#
# ==========================================================================================
# FULL ISO | hour=4 | 2024_07_y24m07day03_hm03:53 | x1 | n_grid=18,126 | n_valid=16,863
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.7s. grid=114x159, heads=0, tails=16863, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.390580 / Max Grad: 6.36e-06 ---
# Converged: max_grad 6.36e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 16.248111835612995, 'range': 0.20804029839818, 'nugget': 1.1340019863778277}
# RESULT: {'resolution_label': 'x1', 'loss': 1.3906, 'total_s': 1.5683, 'est_sigmasq': 16.2481, 'est_range': 0.208, 'est_nugget': 1.134}
#
# ==========================================================================================
# FULL ISO | hour=5 | 2024_07_y24m07day03_hm04:48 | x8 | n_grid=2,266 | n_valid=2,145
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2145, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.789827 / Max Grad: 2.66e-06 ---
# Converged: max_grad 2.66e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.533416682670255, 'range': 0.393603044798678, 'nugget': 5.187894142619011}
# RESULT: {'resolution_label': 'x8', 'loss': 1.7898, 'total_s': 0.1658, 'est_sigmasq': 13.5334, 'est_range': 0.3936, 'est_nugget': 5.1879}
#
# ==========================================================================================
# FULL ISO | hour=5 | 2024_07_y24m07day03_hm04:48 | x4 | n_grid=4,532 | n_valid=4,288
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4288, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.702817 / Max Grad: 5.39e-07 ---
# Converged: max_grad 5.39e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.437343954957855, 'range': 0.3034971843249443, 'nugget': 4.035935858243107}
# RESULT: {'resolution_label': 'x4', 'loss': 1.7028, 'total_s': 0.3539, 'est_sigmasq': 14.4373, 'est_range': 0.3035, 'est_nugget': 4.0359}
#
# ==========================================================================================
# FULL ISO | hour=5 | 2024_07_y24m07day03_hm04:48 | x2 | n_grid=9,063 | n_valid=8,552
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=8552, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.536659 / Max Grad: 3.17e-06 ---
# Converged: max_grad 3.17e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 16.827279951542607, 'range': 0.22628804496621294, 'nugget': 1.6402797647573133}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5367, 'total_s': 0.7093, 'est_sigmasq': 16.8273, 'est_range': 0.2263, 'est_nugget': 1.6403}
#
# ==========================================================================================
# FULL ISO | hour=5 | 2024_07_y24m07day03_hm04:48 | x1 | n_grid=18,126 | n_valid=17,088
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.7s. grid=114x159, heads=0, tails=17088, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.430278 / Max Grad: 6.42e-06 ---
# Converged: max_grad 6.42e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 16.71109820804648, 'range': 0.19044274587110305, 'nugget': 1.1272690289773153}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4303, 'total_s': 1.6757, 'est_sigmasq': 16.7111, 'est_range': 0.1904, 'est_nugget': 1.1273}
#
# ==========================================================================================
# FULL ISO | hour=6 | 2024_07_y24m07day03_hm05:48 | x8 | n_grid=2,266 | n_valid=2,221
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2221, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.757999 / Max Grad: 6.58e-06 ---
# Converged: max_grad 6.58e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.825919818213471, 'range': 0.3611876479900588, 'nugget': 4.7220322109122606}
# RESULT: {'resolution_label': 'x8', 'loss': 1.758, 'total_s': 0.1727, 'est_sigmasq': 12.8259, 'est_range': 0.3612, 'est_nugget': 4.722}
#
# ==========================================================================================
# FULL ISO | hour=6 | 2024_07_y24m07day03_hm05:48 | x4 | n_grid=4,532 | n_valid=4,439
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4439, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.655799 / Max Grad: 7.01e-06 ---
# Converged: max_grad 7.01e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.394902370382814, 'range': 0.30211775073121266, 'nugget': 3.6958274151387176}
# RESULT: {'resolution_label': 'x4', 'loss': 1.6558, 'total_s': 0.3264, 'est_sigmasq': 13.3949, 'est_range': 0.3021, 'est_nugget': 3.6958}
#
# ==========================================================================================
# FULL ISO | hour=6 | 2024_07_y24m07day03_hm05:48 | x2 | n_grid=9,063 | n_valid=8,881
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=8881, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.518810 / Max Grad: 8.23e-06 ---
# Converged: max_grad 8.23e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.48583003957613, 'range': 0.2190667930192361, 'nugget': 2.00764093856491}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5188, 'total_s': 0.686, 'est_sigmasq': 14.4858, 'est_range': 0.2191, 'est_nugget': 2.0076}
#
# ==========================================================================================
# FULL ISO | hour=6 | 2024_07_y24m07day03_hm05:48 | x1 | n_grid=18,126 | n_valid=17,760
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=17760, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.428254 / Max Grad: 2.54e-06 ---
# Converged: max_grad 2.54e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.933628324751028, 'range': 0.16841386960676313, 'nugget': 1.154239685263375}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4283, 'total_s': 1.6783, 'est_sigmasq': 14.9336, 'est_range': 0.1684, 'est_nugget': 1.1542}
#
# ==========================================================================================
# FULL ISO | hour=7 | 2024_07_y24m07day03_hm06:48 | x8 | n_grid=2,266 | n_valid=2,264
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2264, m mean/med/max=8.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.694142 / Max Grad: 3.49e-06 ---
# Converged: max_grad 3.49e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 10.780779675181522, 'range': 0.3368562120248635, 'nugget': 4.28307174198005}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6941, 'total_s': 0.1793, 'est_sigmasq': 10.7808, 'est_range': 0.3369, 'est_nugget': 4.2831}
#
# ==========================================================================================
# FULL ISO | hour=7 | 2024_07_y24m07day03_hm06:48 | x4 | n_grid=4,532 | n_valid=4,527
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4527, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.620300 / Max Grad: 6.83e-07 ---
# Converged: max_grad 6.83e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 11.203393367206514, 'range': 0.352036000018594, 'nugget': 4.346184507167507}
# RESULT: {'resolution_label': 'x4', 'loss': 1.6203, 'total_s': 0.3398, 'est_sigmasq': 11.2034, 'est_range': 0.352, 'est_nugget': 4.3462}
#
# ==========================================================================================
# FULL ISO | hour=7 | 2024_07_y24m07day03_hm06:48 | x2 | n_grid=9,063 | n_valid=9,052
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9052, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.491634 / Max Grad: 1.80e-06 ---
# Converged: max_grad 1.80e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.226754686587922, 'range': 0.22744590787641433, 'nugget': 2.4658243842167917}
# RESULT: {'resolution_label': 'x2', 'loss': 1.4916, 'total_s': 0.6692, 'est_sigmasq': 12.2268, 'est_range': 0.2274, 'est_nugget': 2.4658}
#
# ==========================================================================================
# FULL ISO | hour=7 | 2024_07_y24m07day03_hm06:48 | x1 | n_grid=18,126 | n_valid=18,104
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18104, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.387473 / Max Grad: 9.24e-06 ---
# Converged: max_grad 9.24e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.122485110105083, 'range': 0.15229517634903933, 'nugget': 0.9321026323613387}
# RESULT: {'resolution_label': 'x1', 'loss': 1.3875, 'total_s': 1.7728, 'est_sigmasq': 13.1225, 'est_range': 0.1523, 'est_nugget': 0.9321}
#
# ==========================================================================================
# FULL ISO | hour=8 | 2024_07_y24m07day03_hm07:48 | x8 | n_grid=2,266 | n_valid=2,263
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2263, m mean/med/max=8.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.731268 / Max Grad: 1.95e-06 ---
# Converged: max_grad 1.95e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 9.484484133114476, 'range': 0.38012581728296163, 'nugget': 5.6983660629674615}
# RESULT: {'resolution_label': 'x8', 'loss': 1.7313, 'total_s': 0.1864, 'est_sigmasq': 9.4845, 'est_range': 0.3801, 'est_nugget': 5.6984}
#
# ==========================================================================================
# FULL ISO | hour=8 | 2024_07_y24m07day03_hm07:48 | x4 | n_grid=4,532 | n_valid=4,526
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4526, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.606911 / Max Grad: 4.61e-06 ---
# Converged: max_grad 4.61e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 10.330979332117835, 'range': 0.3223733580494427, 'nugget': 4.183168308853514}
# RESULT: {'resolution_label': 'x4', 'loss': 1.6069, 'total_s': 0.3415, 'est_sigmasq': 10.331, 'est_range': 0.3224, 'est_nugget': 4.1832}
#
# ==========================================================================================
# FULL ISO | hour=8 | 2024_07_y24m07day03_hm07:48 | x2 | n_grid=9,063 | n_valid=9,051
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9051, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.477173 / Max Grad: 9.67e-06 ---
# Converged: max_grad 9.67e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 11.679854181357577, 'range': 0.205917259840175, 'nugget': 2.16603036047659}
# RESULT: {'resolution_label': 'x2', 'loss': 1.4772, 'total_s': 0.6317, 'est_sigmasq': 11.6799, 'est_range': 0.2059, 'est_nugget': 2.166}
#
# ==========================================================================================
# FULL ISO | hour=8 | 2024_07_y24m07day03_hm07:48 | x1 | n_grid=18,126 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.403569 / Max Grad: 1.67e-06 ---
# Converged: max_grad 1.67e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 11.888542307301547, 'range': 0.14981603125123416, 'nugget': 1.3983685436555635}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4036, 'total_s': 1.7721, 'est_sigmasq': 11.8885, 'est_range': 0.1498, 'est_nugget': 1.3984}
# Saved full fits: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_iso_column_resolution_050826_full.csv
#     date_str  day_idx  hour_idx                     time_key  resolution_stride resolution_label  smooth mean_design fit_type                                  model  \
# 0   20240703        2         0  2024_07_y24m07day03_hm00:53                  8               x8     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 1   20240703        2         0  2024_07_y24m07day03_hm00:53                  4               x4     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 2   20240703        2         0  2024_07_y24m07day03_hm00:53                  2               x2     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 3   20240703        2         0  2024_07_y24m07day03_hm00:53                  1               x1     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 4   20240703        2         1  2024_07_y24m07day03_hm01:53                  8               x8     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 5   20240703        2         1  2024_07_y24m07day03_hm01:53                  4               x4     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 6   20240703        2         1  2024_07_y24m07day03_hm01:53                  2               x2     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 7   20240703        2         1  2024_07_y24m07day03_hm01:53                  1               x1     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 8   20240703        2         2  2024_07_y24m07day03_hm02:53                  8               x8     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 9   20240703        2         2  2024_07_y24m07day03_hm02:53                  4               x4     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 10  20240703        2         2  2024_07_y24m07day03_hm02:53                  2               x2     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 11  20240703        2         2  2024_07_y24m07day03_hm02:53                  1               x1     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 12  20240703        2         3  2024_07_y24m07day03_hm03:53                  8               x8     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 13  20240703        2         3  2024_07_y24m07day03_hm03:53                  4               x4     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 14  20240703        2         3  2024_07_y24m07day03_hm03:53                  2               x2     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 15  20240703        2         3  2024_07_y24m07day03_hm03:53                  1               x1     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 16  20240703        2         4  2024_07_y24m07day03_hm04:48                  8               x8     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 17  20240703        2         4  2024_07_y24m07day03_hm04:48                  4               x4     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 18  20240703        2         4  2024_07_y24m07day03_hm04:48                  2               x2     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 19  20240703        2         4  2024_07_y24m07day03_hm04:48                  1               x1     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 20  20240703        2         5  2024_07_y24m07day03_hm05:48                  8               x8     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 21  20240703        2         5  2024_07_y24m07day03_hm05:48                  4               x4     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 22  20240703        2         5  2024_07_y24m07day03_hm05:48                  2               x2     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 23  20240703        2         5  2024_07_y24m07day03_hm05:48                  1               x1     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 24  20240703        2         6  2024_07_y24m07day03_hm06:48                  8               x8     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 25  20240703        2         6  2024_07_y24m07day03_hm06:48                  4               x4     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 26  20240703        2         6  2024_07_y24m07day03_hm06:48                  2               x2     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 27  20240703        2         6  2024_07_y24m07day03_hm06:48                  1               x1     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 28  20240703        2         7  2024_07_y24m07day03_hm07:48                  8               x8     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 29  20240703        2         7  2024_07_y24m07day03_hm07:48                  4               x4     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 30  20240703        2         7  2024_07_y24m07day03_hm07:48                  2               x2     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 31  20240703        2         7  2024_07_y24m07day03_hm07:48                  1               x1     0.5      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
#
#                             kernel                                         coord_mode    loss  fit_iter_raw  fit_steps_reported  precompute_s   fit_s  total_s  n_grid  n_valid  \
# 0   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.6153             0                   1        0.0383  0.1648   0.2031    2266     2259
# 1   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.5040             0                   1        0.0851  0.3430   0.4282    4532     4518
# 2   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.5430             0                   1        0.2239  0.6643   0.8881    9063     9033
# 3   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.4111             0                   1        0.7708  1.2071   1.9780   18126    18067
# 4   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.6512             0                   1        0.0349  0.1572   0.1921    2266     2208
# 5   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.5263             0                   1        0.0831  0.3633   0.4463    4532     4422
# 6   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.4181             0                   1        0.2175  0.5510   0.7686    9063     8840
# 7   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.3587             0                   1        0.7428  0.9497   1.6925   18126    17670
# 8   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.7045             0                   1        0.0332  0.1333   0.1664    2266     2082
# 9   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.6075             0                   1        0.0776  0.2823   0.3598    4532     4176
# 10  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.4629             0                   1        0.2048  0.4037   0.6085    9063     8353
# 11  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.3635             0                   1        0.6999  0.8750   1.5749   18126    16698
# 12  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.7417             0                   1        0.0330  0.1099   0.1429    2266     2114
# 13  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.6400             0                   1        0.0778  0.2400   0.3179    4532     4217
# 14  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.4846             0                   1        0.2063  0.5355   0.7419    9063     8428
# 15  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.3906             0                   1        0.7101  0.8581   1.5683   18126    16863
# 16  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.7898             0                   1        0.0330  0.1328   0.1658    2266     2145
# 17  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.7028             0                   1        0.0809  0.2730   0.3539    4532     4288
# 18  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.5367             0                   1        0.2108  0.4985   0.7093    9063     8552
# 19  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.4303             0                   1        0.7277  0.9481   1.6757   18126    17088
# 20  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.7580             0                   1        0.0347  0.1380   0.1727    2266     2221
# 21  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.6558             0                   1        0.0822  0.2443   0.3264    4532     4439
# 22  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.5188             0                   1        0.2198  0.4662   0.6860    9063     8881
# 23  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.4283             0                   1        0.7549  0.9234   1.6783   18126    17760
# 24  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.6941             0                   1        0.0355  0.1438   0.1793    2266     2264
# 25  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.6203             0                   1        0.0845  0.2553   0.3398    4532     4527
# 26  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.4916             0                   1        0.2215  0.4477   0.6692    9063     9052
# 27  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.3875             0                   1        0.7813  0.9915   1.7728   18126    18104
# 28  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.7313             0                   1        0.0347  0.1517   0.1864    2266     2263
# 29  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.6069             0                   1        0.0836  0.2579   0.3415    4532     4526
# 30  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.4772             0                   1        0.2201  0.4116   0.6317    9063     9051
# 31  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.4036             0                   1        0.7637  1.0084   1.7721   18126    18102
#
#     valid_fraction  est_sigmasq  est_range  est_nugget  n_batches  n_tails  mean_m  max_m  largest_batch_n  total_conditioning_nominal  head_right_cols  above_count  \
# 0           0.9969       8.6677     0.4971      4.4164          1     2259    10.0     10             2259                          10                0            2
# 1           0.9969       9.0600     0.3875      3.4295          1     4518    10.0     10             4518                          10                0            2
# 2           0.9967      10.0542     0.2933      4.2270          1     9033    10.0     10             9033                          10                0            2
# 3           0.9967      10.2213     0.2472      3.0520          1    18067    10.0     10            18067                          10                0            2
# 4           0.9744      11.0936     0.4165      3.8572          1     2208    10.0     10             2208                          10                0            2
# 5           0.9757      12.2582     0.3544      2.6059          1     4422    10.0     10             4422                          10                0            2
# 6           0.9754      12.0204     0.2861      2.2453          1     8840    10.0     10             8840                          10                0            2
# 7           0.9748      11.9110     0.2253      1.9943          1    17670    10.0     10            17670                          10                0            2
# 8           0.9188      12.6140     0.4593      4.4169          1     2082    10.0     10             2082                          10                0            2
# 9           0.9214      13.0138     0.3772      3.7523          1     4176    10.0     10             4176                          10                0            2
# 10          0.9217      14.0772     0.2458      1.8124          1     8353    10.0     10             8353                          10                0            2
# 11          0.9212      14.6136     0.2206      1.3966          1    16698    10.0     10            16698                          10                0            2
# 12          0.9329      14.5660     0.4014      3.9968          1     2114    10.0     10             2114                          10                0            2
# 13          0.9305      15.0092     0.3506      3.4103          1     4217    10.0     10             4217                          10                0            2
# 14          0.9299      16.0211     0.2308      1.3284          1     8428    10.0     10             8428                          10                0            2
# 15          0.9303      16.2481     0.2080      1.1340          1    16863    10.0     10            16863                          10                0            2
# 16          0.9466      13.5334     0.3936      5.1879          1     2145    10.0     10             2145                          10                0            2
# 17          0.9462      14.4373     0.3035      4.0359          1     4288    10.0     10             4288                          10                0            2
# 18          0.9436      16.8273     0.2263      1.6403          1     8552    10.0     10             8552                          10                0            2
# 19          0.9427      16.7111     0.1904      1.1273          1    17088    10.0     10            17088                          10                0            2
# 20          0.9801      12.8259     0.3612      4.7220          1     2221    10.0     10             2221                          10                0            2
# 21          0.9795      13.3949     0.3021      3.6958          1     4439    10.0     10             4439                          10                0            2
# 22          0.9799      14.4858     0.2191      2.0076          1     8881    10.0     10             8881                          10                0            2
# 23          0.9798      14.9336     0.1684      1.1542          1    17760    10.0     10            17760                          10                0            2
# 24          0.9991      10.7808     0.3369      4.2831          1     2264    10.0     10             2264                          10                0            2
# 25          0.9989      11.2034     0.3520      4.3462          1     4527    10.0     10             4527                          10                0            2
# 26          0.9988      12.2268     0.2274      2.4658          1     9052    10.0     10             9052                          10                0            2
# 27          0.9988      13.1225     0.1523      0.9321          1    18104    10.0     10            18104                          10                0            2
# 28          0.9987       9.4845     0.3801      5.6984          1     2263    10.0     10             2263                          10                0            2
# 29          0.9987      10.3310     0.3224      4.1832          1     4526    10.0     10             4526                          10                0            2
# 30          0.9987      11.6799     0.2059      2.1660          1     9051    10.0     10             9051                          10                0            2
# 31          0.9987      11.8885     0.1498      1.3984          1    18102    10.0     10            18102                          10                0            2
#
#     right_col_count  per_time_conditioning_count
# 0                 3                           10
# 1                 3                           10
# 2                 3                           10
# 3                 3                           10
# 4                 3                           10
# 5                 3                           10
# 6                 3                           10
# 7                 3                           10
# 8                 3                           10
# 9                 3                           10
# 10                3                           10
# 11                3                           10
# 12                3                           10
# 13                3                           10
# 14                3                           10
# 15                3                           10
# 16                3                           10
# 17                3                           10
# 18                3                           10
# 19                3                           10
# 20                3                           10
# 21                3                           10
# 22                3                           10
# 23                3                           10
# 24                3                           10
# 25                3                           10
# 26                3                           10
# 27                3                           10
# 28                3                           10
# 29                3                           10
# 30                3                           10
# 31                3                           10

# %%
partial_rows = []
if RUN_PARTIAL:
    if 'full_df' not in globals() or full_df.empty:
        full_path = OUT_DIR / f'{OUT_PREFIX}_full.csv'
        full_df = pd.read_csv(full_path)

    anchor_rows = full_df[full_df['resolution_stride'] == 1].copy()
    anchors = {
        (int(r.hour_idx), float(r.smooth)): {
            'sigmasq': float(r.est_sigmasq),
            'range': float(r.est_range),
            'nugget': float(r.est_nugget),
        }
        for r in anchor_rows.itertuples(index=False)
    }
    print('anchors from x1 full fits:', anchors)

    for smooth in FIT_SMOOTHS:
        for hour_idx in HOUR_IDX_LIST:
            anchor = anchors[(int(hour_idx), float(smooth))]
            for fit_type in ['sigma_only_x1_anchor', 'range_only_x1_anchor']:
                for stride in RESOLUTION_STRIDES:
                    partial_rows.append(fit_partial_iso(hour_idx, stride, smooth, anchor, fit_type))
                    partial_df_tmp = round_df(pd.DataFrame(partial_rows))
                    partial_df_tmp.to_csv(OUT_DIR / f'{OUT_PREFIX}_partial.csv', index=False, float_format=f'%.{ROUND_DECIMALS}f')

partial_df = pd.DataFrame(partial_rows)
partial_path = OUT_DIR / f'{OUT_PREFIX}_partial.csv'
round_df(partial_df).to_csv(partial_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
print('Saved partial fits:', partial_path)
display(round_df(partial_df))
# Out:
# anchors from x1 full fits: {(0, 0.5): {'sigmasq': 10.221319459524755, 'range': 0.24721506242884986, 'nugget': 3.0519666734040785}, (1, 0.5): {'sigmasq': 11.910981146543515, 'range': 0.22525076759027143, 'nugget': 1.9942502867895966}, (2, 0.5): {'sigmasq': 14.61356663415897, 'range': 0.2205532522379307, 'nugget': 1.3965595333038436}, (3, 0.5): {'sigmasq': 16.248111835612995, 'range': 0.20804029839818, 'nugget': 1.1340019863778277}, (4, 0.5): {'sigmasq': 16.71109820804648, 'range': 0.19044274587110305, 'nugget': 1.1272690289773153}, (5, 0.5): {'sigmasq': 14.933628324751028, 'range': 0.16841386960676313, 'nugget': 1.154239685263375}, (6, 0.5): {'sigmasq': 13.122485110105083, 'range': 0.15229517634903933, 'nugget': 0.9321026323613387}, (7, 0.5): {'sigmasq': 11.888542307301547, 'range': 0.14981603125123416, 'nugget': 1.3983685436555635}}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=1 | 2024_07_y24m07day03_hm00:53 | x8 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.608039 / sigmasq Grad: 1.81e-07 ---
# RESULT: {'resolution_label': 'x8', 'loss': 1.608, 'total_s': 0.0817, 'est_sigmasq': 8.9741, 'est_range': 0.2472, 'est_nugget': 3.052}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=1 | 2024_07_y24m07day03_hm00:53 | x4 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.496526 / sigmasq Grad: 1.95e-08 ---
# RESULT: {'resolution_label': 'x4', 'loss': 1.4965, 'total_s': 0.1919, 'est_sigmasq': 7.7706, 'est_range': 0.2472, 'est_nugget': 3.052}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=1 | 2024_07_y24m07day03_hm00:53 | x2 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.539930 / sigmasq Grad: 5.62e-08 ---
# RESULT: {'resolution_label': 'x2', 'loss': 1.5399, 'total_s': 0.4288, 'est_sigmasq': 12.1947, 'est_range': 0.2472, 'est_nugget': 3.052}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=1 | 2024_07_y24m07day03_hm00:53 | x1 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18067, m mean/med/max=9.9/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.409623 / sigmasq Grad: 2.86e-07 ---
# RESULT: {'resolution_label': 'x1', 'loss': 1.4096, 'total_s': 0.8627, 'est_sigmasq': 10.2213, 'est_range': 0.2472, 'est_nugget': 3.052}
#
# ==========================================================================================
# range_only_x1_anchor | hour=1 | 2024_07_y24m07day03_hm00:53 | x8 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.608039 / range Grad: 4.79e-07 ---
# RESULT: {'resolution_label': 'x8', 'loss': 1.608, 'total_s': 0.0934, 'est_sigmasq': 10.2213, 'est_range': 0.3563, 'est_nugget': 3.052}
#
# ==========================================================================================
# range_only_x1_anchor | hour=1 | 2024_07_y24m07day03_hm00:53 | x4 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.496526 / range Grad: 1.93e-06 ---
# RESULT: {'resolution_label': 'x4', 'loss': 1.4965, 'total_s': 0.1854, 'est_sigmasq': 10.2213, 'est_range': 0.3772, 'est_nugget': 3.052}
#
# ==========================================================================================
# range_only_x1_anchor | hour=1 | 2024_07_y24m07day03_hm00:53 | x2 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.539930 / range Grad: 5.15e-06 ---
# RESULT: {'resolution_label': 'x2', 'loss': 1.5399, 'total_s': 0.3907, 'est_sigmasq': 10.2213, 'est_range': 0.1969, 'est_nugget': 3.052}
#
# ==========================================================================================
# range_only_x1_anchor | hour=1 | 2024_07_y24m07day03_hm00:53 | x1 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18067, m mean/med/max=9.9/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.409623 / range Grad: 4.20e-07 ---
# RESULT: {'resolution_label': 'x1', 'loss': 1.4096, 'total_s': 0.8792, 'est_sigmasq': 10.2213, 'est_range': 0.2472, 'est_nugget': 3.052}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=2 | 2024_07_y24m07day03_hm01:53 | x8 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2208, m mean/med/max=8.7/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.651091 / sigmasq Grad: 1.16e-06 ---
# RESULT: {'resolution_label': 'x8', 'loss': 1.6511, 'total_s': 0.072, 'est_sigmasq': 11.8236, 'est_range': 0.2253, 'est_nugget': 1.9943}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=2 | 2024_07_y24m07day03_hm01:53 | x4 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4422, m mean/med/max=9.5/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.522019 / sigmasq Grad: 1.64e-07 ---
# RESULT: {'resolution_label': 'x4', 'loss': 1.522, 'total_s': 0.1837, 'est_sigmasq': 10.3228, 'est_range': 0.2253, 'est_nugget': 1.9943}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=2 | 2024_07_y24m07day03_hm01:53 | x2 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=8840, m mean/med/max=9.8/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.413733 / sigmasq Grad: 1.34e-06 ---
# RESULT: {'resolution_label': 'x2', 'loss': 1.4137, 'total_s': 0.4199, 'est_sigmasq': 10.7284, 'est_range': 0.2253, 'est_nugget': 1.9943}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=2 | 2024_07_y24m07day03_hm01:53 | x1 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.7s. grid=114x159, heads=0, tails=17670, m mean/med/max=9.9/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.355836 / sigmasq Grad: 5.41e-06 ---
# RESULT: {'resolution_label': 'x1', 'loss': 1.3558, 'total_s': 0.8508, 'est_sigmasq': 11.911, 'est_range': 0.2253, 'est_nugget': 1.9943}
#
# ==========================================================================================
# range_only_x1_anchor | hour=2 | 2024_07_y24m07day03_hm01:53 | x8 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2208, m mean/med/max=8.7/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.651091 / range Grad: 6.95e-06 ---
# RESULT: {'resolution_label': 'x8', 'loss': 1.6511, 'total_s': 0.0822, 'est_sigmasq': 11.911, 'est_range': 0.2642, 'est_nugget': 1.9943}
#
# ==========================================================================================
# range_only_x1_anchor | hour=2 | 2024_07_y24m07day03_hm01:53 | x4 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4422, m mean/med/max=9.5/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.522019 / range Grad: 2.22e-07 ---
# RESULT: {'resolution_label': 'x4', 'loss': 1.522, 'total_s': 0.1718, 'est_sigmasq': 11.911, 'est_range': 0.2879, 'est_nugget': 1.9943}
#
# ==========================================================================================
# range_only_x1_anchor | hour=2 | 2024_07_y24m07day03_hm01:53 | x2 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=8840, m mean/med/max=9.8/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.413733 / range Grad: 1.48e-06 ---
# RESULT: {'resolution_label': 'x2', 'loss': 1.4137, 'total_s': 0.3847, 'est_sigmasq': 11.911, 'est_range': 0.2588, 'est_nugget': 1.9943}
#
# ==========================================================================================
# range_only_x1_anchor | hour=2 | 2024_07_y24m07day03_hm01:53 | x1 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.7s. grid=114x159, heads=0, tails=17670, m mean/med/max=9.9/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.355836 / range Grad: 2.42e-06 ---
# RESULT: {'resolution_label': 'x1', 'loss': 1.3558, 'total_s': 0.831, 'est_sigmasq': 11.911, 'est_range': 0.2253, 'est_nugget': 1.9943}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=3 | 2024_07_y24m07day03_hm02:53 | x8 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2082, m mean/med/max=8.6/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.707034 / sigmasq Grad: 7.07e-07 ---
# RESULT: {'resolution_label': 'x8', 'loss': 1.707, 'total_s': 0.0692, 'est_sigmasq': 14.5583, 'est_range': 0.2206, 'est_nugget': 1.3966}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=3 | 2024_07_y24m07day03_hm02:53 | x4 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4176, m mean/med/max=9.5/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.609512 / sigmasq Grad: 1.56e-07 ---
# RESULT: {'resolution_label': 'x4', 'loss': 1.6095, 'total_s': 0.1599, 'est_sigmasq': 14.1006, 'est_range': 0.2206, 'est_nugget': 1.3966}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=3 | 2024_07_y24m07day03_hm02:53 | x2 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=8353, m mean/med/max=9.8/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.461489 / sigmasq Grad: 4.52e-06 ---
# RESULT: {'resolution_label': 'x2', 'loss': 1.4615, 'total_s': 0.3286, 'est_sigmasq': 14.2779, 'est_range': 0.2206, 'est_nugget': 1.3966}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=3 | 2024_07_y24m07day03_hm02:53 | x1 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.7s. grid=114x159, heads=0, tails=16698, m mean/med/max=9.9/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.357688 / sigmasq Grad: 1.08e-06 ---
# RESULT: {'resolution_label': 'x1', 'loss': 1.3577, 'total_s': 0.7831, 'est_sigmasq': 14.6136, 'est_range': 0.2206, 'est_nugget': 1.3966}
#
# ==========================================================================================
# range_only_x1_anchor | hour=3 | 2024_07_y24m07day03_hm02:53 | x8 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2082, m mean/med/max=8.6/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.707034 / range Grad: 8.45e-06 ---
# RESULT: {'resolution_label': 'x8', 'loss': 1.707, 'total_s': 0.0731, 'est_sigmasq': 14.6136, 'est_range': 0.2412, 'est_nugget': 1.3966}
#
# ==========================================================================================
# range_only_x1_anchor | hour=3 | 2024_07_y24m07day03_hm02:53 | x4 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4176, m mean/med/max=9.5/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.609512 / range Grad: 1.02e-06 ---
# RESULT: {'resolution_label': 'x4', 'loss': 1.6095, 'total_s': 0.1547, 'est_sigmasq': 14.6136, 'est_range': 0.2326, 'est_nugget': 1.3966}
#
# ==========================================================================================
# range_only_x1_anchor | hour=3 | 2024_07_y24m07day03_hm02:53 | x2 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=8353, m mean/med/max=9.8/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.461489 / range Grad: 1.23e-05 ---
# --- Step 2/8 / Loss: 1.461426 / range Grad: 1.23e-05 ---
# --- Step 3/8 / Loss: 1.461426 / range Grad: 1.23e-05 ---
# --- Step 4/8 / Loss: 1.461426 / range Grad: 1.23e-05 ---
# --- Step 5/8 / Loss: 1.461426 / range Grad: 1.23e-05 ---
# --- Step 6/8 / Loss: 1.461426 / range Grad: 1.23e-05 ---
# --- Step 7/8 / Loss: 1.461426 / range Grad: 1.23e-05 ---
# --- Step 8/8 / Loss: 1.461426 / range Grad: 1.23e-05 ---
# RESULT: {'resolution_label': 'x2', 'loss': 1.4614, 'total_s': 0.6077, 'est_sigmasq': 14.6136, 'est_range': 0.2259, 'est_nugget': 1.3966}
#
# ==========================================================================================
# range_only_x1_anchor | hour=3 | 2024_07_y24m07day03_hm02:53 | x1 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.7s. grid=114x159, heads=0, tails=16698, m mean/med/max=9.9/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.357688 / range Grad: 9.82e-07 ---
# RESULT: {'resolution_label': 'x1', 'loss': 1.3577, 'total_s': 0.7813, 'est_sigmasq': 14.6136, 'est_range': 0.2206, 'est_nugget': 1.3966}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=4 | 2024_07_y24m07day03_hm03:53 | x8 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2114, m mean/med/max=8.7/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.743507 / sigmasq Grad: 6.60e-08 ---
# RESULT: {'resolution_label': 'x8', 'loss': 1.7435, 'total_s': 0.0759, 'est_sigmasq': 15.9611, 'est_range': 0.208, 'est_nugget': 1.134}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=4 | 2024_07_y24m07day03_hm03:53 | x4 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4217, m mean/med/max=9.5/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.642477 / sigmasq Grad: 1.97e-06 ---
# RESULT: {'resolution_label': 'x4', 'loss': 1.6425, 'total_s': 0.1498, 'est_sigmasq': 15.2698, 'est_range': 0.208, 'est_nugget': 1.134}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=4 | 2024_07_y24m07day03_hm03:53 | x2 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=8428, m mean/med/max=9.8/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.482125 / sigmasq Grad: 4.83e-07 ---
# RESULT: {'resolution_label': 'x2', 'loss': 1.4821, 'total_s': 0.3661, 'est_sigmasq': 15.3582, 'est_range': 0.208, 'est_nugget': 1.134}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=4 | 2024_07_y24m07day03_hm03:53 | x1 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.7s. grid=114x159, heads=0, tails=16863, m mean/med/max=9.9/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.383697 / sigmasq Grad: 1.87e-07 ---
# RESULT: {'resolution_label': 'x1', 'loss': 1.3837, 'total_s': 0.7908, 'est_sigmasq': 16.2481, 'est_range': 0.208, 'est_nugget': 1.134}
#
# ==========================================================================================
# range_only_x1_anchor | hour=4 | 2024_07_y24m07day03_hm03:53 | x8 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2114, m mean/med/max=8.7/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.743507 / range Grad: 8.08e-08 ---
# RESULT: {'resolution_label': 'x8', 'loss': 1.7435, 'total_s': 0.0863, 'est_sigmasq': 16.2481, 'est_range': 0.2362, 'est_nugget': 1.134}
#
# ==========================================================================================
# range_only_x1_anchor | hour=4 | 2024_07_y24m07day03_hm03:53 | x4 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4217, m mean/med/max=9.5/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.642477 / range Grad: 1.23e-05 ---
# --- Step 2/8 / Loss: 1.641278 / range Grad: 1.23e-05 ---
# --- Step 3/8 / Loss: 1.641278 / range Grad: 1.23e-05 ---
# --- Step 4/8 / Loss: 1.641278 / range Grad: 1.23e-05 ---
# --- Step 5/8 / Loss: 1.641278 / range Grad: 1.23e-05 ---
# --- Step 6/8 / Loss: 1.641278 / range Grad: 1.23e-05 ---
# --- Step 7/8 / Loss: 1.641278 / range Grad: 1.23e-05 ---
# --- Step 8/8 / Loss: 1.641278 / range Grad: 1.23e-05 ---
# RESULT: {'resolution_label': 'x4', 'loss': 1.6413, 'total_s': 0.3044, 'est_sigmasq': 16.2481, 'est_range': 0.229, 'est_nugget': 1.134}
#
# ==========================================================================================
# range_only_x1_anchor | hour=4 | 2024_07_y24m07day03_hm03:53 | x2 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=8428, m mean/med/max=9.8/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.482125 / range Grad: 2.14e-06 ---
# RESULT: {'resolution_label': 'x2', 'loss': 1.4821, 'total_s': 0.364, 'est_sigmasq': 16.2481, 'est_range': 0.2225, 'est_nugget': 1.134}
#
# ==========================================================================================
# range_only_x1_anchor | hour=4 | 2024_07_y24m07day03_hm03:53 | x1 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.7s. grid=114x159, heads=0, tails=16863, m mean/med/max=9.9/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.383697 / range Grad: 2.47e-06 ---
# RESULT: {'resolution_label': 'x1', 'loss': 1.3837, 'total_s': 0.7824, 'est_sigmasq': 16.2481, 'est_range': 0.208, 'est_nugget': 1.134}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=5 | 2024_07_y24m07day03_hm04:48 | x8 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2145, m mean/med/max=8.7/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.788887 / sigmasq Grad: 5.59e-06 ---
# RESULT: {'resolution_label': 'x8', 'loss': 1.7889, 'total_s': 0.0648, 'est_sigmasq': 16.8611, 'est_range': 0.1904, 'est_nugget': 1.1273}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=5 | 2024_07_y24m07day03_hm04:48 | x4 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4288, m mean/med/max=9.5/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.699388 / sigmasq Grad: 6.03e-08 ---
# RESULT: {'resolution_label': 'x4', 'loss': 1.6994, 'total_s': 0.1609, 'est_sigmasq': 16.4064, 'est_range': 0.1904, 'est_nugget': 1.1273}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=5 | 2024_07_y24m07day03_hm04:48 | x2 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=8552, m mean/med/max=9.8/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.533176 / sigmasq Grad: 1.05e-07 ---
# RESULT: {'resolution_label': 'x2', 'loss': 1.5332, 'total_s': 0.3712, 'est_sigmasq': 16.2229, 'est_range': 0.1904, 'est_nugget': 1.1273}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=5 | 2024_07_y24m07day03_hm04:48 | x1 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.7s. grid=114x159, heads=0, tails=17088, m mean/med/max=9.9/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.423097 / sigmasq Grad: 6.42e-06 ---
# RESULT: {'resolution_label': 'x1', 'loss': 1.4231, 'total_s': 0.831, 'est_sigmasq': 16.7111, 'est_range': 0.1904, 'est_nugget': 1.1273}
#
# ==========================================================================================
# range_only_x1_anchor | hour=5 | 2024_07_y24m07day03_hm04:48 | x8 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2145, m mean/med/max=8.7/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.788887 / range Grad: 3.91e-06 ---
# RESULT: {'resolution_label': 'x8', 'loss': 1.7889, 'total_s': 0.0822, 'est_sigmasq': 16.7111, 'est_range': 0.2009, 'est_nugget': 1.1273}
#
# ==========================================================================================
# range_only_x1_anchor | hour=5 | 2024_07_y24m07day03_hm04:48 | x4 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4288, m mean/med/max=9.5/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.699388 / range Grad: 4.84e-07 ---
# RESULT: {'resolution_label': 'x4', 'loss': 1.6994, 'total_s': 0.1686, 'est_sigmasq': 16.7111, 'est_range': 0.1966, 'est_nugget': 1.1273}
#
# ==========================================================================================
# range_only_x1_anchor | hour=5 | 2024_07_y24m07day03_hm04:48 | x2 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=8552, m mean/med/max=9.8/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.533176 / range Grad: 6.79e-07 ---
# RESULT: {'resolution_label': 'x2', 'loss': 1.5332, 'total_s': 0.3822, 'est_sigmasq': 16.7111, 'est_range': 0.1985, 'est_nugget': 1.1273}
#
# ==========================================================================================
# range_only_x1_anchor | hour=5 | 2024_07_y24m07day03_hm04:48 | x1 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.7s. grid=114x159, heads=0, tails=17088, m mean/med/max=9.9/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.423097 / range Grad: 5.03e-06 ---
# RESULT: {'resolution_label': 'x1', 'loss': 1.4231, 'total_s': 0.8016, 'est_sigmasq': 16.7111, 'est_range': 0.1904, 'est_nugget': 1.1273}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=6 | 2024_07_y24m07day03_hm05:48 | x8 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2221, m mean/med/max=8.7/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.762207 / sigmasq Grad: 9.88e-06 ---
# RESULT: {'resolution_label': 'x8', 'loss': 1.7622, 'total_s': 0.069, 'est_sigmasq': 15.1126, 'est_range': 0.1684, 'est_nugget': 1.1542}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=6 | 2024_07_y24m07day03_hm05:48 | x4 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4439, m mean/med/max=9.5/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.659511 / sigmasq Grad: 4.15e-06 ---
# RESULT: {'resolution_label': 'x4', 'loss': 1.6595, 'total_s': 0.1668, 'est_sigmasq': 13.8437, 'est_range': 0.1684, 'est_nugget': 1.1542}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=6 | 2024_07_y24m07day03_hm05:48 | x2 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=8881, m mean/med/max=9.8/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.518942 / sigmasq Grad: 5.41e-07 ---
# RESULT: {'resolution_label': 'x2', 'loss': 1.5189, 'total_s': 0.3955, 'est_sigmasq': 14.1523, 'est_range': 0.1684, 'est_nugget': 1.1542}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=6 | 2024_07_y24m07day03_hm05:48 | x1 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=17760, m mean/med/max=9.9/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.422230 / sigmasq Grad: 2.54e-06 ---
# RESULT: {'resolution_label': 'x1', 'loss': 1.4222, 'total_s': 0.8404, 'est_sigmasq': 14.9336, 'est_range': 0.1684, 'est_nugget': 1.1542}
#
# ==========================================================================================
# range_only_x1_anchor | hour=6 | 2024_07_y24m07day03_hm05:48 | x8 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2221, m mean/med/max=8.7/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.762207 / range Grad: 9.80e-08 ---
# RESULT: {'resolution_label': 'x8', 'loss': 1.7622, 'total_s': 0.0906, 'est_sigmasq': 14.9336, 'est_range': 0.1909, 'est_nugget': 1.1542}
#
# ==========================================================================================
# range_only_x1_anchor | hour=6 | 2024_07_y24m07day03_hm05:48 | x4 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4439, m mean/med/max=9.5/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.659511 / range Grad: 3.20e-08 ---
# RESULT: {'resolution_label': 'x4', 'loss': 1.6595, 'total_s': 0.1886, 'est_sigmasq': 14.9336, 'est_range': 0.1936, 'est_nugget': 1.1542}
#
# ==========================================================================================
# range_only_x1_anchor | hour=6 | 2024_07_y24m07day03_hm05:48 | x2 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=8881, m mean/med/max=9.8/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.518942 / range Grad: 2.76e-06 ---
# RESULT: {'resolution_label': 'x2', 'loss': 1.5189, 'total_s': 0.3895, 'est_sigmasq': 14.9336, 'est_range': 0.1807, 'est_nugget': 1.1542}
#
# ==========================================================================================
# range_only_x1_anchor | hour=6 | 2024_07_y24m07day03_hm05:48 | x1 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=17760, m mean/med/max=9.9/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.422230 / range Grad: 1.01e-06 ---
# RESULT: {'resolution_label': 'x1', 'loss': 1.4222, 'total_s': 0.8454, 'est_sigmasq': 14.9336, 'est_range': 0.1684, 'est_nugget': 1.1542}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=7 | 2024_07_y24m07day03_hm06:48 | x8 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2264, m mean/med/max=8.8/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.702067 / sigmasq Grad: 3.73e-06 ---
# RESULT: {'resolution_label': 'x8', 'loss': 1.7021, 'total_s': 0.0683, 'est_sigmasq': 13.0307, 'est_range': 0.1523, 'est_nugget': 0.9321}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=7 | 2024_07_y24m07day03_hm06:48 | x4 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4527, m mean/med/max=9.5/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.627233 / sigmasq Grad: 1.41e-06 ---
# RESULT: {'resolution_label': 'x4', 'loss': 1.6272, 'total_s': 0.1702, 'est_sigmasq': 12.4911, 'est_range': 0.1523, 'est_nugget': 0.9321}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=7 | 2024_07_y24m07day03_hm06:48 | x2 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9052, m mean/med/max=9.8/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.494970 / sigmasq Grad: 1.02e-05 ---
# --- Step 2/8 / Loss: 1.494929 / sigmasq Grad: 1.02e-05 ---
# --- Step 3/8 / Loss: 1.494929 / sigmasq Grad: 1.02e-05 ---
# --- Step 4/8 / Loss: 1.494929 / sigmasq Grad: 1.02e-05 ---
# --- Step 5/8 / Loss: 1.494929 / sigmasq Grad: 1.02e-05 ---
# --- Step 6/8 / Loss: 1.494929 / sigmasq Grad: 1.02e-05 ---
# --- Step 7/8 / Loss: 1.494929 / sigmasq Grad: 1.02e-05 ---
# --- Step 8/8 / Loss: 1.494929 / sigmasq Grad: 1.02e-05 ---
# RESULT: {'resolution_label': 'x2', 'loss': 1.4949, 'total_s': 0.6476, 'est_sigmasq': 12.9226, 'est_range': 0.1523, 'est_nugget': 0.9321}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=7 | 2024_07_y24m07day03_hm06:48 | x1 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18104, m mean/med/max=9.9/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.380722 / sigmasq Grad: 9.24e-06 ---
# RESULT: {'resolution_label': 'x1', 'loss': 1.3807, 'total_s': 0.8614, 'est_sigmasq': 13.1225, 'est_range': 0.1523, 'est_nugget': 0.9321}
#
# ==========================================================================================
# range_only_x1_anchor | hour=7 | 2024_07_y24m07day03_hm06:48 | x8 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2264, m mean/med/max=8.8/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.702067 / range Grad: 3.91e-07 ---
# RESULT: {'resolution_label': 'x8', 'loss': 1.7021, 'total_s': 0.0966, 'est_sigmasq': 13.1225, 'est_range': 0.1767, 'est_nugget': 0.9321}
#
# ==========================================================================================
# range_only_x1_anchor | hour=7 | 2024_07_y24m07day03_hm06:48 | x4 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4527, m mean/med/max=9.5/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.627233 / range Grad: 1.49e-08 ---
# RESULT: {'resolution_label': 'x4', 'loss': 1.6272, 'total_s': 0.1875, 'est_sigmasq': 13.1225, 'est_range': 0.1712, 'est_nugget': 0.9321}
#
# ==========================================================================================
# range_only_x1_anchor | hour=7 | 2024_07_y24m07day03_hm06:48 | x2 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9052, m mean/med/max=9.8/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.494970 / range Grad: 1.11e-07 ---
# RESULT: {'resolution_label': 'x2', 'loss': 1.495, 'total_s': 0.3953, 'est_sigmasq': 13.1225, 'est_range': 0.1557, 'est_nugget': 0.9321}
#
# ==========================================================================================
# range_only_x1_anchor | hour=7 | 2024_07_y24m07day03_hm06:48 | x1 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18104, m mean/med/max=9.9/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.380722 / range Grad: 4.00e-06 ---
# RESULT: {'resolution_label': 'x1', 'loss': 1.3807, 'total_s': 0.8529, 'est_sigmasq': 13.1225, 'est_range': 0.1523, 'est_nugget': 0.9321}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=8 | 2024_07_y24m07day03_hm07:48 | x8 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2263, m mean/med/max=8.8/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.736463 / sigmasq Grad: 7.56e-06 ---
# RESULT: {'resolution_label': 'x8', 'loss': 1.7365, 'total_s': 0.0836, 'est_sigmasq': 13.1347, 'est_range': 0.1498, 'est_nugget': 1.3984}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=8 | 2024_07_y24m07day03_hm07:48 | x4 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4526, m mean/med/max=9.5/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.612497 / sigmasq Grad: 1.24e-06 ---
# RESULT: {'resolution_label': 'x4', 'loss': 1.6125, 'total_s': 0.1717, 'est_sigmasq': 11.1735, 'est_range': 0.1498, 'est_nugget': 1.3984}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=8 | 2024_07_y24m07day03_hm07:48 | x2 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9051, m mean/med/max=9.8/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.478756 / sigmasq Grad: 2.94e-07 ---
# RESULT: {'resolution_label': 'x2', 'loss': 1.4788, 'total_s': 0.3982, 'est_sigmasq': 11.0977, 'est_range': 0.1498, 'est_nugget': 1.3984}
#
# ==========================================================================================
# sigma_only_x1_anchor | hour=8 | 2024_07_y24m07day03_hm07:48 | x1 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=9.9/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.399939 / sigmasq Grad: 1.67e-06 ---
# RESULT: {'resolution_label': 'x1', 'loss': 1.3999, 'total_s': 0.8569, 'est_sigmasq': 11.8885, 'est_range': 0.1498, 'est_nugget': 1.3984}
#
# ==========================================================================================
# range_only_x1_anchor | hour=8 | 2024_07_y24m07day03_hm07:48 | x8 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2263, m mean/med/max=8.8/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.736463 / range Grad: 1.08e-06 ---
# RESULT: {'resolution_label': 'x8', 'loss': 1.7365, 'total_s': 0.0823, 'est_sigmasq': 11.8885, 'est_range': 0.156, 'est_nugget': 1.3984}
#
# ==========================================================================================
# range_only_x1_anchor | hour=8 | 2024_07_y24m07day03_hm07:48 | x4 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4526, m mean/med/max=9.5/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.612497 / range Grad: 1.05e-05 ---
# --- Step 2/8 / Loss: 1.609629 / range Grad: 1.05e-05 ---
# --- Step 3/8 / Loss: 1.609629 / range Grad: 1.05e-05 ---
# --- Step 4/8 / Loss: 1.609629 / range Grad: 1.05e-05 ---
# --- Step 5/8 / Loss: 1.609629 / range Grad: 1.05e-05 ---
# --- Step 6/8 / Loss: 1.609629 / range Grad: 1.05e-05 ---
# --- Step 7/8 / Loss: 1.609629 / range Grad: 1.05e-05 ---
# --- Step 8/8 / Loss: 1.609629 / range Grad: 1.05e-05 ---
# RESULT: {'resolution_label': 'x4', 'loss': 1.6096, 'total_s': 0.3218, 'est_sigmasq': 11.8885, 'est_range': 0.1755, 'est_nugget': 1.3984}
#
# ==========================================================================================
# range_only_x1_anchor | hour=8 | 2024_07_y24m07day03_hm07:48 | x2 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9051, m mean/med/max=9.8/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.478756 / range Grad: 2.31e-06 ---
# RESULT: {'resolution_label': 'x2', 'loss': 1.4788, 'total_s': 0.4025, 'est_sigmasq': 11.8885, 'est_range': 0.1664, 'est_nugget': 1.3984}
#
# ==========================================================================================
# range_only_x1_anchor | hour=8 | 2024_07_y24m07day03_hm07:48 | x1 | anchor=x1
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=9.9/10/10
# --- Starting partial Pure-Space Iso L-BFGS ---
# --- Step 1/8 / Loss: 1.399939 / range Grad: 1.53e-07 ---
# RESULT: {'resolution_label': 'x1', 'loss': 1.3999, 'total_s': 0.8666, 'est_sigmasq': 11.8885, 'est_range': 0.1498, 'est_nugget': 1.3984}
# Saved partial fits: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_iso_column_resolution_050826_partial.csv
#     date_str  day_idx  hour_idx                     time_key  resolution_stride resolution_label  smooth mean_design              fit_type                                  model  \
# 0   20240703        2         0  2024_07_y24m07day03_hm00:53                  8               x8     0.5      latlon  sigma_only_x1_anchor  ColumnSpaceIso_Up2_Right3_M10_realloc
# 1   20240703        2         0  2024_07_y24m07day03_hm00:53                  4               x4     0.5      latlon  sigma_only_x1_anchor  ColumnSpaceIso_Up2_Right3_M10_realloc
# 2   20240703        2         0  2024_07_y24m07day03_hm00:53                  2               x2     0.5      latlon  sigma_only_x1_anchor  ColumnSpaceIso_Up2_Right3_M10_realloc
# 3   20240703        2         0  2024_07_y24m07day03_hm00:53                  1               x1     0.5      latlon  sigma_only_x1_anchor  ColumnSpaceIso_Up2_Right3_M10_realloc
# 4   20240703        2         0  2024_07_y24m07day03_hm00:53                  8               x8     0.5      latlon  range_only_x1_anchor  ColumnSpaceIso_Up2_Right3_M10_realloc
# ..       ...      ...       ...                          ...                ...              ...     ...         ...                   ...                                    ...
# 59  20240703        2         7  2024_07_y24m07day03_hm07:48                  1               x1     0.5      latlon  sigma_only_x1_anchor  ColumnSpaceIso_Up2_Right3_M10_realloc
# 60  20240703        2         7  2024_07_y24m07day03_hm07:48                  8               x8     0.5      latlon  range_only_x1_anchor  ColumnSpaceIso_Up2_Right3_M10_realloc
# 61  20240703        2         7  2024_07_y24m07day03_hm07:48                  4               x4     0.5      latlon  range_only_x1_anchor  ColumnSpaceIso_Up2_Right3_M10_realloc
# 62  20240703        2         7  2024_07_y24m07day03_hm07:48                  2               x2     0.5      latlon  range_only_x1_anchor  ColumnSpaceIso_Up2_Right3_M10_realloc
# 63  20240703        2         7  2024_07_y24m07day03_hm07:48                  1               x1     0.5      latlon  range_only_x1_anchor  ColumnSpaceIso_Up2_Right3_M10_realloc
#
#                             kernel                                         coord_mode    loss  fit_iter_raw  fit_steps_reported  precompute_s   fit_s  total_s  n_grid  n_valid  \
# 0   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.6080             0                   1        0.0350  0.0467   0.0817    2266     2259
# 1   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.4965             0                   1        0.0858  0.1061   0.1919    4532     4518
# 2   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.5399             0                   1        0.2230  0.2058   0.4288    9063     9033
# 3   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.4096             0                   1        0.7697  0.0929   0.8627   18126    18067
# 4   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.6080             0                   1        0.0357  0.0577   0.0934    2266     2259
# ..                             ...                                                ...     ...           ...                 ...           ...     ...      ...     ...      ...
# 59  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.3999             0                   1        0.7689  0.0880   0.8569   18126    18102
# 60  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.7365             0                   1        0.0345  0.0479   0.0823    2266     2263
# 61  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.6096             7                   8        0.0837  0.2381   0.3218    4532     4526
# 62  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.4788             0                   1        0.2260  0.1766   0.4025    9063     9051
# 63  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.3999             0                   1        0.7788  0.0878   0.8666   18126    18102
#
#     valid_fraction  est_sigmasq  est_range  est_nugget  n_batches  n_tails  mean_m  max_m  largest_batch_n  total_conditioning_nominal  head_right_cols  above_count  \
# 0           0.9969       8.9741     0.2472      3.0520          1     2259    10.0     10             2259                          10                0            2
# 1           0.9969       7.7706     0.2472      3.0520          1     4518    10.0     10             4518                          10                0            2
# 2           0.9967      12.1947     0.2472      3.0520          1     9033    10.0     10             9033                          10                0            2
# 3           0.9967      10.2213     0.2472      3.0520          1    18067    10.0     10            18067                          10                0            2
# 4           0.9969      10.2213     0.3563      3.0520          1     2259    10.0     10             2259                          10                0            2
# ..             ...          ...        ...         ...        ...      ...     ...    ...              ...                         ...              ...          ...
# 59          0.9987      11.8885     0.1498      1.3984          1    18102    10.0     10            18102                          10                0            2
# 60          0.9987      11.8885     0.1560      1.3984          1     2263    10.0     10             2263                          10                0            2
# 61          0.9987      11.8885     0.1755      1.3984          1     4526    10.0     10             4526                          10                0            2
# 62          0.9987      11.8885     0.1664      1.3984          1     9051    10.0     10             9051                          10                0            2
# 63          0.9987      11.8885     0.1498      1.3984          1    18102    10.0     10            18102                          10                0            2
#
#     right_col_count  per_time_conditioning_count free_parameter fixed_parameters anchor_resolution_label  anchor_sigmasq  anchor_range  anchor_nugget
# 0                 3                           10        sigmasq     range,nugget                      x1         10.2213        0.2472         3.0520
# 1                 3                           10        sigmasq     range,nugget                      x1         10.2213        0.2472         3.0520
# 2                 3                           10        sigmasq     range,nugget                      x1         10.2213        0.2472         3.0520
# 3                 3                           10        sigmasq     range,nugget                      x1         10.2213        0.2472         3.0520
# 4                 3                           10          range   sigmasq,nugget                      x1         10.2213        0.2472         3.0520
# ..              ...                          ...            ...              ...                     ...             ...           ...            ...
# 59                3                           10        sigmasq     range,nugget                      x1         11.8885        0.1498         1.3984
# 60                3                           10          range   sigmasq,nugget                      x1         11.8885        0.1498         1.3984
# 61                3                           10          range   sigmasq,nugget                      x1         11.8885        0.1498         1.3984
# 62                3                           10          range   sigmasq,nugget                      x1         11.8885        0.1498         1.3984
# 63                3                           10          range   sigmasq,nugget                      x1         11.8885        0.1498         1.3984
#
# [64 rows x 40 columns]

# %%
all_df = pd.concat([full_df, partial_df], ignore_index=True, sort=False)
all_path = OUT_DIR / f'{OUT_PREFIX}_all.csv'
round_df(all_df).to_csv(all_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
print('Saved all:', all_path)

param_rows = []
for _, row in all_df.iterrows():
    for p in P_LABELS:
        param_rows.append({
            'date_str': row['date_str'],
            'hour_idx': int(row['hour_idx']),
            'time_key': row['time_key'],
            'resolution_stride': int(row['resolution_stride']),
            'resolution_label': row['resolution_label'],
            'fit_type': row['fit_type'],
            'parameter': p,
            'estimate': row[f'est_{p}'],
            'loss': row['loss'],
            'n_grid': row['n_grid'],
            'n_valid': row['n_valid'],
        })
param_df = pd.DataFrame(param_rows)
param_path = OUT_DIR / f'{OUT_PREFIX}_param_table.csv'
round_df(param_df).to_csv(param_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
print('Saved param table:', param_path)

display_cols = ['hour_idx', 'resolution_stride', 'resolution_label', 'fit_type', 'loss', 'est_sigmasq', 'est_range', 'est_nugget', 'n_grid', 'n_valid', 'total_s']
display(round_df(all_df[display_cols].sort_values(['fit_type', 'hour_idx', 'resolution_stride'])))
# Out:
# Saved all: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_iso_column_resolution_050826_all.csv
# Saved param table: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_iso_column_resolution_050826_param_table.csv
#     hour_idx  resolution_stride resolution_label              fit_type    loss  est_sigmasq  est_range  est_nugget  n_grid  n_valid  total_s
# 3          0                  1               x1                  full  1.4111      10.2213     0.2472      3.0520   18126    18067   1.9780
# 2          0                  2               x2                  full  1.5430      10.0542     0.2933      4.2270    9063     9033   0.8881
# 1          0                  4               x4                  full  1.5040       9.0600     0.3875      3.4295    4532     4518   0.4282
# 0          0                  8               x8                  full  1.6153       8.6677     0.4971      4.4164    2266     2259   0.2031
# 7          1                  1               x1                  full  1.3587      11.9110     0.2253      1.9943   18126    17670   1.6925
# ..       ...                ...              ...                   ...     ...          ...        ...         ...     ...      ...      ...
# 80         6                  8               x8  sigma_only_x1_anchor  1.7021      13.0307     0.1523      0.9321    2266     2264   0.0683
# 91         7                  1               x1  sigma_only_x1_anchor  1.3999      11.8885     0.1498      1.3984   18126    18102   0.8569
# 90         7                  2               x2  sigma_only_x1_anchor  1.4788      11.0977     0.1498      1.3984    9063     9051   0.3982
# 89         7                  4               x4  sigma_only_x1_anchor  1.6125      11.1735     0.1498      1.3984    4532     4526   0.1717
# 88         7                  8               x8  sigma_only_x1_anchor  1.7365      13.1347     0.1498      1.3984    2266     2263   0.0836
#
# [96 rows x 11 columns]

# %%
# Full-fit parameter trajectories: one line per hour.
plot_full = full_df.copy()
plot_full['resolution_label'] = pd.Categorical(
    plot_full['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
)
plot_full = plot_full.sort_values(['hour_idx', 'resolution_label'])

fig, axes = plt.subplots(1, 3, figsize=(15, 4), constrained_layout=True)
for ax, p in zip(axes, P_LABELS):
    for hour_idx, sub in plot_full.groupby('hour_idx'):
        ax.plot(sub['resolution_label'].astype(str), sub[f'est_{p}'], marker='o', linewidth=1.6, label=f'h{int(hour_idx)+1}')
    ax.set_title(f'full fit: {p}')
    ax.set_xlabel('resolution thinning')
    ax.set_ylabel('estimate')
    ax.grid(True, alpha=0.3)
axes[-1].legend(ncol=2, fontsize=8, title='hour')
fig.suptitle('Pure-space isotropic Column Vecchia: full-fit parameter trajectories', fontsize=14)
full_plot_path = OUT_DIR / f'{OUT_PREFIX}_full_parameter_trajectories.png'
fig.savefig(full_plot_path, dpi=180, bbox_inches='tight')
print('Saved:', full_plot_path)
plt.show()
# Out:
# Saved: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_iso_column_resolution_050826_full_parameter_trajectories.png

# %%
# Partial-fit trajectories: sigma-only and range-only using x1 full-fit anchor.
if not partial_df.empty:
    plot_partial = partial_df.copy()
    plot_partial['resolution_label'] = pd.Categorical(
        plot_partial['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
    )
    plot_partial = plot_partial.sort_values(['fit_type', 'hour_idx', 'resolution_label'])

    fig, axes = plt.subplots(1, 2, figsize=(12, 4), constrained_layout=True)
    specs = [
        ('sigma_only_x1_anchor', 'sigmasq', 'sigma-only: estimated sigmasq'),
        ('range_only_x1_anchor', 'range', 'range-only: estimated range'),
    ]


    for ax, (fit_type, p, title) in zip(axes, specs):
        sub0 = plot_partial[plot_partial['fit_type'] == fit_type]
        for hour_idx, sub in sub0.groupby('hour_idx'):
            ax.plot(sub['resolution_label'].astype(str), sub[f'est_{p}'], marker='o', linewidth=1.6, label=f'h{int(hour_idx)+1}')
        ax.set_title(title)
        ax.set_xlabel('resolution thinning')
        ax.set_ylabel('estimate')
        ax.grid(True, alpha=0.3)
    axes[-1].legend(ncol=2, fontsize=8, title='hour')
    fig.suptitle('Partial profile checks with same-hour x1 full-fit anchors', fontsize=14)
    partial_plot_path = OUT_DIR / f'{OUT_PREFIX}_partial_parameter_trajectories.png'
    fig.savefig(partial_plot_path, dpi=180, bbox_inches='tight')
    print('Saved:', partial_plot_path)
    plt.show()
# Out:
# Saved: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_iso_column_resolution_050826_partial_parameter_trajectories.png

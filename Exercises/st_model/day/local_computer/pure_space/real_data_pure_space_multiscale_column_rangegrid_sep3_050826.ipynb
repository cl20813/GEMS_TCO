# %% [markdown]
# # Pure-space two-scale Column Vecchia diagnostic, separated range grid
#
# This notebook tests a multiscale spatial covariance without making all two-Matern parameters free.
#
# For each hour and resolution, it grid-searches fixed `(range_short, range_long)` pairs with an explicit separation constraint and estimates only two variance weights:
#
# ```text
# Cov(h) = sigmasq_short * Matern(h; range_short, smooth_short)
#        + sigmasq_long  * Matern(h; range_long,  smooth_long)
#        + nugget_fixed
# ```
#
# Default diagnostic:
#
# - Column reverse-L pure-space geometry: `Up2_Right3_M10`, real source coordinates for covariance
# - each time slot fitted independently
# - `x8, x4, x2, x1` regular-grid thinning
# - `nugget_fixed = 0`
# - `smooth_short = smooth_long = 0.5`
# - `range_long >= 3 * range_short`
# - estimate only `sigmasq_short`, `sigmasq_long`
#
# Interpretation target:
#
# - If fine resolution prefers larger `sigmasq_short` or smaller selected `range_short`, that supports multiscale/fine-scale structure.
# - If best range pair and variance split are stable across resolution, single-scale misspecification is less likely.
#
# This `sep3` version is meant to avoid ambiguous pairs such as `(0.12, 0.18)`, where the two components are too close to interpret as separate scales.

# %%
import gc
import sys
import time
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch

LOCAL_SRC = '/Users/joonwonlee/Documents/GEMS_TCO-1/src'
AMAREL_SRC = '/home/jl2815/tco'
SRC = AMAREL_SRC if Path(AMAREL_SRC).exists() else LOCAL_SRC
if SRC not in sys.path:
    sys.path.insert(0, SRC)

from GEMS_TCO import configuration as config
from GEMS_TCO.data_loader import load_data_dynamic_processed
from GEMS_TCO.kernels_space_multiscale_050826 import ColumnSpaceTwoScaleFixedRangeTrendVecchiaFit

DEVICE = torch.device('cpu')
DTYPE = torch.float64
ROUND_DECIMALS = 4

pd.set_option('display.max_columns', 160)
pd.set_option('display.width', 220)
print('SRC:', SRC)
print('device:', DEVICE)
# Out:
# SRC: /Users/joonwonlee/Documents/GEMS_TCO-1/src
# device: cpu

# %%
# Experiment config
YEAR = '2024'
MONTH = 7
DAY_IDX = 2                 # 0-based: 2 -> 2024-07-03
HOUR_IDX_LIST = list(range(8))
LAT_RANGE = [-3, 2]
LON_RANGE = [121, 131]

RESOLUTION_STRIDES = [8, 4, 2, 1]
MEAN_DESIGN = 'latlon'

# Finer short-range grid plus explicit scale separation.
# This avoids treating close pairs such as 0.12 vs 0.18 as two distinct scales.
RANGE_SHORT_GRID = [0.015, 0.025, 0.035, 0.050, 0.070]
RANGE_LONG_GRID = [0.150, 0.250, 0.400, 0.700]
MIN_RANGE_RATIO = 3.0
NUGGET_FIXED = 0.0
SMOOTH_SHORT = 0.5
SMOOTH_LONG = 0.5
MODEL_SMOOTH_FOR_CLASS = 0.5

COLUMN_SPEC = {
    'model': 'ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_realloc',
    'head_right_cols': 0,
    'above_count': 2,
    'right_col_count': 3,
    'per_time_conditioning_count': 10,
    'target_chunk_size': 512,
}

LBFGS_LR = 1.0
LBFGS_STEPS = 6
LBFGS_EVAL = 18
LBFGS_HIST = 10
GRAD_TOL = 1e-5

INIT_SIGMASQ_SHORT = 3.0
INIT_SIGMASQ_LONG = 10.0

PURE_SPACE_DIR = Path('/Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space')
OUT_DIR = PURE_SPACE_DIR / 'log'
OUT_DIR.mkdir(parents=True, exist_ok=True)
OUT_PREFIX = 'real_pure_space_multiscale_column_rangegrid_sep3_050826'

range_pairs = [(rs, rl) for rs in RANGE_SHORT_GRID for rl in RANGE_LONG_GRID if rl >= MIN_RANGE_RATIO * rs]
print('day:', f'{YEAR}{MONTH:02d}{DAY_IDX + 1:02d}')
print('hours:', HOUR_IDX_LIST)
print('strides:', RESOLUTION_STRIDES)
print('range pairs:', range_pairs)
print('n range pairs:', len(range_pairs), '| min long/short ratio:', MIN_RANGE_RATIO)
print('nugget_fixed:', NUGGET_FIXED, 'smooth_short/long:', SMOOTH_SHORT, SMOOTH_LONG)
# Out:
# day: 20240703
# hours: [0, 1, 2, 3, 4, 5, 6, 7]
# strides: [8, 4, 2, 1]
# range pairs: [(0.015, 0.15), (0.015, 0.25), (0.015, 0.4), (0.015, 0.7), (0.025, 0.15), (0.025, 0.25), (0.025, 0.4), (0.025, 0.7), (0.035, 0.15), (0.035, 0.25), (0.035, 0.4), (0.035, 0.7), (0.05, 0.25), (0.05, 0.4), (0.05, 0.7), (0.07, 0.25), (0.07, 0.4), (0.07, 0.7)]
# n range pairs: 18 | min long/short ratio: 3.0
# nugget_fixed: 0.0 smooth_short/long: 0.5 0.5

# %%
def make_sigma_params(sig_short=INIT_SIGMASQ_SHORT, sig_long=INIT_SIGMASQ_LONG):
    return [
        torch.tensor([np.log(sig_short)], device=DEVICE, dtype=DTYPE, requires_grad=True),
        torch.tensor([np.log(sig_long)], device=DEVICE, dtype=DTYPE, requires_grad=True),
    ]


def backmap_two(raw, range_short, range_long):
    sig_short = float(np.exp(raw[0]))
    sig_long = float(np.exp(raw[1]))
    total = sig_short + sig_long
    return {
        'sigmasq_short': sig_short,
        'sigmasq_long': sig_long,
        'sigmasq_total': total,
        'short_fraction': sig_short / total if total > 0 else np.nan,
        'range_short': float(range_short),
        'range_long': float(range_long),
        'nugget': float(NUGGET_FIXED),
    }


def count_valid(input_map):
    return int(sum(((~torch.isnan(v[:, 2])) & (~torch.isnan(v[:, 0])) & (~torch.isnan(v[:, 1]))).sum().item() for v in input_map.values()))


def space_diag(model):
    groups = getattr(model, 'Batched_Groups', []) or []
    if not groups:
        return {'n_batches': 0, 'n_tails': 0, 'mean_m': 0.0, 'max_m': 0, 'largest_batch_n': 0}
    ns = np.asarray([int(g['target_idx'].shape[0]) for g in groups], dtype=np.int64)
    ms = np.asarray([int(g['max_m']) for g in groups], dtype=np.int64)
    return {
        'n_batches': int(len(groups)),
        'n_tails': int(ns.sum()),
        'mean_m': float(ms.mean()),
        'max_m': int(ms.max()),
        'largest_batch_n': int(ns.max()),
    }


def round_df(df, digits=ROUND_DECIMALS):
    out = df.copy()
    num_cols = out.select_dtypes(include=[np.number]).columns
    out[num_cols] = out[num_cols].round(digits)
    return out


def empty_cache():
    gc.collect()
    if DEVICE.type == 'cuda':
        torch.cuda.empty_cache()


def resolution_label(stride):
    return f'x{int(stride)}'

# %%
loader = load_data_dynamic_processed(config.mac_data_load_path)
df_map, _, _, monthly_mean = loader.load_maxmin_ordered_data_bymonthyear(
    lat_lon_resolution=[1, 1],
    mm_cond_number=10,
    years_=[YEAR],
    months_=[MONTH],
    lat_range=LAT_RANGE,
    lon_range=LON_RANGE,
    is_whittle=True,
)
month_keys = sorted(df_map.keys())
day_keys = month_keys[DAY_IDX * 8:(DAY_IDX + 1) * 8]
if len(day_keys) != 8:
    raise ValueError(f'Day {DAY_IDX} has {len(day_keys)} slices, expected 8')

first_df = df_map[day_keys[0]].reset_index(drop=True)
grid_order = (
    first_df
    .assign(_orig_idx=np.arange(len(first_df)))
    .sort_values(['Longitude', 'Latitude', '_orig_idx'], kind='mergesort')['_orig_idx']
    .to_numpy(dtype=np.int64)
)
grid_coords_full = first_df.iloc[grid_order][['Latitude', 'Longitude']].to_numpy(dtype=np.float64)

print('monthly_mean:', round(monthly_mean, 4))
print('day keys:', day_keys[0], '...', day_keys[-1])
print('full grid:', grid_coords_full.shape)
print('unique lat/lon:', len(np.unique(np.round(grid_coords_full[:,0], 6))), len(np.unique(np.round(grid_coords_full[:,1], 6))))
# Out:
# --- Global Monthly Mean for 2024-7: 257.9726 ---
# monthly_mean: 257.9726
# day keys: 2024_07_y24m07day03_hm00:53 ... 2024_07_y24m07day03_hm07:48
# full grid: (18126, 2)
# unique lat/lon: 114 159

# %%
def load_hour_map(hour_idx):
    key = day_keys[int(hour_idx)]
    hour_df_map = {key: df_map[key]}
    hour_map, _ = loader.load_working_data(
        hour_df_map,
        monthly_mean=monthly_mean,
        idx_for_datamap=[0, 1],
        ord_mm=grid_order,
        dtype=DTYPE,
        keep_ori=True,
    )
    return {k: v.to(DEVICE) for k, v in hour_map.items()}, key


def thin_hour_map(hour_map, stride):
    n_full = grid_coords_full.shape[0]
    thin_idx = np.arange(0, n_full, int(stride), dtype=np.int64)
    thin_map = {k: v[thin_idx].contiguous() for k, v in hour_map.items()}
    thin_grid = np.ascontiguousarray(grid_coords_full[thin_idx])
    return thin_map, thin_grid, thin_idx


def build_model(input_map, grid_coords, range_short, range_long):
    return ColumnSpaceTwoScaleFixedRangeTrendVecchiaFit(
        smooth=MODEL_SMOOTH_FOR_CLASS,
        input_map=input_map,
        grid_coords=grid_coords,
        head_right_cols=COLUMN_SPEC['head_right_cols'],
        above_count=COLUMN_SPEC['above_count'],
        right_col_count=COLUMN_SPEC['right_col_count'],
        per_time_conditioning_count=COLUMN_SPEC['per_time_conditioning_count'],
        target_chunk_size=COLUMN_SPEC['target_chunk_size'],
        range_short=range_short,
        range_long=range_long,
        nugget_fixed=NUGGET_FIXED,
        smooth_short=SMOOTH_SHORT,
        smooth_long=SMOOTH_LONG,
        mean_design=MEAN_DESIGN,
    )


def make_row(hour_idx, time_key, stride, range_short, range_long, n_grid, n_valid, pre_s, fit_s, loss, fit_iter, est, diag):
    return {
        'date_str': f'{YEAR}{MONTH:02d}{DAY_IDX + 1:02d}',
        'day_idx': DAY_IDX,
        'hour_idx': int(hour_idx),
        'time_key': str(time_key),
        'resolution_stride': int(stride),
        'resolution_label': resolution_label(stride),
        'mean_design': MEAN_DESIGN,
        'model': COLUMN_SPEC['model'],
        'kernel': 'column_space_twoscale_fixedrange_tonly_realloc',
        'coord_mode': 'regular-grid every-k thinning; covariance on Source_Latitude/Source_Longitude',
        'smooth_short': float(SMOOTH_SHORT),
        'smooth_long': float(SMOOTH_LONG),
        'range_short_fixed': float(range_short),
        'range_long_fixed': float(range_long),
        'nugget_fixed': float(NUGGET_FIXED),
        'loss': float(loss),
        'fit_iter_raw': int(fit_iter),
        'fit_steps_reported': int(fit_iter) + 1,
        'precompute_s': float(pre_s),
        'fit_s': float(fit_s),
        'total_s': float(pre_s + fit_s),
        'n_grid': int(n_grid),
        'n_valid': int(n_valid),
        'valid_fraction': float(n_valid / n_grid) if n_grid else np.nan,
        **{f'est_{k}': v for k, v in est.items()},
        **diag,
        'total_conditioning_nominal': COLUMN_SPEC['per_time_conditioning_count'],
        'head_right_cols': COLUMN_SPEC['head_right_cols'],
        'above_count': COLUMN_SPEC['above_count'],
        'right_col_count': COLUMN_SPEC['right_col_count'],
        'per_time_conditioning_count': COLUMN_SPEC['per_time_conditioning_count'],
    }

# %%
def fit_range_pair(hour_idx, stride, range_short, range_long):
    hour_map, time_key = load_hour_map(hour_idx)
    thin_map, thin_grid, _ = thin_hour_map(hour_map, stride)
    n_grid = int(thin_grid.shape[0])
    n_valid = count_valid(thin_map)
    print('\n' + '=' * 100)
    print(
        f'TWO-SCALE | h{hour_idx + 1} | {time_key} | {resolution_label(stride)} | '
        f'rs={range_short:.3f}, rl={range_long:.3f} | n_valid={n_valid:,}'
    )

    model = build_model(thin_map, thin_grid, range_short, range_long)
    t_pre = time.time()
    model.precompute_conditioning_sets()
    pre_s = time.time() - t_pre
    diag = space_diag(model)

    params = make_sigma_params()
    opt = model.set_optimizer(params, lr=LBFGS_LR, max_iter=LBFGS_EVAL, max_eval=LBFGS_EVAL, history_size=LBFGS_HIST)
    t_fit = time.time()
    out, fit_iter = model.fit_vecc_lbfgs(params, opt, max_steps=LBFGS_STEPS, grad_tol=GRAD_TOL)
    fit_s = time.time() - t_fit
    est = backmap_two(out[:2], range_short, range_long)
    row = make_row(hour_idx, time_key, stride, range_short, range_long, n_grid, n_valid, pre_s, fit_s, out[-1], fit_iter, est, diag)
    print('RESULT:', {k: round(v, 4) if isinstance(v, float) else v for k, v in row.items() if k in ['resolution_label','loss','est_sigmasq_short','est_sigmasq_long','est_short_fraction','est_sigmasq_total']})

    del model, params, opt, hour_map, thin_map
    empty_cache()
    return row

# %%
rows = []
for hour_idx in HOUR_IDX_LIST:
    for stride in RESOLUTION_STRIDES:
        for range_short, range_long in range_pairs:
            rows.append(fit_range_pair(hour_idx, stride, range_short, range_long))
            tmp = round_df(pd.DataFrame(rows))
            tmp.to_csv(OUT_DIR / f'{OUT_PREFIX}_all.csv', index=False, float_format=f'%.{ROUND_DECIMALS}f')

all_df = pd.DataFrame(rows)
all_path = OUT_DIR / f'{OUT_PREFIX}_all.csv'
round_df(all_df).to_csv(all_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
print('Saved all grid results:', all_path)
display(round_df(all_df))
# Out:
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.015, rl=0.150 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.634122 / Max Grad: 3.53e-08 ---
# Converged: max_grad 3.53e-08 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 0.6745535660655849, 'sigmasq_long': 11.219648610322631, 'sigmasq_total': 11.894202176388216, 'range_short': 0.015, 'range_long': 0.15, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6341, 'est_sigmasq_short': 0.6746, 'est_sigmasq_long': 11.2196, 'est_sigmasq_total': 11.8942, 'est_short_fraction': 0.0567}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.015, rl=0.250 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.606963 / Max Grad: 9.66e-06 ---
# Converged: max_grad 9.66e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.9398116459471595, 'sigmasq_long': 9.158472182636132, 'sigmasq_total': 12.098283828583291, 'range_short': 0.015, 'range_long': 0.25, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.607, 'est_sigmasq_short': 2.9398, 'est_sigmasq_long': 9.1585, 'est_sigmasq_total': 12.0983, 'est_short_fraction': 0.243}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.015, rl=0.400 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.603430 / Max Grad: 5.11e-07 ---
# Converged: max_grad 5.11e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.064054592423824, 'sigmasq_long': 8.591324249032372, 'sigmasq_total': 12.655378841456196, 'range_short': 0.015, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6034, 'est_sigmasq_short': 4.0641, 'est_sigmasq_long': 8.5913, 'est_sigmasq_total': 12.6554, 'est_short_fraction': 0.3211}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.015, rl=0.700 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.623576 / Max Grad: 1.21e-06 ---
# Converged: max_grad 1.21e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.904906920307623, 'sigmasq_long': 9.05753980773447, 'sigmasq_total': 13.962446728042092, 'range_short': 0.015, 'range_long': 0.7, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6236, 'est_sigmasq_short': 4.9049, 'est_sigmasq_long': 9.0575, 'est_sigmasq_total': 13.9624, 'est_short_fraction': 0.3513}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.025, rl=0.150 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.633839 / Max Grad: 4.28e-07 ---
# Converged: max_grad 4.28e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 0.6647038575433438, 'sigmasq_long': 11.245878778213832, 'sigmasq_total': 11.910582635757176, 'range_short': 0.025, 'range_long': 0.15, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6338, 'est_sigmasq_short': 0.6647, 'est_sigmasq_long': 11.2459, 'est_sigmasq_total': 11.9106, 'est_short_fraction': 0.0558}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.025, rl=0.250 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.607089 / Max Grad: 5.24e-08 ---
# Converged: max_grad 5.24e-08 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.9882196521021798, 'sigmasq_long': 9.11616852551855, 'sigmasq_total': 12.104388177620729, 'range_short': 0.025, 'range_long': 0.25, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6071, 'est_sigmasq_short': 2.9882, 'est_sigmasq_long': 9.1162, 'est_sigmasq_total': 12.1044, 'est_short_fraction': 0.2469}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.025, rl=0.400 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.603971 / Max Grad: 6.75e-07 ---
# Converged: max_grad 6.75e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.129477260349133, 'sigmasq_long': 8.50459320939962, 'sigmasq_total': 12.634070469748753, 'range_short': 0.025, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.604, 'est_sigmasq_short': 4.1295, 'est_sigmasq_long': 8.5046, 'est_sigmasq_total': 12.6341, 'est_short_fraction': 0.3269}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.025, rl=0.700 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.624501 / Max Grad: 6.52e-07 ---
# Converged: max_grad 6.52e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.977790933025305, 'sigmasq_long': 8.900181671575055, 'sigmasq_total': 13.877972604600359, 'range_short': 0.025, 'range_long': 0.7, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6245, 'est_sigmasq_short': 4.9778, 'est_sigmasq_long': 8.9002, 'est_sigmasq_total': 13.878, 'est_short_fraction': 0.3587}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.035, rl=0.150 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.633066 / Max Grad: 5.60e-06 ---
# Converged: max_grad 5.60e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 0.6365260079705589, 'sigmasq_long': 11.317071103770006, 'sigmasq_total': 11.953597111740565, 'range_short': 0.035, 'range_long': 0.15, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6331, 'est_sigmasq_short': 0.6365, 'est_sigmasq_long': 11.3171, 'est_sigmasq_total': 11.9536, 'est_short_fraction': 0.0532}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.035, rl=0.250 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.607513 / Max Grad: 2.37e-07 ---
# Converged: max_grad 2.37e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.129446411601267, 'sigmasq_long': 8.991950211107653, 'sigmasq_total': 12.12139662270892, 'range_short': 0.035, 'range_long': 0.25, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6075, 'est_sigmasq_short': 3.1294, 'est_sigmasq_long': 8.992, 'est_sigmasq_total': 12.1214, 'est_short_fraction': 0.2582}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.035, rl=0.400 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.605688 / Max Grad: 1.18e-06 ---
# Converged: max_grad 1.18e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.316486009916361, 'sigmasq_long': 8.264667399765859, 'sigmasq_total': 12.58115340968222, 'range_short': 0.035, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6057, 'est_sigmasq_short': 4.3165, 'est_sigmasq_long': 8.2647, 'est_sigmasq_total': 12.5812, 'est_short_fraction': 0.3431}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.035, rl=0.700 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.627560 / Max Grad: 1.39e-06 ---
# Converged: max_grad 1.39e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 5.1829581623754635, 'sigmasq_long': 8.485428617579377, 'sigmasq_total': 13.66838677995484, 'range_short': 0.035, 'range_long': 0.7, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6276, 'est_sigmasq_short': 5.183, 'est_sigmasq_long': 8.4854, 'est_sigmasq_total': 13.6684, 'est_short_fraction': 0.3792}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.050, rl=0.250 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.608929 / Max Grad: 1.61e-06 ---
# Converged: max_grad 1.61e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.4731500357492098, 'sigmasq_long': 8.71011299877888, 'sigmasq_total': 12.18326303452809, 'range_short': 0.05, 'range_long': 0.25, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6089, 'est_sigmasq_short': 3.4732, 'est_sigmasq_long': 8.7101, 'est_sigmasq_total': 12.1833, 'est_short_fraction': 0.2851}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.050, rl=0.400 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.610608 / Max Grad: 1.02e-06 ---
# Converged: max_grad 1.02e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.766216461788022, 'sigmasq_long': 7.74761248960758, 'sigmasq_total': 12.513828951395602, 'range_short': 0.05, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6106, 'est_sigmasq_short': 4.7662, 'est_sigmasq_long': 7.7476, 'est_sigmasq_total': 12.5138, 'est_short_fraction': 0.3809}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.050, rl=0.700 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.636631 / Max Grad: 1.13e-07 ---
# Converged: max_grad 1.13e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 5.667740467958165, 'sigmasq_long': 7.639194948383574, 'sigmasq_total': 13.306935416341739, 'range_short': 0.05, 'range_long': 0.7, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6366, 'est_sigmasq_short': 5.6677, 'est_sigmasq_long': 7.6392, 'est_sigmasq_total': 13.3069, 'est_short_fraction': 0.4259}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.070, rl=0.250 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.612137 / Max Grad: 2.70e-06 ---
# Converged: max_grad 2.70e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.088293188488659, 'sigmasq_long': 8.246768802787704, 'sigmasq_total': 12.335061991276362, 'range_short': 0.07, 'range_long': 0.25, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6121, 'est_sigmasq_short': 4.0883, 'est_sigmasq_long': 8.2468, 'est_sigmasq_total': 12.3351, 'est_short_fraction': 0.3314}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.070, rl=0.400 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.620614 / Max Grad: 4.07e-06 ---
# Converged: max_grad 4.07e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 5.546065367243614, 'sigmasq_long': 6.9904639930008425, 'sigmasq_total': 12.536529360244456, 'range_short': 0.07, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6206, 'est_sigmasq_short': 5.5461, 'est_sigmasq_long': 6.9905, 'est_sigmasq_total': 12.5365, 'est_short_fraction': 0.4424}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.070, rl=0.700 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.655847 / Max Grad: 1.14e-06 ---
# Converged: max_grad 1.14e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 6.486089375991542, 'sigmasq_long': 6.519679918366267, 'sigmasq_total': 13.005769294357808, 'range_short': 0.07, 'range_long': 0.7, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6558, 'est_sigmasq_short': 6.4861, 'est_sigmasq_long': 6.5197, 'est_sigmasq_total': 13.0058, 'est_short_fraction': 0.4987}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.015, rl=0.150 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.529734 / Max Grad: 1.01e-05 ---
# --- Step 2/6 / Loss: 1.500370 / Max Grad: 1.01e-05 ---
# --- Step 3/6 / Loss: 1.500370 / Max Grad: 1.01e-05 ---
# --- Step 4/6 / Loss: 1.500370 / Max Grad: 1.01e-05 ---
# --- Step 5/6 / Loss: 1.500370 / Max Grad: 1.01e-05 ---
# --- Step 6/6 / Loss: 1.500370 / Max Grad: 1.01e-05 ---
# Final Pure-Space Params: {'sigmasq_short': 0.5864530681468775, 'sigmasq_long': 9.877151764725909, 'sigmasq_total': 10.463604832872786, 'range_short': 0.015, 'range_long': 0.15, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5004, 'est_sigmasq_short': 0.5865, 'est_sigmasq_long': 9.8772, 'est_sigmasq_total': 10.4636, 'est_short_fraction': 0.056}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.015, rl=0.250 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.494549 / Max Grad: 8.95e-07 ---
# Converged: max_grad 8.95e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.5734488396998776, 'sigmasq_long': 8.638760008336375, 'sigmasq_total': 11.212208848036251, 'range_short': 0.015, 'range_long': 0.25, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.4945, 'est_sigmasq_short': 2.5734, 'est_sigmasq_long': 8.6388, 'est_sigmasq_total': 11.2122, 'est_short_fraction': 0.2295}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.015, rl=0.400 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.488188 / Max Grad: 9.05e-07 ---
# Converged: max_grad 9.05e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.4908296924286737, 'sigmasq_long': 9.0986582582086, 'sigmasq_total': 12.589487950637274, 'range_short': 0.015, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.4882, 'est_sigmasq_short': 3.4908, 'est_sigmasq_long': 9.0987, 'est_sigmasq_total': 12.5895, 'est_short_fraction': 0.2773}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.015, rl=0.700 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.505862 / Max Grad: 9.25e-06 ---
# Converged: max_grad 9.25e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.042234450841483, 'sigmasq_long': 11.66007333063361, 'sigmasq_total': 15.702307781475092, 'range_short': 0.015, 'range_long': 0.7, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5059, 'est_sigmasq_short': 4.0422, 'est_sigmasq_long': 11.6601, 'est_sigmasq_total': 15.7023, 'est_short_fraction': 0.2574}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.025, rl=0.150 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.529437 / Max Grad: 5.65e-07 ---
# Converged: max_grad 5.65e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 0.5632808107705626, 'sigmasq_long': 9.927997274839074, 'sigmasq_total': 10.491278085609636, 'range_short': 0.025, 'range_long': 0.15, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5294, 'est_sigmasq_short': 0.5633, 'est_sigmasq_long': 9.928, 'est_sigmasq_total': 10.4913, 'est_short_fraction': 0.0537}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.025, rl=0.250 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.494510 / Max Grad: 9.64e-06 ---
# Converged: max_grad 9.64e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.6100771938258047, 'sigmasq_long': 8.59963486467605, 'sigmasq_total': 11.209712058501854, 'range_short': 0.025, 'range_long': 0.25, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.4945, 'est_sigmasq_short': 2.6101, 'est_sigmasq_long': 8.5996, 'est_sigmasq_total': 11.2097, 'est_short_fraction': 0.2328}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.025, rl=0.400 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.488410 / Max Grad: 1.56e-06 ---
# Converged: max_grad 1.56e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.5481981967660534, 'sigmasq_long': 8.975459055433513, 'sigmasq_total': 12.523657252199566, 'range_short': 0.025, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.4884, 'est_sigmasq_short': 3.5482, 'est_sigmasq_long': 8.9755, 'est_sigmasq_total': 12.5237, 'est_short_fraction': 0.2833}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.025, rl=0.700 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.506257 / Max Grad: 3.51e-06 ---
# Converged: max_grad 3.51e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.113669403339357, 'sigmasq_long': 11.372336597624201, 'sigmasq_total': 15.48600600096356, 'range_short': 0.025, 'range_long': 0.7, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5063, 'est_sigmasq_short': 4.1137, 'est_sigmasq_long': 11.3723, 'est_sigmasq_total': 15.486, 'est_short_fraction': 0.2656}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.035, rl=0.150 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.528340 / Max Grad: 1.01e-06 ---
# Converged: max_grad 1.01e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 0.5129523364737094, 'sigmasq_long': 10.042818391734285, 'sigmasq_total': 10.555770728207994, 'range_short': 0.035, 'range_long': 0.15, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5283, 'est_sigmasq_short': 0.513, 'est_sigmasq_long': 10.0428, 'est_sigmasq_total': 10.5558, 'est_short_fraction': 0.0486}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.035, rl=0.250 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.494316 / Max Grad: 8.99e-06 ---
# Converged: max_grad 8.99e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.728920791722857, 'sigmasq_long': 8.468930117777147, 'sigmasq_total': 11.197850909500003, 'range_short': 0.035, 'range_long': 0.25, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.4943, 'est_sigmasq_short': 2.7289, 'est_sigmasq_long': 8.4689, 'est_sigmasq_total': 11.1979, 'est_short_fraction': 0.2437}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.035, rl=0.400 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.489196 / Max Grad: 4.68e-06 ---
# Converged: max_grad 4.68e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.723569753729068, 'sigmasq_long': 8.62467295748104, 'sigmasq_total': 12.348242711210109, 'range_short': 0.035, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.4892, 'est_sigmasq_short': 3.7236, 'est_sigmasq_long': 8.6247, 'est_sigmasq_total': 12.3482, 'est_short_fraction': 0.3015}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.035, rl=0.700 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.507953 / Max Grad: 9.07e-07 ---
# Converged: max_grad 9.07e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.324457530043284, 'sigmasq_long': 10.602293457882919, 'sigmasq_total': 14.926750987926201, 'range_short': 0.035, 'range_long': 0.7, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.508, 'est_sigmasq_short': 4.3245, 'est_sigmasq_long': 10.6023, 'est_sigmasq_total': 14.9268, 'est_short_fraction': 0.2897}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.050, rl=0.250 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.494091 / Max Grad: 9.70e-06 ---
# Converged: max_grad 9.70e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.037261580329346, 'sigmasq_long': 8.164351643074257, 'sigmasq_total': 11.201613223403603, 'range_short': 0.05, 'range_long': 0.25, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.4941, 'est_sigmasq_short': 3.0373, 'est_sigmasq_long': 8.1644, 'est_sigmasq_total': 11.2016, 'est_short_fraction': 0.2711}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.050, rl=0.400 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.492104 / Max Grad: 2.53e-06 ---
# Converged: max_grad 2.53e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.155107185514359, 'sigmasq_long': 7.902233105106319, 'sigmasq_total': 12.057340290620678, 'range_short': 0.05, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.4921, 'est_sigmasq_short': 4.1551, 'est_sigmasq_long': 7.9022, 'est_sigmasq_total': 12.0573, 'est_short_fraction': 0.3446}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.050, rl=0.700 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.514619 / Max Grad: 7.26e-07 ---
# Converged: max_grad 7.26e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.827396612016073, 'sigmasq_long': 9.097290871742985, 'sigmasq_total': 13.924687483759058, 'range_short': 0.05, 'range_long': 0.7, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5146, 'est_sigmasq_short': 4.8274, 'est_sigmasq_long': 9.0973, 'est_sigmasq_total': 13.9247, 'est_short_fraction': 0.3467}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.070, rl=0.250 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.494703 / Max Grad: 6.14e-07 ---
# Converged: max_grad 6.14e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.6159032511458484, 'sigmasq_long': 7.671252081431252, 'sigmasq_total': 11.2871553325771, 'range_short': 0.07, 'range_long': 0.25, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.4947, 'est_sigmasq_short': 3.6159, 'est_sigmasq_long': 7.6713, 'est_sigmasq_total': 11.2872, 'est_short_fraction': 0.3204}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.070, rl=0.400 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.499472 / Max Grad: 2.48e-07 ---
# Converged: max_grad 2.48e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.913425069756193, 'sigmasq_long': 6.93614777855766, 'sigmasq_total': 11.849572848313853, 'range_short': 0.07, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.4995, 'est_sigmasq_short': 4.9134, 'est_sigmasq_long': 6.9361, 'est_sigmasq_total': 11.8496, 'est_short_fraction': 0.4146}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.070, rl=0.700 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.531591 / Max Grad: 3.41e-07 ---
# Converged: max_grad 3.41e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 5.675910590618946, 'sigmasq_long': 7.270305451379307, 'sigmasq_total': 12.946216041998252, 'range_short': 0.07, 'range_long': 0.7, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5316, 'est_sigmasq_short': 5.6759, 'est_sigmasq_long': 7.2703, 'est_sigmasq_total': 12.9462, 'est_short_fraction': 0.4384}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.015, rl=0.150 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.540798 / Max Grad: 3.11e-07 ---
# Converged: max_grad 3.11e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.1046522342589147, 'sigmasq_long': 8.86032900651333, 'sigmasq_total': 11.964981240772245, 'range_short': 0.015, 'range_long': 0.15, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5408, 'est_sigmasq_short': 3.1047, 'est_sigmasq_long': 8.8603, 'est_sigmasq_total': 11.965, 'est_short_fraction': 0.2595}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.015, rl=0.250 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.542088 / Max Grad: 3.67e-06 ---
# Converged: max_grad 3.67e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.134771875954481, 'sigmasq_long': 9.2528621536484, 'sigmasq_total': 13.38763402960288, 'range_short': 0.015, 'range_long': 0.25, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5421, 'est_sigmasq_short': 4.1348, 'est_sigmasq_long': 9.2529, 'est_sigmasq_total': 13.3876, 'est_short_fraction': 0.3089}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.015, rl=0.400 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.564771 / Max Grad: 2.92e-06 ---
# Converged: max_grad 2.92e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.597623820052777, 'sigmasq_long': 11.42433835828252, 'sigmasq_total': 16.021962178335297, 'range_short': 0.015, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5648, 'est_sigmasq_short': 4.5976, 'est_sigmasq_long': 11.4243, 'est_sigmasq_total': 16.022, 'est_short_fraction': 0.287}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.015, rl=0.700 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.609715 / Max Grad: 5.39e-07 ---
# Converged: max_grad 5.39e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.831232454691375, 'sigmasq_long': 17.236952394337962, 'sigmasq_total': 22.068184849029336, 'range_short': 0.015, 'range_long': 0.7, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.6097, 'est_sigmasq_short': 4.8312, 'est_sigmasq_long': 17.237, 'est_sigmasq_total': 22.0682, 'est_short_fraction': 0.2189}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.025, rl=0.150 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.541557 / Max Grad: 9.14e-06 ---
# Converged: max_grad 9.14e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.3906278442526028, 'sigmasq_long': 8.562963209851155, 'sigmasq_total': 11.953591054103757, 'range_short': 0.025, 'range_long': 0.15, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5416, 'est_sigmasq_short': 3.3906, 'est_sigmasq_long': 8.563, 'est_sigmasq_total': 11.9536, 'est_short_fraction': 0.2836}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.025, rl=0.250 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.545587 / Max Grad: 2.11e-07 ---
# Converged: max_grad 2.11e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.53338982784546, 'sigmasq_long': 8.49571178693791, 'sigmasq_total': 13.029101614783372, 'range_short': 0.025, 'range_long': 0.25, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5456, 'est_sigmasq_short': 4.5334, 'est_sigmasq_long': 8.4957, 'est_sigmasq_total': 13.0291, 'est_short_fraction': 0.3479}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.025, rl=0.400 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.570361 / Max Grad: 2.47e-07 ---
# Converged: max_grad 2.47e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 5.069893394615899, 'sigmasq_long': 9.908662045241288, 'sigmasq_total': 14.978555439857185, 'range_short': 0.025, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5704, 'est_sigmasq_short': 5.0699, 'est_sigmasq_long': 9.9087, 'est_sigmasq_total': 14.9786, 'est_short_fraction': 0.3385}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.025, rl=0.700 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.615851 / Max Grad: 3.56e-06 ---
# Converged: max_grad 3.56e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 5.371513974391498, 'sigmasq_long': 14.080998472591704, 'sigmasq_total': 19.452512446983203, 'range_short': 0.025, 'range_long': 0.7, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.6159, 'est_sigmasq_short': 5.3715, 'est_sigmasq_long': 14.081, 'est_sigmasq_total': 19.4525, 'est_short_fraction': 0.2761}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.035, rl=0.150 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.543804 / Max Grad: 8.01e-06 ---
# Converged: max_grad 8.01e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.8238051758937925, 'sigmasq_long': 8.243184323405876, 'sigmasq_total': 12.066989499299668, 'range_short': 0.035, 'range_long': 0.15, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5438, 'est_sigmasq_short': 3.8238, 'est_sigmasq_long': 8.2432, 'est_sigmasq_total': 12.067, 'est_short_fraction': 0.3169}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.035, rl=0.250 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.553566 / Max Grad: 2.96e-06 ---
# Converged: max_grad 2.96e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 5.13396834201056, 'sigmasq_long': 7.655608099958829, 'sigmasq_total': 12.789576441969388, 'range_short': 0.035, 'range_long': 0.25, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5536, 'est_sigmasq_short': 5.134, 'est_sigmasq_long': 7.6556, 'est_sigmasq_total': 12.7896, 'est_short_fraction': 0.4014}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.035, rl=0.400 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.583899 / Max Grad: 6.71e-06 ---
# Converged: max_grad 6.71e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 5.766090114227339, 'sigmasq_long': 8.227641097698253, 'sigmasq_total': 13.993731211925592, 'range_short': 0.035, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5839, 'est_sigmasq_short': 5.7661, 'est_sigmasq_long': 8.2276, 'est_sigmasq_total': 13.9937, 'est_short_fraction': 0.412}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.035, rl=0.700 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.634112 / Max Grad: 8.35e-07 ---
# Converged: max_grad 8.35e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 6.190558209621323, 'sigmasq_long': 10.27032081636562, 'sigmasq_total': 16.460879025986944, 'range_short': 0.035, 'range_long': 0.7, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.6341, 'est_sigmasq_short': 6.1906, 'est_sigmasq_long': 10.2703, 'est_sigmasq_total': 16.4609, 'est_short_fraction': 0.3761}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.050, rl=0.250 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.571395 / Max Grad: 7.35e-06 ---
# Converged: max_grad 7.35e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 6.191587702312366, 'sigmasq_long': 6.713756581228389, 'sigmasq_total': 12.905344283540755, 'range_short': 0.05, 'range_long': 0.25, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5714, 'est_sigmasq_short': 6.1916, 'est_sigmasq_long': 6.7138, 'est_sigmasq_total': 12.9053, 'est_short_fraction': 0.4798}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.050, rl=0.400 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.615601 / Max Grad: 7.36e-08 ---
# Converged: max_grad 7.36e-08 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 6.909677036515712, 'sigmasq_long': 6.619672754238812, 'sigmasq_total': 13.529349790754523, 'range_short': 0.05, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.6156, 'est_sigmasq_short': 6.9097, 'est_sigmasq_long': 6.6197, 'est_sigmasq_total': 13.5293, 'est_short_fraction': 0.5107}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.050, rl=0.700 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.681503 / Max Grad: 3.83e-06 ---
# Converged: max_grad 3.83e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 7.413277568285734, 'sigmasq_long': 7.076130338425914, 'sigmasq_total': 14.489407906711648, 'range_short': 0.05, 'range_long': 0.7, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.6815, 'est_sigmasq_short': 7.4133, 'est_sigmasq_long': 7.0761, 'est_sigmasq_total': 14.4894, 'est_short_fraction': 0.5116}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.070, rl=0.250 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.599315 / Max Grad: 1.68e-05 ---
# --- Step 2/6 / Loss: 1.545089 / Max Grad: 1.68e-05 ---
# --- Step 3/6 / Loss: 1.545089 / Max Grad: 1.68e-05 ---
# --- Step 4/6 / Loss: 1.545089 / Max Grad: 1.68e-05 ---
# --- Step 5/6 / Loss: 1.545089 / Max Grad: 1.68e-05 ---
# --- Step 6/6 / Loss: 1.545089 / Max Grad: 1.68e-05 ---
# Final Pure-Space Params: {'sigmasq_short': 7.835266812834809, 'sigmasq_long': 5.715335499732693, 'sigmasq_total': 13.550602312567502, 'range_short': 0.07, 'range_long': 0.25, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5451, 'est_sigmasq_short': 7.8353, 'est_sigmasq_long': 5.7153, 'est_sigmasq_total': 13.5506, 'est_short_fraction': 0.5782}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.070, rl=0.400 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.667662 / Max Grad: 8.39e-08 ---
# Converged: max_grad 8.39e-08 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 8.5747276884797, 'sigmasq_long': 5.452777670908284, 'sigmasq_total': 14.027505359387984, 'range_short': 0.07, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.6677, 'est_sigmasq_short': 8.5747, 'est_sigmasq_long': 5.4528, 'est_sigmasq_total': 14.0275, 'est_short_fraction': 0.6113}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.070, rl=0.700 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.765221 / Max Grad: 1.36e-06 ---
# Converged: max_grad 1.36e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 9.059711609254428, 'sigmasq_long': 5.582343358627169, 'sigmasq_total': 14.642054967881597, 'range_short': 0.07, 'range_long': 0.7, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.7652, 'est_sigmasq_short': 9.0597, 'est_sigmasq_long': 5.5823, 'est_sigmasq_total': 14.6421, 'est_short_fraction': 0.6187}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x1 | rs=0.015, rl=0.150 | n_valid=18,067
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18067, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.417704 / Max Grad: 2.89e-07 ---
# Converged: max_grad 2.89e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.649590619105291, 'sigmasq_long': 8.39205439653415, 'sigmasq_total': 11.04164501563944, 'range_short': 0.015, 'range_long': 0.15, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4177, 'est_sigmasq_short': 2.6496, 'est_sigmasq_long': 8.3921, 'est_sigmasq_total': 11.0416, 'est_short_fraction': 0.24}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x1 | rs=0.015, rl=0.250 | n_valid=18,067
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18067, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.409776 / Max Grad: 1.27e-07 ---
# Converged: max_grad 1.27e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.327485936880968, 'sigmasq_long': 9.453416909526059, 'sigmasq_total': 12.780902846407027, 'range_short': 0.015, 'range_long': 0.25, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4098, 'est_sigmasq_short': 3.3275, 'est_sigmasq_long': 9.4534, 'est_sigmasq_total': 12.7809, 'est_short_fraction': 0.2603}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x1 | rs=0.015, rl=0.400 | n_valid=18,067
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18067, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.419372 / Max Grad: 1.55e-06 ---
# Converged: max_grad 1.55e-06 < 1.00e-05
# ...
# TWO-SCALE | h8 | 2024_07_y24m07day03_hm07:48 | x1 | rs=0.035, rl=0.400 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.426365 / Max Grad: 5.46e-07 ---
# Converged: max_grad 5.46e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.420722019011873, 'sigmasq_long': 11.680379258591552, 'sigmasq_total': 16.101101277603426, 'range_short': 0.035, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4264, 'est_sigmasq_short': 4.4207, 'est_sigmasq_long': 11.6804, 'est_sigmasq_total': 16.1011, 'est_short_fraction': 0.2746}
#
# ====================================================================================================
# TWO-SCALE | h8 | 2024_07_y24m07day03_hm07:48 | x1 | rs=0.035, rl=0.700 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.464140 / Max Grad: 9.93e-07 ---
# Converged: max_grad 9.93e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.728909687585114, 'sigmasq_long': 16.567963152208346, 'sigmasq_total': 21.29687283979346, 'range_short': 0.035, 'range_long': 0.7, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4641, 'est_sigmasq_short': 4.7289, 'est_sigmasq_long': 16.568, 'est_sigmasq_total': 21.2969, 'est_short_fraction': 0.222}
#
# ====================================================================================================
# TWO-SCALE | h8 | 2024_07_y24m07day03_hm07:48 | x1 | rs=0.050, rl=0.250 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.418128 / Max Grad: 6.15e-06 ---
# Converged: max_grad 6.15e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 5.2507813182598975, 'sigmasq_long': 7.858269518401259, 'sigmasq_total': 13.109050836661156, 'range_short': 0.05, 'range_long': 0.25, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4181, 'est_sigmasq_short': 5.2508, 'est_sigmasq_long': 7.8583, 'est_sigmasq_total': 13.1091, 'est_short_fraction': 0.4005}
#
# ====================================================================================================
# TWO-SCALE | h8 | 2024_07_y24m07day03_hm07:48 | x1 | rs=0.050, rl=0.400 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.455955 / Max Grad: 1.56e-06 ---
# Converged: max_grad 1.56e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 5.973183544238604, 'sigmasq_long': 8.044873109601648, 'sigmasq_total': 14.018056653840251, 'range_short': 0.05, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.456, 'est_sigmasq_short': 5.9732, 'est_sigmasq_long': 8.0449, 'est_sigmasq_total': 14.0181, 'est_short_fraction': 0.4261}
#
# ====================================================================================================
# TWO-SCALE | h8 | 2024_07_y24m07day03_hm07:48 | x1 | rs=0.050, rl=0.700 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.511756 / Max Grad: 1.05e-05 ---
# --- Step 2/6 / Loss: 1.397385 / Max Grad: 1.05e-05 ---
# --- Step 3/6 / Loss: 1.397385 / Max Grad: 1.05e-05 ---
# --- Step 4/6 / Loss: 1.397385 / Max Grad: 1.05e-05 ---
# --- Step 5/6 / Loss: 1.397385 / Max Grad: 1.05e-05 ---
# --- Step 6/6 / Loss: 1.397385 / Max Grad: 1.05e-05 ---
# Final Pure-Space Params: {'sigmasq_short': 6.476133442622103, 'sigmasq_long': 8.956777272719265, 'sigmasq_total': 15.432910715341368, 'range_short': 0.05, 'range_long': 0.7, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.3974, 'est_sigmasq_short': 6.4761, 'est_sigmasq_long': 8.9568, 'est_sigmasq_total': 15.4329, 'est_short_fraction': 0.4196}
#
# ====================================================================================================
# TWO-SCALE | h8 | 2024_07_y24m07day03_hm07:48 | x1 | rs=0.070, rl=0.250 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.444142 / Max Grad: 8.11e-06 ---
# Converged: max_grad 8.11e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 7.217269680352873, 'sigmasq_long': 6.044717242346685, 'sigmasq_total': 13.261986922699558, 'range_short': 0.07, 'range_long': 0.25, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4441, 'est_sigmasq_short': 7.2173, 'est_sigmasq_long': 6.0447, 'est_sigmasq_total': 13.262, 'est_short_fraction': 0.5442}
#
# ====================================================================================================
# TWO-SCALE | h8 | 2024_07_y24m07day03_hm07:48 | x1 | rs=0.070, rl=0.400 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.9s. grid=114x159, heads=0, tails=18102, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.508546 / Max Grad: 1.17e-06 ---
# Converged: max_grad 1.17e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 7.979736707549764, 'sigmasq_long': 5.78213661738892, 'sigmasq_total': 13.761873324938684, 'range_short': 0.07, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.5085, 'est_sigmasq_short': 7.9797, 'est_sigmasq_long': 5.7821, 'est_sigmasq_total': 13.7619, 'est_short_fraction': 0.5798}
#
# ====================================================================================================
# TWO-SCALE | h8 | 2024_07_y24m07day03_hm07:48 | x1 | rs=0.070, rl=0.700 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.599204 / Max Grad: 3.37e-06 ---
# Converged: max_grad 3.37e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 8.483596817477869, 'sigmasq_long': 5.82509483101829, 'sigmasq_total': 14.308691648496158, 'range_short': 0.07, 'range_long': 0.7, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.5992, 'est_sigmasq_short': 8.4836, 'est_sigmasq_long': 5.8251, 'est_sigmasq_total': 14.3087, 'est_short_fraction': 0.5929}
# Saved all grid results: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_multiscale_column_rangegrid_sep3_050826_all.csv
#      date_str  day_idx  hour_idx                     time_key  resolution_stride resolution_label mean_design                                              model                                          kernel  \
# 0    20240703        2         0  2024_07_y24m07day03_hm00:53                  8               x8      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 1    20240703        2         0  2024_07_y24m07day03_hm00:53                  8               x8      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 2    20240703        2         0  2024_07_y24m07day03_hm00:53                  8               x8      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 3    20240703        2         0  2024_07_y24m07day03_hm00:53                  8               x8      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 4    20240703        2         0  2024_07_y24m07day03_hm00:53                  8               x8      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# ..        ...      ...       ...                          ...                ...              ...         ...                                                ...                                             ...
# 571  20240703        2         7  2024_07_y24m07day03_hm07:48                  1               x1      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 572  20240703        2         7  2024_07_y24m07day03_hm07:48                  1               x1      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 573  20240703        2         7  2024_07_y24m07day03_hm07:48                  1               x1      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 574  20240703        2         7  2024_07_y24m07day03_hm07:48                  1               x1      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 575  20240703        2         7  2024_07_y24m07day03_hm07:48                  1               x1      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
#
#                                             coord_mode  smooth_short  smooth_long  range_short_fixed  range_long_fixed  nugget_fixed    loss  fit_iter_raw  fit_steps_reported  precompute_s   fit_s  total_s  n_grid  \
# 0    regular-grid every-k thinning; covariance on S...           0.5          0.5              0.015              0.15           0.0  1.6341             0                   1        0.0413  0.1517   0.1929    2266
# 1    regular-grid every-k thinning; covariance on S...           0.5          0.5              0.015              0.25           0.0  1.6070             0                   1        0.0379  0.0699   0.1079    2266
# 2    regular-grid every-k thinning; covariance on S...           0.5          0.5              0.015              0.40           0.0  1.6034             0                   1        0.0377  0.0712   0.1090    2266
# 3    regular-grid every-k thinning; covariance on S...           0.5          0.5              0.015              0.70           0.0  1.6236             0                   1        0.0372  0.0796   0.1168    2266
# 4    regular-grid every-k thinning; covariance on S...           0.5          0.5              0.025              0.15           0.0  1.6338             0                   1        0.0376  0.1270   0.1646    2266
# ..                                                 ...           ...          ...                ...               ...           ...     ...           ...                 ...           ...     ...      ...     ...
# 571  regular-grid every-k thinning; covariance on S...           0.5          0.5              0.050              0.40           0.0  1.4560             0                   1        0.8401  1.1102   1.9502   18126
# 572  regular-grid every-k thinning; covariance on S...           0.5          0.5              0.050              0.70           0.0  1.3974             5                   6        0.8071  1.4686   2.2757   18126
# 573  regular-grid every-k thinning; covariance on S...           0.5          0.5              0.070              0.25           0.0  1.4441             0                   1        0.8370  1.4177   2.2548   18126
# 574  regular-grid every-k thinning; covariance on S...           0.5          0.5              0.070              0.40           0.0  1.5085             0                   1        0.8550  1.2238   2.0788   18126
# 575  regular-grid every-k thinning; covariance on S...           0.5          0.5              0.070              0.70           0.0  1.5992             0                   1        0.8348  0.9369   1.7717   18126
#
#      n_valid  valid_fraction  est_sigmasq_short  est_sigmasq_long  est_sigmasq_total  est_short_fraction  est_range_short  est_range_long  est_nugget  n_batches  n_tails  mean_m  max_m  largest_batch_n  \
# 0       2259          0.9969             0.6746           11.2196            11.8942              0.0567            0.015            0.15         0.0          1     2259    10.0     10             2259
# 1       2259          0.9969             2.9398            9.1585            12.0983              0.2430            0.015            0.25         0.0          1     2259    10.0     10             2259
# 2       2259          0.9969             4.0641            8.5913            12.6554              0.3211            0.015            0.40         0.0          1     2259    10.0     10             2259
# 3       2259          0.9969             4.9049            9.0575            13.9624              0.3513            0.015            0.70         0.0          1     2259    10.0     10             2259
# 4       2259          0.9969             0.6647           11.2459            11.9106              0.0558            0.025            0.15         0.0          1     2259    10.0     10             2259
# ..       ...             ...                ...               ...                ...                 ...              ...             ...         ...        ...      ...     ...    ...              ...
# 571    18102          0.9987             5.9732            8.0449            14.0181              0.4261            0.050            0.40         0.0          1    18102    10.0     10            18102
# 572    18102          0.9987             6.4761            8.9568            15.4329              0.4196            0.050            0.70         0.0          1    18102    10.0     10            18102
# 573    18102          0.9987             7.2173            6.0447            13.2620              0.5442            0.070            0.25         0.0          1    18102    10.0     10            18102
# 574    18102          0.9987             7.9797            5.7821            13.7619              0.5798            0.070            0.40         0.0          1    18102    10.0     10            18102
# 575    18102          0.9987             8.4836            5.8251            14.3087              0.5929            0.070            0.70         0.0          1    18102    10.0     10            18102
#
#      total_conditioning_nominal  head_right_cols  above_count  right_col_count  per_time_conditioning_count
# 0                            10                0            2                3                           10
# 1                            10                0            2                3                           10
# 2                            10                0            2                3                           10
# 3                            10                0            2                3                           10
# 4                            10                0            2                3                           10
# ..                          ...              ...          ...              ...                          ...
# 571                          10                0            2                3                           10
# 572                          10                0            2                3                           10
# 573                          10                0            2                3                           10
# 574                          10                0            2                3                           10
# 575                          10                0            2                3                           10
#
# [576 rows x 41 columns]

# %%
# Best range pair by hour and resolution.
if 'all_df' not in globals() or all_df.empty:
    all_df = pd.read_csv(OUT_DIR / f'{OUT_PREFIX}_all.csv')

idx = all_df.groupby(['hour_idx', 'resolution_stride'])['loss'].idxmin()
best_df = all_df.loc[idx].copy().sort_values(['hour_idx', 'resolution_stride'])
best_path = OUT_DIR / f'{OUT_PREFIX}_best_by_hour_resolution.csv'
round_df(best_df).to_csv(best_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
print('Saved best table:', best_path)

display_cols = [
    'hour_idx', 'resolution_stride', 'resolution_label', 'loss',
    'range_short_fixed', 'range_long_fixed',
    'est_sigmasq_short', 'est_sigmasq_long', 'est_sigmasq_total', 'est_short_fraction',
    'n_grid', 'n_valid', 'total_s'
]
display(round_df(best_df[display_cols]))
# Out:
# Saved best table: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_multiscale_column_rangegrid_sep3_050826_best_by_hour_resolution.csv
#      hour_idx  resolution_stride resolution_label    loss  range_short_fixed  range_long_fixed  est_sigmasq_short  est_sigmasq_long  est_sigmasq_total  est_short_fraction  n_grid  n_valid  total_s
# 55          0                  1               x1  1.4098              0.015              0.25             3.3275            9.4534            12.7809              0.2603   18126    18067   1.3400
# 36          0                  2               x2  1.5408              0.015              0.15             3.1047            8.8603            11.9650              0.2595    9063     9033   0.4911
# 20          0                  4               x4  1.4882              0.015              0.40             3.4908            9.0987            12.5895              0.2773    4532     4518   0.2291
# 2           0                  8               x8  1.6034              0.015              0.40             4.0641            8.5913            12.6554              0.3211    2266     2259   0.1090
# 140         1                  1               x1  1.3541              0.050              0.70             5.9115            8.4048            14.3163              0.4129   18126    17670   1.8660
# 117         1                  2               x2  1.4109              0.035              0.25             2.8781            9.5986            12.4767              0.2307    9063     8840   0.5732
# 105         1                  4               x4  1.5194              0.070              0.25             2.5831           10.6460            13.2292              0.1953    4532     4422   0.2678
# 75          1                  8               x8  1.6479              0.015              0.70             4.8238           11.9300            16.7539              0.2879    2266     2208   0.1664
# 209         2                  1               x1  1.3575              0.035              0.70             3.8682           20.1308            23.9990              0.1612   18126    16698   1.8883
# 189         2                  2               x2  1.4610              0.035              0.25             2.6703           12.1874            14.8576              0.1797    9063     8353   0.5101
# 163         2                  4               x4  1.6101              0.015              0.25             2.5317           12.5839            15.1156              0.1675    4532     4176   0.2363
# 149         2                  8               x8  1.7108              0.025              0.25             2.4015           13.4168            15.8183              0.1518    2266     2082   0.1199
# 279         3                  1               x1  1.3873              0.035              0.25             2.6705           14.1051            16.7756              0.1592   18126    16863   1.3886
# 261         3                  2               x2  1.4846              0.035              0.25             2.2558           14.5359            16.7917              0.1343    9063     8428   0.5877
# 235         3                  4               x4  1.6470              0.015              0.25             2.3778           14.2208            16.5986              0.1433    4532     4217   0.2541
# 217         3                  8               x8  1.7542              0.015              0.25             2.1883           15.1666            17.3549              0.1261    2266     2114   0.1363
# 346         4                  1               x1  1.4239              0.025              0.15             1.2263           13.9224            15.1487              0.0809   18126    17088   1.8773
# 341         4                  2               x2  1.5306              0.070              0.70             7.4518           14.1243            21.5760              0.3454    9063     8552   0.8177
# 310         4                  4               x4  1.7036              0.025              0.15             0.2246           15.8802            16.1047              0.0139    4532     4288   0.5066
# 290         4                  8               x8  1.7785              0.015              0.40             5.2609           13.4921            18.7531              0.2805    2266     2145   0.1616
# 422         5                  1               x1  1.4237              0.035              0.15             2.0106           12.2423            14.2529              0.1411   18126    17760   1.5595
# 404         5                  2               x2  1.5226              0.035              0.15             1.5349           12.5542            14.0891              0.1089    9063     8881   0.6460
# 384         5                  4               x4  1.6540              0.025              0.40             4.4489           14.2172            18.6661              0.2383    4532     4439   0.3445
# 368         5                  8               x8  1.7656              0.035              0.15             0.1280           16.1254            16.2535              0.0079    2266     2221   0.2557
# 495         6                  1               x1  1.3815              0.035              0.25             3.2400           11.5606            14.8006              0.2189   18126    18104   1.5352
# 473         6                  2               x2  1.4922              0.025              0.25             3.0637           11.5489            14.6126              0.2097    9063     9052   0.5733
# 452         6                  4               x4  1.6173              0.015              0.40             4.5869           11.5956            16.1826              0.2834    4532     4527   0.3511
# 433         6                  8               x8  1.6959              0.015              0.25             3.3725           11.1350            14.5076              0.2325    2266     2264   0.1215
# 572         7                  1               x1  1.3974              0.050              0.70             6.4761            8.9568            15.4329              0.4196   18126    18102   2.2757
# 545         7                  2               x2  1.4765              0.025              0.25             2.9132           11.4319            14.3451              0.2031    9063     9051   0.5055
# 523         7                  4               x4  1.6064              0.015              0.25             3.5791           10.0531            13.6323              0.2625    4532     4526   0.2510
# 505         7                  8               x8  1.7339              0.015              0.25             4.5094           10.0961            14.6055              0.3087    2266     2263   0.1269

# %%
# Compact stability diagnostics for the selected range pairs.
# A good multiscale explanation should not only lower loss; it should also choose separated
# range pairs and variance fractions with some stability across resolution.
if 'best_df' not in globals() or best_df.empty:
    best_df = pd.read_csv(OUT_DIR / f'{OUT_PREFIX}_best_by_hour_resolution.csv')

stability = (
    best_df
    .groupby('resolution_label')
    .agg(
        loss_mean=('loss', 'mean'),
        loss_sd=('loss', 'std'),
        range_short_median=('range_short_fixed', 'median'),
        range_long_median=('range_long_fixed', 'median'),
        short_fraction_mean=('est_short_fraction', 'mean'),
        short_fraction_sd=('est_short_fraction', 'std'),
        sigmasq_total_mean=('est_sigmasq_total', 'mean'),
    )
    .reset_index()
)
stability['resolution_label'] = pd.Categorical(
    stability['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
)
stability = stability.sort_values('resolution_label')
stability_path = OUT_DIR / f'{OUT_PREFIX}_stability_by_resolution.csv'
round_df(stability).to_csv(stability_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
print('Saved stability table:', stability_path)
display(round_df(stability))
# Out:
# Saved stability table: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_multiscale_column_rangegrid_sep3_050826_stability_by_resolution.csv
#   resolution_label  loss_mean  loss_sd  range_short_median  range_long_median  short_fraction_mean  short_fraction_sd  sigmasq_total_mean
# 3               x8     1.7113   0.0606               0.015               0.25               0.2146             0.1100             15.8378
# 2               x4     1.6057   0.0708               0.015               0.25               0.1977             0.0904             15.2648
# 1               x2     1.4899   0.0424               0.035               0.25               0.2089             0.0738             15.0892
# 0               x1     1.3919   0.0271               0.035               0.25               0.2318             0.1255             15.9384

# %%
# Plot best variance split and selected ranges across resolution.
plot_df = best_df.copy()
plot_df['resolution_label'] = pd.Categorical(
    plot_df['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
)
plot_df = plot_df.sort_values(['hour_idx', 'resolution_label'])

fig, axes = plt.subplots(2, 2, figsize=(13, 8), constrained_layout=True)
plot_specs = [
    ('est_sigmasq_short', 'estimated short-scale variance'),
    ('est_sigmasq_long', 'estimated long-scale variance'),
    ('est_short_fraction', 'short-scale variance fraction'),
    ('loss', 'best Vecchia loss'),
]
for ax, (col, title) in zip(axes.ravel(), plot_specs):
    for hour_idx, sub in plot_df.groupby('hour_idx'):
        ax.plot(sub['resolution_label'].astype(str), sub[col], marker='o', linewidth=1.5, label=f'h{int(hour_idx)+1}')
    ax.set_title(title)
    ax.set_xlabel('resolution thinning')
    ax.grid(True, alpha=0.3)
axes.ravel()[-1].legend(ncol=2, fontsize=8, title='hour')
fig.suptitle('Two-scale fixed-range Column Vecchia: best grid-search fits', fontsize=14)
plot_path = OUT_DIR / f'{OUT_PREFIX}_best_variance_trajectories.png'
fig.savefig(plot_path, dpi=180, bbox_inches='tight')
print('Saved:', plot_path)
plt.show()

fig, axes = plt.subplots(1, 2, figsize=(12, 4), constrained_layout=True)
for ax, col, title in [
    (axes[0], 'range_short_fixed', 'selected short range'),
    (axes[1], 'range_long_fixed', 'selected long range'),
]:
    for hour_idx, sub in plot_df.groupby('hour_idx'):
        ax.plot(sub['resolution_label'].astype(str), sub[col], marker='o', linewidth=1.5, label=f'h{int(hour_idx)+1}')
    ax.set_title(title)
    ax.set_xlabel('resolution thinning')
    ax.grid(True, alpha=0.3)
axes[-1].legend(ncol=2, fontsize=8, title='hour')
fig.suptitle('Selected fixed range pair by resolution', fontsize=14)
range_plot_path = OUT_DIR / f'{OUT_PREFIX}_best_range_pair_trajectories.png'
fig.savefig(range_plot_path, dpi=180, bbox_inches='tight')
print('Saved:', range_plot_path)
plt.show()
# Out:
# Saved: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_multiscale_column_rangegrid_sep3_050826_best_variance_trajectories.png
# Saved: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_multiscale_column_rangegrid_sep3_050826_best_range_pair_trajectories.png

# %%
# Optional: loss table for one hour/resolution to inspect the range grid surface.
INSPECT_HOUR_IDX = HOUR_IDX_LIST[0]
INSPECT_STRIDE = 1
surf = all_df[(all_df['hour_idx'] == INSPECT_HOUR_IDX) & (all_df['resolution_stride'] == INSPECT_STRIDE)].copy()
if len(surf):
    loss_pivot = surf.pivot(index='range_short_fixed', columns='range_long_fixed', values='loss')
    shortfrac_pivot = surf.pivot(index='range_short_fixed', columns='range_long_fixed', values='est_short_fraction')
    print(f'Loss surface: hour={INSPECT_HOUR_IDX + 1}, resolution=x{INSPECT_STRIDE}')
    display(round_df(loss_pivot))
    print('Short variance fraction surface')
    display(round_df(shortfrac_pivot))
# Out:
# Loss surface: hour=1, resolution=x1
# range_long_fixed     0.15    0.25    0.40    0.70
# range_short_fixed
# 0.015              1.4177  1.4098  1.4194  1.4436
# 0.025              1.4174  1.4142  1.4277  1.4541
# 0.035              1.4195  1.4252  1.4474  1.4826
# 0.050                 NaN  1.4489  1.4904  1.5481
# 0.070                 NaN  1.4236  1.5567  1.6544
# Short variance fraction surface
# range_long_fixed     0.15    0.25    0.40    0.70
# range_short_fixed
# 0.015              0.2400  0.2603  0.2361  0.1789
# 0.025              0.2871  0.3296  0.3200  0.2673
# 0.035              0.3385  0.4006  0.4092  0.3844
# 0.050                 NaN  0.4955  0.5168  0.5162
# 0.070                 NaN  0.6175  0.6331  0.6311

# %% [markdown]
# # Pure-space two-scale Column Vecchia diagnostic, separated range grid, fixed positive nugget
#
# This notebook tests a multiscale spatial covariance without making all two-Matern parameters free.
#
# For each hour and resolution, it grid-searches fixed `(range_short, range_long)` pairs with an explicit separation constraint and estimates only two variance weights:
#
# ```text
# Cov(h) = sigmasq_short * Matern(h; range_short, smooth_short)
#        + sigmasq_long  * Matern(h; range_long,  smooth_long)
#        + nugget_fixed
# ```
#
# Default diagnostic:
#
# - Column reverse-L pure-space geometry: `Up2_Right3_M10`, real source coordinates for covariance
# - each time slot fitted independently
# - `x8, x4, x2, x1` regular-grid thinning
# - `nugget_fixed = 2.0`
# - `smooth_short = smooth_long = 0.5`
# - `range_long >= 3 * range_short`
# - estimate only `sigmasq_short`, `sigmasq_long`
#
# Interpretation target:
#
# - If fine resolution prefers larger `sigmasq_short` or smaller selected `range_short`, that supports multiscale/fine-scale structure.
# - If best range pair and variance split are stable across resolution, single-scale misspecification is less likely.
#
# This `sep3` version is meant to avoid ambiguous pairs such as `(0.12, 0.18)`, where the two components are too close to interpret as separate scales.
#
#
# This `nug2` version keeps `smooth_short = smooth_long = 0.5` and fixes a positive nugget to test whether the previous short-scale component was absorbing nugget-like unresolved variability.

# %%
import gc
import sys
import time
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch

LOCAL_SRC = '/Users/joonwonlee/Documents/GEMS_TCO-1/src'
AMAREL_SRC = '/home/jl2815/tco'
SRC = AMAREL_SRC if Path(AMAREL_SRC).exists() else LOCAL_SRC
if SRC not in sys.path:
    sys.path.insert(0, SRC)

from GEMS_TCO import configuration as config
from GEMS_TCO.data_loader import load_data_dynamic_processed
from GEMS_TCO.kernels_space_multiscale_050826 import ColumnSpaceTwoScaleFixedRangeTrendVecchiaFit

DEVICE = torch.device('cpu')
DTYPE = torch.float64
ROUND_DECIMALS = 4

pd.set_option('display.max_columns', 160)
pd.set_option('display.width', 220)
print('SRC:', SRC)
print('device:', DEVICE)
# Out:
# SRC: /Users/joonwonlee/Documents/GEMS_TCO-1/src
# device: cpu

# %%
# Experiment config
YEAR = '2024'
MONTH = 7
DAY_IDX = 2                 # 0-based: 2 -> 2024-07-03
HOUR_IDX_LIST = list(range(8))
LAT_RANGE = [-3, 2]
LON_RANGE = [121, 131]

RESOLUTION_STRIDES = [8, 4, 2, 1]
MEAN_DESIGN = 'latlon'

# Finer short-range grid plus explicit scale separation.
# This avoids treating close pairs such as 0.12 vs 0.18 as two distinct scales.
RANGE_SHORT_GRID = [0.015, 0.025, 0.035, 0.050, 0.070]
RANGE_LONG_GRID = [0.150, 0.250, 0.400, 0.700]
MIN_RANGE_RATIO = 3.0
NUGGET_FIXED = 2.0
SMOOTH_SHORT = 0.5
SMOOTH_LONG = 0.5
MODEL_SMOOTH_FOR_CLASS = 0.5

COLUMN_SPEC = {
    'model': 'ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_realloc',
    'head_right_cols': 0,
    'above_count': 2,
    'right_col_count': 3,
    'per_time_conditioning_count': 8,
    'target_chunk_size': 512,
}

LBFGS_LR = 1.0
LBFGS_STEPS = 6
LBFGS_EVAL = 18
LBFGS_HIST = 10
GRAD_TOL = 1e-5

INIT_SIGMASQ_SHORT = 3.0
INIT_SIGMASQ_LONG = 10.0

PURE_SPACE_DIR = Path('/Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space')
OUT_DIR = PURE_SPACE_DIR / 'log'
OUT_DIR.mkdir(parents=True, exist_ok=True)
OUT_PREFIX = 'real_pure_space_multiscale_column_rangegrid_sep3_nug2_050826'

range_pairs = [(rs, rl) for rs in RANGE_SHORT_GRID for rl in RANGE_LONG_GRID if rl >= MIN_RANGE_RATIO * rs]
print('day:', f'{YEAR}{MONTH:02d}{DAY_IDX + 1:02d}')
print('hours:', HOUR_IDX_LIST)
print('strides:', RESOLUTION_STRIDES)
print('range pairs:', range_pairs)
print('n range pairs:', len(range_pairs), '| min long/short ratio:', MIN_RANGE_RATIO)
print('nugget_fixed:', NUGGET_FIXED, 'smooth_short/long:', SMOOTH_SHORT, SMOOTH_LONG)
# Out:
# day: 20240703
# hours: [0, 1, 2, 3, 4, 5, 6, 7]
# strides: [8, 4, 2, 1]
# range pairs: [(0.015, 0.15), (0.015, 0.25), (0.015, 0.4), (0.015, 0.7), (0.025, 0.15), (0.025, 0.25), (0.025, 0.4), (0.025, 0.7), (0.035, 0.15), (0.035, 0.25), (0.035, 0.4), (0.035, 0.7), (0.05, 0.25), (0.05, 0.4), (0.05, 0.7), (0.07, 0.25), (0.07, 0.4), (0.07, 0.7)]
# n range pairs: 18 | min long/short ratio: 3.0
# nugget_fixed: 2.0 smooth_short/long: 0.5 0.5

# %%
def make_sigma_params(sig_short=INIT_SIGMASQ_SHORT, sig_long=INIT_SIGMASQ_LONG):
    return [
        torch.tensor([np.log(sig_short)], device=DEVICE, dtype=DTYPE, requires_grad=True),
        torch.tensor([np.log(sig_long)], device=DEVICE, dtype=DTYPE, requires_grad=True),
    ]


def backmap_two(raw, range_short, range_long):
    sig_short = float(np.exp(raw[0]))
    sig_long = float(np.exp(raw[1]))
    total = sig_short + sig_long
    return {
        'sigmasq_short': sig_short,
        'sigmasq_long': sig_long,
        'sigmasq_total': total,
        'short_fraction': sig_short / total if total > 0 else np.nan,
        'range_short': float(range_short),
        'range_long': float(range_long),
        'nugget': float(NUGGET_FIXED),
    }


def count_valid(input_map):
    return int(sum(((~torch.isnan(v[:, 2])) & (~torch.isnan(v[:, 0])) & (~torch.isnan(v[:, 1]))).sum().item() for v in input_map.values()))


def space_diag(model):
    groups = getattr(model, 'Batched_Groups', []) or []
    if not groups:
        return {'n_batches': 0, 'n_tails': 0, 'mean_m': 0.0, 'max_m': 0, 'largest_batch_n': 0}
    ns = np.asarray([int(g['target_idx'].shape[0]) for g in groups], dtype=np.int64)
    ms = np.asarray([int(g['max_m']) for g in groups], dtype=np.int64)
    return {
        'n_batches': int(len(groups)),
        'n_tails': int(ns.sum()),
        'mean_m': float(ms.mean()),
        'max_m': int(ms.max()),
        'largest_batch_n': int(ns.max()),
    }


def round_df(df, digits=ROUND_DECIMALS):
    out = df.copy()
    num_cols = out.select_dtypes(include=[np.number]).columns
    out[num_cols] = out[num_cols].round(digits)
    return out


def empty_cache():
    gc.collect()
    if DEVICE.type == 'cuda':
        torch.cuda.empty_cache()


def resolution_label(stride):
    return f'x{int(stride)}'

# %%
loader = load_data_dynamic_processed(config.mac_data_load_path)
df_map, _, _, monthly_mean = loader.load_maxmin_ordered_data_bymonthyear(
    lat_lon_resolution=[1, 1],
    mm_cond_number=10,
    years_=[YEAR],
    months_=[MONTH],
    lat_range=LAT_RANGE,
    lon_range=LON_RANGE,
    is_whittle=True,
)
month_keys = sorted(df_map.keys())
day_keys = month_keys[DAY_IDX * 8:(DAY_IDX + 1) * 8]
if len(day_keys) != 8:
    raise ValueError(f'Day {DAY_IDX} has {len(day_keys)} slices, expected 8')

first_df = df_map[day_keys[0]].reset_index(drop=True)
grid_order = (
    first_df
    .assign(_orig_idx=np.arange(len(first_df)))
    .sort_values(['Longitude', 'Latitude', '_orig_idx'], kind='mergesort')['_orig_idx']
    .to_numpy(dtype=np.int64)
)
grid_coords_full = first_df.iloc[grid_order][['Latitude', 'Longitude']].to_numpy(dtype=np.float64)

print('monthly_mean:', round(monthly_mean, 4))
print('day keys:', day_keys[0], '...', day_keys[-1])
print('full grid:', grid_coords_full.shape)
print('unique lat/lon:', len(np.unique(np.round(grid_coords_full[:,0], 6))), len(np.unique(np.round(grid_coords_full[:,1], 6))))
# Out:
# --- Global Monthly Mean for 2024-7: 257.9726 ---
# monthly_mean: 257.9726
# day keys: 2024_07_y24m07day03_hm00:53 ... 2024_07_y24m07day03_hm07:48
# full grid: (18126, 2)
# unique lat/lon: 114 159

# %%
def load_hour_map(hour_idx):
    key = day_keys[int(hour_idx)]
    hour_df_map = {key: df_map[key]}
    hour_map, _ = loader.load_working_data(
        hour_df_map,
        monthly_mean=monthly_mean,
        idx_for_datamap=[0, 1],
        ord_mm=grid_order,
        dtype=DTYPE,
        keep_ori=True,
    )
    return {k: v.to(DEVICE) for k, v in hour_map.items()}, key


def thin_hour_map(hour_map, stride):
    n_full = grid_coords_full.shape[0]
    thin_idx = np.arange(0, n_full, int(stride), dtype=np.int64)
    thin_map = {k: v[thin_idx].contiguous() for k, v in hour_map.items()}
    thin_grid = np.ascontiguousarray(grid_coords_full[thin_idx])
    return thin_map, thin_grid, thin_idx


def build_model(input_map, grid_coords, range_short, range_long):
    return ColumnSpaceTwoScaleFixedRangeTrendVecchiaFit(
        smooth=MODEL_SMOOTH_FOR_CLASS,
        input_map=input_map,
        grid_coords=grid_coords,
        head_right_cols=COLUMN_SPEC['head_right_cols'],
        above_count=COLUMN_SPEC['above_count'],
        right_col_count=COLUMN_SPEC['right_col_count'],
        per_time_conditioning_count=COLUMN_SPEC['per_time_conditioning_count'],
        target_chunk_size=COLUMN_SPEC['target_chunk_size'],
        range_short=range_short,
        range_long=range_long,
        nugget_fixed=NUGGET_FIXED,
        smooth_short=SMOOTH_SHORT,
        smooth_long=SMOOTH_LONG,
        mean_design=MEAN_DESIGN,
    )


def make_row(hour_idx, time_key, stride, range_short, range_long, n_grid, n_valid, pre_s, fit_s, loss, fit_iter, est, diag):
    return {
        'date_str': f'{YEAR}{MONTH:02d}{DAY_IDX + 1:02d}',
        'day_idx': DAY_IDX,
        'hour_idx': int(hour_idx),
        'time_key': str(time_key),
        'resolution_stride': int(stride),
        'resolution_label': resolution_label(stride),
        'mean_design': MEAN_DESIGN,
        'model': COLUMN_SPEC['model'],
        'kernel': 'column_space_twoscale_fixedrange_tonly_realloc',
        'coord_mode': 'regular-grid every-k thinning; covariance on Source_Latitude/Source_Longitude',
        'smooth_short': float(SMOOTH_SHORT),
        'smooth_long': float(SMOOTH_LONG),
        'range_short_fixed': float(range_short),
        'range_long_fixed': float(range_long),
        'nugget_fixed': float(NUGGET_FIXED),
        'loss': float(loss),
        'fit_iter_raw': int(fit_iter),
        'fit_steps_reported': int(fit_iter) + 1,
        'precompute_s': float(pre_s),
        'fit_s': float(fit_s),
        'total_s': float(pre_s + fit_s),
        'n_grid': int(n_grid),
        'n_valid': int(n_valid),
        'valid_fraction': float(n_valid / n_grid) if n_grid else np.nan,
        **{f'est_{k}': v for k, v in est.items()},
        **diag,
        'total_conditioning_nominal': COLUMN_SPEC['per_time_conditioning_count'],
        'head_right_cols': COLUMN_SPEC['head_right_cols'],
        'above_count': COLUMN_SPEC['above_count'],
        'right_col_count': COLUMN_SPEC['right_col_count'],
        'per_time_conditioning_count': COLUMN_SPEC['per_time_conditioning_count'],
    }

# %%
def fit_range_pair(hour_idx, stride, range_short, range_long):
    hour_map, time_key = load_hour_map(hour_idx)
    thin_map, thin_grid, _ = thin_hour_map(hour_map, stride)
    n_grid = int(thin_grid.shape[0])
    n_valid = count_valid(thin_map)
    print('\n' + '=' * 100)
    print(
        f'TWO-SCALE | h{hour_idx + 1} | {time_key} | {resolution_label(stride)} | '
        f'rs={range_short:.3f}, rl={range_long:.3f} | n_valid={n_valid:,}'
    )

    model = build_model(thin_map, thin_grid, range_short, range_long)
    t_pre = time.time()
    model.precompute_conditioning_sets()
    pre_s = time.time() - t_pre
    diag = space_diag(model)

    params = make_sigma_params()
    opt = model.set_optimizer(params, lr=LBFGS_LR, max_iter=LBFGS_EVAL, max_eval=LBFGS_EVAL, history_size=LBFGS_HIST)
    t_fit = time.time()
    out, fit_iter = model.fit_vecc_lbfgs(params, opt, max_steps=LBFGS_STEPS, grad_tol=GRAD_TOL)
    fit_s = time.time() - t_fit
    est = backmap_two(out[:2], range_short, range_long)
    row = make_row(hour_idx, time_key, stride, range_short, range_long, n_grid, n_valid, pre_s, fit_s, out[-1], fit_iter, est, diag)
    print('RESULT:', {k: round(v, 4) if isinstance(v, float) else v for k, v in row.items() if k in ['resolution_label','loss','est_sigmasq_short','est_sigmasq_long','est_short_fraction','est_sigmasq_total']})

    del model, params, opt, hour_map, thin_map
    empty_cache()
    return row

# %%
rows = []
for hour_idx in HOUR_IDX_LIST:
    for stride in RESOLUTION_STRIDES:
        for range_short, range_long in range_pairs:
            rows.append(fit_range_pair(hour_idx, stride, range_short, range_long))
            tmp = round_df(pd.DataFrame(rows))
            tmp.to_csv(OUT_DIR / f'{OUT_PREFIX}_all.csv', index=False, float_format=f'%.{ROUND_DECIMALS}f')

all_df = pd.DataFrame(rows)
all_path = OUT_DIR / f'{OUT_PREFIX}_all.csv'
round_df(all_df).to_csv(all_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
print('Saved all grid results:', all_path)
display(round_df(all_df))
# Out:
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.015, rl=0.150 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=7.2/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.660055 / Max Grad: 4.49e-06 ---
# Converged: max_grad 4.49e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 0.0010319572105111873, 'sigmasq_long': 9.4893177291267, 'sigmasq_total': 9.490349686337211, 'range_short': 0.015, 'range_long': 0.15, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6601, 'est_sigmasq_short': 0.001, 'est_sigmasq_long': 9.4893, 'est_sigmasq_total': 9.4903, 'est_short_fraction': 0.0001}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.015, rl=0.250 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=7.2/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.625523 / Max Grad: 2.54e-06 ---
# Converged: max_grad 2.54e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 0.9276508853183961, 'sigmasq_long': 9.17481973281656, 'sigmasq_total': 10.102470618134957, 'range_short': 0.015, 'range_long': 0.25, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6255, 'est_sigmasq_short': 0.9277, 'est_sigmasq_long': 9.1748, 'est_sigmasq_total': 10.1025, 'est_short_fraction': 0.0918}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.015, rl=0.400 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=7.2/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.606892 / Max Grad: 1.12e-06 ---
# Converged: max_grad 1.12e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.053116555742011, 'sigmasq_long': 8.609695190123407, 'sigmasq_total': 10.662811745865419, 'range_short': 0.015, 'range_long': 0.4, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6069, 'est_sigmasq_short': 2.0531, 'est_sigmasq_long': 8.6097, 'est_sigmasq_total': 10.6628, 'est_short_fraction': 0.1925}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.015, rl=0.700 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=7.2/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.600371 / Max Grad: 1.31e-07 ---
# Converged: max_grad 1.31e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.8938734156833803, 'sigmasq_long': 9.082544836329957, 'sigmasq_total': 11.976418252013337, 'range_short': 0.015, 'range_long': 0.7, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6004, 'est_sigmasq_short': 2.8939, 'est_sigmasq_long': 9.0825, 'est_sigmasq_total': 11.9764, 'est_short_fraction': 0.2416}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.025, rl=0.150 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=7.2/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.659639 / Max Grad: 2.36e-04 ---
# --- Step 2/6 / Loss: 1.625112 / Max Grad: 8.16e-06 ---
# Converged: max_grad 8.16e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 0.0002562932417154939, 'sigmasq_long': 9.490539570801884, 'sigmasq_total': 9.4907958640436, 'range_short': 0.025, 'range_long': 0.15, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6251, 'est_sigmasq_short': 0.0003, 'est_sigmasq_long': 9.4905, 'est_sigmasq_total': 9.4908, 'est_short_fraction': 0.0}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.025, rl=0.250 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=7.2/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.625251 / Max Grad: 2.64e-06 ---
# Converged: max_grad 2.64e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 0.934677086950362, 'sigmasq_long': 9.17357196828409, 'sigmasq_total': 10.108249055234452, 'range_short': 0.025, 'range_long': 0.25, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6253, 'est_sigmasq_short': 0.9347, 'est_sigmasq_long': 9.1736, 'est_sigmasq_total': 10.1082, 'est_short_fraction': 0.0925}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.025, rl=0.400 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=7.2/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.606710 / Max Grad: 9.06e-07 ---
# Converged: max_grad 9.06e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.08502776144097, 'sigmasq_long': 8.5672666696462, 'sigmasq_total': 10.65229443108717, 'range_short': 0.025, 'range_long': 0.4, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6067, 'est_sigmasq_short': 2.085, 'est_sigmasq_long': 8.5673, 'est_sigmasq_total': 10.6523, 'est_short_fraction': 0.1957}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.025, rl=0.700 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=7.2/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.600210 / Max Grad: 4.48e-07 ---
# Converged: max_grad 4.48e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.9403634121840745, 'sigmasq_long': 8.982783749347389, 'sigmasq_total': 11.923147161531464, 'range_short': 0.025, 'range_long': 0.7, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6002, 'est_sigmasq_short': 2.9404, 'est_sigmasq_long': 8.9828, 'est_sigmasq_total': 11.9231, 'est_short_fraction': 0.2466}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.035, rl=0.150 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=7.2/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.658496 / Max Grad: 2.48e-04 ---
# --- Step 2/6 / Loss: 1.625109 / Max Grad: 8.63e-06 ---
# Converged: max_grad 8.63e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 6.62378633615328e-05, 'sigmasq_long': 9.490234746587092, 'sigmasq_total': 9.490300984450453, 'range_short': 0.035, 'range_long': 0.15, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6251, 'est_sigmasq_short': 0.0001, 'est_sigmasq_long': 9.4902, 'est_sigmasq_total': 9.4903, 'est_short_fraction': 0.0}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.035, rl=0.250 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=7.2/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.624522 / Max Grad: 2.96e-06 ---
# Converged: max_grad 2.96e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 0.9551811348248244, 'sigmasq_long': 9.168042501627879, 'sigmasq_total': 10.123223636452703, 'range_short': 0.035, 'range_long': 0.25, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6245, 'est_sigmasq_short': 0.9552, 'est_sigmasq_long': 9.168, 'est_sigmasq_total': 10.1232, 'est_short_fraction': 0.0944}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.035, rl=0.400 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=7.2/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.606272 / Max Grad: 4.87e-07 ---
# Converged: max_grad 4.87e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.1754267118694863, 'sigmasq_long': 8.448747876640393, 'sigmasq_total': 10.624174588509879, 'range_short': 0.035, 'range_long': 0.4, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6063, 'est_sigmasq_short': 2.1754, 'est_sigmasq_long': 8.4487, 'est_sigmasq_total': 10.6242, 'est_short_fraction': 0.2048}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.035, rl=0.700 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=7.2/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.599901 / Max Grad: 2.15e-06 ---
# Converged: max_grad 2.15e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.069555972719227, 'sigmasq_long': 8.716227842390161, 'sigmasq_total': 11.785783815109388, 'range_short': 0.035, 'range_long': 0.7, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.5999, 'est_sigmasq_short': 3.0696, 'est_sigmasq_long': 8.7162, 'est_sigmasq_total': 11.7858, 'est_short_fraction': 0.2604}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.050, rl=0.250 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=7.2/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.623013 / Max Grad: 3.64e-06 ---
# Converged: max_grad 3.64e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 0.9965814256891272, 'sigmasq_long': 9.166711016303388, 'sigmasq_total': 10.163292441992516, 'range_short': 0.05, 'range_long': 0.25, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.623, 'est_sigmasq_short': 0.9966, 'est_sigmasq_long': 9.1667, 'est_sigmasq_total': 10.1633, 'est_short_fraction': 0.0981}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.050, rl=0.400 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=7.2/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.605564 / Max Grad: 1.15e-06 ---
# Converged: max_grad 1.15e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.387991785287955, 'sigmasq_long': 8.189699371951352, 'sigmasq_total': 10.577691157239308, 'range_short': 0.05, 'range_long': 0.4, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6056, 'est_sigmasq_short': 2.388, 'est_sigmasq_long': 8.1897, 'est_sigmasq_total': 10.5777, 'est_short_fraction': 0.2258}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.050, rl=0.700 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=7.2/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.599735 / Max Grad: 1.37e-06 ---
# Converged: max_grad 1.37e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.369706634179466, 'sigmasq_long': 8.149475268990066, 'sigmasq_total': 11.519181903169532, 'range_short': 0.05, 'range_long': 0.7, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.5997, 'est_sigmasq_short': 3.3697, 'est_sigmasq_long': 8.1495, 'est_sigmasq_total': 11.5192, 'est_short_fraction': 0.2925}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.070, rl=0.250 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=7.2/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.621011 / Max Grad: 2.25e-06 ---
# Converged: max_grad 2.25e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 1.0447774932559182, 'sigmasq_long': 9.195273447015726, 'sigmasq_total': 10.240050940271644, 'range_short': 0.07, 'range_long': 0.25, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.621, 'est_sigmasq_short': 1.0448, 'est_sigmasq_long': 9.1953, 'est_sigmasq_total': 10.2401, 'est_short_fraction': 0.102}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.070, rl=0.400 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=7.2/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.605110 / Max Grad: 4.87e-06 ---
# Converged: max_grad 4.87e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.743909846246371, 'sigmasq_long': 7.804878171302403, 'sigmasq_total': 10.548788017548773, 'range_short': 0.07, 'range_long': 0.4, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6051, 'est_sigmasq_short': 2.7439, 'est_sigmasq_long': 7.8049, 'est_sigmasq_total': 10.5488, 'est_short_fraction': 0.2601}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.070, rl=0.700 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=7.2/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.600676 / Max Grad: 6.68e-06 ---
# Converged: max_grad 6.68e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.859947475461298, 'sigmasq_long': 7.353800543685864, 'sigmasq_total': 11.213748019147161, 'range_short': 0.07, 'range_long': 0.7, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6007, 'est_sigmasq_short': 3.8599, 'est_sigmasq_long': 7.3538, 'est_sigmasq_total': 11.2137, 'est_short_fraction': 0.3442}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.015, rl=0.150 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=7.7/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.569401 / Max Grad: 4.08e-04 ---
# --- Step 2/6 / Loss: 1.505509 / Max Grad: 2.39e-06 ---
# Converged: max_grad 2.39e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 0.00015839499227740652, 'sigmasq_long': 7.874804226605099, 'sigmasq_total': 7.874962621597376, 'range_short': 0.015, 'range_long': 0.15, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5055, 'est_sigmasq_short': 0.0002, 'est_sigmasq_long': 7.8748, 'est_sigmasq_total': 7.875, 'est_short_fraction': 0.0}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.015, rl=0.250 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=7.7/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.525527 / Max Grad: 4.13e-06 ---
# Converged: max_grad 4.13e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 0.5539538013680951, 'sigmasq_long': 8.679025836107247, 'sigmasq_total': 9.232979637475342, 'range_short': 0.015, 'range_long': 0.25, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5255, 'est_sigmasq_short': 0.554, 'est_sigmasq_long': 8.679, 'est_sigmasq_total': 9.233, 'est_short_fraction': 0.06}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.015, rl=0.400 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=7.7/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.502712 / Max Grad: 1.55e-06 ---
# Converged: max_grad 1.55e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 1.466399846782615, 'sigmasq_long': 9.170396086803839, 'sigmasq_total': 10.636795933586454, 'range_short': 0.015, 'range_long': 0.4, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5027, 'est_sigmasq_short': 1.4664, 'est_sigmasq_long': 9.1704, 'est_sigmasq_total': 10.6368, 'est_short_fraction': 0.1379}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.015, rl=0.700 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=7.7/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.492830 / Max Grad: 5.14e-06 ---
# Converged: max_grad 5.14e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.0087958826507974, 'sigmasq_long': 11.822408066149652, 'sigmasq_total': 13.83120394880045, 'range_short': 0.015, 'range_long': 0.7, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.4928, 'est_sigmasq_short': 2.0088, 'est_sigmasq_long': 11.8224, 'est_sigmasq_total': 13.8312, 'est_short_fraction': 0.1452}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.025, rl=0.150 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=7.7/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.568998 / Max Grad: 1.52e-05 ---
# --- Step 2/6 / Loss: 1.505506 / Max Grad: 6.01e-06 ---
# Converged: max_grad 6.01e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 1.8640532525561074e-05, 'sigmasq_long': 7.8752024980418955, 'sigmasq_total': 7.875221138574421, 'range_short': 0.025, 'range_long': 0.15, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5055, 'est_sigmasq_short': 0.0, 'est_sigmasq_long': 7.8752, 'est_sigmasq_total': 7.8752, 'est_short_fraction': 0.0}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.025, rl=0.250 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=7.7/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.525186 / Max Grad: 5.06e-06 ---
# Converged: max_grad 5.06e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 0.5530019665596252, 'sigmasq_long': 8.687619886128694, 'sigmasq_total': 9.240621852688319, 'range_short': 0.025, 'range_long': 0.25, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5252, 'est_sigmasq_short': 0.553, 'est_sigmasq_long': 8.6876, 'est_sigmasq_total': 9.2406, 'est_short_fraction': 0.0598}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.025, rl=0.400 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=7.7/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.502387 / Max Grad: 1.33e-06 ---
# Converged: max_grad 1.33e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 1.4905542330512909, 'sigmasq_long': 9.11811578580988, 'sigmasq_total': 10.608670018861172, 'range_short': 0.025, 'range_long': 0.4, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5024, 'est_sigmasq_short': 1.4906, 'est_sigmasq_long': 9.1181, 'est_sigmasq_total': 10.6087, 'est_short_fraction': 0.1405}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.025, rl=0.700 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=7.7/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.492435 / Max Grad: 3.78e-06 ---
# Converged: max_grad 3.78e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.0495796373613797, 'sigmasq_long': 11.656669113022513, 'sigmasq_total': 13.706248750383892, 'range_short': 0.025, 'range_long': 0.7, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.4924, 'est_sigmasq_short': 2.0496, 'est_sigmasq_long': 11.6567, 'est_sigmasq_total': 13.7062, 'est_short_fraction': 0.1495}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.035, rl=0.150 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=7.7/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.567613 / Max Grad: 2.24e-05 ---
# --- Step 2/6 / Loss: 1.505506 / Max Grad: 5.20e-06 ---
# Converged: max_grad 5.20e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.1719798995780298e-05, 'sigmasq_long': 7.874876537312416, 'sigmasq_total': 7.874898257111412, 'range_short': 0.035, 'range_long': 0.15, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5055, 'est_sigmasq_short': 0.0, 'est_sigmasq_long': 7.8749, 'est_sigmasq_total': 7.8749, 'est_short_fraction': 0.0}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.035, rl=0.250 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=7.7/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.524051 / Max Grad: 9.83e-06 ---
# Converged: max_grad 9.83e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 0.5585082049618731, 'sigmasq_long': 8.696261885036135, 'sigmasq_total': 9.254770089998008, 'range_short': 0.035, 'range_long': 0.25, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5241, 'est_sigmasq_short': 0.5585, 'est_sigmasq_long': 8.6963, 'est_sigmasq_total': 9.2548, 'est_short_fraction': 0.0603}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.035, rl=0.400 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=7.7/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.501371 / Max Grad: 8.17e-07 ---
# Converged: max_grad 8.17e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 1.5675144947683064, 'sigmasq_long': 8.957517532294458, 'sigmasq_total': 10.525032027062764, 'range_short': 0.035, 'range_long': 0.4, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5014, 'est_sigmasq_short': 1.5675, 'est_sigmasq_long': 8.9575, 'est_sigmasq_total': 10.525, 'est_short_fraction': 0.1489}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.035, rl=0.700 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=7.7/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.491330 / Max Grad: 1.25e-06 ---
# Converged: max_grad 1.25e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.1732317832874832, 'sigmasq_long': 11.183863823308274, 'sigmasq_total': 13.357095606595756, 'range_short': 0.035, 'range_long': 0.7, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.4913, 'est_sigmasq_short': 2.1732, 'est_sigmasq_long': 11.1839, 'est_sigmasq_total': 13.3571, 'est_short_fraction': 0.1627}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.050, rl=0.250 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=7.7/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.521245 / Max Grad: 6.59e-06 ---
# Converged: max_grad 6.59e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 0.5775496322931396, 'sigmasq_long': 8.710527473794388, 'sigmasq_total': 9.288077106087528, 'range_short': 0.05, 'range_long': 0.25, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5212, 'est_sigmasq_short': 0.5775, 'est_sigmasq_long': 8.7105, 'est_sigmasq_total': 9.2881, 'est_short_fraction': 0.0622}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.050, rl=0.400 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=7.7/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.499102 / Max Grad: 1.95e-07 ---
# Converged: max_grad 1.95e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 1.7619885577019165, 'sigmasq_long': 8.59363121105195, 'sigmasq_total': 10.355619768753867, 'range_short': 0.05, 'range_long': 0.4, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.4991, 'est_sigmasq_short': 1.762, 'est_sigmasq_long': 8.5936, 'est_sigmasq_total': 10.3556, 'est_short_fraction': 0.1701}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.050, rl=0.700 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=7.7/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.489278 / Max Grad: 1.68e-06 ---
# Converged: max_grad 1.68e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.4784455248677437, 'sigmasq_long': 10.148841696645942, 'sigmasq_total': 12.627287221513686, 'range_short': 0.05, 'range_long': 0.7, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.4893, 'est_sigmasq_short': 2.4784, 'est_sigmasq_long': 10.1488, 'est_sigmasq_total': 12.6273, 'est_short_fraction': 0.1963}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.070, rl=0.250 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=7.7/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.516941 / Max Grad: 3.47e-06 ---
# Converged: max_grad 3.47e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 0.6105798287044243, 'sigmasq_long': 8.737160809316128, 'sigmasq_total': 9.347740638020552, 'range_short': 0.07, 'range_long': 0.25, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5169, 'est_sigmasq_short': 0.6106, 'est_sigmasq_long': 8.7372, 'est_sigmasq_total': 9.3477, 'est_short_fraction': 0.0653}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.070, rl=0.400 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=7.7/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.496158 / Max Grad: 6.46e-07 ---
# Converged: max_grad 6.46e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.1039267935093826, 'sigmasq_long': 8.060904269952806, 'sigmasq_total': 10.164831063462188, 'range_short': 0.07, 'range_long': 0.4, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.4962, 'est_sigmasq_short': 2.1039, 'est_sigmasq_long': 8.0609, 'est_sigmasq_total': 10.1648, 'est_short_fraction': 0.207}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.070, rl=0.700 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=7.7/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.487587 / Max Grad: 7.91e-06 ---
# Converged: max_grad 7.91e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.9959780925382584, 'sigmasq_long': 8.721796117335847, 'sigmasq_total': 11.717774209874106, 'range_short': 0.07, 'range_long': 0.7, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.4876, 'est_sigmasq_short': 2.996, 'est_sigmasq_long': 8.7218, 'est_sigmasq_total': 11.7178, 'est_short_fraction': 0.2557}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.015, rl=0.150 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.562943 / Max Grad: 2.57e-06 ---
# Converged: max_grad 2.57e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 0.9640099963551786, 'sigmasq_long': 9.167408667054115, 'sigmasq_total': 10.131418663409294, 'range_short': 0.015, 'range_long': 0.15, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5629, 'est_sigmasq_short': 0.964, 'est_sigmasq_long': 9.1674, 'est_sigmasq_total': 10.1314, 'est_short_fraction': 0.0952}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.015, rl=0.250 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.541668 / Max Grad: 1.89e-06 ---
# Converged: max_grad 1.89e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.0530526849997974, 'sigmasq_long': 9.447959898753764, 'sigmasq_total': 11.50101258375356, 'range_short': 0.015, 'range_long': 0.25, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5417, 'est_sigmasq_short': 2.0531, 'est_sigmasq_long': 9.448, 'est_sigmasq_total': 11.501, 'est_short_fraction': 0.1785}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.015, rl=0.400 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.536498 / Max Grad: 1.75e-06 ---
# Converged: max_grad 1.75e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.572196125633666, 'sigmasq_long': 11.34706171025994, 'sigmasq_total': 13.919257835893607, 'range_short': 0.015, 'range_long': 0.4, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5365, 'est_sigmasq_short': 2.5722, 'est_sigmasq_long': 11.3471, 'est_sigmasq_total': 13.9193, 'est_short_fraction': 0.1848}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.015, rl=0.700 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.542971 / Max Grad: 4.02e-07 ---
# Converged: max_grad 4.02e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.8502654889572403, 'sigmasq_long': 16.625067866557306, 'sigmasq_total': 19.475333355514547, 'range_short': 0.015, 'range_long': 0.7, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.543, 'est_sigmasq_short': 2.8503, 'est_sigmasq_long': 16.6251, 'est_sigmasq_total': 19.4753, 'est_short_fraction': 0.1464}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.025, rl=0.150 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.561144 / Max Grad: 2.96e-06 ---
# Converged: max_grad 2.96e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 1.02100151059165, 'sigmasq_long': 9.128504098934881, 'sigmasq_total': 10.149505609526532, 'range_short': 0.025, 'range_long': 0.15, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5611, 'est_sigmasq_short': 1.021, 'est_sigmasq_long': 9.1285, 'est_sigmasq_total': 10.1495, 'est_short_fraction': 0.1006}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.025, rl=0.250 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.540327 / Max Grad: 2.92e-07 ---
# Converged: max_grad 2.92e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.2561453937332776, 'sigmasq_long': 9.051445819070963, 'sigmasq_total': 11.30759121280424, 'range_short': 0.025, 'range_long': 0.25, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5403, 'est_sigmasq_short': 2.2561, 'est_sigmasq_long': 9.0514, 'est_sigmasq_total': 11.3076, 'est_short_fraction': 0.1995}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.025, rl=0.400 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.535166 / Max Grad: 4.51e-06 ---
# Converged: max_grad 4.51e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.8557289037449665, 'sigmasq_long': 10.427512742499701, 'sigmasq_total': 13.283241646244667, 'range_short': 0.025, 'range_long': 0.4, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5352, 'est_sigmasq_short': 2.8557, 'est_sigmasq_long': 10.4275, 'est_sigmasq_total': 13.2832, 'est_short_fraction': 0.215}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.025, rl=0.700 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.540928 / Max Grad: 2.94e-06 ---
# Converged: max_grad 2.94e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.206424336474058, 'sigmasq_long': 14.529990102416695, 'sigmasq_total': 17.736414438890755, 'range_short': 0.025, 'range_long': 0.7, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5409, 'est_sigmasq_short': 3.2064, 'est_sigmasq_long': 14.53, 'est_sigmasq_total': 17.7364, 'est_short_fraction': 0.1808}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.035, rl=0.150 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.558804 / Max Grad: 5.78e-06 ---
# Converged: max_grad 5.78e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 1.0818018160705156, 'sigmasq_long': 9.137469186786367, 'sigmasq_total': 10.219271002856882, 'range_short': 0.035, 'range_long': 0.15, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5588, 'est_sigmasq_short': 1.0818, 'est_sigmasq_long': 9.1375, 'est_sigmasq_total': 10.2193, 'est_short_fraction': 0.1059}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.035, rl=0.250 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.539199 / Max Grad: 1.16e-06 ---
# Converged: max_grad 1.16e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.5524265565297517, 'sigmasq_long': 8.591806906350955, 'sigmasq_total': 11.144233462880706, 'range_short': 0.035, 'range_long': 0.25, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5392, 'est_sigmasq_short': 2.5524, 'est_sigmasq_long': 8.5918, 'est_sigmasq_total': 11.1442, 'est_short_fraction': 0.229}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.035, rl=0.400 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.534731 / Max Grad: 2.03e-08 ---
# Converged: max_grad 2.03e-08 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.2709189078981784, 'sigmasq_long': 9.329215103918568, 'sigmasq_total': 12.600134011816746, 'range_short': 0.035, 'range_long': 0.4, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5347, 'est_sigmasq_short': 3.2709, 'est_sigmasq_long': 9.3292, 'est_sigmasq_total': 12.6001, 'est_short_fraction': 0.2596}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.035, rl=0.700 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.540422 / Max Grad: 1.72e-06 ---
# Converged: max_grad 1.72e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.751735940184097, 'sigmasq_long': 11.814150500917318, 'sigmasq_total': 15.565886441101416, 'range_short': 0.035, 'range_long': 0.7, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5404, 'est_sigmasq_short': 3.7517, 'est_sigmasq_long': 11.8142, 'est_sigmasq_total': 15.5659, 'est_short_fraction': 0.241}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.050, rl=0.250 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.538786 / Max Grad: 1.39e-06 ---
# Converged: max_grad 1.39e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.059769748013958, 'sigmasq_long': 8.019046481210834, 'sigmasq_total': 11.078816229224792, 'range_short': 0.05, 'range_long': 0.25, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5388, 'est_sigmasq_short': 3.0598, 'est_sigmasq_long': 8.019, 'est_sigmasq_total': 11.0788, 'est_short_fraction': 0.2762}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.050, rl=0.400 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.536572 / Max Grad: 2.24e-06 ---
# Converged: max_grad 2.24e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.9524793922187635, 'sigmasq_long': 8.043301910930598, 'sigmasq_total': 11.99578130314936, 'range_short': 0.05, 'range_long': 0.4, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5366, 'est_sigmasq_short': 3.9525, 'est_sigmasq_long': 8.0433, 'est_sigmasq_total': 11.9958, 'est_short_fraction': 0.3295}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.050, rl=0.700 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.543883 / Max Grad: 1.29e-06 ---
# Converged: max_grad 1.29e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.597682790431918, 'sigmasq_long': 8.814397046991687, 'sigmasq_total': 13.412079837423605, 'range_short': 0.05, 'range_long': 0.7, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5439, 'est_sigmasq_short': 4.5977, 'est_sigmasq_long': 8.8144, 'est_sigmasq_total': 13.4121, 'est_short_fraction': 0.3428}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.070, rl=0.250 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.539872 / Max Grad: 7.40e-06 ---
# Converged: max_grad 7.40e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.8160785522942393, 'sigmasq_long': 7.397126194248486, 'sigmasq_total': 11.213204746542726, 'range_short': 0.07, 'range_long': 0.25, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5399, 'est_sigmasq_short': 3.8161, 'est_sigmasq_long': 7.3971, 'est_sigmasq_total': 11.2132, 'est_short_fraction': 0.3403}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.070, rl=0.400 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.541714 / Max Grad: 4.19e-07 ---
# Converged: max_grad 4.19e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.891058503856987, 'sigmasq_long': 6.93421051514409, 'sigmasq_total': 11.825269019001077, 'range_short': 0.07, 'range_long': 0.4, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5417, 'est_sigmasq_short': 4.8911, 'est_sigmasq_long': 6.9342, 'est_sigmasq_total': 11.8253, 'est_short_fraction': 0.4136}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.070, rl=0.700 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.553051 / Max Grad: 8.79e-07 ---
# Converged: max_grad 8.79e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 5.611144185378811, 'sigmasq_long': 6.9768976724073575, 'sigmasq_total': 12.58804185778617, 'range_short': 0.07, 'range_long': 0.7, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5531, 'est_sigmasq_short': 5.6111, 'est_sigmasq_long': 6.9769, 'est_sigmasq_total': 12.588, 'est_short_fraction': 0.4458}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x1 | rs=0.015, rl=0.150 | n_valid=18,067
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.8s. grid=114x159, heads=0, tails=18067, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.459782 / Max Grad: 5.59e-08 ---
# Converged: max_grad 5.59e-08 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 0.4561121347814583, 'sigmasq_long': 8.763681405145393, 'sigmasq_total': 9.219793539926851, 'range_short': 0.015, 'range_long': 0.15, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4598, 'est_sigmasq_short': 0.4561, 'est_sigmasq_long': 8.7637, 'est_sigmasq_total': 9.2198, 'est_short_fraction': 0.0495}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x1 | rs=0.015, rl=0.250 | n_valid=18,067
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.8s. grid=114x159, heads=0, tails=18067, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.434158 / Max Grad: 8.09e-06 ---
# Converged: max_grad 8.09e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 1.2138980289023356, 'sigmasq_long': 9.587116118116992, 'sigmasq_total': 10.801014147019327, 'range_short': 0.015, 'range_long': 0.25, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4342, 'est_sigmasq_short': 1.2139, 'est_sigmasq_long': 9.5871, 'est_sigmasq_total': 10.801, 'est_short_fraction': 0.1124}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x1 | rs=0.015, rl=0.400 | n_valid=18,067
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.8s. grid=114x159, heads=0, tails=18067, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.422844 / Max Grad: 1.84e-06 ---
# Converged: max_grad 1.84e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 1.6096544178890626, 'sigmasq_long': 11.69135559649807, 'sigmasq_total': 13.301010014387133, 'range_short': 0.015, 'range_long': 0.4, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4228, 'est_sigmasq_short': 1.6097, 'est_sigmasq_long': 11.6914, 'est_sigmasq_total': 13.301, 'est_short_fraction': 0.121}
#
# ====================================================================================================
# ...
#
# ====================================================================================================
# TWO-SCALE | h8 | 2024_07_y24m07day03_hm07:48 | x1 | rs=0.035, rl=0.400 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.410831 / Max Grad: 9.28e-07 ---
# Converged: max_grad 9.28e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 1.380764141829079, 'sigmasq_long': 15.129967170187705, 'sigmasq_total': 16.510731312016784, 'range_short': 0.035, 'range_long': 0.4, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4108, 'est_sigmasq_short': 1.3808, 'est_sigmasq_long': 15.13, 'est_sigmasq_total': 16.5107, 'est_short_fraction': 0.0836}
#
# ====================================================================================================
# TWO-SCALE | h8 | 2024_07_y24m07day03_hm07:48 | x1 | rs=0.035, rl=0.700 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.412617 / Max Grad: 3.72e-06 ---
# Converged: max_grad 3.72e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 1.7460786958707053, 'sigmasq_long': 22.06152822761142, 'sigmasq_total': 23.807606923482123, 'range_short': 0.035, 'range_long': 0.7, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4126, 'est_sigmasq_short': 1.7461, 'est_sigmasq_long': 22.0615, 'est_sigmasq_total': 23.8076, 'est_short_fraction': 0.0733}
#
# ====================================================================================================
# TWO-SCALE | h8 | 2024_07_y24m07day03_hm07:48 | x1 | rs=0.050, rl=0.250 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.410818 / Max Grad: 4.22e-07 ---
# Converged: max_grad 4.22e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 1.212167329179143, 'sigmasq_long': 11.30353720391189, 'sigmasq_total': 12.515704533091034, 'range_short': 0.05, 'range_long': 0.25, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4108, 'est_sigmasq_short': 1.2122, 'est_sigmasq_long': 11.3035, 'est_sigmasq_total': 12.5157, 'est_short_fraction': 0.0969}
#
# ====================================================================================================
# TWO-SCALE | h8 | 2024_07_y24m07day03_hm07:48 | x1 | rs=0.050, rl=0.400 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.404989 / Max Grad: 2.36e-06 ---
# Converged: max_grad 2.36e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.207110176286501, 'sigmasq_long': 12.25096657103308, 'sigmasq_total': 14.45807674731958, 'range_short': 0.05, 'range_long': 0.4, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.405, 'est_sigmasq_short': 2.2071, 'est_sigmasq_long': 12.251, 'est_sigmasq_total': 14.4581, 'est_short_fraction': 0.1527}
#
# ====================================================================================================
# TWO-SCALE | h8 | 2024_07_y24m07day03_hm07:48 | x1 | rs=0.050, rl=0.700 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.407789 / Max Grad: 4.69e-06 ---
# Converged: max_grad 4.69e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.7721030742331703, 'sigmasq_long': 16.00152706906525, 'sigmasq_total': 18.77363014329842, 'range_short': 0.05, 'range_long': 0.7, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4078, 'est_sigmasq_short': 2.7721, 'est_sigmasq_long': 16.0015, 'est_sigmasq_total': 18.7736, 'est_short_fraction': 0.1477}
#
# ====================================================================================================
# TWO-SCALE | h8 | 2024_07_y24m07day03_hm07:48 | x1 | rs=0.070, rl=0.250 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.405876 / Max Grad: 8.12e-06 ---
# Converged: max_grad 8.12e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 1.9381713182303577, 'sigmasq_long': 10.077234966959569, 'sigmasq_total': 12.015406285189927, 'range_short': 0.07, 'range_long': 0.25, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4059, 'est_sigmasq_short': 1.9382, 'est_sigmasq_long': 10.0772, 'est_sigmasq_total': 12.0154, 'est_short_fraction': 0.1613}
#
# ====================================================================================================
# TWO-SCALE | h8 | 2024_07_y24m07day03_hm07:48 | x1 | rs=0.070, rl=0.400 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.403259 / Max Grad: 2.90e-06 ---
# Converged: max_grad 2.90e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.317053703167354, 'sigmasq_long': 9.664867534286138, 'sigmasq_total': 12.981921237453491, 'range_short': 0.07, 'range_long': 0.4, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4033, 'est_sigmasq_short': 3.3171, 'est_sigmasq_long': 9.6649, 'est_sigmasq_total': 12.9819, 'est_short_fraction': 0.2555}
#
# ====================================================================================================
# TWO-SCALE | h8 | 2024_07_y24m07day03_hm07:48 | x1 | rs=0.070, rl=0.700 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=8]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=7.9/8/8
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.409270 / Max Grad: 4.84e-06 ---
# Converged: max_grad 4.84e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.216268941059179, 'sigmasq_long': 10.158687607452109, 'sigmasq_total': 14.374956548511289, 'range_short': 0.07, 'range_long': 0.7, 'nugget': 2.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4093, 'est_sigmasq_short': 4.2163, 'est_sigmasq_long': 10.1587, 'est_sigmasq_total': 14.375, 'est_short_fraction': 0.2933}
# Saved all grid results: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_multiscale_column_rangegrid_sep3_nug2_050826_all.csv
#      date_str  day_idx  hour_idx                     time_key  resolution_stride resolution_label mean_design                                              model                                          kernel  \
# 0    20240703        2         0  2024_07_y24m07day03_hm00:53                  8               x8      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 1    20240703        2         0  2024_07_y24m07day03_hm00:53                  8               x8      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 2    20240703        2         0  2024_07_y24m07day03_hm00:53                  8               x8      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 3    20240703        2         0  2024_07_y24m07day03_hm00:53                  8               x8      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 4    20240703        2         0  2024_07_y24m07day03_hm00:53                  8               x8      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# ..        ...      ...       ...                          ...                ...              ...         ...                                                ...                                             ...
# 571  20240703        2         7  2024_07_y24m07day03_hm07:48                  1               x1      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 572  20240703        2         7  2024_07_y24m07day03_hm07:48                  1               x1      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 573  20240703        2         7  2024_07_y24m07day03_hm07:48                  1               x1      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 574  20240703        2         7  2024_07_y24m07day03_hm07:48                  1               x1      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 575  20240703        2         7  2024_07_y24m07day03_hm07:48                  1               x1      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
#
#                                             coord_mode  smooth_short  smooth_long  range_short_fixed  range_long_fixed  nugget_fixed    loss  fit_iter_raw  fit_steps_reported  precompute_s   fit_s  total_s  n_grid  \
# 0    regular-grid every-k thinning; covariance on S...           0.5          0.5              0.015              0.15           2.0  1.6601             0                   1        0.0389  0.1674   0.2064    2266
# 1    regular-grid every-k thinning; covariance on S...           0.5          0.5              0.015              0.25           2.0  1.6255             0                   1        0.0372  0.0961   0.1333    2266
# 2    regular-grid every-k thinning; covariance on S...           0.5          0.5              0.015              0.40           2.0  1.6069             0                   1        0.0392  0.0755   0.1147    2266
# 3    regular-grid every-k thinning; covariance on S...           0.5          0.5              0.015              0.70           2.0  1.6004             0                   1        0.0376  0.0656   0.1032    2266
# 4    regular-grid every-k thinning; covariance on S...           0.5          0.5              0.025              0.15           2.0  1.6251             1                   2        0.0374  0.2376   0.2750    2266
# ..                                                 ...           ...          ...                ...               ...           ...     ...           ...                 ...           ...     ...      ...     ...
# 571  regular-grid every-k thinning; covariance on S...           0.5          0.5              0.050              0.40           2.0  1.4050             0                   1        0.8006  0.5597   1.3602   18126
# 572  regular-grid every-k thinning; covariance on S...           0.5          0.5              0.050              0.70           2.0  1.4078             0                   1        0.7987  0.6270   1.4257   18126
# 573  regular-grid every-k thinning; covariance on S...           0.5          0.5              0.070              0.25           2.0  1.4059             0                   1        0.8001  0.5627   1.3628   18126
# 574  regular-grid every-k thinning; covariance on S...           0.5          0.5              0.070              0.40           2.0  1.4033             0                   1        0.7992  0.4761   1.2753   18126
# 575  regular-grid every-k thinning; covariance on S...           0.5          0.5              0.070              0.70           2.0  1.4093             0                   1        0.7967  0.5835   1.3802   18126
#
#      n_valid  valid_fraction  est_sigmasq_short  est_sigmasq_long  est_sigmasq_total  est_short_fraction  est_range_short  est_range_long  est_nugget  n_batches  n_tails  mean_m  max_m  largest_batch_n  \
# 0       2259          0.9969             0.0010            9.4893             9.4903              0.0001            0.015            0.15         2.0          1     2259     8.0      8             2259
# 1       2259          0.9969             0.9277            9.1748            10.1025              0.0918            0.015            0.25         2.0          1     2259     8.0      8             2259
# 2       2259          0.9969             2.0531            8.6097            10.6628              0.1925            0.015            0.40         2.0          1     2259     8.0      8             2259
# 3       2259          0.9969             2.8939            9.0825            11.9764              0.2416            0.015            0.70         2.0          1     2259     8.0      8             2259
# 4       2259          0.9969             0.0003            9.4905             9.4908              0.0000            0.025            0.15         2.0          1     2259     8.0      8             2259
# ..       ...             ...                ...               ...                ...                 ...              ...             ...         ...        ...      ...     ...    ...              ...
# 571    18102          0.9987             2.2071           12.2510            14.4581              0.1527            0.050            0.40         2.0          1    18102     8.0      8            18102
# 572    18102          0.9987             2.7721           16.0015            18.7736              0.1477            0.050            0.70         2.0          1    18102     8.0      8            18102
# 573    18102          0.9987             1.9382           10.0772            12.0154              0.1613            0.070            0.25         2.0          1    18102     8.0      8            18102
# 574    18102          0.9987             3.3171            9.6649            12.9819              0.2555            0.070            0.40         2.0          1    18102     8.0      8            18102
# 575    18102          0.9987             4.2163           10.1587            14.3750              0.2933            0.070            0.70         2.0          1    18102     8.0      8            18102
#
#      total_conditioning_nominal  head_right_cols  above_count  right_col_count  per_time_conditioning_count
# 0                             8                0            2                3                            8
# 1                             8                0            2                3                            8
# 2                             8                0            2                3                            8
# 3                             8                0            2                3                            8
# 4                             8                0            2                3                            8
# ..                          ...              ...          ...              ...                          ...
# 571                           8                0            2                3                            8
# 572                           8                0            2                3                            8
# 573                           8                0            2                3                            8
# 574                           8                0            2                3                            8
# 575                           8                0            2                3                            8
#
# [576 rows x 41 columns]

# %%
# Best range pair by hour and resolution.
if 'all_df' not in globals() or all_df.empty:
    all_df = pd.read_csv(OUT_DIR / f'{OUT_PREFIX}_all.csv')

idx = all_df.groupby(['hour_idx', 'resolution_stride'])['loss'].idxmin()
best_df = all_df.loc[idx].copy().sort_values(['hour_idx', 'resolution_stride'])
best_path = OUT_DIR / f'{OUT_PREFIX}_best_by_hour_resolution.csv'
round_df(best_df).to_csv(best_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
print('Saved best table:', best_path)

display_cols = [
    'hour_idx', 'resolution_stride', 'resolution_label', 'loss',
    'range_short_fixed', 'range_long_fixed',
    'est_sigmasq_short', 'est_sigmasq_long', 'est_sigmasq_total', 'est_short_fraction',
    'n_grid', 'n_valid', 'total_s'
]
display(round_df(best_df[display_cols]))
# Out:
# Saved best table: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_multiscale_column_rangegrid_sep3_nug2_050826_best_by_hour_resolution.csv
#      hour_idx  resolution_stride resolution_label    loss  range_short_fixed  range_long_fixed  est_sigmasq_short  est_sigmasq_long  est_sigmasq_total  est_short_fraction  n_grid  n_valid  total_s
# 65          0                  1               x1  1.4119              0.035              0.70             2.7652           11.6976            14.4628              0.1912   18126    18067   1.2612
# 46          0                  2               x2  1.5347              0.035              0.40             3.2709            9.3292            12.6001              0.2596    9063     9033   0.4672
# 35          0                  4               x4  1.4876              0.070              0.70             2.9960            8.7218            11.7178              0.2557    4532     4518   0.1909
# 14          0                  8               x8  1.5997              0.050              0.70             3.3697            8.1495            11.5192              0.2925    2266     2259   0.1045
# 143         1                  1               x1  1.3558              0.070              0.70             3.1454           10.9551            14.1006              0.2231   18126    17670   1.3075
# 125         1                  2               x2  1.4145              0.070              0.70             2.7973           12.1070            14.9043              0.1877    9063     8840   0.4929
# 91          1                  4               x4  1.5179              0.015              0.25             0.0000           10.9795            10.9795              0.0000    4532     4422   0.5168
# 88          1                  8               x8  1.6447              0.070              0.40             2.5306           10.0303            12.5608              0.2015    2266     2208   0.0943
# 213         2                  1               x1  1.3600              0.070              0.25             0.0002           13.3024            13.3026              0.0000   18126    16698   2.1862
# 192         2                  2               x2  1.4618              0.050              0.25             0.1385           13.1848            13.3233              0.0104    9063     8353   0.8318
# 178         2                  4               x4  1.6053              0.070              0.40             2.9772           10.9892            13.9664              0.2132    4532     4176   0.1774
# 160         2                  8               x8  1.6991              0.070              0.40             2.9956           11.2780            14.2736              0.2099    2266     2082   0.0849
# 271         3                  1               x1  1.3896              0.015              0.25             0.0001           14.9017            14.9018              0.0000   18126    16863   1.9866
# 261         3                  2               x2  1.4829              0.035              0.25             0.0001           14.6816            14.6817              0.0000    9063     8428   0.9051
# 244         3                  4               x4  1.6381              0.035              0.40             1.8570           15.2832            17.1401              0.1083    4532     4217   0.3069
# 231         3                  8               x8  1.7396              0.070              0.25             0.0782           15.3913            15.4695              0.0051    2266     2114   0.2152
# 351         4                  1               x1  1.4274              0.035              0.25             0.0002           16.7502            16.7504              0.0000   18126    17088   2.1668
# 333         4                  2               x2  1.5345              0.035              0.25             0.0042           16.9523            16.9564              0.0002    9063     8552   1.0301
# 321         4                  4               x4  1.6992              0.070              0.25             1.8519           13.7209            15.5728              0.1189    4532     4288   0.2319
# 290         4                  8               x8  1.7871              0.015              0.40             3.2509           13.5070            16.7579              0.1940    2266     2145   0.1028
# 423         5                  1               x1  1.4279              0.035              0.25             0.0685           16.4091            16.4776              0.0042   18126    17760   2.1667
# 408         5                  2               x2  1.5195              0.050              0.25             0.9145           13.5984            14.5129              0.0630    9063     8881   0.7939
# 393         5                  4               x4  1.6558              0.070              0.25             1.4997           12.7222            14.2219              0.1055    4532     4439   0.2585
# 369         5                  8               x8  1.7542              0.035              0.25             1.4900           13.2524            14.7424              0.1011    2266     2221   0.1694
# 487         6                  1               x1  1.3876              0.015              0.25             0.0000           14.7015            14.7015              0.0000   18126    18104   2.5115
# 484         6                  2               x2  1.4927              0.070              0.40             3.3112           10.1813            13.4925              0.2454    9063     9052   0.4682
# 460         6                  4               x4  1.6179              0.035              0.40             2.7568           11.2456            14.0024              0.1969    4532     4527   0.2063
# 445         6                  8               x8  1.6914              0.050              0.40             3.2768            9.9358            13.2126              0.2480    2266     2264   0.0891
# 574         7                  1               x1  1.4033              0.070              0.40             3.3171            9.6649            12.9819              0.2555   18126    18102   1.2753
# 556         7                  2               x2  1.4796              0.070              0.40             3.2346            9.7327            12.9673              0.2494    9063     9051   0.5106
# 535         7                  4               x4  1.6043              0.050              0.40             3.1242            9.8159            12.9401              0.2414    4532     4526   0.2046
# 506         7                  8               x8  1.7231              0.015              0.40             3.8327            9.4327            13.2654              0.2889    2266     2263   0.1009

# %%
# Compact stability diagnostics for the selected range pairs.
# A good multiscale explanation should not only lower loss; it should also choose separated
# range pairs and variance fractions with some stability across resolution.
if 'best_df' not in globals() or best_df.empty:
    best_df = pd.read_csv(OUT_DIR / f'{OUT_PREFIX}_best_by_hour_resolution.csv')

stability = (
    best_df
    .groupby('resolution_label')
    .agg(
        loss_mean=('loss', 'mean'),
        loss_sd=('loss', 'std'),
        range_short_median=('range_short_fixed', 'median'),
        range_long_median=('range_long_fixed', 'median'),
        short_fraction_mean=('est_short_fraction', 'mean'),
        short_fraction_sd=('est_short_fraction', 'std'),
        sigmasq_total_mean=('est_sigmasq_total', 'mean'),
    )
    .reset_index()
)
stability['resolution_label'] = pd.Categorical(
    stability['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
)
stability = stability.sort_values('resolution_label')
stability_path = OUT_DIR / f'{OUT_PREFIX}_stability_by_resolution.csv'
round_df(stability).to_csv(stability_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
print('Saved stability table:', stability_path)
display(round_df(stability))
# Out:
# Saved stability table: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_multiscale_column_rangegrid_sep3_nug2_050826_stability_by_resolution.csv
#   resolution_label  loss_mean  loss_sd  range_short_median  range_long_median  short_fraction_mean  short_fraction_sd  sigmasq_total_mean
# 3               x8     1.7049   0.0605               0.050              0.400               0.1926             0.0973             13.9752
# 2               x4     1.6033   0.0698               0.060              0.400               0.1550             0.0868             13.8176
# 1               x2     1.4900   0.0405               0.050              0.325               0.1270             0.1196             14.1798
# 0               x1     1.3954   0.0276               0.035              0.250               0.0842             0.1164             14.7099

# %%
# Helper: compare against the nugget-free sep3 run if that CSV exists.
base_path = OUT_DIR / 'real_pure_space_multiscale_column_rangegrid_sep3_050826_best_by_hour_resolution.csv'
this_path = OUT_DIR / f'{OUT_PREFIX}_best_by_hour_resolution.csv'

if base_path.exists() and this_path.exists():
    base = pd.read_csv(base_path).rename(columns={
        'loss': 'loss_nug0',
        'est_short_fraction': 'short_fraction_nug0',
        'est_sigmasq_short': 'sigmasq_short_nug0',
        'est_sigmasq_long': 'sigmasq_long_nug0',
        'range_short_fixed': 'range_short_nug0',
        'range_long_fixed': 'range_long_nug0',
    })
    this = pd.read_csv(this_path).rename(columns={
        'loss': 'loss_nug2',
        'est_short_fraction': 'short_fraction_nug2',
        'est_sigmasq_short': 'sigmasq_short_nug2',
        'est_sigmasq_long': 'sigmasq_long_nug2',
        'range_short_fixed': 'range_short_nug2',
        'range_long_fixed': 'range_long_nug2',
    })

    comp = this.merge(
        base,
        on=['hour_idx', 'resolution_stride', 'resolution_label'],
        suffixes=('', '_base')
    )

    comp['loss_delta_nug2_minus_nug0'] = comp['loss_nug2'] - comp['loss_nug0']
    comp['short_fraction_delta'] = comp['short_fraction_nug2'] - comp['short_fraction_nug0']

    comp_cols = [
        'hour_idx', 'resolution_label',
        'loss_nug0', 'loss_nug2', 'loss_delta_nug2_minus_nug0',
        'short_fraction_nug0', 'short_fraction_nug2', 'short_fraction_delta',
        'range_short_nug0', 'range_short_nug2',
        'range_long_nug0', 'range_long_nug2',
    ]

    comp_display = comp.sort_values(['hour_idx', 'resolution_stride'])[comp_cols]

    comp_path = OUT_DIR / f'{OUT_PREFIX}_vs_nug0_best_comparison.csv'
    round_df(comp_display).to_csv(comp_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
    print('Saved nugget comparison:', comp_path)
    display(round_df(comp_display))
else:
    print('Nugget-free comparison CSV not found yet; run baseline sep3 first if comparison is needed.')
# Out:
# Saved nugget comparison: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_multiscale_column_rangegrid_sep3_nug2_050826_vs_nug0_best_comparison.csv
#     hour_idx resolution_label  loss_nug0  loss_nug2  loss_delta_nug2_minus_nug0  short_fraction_nug0  short_fraction_nug2  short_fraction_delta  range_short_nug0  range_short_nug2  range_long_nug0  range_long_nug2
# 0          0               x1     1.4098     1.4119                      0.0021               0.2603               0.1912               -0.0691             0.015             0.035             0.25             0.70
# 1          0               x2     1.5408     1.5347                     -0.0061               0.2595               0.2596                0.0001             0.015             0.035             0.15             0.40
# 2          0               x4     1.4882     1.4876                     -0.0006               0.2773               0.2557               -0.0216             0.015             0.070             0.40             0.70
# 3          0               x8     1.6034     1.5997                     -0.0037               0.3211               0.2925               -0.0286             0.015             0.050             0.40             0.70
# 4          1               x1     1.3541     1.3558                      0.0017               0.4129               0.2231               -0.1898             0.050             0.070             0.70             0.70
# 5          1               x2     1.4109     1.4145                      0.0036               0.2307               0.1877               -0.0430             0.035             0.070             0.25             0.70
# 6          1               x4     1.5194     1.5179                     -0.0015               0.1953               0.0000               -0.1953             0.070             0.015             0.25             0.25
# 7          1               x8     1.6479     1.6447                     -0.0032               0.2879               0.2015               -0.0864             0.015             0.070             0.70             0.40
# 8          2               x1     1.3575     1.3600                      0.0025               0.1612               0.0000               -0.1612             0.035             0.070             0.70             0.25
# 9          2               x2     1.4610     1.4618                      0.0008               0.1797               0.0104               -0.1693             0.035             0.050             0.25             0.25
# 10         2               x4     1.6101     1.6053                     -0.0048               0.1675               0.2132                0.0457             0.015             0.070             0.25             0.40
# 11         2               x8     1.7108     1.6991                     -0.0117               0.1518               0.2099                0.0581             0.025             0.070             0.25             0.40
# 12         3               x1     1.3873     1.3896                      0.0023               0.1592               0.0000               -0.1592             0.035             0.015             0.25             0.25
# 13         3               x2     1.4846     1.4829                     -0.0017               0.1343               0.0000               -0.1343             0.035             0.035             0.25             0.25
# 14         3               x4     1.6470     1.6381                     -0.0089               0.1433               0.1083               -0.0350             0.015             0.035             0.25             0.40
# 15         3               x8     1.7542     1.7396                     -0.0146               0.1261               0.0051               -0.1210             0.015             0.070             0.25             0.25
# 16         4               x1     1.4239     1.4274                      0.0035               0.0809               0.0000               -0.0809             0.025             0.035             0.15             0.25
# 17         4               x2     1.5306     1.5345                      0.0039               0.3454               0.0002               -0.3452             0.070             0.035             0.70             0.25
# 18         4               x4     1.7036     1.6992                     -0.0044               0.0139               0.1189                0.1050             0.025             0.070             0.15             0.25
# 19         4               x8     1.7785     1.7871                      0.0086               0.2805               0.1940               -0.0865             0.015             0.015             0.40             0.40
# 20         5               x1     1.4237     1.4279                      0.0042               0.1411               0.0042               -0.1369             0.035             0.035             0.15             0.25
# 21         5               x2     1.5226     1.5195                     -0.0031               0.1089               0.0630               -0.0459             0.035             0.050             0.15             0.25
# 22         5               x4     1.6540     1.6558                      0.0018               0.2383               0.1055               -0.1328             0.025             0.070             0.40             0.25
# 23         5               x8     1.7656     1.7542                     -0.0114               0.0079               0.1011                0.0932             0.035             0.035             0.15             0.25
# 24         6               x1     1.3815     1.3876                      0.0061               0.2189               0.0000               -0.2189             0.035             0.015             0.25             0.25
# 25         6               x2     1.4922     1.4927                      0.0005               0.2097               0.2454                0.0357             0.025             0.070             0.25             0.40
# 26         6               x4     1.6173     1.6179                      0.0006               0.2834               0.1969               -0.0865             0.015             0.035             0.40             0.40
# 27         6               x8     1.6959     1.6914                     -0.0045               0.2325               0.2480                0.0155             0.015             0.050             0.25             0.40
# 28         7               x1     1.3974     1.4033                      0.0059               0.4196               0.2555               -0.1641             0.050             0.070             0.70             0.40
# 29         7               x2     1.4765     1.4796                      0.0031               0.2031               0.2494                0.0463             0.025             0.070             0.25             0.40
# 30         7               x4     1.6064     1.6043                     -0.0021               0.2625               0.2414               -0.0211             0.015             0.050             0.25             0.40
# 31         7               x8     1.7339     1.7231                     -0.0108               0.3087               0.2889               -0.0198             0.015             0.015             0.25             0.40

# %%
# Plot best variance split and selected ranges across resolution.
plot_df = best_df.copy()
plot_df['resolution_label'] = pd.Categorical(
    plot_df['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
)
plot_df = plot_df.sort_values(['hour_idx', 'resolution_label'])

fig, axes = plt.subplots(2, 2, figsize=(13, 8), constrained_layout=True)
plot_specs = [
    ('est_sigmasq_short', 'estimated short-scale variance'),
    ('est_sigmasq_long', 'estimated long-scale variance'),
    ('est_short_fraction', 'short-scale variance fraction'),
    ('loss', 'best Vecchia loss'),
]
for ax, (col, title) in zip(axes.ravel(), plot_specs):
    for hour_idx, sub in plot_df.groupby('hour_idx'):
        ax.plot(sub['resolution_label'].astype(str), sub[col], marker='o', linewidth=1.5, label=f'h{int(hour_idx)+1}')
    ax.set_title(title)
    ax.set_xlabel('resolution thinning')
    ax.grid(True, alpha=0.3)
axes.ravel()[-1].legend(ncol=2, fontsize=8, title='hour')
fig.suptitle('Two-scale fixed-range Column Vecchia: best grid-search fits', fontsize=14)
plot_path = OUT_DIR / f'{OUT_PREFIX}_best_variance_trajectories.png'
fig.savefig(plot_path, dpi=180, bbox_inches='tight')
print('Saved:', plot_path)
plt.show()

fig, axes = plt.subplots(1, 2, figsize=(12, 4), constrained_layout=True)
for ax, col, title in [
    (axes[0], 'range_short_fixed', 'selected short range'),
    (axes[1], 'range_long_fixed', 'selected long range'),
]:
    for hour_idx, sub in plot_df.groupby('hour_idx'):
        ax.plot(sub['resolution_label'].astype(str), sub[col], marker='o', linewidth=1.5, label=f'h{int(hour_idx)+1}')
    ax.set_title(title)
    ax.set_xlabel('resolution thinning')
    ax.grid(True, alpha=0.3)
axes[-1].legend(ncol=2, fontsize=8, title='hour')
fig.suptitle('Selected fixed range pair by resolution', fontsize=14)
range_plot_path = OUT_DIR / f'{OUT_PREFIX}_best_range_pair_trajectories.png'
fig.savefig(range_plot_path, dpi=180, bbox_inches='tight')
print('Saved:', range_plot_path)
plt.show()
# Out:
# Saved: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_multiscale_column_rangegrid_sep3_nug2_050826_best_variance_trajectories.png
# Saved: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_multiscale_column_rangegrid_sep3_nug2_050826_best_range_pair_trajectories.png

# %%
# Optional: loss table for one hour/resolution to inspect the range grid surface.
INSPECT_HOUR_IDX = HOUR_IDX_LIST[0]
INSPECT_STRIDE = 1
surf = all_df[(all_df['hour_idx'] == INSPECT_HOUR_IDX) & (all_df['resolution_stride'] == INSPECT_STRIDE)].copy()
if len(surf):
    loss_pivot = surf.pivot(index='range_short_fixed', columns='range_long_fixed', values='loss')
    shortfrac_pivot = surf.pivot(index='range_short_fixed', columns='range_long_fixed', values='est_short_fraction')
    print(f'Loss surface: hour={INSPECT_HOUR_IDX + 1}, resolution=x{INSPECT_STRIDE}')
    display(round_df(loss_pivot))
    print('Short variance fraction surface')
    display(round_df(shortfrac_pivot))
# Out:
# Loss surface: hour=1, resolution=x1
# range_long_fixed     0.15    0.25    0.40    0.70
# range_short_fixed
# 0.015              1.4598  1.4342  1.4228  1.4205
# 0.025              1.4540  1.4290  1.4179  1.4149
# 0.035              1.4480  1.4245  1.4145  1.4119
# 0.050                 NaN  1.4202  1.4126  1.4121
# 0.070                 NaN  1.4176  1.4136  1.4169
# Short variance fraction surface
# range_long_fixed     0.15    0.25    0.40    0.70
# range_short_fixed
# 0.015              0.0495  0.1124  0.1210  0.0972
# 0.025              0.0526  0.1386  0.1574  0.1354
# 0.035              0.0533  0.1687  0.2020  0.1912
# 0.050                 NaN  0.2133  0.2692  0.2850
# 0.070                 NaN  0.2724  0.3518  0.3877

# %% [markdown]
# ClusterB2 version: 4x4 target cluster with 2 previous cluster blocks, keeping the same spectral plotting workflow.
#
# # Pure-space spectral diagnostic: smooth=0.5, nugget-free vs nugget=0
#
# This notebook fits each hourly pure-space slice with isotropic ClusterB2 Vecchia under two variants:
#
# - `nugget_free`: estimate `sigmasq`, `range`, and `nugget`
# - `nugget0`: estimate `sigmasq` and `range`, with nugget fixed at zero
#
# Both use `smooth=0.5`, `mean_design='lat'`, and the same every-k resolution thinning used in the previous pure-space resolution checks.
#
# The spectral diagnostic compares the detrended empirical residual spectrum against a DW-style finite-sample expected periodogram from the fitted Matérn covariance plus nugget. The expected curve uses the same regular 2D thinning, mask, taper, zero-fill FFT normalization, and radial binning as the empirical periodogram; no median rescaling is used in the main diagnostic.

# %%
import gc
import importlib
import pickle
import sys
import time
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
from scipy.special import gamma, kv

LOCAL_SRC = '/Users/joonwonlee/Documents/GEMS_TCO-1/src'
AMAREL_SRC = '/home/jl2815/tco'
SRC = AMAREL_SRC if Path(AMAREL_SRC).exists() else LOCAL_SRC
if SRC not in sys.path:
    sys.path.insert(0, SRC)

from GEMS_TCO import configuration as config
from GEMS_TCO.data_loader import load_data_dynamic_processed
import GEMS_TCO.kernels_space_base_engine_052126 as kernels_space_base_engine_052126
import GEMS_TCO.kernels_space_iso_cluster_052426 as kernels_space_iso_cluster_052426

importlib.reload(kernels_space_base_engine_052126)
importlib.reload(kernels_space_iso_cluster_052426)

from GEMS_TCO.kernels_space_iso_cluster_052426 import (
    ClusterSpaceIsoTrendVecchiaFit,
    ClusterSpaceIsoNoNuggetTrendVecchiaFit,
)

DEVICE = torch.device('cpu')
DTYPE = torch.float64
ROUND_DECIMALS = 4

pd.set_option('display.max_columns', 140)
pd.set_option('display.width', 200)
print('SRC:', SRC)
print('device:', DEVICE)
# Out:
# SRC: /Users/joonwonlee/Documents/GEMS_TCO-1/src
# device: cpu

# %%
# Experiment config
YEAR = '2024'
MONTH = 7
DAY_IDX = 5                 # 0-based: 2 -> 2024-07-03
HOUR_IDX_LIST = list(range(8))
LAT_RANGE = [-3, 7]
LON_RANGE = [111, 131]

SMOOTH = 0.5
RESOLUTION_STRIDES = [8, 4, 2, 1]
MEAN_DESIGN = 'lat'

CLUSTER_SPEC = {
    'block_shape': (4, 4),
    'n_neighbor_blocks': 2,
    'target_chunk_size': 128,
    'min_target_points': 1,
}

VARIANTS = {
    'nugget_free': {
        'class': ClusterSpaceIsoTrendVecchiaFit,
        'model': 'ClusterSpaceIso_4x4_B2_exactloc',
        'kernel': 'cluster_space_iso_4x4_b2_exactloc',
        'p_labels': ['sigmasq', 'range', 'nugget'],
        'init': {'sigmasq': 13.0, 'range': 0.25, 'nugget': 2.5},
    },
    'nugget0': {
        'class': ClusterSpaceIsoNoNuggetTrendVecchiaFit,
        'model': 'ClusterSpaceIsoNoNugget_4x4_B2_exactloc',
        'kernel': 'cluster_space_iso_nugget0_4x4_b2_exactloc',
        'p_labels': ['sigmasq', 'range'],
        'init': {'sigmasq': 13.0, 'range': 0.25},
    },
}

LBFGS_LR = 1.0
LBFGS_STEPS_FULL = 8
LBFGS_EVAL = 20
LBFGS_HIST = 10
GRAD_TOL = 1e-5

RUN_FULL = True
RUN_SPECTRUM = True

PURE_SPACE_DIR = Path('/Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space')
OUT_DIR = PURE_SPACE_DIR / 'log'
OUT_DIR.mkdir(parents=True, exist_ok=True)
OUT_PREFIX = 'real_pure_space_spectral_s05_nugget_compare_clusterb2_111131_052426'

print('day:', f'{YEAR}{MONTH:02d}{DAY_IDX + 1:02d}')
print('hours:', HOUR_IDX_LIST)
print('strides:', RESOLUTION_STRIDES)
print('smooth:', SMOOTH)
print('variants:', list(VARIANTS))
# Out:
# day: 20240706
# hours: [0, 1, 2, 3, 4, 5, 6, 7]
# strides: [8, 4, 2, 1]
# smooth: 0.5
# variants: ['nugget_free', 'nugget0']

# %%
def phys_to_log(init, p_labels):
    return [np.log(init[p]) for p in p_labels]


def backmap(raw, p_labels, variant):
    est = {p: float(np.exp(raw[i])) for i, p in enumerate(p_labels)}
    if 'nugget' not in est:
        est['nugget'] = 0.0
    return est


def make_full_params(variant):
    spec = VARIANTS[variant]
    return [torch.tensor([v], device=DEVICE, dtype=DTYPE, requires_grad=True) for v in phys_to_log(spec['init'], spec['p_labels'])]


def count_valid(input_map):
    return int(sum(((~torch.isnan(v[:, 2])) & (~torch.isnan(v[:, 0])) & (~torch.isnan(v[:, 1]))).sum().item() for v in input_map.values()))


def space_diag(model):
    if hasattr(model, 'cluster_summary'):
        return dict(model.cluster_summary())

    groups = getattr(model, 'Batched_Groups', []) or []
    if not groups:
        return {'n_batches': 0, 'n_tails': 0, 'mean_m': 0.0, 'max_m': 0, 'largest_batch_n': 0}
    ns = np.asarray([int(g['target_idx'].shape[0]) for g in groups], dtype=np.int64)
    ms = np.asarray([int(g['max_m']) for g in groups], dtype=np.int64)
    return {
        'n_batches': int(len(groups)),
        'n_tails': int(ns.sum()),
        'mean_m': float(ms.mean()),
        'max_m': int(ms.max()),
        'largest_batch_n': int(ns.max()),
    }


def round_df(df, digits=ROUND_DECIMALS):
    out = df.copy()
    num_cols = out.select_dtypes(include=[np.number]).columns
    out[num_cols] = out[num_cols].round(digits)
    return out


def empty_cache():
    gc.collect()
    if DEVICE.type == 'cuda':
        torch.cuda.empty_cache()


def resolution_label(stride):
    return f'x{int(stride)}'


def expanded_bounds_tag(lat_range, lon_range):
    def fmt(v):
        return str(int(v)) if float(v).is_integer() else str(v).replace('.', 'p')
    return f"lat{fmt(lat_range[0])}to{fmt(lat_range[1])}_lon{fmt(lon_range[0])}to{fmt(lon_range[1])}"


def load_bounds_tagged_tco_grid_dicts(datapath, years_, months_, lat_range, lon_range):
    base = Path(datapath)
    tag = expanded_bounds_tag(lat_range, lon_range)
    coarse_dicts = {}
    for year in years_:
        yy = str(year)[2:]
        for month in months_:
            path = base / f'pickle_{year}' / f'tco_grid_{tag}_{yy}_{month:02d}.pkl'
            if not path.exists():
                raise FileNotFoundError(f'Expanded tco_grid not found: {path}')
            with open(path, 'rb') as f:
                loaded_map = pickle.load(f)
            for key, df in loaded_map.items():
                coarse_dicts[f'{year}_{month:02d}_{key}'] = df.reset_index(drop=True)
    if not coarse_dicts:
        raise ValueError('No expanded tco_grid data loaded')
    return coarse_dicts


def validate_bounds_coverage(coarse_dicts, lat_range, lon_range):
    first_key = sorted(coarse_dicts)[0]
    finite = coarse_dicts[first_key].dropna(subset=['ColumnAmountO3'])
    lat_min, lat_max = float(finite['Latitude'].min()), float(finite['Latitude'].max())
    lon_min, lon_max = float(finite['Longitude'].min()), float(finite['Longitude'].max())
    print('expanded coverage check:', first_key, 'lat', (round(lat_min, 4), round(lat_max, 4)), 'lon', (round(lon_min, 4), round(lon_max, 4)))
    tol = 0.25
    if lat_min > lat_range[0] + tol or lat_max < lat_range[1] - tol or lon_min > lon_range[0] + tol or lon_max < lon_range[1] - tol:
        raise ValueError(
            f'Loaded data do not cover requested expanded bounds {lat_range} x {lon_range}: '
            f'lat=({lat_min:.4f}, {lat_max:.4f}), lon=({lon_min:.4f}, {lon_max:.4f})'
        )

# %%
loader = load_data_dynamic_processed(config.mac_data_load_path)
df_map = load_bounds_tagged_tco_grid_dicts(
    config.mac_data_load_path,
    years_=[YEAR],
    months_=[MONTH],
    lat_range=LAT_RANGE,
    lon_range=LON_RANGE,
)
validate_bounds_coverage(df_map, LAT_RANGE, LON_RANGE)
ozone_vals = [
    pd.to_numeric(df['ColumnAmountO3'], errors='coerce').values
    for df in df_map.values()
]
raw_monthly_mean = float(np.nanmean(np.concatenate(ozone_vals))) if ozone_vals else 0.0
print(f'--- Global Monthly Mean for expanded {YEAR}-{MONTH}: {raw_monthly_mean:.4f} ---')
month_keys = sorted(df_map.keys())
day_keys = month_keys[DAY_IDX * 8:(DAY_IDX + 1) * 8]
if len(day_keys) != 8:
    raise ValueError(f'Day {DAY_IDX} has {len(day_keys)} slices, expected 8')

first_df = df_map[day_keys[0]].reset_index(drop=True)
grid_order = (
    first_df
    .assign(_orig_idx=np.arange(len(first_df)))
    .sort_values(['Longitude', 'Latitude', '_orig_idx'], kind='mergesort')['_orig_idx']
    .to_numpy(dtype=np.int64)
)
grid_coords_full = first_df.iloc[grid_order][['Latitude', 'Longitude']].to_numpy(dtype=np.float64)

# Full-grid topology used by both fitting thins and spectral diagnostics.
_lat_key = np.round(grid_coords_full[:, 0], 10)
_lon_key = np.round(grid_coords_full[:, 1], 10)
lat_vals = np.sort(np.unique(_lat_key))
lon_vals = np.sort(np.unique(_lon_key))
lat_to_row = {float(v): i for i, v in enumerate(lat_vals)}
lon_to_col = {float(v): i for i, v in enumerate(lon_vals)}
local_to_row = np.asarray([lat_to_row[float(v)] for v in _lat_key], dtype=np.int64)
local_to_col = np.asarray([lon_to_col[float(v)] for v in _lon_key], dtype=np.int64)
N_LAT, N_LON = len(lat_vals), len(lon_vals)
LAT_STEP = float(np.median(np.diff(lat_vals))) if N_LAT > 1 else 1.0
LON_STEP = float(np.median(np.diff(lon_vals))) if N_LON > 1 else 1.0

ANALYSIS_MONTHLY_MEAN = 0.0
print('raw monthly_mean:', round(raw_monthly_mean, 4), '(not subtracted; intercept handles the level)')
print('day keys:', day_keys[0], '...', day_keys[-1])
print('full grid:', grid_coords_full.shape)
print('unique lat/lon:', N_LAT, N_LON)
print('lat/lon step:', LAT_STEP, LON_STEP)
# Out:
# expanded coverage check: 2024_07_y24m07day01_hm00:56 lat (-2.988, 7.0) lon (111.029, 131.0)
# --- Global Monthly Mean for expanded 2024-7: 261.8370 ---
# raw monthly_mean: 261.837 (not subtracted; intercept handles the level)
# day keys: 2024_07_y24m07day06_hm00:56 ... 2024_07_y24m07day06_hm07:52
# full grid: (72504, 2)
# unique lat/lon: 228 318
# lat/lon step: 0.04400000000000004 0.06300000000000239

# %%
def load_hour_map(hour_idx):
    key = day_keys[int(hour_idx)]
    hour_df_map = {key: df_map[key]}
    hour_map, _ = loader.load_working_data(
        hour_df_map,
        monthly_mean=ANALYSIS_MONTHLY_MEAN,
        idx_for_datamap=[0, 1],
        ord_mm=grid_order,
        dtype=DTYPE,
        keep_ori=True,
    )
    return {k: v.to(DEVICE) for k, v in hour_map.items()}, key


def thin_hour_map(hour_map, stride):
    """Thin on the 2D regular grid, not by 1D every-k flattening.

    A stride of 8 means both latitude and longitude grid spacings are multiplied
    by 8. This makes the effective Nyquist interpretation coherent for spectra.
    """
    stride = int(stride)
    if stride <= 0:
        raise ValueError(f'stride must be positive, got {stride}')
    keep = (local_to_row % stride == 0) & (local_to_col % stride == 0)
    thin_idx = np.flatnonzero(keep).astype(np.int64)
    thin_map = {k: v[thin_idx].contiguous() for k, v in hour_map.items()}
    thin_grid = np.ascontiguousarray(grid_coords_full[thin_idx])
    return thin_map, thin_grid, thin_idx


def build_model(variant, input_map, grid_coords):
    spec = VARIANTS[variant]
    return spec['class'](
        smooth=SMOOTH,
        input_map=input_map,
        grid_coords=np.ascontiguousarray(grid_coords.astype(np.float64)),
        block_shape=CLUSTER_SPEC['block_shape'],
        n_neighbor_blocks=CLUSTER_SPEC['n_neighbor_blocks'],
        target_chunk_size=CLUSTER_SPEC['target_chunk_size'],
        min_target_points=CLUSTER_SPEC['min_target_points'],
        mean_design=MEAN_DESIGN,
    )


def make_base_row(variant, hour_idx, time_key, stride, n_grid, n_valid, pre_s, fit_s, loss, fit_iter, est, diag):
    spec = VARIANTS[variant]
    row = {
        'date_str': f'{YEAR}{MONTH:02d}{DAY_IDX + 1:02d}',
        'day_idx': DAY_IDX,
        'hour_idx': int(hour_idx),
        'time_key': str(time_key),
        'resolution_stride': int(stride),
        'resolution_label': resolution_label(stride),
        'variant': variant,
        'smooth': float(SMOOTH),
        'mean_design': MEAN_DESIGN,
        'fit_type': 'full',
        'model': spec['model'],
        'kernel': spec['kernel'],
        'coord_mode': '2D grid thinning by stride in both lat/lon, fixed thinned grid order; 4x4 cluster max-min ordering on cluster centroids; covariance on Source_Latitude/Source_Longitude',
        'loss': float(loss),
        'fit_iter_raw': int(fit_iter),
        'fit_steps_reported': int(fit_iter) + 1,
        'precompute_s': float(pre_s),
        'fit_s': float(fit_s),
        'total_s': float(pre_s + fit_s),
        'n_grid': int(n_grid),
        'n_valid': int(n_valid),
        'valid_fraction': float(n_valid / n_grid) if n_grid else np.nan,
        'est_sigmasq': float(est['sigmasq']),
        'est_range': float(est['range']),
        'est_nugget': float(est.get('nugget', 0.0)),
        **diag,
        'cluster_block_shape': '4x4',
        'cluster_neighbor_blocks': CLUSTER_SPEC['n_neighbor_blocks'],
        'total_conditioning_nominal': int(CLUSTER_SPEC['n_neighbor_blocks'] * np.prod(CLUSTER_SPEC['block_shape'])),
    }
    return row

# %%
def fit_full_variant(variant, hour_idx, stride):
    hour_map, time_key = load_hour_map(hour_idx)
    thin_map, thin_grid, _ = thin_hour_map(hour_map, stride)
    n_grid = int(thin_grid.shape[0])
    n_valid = count_valid(thin_map)
    print('\n' + '=' * 100)
    print(f'{variant} | smooth={SMOOTH} | hour={hour_idx + 1} | {time_key} | {resolution_label(stride)} | n_grid={n_grid:,} | n_valid={n_valid:,}')

    model = build_model(variant, thin_map, thin_grid)
    t_pre = time.time()
    model.precompute_conditioning_sets()
    pre_s = time.time() - t_pre
    diag = space_diag(model)

    params = make_full_params(variant)
    opt = model.set_optimizer(params, lr=LBFGS_LR, max_iter=LBFGS_EVAL, max_eval=LBFGS_EVAL, history_size=LBFGS_HIST)
    t_fit = time.time()
    out, fit_iter = model.fit_vecc_lbfgs(params, opt, max_steps=LBFGS_STEPS_FULL, grad_tol=GRAD_TOL)
    fit_s = time.time() - t_fit
    p_labels = VARIANTS[variant]['p_labels']
    est = backmap(out[:len(p_labels)], p_labels, variant)
    row = make_base_row(variant, hour_idx, time_key, stride, n_grid, n_valid, pre_s, fit_s, out[-1], fit_iter, est, diag)
    print('RESULT:', {k: round(v, 4) if isinstance(v, float) else v for k, v in row.items() if k in ['variant','resolution_label','loss','est_sigmasq','est_range','est_nugget','total_s']})

    del model, params, opt, hour_map, thin_map
    empty_cache()
    return row

# %%
fit_rows = []
if RUN_FULL:
    for variant in VARIANTS:
        for hour_idx in HOUR_IDX_LIST:
            for stride in RESOLUTION_STRIDES:
                fit_rows.append(fit_full_variant(variant, hour_idx, stride))
                tmp = round_df(pd.DataFrame(fit_rows))
                tmp.to_csv(OUT_DIR / f'{OUT_PREFIX}_full.csv', index=False, float_format=f'%.{ROUND_DECIMALS}f')

fit_df = pd.DataFrame(fit_rows)
full_path = OUT_DIR / f'{OUT_PREFIX}_full.csv'
round_df(fit_df).to_csv(full_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
print('Saved full fits:', full_path)
display(round_df(fit_df))

param_rows = []
for _, row in fit_df.iterrows():
    for p in ['sigmasq', 'range', 'nugget']:
        param_rows.append({
            'date_str': row['date_str'],
            'hour_idx': int(row['hour_idx']),
            'time_key': row['time_key'],
            'resolution_stride': int(row['resolution_stride']),
            'resolution_label': row['resolution_label'],
            'variant': row['variant'],
            'smooth': row['smooth'],
            'parameter': p,
            'estimate': row[f'est_{p}'],
            'loss': row['loss'],
            'n_grid': row['n_grid'],
            'n_valid': row['n_valid'],
        })
param_df = pd.DataFrame(param_rows)
param_path = OUT_DIR / f'{OUT_PREFIX}_param_table.csv'
round_df(param_df).to_csv(param_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
print('Saved param table:', param_path)
# Out:
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=1 | 2024_07_y24m07day06_hm00:56 | x8 | n_grid=1,160 | n_valid=1,090
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1090, m mean/med/max=25.2/28/32, target med/max=15/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.791363 / Max Grad: 1.59e-06 ---
# Converged: max_grad 1.59e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.254894710641528, 'range': 1.3665160655713189, 'nugget': 4.378117557277749}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.7914, 'total_s': 0.1318, 'est_sigmasq': 13.2549, 'est_range': 1.3665, 'est_nugget': 4.3781}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=1 | 2024_07_y24m07day06_hm00:56 | x4 | n_grid=4,560 | n_valid=4,295
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4295, m mean/med/max=27.1/30/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.640635 / Max Grad: 6.94e-06 ---
# Converged: max_grad 6.94e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.115447255542437, 'range': 1.2462831649276538, 'nugget': 4.618199341445058}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.6406, 'total_s': 0.2317, 'est_sigmasq': 14.1154, 'est_range': 1.2463, 'est_nugget': 4.6182}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=1 | 2024_07_y24m07day06_hm00:56 | x2 | n_grid=18,126 | n_valid=17,066
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1158, target_points=17066, m mean/med/max=29.0/31/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.687472 / Max Grad: 7.33e-06 ---
# Converged: max_grad 7.33e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.034113301928492, 'range': 1.2326649577461246, 'nugget': 7.0231024903729145}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.6875, 'total_s': 1.1133, 'est_sigmasq': 15.0341, 'est_range': 1.2327, 'est_nugget': 7.0231}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=1 | 2024_07_y24m07day06_hm00:56 | x1 | n_grid=72,504 | n_valid=68,157
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.3s. clusters=4560, max_points/block=16, target_blocks=4532, target_points=68157, m mean/med/max=29.9/32/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.433931 / Max Grad: 1.15e-05 ---
# --- Step 2/8 / Loss: 1.419248 / Max Grad: 1.15e-05 ---
# --- Step 3/8 / Loss: 1.419248 / Max Grad: 1.15e-05 ---
# --- Step 4/8 / Loss: 1.419248 / Max Grad: 1.15e-05 ---
# --- Step 5/8 / Loss: 1.419248 / Max Grad: 1.15e-05 ---
# --- Step 6/8 / Loss: 1.419248 / Max Grad: 1.15e-05 ---
# --- Step 7/8 / Loss: 1.419248 / Max Grad: 1.15e-05 ---
# --- Step 8/8 / Loss: 1.419248 / Max Grad: 1.15e-05 ---
# Final Pure-Space Params: {'sigmasq': 14.439737696152312, 'range': 0.7076585014639483, 'nugget': 4.148984754086255}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.4192, 'total_s': 3.8905, 'est_sigmasq': 14.4397, 'est_range': 0.7077, 'est_nugget': 4.149}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=2 | 2024_07_y24m07day06_hm01:56 | x8 | n_grid=1,160 | n_valid=1,101
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1101, m mean/med/max=26.0/29/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.850925 / Max Grad: 7.34e-06 ---
# Converged: max_grad 7.34e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.281348824656837, 'range': 2.6015769419367056, 'nugget': 6.78526458001463}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.8509, 'total_s': 0.1417, 'est_sigmasq': 14.2813, 'est_range': 2.6016, 'est_nugget': 6.7853}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=2 | 2024_07_y24m07day06_hm01:56 | x4 | n_grid=4,560 | n_valid=4,343
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4343, m mean/med/max=27.1/30/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.687063 / Max Grad: 3.58e-06 ---
# Converged: max_grad 3.58e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.876061471583954, 'range': 1.6201735109287785, 'nugget': 5.687478204491729}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.6871, 'total_s': 0.2305, 'est_sigmasq': 15.8761, 'est_range': 1.6202, 'est_nugget': 5.6875}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=2 | 2024_07_y24m07day06_hm01:56 | x2 | n_grid=18,126 | n_valid=17,265
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1159, target_points=17265, m mean/med/max=29.3/31/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.548262 / Max Grad: 3.82e-06 ---
# Converged: max_grad 3.82e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.970989643773757, 'range': 0.9098541884071955, 'nugget': 4.538593366574202}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.5483, 'total_s': 0.9348, 'est_sigmasq': 15.971, 'est_range': 0.9099, 'est_nugget': 4.5386}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=2 | 2024_07_y24m07day06_hm01:56 | x1 | n_grid=72,504 | n_valid=68,961
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.3s. clusters=4560, max_points/block=16, target_blocks=4535, target_points=68961, m mean/med/max=30.3/32/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.422252 / Max Grad: 2.33e-06 ---
# Converged: max_grad 2.33e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 16.494886096413513, 'range': 0.5369662794455629, 'nugget': 3.4798691224597094}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.4223, 'total_s': 2.6152, 'est_sigmasq': 16.4949, 'est_range': 0.537, 'est_nugget': 3.4799}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=3 | 2024_07_y24m07day06_hm02:56 | x8 | n_grid=1,160 | n_valid=1,111
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1111, m mean/med/max=26.1/29/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.938892 / Max Grad: 8.15e-07 ---
# Converged: max_grad 8.15e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.185753375644671, 'range': 1.659557189144405, 'nugget': 7.6727099097096865}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.9389, 'total_s': 0.112, 'est_sigmasq': 15.1858, 'est_range': 1.6596, 'est_nugget': 7.6727}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=3 | 2024_07_y24m07day06_hm02:56 | x4 | n_grid=4,560 | n_valid=4,356
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4356, m mean/med/max=27.3/30/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.712269 / Max Grad: 1.16e-06 ---
# Converged: max_grad 1.16e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 17.071076115159258, 'range': 1.4406511372661557, 'nugget': 5.678132047010589}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.7123, 'total_s': 0.2995, 'est_sigmasq': 17.0711, 'est_range': 1.4407, 'est_nugget': 5.6781}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=3 | 2024_07_y24m07day06_hm02:56 | x2 | n_grid=18,126 | n_valid=17,333
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1160, target_points=17333, m mean/med/max=29.5/32/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.624511 / Max Grad: 5.21e-07 ---
# Converged: max_grad 5.21e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 18.29860651408537, 'range': 0.8484507462698947, 'nugget': 5.221892754008002}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.6245, 'total_s': 0.9444, 'est_sigmasq': 18.2986, 'est_range': 0.8485, 'est_nugget': 5.2219}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=3 | 2024_07_y24m07day06_hm02:56 | x1 | n_grid=72,504 | n_valid=69,193
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.2s. clusters=4560, max_points/block=16, target_blocks=4533, target_points=69193, m mean/med/max=30.5/32/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.415530 / Max Grad: 2.85e-06 ---
# Converged: max_grad 2.85e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 19.17935022339156, 'range': 0.39553243418859313, 'nugget': 2.5187397802077105}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.4155, 'total_s': 2.1361, 'est_sigmasq': 19.1794, 'est_range': 0.3955, 'est_nugget': 2.5187}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=4 | 2024_07_y24m07day06_hm03:56 | x8 | n_grid=1,160 | n_valid=1,108
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1108, m mean/med/max=25.8/27/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.985424 / Max Grad: 3.80e-06 ---
# Converged: max_grad 3.80e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.003006130934597, 'range': 1.941033790326409, 'nugget': 9.845774067617723}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.9854, 'total_s': 0.1126, 'est_sigmasq': 15.003, 'est_range': 1.941, 'est_nugget': 9.8458}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=4 | 2024_07_y24m07day06_hm03:56 | x4 | n_grid=4,560 | n_valid=4,375
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4375, m mean/med/max=27.6/31/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.776427 / Max Grad: 3.70e-06 ---
# Converged: max_grad 3.70e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 17.50115495753146, 'range': 1.3143113755236904, 'nugget': 6.8454992220199555}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.7764, 'total_s': 0.3086, 'est_sigmasq': 17.5012, 'est_range': 1.3143, 'est_nugget': 6.8455}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=4 | 2024_07_y24m07day06_hm03:56 | x2 | n_grid=18,126 | n_valid=17,372
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1158, target_points=17372, m mean/med/max=29.5/32/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.610194 / Max Grad: 5.99e-06 ---
# Converged: max_grad 5.99e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 18.26296772330589, 'range': 0.709631640211865, 'nugget': 4.617788874078917}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.6102, 'total_s': 0.8502, 'est_sigmasq': 18.263, 'est_range': 0.7096, 'est_nugget': 4.6178}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=4 | 2024_07_y24m07day06_hm03:56 | x1 | n_grid=72,504 | n_valid=69,427
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.3s. clusters=4560, max_points/block=16, target_blocks=4528, target_points=69427, m mean/med/max=30.6/32/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.423520 / Max Grad: 7.27e-07 ---
# Converged: max_grad 7.27e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 19.85683359512302, 'range': 0.3377339526085059, 'nugget': 2.109816400408327}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.4235, 'total_s': 2.6819, 'est_sigmasq': 19.8568, 'est_range': 0.3377, 'est_nugget': 2.1098}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=5 | 2024_07_y24m07day06_hm04:52 | x8 | n_grid=1,160 | n_valid=1,109
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1109, m mean/med/max=25.9/28/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 2.009961 / Max Grad: 2.34e-04 ---
# --- Step 2/8 / Loss: 1.892234 / Max Grad: 3.56e-06 ---
# Converged: max_grad 3.56e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 16.42413013839429, 'range': 1.8001398558591548, 'nugget': 9.771791516510874}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.8922, 'total_s': 0.1381, 'est_sigmasq': 16.4241, 'est_range': 1.8001, 'est_nugget': 9.7718}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=5 | 2024_07_y24m07day06_hm04:52 | x4 | n_grid=4,560 | n_valid=4,362
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4362, m mean/med/max=27.7/31/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.805606 / Max Grad: 8.74e-06 ---
# Converged: max_grad 8.74e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 17.9253551609929, 'range': 1.2048814514314226, 'nugget': 7.164974618484899}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.8056, 'total_s': 0.2196, 'est_sigmasq': 17.9254, 'est_range': 1.2049, 'est_nugget': 7.165}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=5 | 2024_07_y24m07day06_hm04:52 | x2 | n_grid=18,126 | n_valid=17,370
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1158, target_points=17370, m mean/med/max=29.5/32/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.669694 / Max Grad: 1.59e-06 ---
# Converged: max_grad 1.59e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 19.86383981166769, 'range': 0.6538563549154796, 'nugget': 5.011214301591065}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.6697, 'total_s': 1.0082, 'est_sigmasq': 19.8638, 'est_range': 0.6539, 'est_nugget': 5.0112}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=5 | 2024_07_y24m07day06_hm04:52 | x1 | n_grid=72,504 | n_valid=69,444
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.2s. clusters=4560, max_points/block=16, target_blocks=4537, target_points=69444, m mean/med/max=30.5/32/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.462407 / Max Grad: 3.23e-06 ---
# Converged: max_grad 3.23e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 21.322189463449998, 'range': 0.3474271412011851, 'nugget': 2.364009523601291}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.4624, 'total_s': 2.3374, 'est_sigmasq': 21.3222, 'est_range': 0.3474, 'est_nugget': 2.364}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=6 | 2024_07_y24m07day06_hm05:52 | x8 | n_grid=1,160 | n_valid=1,099
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1099, m mean/med/max=25.4/28/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.934731 / Max Grad: 4.46e-05 ---
# --- Step 2/8 / Loss: 1.853909 / Max Grad: 6.24e-07 ---
# Converged: max_grad 6.24e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.508672606521, 'range': 1.2307627816959217, 'nugget': 7.898116211198211}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.8539, 'total_s': 0.2027, 'est_sigmasq': 14.5087, 'est_range': 1.2308, 'est_nugget': 7.8981}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=6 | 2024_07_y24m07day06_hm05:52 | x4 | n_grid=4,560 | n_valid=4,351
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4351, m mean/med/max=27.5/31/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.811520 / Max Grad: 2.83e-07 ---
# Converged: max_grad 2.83e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 16.602770064861854, 'range': 0.9754529080970402, 'nugget': 7.077974449144477}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.8115, 'total_s': 0.3285, 'est_sigmasq': 16.6028, 'est_range': 0.9755, 'est_nugget': 7.078}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=6 | 2024_07_y24m07day06_hm05:52 | x2 | n_grid=18,126 | n_valid=17,339
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1159, target_points=17339, m mean/med/max=29.5/31/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.677638 / Max Grad: 1.83e-07 ---
# Converged: max_grad 1.83e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 18.05876018617622, 'range': 0.5924836857691375, 'nugget': 5.177141257207814}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.6776, 'total_s': 0.9945, 'est_sigmasq': 18.0588, 'est_range': 0.5925, 'est_nugget': 5.1771}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=6 | 2024_07_y24m07day06_hm05:52 | x1 | n_grid=72,504 | n_valid=69,400
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.2s. clusters=4560, max_points/block=16, target_blocks=4534, target_points=69400, m mean/med/max=30.5/32/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.495375 / Max Grad: 2.49e-06 ---
# Converged: max_grad 2.49e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 19.685539945102384, 'range': 0.3188704469346524, 'nugget': 2.709641850176004}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.4954, 'total_s': 2.6315, 'est_sigmasq': 19.6855, 'est_range': 0.3189, 'est_nugget': 2.7096}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=7 | 2024_07_y24m07day06_hm06:52 | x8 | n_grid=1,160 | n_valid=1,101
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1101, m mean/med/max=25.6/29/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.945709 / Max Grad: 2.56e-07 ---
# Converged: max_grad 2.56e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.08303836820449, 'range': 0.8693806759043754, 'nugget': 7.605935373572147}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.9457, 'total_s': 0.1508, 'est_sigmasq': 14.083, 'est_range': 0.8694, 'est_nugget': 7.6059}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=7 | 2024_07_y24m07day06_hm06:52 | x4 | n_grid=4,560 | n_valid=4,345
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4345, m mean/med/max=27.6/30/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.832837 / Max Grad: 6.88e-06 ---
# Converged: max_grad 6.88e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.75787280165849, 'range': 0.7459388141030185, 'nugget': 7.358610899204818}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.8328, 'total_s': 0.2842, 'est_sigmasq': 14.7579, 'est_range': 0.7459, 'est_nugget': 7.3586}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=7 | 2024_07_y24m07day06_hm06:52 | x2 | n_grid=18,126 | n_valid=17,319
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1158, target_points=17319, m mean/med/max=29.4/31/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.675187 / Max Grad: 8.16e-06 ---
# Converged: max_grad 8.16e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 16.866672082259736, 'range': 0.5256529662888485, 'nugget': 5.05849210197565}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.6752, 'total_s': 0.9699, 'est_sigmasq': 16.8667, 'est_range': 0.5257, 'est_nugget': 5.0585}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=7 | 2024_07_y24m07day06_hm06:52 | x1 | n_grid=72,504 | n_valid=69,393
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.3s. clusters=4560, max_points/block=16, target_blocks=4543, target_points=69393, m mean/med/max=30.4/32/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.530255 / Max Grad: 3.25e-06 ---
# Converged: max_grad 3.25e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 18.346297471850537, 'range': 0.298450840400393, 'nugget': 3.101301384964771}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.5303, 'total_s': 2.3919, 'est_sigmasq': 18.3463, 'est_range': 0.2985, 'est_nugget': 3.1013}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=8 | 2024_07_y24m07day06_hm07:52 | x8 | n_grid=1,160 | n_valid=1,109
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1109, m mean/med/max=26.2/30/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.829487 / Max Grad: 1.86e-06 ---
# Converged: max_grad 1.86e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.751011234922379, 'range': 0.8138730280819597, 'nugget': 5.113629854796471}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.8295, 'total_s': 0.1434, 'est_sigmasq': 12.751, 'est_range': 0.8139, 'est_nugget': 5.1136}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=8 | 2024_07_y24m07day06_hm07:52 | x4 | n_grid=4,560 | n_valid=4,355
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4355, m mean/med/max=27.7/31/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.763516 / Max Grad: 2.68e-06 ---
# Converged: max_grad 2.68e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.120066227331014, 'range': 0.7389345760929619, 'nugget': 6.092515735155642}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.7635, 'total_s': 0.2867, 'est_sigmasq': 14.1201, 'est_range': 0.7389, 'est_nugget': 6.0925}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=8 | 2024_07_y24m07day06_hm07:52 | x2 | n_grid=18,126 | n_valid=17,385
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1160, target_points=17385, m mean/med/max=29.6/31/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.662297 / Max Grad: 5.69e-06 ---
# Converged: max_grad 5.69e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.17903014527758, 'range': 0.5807891469088834, 'nugget': 5.632775382165627}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.6623, 'total_s': 0.9986, 'est_sigmasq': 14.179, 'est_range': 0.5808, 'est_nugget': 5.6328}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=8 | 2024_07_y24m07day06_hm07:52 | x1 | n_grid=72,504 | n_valid=69,655
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.3s. clusters=4560, max_points/block=16, target_blocks=4559, target_points=69655, m mean/med/max=30.5/32/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.502172 / Max Grad: 1.18e-06 ---
# Converged: max_grad 1.18e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.280014723787572, 'range': 0.3092024907035609, 'nugget': 3.4254789147216087}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.5022, 'total_s': 2.9628, 'est_sigmasq': 15.28, 'est_range': 0.3092, 'est_nugget': 3.4255}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=1 | 2024_07_y24m07day06_hm00:56 | x8 | n_grid=1,160 | n_valid=1,090
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1090, m mean/med/max=25.2/28/32, target med/max=15/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.770788 / Max Grad: 4.70e-06 ---
# Converged: max_grad 4.70e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 17.264980208934205, 'range': 0.6569135502645088, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 1.7708, 'total_s': 0.0684, 'est_sigmasq': 17.265, 'est_range': 0.6569, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=1 | 2024_07_y24m07day06_hm00:56 | x4 | n_grid=4,560 | n_valid=4,295
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4295, m mean/med/max=27.1/30/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.619305 / Max Grad: 2.65e-06 ---
# Converged: max_grad 2.65e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 17.445996004964858, 'range': 0.3952723582796288, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.6193, 'total_s': 0.1449, 'est_sigmasq': 17.446, 'est_range': 0.3953, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=1 | 2024_07_y24m07day06_hm00:56 | x2 | n_grid=18,126 | n_valid=17,066
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1158, target_points=17066, m mean/med/max=29.0/31/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.880381 / Max Grad: 9.59e-06 ---
# Converged: max_grad 9.59e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 19.684180397835224, 'range': 0.1716158491354318, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 1.8804, 'total_s': 0.7723, 'est_sigmasq': 19.6842, 'est_range': 0.1716, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=1 | 2024_07_y24m07day06_hm00:56 | x1 | n_grid=72,504 | n_valid=68,157
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.2s. clusters=4560, max_points/block=16, target_blocks=4532, target_points=68157, m mean/med/max=29.9/32/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.760314 / Max Grad: 4.19e-06 ---
# Converged: max_grad 4.19e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 16.563775013488357, 'range': 0.12303837594960906, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 1.7603, 'total_s': 2.1584, 'est_sigmasq': 16.5638, 'est_range': 0.123, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=2 | 2024_07_y24m07day06_hm01:56 | x8 | n_grid=1,160 | n_valid=1,101
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1101, m mean/med/max=26.0/29/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.841848 / Max Grad: 8.68e-07 ---
# Converged: max_grad 8.68e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 19.272193640767995, 'range': 0.6258936795849058, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 1.8418, 'total_s': 0.0635, 'est_sigmasq': 19.2722, 'est_range': 0.6259, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=2 | 2024_07_y24m07day06_hm01:56 | x4 | n_grid=4,560 | n_valid=4,343
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4343, m mean/med/max=27.1/30/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.683616 / Max Grad: 2.68e-07 ---
# Converged: max_grad 2.68e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 19.3858443847731, 'range': 0.38532454438794245, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.6836, 'total_s': 0.201, 'est_sigmasq': 19.3858, 'est_range': 0.3853, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=2 | 2024_07_y24m07day06_hm01:56 | x2 | n_grid=18,126 | n_valid=17,265
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1159, target_points=17265, m mean/med/max=29.3/31/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.616329 / Max Grad: 7.89e-06 ---
# Converged: max_grad 7.89e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 18.770271871662988, 'range': 0.2357449910498664, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 1.6163, 'total_s': 0.6517, 'est_sigmasq': 18.7703, 'est_range': 0.2357, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=2 | 2024_07_y24m07day06_hm01:56 | x1 | n_grid=72,504 | n_valid=68,961
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.2s. clusters=4560, max_points/block=16, target_blocks=4535, target_points=68961, m mean/med/max=30.3/32/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.720960 / Max Grad: 7.75e-06 ---
# Converged: max_grad 7.75e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 18.189733319134678, 'range': 0.1420433867116584, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 1.721, 'total_s': 2.0282, 'est_sigmasq': 18.1897, 'est_range': 0.142, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=3 | 2024_07_y24m07day06_hm02:56 | x8 | n_grid=1,160 | n_valid=1,111
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1111, m mean/med/max=26.1/29/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.947319 / Max Grad: 1.02e-06 ---
# Converged: max_grad 1.02e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 22.37261266563968, 'range': 0.5818730012438366, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 1.9473, 'total_s': 0.0471, 'est_sigmasq': 22.3726, 'est_range': 0.5819, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=3 | 2024_07_y24m07day06_hm02:56 | x4 | n_grid=4,560 | n_valid=4,356
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4356, m mean/med/max=27.3/30/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.714041 / Max Grad: 1.17e-06 ---
# Converged: max_grad 1.17e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 20.90044538122882, 'range': 0.40060710077680495, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.714, 'total_s': 0.1338, 'est_sigmasq': 20.9004, 'est_range': 0.4006, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=3 | 2024_07_y24m07day06_hm02:56 | x2 | n_grid=18,126 | n_valid=17,333
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1160, target_points=17333, m mean/med/max=29.5/32/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.739321 / Max Grad: 2.00e-05 ---
# --- Step 2/8 / Loss: 1.641441 / Max Grad: 2.00e-05 ---
# --- Step 3/8 / Loss: 1.641441 / Max Grad: 2.00e-05 ---
# --- Step 4/8 / Loss: 1.641441 / Max Grad: 2.00e-05 ---
# --- Step 5/8 / Loss: 1.641441 / Max Grad: 2.00e-05 ---
# --- Step 6/8 / Loss: 1.641441 / Max Grad: 2.00e-05 ---
# --- Step 7/8 / Loss: 1.641441 / Max Grad: 2.00e-05 ---
# --- Step 8/8 / Loss: 1.641441 / Max Grad: 2.00e-05 ---
# Final Pure-Space Params: {'sigmasq': 21.550971485635024, 'range': 0.23201815481194035, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 1.6414, 'total_s': 1.2575, 'est_sigmasq': 21.551, 'est_range': 0.232, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=3 | 2024_07_y24m07day06_hm02:56 | x1 | n_grid=72,504 | n_valid=69,193
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.2s. clusters=4560, max_points/block=16, target_blocks=4533, target_points=69193, m mean/med/max=30.5/32/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.633803 / Max Grad: 1.70e-05 ---
# --- Step 2/8 / Loss: 1.434497 / Max Grad: 1.70e-05 ---
# --- Step 3/8 / Loss: 1.434497 / Max Grad: 1.70e-05 ---
# --- Step 4/8 / Loss: 1.434497 / Max Grad: 1.70e-05 ---
# --- Step 5/8 / Loss: 1.434497 / Max Grad: 1.70e-05 ---
# --- Step 6/8 / Loss: 1.434497 / Max Grad: 1.70e-05 ---
# --- Step 7/8 / Loss: 1.434497 / Max Grad: 1.70e-05 ---
# --- Step 8/8 / Loss: 1.434497 / Max Grad: 1.70e-05 ---
# Final Pure-Space Params: {'sigmasq': 20.254627164159878, 'range': 0.17444068217138614, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 1.4345, 'total_s': 3.1834, 'est_sigmasq': 20.2546, 'est_range': 0.1744, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=4 | 2024_07_y24m07day06_hm03:56 | x8 | n_grid=1,160 | n_valid=1,108
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1108, m mean/med/max=25.8/27/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 2.007391 / Max Grad: 2.52e-06 ---
# Converged: max_grad 2.52e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 23.65737936428552, 'range': 0.5123031356281199, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 2.0074, 'total_s': 0.0462, 'est_sigmasq': 23.6574, 'est_range': 0.5123, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=4 | 2024_07_y24m07day06_hm03:56 | x4 | n_grid=4,560 | n_valid=4,375
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4375, m mean/med/max=27.6/31/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.803436 / Max Grad: 5.55e-06 ---
# Converged: max_grad 5.55e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 22.211234378748532, 'range': 0.35208291045165774, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.8034, 'total_s': 0.1234, 'est_sigmasq': 22.2112, 'est_range': 0.3521, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=4 | 2024_07_y24m07day06_hm03:56 | x2 | n_grid=18,126 | n_valid=17,372
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1158, target_points=17372, m mean/med/max=29.5/32/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.712632 / Max Grad: 5.48e-06 ---
# Converged: max_grad 5.48e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 21.23479352710512, 'range': 0.23647916782835762, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 1.7126, 'total_s': 0.8684, 'est_sigmasq': 21.2348, 'est_range': 0.2365, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=4 | 2024_07_y24m07day06_hm03:56 | x1 | n_grid=72,504 | n_valid=69,427
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.2s. clusters=4560, max_points/block=16, target_blocks=4528, target_points=69427, m mean/med/max=30.6/32/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.634673 / Max Grad: 8.78e-07 ---
# Converged: max_grad 8.78e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 20.716776279775594, 'range': 0.1786225039835354, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 1.6347, 'total_s': 2.3721, 'est_sigmasq': 20.7168, 'est_range': 0.1786, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=5 | 2024_07_y24m07day06_hm04:52 | x8 | n_grid=1,160 | n_valid=1,109
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1109, m mean/med/max=25.9/28/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 2.037077 / Max Grad: 5.12e-07 ---
# Converged: max_grad 5.12e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 24.7398301441908, 'range': 0.5160898924289098, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 2.0371, 'total_s': 0.0677, 'est_sigmasq': 24.7398, 'est_range': 0.5161, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=5 | 2024_07_y24m07day06_hm04:52 | x4 | n_grid=4,560 | n_valid=4,362
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4362, m mean/med/max=27.7/31/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.843243 / Max Grad: 6.33e-06 ---
# Converged: max_grad 6.33e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 23.117153150256527, 'range': 0.3429776318423572, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.8432, 'total_s': 0.1503, 'est_sigmasq': 23.1172, 'est_range': 0.343, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=5 | 2024_07_y24m07day06_hm04:52 | x2 | n_grid=18,126 | n_valid=17,370
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1158, target_points=17370, m mean/med/max=29.5/32/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.811523 / Max Grad: 2.14e-05 ---
# --- Step 2/8 / Loss: 1.680492 / Max Grad: 2.14e-05 ---
# --- Step 3/8 / Loss: 1.680492 / Max Grad: 2.14e-05 ---
# --- Step 4/8 / Loss: 1.680492 / Max Grad: 2.14e-05 ---
# --- Step 5/8 / Loss: 1.680492 / Max Grad: 2.14e-05 ---
# --- Step 6/8 / Loss: 1.680492 / Max Grad: 2.14e-05 ---
# --- Step 7/8 / Loss: 1.680492 / Max Grad: 2.14e-05 ---
# --- Step 8/8 / Loss: 1.680492 / Max Grad: 2.14e-05 ---
# Final Pure-Space Params: {'sigmasq': 22.972057623309883, 'range': 0.22763035436278684, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 1.6805, 'total_s': 1.0859, 'est_sigmasq': 22.9721, 'est_range': 0.2276, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=5 | 2024_07_y24m07day06_hm04:52 | x1 | n_grid=72,504 | n_valid=69,444
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.3s. clusters=4560, max_points/block=16, target_blocks=4537, target_points=69444, m mean/med/max=30.5/32/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.722004 / Max Grad: 2.02e-06 ---
# Converged: max_grad 2.02e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 21.857979828319454, 'range': 0.17399183535616153, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 1.722, 'total_s': 2.3288, 'est_sigmasq': 21.858, 'est_range': 0.174, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=6 | 2024_07_y24m07day06_hm05:52 | x8 | n_grid=1,160 | n_valid=1,099
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1099, m mean/med/max=25.4/28/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.948081 / Max Grad: 4.23e-06 ---
# Converged: max_grad 4.23e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 21.518348071048948, 'range': 0.48578178514577564, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 1.9481, 'total_s': 0.0647, 'est_sigmasq': 21.5183, 'est_range': 0.4858, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=6 | 2024_07_y24m07day06_hm05:52 | x4 | n_grid=4,560 | n_valid=4,351
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4351, m mean/med/max=27.5/31/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.855508 / Max Grad: 9.01e-09 ---
# Converged: max_grad 9.01e-09 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 22.09826198986192, 'range': 0.3103657430772614, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.8555, 'total_s': 0.2362, 'est_sigmasq': 22.0983, 'est_range': 0.3104, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=6 | 2024_07_y24m07day06_hm05:52 | x2 | n_grid=18,126 | n_valid=17,339
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1159, target_points=17339, m mean/med/max=29.5/31/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.829689 / Max Grad: 5.41e-07 ---
# Converged: max_grad 5.41e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 21.720235929767068, 'range': 0.2074213373509414, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 1.8297, 'total_s': 0.7249, 'est_sigmasq': 21.7202, 'est_range': 0.2074, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=6 | 2024_07_y24m07day06_hm05:52 | x1 | n_grid=72,504 | n_valid=69,400
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.2s. clusters=4560, max_points/block=16, target_blocks=4534, target_points=69400, m mean/med/max=30.5/32/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.808305 / Max Grad: 1.54e-05 ---
# --- Step 2/8 / Loss: 1.507105 / Max Grad: 1.54e-05 ---
# --- Step 3/8 / Loss: 1.507105 / Max Grad: 1.54e-05 ---
# --- Step 4/8 / Loss: 1.507105 / Max Grad: 1.54e-05 ---
# --- Step 5/8 / Loss: 1.507105 / Max Grad: 1.54e-05 ---
# --- Step 6/8 / Loss: 1.507105 / Max Grad: 1.54e-05 ---
# --- Step 7/8 / Loss: 1.507105 / Max Grad: 1.54e-05 ---
# --- Step 8/8 / Loss: 1.507105 / Max Grad: 1.54e-05 ---
# Final Pure-Space Params: {'sigmasq': 20.773989561889106, 'range': 0.15196613904096734, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 1.5071, 'total_s': 3.2633, 'est_sigmasq': 20.774, 'est_range': 0.152, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=7 | 2024_07_y24m07day06_hm06:52 | x8 | n_grid=1,160 | n_valid=1,101
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1101, m mean/med/max=25.6/29/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.964542 / Max Grad: 2.35e-06 ---
# Converged: max_grad 2.35e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 21.60572759967398, 'range': 0.44232487651484725, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 1.9645, 'total_s': 0.0735, 'est_sigmasq': 21.6057, 'est_range': 0.4423, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=7 | 2024_07_y24m07day06_hm06:52 | x4 | n_grid=4,560 | n_valid=4,345
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4345, m mean/med/max=27.6/30/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.887306 / Max Grad: 2.83e-06 ---
# Converged: max_grad 2.83e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 21.47149421460016, 'range': 0.27563108505350264, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.8873, 'total_s': 0.1312, 'est_sigmasq': 21.4715, 'est_range': 0.2756, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=7 | 2024_07_y24m07day06_hm06:52 | x2 | n_grid=18,126 | n_valid=17,319
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1158, target_points=17319, m mean/med/max=29.4/31/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.824506 / Max Grad: 1.28e-05 ---
# --- Step 2/8 / Loss: 1.685640 / Max Grad: 1.28e-05 ---
# --- Step 3/8 / Loss: 1.685640 / Max Grad: 1.28e-05 ---
# --- Step 4/8 / Loss: 1.685640 / Max Grad: 1.28e-05 ---
# --- Step 5/8 / Loss: 1.685640 / Max Grad: 1.28e-05 ---
# --- Step 6/8 / Loss: 1.685640 / Max Grad: 1.28e-05 ---
# --- Step 7/8 / Loss: 1.685640 / Max Grad: 1.28e-05 ---
# --- Step 8/8 / Loss: 1.685640 / Max Grad: 1.28e-05 ---
# Final Pure-Space Params: {'sigmasq': 20.567278250429343, 'range': 0.19495221591315592, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 1.6856, 'total_s': 1.1095, 'est_sigmasq': 20.5673, 'est_range': 0.195, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=7 | 2024_07_y24m07day06_hm06:52 | x1 | n_grid=72,504 | n_valid=69,393
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.2s. clusters=4560, max_points/block=16, target_blocks=4543, target_points=69393, m mean/med/max=30.4/32/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.893737 / Max Grad: 1.46e-05 ---
# --- Step 2/8 / Loss: 1.537705 / Max Grad: 1.46e-05 ---
# --- Step 3/8 / Loss: 1.537705 / Max Grad: 1.46e-05 ---
# --- Step 4/8 / Loss: 1.537705 / Max Grad: 1.46e-05 ---
# --- Step 5/8 / Loss: 1.537705 / Max Grad: 1.46e-05 ---
# --- Step 6/8 / Loss: 1.537705 / Max Grad: 1.46e-05 ---
# --- Step 7/8 / Loss: 1.537705 / Max Grad: 1.46e-05 ---
# --- Step 8/8 / Loss: 1.537705 / Max Grad: 1.46e-05 ---
# Final Pure-Space Params: {'sigmasq': 19.926793823614577, 'range': 0.13464879691181608, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 1.5377, 'total_s': 3.5864, 'est_sigmasq': 19.9268, 'est_range': 0.1346, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=8 | 2024_07_y24m07day06_hm07:52 | x8 | n_grid=1,160 | n_valid=1,109
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1109, m mean/med/max=26.2/30/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.823867 / Max Grad: 3.96e-06 ---
# Converged: max_grad 3.96e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 17.633692049243855, 'range': 0.466763089342234, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 1.8239, 'total_s': 0.0712, 'est_sigmasq': 17.6337, 'est_range': 0.4668, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=8 | 2024_07_y24m07day06_hm07:52 | x4 | n_grid=4,560 | n_valid=4,355
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4355, m mean/med/max=27.7/31/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.793366 / Max Grad: 3.80e-06 ---
# Converged: max_grad 3.80e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 19.431467507169867, 'range': 0.2893464690324943, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.7934, 'total_s': 0.1503, 'est_sigmasq': 19.4315, 'est_range': 0.2893, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=8 | 2024_07_y24m07day06_hm07:52 | x2 | n_grid=18,126 | n_valid=17,385
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1160, target_points=17385, m mean/med/max=29.6/31/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.819073 / Max Grad: 4.85e-07 ---
# Converged: max_grad 4.85e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 18.505558185180007, 'range': 0.17145339911168886, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 1.8191, 'total_s': 0.7501, 'est_sigmasq': 18.5056, 'est_range': 0.1715, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=8 | 2024_07_y24m07day06_hm07:52 | x1 | n_grid=72,504 | n_valid=69,655
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.2s. clusters=4560, max_points/block=16, target_blocks=4559, target_points=69655, m mean/med/max=30.5/32/32, target med/max=16/16
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.868184 / Max Grad: 9.56e-07 ---
# Converged: max_grad 9.56e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 17.63462835803268, 'range': 0.1196524935126679, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 1.8682, 'total_s': 2.4157, 'est_sigmasq': 17.6346, 'est_range': 0.1197, 'est_nugget': 0.0}
# Saved full fits: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_expanded_lat-3to7_lon111to131_spectral_s05_nugget_compare_clusterb2_052426_full.csv
#     date_str  day_idx  hour_idx                     time_key  resolution_stride resolution_label      variant  smooth mean_design fit_type                                    model  \
# 0   20240706        5         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     0.5         lat     full          ClusterSpaceIso_4x4_B2_exactloc
# 1   20240706        5         0  2024_07_y24m07day06_hm00:56                  4               x4  nugget_free     0.5         lat     full          ClusterSpaceIso_4x4_B2_exactloc
# 2   20240706        5         0  2024_07_y24m07day06_hm00:56                  2               x2  nugget_free     0.5         lat     full          ClusterSpaceIso_4x4_B2_exactloc
# 3   20240706        5         0  2024_07_y24m07day06_hm00:56                  1               x1  nugget_free     0.5         lat     full          ClusterSpaceIso_4x4_B2_exactloc
# 4   20240706        5         1  2024_07_y24m07day06_hm01:56                  8               x8  nugget_free     0.5         lat     full          ClusterSpaceIso_4x4_B2_exactloc
# ..       ...      ...       ...                          ...                ...              ...          ...     ...         ...      ...                                      ...
# 59  20240706        5         6  2024_07_y24m07day06_hm06:52                  1               x1      nugget0     0.5         lat     full  ClusterSpaceIsoNoNugget_4x4_B2_exactloc
# 60  20240706        5         7  2024_07_y24m07day06_hm07:52                  8               x8      nugget0     0.5         lat     full  ClusterSpaceIsoNoNugget_4x4_B2_exactloc
# 61  20240706        5         7  2024_07_y24m07day06_hm07:52                  4               x4      nugget0     0.5         lat     full  ClusterSpaceIsoNoNugget_4x4_B2_exactloc
# 62  20240706        5         7  2024_07_y24m07day06_hm07:52                  2               x2      nugget0     0.5         lat     full  ClusterSpaceIsoNoNugget_4x4_B2_exactloc
# 63  20240706        5         7  2024_07_y24m07day06_hm07:52                  1               x1      nugget0     0.5         lat     full  ClusterSpaceIsoNoNugget_4x4_B2_exactloc
#
#                                        kernel                                         coord_mode    loss  fit_iter_raw  fit_steps_reported  precompute_s   fit_s  total_s  n_grid  n_valid  \
# 0           cluster_space_iso_4x4_b2_exactloc  2D grid thinning by stride in both lat/lon, fi...  1.7914             0                   1        0.0091  0.1227   0.1318    1160     1090
# 1           cluster_space_iso_4x4_b2_exactloc  2D grid thinning by stride in both lat/lon, fi...  1.6406             0                   1        0.0072  0.2245   0.2317    4560     4295
# 2           cluster_space_iso_4x4_b2_exactloc  2D grid thinning by stride in both lat/lon, fi...  1.6875             0                   1        0.0775  1.0357   1.1133   18126    17066
# 3           cluster_space_iso_4x4_b2_exactloc  2D grid thinning by stride in both lat/lon, fi...  1.4192             7                   8        0.2846  3.6059   3.8905   72504    68157
# 4           cluster_space_iso_4x4_b2_exactloc  2D grid thinning by stride in both lat/lon, fi...  1.8509             0                   1        0.0032  0.1385   0.1417    1160     1101
# ..                                        ...                                                ...     ...           ...                 ...           ...     ...      ...     ...      ...
# 59  cluster_space_iso_nugget0_4x4_b2_exactloc  2D grid thinning by stride in both lat/lon, fi...  1.5377             7                   8        0.2240  3.3624   3.5864   72504    69393
# 60  cluster_space_iso_nugget0_4x4_b2_exactloc  2D grid thinning by stride in both lat/lon, fi...  1.8239             0                   1        0.0025  0.0688   0.0712    1160     1109
# 61  cluster_space_iso_nugget0_4x4_b2_exactloc  2D grid thinning by stride in both lat/lon, fi...  1.7934             0                   1        0.0076  0.1427   0.1503    4560     4355
# 62  cluster_space_iso_nugget0_4x4_b2_exactloc  2D grid thinning by stride in both lat/lon, fi...  1.8191             0                   1        0.0604  0.6897   0.7501   18126    17385
# 63  cluster_space_iso_nugget0_4x4_b2_exactloc  2D grid thinning by stride in both lat/lon, fi...  1.8682             0                   1        0.2449  2.1709   2.4157   72504    69655
#
#     valid_fraction  est_sigmasq  est_range  est_nugget  n_clusters  block_shape_lat  block_shape_lon  n_neighbor_blocks  max_points_per_cluster  n_target_blocks  n_target_points  n_batches  \
# 0           0.9397      13.2549     1.3665      4.3781          80                4                4                  2                      16               80             1090          9
# 1           0.9419      14.1154     1.2463      4.6182         300                4                4                  2                      16              300             4295         13
# 2           0.9415      15.0341     1.2327      7.0231        1160                4                4                  2                      16             1158            17066         16
# 3           0.9400      14.4397     0.7077      4.1490        4560                4                4                  2                      16             4532            68157         16
# 4           0.9491      14.2813     2.6016      6.7853          80                4                4                  2                      16               80             1101          8
# ..             ...          ...        ...         ...         ...              ...              ...                ...                     ...              ...              ...        ...
# 59          0.9571      19.9268     0.1346      0.0000        4560                4                4                  2                      16             4543            69393         16
# 60          0.9560      17.6337     0.4668      0.0000          80                4                4                  2                      16               80             1109          8
# 61          0.9550      19.4315     0.2893      0.0000         300                4                4                  2                      16              300             4355          8
# 62          0.9591      18.5056     0.1715      0.0000        1160                4                4                  2                      16             1160            17385         12
# 63          0.9607      17.6346     0.1197      0.0000        4560                4                4                  2                      16             4559            69655         16
#
#     max_cond_points  median_cond_points  median_target_size  max_target_size  target_chunk_size cluster_block_shape  cluster_neighbor_blocks  total_conditioning_nominal
# 0                32                32.0                12.0               16                128                 4x4                        2                          32
# 1                32                32.0                10.0               16                128                 4x4                        2                          32
# 2                32                32.0                 8.5               16                128                 4x4                        2                          32
# 3                32                32.0                 8.5               16                128                 4x4                        2                          32
# 4                32                32.0                12.5               16                128                 4x4                        2                          32
# ..              ...                 ...                 ...              ...                ...                 ...                      ...                         ...
# 59               32                32.0                 8.5               16                128                 4x4                        2                          32
# 60               32                32.0                12.5               16                128                 4x4                        2                          32
# 61               32                32.0                12.5               16                128                 4x4                        2                          32
# 62               32                32.0                10.5               16                128                 4x4                        2                          32
# 63               32                32.0                 8.5               16                128                 4x4                        2                          32
#
# [64 rows x 41 columns]
# Saved param table: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_expanded_lat-3to7_lon111to131_spectral_s05_nugget_compare_clusterb2_052426_param_table.csv

# %%
# Full-fit results table.
plot_df = fit_df.copy()
plot_df['resolution_label'] = pd.Categorical(
    plot_df['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
)
plot_df = plot_df.sort_values(['variant', 'hour_idx', 'resolution_label'])

display(round_df(plot_df[['variant','hour_idx','resolution_stride','resolution_label','loss','est_sigmasq','est_range','est_nugget','n_grid','n_valid','total_s']]))
# Out:
#         variant  hour_idx  resolution_stride resolution_label    loss  est_sigmasq  est_range  est_nugget  n_grid  n_valid  total_s
# 32      nugget0         0                  8               x8  1.7708      17.2650     0.6569      0.0000    1160     1090   0.0684
# 33      nugget0         0                  4               x4  1.6193      17.4460     0.3953      0.0000    4560     4295   0.1449
# 34      nugget0         0                  2               x2  1.8804      19.6842     0.1716      0.0000   18126    17066   0.7723
# 35      nugget0         0                  1               x1  1.7603      16.5638     0.1230      0.0000   72504    68157   2.1584
# 36      nugget0         1                  8               x8  1.8418      19.2722     0.6259      0.0000    1160     1101   0.0635
# ..          ...       ...                ...              ...     ...          ...        ...         ...     ...      ...      ...
# 27  nugget_free         6                  1               x1  1.5303      18.3463     0.2985      3.1013   72504    69393   2.3919
# 28  nugget_free         7                  8               x8  1.8295      12.7510     0.8139      5.1136    1160     1109   0.1434
# 29  nugget_free         7                  4               x4  1.7635      14.1201     0.7389      6.0925    4560     4355   0.2867
# 30  nugget_free         7                  2               x2  1.6623      14.1790     0.5808      5.6328   18126    17385   0.9986
# 31  nugget_free         7                  1               x1  1.5022      15.2800     0.3092      3.4255   72504    69655   2.9628
#
# [64 rows x 11 columns]

# %%
# %%
# Partial-profile fits anchored at the full-fit estimates.
# sigma_only: estimate sigmasq only; keep range and nugget fixed at the full-fit estimates.
# range_only: estimate range only; keep sigmasq and nugget fixed at the full-fit estimates.
RUN_PROFILE_FITS = True
PROFILE_TYPES = ['sigma_only', 'range_only']
PROFILE_LBFGS_STEPS = 8
PROFILE_GRAD_TOL = 1e-5
PROFILE_EPS = 1e-10


def safe_log_value(x, eps=PROFILE_EPS):
    return float(np.log(max(float(x), eps)))


def log_tensor_value(x, like, eps=PROFILE_EPS):
    return torch.as_tensor(np.log(max(float(x), eps)), device=like.device, dtype=like.dtype)


def profile_param_tensor(variant, profile_type, theta, anchor):
    if variant == 'nugget_free':
        vals = {
            'sigmasq': log_tensor_value(anchor['sigmasq'], theta),
            'range': log_tensor_value(anchor['range'], theta),
            'nugget': log_tensor_value(anchor['nugget'], theta),
        }
        vals['sigmasq' if profile_type == 'sigma_only' else 'range'] = theta.reshape(())
        return torch.stack([vals['sigmasq'], vals['range'], vals['nugget']])
    if variant == 'nugget0':
        vals = {
            'sigmasq': log_tensor_value(anchor['sigmasq'], theta),
            'range': log_tensor_value(anchor['range'], theta),
        }
        vals['sigmasq' if profile_type == 'sigma_only' else 'range'] = theta.reshape(())
        return torch.stack([vals['sigmasq'], vals['range']])
    raise ValueError(f'Unknown variant: {variant}')


def profile_estimate_from_theta(profile_type, theta, anchor):
    est = dict(anchor)
    est['sigmasq' if profile_type == 'sigma_only' else 'range'] = float(torch.exp(theta.detach()).cpu().item())
    return est


def optimize_profile(model, variant, profile_type, anchor):
    free_name = 'sigmasq' if profile_type == 'sigma_only' else 'range'
    theta = torch.tensor([safe_log_value(anchor[free_name])], device=DEVICE, dtype=DTYPE, requires_grad=True)
    optimizer = torch.optim.LBFGS(
        [theta],
        lr=LBFGS_LR,
        max_iter=LBFGS_EVAL,
        max_eval=LBFGS_EVAL,
        history_size=LBFGS_HIST,
        line_search_fn='strong_wolfe',
    )

    last_loss = None
    last_iter = 0
    for i in range(PROFILE_LBFGS_STEPS):
        last_iter = i

        def closure():
            optimizer.zero_grad()
            params = profile_param_tensor(variant, profile_type, theta, anchor)
            loss = model.vecchia_batched_likelihood(params)
            loss.backward()
            return loss

        last_loss = optimizer.step(closure)
        with torch.no_grad():
            max_grad = abs(float(theta.grad.detach().item())) if theta.grad is not None else 0.0
            print(f'    {profile_type} step {i + 1}/{PROFILE_LBFGS_STEPS}: loss={float(last_loss.detach().item()):.6f}, grad={max_grad:.2e}')
            if max_grad < PROFILE_GRAD_TOL:
                break

    est = profile_estimate_from_theta(profile_type, theta, anchor)
    loss = float(last_loss.detach().cpu().item()) if isinstance(last_loss, torch.Tensor) else np.nan
    return est, loss, last_iter


def fit_partial_profiles_for_row(row):
    variant = str(row['variant'])
    hour_idx = int(row['hour_idx'])
    stride = int(row['resolution_stride'])
    anchor = {
        'sigmasq': float(row['est_sigmasq']),
        'range': float(row['est_range']),
        'nugget': float(row.get('est_nugget', 0.0)),
    }

    hour_map, time_key = load_hour_map(hour_idx)
    thin_map, thin_grid, _ = thin_hour_map(hour_map, stride)
    model = build_model(variant, thin_map, thin_grid)
    t_pre = time.time()
    model.precompute_conditioning_sets()
    pre_s = time.time() - t_pre
    diag = space_diag(model)

    out_rows = []
    for profile_type in PROFILE_TYPES:
        print('\n' + '-' * 90)
        print(f"profile={profile_type} | {variant} | hour={hour_idx + 1} | {resolution_label(stride)} | anchor={anchor}")
        t_fit = time.time()
        est, loss, fit_iter = optimize_profile(model, variant, profile_type, anchor)
        fit_s = time.time() - t_fit
        profile_row = dict(row)
        profile_row.update({
            'fit_type': profile_type,
            'profile_type': profile_type,
            'fixed_sigmasq': anchor['sigmasq'] if profile_type == 'range_only' else np.nan,
            'fixed_range': anchor['range'] if profile_type == 'sigma_only' else np.nan,
            'fixed_nugget': anchor['nugget'],
            'loss': float(loss),
            'fit_iter_raw': int(fit_iter),
            'fit_steps_reported': int(fit_iter) + 1,
            'precompute_s': float(pre_s),
            'fit_s': float(fit_s),
            'total_s': float(pre_s + fit_s),
            'est_sigmasq': float(est['sigmasq']),
            'est_range': float(est['range']),
            'est_nugget': float(est.get('nugget', 0.0)),
            **diag,
        })
        out_rows.append(profile_row)

    del model, hour_map, thin_map
    empty_cache()
    return out_rows


profile_path = OUT_DIR / f'{OUT_PREFIX}_partial_profile.csv'
if RUN_PROFILE_FITS:
    if 'fit_df' not in globals() or fit_df.empty:
        fit_df = pd.read_csv(OUT_DIR / f'{OUT_PREFIX}_full.csv')

    profile_rows = []
    for _, fit_row in fit_df.iterrows():
        profile_rows.extend(fit_partial_profiles_for_row(fit_row))
        tmp = round_df(pd.DataFrame(profile_rows))
        tmp.to_csv(profile_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')

    profile_df = pd.DataFrame(profile_rows)
    round_df(profile_df).to_csv(profile_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
else:
    profile_df = pd.read_csv(profile_path) if profile_path.exists() else pd.DataFrame()

print('Saved partial-profile fits:', profile_path)
display(round_df(profile_df[['variant','profile_type','hour_idx','resolution_stride','resolution_label','loss','est_sigmasq','est_range','est_nugget','fixed_sigmasq','fixed_range','fixed_nugget','n_grid','n_valid','total_s']]))

# %%
# Combined parameter trajectories:
# row 1: nugget0 full fit
# row 2: nugget_free full fit
# row 3: nugget0 partial profiles anchored at the full-fit estimates
if 'fit_df' not in globals() or fit_df.empty:
    fit_df = pd.read_csv(OUT_DIR / f'{OUT_PREFIX}_full.csv')
if 'profile_df' not in globals() or profile_df.empty:
    profile_df = pd.read_csv(OUT_DIR / f'{OUT_PREFIX}_partial_profile.csv')

full_plot_df = fit_df.copy()
full_plot_df['resolution_label'] = pd.Categorical(
    full_plot_df['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
)
full_plot_df = full_plot_df.sort_values(['variant', 'hour_idx', 'resolution_label'])

prof_plot_df = profile_df.copy()
prof_plot_df['resolution_label'] = pd.Categorical(
    prof_plot_df['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
)
prof_plot_df = prof_plot_df.sort_values(['variant', 'profile_type', 'hour_idx', 'resolution_label'])
prof_anchor_variant = 'nugget0'

combined_param_values = {
    'sigmasq': [full_plot_df['est_sigmasq'], prof_plot_df.loc[prof_plot_df['profile_type'] == 'sigma_only', 'est_sigmasq']],
    'range': [full_plot_df['est_range'], prof_plot_df.loc[prof_plot_df['profile_type'] == 'range_only', 'est_range']],
    'nugget': [full_plot_df['est_nugget'], prof_plot_df['fixed_nugget']],
}
combined_param_ylims = {}
for p, series_list in combined_param_values.items():
    vals = pd.concat([pd.to_numeric(s, errors='coerce') for s in series_list], ignore_index=True)
    vals = vals.replace([np.inf, -np.inf], np.nan).dropna()
    if vals.empty:
        combined_param_ylims[p] = (0.0, 1.0)
        continue
    lo, hi = float(vals.min()), float(vals.max())
    pad = max(abs(hi) * 0.05, 0.05) if np.isclose(lo, hi) else 0.08 * (hi - lo)
    if p == 'nugget':
        lo = min(0.0, lo)
    combined_param_ylims[p] = (lo - pad, hi + pad)

fig, axes = plt.subplots(3, 3, figsize=(15, 10.5), constrained_layout=True, sharex=True)
full_rows = [('nugget0', 'full: nugget fixed 0'), ('nugget_free', 'full: nugget free')]
params_to_plot = ['sigmasq', 'range', 'nugget']
for r, (variant, row_label) in enumerate(full_rows):
    sub_v = full_plot_df[full_plot_df['variant'] == variant]
    for c, p in enumerate(params_to_plot):
        ax = axes[r, c]
        for hour_idx, sub in sub_v.groupby('hour_idx'):
            ax.plot(sub['resolution_label'].astype(str), sub[f'est_{p}'], marker='o', linewidth=1.4, label=f'h{int(hour_idx)+1}')
        ax.set_title(f'{row_label}: {p}')
        ax.set_xlabel('resolution thinning')
        ax.set_ylabel('estimate')
        ax.set_ylim(*combined_param_ylims[p])
        ax.grid(True, alpha=0.3)

sigma_prof = prof_plot_df[(prof_plot_df['variant'] == prof_anchor_variant) & (prof_plot_df['profile_type'] == 'sigma_only')]
range_prof = prof_plot_df[(prof_plot_df['variant'] == prof_anchor_variant) & (prof_plot_df['profile_type'] == 'range_only')]

ax = axes[2, 0]
for hour_idx, sub in sigma_prof.groupby('hour_idx'):
    ax.plot(sub['resolution_label'].astype(str), sub['est_sigmasq'], marker='o', linewidth=1.4, label=f'h{int(hour_idx)+1}')
ax.set_title('profile: estimate sigmasq only\nrange+nugget fixed')
ax.set_xlabel('resolution thinning')
ax.set_ylabel('estimate')
ax.set_ylim(*combined_param_ylims['sigmasq'])
ax.grid(True, alpha=0.3)

ax = axes[2, 1]
for hour_idx, sub in range_prof.groupby('hour_idx'):
    ax.plot(sub['resolution_label'].astype(str), sub['est_range'], marker='o', linewidth=1.4, label=f'h{int(hour_idx)+1}')
ax.set_title('profile: estimate range only\nsigmasq+nugget fixed')
ax.set_xlabel('resolution thinning')
ax.set_ylabel('estimate')
ax.set_ylim(*combined_param_ylims['range'])
ax.grid(True, alpha=0.3)

ax = axes[2, 2]
for hour_idx, sub in sigma_prof.groupby('hour_idx'):
    ax.plot(sub['resolution_label'].astype(str), sub['fixed_nugget'], marker='o', linewidth=1.4, label=f'h{int(hour_idx)+1}')
ax.set_title('profile anchor: fixed nugget')
ax.set_xlabel('resolution thinning')
ax.set_ylabel('estimate')
ax.set_ylim(*combined_param_ylims['nugget'])
ax.grid(True, alpha=0.3)

axes[0, -1].legend(ncol=2, fontsize=8, title='hour')
fig.suptitle(f'Pure-space isotropic clusterB2 Vecchia, smooth={SMOOTH}: full and partial-profile parameter trajectories', fontsize=14)
param_plot_path = OUT_DIR / f'{OUT_PREFIX}_parameter_trajectories.png'
fig.savefig(param_plot_path, dpi=180, bbox_inches='tight')
print('Saved combined parameter plot:', param_plot_path)
plt.show()
# Out:
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1090, m mean/med/max=25.2/28/32, target med/max=15/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=1 | x8 | anchor={'sigmasq': 13.254894710641528, 'range': 1.3665160655713189, 'nugget': 4.378117557277749}
#     sigma_only step 1/8: loss=1.652135, grad=1.59e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=1 | x8 | anchor={'sigmasq': 13.254894710641528, 'range': 1.3665160655713189, 'nugget': 4.378117557277749}
#     range_only step 1/8: loss=1.652135, grad=5.48e-07
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4295, m mean/med/max=27.1/30/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=1 | x4 | anchor={'sigmasq': 14.115447255542437, 'range': 1.2462831649276538, 'nugget': 4.618199341445058}
#     sigma_only step 1/8: loss=1.571744, grad=3.79e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=1 | x4 | anchor={'sigmasq': 14.115447255542437, 'range': 1.2462831649276538, 'nugget': 4.618199341445058}
#     range_only step 1/8: loss=1.571744, grad=2.85e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1158, target_points=17066, m mean/med/max=29.0/31/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=1 | x2 | anchor={'sigmasq': 15.034113301928492, 'range': 1.2326649577461246, 'nugget': 7.0231024903729145}
#     sigma_only step 1/8: loss=1.642580, grad=2.64e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=1 | x2 | anchor={'sigmasq': 15.034113301928492, 'range': 1.2326649577461246, 'nugget': 7.0231024903729145}
#     range_only step 1/8: loss=1.642580, grad=1.26e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.2s. clusters=4560, max_points/block=16, target_blocks=4532, target_points=68157, m mean/med/max=29.9/32/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=1 | x1 | anchor={'sigmasq': 14.439737696152312, 'range': 0.7076585014639483, 'nugget': 4.148984754086255}
#     sigma_only step 1/8: loss=1.419248, grad=3.67e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=1 | x1 | anchor={'sigmasq': 14.439737696152312, 'range': 0.7076585014639483, 'nugget': 4.148984754086255}
#     range_only step 1/8: loss=1.419248, grad=4.47e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1101, m mean/med/max=26.0/29/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=2 | x8 | anchor={'sigmasq': 14.281348824656837, 'range': 2.6015769419367056, 'nugget': 6.78526458001463}
#     sigma_only step 1/8: loss=1.698127, grad=3.00e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=2 | x8 | anchor={'sigmasq': 14.281348824656837, 'range': 2.6015769419367056, 'nugget': 6.78526458001463}
#     range_only step 1/8: loss=1.698127, grad=1.82e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4343, m mean/med/max=27.1/30/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=2 | x4 | anchor={'sigmasq': 15.876061471583954, 'range': 1.6201735109287785, 'nugget': 5.687478204491729}
#     sigma_only step 1/8: loss=1.620811, grad=6.30e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=2 | x4 | anchor={'sigmasq': 15.876061471583954, 'range': 1.6201735109287785, 'nugget': 5.687478204491729}
#     range_only step 1/8: loss=1.620811, grad=1.43e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1159, target_points=17265, m mean/med/max=29.3/31/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=2 | x2 | anchor={'sigmasq': 15.970989643773757, 'range': 0.9098541884071955, 'nugget': 4.538593366574202}
#     sigma_only step 1/8: loss=1.525946, grad=3.82e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=2 | x2 | anchor={'sigmasq': 15.970989643773757, 'range': 0.9098541884071955, 'nugget': 4.538593366574202}
#     range_only step 1/8: loss=1.525946, grad=3.30e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.3s. clusters=4560, max_points/block=16, target_blocks=4535, target_points=68961, m mean/med/max=30.3/32/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=2 | x1 | anchor={'sigmasq': 16.494886096413513, 'range': 0.5369662794455629, 'nugget': 3.4798691224597094}
#     sigma_only step 1/8: loss=1.415619, grad=1.35e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=2 | x1 | anchor={'sigmasq': 16.494886096413513, 'range': 0.5369662794455629, 'nugget': 3.4798691224597094}
#     range_only step 1/8: loss=1.415619, grad=1.30e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1111, m mean/med/max=26.1/29/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=3 | x8 | anchor={'sigmasq': 15.185753375644671, 'range': 1.659557189144405, 'nugget': 7.6727099097096865}
#     sigma_only step 1/8: loss=1.809926, grad=2.53e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=3 | x8 | anchor={'sigmasq': 15.185753375644671, 'range': 1.659557189144405, 'nugget': 7.6727099097096865}
#     range_only step 1/8: loss=1.809926, grad=3.67e-08
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4356, m mean/med/max=27.3/30/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=3 | x4 | anchor={'sigmasq': 17.071076115159258, 'range': 1.4406511372661557, 'nugget': 5.678132047010589}
#     sigma_only step 1/8: loss=1.648695, grad=7.82e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=3 | x4 | anchor={'sigmasq': 17.071076115159258, 'range': 1.4406511372661557, 'nugget': 5.678132047010589}
#     range_only step 1/8: loss=1.648695, grad=5.02e-08
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1160, target_points=17333, m mean/med/max=29.5/32/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=3 | x2 | anchor={'sigmasq': 18.29860651408537, 'range': 0.8484507462698947, 'nugget': 5.221892754008002}
#     sigma_only step 1/8: loss=1.605685, grad=5.21e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=3 | x2 | anchor={'sigmasq': 18.29860651408537, 'range': 0.8484507462698947, 'nugget': 5.221892754008002}
#     range_only step 1/8: loss=1.605685, grad=2.18e-07
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.2s. clusters=4560, max_points/block=16, target_blocks=4533, target_points=69193, m mean/med/max=30.5/32/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=3 | x1 | anchor={'sigmasq': 19.17935022339156, 'range': 0.39553243418859313, 'nugget': 2.5187397802077105}
#     sigma_only step 1/8: loss=1.413330, grad=2.60e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=3 | x1 | anchor={'sigmasq': 19.17935022339156, 'range': 0.39553243418859313, 'nugget': 2.5187397802077105}
#     range_only step 1/8: loss=1.413330, grad=2.85e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1108, m mean/med/max=25.8/27/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=4 | x8 | anchor={'sigmasq': 15.003006130934597, 'range': 1.941033790326409, 'nugget': 9.845774067617723}
#     sigma_only step 1/8: loss=1.872264, grad=3.80e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=4 | x8 | anchor={'sigmasq': 15.003006130934597, 'range': 1.941033790326409, 'nugget': 9.845774067617723}
#     range_only step 1/8: loss=1.872264, grad=1.95e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4375, m mean/med/max=27.6/31/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=4 | x4 | anchor={'sigmasq': 17.50115495753146, 'range': 1.3143113755236904, 'nugget': 6.8454992220199555}
#     sigma_only step 1/8: loss=1.728414, grad=1.22e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=4 | x4 | anchor={'sigmasq': 17.50115495753146, 'range': 1.3143113755236904, 'nugget': 6.8454992220199555}
#     range_only step 1/8: loss=1.728414, grad=1.35e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1158, target_points=17372, m mean/med/max=29.5/32/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=4 | x2 | anchor={'sigmasq': 18.26296772330589, 'range': 0.709631640211865, 'nugget': 4.617788874078917}
#     sigma_only step 1/8: loss=1.595191, grad=2.81e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=4 | x2 | anchor={'sigmasq': 18.26296772330589, 'range': 0.709631640211865, 'nugget': 4.617788874078917}
#     range_only step 1/8: loss=1.595191, grad=5.99e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.2s. clusters=4560, max_points/block=16, target_blocks=4528, target_points=69427, m mean/med/max=30.6/32/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=4 | x1 | anchor={'sigmasq': 19.85683359512302, 'range': 0.3377339526085059, 'nugget': 2.109816400408327}
#     sigma_only step 1/8: loss=1.420707, grad=6.26e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=4 | x1 | anchor={'sigmasq': 19.85683359512302, 'range': 0.3377339526085059, 'nugget': 2.109816400408327}
#     range_only step 1/8: loss=1.420707, grad=6.28e-07
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1109, m mean/med/max=25.9/28/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=5 | x8 | anchor={'sigmasq': 16.42413013839429, 'range': 1.8001398558591548, 'nugget': 9.771791516510874}
#     sigma_only step 1/8: loss=1.892234, grad=2.78e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=5 | x8 | anchor={'sigmasq': 16.42413013839429, 'range': 1.8001398558591548, 'nugget': 9.771791516510874}
#     range_only step 1/8: loss=1.892234, grad=3.56e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4362, m mean/med/max=27.7/31/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=5 | x4 | anchor={'sigmasq': 17.9253551609929, 'range': 1.2048814514314226, 'nugget': 7.164974618484899}
#     sigma_only step 1/8: loss=1.760150, grad=8.55e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=5 | x4 | anchor={'sigmasq': 17.9253551609929, 'range': 1.2048814514314226, 'nugget': 7.164974618484899}
#     range_only step 1/8: loss=1.760150, grad=5.20e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1158, target_points=17370, m mean/med/max=29.5/32/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=5 | x2 | anchor={'sigmasq': 19.86383981166769, 'range': 0.6538563549154796, 'nugget': 5.011214301591065}
#     sigma_only step 1/8: loss=1.651155, grad=4.23e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=5 | x2 | anchor={'sigmasq': 19.86383981166769, 'range': 0.6538563549154796, 'nugget': 5.011214301591065}
#     range_only step 1/8: loss=1.651155, grad=1.59e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.2s. clusters=4560, max_points/block=16, target_blocks=4537, target_points=69444, m mean/med/max=30.5/32/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=5 | x1 | anchor={'sigmasq': 21.322189463449998, 'range': 0.3474271412011851, 'nugget': 2.364009523601291}
#     sigma_only step 1/8: loss=1.458107, grad=3.23e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=5 | x1 | anchor={'sigmasq': 21.322189463449998, 'range': 0.3474271412011851, 'nugget': 2.364009523601291}
#     range_only step 1/8: loss=1.458107, grad=4.24e-07
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1099, m mean/med/max=25.4/28/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=6 | x8 | anchor={'sigmasq': 14.508672606521, 'range': 1.2307627816959217, 'nugget': 7.898116211198211}
#     sigma_only step 1/8: loss=1.853909, grad=5.41e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=6 | x8 | anchor={'sigmasq': 14.508672606521, 'range': 1.2307627816959217, 'nugget': 7.898116211198211}
#     range_only step 1/8: loss=1.853909, grad=4.76e-07
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4351, m mean/med/max=27.5/31/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=6 | x4 | anchor={'sigmasq': 16.602770064861854, 'range': 0.9754529080970402, 'nugget': 7.077974449144477}
#     sigma_only step 1/8: loss=1.774340, grad=2.83e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=6 | x4 | anchor={'sigmasq': 16.602770064861854, 'range': 0.9754529080970402, 'nugget': 7.077974449144477}
#     range_only step 1/8: loss=1.774340, grad=2.48e-07
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1159, target_points=17339, m mean/med/max=29.5/31/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=6 | x2 | anchor={'sigmasq': 18.05876018617622, 'range': 0.5924836857691375, 'nugget': 5.177141257207814}
#     sigma_only step 1/8: loss=1.659668, grad=2.71e-08
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=6 | x2 | anchor={'sigmasq': 18.05876018617622, 'range': 0.5924836857691375, 'nugget': 5.177141257207814}
#     range_only step 1/8: loss=1.659668, grad=1.83e-07
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.2s. clusters=4560, max_points/block=16, target_blocks=4534, target_points=69400, m mean/med/max=30.5/32/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=6 | x1 | anchor={'sigmasq': 19.685539945102384, 'range': 0.3188704469346524, 'nugget': 2.709641850176004}
#     sigma_only step 1/8: loss=1.488995, grad=2.49e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=6 | x1 | anchor={'sigmasq': 19.685539945102384, 'range': 0.3188704469346524, 'nugget': 2.709641850176004}
#     range_only step 1/8: loss=1.488995, grad=2.18e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1101, m mean/med/max=25.6/29/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=7 | x8 | anchor={'sigmasq': 14.08303836820449, 'range': 0.8693806759043754, 'nugget': 7.605935373572147}
#     sigma_only step 1/8: loss=1.887308, grad=2.56e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=7 | x8 | anchor={'sigmasq': 14.08303836820449, 'range': 0.8693806759043754, 'nugget': 7.605935373572147}
#     range_only step 1/8: loss=1.887308, grad=1.77e-07
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4345, m mean/med/max=27.6/30/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=7 | x4 | anchor={'sigmasq': 14.75787280165849, 'range': 0.7459388141030185, 'nugget': 7.358610899204818}
#     sigma_only step 1/8: loss=1.804814, grad=6.88e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=7 | x4 | anchor={'sigmasq': 14.75787280165849, 'range': 0.7459388141030185, 'nugget': 7.358610899204818}
#     range_only step 1/8: loss=1.804814, grad=1.32e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1158, target_points=17319, m mean/med/max=29.4/31/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=7 | x2 | anchor={'sigmasq': 16.866672082259736, 'range': 0.5256529662888485, 'nugget': 5.05849210197565}
#     sigma_only step 1/8: loss=1.660291, grad=6.97e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=7 | x2 | anchor={'sigmasq': 16.866672082259736, 'range': 0.5256529662888485, 'nugget': 5.05849210197565}
#     range_only step 1/8: loss=1.660291, grad=7.35e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.3s. clusters=4560, max_points/block=16, target_blocks=4543, target_points=69393, m mean/med/max=30.4/32/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=7 | x1 | anchor={'sigmasq': 18.346297471850537, 'range': 0.298450840400393, 'nugget': 3.101301384964771}
#     sigma_only step 1/8: loss=1.519119, grad=3.89e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=7 | x1 | anchor={'sigmasq': 18.346297471850537, 'range': 0.298450840400393, 'nugget': 3.101301384964771}
#     range_only step 1/8: loss=1.519119, grad=6.76e-07
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1109, m mean/med/max=26.2/30/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=8 | x8 | anchor={'sigmasq': 12.751011234922379, 'range': 0.8138730280819597, 'nugget': 5.113629854796471}
#     sigma_only step 1/8: loss=1.773279, grad=4.77e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=8 | x8 | anchor={'sigmasq': 12.751011234922379, 'range': 0.8138730280819597, 'nugget': 5.113629854796471}
#     range_only step 1/8: loss=1.773279, grad=1.18e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4355, m mean/med/max=27.7/31/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=8 | x4 | anchor={'sigmasq': 14.120066227331014, 'range': 0.7389345760929619, 'nugget': 6.092515735155642}
#     sigma_only step 1/8: loss=1.740403, grad=1.08e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=8 | x4 | anchor={'sigmasq': 14.120066227331014, 'range': 0.7389345760929619, 'nugget': 6.092515735155642}
#     range_only step 1/8: loss=1.740403, grad=5.57e-07
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1160, target_points=17385, m mean/med/max=29.6/31/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=8 | x2 | anchor={'sigmasq': 14.17903014527758, 'range': 0.5807891469088834, 'nugget': 5.632775382165627}
#     sigma_only step 1/8: loss=1.644924, grad=2.63e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=8 | x2 | anchor={'sigmasq': 14.17903014527758, 'range': 0.5807891469088834, 'nugget': 5.632775382165627}
#     range_only step 1/8: loss=1.644924, grad=5.69e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.2s. clusters=4560, max_points/block=16, target_blocks=4559, target_points=69655, m mean/med/max=30.5/32/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=8 | x1 | anchor={'sigmasq': 15.280014723787572, 'range': 0.3092024907035609, 'nugget': 3.4254789147216087}
#     sigma_only step 1/8: loss=1.495070, grad=5.37e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=8 | x1 | anchor={'sigmasq': 15.280014723787572, 'range': 0.3092024907035609, 'nugget': 3.4254789147216087}
#     range_only step 1/8: loss=1.495070, grad=1.18e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1090, m mean/med/max=25.2/28/32, target med/max=15/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=1 | x8 | anchor={'sigmasq': 17.264980208934205, 'range': 0.6569135502645088, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.668472, grad=4.13e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=1 | x8 | anchor={'sigmasq': 17.264980208934205, 'range': 0.6569135502645088, 'nugget': 0.0}
#     range_only step 1/8: loss=1.668472, grad=4.70e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4295, m mean/med/max=27.1/30/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=1 | x4 | anchor={'sigmasq': 17.445996004964858, 'range': 0.3952723582796288, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.602865, grad=2.12e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=1 | x4 | anchor={'sigmasq': 17.445996004964858, 'range': 0.3952723582796288, 'nugget': 0.0}
#     range_only step 1/8: loss=1.602865, grad=2.65e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1158, target_points=17066, m mean/med/max=29.0/31/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=1 | x2 | anchor={'sigmasq': 19.684180397835224, 'range': 0.1716158491354318, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.711138, grad=9.06e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=1 | x2 | anchor={'sigmasq': 19.684180397835224, 'range': 0.1716158491354318, 'nugget': 0.0}
#     range_only step 1/8: loss=1.711138, grad=9.59e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.3s. clusters=4560, max_points/block=16, target_blocks=4532, target_points=68157, m mean/med/max=29.9/32/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=1 | x1 | anchor={'sigmasq': 16.563775013488357, 'range': 0.12303837594960906, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.483165, grad=1.78e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=1 | x1 | anchor={'sigmasq': 16.563775013488357, 'range': 0.12303837594960906, 'nugget': 0.0}
#     range_only step 1/8: loss=1.483165, grad=4.19e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1101, m mean/med/max=26.0/29/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=2 | x8 | anchor={'sigmasq': 19.272193640767995, 'range': 0.6258936795849058, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.737698, grad=8.68e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=2 | x8 | anchor={'sigmasq': 19.272193640767995, 'range': 0.6258936795849058, 'nugget': 0.0}
#     range_only step 1/8: loss=1.737698, grad=2.61e-07
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4343, m mean/med/max=27.1/30/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=2 | x4 | anchor={'sigmasq': 19.3858443847731, 'range': 0.38532454438794245, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.663666, grad=2.68e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=2 | x4 | anchor={'sigmasq': 19.3858443847731, 'range': 0.38532454438794245, 'nugget': 0.0}
#     range_only step 1/8: loss=1.663666, grad=2.51e-07
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1159, target_points=17265, m mean/med/max=29.3/31/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=2 | x2 | anchor={'sigmasq': 18.770271871662988, 'range': 0.2357449910498664, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.566497, grad=5.97e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=2 | x2 | anchor={'sigmasq': 18.770271871662988, 'range': 0.2357449910498664, 'nugget': 0.0}
#     range_only step 1/8: loss=1.566497, grad=7.89e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.3s. clusters=4560, max_points/block=16, target_blocks=4535, target_points=68961, m mean/med/max=30.3/32/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=2 | x1 | anchor={'sigmasq': 18.189733319134678, 'range': 0.1420433867116584, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.469867, grad=7.75e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=2 | x1 | anchor={'sigmasq': 18.189733319134678, 'range': 0.1420433867116584, 'nugget': 0.0}
#     range_only step 1/8: loss=1.469867, grad=2.43e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1111, m mean/med/max=26.1/29/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=3 | x8 | anchor={'sigmasq': 22.37261266563968, 'range': 0.5818730012438366, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.835701, grad=1.02e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=3 | x8 | anchor={'sigmasq': 22.37261266563968, 'range': 0.5818730012438366, 'nugget': 0.0}
#     range_only step 1/8: loss=1.835701, grad=3.77e-07
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4356, m mean/med/max=27.3/30/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=3 | x4 | anchor={'sigmasq': 20.90044538122882, 'range': 0.40060710077680495, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.686622, grad=1.17e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=3 | x4 | anchor={'sigmasq': 20.90044538122882, 'range': 0.40060710077680495, 'nugget': 0.0}
#     range_only step 1/8: loss=1.686622, grad=2.82e-07
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1160, target_points=17333, m mean/med/max=29.5/32/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=3 | x2 | anchor={'sigmasq': 21.550971485635024, 'range': 0.23201815481194035, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.641441, grad=2.00e-05
#     sigma_only step 2/8: loss=1.641441, grad=2.00e-05
#     sigma_only step 3/8: loss=1.641441, grad=2.00e-05
#     sigma_only step 4/8: loss=1.641441, grad=2.00e-05
#     sigma_only step 5/8: loss=1.641441, grad=2.00e-05
#     sigma_only step 6/8: loss=1.641441, grad=2.00e-05
#     sigma_only step 7/8: loss=1.641441, grad=2.00e-05
#     sigma_only step 8/8: loss=1.641441, grad=2.00e-05
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=3 | x2 | anchor={'sigmasq': 21.550971485635024, 'range': 0.23201815481194035, 'nugget': 0.0}
#     range_only step 1/8: loss=1.641441, grad=1.44e-05
#     range_only step 2/8: loss=1.641441, grad=1.44e-05
#     range_only step 3/8: loss=1.641441, grad=1.44e-05
#     range_only step 4/8: loss=1.641441, grad=1.44e-05
#     range_only step 5/8: loss=1.641441, grad=1.44e-05
#     range_only step 6/8: loss=1.641441, grad=1.44e-05
#     range_only step 7/8: loss=1.641441, grad=1.44e-05
#     range_only step 8/8: loss=1.641441, grad=1.44e-05
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.2s. clusters=4560, max_points/block=16, target_blocks=4533, target_points=69193, m mean/med/max=30.5/32/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=3 | x1 | anchor={'sigmasq': 20.254627164159878, 'range': 0.17444068217138614, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.434497, grad=1.44e-05
#     sigma_only step 2/8: loss=1.434497, grad=1.44e-05
#     sigma_only step 3/8: loss=1.434497, grad=1.44e-05
#     sigma_only step 4/8: loss=1.434497, grad=1.44e-05
#     sigma_only step 5/8: loss=1.434497, grad=1.44e-05
#     sigma_only step 6/8: loss=1.434497, grad=1.44e-05
#     sigma_only step 7/8: loss=1.434497, grad=1.44e-05
#     sigma_only step 8/8: loss=1.434497, grad=1.44e-05
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=3 | x1 | anchor={'sigmasq': 20.254627164159878, 'range': 0.17444068217138614, 'nugget': 0.0}
#     range_only step 1/8: loss=1.434497, grad=1.70e-05
#     range_only step 2/8: loss=1.434497, grad=1.70e-05
#     range_only step 3/8: loss=1.434497, grad=1.70e-05
#     range_only step 4/8: loss=1.434497, grad=1.70e-05
#     range_only step 5/8: loss=1.434497, grad=1.70e-05
#     range_only step 6/8: loss=1.434497, grad=1.70e-05
#     range_only step 7/8: loss=1.434497, grad=1.70e-05
#     range_only step 8/8: loss=1.434497, grad=1.70e-05
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1108, m mean/med/max=25.8/27/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=4 | x8 | anchor={'sigmasq': 23.65737936428552, 'range': 0.5123031356281199, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.902445, grad=1.28e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=4 | x8 | anchor={'sigmasq': 23.65737936428552, 'range': 0.5123031356281199, 'nugget': 0.0}
#     range_only step 1/8: loss=1.902445, grad=2.52e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4375, m mean/med/max=27.6/31/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=4 | x4 | anchor={'sigmasq': 22.211234378748532, 'range': 0.35208291045165774, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.763635, grad=5.55e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=4 | x4 | anchor={'sigmasq': 22.211234378748532, 'range': 0.35208291045165774, 'nugget': 0.0}
#     range_only step 1/8: loss=1.763635, grad=5.24e-07
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1158, target_points=17372, m mean/med/max=29.5/32/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=4 | x2 | anchor={'sigmasq': 21.23479352710512, 'range': 0.23647916782835762, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.625954, grad=2.04e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=4 | x2 | anchor={'sigmasq': 21.23479352710512, 'range': 0.23647916782835762, 'nugget': 0.0}
#     range_only step 1/8: loss=1.625954, grad=5.48e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.2s. clusters=4560, max_points/block=16, target_blocks=4528, target_points=69427, m mean/med/max=30.6/32/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=4 | x1 | anchor={'sigmasq': 20.716776279775594, 'range': 0.1786225039835354, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.434966, grad=7.28e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=4 | x1 | anchor={'sigmasq': 20.716776279775594, 'range': 0.1786225039835354, 'nugget': 0.0}
#     range_only step 1/8: loss=1.434966, grad=8.78e-07
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1109, m mean/med/max=25.9/28/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=5 | x8 | anchor={'sigmasq': 24.7398301441908, 'range': 0.5160898924289098, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.922169, grad=5.12e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=5 | x8 | anchor={'sigmasq': 24.7398301441908, 'range': 0.5160898924289098, 'nugget': 0.0}
#     range_only step 1/8: loss=1.922169, grad=4.58e-07
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4362, m mean/med/max=27.7/31/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=5 | x4 | anchor={'sigmasq': 23.117153150256527, 'range': 0.3429776318423572, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.792999, grad=3.44e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=5 | x4 | anchor={'sigmasq': 23.117153150256527, 'range': 0.3429776318423572, 'nugget': 0.0}
#     range_only step 1/8: loss=1.792999, grad=6.33e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1158, target_points=17370, m mean/med/max=29.5/32/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=5 | x2 | anchor={'sigmasq': 22.972057623309883, 'range': 0.22763035436278684, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.680492, grad=2.14e-05
#     sigma_only step 2/8: loss=1.680492, grad=2.14e-05
#     sigma_only step 3/8: loss=1.680492, grad=2.14e-05
#     sigma_only step 4/8: loss=1.680492, grad=2.14e-05
#     sigma_only step 5/8: loss=1.680492, grad=2.14e-05
#     sigma_only step 6/8: loss=1.680492, grad=2.14e-05
#     sigma_only step 7/8: loss=1.680492, grad=2.14e-05
#     sigma_only step 8/8: loss=1.680492, grad=2.14e-05
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=5 | x2 | anchor={'sigmasq': 22.972057623309883, 'range': 0.22763035436278684, 'nugget': 0.0}
#     range_only step 1/8: loss=1.680492, grad=1.69e-05
#     range_only step 2/8: loss=1.680492, grad=1.69e-05
#     range_only step 3/8: loss=1.680492, grad=1.69e-05
#     range_only step 4/8: loss=1.680492, grad=1.69e-05
#     range_only step 5/8: loss=1.680492, grad=1.69e-05
#     range_only step 6/8: loss=1.680492, grad=1.69e-05
#     range_only step 7/8: loss=1.680492, grad=1.69e-05
#     range_only step 8/8: loss=1.680492, grad=1.69e-05
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.2s. clusters=4560, max_points/block=16, target_blocks=4537, target_points=69444, m mean/med/max=30.5/32/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=5 | x1 | anchor={'sigmasq': 21.857979828319454, 'range': 0.17399183535616153, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.473437, grad=6.48e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=5 | x1 | anchor={'sigmasq': 21.857979828319454, 'range': 0.17399183535616153, 'nugget': 0.0}
#     range_only step 1/8: loss=1.473437, grad=2.02e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1099, m mean/med/max=25.4/28/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=6 | x8 | anchor={'sigmasq': 21.518348071048948, 'range': 0.48578178514577564, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.870619, grad=4.21e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=6 | x8 | anchor={'sigmasq': 21.518348071048948, 'range': 0.48578178514577564, 'nugget': 0.0}
#     range_only step 1/8: loss=1.870619, grad=4.23e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4351, m mean/med/max=27.5/31/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=6 | x4 | anchor={'sigmasq': 22.09826198986192, 'range': 0.3103657430772614, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.805182, grad=9.01e-09
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=6 | x4 | anchor={'sigmasq': 22.09826198986192, 'range': 0.3103657430772614, 'nugget': 0.0}
#     range_only step 1/8: loss=1.805182, grad=3.98e-09
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1159, target_points=17339, m mean/med/max=29.5/31/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=6 | x2 | anchor={'sigmasq': 21.720235929767068, 'range': 0.2074213373509414, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.689207, grad=5.41e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=6 | x2 | anchor={'sigmasq': 21.720235929767068, 'range': 0.2074213373509414, 'nugget': 0.0}
#     range_only step 1/8: loss=1.689207, grad=3.80e-07
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.3s. clusters=4560, max_points/block=16, target_blocks=4534, target_points=69400, m mean/med/max=30.5/32/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=6 | x1 | anchor={'sigmasq': 20.773989561889106, 'range': 0.15196613904096734, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.507105, grad=1.42e-05
#     sigma_only step 2/8: loss=1.507105, grad=1.42e-05
#     sigma_only step 3/8: loss=1.507105, grad=1.42e-05
#     sigma_only step 4/8: loss=1.507105, grad=1.42e-05
#     sigma_only step 5/8: loss=1.507105, grad=1.42e-05
#     sigma_only step 6/8: loss=1.507105, grad=1.42e-05
#     sigma_only step 7/8: loss=1.507105, grad=1.42e-05
#     sigma_only step 8/8: loss=1.507105, grad=1.42e-05
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=6 | x1 | anchor={'sigmasq': 20.773989561889106, 'range': 0.15196613904096734, 'nugget': 0.0}
#     range_only step 1/8: loss=1.507105, grad=1.54e-05
#     range_only step 2/8: loss=1.507105, grad=1.54e-05
#     range_only step 3/8: loss=1.507105, grad=1.54e-05
#     range_only step 4/8: loss=1.507105, grad=1.54e-05
#     range_only step 5/8: loss=1.507105, grad=1.54e-05
#     range_only step 6/8: loss=1.507105, grad=1.54e-05
#     range_only step 7/8: loss=1.507105, grad=1.54e-05
#     range_only step 8/8: loss=1.507105, grad=1.54e-05
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1101, m mean/med/max=25.6/29/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=7 | x8 | anchor={'sigmasq': 21.60572759967398, 'range': 0.44232487651484725, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.896870, grad=2.35e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=7 | x8 | anchor={'sigmasq': 21.60572759967398, 'range': 0.44232487651484725, 'nugget': 0.0}
#     range_only step 1/8: loss=1.896870, grad=1.10e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4345, m mean/med/max=27.6/30/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=7 | x4 | anchor={'sigmasq': 21.47149421460016, 'range': 0.27563108505350264, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.828790, grad=2.04e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=7 | x4 | anchor={'sigmasq': 21.47149421460016, 'range': 0.27563108505350264, 'nugget': 0.0}
#     range_only step 1/8: loss=1.828790, grad=2.83e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1158, target_points=17319, m mean/med/max=29.4/31/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=7 | x2 | anchor={'sigmasq': 20.567278250429343, 'range': 0.19495221591315592, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.685640, grad=1.28e-05
#     sigma_only step 2/8: loss=1.685640, grad=1.28e-05
#     sigma_only step 3/8: loss=1.685640, grad=1.28e-05
#     sigma_only step 4/8: loss=1.685640, grad=1.28e-05
#     sigma_only step 5/8: loss=1.685640, grad=1.28e-05
#     sigma_only step 6/8: loss=1.685640, grad=1.28e-05
#     sigma_only step 7/8: loss=1.685640, grad=1.28e-05
#     sigma_only step 8/8: loss=1.685640, grad=1.28e-05
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=7 | x2 | anchor={'sigmasq': 20.567278250429343, 'range': 0.19495221591315592, 'nugget': 0.0}
#     range_only step 1/8: loss=1.685640, grad=5.94e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.3s. clusters=4560, max_points/block=16, target_blocks=4543, target_points=69393, m mean/med/max=30.4/32/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=7 | x1 | anchor={'sigmasq': 19.926793823614577, 'range': 0.13464879691181608, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.537705, grad=9.57e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=7 | x1 | anchor={'sigmasq': 19.926793823614577, 'range': 0.13464879691181608, 'nugget': 0.0}
#     range_only step 1/8: loss=1.537705, grad=1.46e-05
#     range_only step 2/8: loss=1.537705, grad=1.46e-05
#     range_only step 3/8: loss=1.537705, grad=1.46e-05
#     range_only step 4/8: loss=1.537705, grad=1.46e-05
#     range_only step 5/8: loss=1.537705, grad=1.46e-05
#     range_only step 6/8: loss=1.537705, grad=1.46e-05
#     range_only step 7/8: loss=1.537705, grad=1.46e-05
#     range_only step 8/8: loss=1.537705, grad=1.46e-05
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=80, max_points/block=16, target_blocks=80, target_points=1109, m mean/med/max=26.2/30/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=8 | x8 | anchor={'sigmasq': 17.633692049243855, 'range': 0.466763089342234, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.780821, grad=3.96e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=8 | x8 | anchor={'sigmasq': 17.633692049243855, 'range': 0.466763089342234, 'nugget': 0.0}
#     range_only step 1/8: loss=1.780821, grad=3.03e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.0s. clusters=300, max_points/block=16, target_blocks=300, target_points=4355, m mean/med/max=27.7/31/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=8 | x4 | anchor={'sigmasq': 19.431467507169867, 'range': 0.2893464690324943, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.763875, grad=3.21e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=8 | x4 | anchor={'sigmasq': 19.431467507169867, 'range': 0.2893464690324943, 'nugget': 0.0}
#     range_only step 1/8: loss=1.763875, grad=3.80e-06
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.1s. clusters=1160, max_points/block=16, target_blocks=1160, target_points=17385, m mean/med/max=29.6/31/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=8 | x2 | anchor={'sigmasq': 18.505558185180007, 'range': 0.17145339911168886, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.679769, grad=1.74e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=8 | x2 | anchor={'sigmasq': 18.505558185180007, 'range': 0.17145339911168886, 'nugget': 0.0}
#     range_only step 1/8: loss=1.679769, grad=4.85e-07
# Pre-computing ClusterSpaceVecchia [block=4x4, B=2]... Done in 0.2s. clusters=4560, max_points/block=16, target_blocks=4559, target_points=69655, m mean/med/max=30.5/32/32, target med/max=16/16
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=8 | x1 | anchor={'sigmasq': 17.63462835803268, 'range': 0.1196524935126679, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.525085, grad=9.56e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=8 | x1 | anchor={'sigmasq': 17.63462835803268, 'range': 0.1196524935126679, 'nugget': 0.0}
#     range_only step 1/8: loss=1.525085, grad=6.97e-07
# Saved partial-profile fits: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_expanded_lat-3to7_lon111to131_spectral_s05_nugget_compare_clusterb2_052426_partial_profile.csv
#          variant profile_type  hour_idx  resolution_stride resolution_label    loss  est_sigmasq  est_range  est_nugget  fixed_sigmasq  fixed_range  fixed_nugget  n_grid  n_valid  total_s
# 0    nugget_free   sigma_only         0                  8               x8  1.6521      13.2549     1.3665      4.3781            NaN       1.3665        4.3781    1160     1090   0.0317
# 1    nugget_free   range_only         0                  8               x8  1.6521      13.2549     1.3665      4.3781        13.2549          NaN        4.3781    1160     1090   0.0162
# 2    nugget_free   sigma_only         0                  4               x4  1.5717      14.1154     1.2463      4.6182            NaN       1.2463        4.6182    4560     4295   0.0376
# 3    nugget_free   range_only         0                  4               x4  1.5717      14.1154     1.2463      4.6182        14.1154          NaN        4.6182    4560     4295   0.0325
# 4    nugget_free   sigma_only         0                  2               x2  1.6426      15.0341     1.2327      7.0231            NaN       1.2327        7.0231   18126    17066   0.3553
# ..           ...          ...       ...                ...              ...     ...          ...        ...         ...            ...          ...           ...     ...      ...      ...
# 123      nugget0   range_only         7                  4               x4  1.7639      19.4315     0.2893      0.0000        19.4315          NaN        0.0000    4560     4355   0.0232
# 124      nugget0   sigma_only         7                  2               x2  1.6798      18.5056     0.1715      0.0000            NaN       0.1715        0.0000   18126    17385   0.3827
# 125      nugget0   range_only         7                  2               x2  1.6798      18.5056     0.1715      0.0000        18.5056          NaN        0.0000   18126    17385   0.1580
# 126      nugget0   sigma_only         7                  1               x1  1.5251      17.6346     0.1197      0.0000            NaN       0.1197        0.0000   72504    69655   0.5696
# 127      nugget0   range_only         7                  1               x1  1.5251      17.6346     0.1197      0.0000        17.6346          NaN        0.0000   72504    69655   0.4295
#
# [128 rows x 15 columns]
# Saved combined parameter plot: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_expanded_lat-3to7_lon111to131_spectral_s05_nugget_compare_clusterb2_052426_parameter_trajectories.png

# %% [markdown]
# ## Spectral diagnostic
#
# The empirical spectrum uses the same thinned points as each fit. Residuals are computed after an OLS `intercept + lat` detrend, placed back onto the thinned 2D grid, tapered, zero-filled, FFTed, and radially averaged. The main theory curve is now a DW-style finite-sample expected periodogram: the fitted Matérn covariance plus nugget is passed through the same mask/taper/FFT normalization before radial averaging, without median scaling.
#
# The primary radial figure compares data to this expected periodogram. The median-matched Matérn curve is saved separately with `shape_diagnostic` in the filename for shape-only comparison. Raw continuous `f(omega)` is used only internally to form that scaled shape curve; raw `f(omega)` plots and CSV columns are not part of the output.

# %%
SPECTRAL_SMOOTH = SMOOTH
RADIAL_N_BINS = 70
RADIAL_QMAX = 0.985
APPLY_HANN = True
EPS = 1e-12

print('spectral full grid:', (N_LAT, N_LON), 'lat/lon step:', LAT_STEP, LON_STEP)


def trend_design(lat, lon, lat_center=None, lon_center=None):
    lat_center = np.nanmean(lat) if lat_center is None else float(lat_center)
    lon_center = np.nanmean(lon) if lon_center is None else float(lon_center)
    lat_c = lat - lat_center
    lon_c = lon - lon_center
    if MEAN_DESIGN in ('base', 'lat'):
        return np.column_stack([np.ones(len(lat)), lat_c])
    # Keep the residual trend matched to the fitted mean design.
    return np.column_stack([np.ones(len(lat)), lat_c, lon_c])


def detrended_residual_grid(hour_idx, stride):
    hour_map, time_key = load_hour_map(hour_idx)
    thin_map, thin_grid, thin_idx = thin_hour_map(hour_map, stride)
    arr = next(iter(thin_map.values())).detach().cpu().numpy()
    y = arr[:, 2].astype(float)
    lat = arr[:, 0].astype(float)
    lon = arr[:, 1].astype(float)
    valid = np.isfinite(y) & np.isfinite(lat) & np.isfinite(lon)
    if valid.sum() < 4:
        raise ValueError(f'Not enough valid points for hour={hour_idx}, stride={stride}')

    lat_center = np.nanmean(lat[valid])
    lon_center = np.nanmean(lon[valid])
    X = trend_design(lat[valid], lon[valid], lat_center=lat_center, lon_center=lon_center)
    beta, *_ = np.linalg.lstsq(X, y[valid], rcond=None)
    X_all = trend_design(lat, lon, lat_center=lat_center, lon_center=lon_center)
    resid = y - X_all @ beta

    rows_full = local_to_row[thin_idx]
    cols_full = local_to_col[thin_idx]
    row_keep = np.sort(np.unique(rows_full))
    col_keep = np.sort(np.unique(cols_full))
    row_pos = {int(r): i for i, r in enumerate(row_keep)}
    col_pos = {int(c): i for i, c in enumerate(col_keep)}

    grid = np.full((len(row_keep), len(col_keep)), np.nan, dtype=float)
    mask = np.zeros_like(grid, dtype=float)
    rr = np.asarray([row_pos[int(r)] for r in rows_full[valid]], dtype=np.int64)
    cc = np.asarray([col_pos[int(c)] for c in cols_full[valid]], dtype=np.int64)
    grid[rr, cc] = resid[valid]
    mask[rr, cc] = 1.0

    lat_axis = lat_vals[row_keep].astype(float)
    lon_axis = lon_vals[col_keep].astype(float)
    return grid, mask, time_key, int(valid.sum()), lat_axis, lon_axis


def masked_periodogram(grid, mask):
    obs = mask > 0
    if not np.any(obs):
        raise ValueError('No observed cells in spectral grid.')
    z = np.zeros_like(grid, dtype=float)
    z[obs] = grid[obs]
    win = np.outer(np.hanning(z.shape[0]), np.hanning(z.shape[1])) if APPLY_HANN else np.ones_like(z)
    zw = z * win
    norm = np.sum((mask * win) ** 2)
    norm = norm if norm > EPS else 1.0
    return np.abs(np.fft.fftshift(np.fft.fft2(zw))) ** 2 / norm


def matern_covariance_lag(sigmasq, range_, nugget, smooth, lag_lat, lag_lon):
    lag_lat = np.asarray(lag_lat, dtype=float)
    lag_lon = np.asarray(lag_lon, dtype=float)
    r = np.sqrt(lag_lat ** 2 + lag_lon ** 2) / max(float(range_), EPS)
    nu = float(smooth)
    if np.isclose(nu, 0.5):
        corr = np.exp(-r)
    elif np.isclose(nu, 1.5):
        corr = (1.0 + r) * np.exp(-r)
    else:
        corr = np.ones_like(r, dtype=float)
        positive = r > EPS
        if np.any(positive):
            scaled = np.sqrt(2.0 * nu) * r[positive]
            corr[positive] = (2.0 ** (1.0 - nu) / gamma(nu)) * (scaled ** nu) * kv(nu, scaled)
        corr = np.nan_to_num(corr, nan=0.0, posinf=0.0, neginf=0.0)
    cov = float(sigmasq) * corr
    zero_lag = (np.abs(lag_lat) < EPS) & (np.abs(lag_lon) < EPS)
    return cov + max(float(nugget), 0.0) * zero_lag


def taper_mask_autocorrelation(mask):
    mask = np.asarray(mask, dtype=float)
    win = np.outer(np.hanning(mask.shape[0]), np.hanning(mask.shape[1])) if APPLY_HANN else np.ones_like(mask)
    g = mask * win
    H = float(np.sum(g ** 2))
    if H <= EPS:
        raise ValueError('Taper/mask normalization is zero.')
    n1, n2 = g.shape
    G = np.fft.fft2(g, s=(2 * n1 - 1, 2 * n2 - 1))
    ac = np.fft.fftshift(np.fft.ifft2(G * np.conj(G)).real) / H
    return ac, H


def _autocorr_for_lags(ac, lag1, lag2, n1, n2):
    out = np.zeros_like(lag1, dtype=float)
    valid = (np.abs(lag1) <= n1 - 1) & (np.abs(lag2) <= n2 - 1)
    if np.any(valid):
        out[valid] = ac[(n1 - 1 + lag1[valid]).astype(int), (n2 - 1 + lag2[valid]).astype(int)]
    return out


def covariance_lag_kernel(sigmasq, range_, nugget, smooth, n1, n2, dlat, dlon):
    lag1_vals = np.arange(-(n1 - 1), n1, dtype=int)
    lag2_vals = np.arange(-(n2 - 1), n2, dtype=int)
    lag1, lag2 = np.meshgrid(lag1_vals, lag2_vals, indexing='ij')
    return matern_covariance_lag(sigmasq, range_, nugget, smooth, lag1 * dlat, lag2 * dlon)


def fft_convolve_same(values, kernel):
    values = np.asarray(values, dtype=float)
    kernel = np.asarray(kernel, dtype=float)
    out_shape = (values.shape[0] + kernel.shape[0] - 1, values.shape[1] + kernel.shape[1] - 1)
    conv = np.fft.ifft2(np.fft.fft2(values, s=out_shape) * np.fft.fft2(kernel, s=out_shape)).real
    start0 = kernel.shape[0] // 2
    start1 = kernel.shape[1] // 2
    return conv[start0:start0 + values.shape[0], start1:start1 + values.shape[1]]


def expected_periodogram_dw_style(sigmasq, range_, nugget, smooth, mask, lat_axis, lon_axis, project_mean=True):
    """Finite-sample expected periodogram for the same mask/taper/FFT normalization.

    This mirrors the debiased-Whittle idea on the regular FFT grid: multiply
    the fitted covariance at each grid lag by the taper/mask autocorrelation,
    then FFT the lag surface.
    It intentionally avoids median scaling and treats the nugget in covariance
    space before the periodogram operator is applied.  When project_mean=True,
    it also applies the same finite-sample OLS mean projection used to form the
    empirical residual grid, via a low-rank correction rather than an n x n C.
    """
    n1, n2 = mask.shape
    ac, _ = taper_mask_autocorrelation(mask)
    dlat = axis_step(lat_axis)
    dlon = axis_step(lon_axis)
    u1, u2 = np.meshgrid(np.arange(n1, dtype=int), np.arange(n2, dtype=int), indexing='ij')
    tilde_cov = np.zeros((n1, n2), dtype=float)
    for shift1 in (0, -n1):
        for shift2 in (0, -n2):
            lag1 = u1 + shift1
            lag2 = u2 + shift2
            ac_lag = _autocorr_for_lags(ac, lag1, lag2, n1, n2)
            if not np.any(ac_lag):
                continue
            cov_lag = matern_covariance_lag(sigmasq, range_, nugget, smooth, lag1 * dlat, lag2 * dlon)
            tilde_cov += cov_lag * ac_lag
    expected_no_projection = np.fft.fftshift(np.fft.fft2(tilde_cov).real)
    if not project_mean:
        return np.maximum(expected_no_projection, EPS)

    obs = mask > 0
    if obs.sum() <= 2:
        return np.maximum(expected_no_projection, EPS)
    win = np.outer(np.hanning(n1), np.hanning(n2)) if APPLY_HANN else np.ones((n1, n2), dtype=float)
    g = mask * win
    H = float(np.sum(g ** 2))
    lat_grid = np.repeat(np.asarray(lat_axis, dtype=float)[:, None], n2, axis=1)
    lon_grid = np.repeat(np.asarray(lon_axis, dtype=float)[None, :], n1, axis=0)
    X_flat = trend_design(lat_grid.ravel(), lon_grid.ravel(), lat_center=float(np.nanmean(lat_grid[obs])), lon_center=float(np.nanmean(lon_grid[obs])))
    X = X_flat.reshape(n1, n2, X_flat.shape[1])
    U = X * mask[..., None]
    XtX = np.einsum('ijp,ijq->pq', U, X)
    B = np.linalg.pinv(XtX)

    kernel = covariance_lag_kernel(sigmasq, range_, nugget, smooth, n1, n2, dlat, dlon)
    CU = np.empty_like(U, dtype=float)
    for p_idx in range(U.shape[2]):
        CU[..., p_idx] = fft_convolve_same(U[..., p_idx], kernel)
    S = np.einsum('ijp,ijq->pq', U, CU)

    h_fft = []
    c_fft = []
    for p_idx in range(U.shape[2]):
        h_fft.append(np.fft.fftshift(np.fft.fft2(g * X[..., p_idx])))
        c_fft.append(np.fft.fftshift(np.fft.fft2(g * CU[..., p_idx])))
    h_fft = np.stack(h_fft, axis=-1)
    c_fft = np.stack(c_fft, axis=-1)

    A_raw = expected_no_projection * H
    cross = np.einsum('...p,pq,...q->...', c_fft, B, np.conj(h_fft))
    mean_quad = np.einsum('...p,pq,...q->...', h_fft, B @ S @ B, np.conj(h_fft))
    expected_projected = (A_raw - 2.0 * np.real(cross) + np.real(mean_quad)) / H
    return np.maximum(expected_projected, EPS)


def axis_step(axis_vals):
    axis_vals = np.asarray(axis_vals, dtype=float)
    return float(np.median(np.diff(axis_vals))) if len(axis_vals) > 1 else 1.0


def frequency_grid_for_axes(lat_axis, lon_axis):
    dlat = axis_step(lat_axis)
    dlon = axis_step(lon_axis)
    fy = np.fft.fftshift(np.fft.fftfreq(len(lat_axis), d=dlat))
    fx = np.fft.fftshift(np.fft.fftfreq(len(lon_axis), d=dlon))
    omega_y = 2.0 * np.pi * fy
    omega_x = 2.0 * np.pi * fx
    OX, OY = np.meshgrid(omega_x, omega_y)
    k = np.sqrt(OX ** 2 + OY ** 2)
    return k, OX ** 2 + OY ** 2, omega_y, omega_x


K_FULL_RADIAL, OMEGA2_FULL, OMEGA_LAT_FULL, OMEGA_LON_FULL = frequency_grid_for_axes(lat_vals, lon_vals)
_positive_k = K_FULL_RADIAL[np.isfinite(K_FULL_RADIAL) & (K_FULL_RADIAL > 0)]
K_MAX_FULL = float(np.quantile(_positive_k, RADIAL_QMAX))
RADIAL_BINS = np.linspace(0.0, K_MAX_FULL, RADIAL_N_BINS + 1)
FULL_K_PLOT_MAX = K_MAX_FULL


def matern_spectrum_shape(sigmasq, range_, nugget, smooth, omega2):
    nu = float(smooth)
    alpha = 2.0 * nu / max(float(range_) ** 2, EPS)
    # Shape of the 2D Matérn spectral density. The missing normalizing constant
    # is harmless here because each theory curve is scaled to the empirical spectrum.
    matern = float(sigmasq) * (alpha + omega2) ** (-(nu + 1.0))
    return matern + max(float(nugget), 0.0)


def matern_directional_spectrum_shape(sigmasq, range_, nugget, smooth, omega):
    nu = float(smooth)
    alpha = 2.0 * nu / max(float(range_) ** 2, EPS)
    # A 1D lat/lon slice of a 2D Matérn field has spectral shape obtained by
    # integrating the 2D spectrum over the orthogonal frequency: exponent nu+1/2.
    matern = float(sigmasq) * (alpha + omega ** 2) ** (-(nu + 0.5))
    return matern + max(float(nugget), 0.0)


def radial_average(surface, k_radial, bins=RADIAL_BINS, k_max=K_MAX_FULL):
    vals = np.asarray(surface, dtype=float).ravel()
    kk = np.asarray(k_radial, dtype=float).ravel()
    good = np.isfinite(vals) & np.isfinite(kk) & (kk > 0) & (kk <= k_max)
    bin_idx = np.digitize(kk[good], bins) - 1
    rows = []
    vg = vals[good]
    kg = kk[good]
    for b in range(len(bins) - 1):
        m = bin_idx == b
        if not np.any(m):
            continue
        rows.append({
            'k_bin': b,
            'k_mid': 0.5 * (bins[b] + bins[b + 1]),
            'k_mean': float(np.nanmean(kg[m])),
            'spectrum': float(np.nanmean(vg[m])),
            'n_freq': int(m.sum()),
        })
    return pd.DataFrame(rows)


def directional_average_surface(surface, omega_lat, omega_lon, direction):
    vals = np.asarray(surface, dtype=float)
    if direction == 'lon':
        k_abs = np.broadcast_to(np.abs(np.asarray(omega_lon, dtype=float))[None, :], vals.shape)
    elif direction == 'lat':
        k_abs = np.broadcast_to(np.abs(np.asarray(omega_lat, dtype=float))[:, None], vals.shape)
    else:
        raise ValueError(direction)

    good = np.isfinite(vals) & np.isfinite(k_abs) & (k_abs > 0)
    rows = []
    for kval in np.sort(np.unique(np.round(k_abs[good], 12))):
        m = good & np.isclose(k_abs, kval)
        if not np.any(m):
            continue
        rows.append({
            'direction': direction,
            'k_mid': float(kval),
            'spectrum': float(np.nanmean(vals[m])),
            'n_freq': int(m.sum()),
        })
    return pd.DataFrame(rows)


def directional_periodogram(grid, mask, lat_axis, lon_axis, direction):
    obs = mask > 0
    z = np.zeros_like(grid, dtype=float)
    z[obs] = grid[obs]

    if direction == 'lon':
        n = grid.shape[1]
        omega = 2.0 * np.pi * np.fft.fftshift(np.fft.fftfreq(n, d=axis_step(lon_axis)))
        win = np.hanning(n) if APPLY_HANN else np.ones(n)
        powers = []
        for i in range(grid.shape[0]):
            m = mask[i, :]
            if m.sum() < 4:
                continue
            norm = np.sum((m * win) ** 2)
            if norm <= EPS:
                continue
            powers.append(np.abs(np.fft.fftshift(np.fft.fft(z[i, :] * win))) ** 2 / norm)
    elif direction == 'lat':
        n = grid.shape[0]
        omega = 2.0 * np.pi * np.fft.fftshift(np.fft.fftfreq(n, d=axis_step(lat_axis)))
        win = np.hanning(n) if APPLY_HANN else np.ones(n)
        powers = []
        for j in range(grid.shape[1]):
            m = mask[:, j]
            if m.sum() < 4:
                continue
            norm = np.sum((m * win) ** 2)
            if norm <= EPS:
                continue
            powers.append(np.abs(np.fft.fftshift(np.fft.fft(z[:, j] * win))) ** 2 / norm)
    else:
        raise ValueError(direction)

    if not powers:
        return pd.DataFrame(columns=['direction', 'k_mid', 'spectrum', 'n_freq'])
    p = np.nanmean(np.vstack(powers), axis=0)
    k_abs = np.abs(omega)
    rows = []
    for kval in np.sort(np.unique(np.round(k_abs[k_abs > 0], 12))):
        m = np.isclose(k_abs, kval)
        rows.append({
            'direction': direction,
            'k_mid': float(kval),
            'spectrum': float(np.nanmean(p[m])),
            'n_freq': int(m.sum() * len(powers)),
        })
    return pd.DataFrame(rows)


def scale_theory_to_data(data_vals, theory_vals, method='median'):
    d = np.asarray(data_vals, dtype=float)
    t = np.asarray(theory_vals, dtype=float)
    good = np.isfinite(d) & np.isfinite(t) & (d > 0) & (t > 0)
    if not good.any():
        return 1.0
    if method == 'geomean':
        return float(np.exp(np.mean(np.log(d[good]) - np.log(t[good]))))
    return float(np.nanmedian(d[good] / t[good]))
# Out:
# spectral full grid: (228, 318) lat/lon step: 0.04400000000000004 0.06300000000000239

# %%
if RUN_SPECTRUM:
    if 'fit_df' not in globals() or fit_df.empty:
        fit_df = pd.read_csv(OUT_DIR / f'{OUT_PREFIX}_full.csv')

    spectral_rows = []
    directional_rows = []
    for r in fit_df.itertuples(index=False):
        grid, mask, time_key, n_valid_spectrum, lat_axis, lon_axis = detrended_residual_grid(
            int(r.hour_idx), int(r.resolution_stride)
        )
        data_p = masked_periodogram(grid, mask)
        k_data, omega2_data, omega_lat_data, omega_lon_data = frequency_grid_for_axes(lat_axis, lon_axis)
        data_rad = radial_average(data_p, k_data).rename(columns={'spectrum': 'data_spectrum'})

        # Continuous Matérn shape, used only to form the scaled radial shape diagnostic.
        theory_p = matern_spectrum_shape(r.est_sigmasq, r.est_range, r.est_nugget, SPECTRAL_SMOOTH, OMEGA2_FULL)
        theory_rad = radial_average(theory_p, K_FULL_RADIAL).rename(columns={'spectrum': 'theory_spectrum_shape'})

        # DW-style finite-sample expected periodogram in the same FFT convention as data_p.
        theory_expected_p = expected_periodogram_dw_style(
            r.est_sigmasq, r.est_range, r.est_nugget, SPECTRAL_SMOOTH, mask, lat_axis, lon_axis
        )
        theory_expected_rad = radial_average(theory_expected_p, k_data).rename(columns={'spectrum': 'theory_spectrum_expected'})

        merged = theory_rad.merge(theory_expected_rad[['k_bin', 'theory_spectrum_expected']], on='k_bin', how='left')
        merged = merged.merge(data_rad[['k_bin', 'data_spectrum', 'n_freq']], on='k_bin', how='left', suffixes=('', '_data'))
        scale = scale_theory_to_data(merged['data_spectrum'], merged['theory_spectrum_shape'], method='median')
        merged['theory_spectrum_scaled'] = merged['theory_spectrum_shape'] * scale
        data_k_max = float(data_rad['k_mid'].max()) if not data_rad.empty else np.nan

        for m in merged.itertuples(index=False):
            spectral_rows.append({
                'date_str': r.date_str,
                'hour_idx': int(r.hour_idx),
                'time_key': time_key,
                'resolution_stride': int(r.resolution_stride),
                'resolution_label': r.resolution_label,
                'variant': r.variant,
                'fit_type': 'full',
                'smooth': float(r.smooth),
                'n_valid_spectrum': n_valid_spectrum,
                'est_sigmasq': float(r.est_sigmasq),
                'est_range': float(r.est_range),
                'est_nugget': float(r.est_nugget),
                'k_bin': int(m.k_bin),
                'k_mid': float(m.k_mid),
                'k_mean': float(m.k_mean),
                'n_freq': int(getattr(m, 'n_freq_data')) if pd.notna(getattr(m, 'n_freq_data', np.nan)) else 0,
                'data_k_max': data_k_max,
                'data_spectrum': float(m.data_spectrum) if pd.notna(m.data_spectrum) else np.nan,
                'theory_spectrum_expected': float(m.theory_spectrum_expected) if pd.notna(m.theory_spectrum_expected) else np.nan,
                'theory_spectrum_scaled': float(m.theory_spectrum_scaled),
                'theory_scale_to_data': scale,
            })

        for direction in ['lat', 'lon']:
            data_dir = directional_average_surface(data_p, omega_lat_data, omega_lon_data, direction).rename(columns={'spectrum': 'data_spectrum'})
            expected_dir = directional_average_surface(theory_expected_p, omega_lat_data, omega_lon_data, direction).rename(columns={'spectrum': 'theory_spectrum_expected'})
            data_dir['k_key'] = data_dir['k_mid'].round(10)
            expected_dir['k_key'] = expected_dir['k_mid'].round(10)
            merged_dir = data_dir.merge(
                expected_dir[['direction', 'k_key', 'theory_spectrum_expected']],
                on=['direction', 'k_key'], how='left',
            )
            merged_dir['theory_spectrum_shape'] = matern_directional_spectrum_shape(
                r.est_sigmasq, r.est_range, r.est_nugget, SPECTRAL_SMOOTH, merged_dir['k_mid'].to_numpy(dtype=float)
            )
            scale_dir = scale_theory_to_data(merged_dir['data_spectrum'], merged_dir['theory_spectrum_shape'], method='median')
            merged_dir['theory_spectrum_scaled'] = merged_dir['theory_spectrum_shape'] * scale_dir
            data_k_max_dir = float(data_dir['k_mid'].max()) if not data_dir.empty else np.nan
            for m in merged_dir.itertuples(index=False):
                directional_rows.append({
                    'date_str': r.date_str,
                    'hour_idx': int(r.hour_idx),
                    'time_key': time_key,
                    'resolution_stride': int(r.resolution_stride),
                    'resolution_label': r.resolution_label,
                    'variant': r.variant,
                    'fit_type': 'full',
                    'smooth': float(r.smooth),
                    'est_sigmasq': float(r.est_sigmasq),
                    'est_range': float(r.est_range),
                    'est_nugget': float(r.est_nugget),
                    'direction': direction,
                    'k_mid': float(m.k_mid),
                    'data_k_max': data_k_max_dir,
                    'data_spectrum': float(m.data_spectrum) if pd.notna(m.data_spectrum) else np.nan,
                    'theory_spectrum_expected': float(m.theory_spectrum_expected) if pd.notna(m.theory_spectrum_expected) else np.nan,
                    'theory_spectrum_scaled': float(m.theory_spectrum_scaled),
                    'theory_scale_to_data': scale_dir,
                })

    spectral_df = pd.DataFrame(spectral_rows)
    spectral_path = OUT_DIR / f'{OUT_PREFIX}_radial_spectrum.csv'
    spectral_df.to_csv(spectral_path, index=False)
    print('Saved radial spectrum:', spectral_path)
    display(round_df(spectral_df.head(12)))

    directional_spectral_df = pd.DataFrame(directional_rows)
    directional_spectral_path = OUT_DIR / f'{OUT_PREFIX}_directional_spectrum_lat_lon.csv'
    directional_spectral_df.to_csv(directional_spectral_path, index=False)
    print('Saved directional spectrum:', directional_spectral_path)
    display(round_df(directional_spectral_df.head(12)))
# Out:
# Saved radial spectrum: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_expanded_lat-3to7_lon111to131_spectral_s05_nugget_compare_clusterb2_052426_radial_spectrum.csv
#     date_str  hour_idx                     time_key  resolution_stride resolution_label      variant fit_type  smooth  n_valid_spectrum  est_sigmasq  est_range  est_nugget  k_bin    k_mid   k_mean  \
# 0   20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5              1090      13.2549     1.3665      4.3781      0   0.5726   0.7942
# 1   20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5              1090      13.2549     1.3665      4.3781      1   1.7178   1.8187
# 2   20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5              1090      13.2549     1.3665      4.3781      2   2.8631   2.9426
# 3   20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5              1090      13.2549     1.3665      4.3781      3   4.0083   4.0719
# 4   20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5              1090      13.2549     1.3665      4.3781      4   5.1535   5.2083
# 5   20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5              1090      13.2549     1.3665      4.3781      5   6.2987   6.3023
# 6   20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5              1090      13.2549     1.3665      4.3781      6   7.4439   7.4293
# 7   20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5              1090      13.2549     1.3665      4.3781      7   8.5892   8.6004
# 8   20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5              1090      13.2549     1.3665      4.3781      8   9.7344   9.7563
# 9   20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5              1090      13.2549     1.3665      4.3781      9  10.8796  10.8984
# 10  20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5              1090      13.2549     1.3665      4.3781     10  12.0248  12.0335
# 11  20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5              1090      13.2549     1.3665      4.3781     11  13.1700  13.1530
#
#     n_freq  data_k_max  data_spectrum  theory_spectrum_expected  theory_spectrum_scaled  theory_scale_to_data
# 0       20     10.8796       188.7421                  248.4661                 41.7082                2.5853
# 1       68     10.8796        51.5916                   62.4193                 16.6362                2.5853
# 2      104     10.8796        28.3166                   19.4408                 12.6211                2.5853
# 3      150     10.8796        11.9662                   11.2752                 11.8217                2.5853
# 4      200     10.8796         8.4763                    8.6594                 11.5596                2.5853
# 5      207     10.8796         6.9582                    7.6416                 11.4551                2.5853
# 6      168     10.8796         9.8411                    7.0549                 11.4022                2.5853
# 7      166     10.8796         7.3721                    6.8472                 11.3726                2.5853
# 8       70     10.8796        11.2169                    6.6053                 11.3557                2.5853
# 9        6     10.8796        25.2149                    6.5076                 11.3453                2.5853
# 10       0     10.8796            NaN                       NaN                 11.3385                2.5853
# 11       0     10.8796            NaN                       NaN                 11.3339                2.5853
# Saved directional spectrum: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_expanded_lat-3to7_lon111to131_spectral_s05_nugget_compare_clusterb2_052426_directional_spectrum_lat_lon.csv
#     date_str  hour_idx                     time_key  resolution_stride resolution_label      variant fit_type  smooth  est_sigmasq  est_range  est_nugget direction   k_mid  data_k_max  \
# 0   20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5      13.2549     1.3665      4.3781       lat  0.6155      8.6172
# 1   20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5      13.2549     1.3665      4.3781       lat  1.2310      8.6172
# 2   20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5      13.2549     1.3665      4.3781       lat  1.8465      8.6172
# 3   20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5      13.2549     1.3665      4.3781       lat  2.4621      8.6172
# 4   20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5      13.2549     1.3665      4.3781       lat  3.0776      8.6172
# 5   20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5      13.2549     1.3665      4.3781       lat  3.6931      8.6172
# 6   20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5      13.2549     1.3665      4.3781       lat  4.3086      8.6172
# 7   20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5      13.2549     1.3665      4.3781       lat  4.9241      8.6172
# 8   20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5      13.2549     1.3665      4.3781       lat  5.5396      8.6172
# 9   20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5      13.2549     1.3665      4.3781       lat  6.1552      8.6172
# 10  20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5      13.2549     1.3665      4.3781       lat  6.7707      8.6172
# 11  20240706         0  2024_07_y24m07day06_hm00:56                  8               x8  nugget_free     full     0.5      13.2549     1.3665      4.3781       lat  7.3862      8.6172
#
#     data_spectrum  theory_spectrum_expected  theory_spectrum_scaled  theory_scale_to_data
# 0         37.7419                   57.9600                 37.8491                2.0053
# 1         21.8012                   33.9679                 21.7396                2.0053
# 2         25.8983                   20.0261                 15.5169                2.0053
# 3         28.1411                   14.0358                 12.8086                2.0053
# 4         13.9887                   11.0877                 11.4357                2.0053
# 5         11.1090                    9.4734                 10.6548                2.0053
# 6          9.9815                    8.5215                 10.1712                2.0053
# 7          9.0787                    7.9044                  9.8521                2.0053
# 8          6.5645                    7.4860                  9.6309                2.0053
# 9          9.0096                    7.1902                  9.4714                2.0053
# 10        11.0678                    6.9693                  9.3527                2.0053
# 11        10.5514                    6.8340                  9.2620                2.0053

# %%
# %%
# Resolution-aware radial spectrum summaries.
# Data spectra are computed on the actual 2D thinned grid for each stride.
# Main theory curves use a DW-style finite-sample expected periodogram:
# fitted covariance + nugget, same mask/taper/FFT normalization, no median scaling.
if 'spectral_df' not in globals():
    spectral_df = pd.read_csv(OUT_DIR / f'{OUT_PREFIX}_radial_spectrum.csv')
required_spectrum_cols = {'theory_spectrum_expected', 'theory_spectrum_scaled'}
missing_spectrum_cols = required_spectrum_cols.difference(spectral_df.columns)
if missing_spectrum_cols:
    raise ValueError(f'spectral_df lacks {sorted(missing_spectrum_cols)}; rerun the RUN_SPECTRUM cell after this update.')

plot_spec = spectral_df.copy()
plot_spec['resolution_label'] = pd.Categorical(
    plot_spec['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
)

avg_low_data = (
    plot_spec.dropna(subset=['data_spectrum'])
    .groupby(['variant', 'resolution_label', 'resolution_stride', 'k_bin'], observed=False)
    .agg(
        k_mid=('k_mid', 'mean'),
        data_spectrum=('data_spectrum', 'mean'),
        n_hours=('hour_idx', 'nunique'),
        data_k_max=('data_k_max', 'mean'),
    )
    .reset_index()
)
low_path = OUT_DIR / f'{OUT_PREFIX}_radial_spectrum_lowfreq_only_avg.csv'
avg_low_data.to_csv(low_path, index=False)
print('Saved low-frequency data spectrum:', low_path)

avg_theory_full = (
    plot_spec
    .groupby(['variant', 'resolution_label', 'k_bin'], observed=False)
    .agg(
        k_mid=('k_mid', 'mean'),
        theory_spectrum_expected=('theory_spectrum_expected', 'mean'),
        theory_spectrum_scaled=('theory_spectrum_scaled', 'mean'),
    )
    .reset_index()
)

positive_spectrum_vals = pd.concat(
    [
        pd.to_numeric(avg_low_data['data_spectrum'], errors='coerce'),
        pd.to_numeric(avg_theory_full['theory_spectrum_expected'], errors='coerce'),
    ],
    ignore_index=True,
).replace([np.inf, -np.inf], np.nan).dropna()
positive_spectrum_vals = positive_spectrum_vals[positive_spectrum_vals > 0]
SPECTRUM_YLIM = (1e-1, 1e4) if positive_spectrum_vals.empty else (
    10 ** np.floor(np.log10(float(positive_spectrum_vals.min()))),
    10 ** np.ceil(np.log10(float(positive_spectrum_vals.max()))),
)
print('Radial spectrum y-limits:', SPECTRUM_YLIM)

labels_order = [f'x{s}' for s in RESOLUTION_STRIDES]

def _format_fit_param_label(source_df, variant, resolution_label, direction=None, profile_type=None, prefix='fit median'):
    required = {'variant', 'resolution_label', 'est_sigmasq', 'est_range', 'est_nugget'}
    if source_df is None or source_df.empty or not required.issubset(source_df.columns):
        return None
    df = source_df[
        (source_df['variant'].astype(str) == str(variant))
        & (source_df['resolution_label'].astype(str) == str(resolution_label))
    ].copy()
    if direction is not None and 'direction' in df.columns:
        df = df[df['direction'].astype(str) == str(direction)]
    if profile_type is not None and 'profile_type' in df.columns:
        df = df[df['profile_type'].astype(str) == str(profile_type)]
    if df.empty:
        return None
    key_cols = [
        c for c in ['date_str', 'hour_idx', 'time_key', 'variant', 'resolution_label', 'direction', 'profile_type']
        if c in df.columns
    ]
    if key_cols:
        df = df.drop_duplicates(key_cols)
    sigmasq = float(pd.to_numeric(df['est_sigmasq'], errors='coerce').median())
    range_ = float(pd.to_numeric(df['est_range'], errors='coerce').median())
    nugget = float(pd.to_numeric(df['est_nugget'], errors='coerce').median())
    if not np.isfinite(sigmasq) or not np.isfinite(range_):
        return None
    label = f'{prefix}: sigma^2={sigmasq:.3g}\nrange={range_:.3g}'
    if str(variant) == 'nugget_free' or (np.isfinite(nugget) and abs(nugget) > EPS):
        label += f'\nnugget={nugget:.3g}'
    return label


def _ratio_from_arrays(x_vals, numerator_vals, denominator_vals):
    ratio_df = pd.DataFrame({
        'k_mid': pd.to_numeric(pd.Series(x_vals), errors='coerce'),
        'numerator': pd.to_numeric(pd.Series(numerator_vals), errors='coerce'),
        'denominator': pd.to_numeric(pd.Series(denominator_vals), errors='coerce'),
    }).replace([np.inf, -np.inf], np.nan)
    good = (
        ratio_df['k_mid'].notna()
        & ratio_df['numerator'].notna()
        & ratio_df['denominator'].notna()
        & (ratio_df['numerator'] > 0)
        & (ratio_df['denominator'] > 0)
    )
    ratio_df = ratio_df.loc[good, ['k_mid']].copy()
    if ratio_df.empty:
        ratio_df['ratio'] = []
        return ratio_df
    ratio_df['ratio'] = (
        pd.to_numeric(pd.Series(numerator_vals), errors='coerce').loc[good].to_numpy(dtype=float)
        / pd.to_numeric(pd.Series(denominator_vals), errors='coerce').loc[good].to_numpy(dtype=float)
    )
    return ratio_df.sort_values('k_mid')


def _ratio_frame(numerator_df, denominator_df, numerator_col, denominator_col, x_col='k_mid'):
    if numerator_df is None or denominator_df is None or numerator_df.empty or denominator_df.empty:
        return pd.DataFrame(columns=[x_col, 'ratio'])
    left = numerator_df[[x_col, numerator_col]].copy()
    right = denominator_df[[x_col, denominator_col]].copy()
    left[x_col] = pd.to_numeric(left[x_col], errors='coerce').round(10)
    right[x_col] = pd.to_numeric(right[x_col], errors='coerce').round(10)
    merged = left.merge(right, on=x_col, how='inner')
    if merged.empty:
        return pd.DataFrame(columns=[x_col, 'ratio'])
    return _ratio_from_arrays(merged[x_col], merged[numerator_col], merged[denominator_col])


def _add_ratio_axis(ax, ratio_df, ylabel=None, color='tab:blue'):
    if ratio_df is None or ratio_df.empty:
        return None
    ratio_df = ratio_df.replace([np.inf, -np.inf], np.nan).dropna(subset=['k_mid', 'ratio'])
    ratio_df = ratio_df[ratio_df['ratio'] > 0].sort_values('k_mid')
    if ratio_df.empty:
        return None
    ratio_ax = ax.twinx()
    ratio_ax.plot(ratio_df['k_mid'], ratio_df['ratio'], color=color, linewidth=1.35, linestyle=':', alpha=0.95, zorder=8)
    ratio_ax.axhline(1.0, color=color, linewidth=0.8, linestyle='-', alpha=0.35, zorder=7)
    ratio_ax.set_yscale('log')
    vals = pd.to_numeric(ratio_df['ratio'], errors='coerce').replace([np.inf, -np.inf], np.nan).dropna()
    vals = vals[vals > 0]
    if not vals.empty:
        lo_raw = float(vals.min())
        hi_raw = float(vals.max())
        lo = max(1e-3, min(0.5, lo_raw / 1.2))
        hi = min(1e3, max(2.0, hi_raw * 1.2))
        if np.isfinite(lo) and np.isfinite(hi) and lo < hi:
            ratio_ax.set_ylim(lo, hi)
    ratio_ax.tick_params(axis='y', colors=color, labelsize=7)
    ratio_ax.spines['right'].set_color(color)
    ratio_ax.grid(False)
    if ylabel:
        ratio_ax.set_ylabel(ylabel, color=color, fontsize=8)
    return ratio_ax


def _expected_rescaled_shape_frame(sub_theory):
    curve = sub_theory[['k_mid', 'theory_spectrum_expected', 'theory_spectrum_scaled']].copy()
    curve = curve.replace([np.inf, -np.inf], np.nan).dropna(
        subset=['k_mid', 'theory_spectrum_expected', 'theory_spectrum_scaled']
    )
    curve = curve[(curve['k_mid'] > 0) & (curve['theory_spectrum_expected'] > 0) & (curve['theory_spectrum_scaled'] > 0)]
    if curve.empty:
        curve['theory_spectrum_shape_rescaled_to_expected'] = []
        return curve
    scale_to_expected = scale_theory_to_data(
        curve['theory_spectrum_expected'], curve['theory_spectrum_scaled'], method='median'
    )
    curve['theory_spectrum_shape_rescaled_to_expected'] = curve['theory_spectrum_scaled'] * scale_to_expected
    return curve

row_specs = [('nugget0', 'full: nugget fixed 0'), ('nugget_free', 'full: nugget free')]
fig, axes = plt.subplots(len(row_specs), len(labels_order), figsize=(4.4 * len(labels_order), 3.4 * len(row_specs)), sharey=True)
if len(row_specs) == 1:
    axes = np.asarray([axes])

for i, (variant, row_title) in enumerate(row_specs):
    for j, label in enumerate(labels_order):
        ax = axes[i, j]
        sub_data = avg_low_data[
            (avg_low_data['variant'] == variant)
            & (avg_low_data['resolution_label'].astype(str) == label)
            & (avg_low_data['k_mid'] > 0)
        ]
        sub_theory = avg_theory_full[
            (avg_theory_full['variant'] == variant)
            & (avg_theory_full['resolution_label'].astype(str) == label)
            & (avg_theory_full['k_mid'] > 0)
        ]
        hour_sub = plot_spec[
            (plot_spec['variant'] == variant)
            & (plot_spec['resolution_label'].astype(str) == label)
            & (plot_spec['k_mid'] > 0)
            & plot_spec['data_spectrum'].notna()
        ]
        if sub_data.empty or sub_theory.empty:
            ax.set_visible(False)
            continue
        k_cut = float(sub_data['data_k_max'].dropna().iloc[0]) if sub_data['data_k_max'].notna().any() else float(sub_data['k_mid'].max())
        param_label = _format_fit_param_label(plot_spec, variant, label)
        if param_label:
            ax.plot([], [], color='none', label=param_label)
        ax.plot(sub_theory['k_mid'], sub_theory['theory_spectrum_expected'], color='tab:red', linewidth=1.9, linestyle='--', label='expected periodogram', zorder=3)
        for h_i, (_, hs) in enumerate(hour_sub.groupby('hour_idx')):
            hour_label = 'hourly data spectra' if (i == 0 and j == 0 and h_i == 0) else None
            ax.plot(hs['k_mid'], hs['data_spectrum'], color='0.35', alpha=0.55, linewidth=1.05, label=hour_label, zorder=1)
        ax.plot(sub_data['k_mid'], sub_data['data_spectrum'], color='black', linewidth=2.2, label='data residual spectrum', zorder=4)
        ratio_df = _ratio_frame(sub_data, sub_theory, 'data_spectrum', 'theory_spectrum_expected')
        _add_ratio_axis(ax, ratio_df, ylabel='I / E[I]' if j == len(labels_order) - 1 else None)
        ax.plot([], [], color='tab:blue', linewidth=1.35, linestyle=':', label='I / E[I]')
        ax.axvline(k_cut, color='0.45', linewidth=1.0, linestyle=':', alpha=0.95, zorder=2)
        ax.set_xlim(0, FULL_K_PLOT_MAX)
        ax.set_ylim(*SPECTRUM_YLIM)
        ax.set_title(f'{row_title}, {label}  (data k <= {k_cut:.1f})')
        ax.set_xlabel('radial frequency on full-grid scale')
        if j == 0:
            ax.set_ylabel('spectrum')
        ax.set_yscale('log')
        ax.grid(alpha=0.2)
        ax.legend(fontsize=7, handlelength=1.5)

fig.suptitle(f'smooth={SMOOTH}: radial residual spectrum vs fitted expected periodogram')
fig.tight_layout()
combined_spectrum_plot_path = OUT_DIR / f'{OUT_PREFIX}_data_vs_expected_periodogram_by_variant_resolution.png'
fig.savefig(combined_spectrum_plot_path, dpi=180, bbox_inches='tight')
print('Saved radial spectrum plot:', combined_spectrum_plot_path)
plt.show()


# Shape diagnostic: median-matched Matérn+nugget spectral shape.
# This is useful for comparing curvature only; do not read its vertical scale or nugget floor literally.
fig_shape, axes_shape = plt.subplots(len(row_specs), len(labels_order), figsize=(4.4 * len(labels_order), 3.4 * len(row_specs)), sharey=True)
if len(row_specs) == 1:
    axes_shape = np.asarray([axes_shape])

for i, (variant, row_title) in enumerate(row_specs):
    for j, label in enumerate(labels_order):
        ax = axes_shape[i, j]
        sub_data = avg_low_data[
            (avg_low_data['variant'] == variant)
            & (avg_low_data['resolution_label'].astype(str) == label)
            & (avg_low_data['k_mid'] > 0)
        ]
        sub_theory = avg_theory_full[
            (avg_theory_full['variant'] == variant)
            & (avg_theory_full['resolution_label'].astype(str) == label)
            & (avg_theory_full['k_mid'] > 0)
        ]
        hour_sub = plot_spec[
            (plot_spec['variant'] == variant)
            & (plot_spec['resolution_label'].astype(str) == label)
            & (plot_spec['k_mid'] > 0)
            & plot_spec['data_spectrum'].notna()
        ]
        if sub_data.empty or sub_theory.empty:
            ax.set_visible(False)
            continue
        k_cut = float(sub_data['data_k_max'].dropna().iloc[0]) if sub_data['data_k_max'].notna().any() else float(sub_data['k_mid'].max())
        param_label = _format_fit_param_label(plot_spec, variant, label)
        if param_label:
            ax.plot([], [], color='none', label=param_label)
        ax.plot(sub_theory['k_mid'], sub_theory['theory_spectrum_scaled'], color='tab:red', linewidth=1.8, linestyle='--', label='median-matched theory shape', zorder=3)
        for h_i, (_, hs) in enumerate(hour_sub.groupby('hour_idx')):
            hour_label = 'hourly data spectra' if (i == 0 and j == 0 and h_i == 0) else None
            ax.plot(hs['k_mid'], hs['data_spectrum'], color='0.35', alpha=0.55, linewidth=1.05, label=hour_label, zorder=1)
        ax.plot(sub_data['k_mid'], sub_data['data_spectrum'], color='black', linewidth=2.2, label='data residual spectrum', zorder=4)
        ratio_df = _ratio_frame(sub_data, sub_theory, 'data_spectrum', 'theory_spectrum_scaled')
        _add_ratio_axis(ax, ratio_df, ylabel='I / f' if j == len(labels_order) - 1 else None)
        ax.plot([], [], color='tab:blue', linewidth=1.35, linestyle=':', label='I / f scaled')
        ax.axvline(k_cut, color='0.45', linewidth=1.0, linestyle=':', alpha=0.95, zorder=2)
        ax.set_xlim(0, FULL_K_PLOT_MAX)
        ax.set_ylim(*SPECTRUM_YLIM)
        ax.set_title(f'{row_title}, {label}  (data k <= {k_cut:.1f})')
        ax.set_xlabel('radial frequency on full-grid scale')
        if j == 0:
            ax.set_ylabel('spectrum')
        ax.set_yscale('log')
        ax.grid(alpha=0.2)
        ax.legend(fontsize=7, handlelength=1.5)

fig_shape.suptitle(f'smooth={SMOOTH}: radial shape diagnostic, median-matched Matérn+nugget theory')
fig_shape.tight_layout()
shape_diagnostic_plot_path = OUT_DIR / f'{OUT_PREFIX}_shape_diagnostic_median_matched_theory_by_variant_resolution.png'
fig_shape.savefig(shape_diagnostic_plot_path, dpi=180, bbox_inches='tight')
print('Saved shape diagnostic radial spectrum plot:', shape_diagnostic_plot_path)
plt.show()


# Expected-periodogram vs continuous Matérn shape after rescaling f to E[I].
# This isolates finite-grid, mask/taper, and leakage effects from the model shape.
fig_ei_shape, axes_ei_shape = plt.subplots(len(row_specs), len(labels_order), figsize=(4.4 * len(labels_order), 3.4 * len(row_specs)), sharey=True)
if len(row_specs) == 1:
    axes_ei_shape = np.asarray([axes_ei_shape])

for i, (variant, row_title) in enumerate(row_specs):
    for j, label in enumerate(labels_order):
        ax = axes_ei_shape[i, j]
        sub_data = avg_low_data[
            (avg_low_data['variant'] == variant)
            & (avg_low_data['resolution_label'].astype(str) == label)
            & (avg_low_data['k_mid'] > 0)
        ]
        sub_theory = avg_theory_full[
            (avg_theory_full['variant'] == variant)
            & (avg_theory_full['resolution_label'].astype(str) == label)
            & (avg_theory_full['k_mid'] > 0)
        ]
        curve = _expected_rescaled_shape_frame(sub_theory)
        if curve.empty:
            ax.set_visible(False)
            continue
        k_cut = np.nan
        if not sub_data.empty:
            k_cut = float(sub_data['data_k_max'].dropna().iloc[0]) if sub_data['data_k_max'].notna().any() else float(sub_data['k_mid'].max())
        param_label = _format_fit_param_label(plot_spec, variant, label)
        if param_label:
            ax.plot([], [], color='none', label=param_label)
        ax.plot(curve['k_mid'], curve['theory_spectrum_expected'], color='tab:red', linewidth=1.9, linestyle='--', label='expected periodogram', zorder=4)
        ax.plot(curve['k_mid'], curve['theory_spectrum_shape_rescaled_to_expected'], color='tab:purple', linewidth=1.8, linestyle='-.', label='f rescaled to E[I]', zorder=3)
        ratio_df = _ratio_from_arrays(curve['k_mid'], curve['theory_spectrum_expected'], curve['theory_spectrum_shape_rescaled_to_expected'])
        _add_ratio_axis(ax, ratio_df, ylabel='E[I] / f' if j == len(labels_order) - 1 else None)
        ax.plot([], [], color='tab:blue', linewidth=1.35, linestyle=':', label='E[I] / f rescaled')
        if np.isfinite(k_cut):
            ax.axvline(k_cut, color='0.45', linewidth=1.0, linestyle=':', alpha=0.95, zorder=2)
        ax.set_xlim(0, FULL_K_PLOT_MAX)
        ax.set_ylim(*SPECTRUM_YLIM)
        title_suffix = f'  (data k <= {k_cut:.1f})' if np.isfinite(k_cut) else ''
        ax.set_title(f'{row_title}, {label}{title_suffix}')
        ax.set_xlabel('radial frequency on full-grid scale')
        if j == 0:
            ax.set_ylabel('spectrum')
        ax.set_yscale('log')
        ax.grid(alpha=0.2)
        ax.legend(fontsize=7, handlelength=1.5)

fig_ei_shape.suptitle(f'smooth={SMOOTH}: radial expected periodogram vs rescaled Matérn shape')
fig_ei_shape.tight_layout()
ei_shape_plot_path = OUT_DIR / f'{OUT_PREFIX}_expected_vs_rescaled_matern_shape_by_variant_resolution.png'
fig_ei_shape.savefig(ei_shape_plot_path, dpi=180, bbox_inches='tight')
print('Saved radial expected-vs-rescaled-shape plot:', ei_shape_plot_path)
plt.show()
# Out:
# Saved low-frequency data spectrum: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_expanded_lat-3to7_lon111to131_spectral_s05_nugget_compare_clusterb2_052426_radial_spectrum_lowfreq_only_avg.csv
# Radial spectrum y-limits: (1.0, 100000.0)
# Saved radial spectrum plot: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_expanded_lat-3to7_lon111to131_spectral_s05_nugget_compare_clusterb2_052426_data_vs_expected_periodogram_by_variant_resolution.png
# Saved shape diagnostic radial spectrum plot: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_expanded_lat-3to7_lon111to131_spectral_s05_nugget_compare_clusterb2_052426_shape_diagnostic_median_matched_theory_by_variant_resolution.png
# Saved radial expected-vs-rescaled-shape plot: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_expanded_lat-3to7_lon111to131_spectral_s05_nugget_compare_clusterb2_052426_expected_vs_rescaled_matern_shape_by_variant_resolution.png

# %%
# %%
# Directional lat/lon spectrum diagnostics.
# These are directional summaries of the same 2D masked/tapered/projected FFT
# periodogram used by the radial diagnostic, so empirical and expected curves
# share the same finite-grid convention.
if 'directional_spectral_df' not in globals():
    directional_spectral_df = pd.read_csv(OUT_DIR / f'{OUT_PREFIX}_directional_spectrum_lat_lon.csv')
required_dir_cols = {'theory_spectrum_expected', 'theory_spectrum_scaled'}
missing_dir_cols = required_dir_cols.difference(directional_spectral_df.columns)
if missing_dir_cols:
    raise ValueError(f'directional_spectral_df lacks {sorted(missing_dir_cols)}; rerun the RUN_SPECTRUM cell after this update.')

plot_dir = directional_spectral_df.copy()
plot_dir['resolution_label'] = pd.Categorical(
    plot_dir['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
)

avg_dir_data = (
    plot_dir.dropna(subset=['data_spectrum'])
    .groupby(['variant', 'direction', 'resolution_label', 'resolution_stride', 'k_mid'], observed=False)
    .agg(
        data_spectrum=('data_spectrum', 'mean'),
        n_hours=('hour_idx', 'nunique'),
        data_k_max=('data_k_max', 'mean'),
    )
    .reset_index()
)
avg_dir_theory = (
    plot_dir
    .groupby(['variant', 'direction', 'resolution_label', 'k_mid'], observed=False)
    .agg(
        theory_spectrum_expected=('theory_spectrum_expected', 'mean'),
        theory_spectrum_scaled=('theory_spectrum_scaled', 'mean'),
    )
    .reset_index()
)

dir_expected_vals = pd.concat(
    [
        pd.to_numeric(avg_dir_data['data_spectrum'], errors='coerce'),
        pd.to_numeric(avg_dir_theory['theory_spectrum_expected'], errors='coerce'),
    ],
    ignore_index=True,
).replace([np.inf, -np.inf], np.nan).dropna()
dir_expected_vals = dir_expected_vals[dir_expected_vals > 0]
DIR_EXPECTED_SPECTRUM_YLIM = SPECTRUM_YLIM if dir_expected_vals.empty else (
    10 ** np.floor(np.log10(float(dir_expected_vals.min()))),
    10 ** np.ceil(np.log10(float(dir_expected_vals.max()))),
)
print('Directional expected-periodogram y-limits:', DIR_EXPECTED_SPECTRUM_YLIM)

row_specs = [
    ('nugget0', 'lat', 'nugget fixed 0: latitude direction'),
    ('nugget0', 'lon', 'nugget fixed 0: longitude direction'),
    ('nugget_free', 'lat', 'nugget free: latitude direction'),
    ('nugget_free', 'lon', 'nugget free: longitude direction'),
]
labels_order = [f'x{s}' for s in RESOLUTION_STRIDES]
fig, axes = plt.subplots(len(row_specs), len(labels_order), figsize=(4.4 * len(labels_order), 3.0 * len(row_specs)), sharey=True)

for i, (variant, direction, row_title) in enumerate(row_specs):
    for j, label in enumerate(labels_order):
        ax = axes[i, j]
        sub_data = avg_dir_data[
            (avg_dir_data['variant'] == variant)
            & (avg_dir_data['direction'] == direction)
            & (avg_dir_data['resolution_label'].astype(str) == label)
            & (avg_dir_data['k_mid'] > 0)
        ]
        sub_theory = avg_dir_theory[
            (avg_dir_theory['variant'] == variant)
            & (avg_dir_theory['direction'] == direction)
            & (avg_dir_theory['resolution_label'].astype(str) == label)
            & (avg_dir_theory['k_mid'] > 0)
        ]
        hour_sub = plot_dir[
            (plot_dir['variant'] == variant)
            & (plot_dir['direction'] == direction)
            & (plot_dir['resolution_label'].astype(str) == label)
            & (plot_dir['k_mid'] > 0)
            & plot_dir['data_spectrum'].notna()
        ]
        if sub_data.empty or sub_theory.empty:
            ax.set_visible(False)
            continue
        k_cut = float(sub_data['data_k_max'].dropna().iloc[0]) if sub_data['data_k_max'].notna().any() else float(sub_data['k_mid'].max())
        param_label = _format_fit_param_label(plot_spec, variant, label)
        if param_label:
            ax.plot([], [], color='none', label=param_label)
        ax.plot(sub_theory['k_mid'], sub_theory['theory_spectrum_expected'], color='tab:red', linewidth=2.2, linestyle='--', marker='o', markersize=3.0, markerfacecolor='tab:red', markeredgewidth=0.0, label='expected periodogram', zorder=6)
        for h_i, (_, hs) in enumerate(hour_sub.groupby('hour_idx')):
            hour_label = 'hourly data spectra' if (i == 0 and j == 0 and h_i == 0) else None
            ax.plot(hs['k_mid'], hs['data_spectrum'], color='0.35', alpha=0.55, linewidth=1.05, label=hour_label, zorder=1)
        ax.plot(sub_data['k_mid'], sub_data['data_spectrum'], color='black', linewidth=2.2, label='data residual spectrum', zorder=4)
        ratio_df = _ratio_frame(sub_data, sub_theory, 'data_spectrum', 'theory_spectrum_expected')
        _add_ratio_axis(ax, ratio_df, ylabel='I / E[I]' if j == len(labels_order) - 1 else None)
        ax.plot([], [], color='tab:blue', linewidth=1.35, linestyle=':', label='I / E[I]')
        ax.axvline(k_cut, color='0.45', linewidth=1.0, linestyle=':', alpha=0.95, zorder=2)
        ax.set_xlim(0, max(float(sub_theory['k_mid'].max()), float(sub_data['k_mid'].max())))
        ax.set_ylim(*DIR_EXPECTED_SPECTRUM_YLIM)
        ax.set_title(f'{row_title}, {label}')
        ax.set_xlabel(f'{direction} frequency')
        if j == 0:
            ax.set_ylabel('directional spectrum')
        ax.set_yscale('log')
        ax.grid(alpha=0.2)
        ax.legend(fontsize=7, handlelength=1.5)

fig.suptitle(f'smooth={SMOOTH}: directional residual spectrum vs fitted expected periodogram')
fig.tight_layout()
directional_expected_plot_path = OUT_DIR / f'{OUT_PREFIX}_directional_data_vs_expected_periodogram_by_variant_resolution.png'
fig.savefig(directional_expected_plot_path, dpi=180, bbox_inches='tight')
print('Saved directional expected-periodogram plot:', directional_expected_plot_path)
plt.show()


dir_shape_vals = pd.concat(
    [
        pd.to_numeric(avg_dir_data['data_spectrum'], errors='coerce'),
        pd.to_numeric(avg_dir_theory['theory_spectrum_scaled'], errors='coerce'),
    ],
    ignore_index=True,
).replace([np.inf, -np.inf], np.nan).dropna()
dir_shape_vals = dir_shape_vals[dir_shape_vals > 0]
DIR_SHAPE_SPECTRUM_YLIM = SPECTRUM_YLIM if dir_shape_vals.empty else (
    10 ** np.floor(np.log10(float(dir_shape_vals.min()))),
    10 ** np.ceil(np.log10(float(dir_shape_vals.max()))),
)
print('Directional scaled-shape y-limits:', DIR_SHAPE_SPECTRUM_YLIM)

fig_shape, axes_shape = plt.subplots(len(row_specs), len(labels_order), figsize=(4.4 * len(labels_order), 3.0 * len(row_specs)), sharey=True)
for i, (variant, direction, row_title) in enumerate(row_specs):
    for j, label in enumerate(labels_order):
        ax = axes_shape[i, j]
        sub_data = avg_dir_data[
            (avg_dir_data['variant'] == variant)
            & (avg_dir_data['direction'] == direction)
            & (avg_dir_data['resolution_label'].astype(str) == label)
            & (avg_dir_data['k_mid'] > 0)
        ]
        sub_theory = avg_dir_theory[
            (avg_dir_theory['variant'] == variant)
            & (avg_dir_theory['direction'] == direction)
            & (avg_dir_theory['resolution_label'].astype(str) == label)
            & (avg_dir_theory['k_mid'] > 0)
        ]
        hour_sub = plot_dir[
            (plot_dir['variant'] == variant)
            & (plot_dir['direction'] == direction)
            & (plot_dir['resolution_label'].astype(str) == label)
            & (plot_dir['k_mid'] > 0)
            & plot_dir['data_spectrum'].notna()
        ]
        if sub_data.empty or sub_theory.empty:
            ax.set_visible(False)
            continue
        k_cut = float(sub_data['data_k_max'].dropna().iloc[0]) if sub_data['data_k_max'].notna().any() else float(sub_data['k_mid'].max())
        param_label = _format_fit_param_label(plot_spec, variant, label)
        if param_label:
            ax.plot([], [], color='none', label=param_label)
        ax.plot(sub_theory['k_mid'], sub_theory['theory_spectrum_scaled'], color='tab:red', linewidth=2.2, linestyle='--', marker='o', markersize=3.0, markerfacecolor='tab:red', markeredgewidth=0.0, label='scaled Matérn shape', zorder=6)
        for h_i, (_, hs) in enumerate(hour_sub.groupby('hour_idx')):
            hour_label = 'hourly data spectra' if (i == 0 and j == 0 and h_i == 0) else None
            ax.plot(hs['k_mid'], hs['data_spectrum'], color='0.35', alpha=0.55, linewidth=1.05, label=hour_label, zorder=1)
        ax.plot(sub_data['k_mid'], sub_data['data_spectrum'], color='black', linewidth=2.2, label='data residual spectrum', zorder=4)
        ratio_df = _ratio_frame(sub_data, sub_theory, 'data_spectrum', 'theory_spectrum_scaled')
        _add_ratio_axis(ax, ratio_df, ylabel='I / f' if j == len(labels_order) - 1 else None)
        ax.plot([], [], color='tab:blue', linewidth=1.35, linestyle=':', label='I / f scaled')
        ax.axvline(k_cut, color='0.45', linewidth=1.0, linestyle=':', alpha=0.95, zorder=2)
        ax.set_xlim(0, max(float(sub_theory['k_mid'].max()), float(sub_data['k_mid'].max())))
        ax.set_ylim(*DIR_SHAPE_SPECTRUM_YLIM)
        ax.set_title(f'{row_title}, {label}')
        ax.set_xlabel(f'{direction} frequency')
        if j == 0:
            ax.set_ylabel('directional spectrum')
        ax.set_yscale('log')
        ax.grid(alpha=0.2)
        ax.legend(fontsize=7, handlelength=1.5)

fig_shape.suptitle(f'smooth={SMOOTH}: directional scaled Matérn shape diagnostic')
fig_shape.tight_layout()
directional_shape_plot_path = OUT_DIR / f'{OUT_PREFIX}_shape_diagnostic_directional_scaled_matern_by_variant_resolution.png'
fig_shape.savefig(directional_shape_plot_path, dpi=180, bbox_inches='tight')
print('Saved directional scaled-shape plot:', directional_shape_plot_path)
plt.show()


# Directional expected-periodogram vs continuous Matérn shape after rescaling f to E[I].
fig_ei_dir_shape, axes_ei_dir_shape = plt.subplots(len(row_specs), len(labels_order), figsize=(4.4 * len(labels_order), 3.0 * len(row_specs)), sharey=True)
for i, (variant, direction, row_title) in enumerate(row_specs):
    for j, label in enumerate(labels_order):
        ax = axes_ei_dir_shape[i, j]
        sub_data = avg_dir_data[
            (avg_dir_data['variant'] == variant)
            & (avg_dir_data['direction'] == direction)
            & (avg_dir_data['resolution_label'].astype(str) == label)
            & (avg_dir_data['k_mid'] > 0)
        ]
        sub_theory = avg_dir_theory[
            (avg_dir_theory['variant'] == variant)
            & (avg_dir_theory['direction'] == direction)
            & (avg_dir_theory['resolution_label'].astype(str) == label)
            & (avg_dir_theory['k_mid'] > 0)
        ]
        curve = _expected_rescaled_shape_frame(sub_theory)
        if curve.empty:
            ax.set_visible(False)
            continue
        k_cut = np.nan
        if not sub_data.empty:
            k_cut = float(sub_data['data_k_max'].dropna().iloc[0]) if sub_data['data_k_max'].notna().any() else float(sub_data['k_mid'].max())
        param_label = _format_fit_param_label(plot_spec, variant, label)
        if param_label:
            ax.plot([], [], color='none', label=param_label)
        ax.plot(curve['k_mid'], curve['theory_spectrum_expected'], color='tab:red', linewidth=2.2, linestyle='--', marker='o', markersize=3.0, markerfacecolor='tab:red', markeredgewidth=0.0, label='expected periodogram', zorder=6)
        ax.plot(curve['k_mid'], curve['theory_spectrum_shape_rescaled_to_expected'], color='tab:purple', linewidth=2.0, linestyle='-.', marker='o', markersize=2.6, markerfacecolor='tab:purple', markeredgewidth=0.0, label='f rescaled to E[I]', zorder=5)
        ratio_df = _ratio_from_arrays(curve['k_mid'], curve['theory_spectrum_expected'], curve['theory_spectrum_shape_rescaled_to_expected'])
        _add_ratio_axis(ax, ratio_df, ylabel='E[I] / f' if j == len(labels_order) - 1 else None)
        ax.plot([], [], color='tab:blue', linewidth=1.35, linestyle=':', label='E[I] / f rescaled')
        if np.isfinite(k_cut):
            ax.axvline(k_cut, color='0.45', linewidth=1.0, linestyle=':', alpha=0.95, zorder=2)
        x_max = float(curve['k_mid'].max())
        if not sub_data.empty:
            x_max = max(x_max, float(sub_data['k_mid'].max()))
        ax.set_xlim(0, x_max)
        ax.set_ylim(*DIR_EXPECTED_SPECTRUM_YLIM)
        ax.set_title(f'{row_title}, {label}')
        ax.set_xlabel(f'{direction} frequency')
        if j == 0:
            ax.set_ylabel('directional spectrum')
        ax.set_yscale('log')
        ax.grid(alpha=0.2)
        ax.legend(fontsize=7, handlelength=1.5)

fig_ei_dir_shape.suptitle(f'smooth={SMOOTH}: directional expected periodogram vs rescaled Matérn shape')
fig_ei_dir_shape.tight_layout()
directional_ei_shape_plot_path = OUT_DIR / f'{OUT_PREFIX}_directional_expected_vs_rescaled_matern_shape_by_variant_resolution.png'
fig_ei_dir_shape.savefig(directional_ei_shape_plot_path, dpi=180, bbox_inches='tight')
print('Saved directional expected-vs-rescaled-shape plot:', directional_ei_shape_plot_path)
plt.show()
# Out:
# Directional expected-periodogram y-limits: (1.0, 1000.0)
# Saved directional expected-periodogram plot: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_expanded_lat-3to7_lon111to131_spectral_s05_nugget_compare_clusterb2_052426_directional_data_vs_expected_periodogram_by_variant_resolution.png
# Directional scaled-shape y-limits: (1.0, 1000.0)
# Saved directional scaled-shape plot: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_expanded_lat-3to7_lon111to131_spectral_s05_nugget_compare_clusterb2_052426_shape_diagnostic_directional_scaled_matern_by_variant_resolution.png
# Saved directional expected-vs-rescaled-shape plot: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_expanded_lat-3to7_lon111to131_spectral_s05_nugget_compare_clusterb2_052426_directional_expected_vs_rescaled_matern_shape_by_variant_resolution.png

# %%
# %%
# Scaled Matérn shape diagnostics for partial-profile fits.
# This keeps the original partial-profile spectral comparison, but writes only
# the median-matched shape curves rather than raw continuous f(omega) output.
if 'profile_df' not in globals() or profile_df.empty:
    profile_path = OUT_DIR / f'{OUT_PREFIX}_partial_profile.csv'
    profile_df = pd.read_csv(profile_path) if profile_path.exists() else pd.DataFrame()

if RUN_SPECTRUM and not profile_df.empty:
    profile_spectral_rows = []
    for r in profile_df.itertuples(index=False):
        grid, mask, time_key, n_valid_spectrum, lat_axis, lon_axis = detrended_residual_grid(
            int(r.hour_idx), int(r.resolution_stride)
        )
        data_p = masked_periodogram(grid, mask)
        k_data, omega2_data, _, _ = frequency_grid_for_axes(lat_axis, lon_axis)
        data_rad = radial_average(data_p, k_data).rename(columns={'spectrum': 'data_spectrum'})

        theory_p = matern_spectrum_shape(r.est_sigmasq, r.est_range, r.est_nugget, SPECTRAL_SMOOTH, OMEGA2_FULL)
        theory_rad = radial_average(theory_p, K_FULL_RADIAL).rename(columns={'spectrum': 'theory_spectrum'})
        merged = theory_rad.merge(data_rad[['k_bin', 'data_spectrum', 'n_freq']], on='k_bin', how='left', suffixes=('', '_data'))
        scale = scale_theory_to_data(merged['data_spectrum'], merged['theory_spectrum'], method='geomean')
        merged['theory_spectrum_scaled'] = merged['theory_spectrum'] * scale
        data_k_max = float(data_rad['k_mid'].max()) if not data_rad.empty else np.nan

        for m in merged.itertuples(index=False):
            profile_spectral_rows.append({
                'date_str': str(r.date_str),
                'hour_idx': int(r.hour_idx),
                'time_key': str(r.time_key),
                'resolution_stride': int(r.resolution_stride),
                'resolution_label': str(r.resolution_label),
                'variant': str(r.variant),
                'profile_type': str(r.profile_type),
                'fit_type': str(r.profile_type),
                'smooth': float(SMOOTH),
                'n_valid_spectrum': int(n_valid_spectrum),
                'est_sigmasq': float(r.est_sigmasq),
                'est_range': float(r.est_range),
                'est_nugget': float(r.est_nugget),
                'k_bin': int(m.k_bin),
                'k_mid': float(m.k_mid),
                'k_mean': float(m.k_mean),
                'n_freq': int(getattr(m, 'n_freq_data')) if pd.notna(getattr(m, 'n_freq_data', np.nan)) else 0,
                'data_k_max': data_k_max,
                'data_spectrum': float(m.data_spectrum) if pd.notna(m.data_spectrum) else np.nan,
                'theory_spectrum_scaled': float(m.theory_spectrum_scaled),
                'theory_scale_to_data': scale,
            })

    profile_spectral_df = pd.DataFrame(profile_spectral_rows)
    profile_spectral_path = OUT_DIR / f'{OUT_PREFIX}_partial_profile_radial_spectrum.csv'
    profile_spectral_df.to_csv(profile_spectral_path, index=False)
    print('Saved partial-profile scaled Matérn shape spectrum:', profile_spectral_path)

    plot_prof = profile_spectral_df.copy()
    plot_prof['resolution_label'] = pd.Categorical(
        plot_prof['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
    )
    avg_prof_data = (
        plot_prof.dropna(subset=['data_spectrum'])
        .groupby(['variant', 'profile_type', 'resolution_label', 'resolution_stride', 'k_bin'], observed=False)
        .agg(k_mid=('k_mid', 'mean'), data_spectrum=('data_spectrum', 'mean'), data_k_max=('data_k_max', 'mean'))
        .reset_index()
    )
    avg_prof_theory = (
        plot_prof
        .groupby(['variant', 'profile_type', 'resolution_label', 'k_bin'], observed=False)
        .agg(
            k_mid=('k_mid', 'mean'),
            theory_spectrum_scaled=('theory_spectrum_scaled', 'mean'),
        )
        .reset_index()
    )

    labels_order = [f'x{s}' for s in RESOLUTION_STRIDES]
    fig, axes = plt.subplots(1, len(labels_order), figsize=(4.4 * len(labels_order), 3.5), sharey=True)
    for j, label in enumerate(labels_order):
        ax = axes[j]
        sub_data = avg_prof_data[
            (avg_prof_data['variant'] == 'nugget0')
            & (avg_prof_data['profile_type'] == 'sigma_only')
            & (avg_prof_data['resolution_label'].astype(str) == label)
            & (avg_prof_data['k_mid'] > 0)
        ]
        sub_sigma = avg_prof_theory[
            (avg_prof_theory['variant'] == 'nugget0')
            & (avg_prof_theory['profile_type'] == 'sigma_only')
            & (avg_prof_theory['resolution_label'].astype(str) == label)
            & (avg_prof_theory['k_mid'] > 0)
        ]
        sub_range = avg_prof_theory[
            (avg_prof_theory['variant'] == 'nugget0')
            & (avg_prof_theory['profile_type'] == 'range_only')
            & (avg_prof_theory['resolution_label'].astype(str) == label)
            & (avg_prof_theory['k_mid'] > 0)
        ]
        if sub_data.empty or sub_sigma.empty or sub_range.empty:
            ax.set_visible(False)
            continue
        k_cut = float(sub_data['data_k_max'].dropna().iloc[0]) if sub_data['data_k_max'].notna().any() else float(sub_data['k_mid'].max())
        ax.plot(sub_data['k_mid'], sub_data['data_spectrum'], color='black', linewidth=2.0, label='data residual spectrum')
        ax.plot(sub_sigma['k_mid'], sub_sigma['theory_spectrum_scaled'], color='tab:blue', linewidth=1.8, linestyle='--', label='scaled sigma-only Matérn shape')
        ax.plot(sub_range['k_mid'], sub_range['theory_spectrum_scaled'], color='tab:green', linewidth=1.8, linestyle='--', label='scaled range-only Matérn shape')
        ax.axvline(k_cut, color='0.55', linewidth=1.0, linestyle=':', alpha=0.9)
        ax.set_xlim(0, FULL_K_PLOT_MAX)
        ax.set_ylim(*SPECTRUM_YLIM)
        ax.set_yscale('log')
        ax.grid(alpha=0.2)
        ax.set_title(f'nugget0 partial profiles, {label}')
        ax.set_xlabel('radial frequency on full-grid scale')
        if j == 0:
            ax.set_ylabel('spectrum')
            ax.legend(fontsize=8)

    fig.suptitle(f'smooth={SMOOTH}: partial-profile scaled Matérn shape diagnostics')
    fig.tight_layout()
    partial_profile_plot_path = OUT_DIR / f'{OUT_PREFIX}_partial_profile_shape_diagnostic_scaled_matern.png'
    fig.savefig(partial_profile_plot_path, dpi=180, bbox_inches='tight')
    print('Saved partial-profile scaled Matérn shape diagnostic plot:', partial_profile_plot_path)
    plt.show()

else:
    print('No partial-profile spectra: profile_df is empty or RUN_SPECTRUM is False.')
# Out:
# Saved partial-profile scaled Matérn shape spectrum: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_expanded_lat-3to7_lon111to131_spectral_s05_nugget_compare_clusterb2_052426_partial_profile_radial_spectrum.csv
# Saved partial-profile scaled Matérn shape diagnostic plot: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_expanded_lat-3to7_lon111to131_spectral_s05_nugget_compare_clusterb2_052426_partial_profile_shape_diagnostic_scaled_matern.png

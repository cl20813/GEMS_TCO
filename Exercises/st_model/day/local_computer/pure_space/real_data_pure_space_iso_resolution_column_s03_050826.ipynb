# %% [markdown]
# # Pure-space isotropic Column Vecchia: resolution sensitivity by hour
#
# This notebook removes the temporal covariance entirely and fits each time slot independently using a pure-space isotropic Column Vecchia model.
#
# Resolution thinning:
#
# - `x8`: keep regular-grid rows `0, 8, 16, ...`
# - `x4`: keep `0, 4, 8, ...`
# - `x2`: keep `0, 2, 4, ...`
# - `x1`: keep all rows
#
# Estimated full-fit parameters:
#
# - `sigmasq`
# - `range` (single isotropic spatial range)
# - `nugget`
#
# Additional profile checks:
#
# - `sigma_only_x1_anchor`: fix `range` and `nugget` at the same hour's full `x1` estimate, re-estimate only `sigmasq` at each resolution.
# - `range_only_x1_anchor`: fix `sigmasq` and `nugget` at the same hour's full `x1` estimate, re-estimate only `range` at each resolution.
#
# This version fixes Matérn smoothness at `0.3` to test whether the high-resolution range still decreases after allowing a rougher spatial process.

# %%
import gc
import sys
import time
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch

LOCAL_SRC = '/Users/joonwonlee/Documents/GEMS_TCO-1/src'
AMAREL_SRC = '/home/jl2815/tco'
SRC = AMAREL_SRC if Path(AMAREL_SRC).exists() else LOCAL_SRC
if SRC not in sys.path:
    sys.path.insert(0, SRC)

from GEMS_TCO import configuration as config
from GEMS_TCO.data_loader import load_data_dynamic_processed
from GEMS_TCO.kernels_space_iso_050826 import ColumnSpaceIsoTrendVecchiaFit

DEVICE = torch.device('cpu')
DTYPE = torch.float64
ROUND_DECIMALS = 4

pd.set_option('display.max_columns', 120)
pd.set_option('display.width', 180)
print('SRC:', SRC)
print('device:', DEVICE)
# Out:
# SRC: /Users/joonwonlee/Documents/GEMS_TCO-1/src
# device: cpu

# %%
# Experiment config
YEAR = '2024'
MONTH = 7
DAY_IDX = 2                 # 0-based: 2 -> 2024-07-03
HOUR_IDX_LIST = list(range(8))
LAT_RANGE = [-3, 2]
LON_RANGE = [121, 131]

RESOLUTION_STRIDES = [8, 4, 2, 1]
FIT_SMOOTHS = [0.3]
MEAN_DESIGN = 'latlon'      # hourly pure-space: intercept + lat + lon detrending

COLUMN_SPEC = {
    'model': 'ColumnSpaceIso_Up2_Right3_M10_realloc',
    'head_right_cols': 0,
    'above_count': 2,
    'right_col_count': 3,
    'per_time_conditioning_count': 10,
    'target_chunk_size': 512,
}

LBFGS_LR = 1.0
LBFGS_STEPS_FULL = 8
LBFGS_STEPS_PARTIAL = 8
LBFGS_EVAL = 20
LBFGS_HIST = 10
GRAD_TOL = 1e-5

INIT_ISO = {
    'sigmasq': 13.0,
    'range': 0.25,
    'nugget': 2.5,
}
P_LABELS = ['sigmasq', 'range', 'nugget']
P_IDX = {'sigmasq': 0, 'range': 1, 'nugget': 2}

RUN_FULL = True
RUN_PARTIAL = False

PURE_SPACE_DIR = Path('/Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space')
OUT_DIR = PURE_SPACE_DIR / 'log'
OUT_DIR.mkdir(parents=True, exist_ok=True)
OUT_PREFIX = 'real_pure_space_iso_column_resolution_s03_050826'

print('day:', f'{YEAR}{MONTH:02d}{DAY_IDX + 1:02d}')
print('hours:', HOUR_IDX_LIST)
print('strides:', RESOLUTION_STRIDES)
print('column:', COLUMN_SPEC)
print('init:', INIT_ISO)
# Out:
# day: 20240703
# hours: [0, 1, 2, 3, 4, 5, 6, 7]
# strides: [8, 4, 2, 1]
# column: {'model': 'ColumnSpaceIso_Up2_Right3_M10_realloc', 'head_right_cols': 0, 'above_count': 2, 'right_col_count': 3, 'per_time_conditioning_count': 10, 'target_chunk_size': 512}
# init: {'sigmasq': 13.0, 'range': 0.25, 'nugget': 2.5}

# %%
def phys_to_log_iso(d):
    return [np.log(d['sigmasq']), np.log(d['range']), np.log(d['nugget'])]


def backmap_iso(raw):
    return {
        'sigmasq': float(np.exp(raw[0])),
        'range': float(np.exp(raw[1])),
        'nugget': float(np.exp(raw[2])),
    }


def make_full_params(init=INIT_ISO):
    return [torch.tensor([v], device=DEVICE, dtype=DTYPE, requires_grad=True) for v in phys_to_log_iso(init)]


def count_valid(input_map):
    return int(sum(((~torch.isnan(v[:, 2])) & (~torch.isnan(v[:, 0])) & (~torch.isnan(v[:, 1]))).sum().item() for v in input_map.values()))


def space_diag(model):
    groups = getattr(model, 'Batched_Groups', []) or []
    if not groups:
        return {'n_batches': 0, 'n_tails': 0, 'mean_m': 0.0, 'max_m': 0, 'largest_batch_n': 0}
    ns = np.asarray([int(g['target_idx'].shape[0]) for g in groups], dtype=np.int64)
    ms = np.asarray([int(g['max_m']) for g in groups], dtype=np.int64)
    return {
        'n_batches': int(len(groups)),
        'n_tails': int(ns.sum()),
        'mean_m': float(ms.mean()),
        'max_m': int(ms.max()),
        'largest_batch_n': int(ns.max()),
    }


def round_df(df, digits=ROUND_DECIMALS):
    out = df.copy()
    num_cols = out.select_dtypes(include=[np.number]).columns
    out[num_cols] = out[num_cols].round(digits)
    return out


def empty_cache():
    gc.collect()
    if DEVICE.type == 'cuda':
        torch.cuda.empty_cache()


def resolution_label(stride):
    return f'x{int(stride)}'

# %%
loader = load_data_dynamic_processed(config.mac_data_load_path)
df_map, _, _, monthly_mean = loader.load_maxmin_ordered_data_bymonthyear(
    lat_lon_resolution=[1, 1],
    mm_cond_number=10,
    years_=[YEAR],
    months_=[MONTH],
    lat_range=LAT_RANGE,
    lon_range=LON_RANGE,
    is_whittle=True,
)
month_keys = sorted(df_map.keys())
day_keys = month_keys[DAY_IDX * 8:(DAY_IDX + 1) * 8]
if len(day_keys) != 8:
    raise ValueError(f'Day {DAY_IDX} has {len(day_keys)} slices, expected 8')

first_df = df_map[day_keys[0]].reset_index(drop=True)
grid_order = (
    first_df
    .assign(_orig_idx=np.arange(len(first_df)))
    .sort_values(['Longitude', 'Latitude', '_orig_idx'], kind='mergesort')['_orig_idx']
    .to_numpy(dtype=np.int64)
)
grid_coords_full = first_df.iloc[grid_order][['Latitude', 'Longitude']].to_numpy(dtype=np.float64)

print('monthly_mean:', round(monthly_mean, 4))
print('day keys:', day_keys[0], '...', day_keys[-1])
print('full grid:', grid_coords_full.shape)
print('unique lat/lon:', len(np.unique(np.round(grid_coords_full[:,0], 6))), len(np.unique(np.round(grid_coords_full[:,1], 6))))
# Out:
# --- Global Monthly Mean for 2024-7: 257.9726 ---
# monthly_mean: 257.9726
# day keys: 2024_07_y24m07day03_hm00:53 ... 2024_07_y24m07day03_hm07:48
# full grid: (18126, 2)
# unique lat/lon: 114 159

# %%
def load_hour_map(hour_idx):
    key = day_keys[int(hour_idx)]
    hour_df_map = {key: df_map[key]}
    hour_map, _ = loader.load_working_data(
        hour_df_map,
        monthly_mean=monthly_mean,
        idx_for_datamap=[0, 1],
        ord_mm=grid_order,
        dtype=DTYPE,
        keep_ori=True,
    )
    return {k: v.to(DEVICE) for k, v in hour_map.items()}, key


def thin_hour_map(hour_map, stride):
    n_full = grid_coords_full.shape[0]
    thin_idx = np.arange(0, n_full, int(stride), dtype=np.int64)
    thin_map = {k: v[thin_idx].contiguous() for k, v in hour_map.items()}
    thin_grid = np.ascontiguousarray(grid_coords_full[thin_idx])
    return thin_map, thin_grid, thin_idx


def build_model(input_map, grid_coords, smooth):
    return ColumnSpaceIsoTrendVecchiaFit(
        smooth=smooth,
        input_map=input_map,
        grid_coords=grid_coords,
        head_right_cols=COLUMN_SPEC['head_right_cols'],
        above_count=COLUMN_SPEC['above_count'],
        right_col_count=COLUMN_SPEC['right_col_count'],
        per_time_conditioning_count=COLUMN_SPEC['per_time_conditioning_count'],
        target_chunk_size=COLUMN_SPEC['target_chunk_size'],
        mean_design=MEAN_DESIGN,
    )


def make_base_row(hour_idx, time_key, stride, smooth, fit_type, n_grid, n_valid, pre_s, fit_s, loss, fit_iter, est, diag):
    row = {
        'date_str': f'{YEAR}{MONTH:02d}{DAY_IDX + 1:02d}',
        'day_idx': DAY_IDX,
        'hour_idx': int(hour_idx),
        'time_key': str(time_key),
        'resolution_stride': int(stride),
        'resolution_label': resolution_label(stride),
        'smooth': float(smooth),
        'mean_design': MEAN_DESIGN,
        'fit_type': fit_type,
        'model': COLUMN_SPEC['model'],
        'kernel': 'column_space_iso_tonly_realloc',
        'coord_mode': 'regular-grid every-k thinning; covariance on Source_Latitude/Source_Longitude',
        'loss': float(loss),
        'fit_iter_raw': int(fit_iter),
        'fit_steps_reported': int(fit_iter) + 1,
        'precompute_s': float(pre_s),
        'fit_s': float(fit_s),
        'total_s': float(pre_s + fit_s),
        'n_grid': int(n_grid),
        'n_valid': int(n_valid),
        'valid_fraction': float(n_valid / n_grid) if n_grid else np.nan,
        **{f'est_{p}': est[p] for p in P_LABELS},
        **diag,
        'total_conditioning_nominal': COLUMN_SPEC['per_time_conditioning_count'],
        'head_right_cols': COLUMN_SPEC['head_right_cols'],
        'above_count': COLUMN_SPEC['above_count'],
        'right_col_count': COLUMN_SPEC['right_col_count'],
        'per_time_conditioning_count': COLUMN_SPEC['per_time_conditioning_count'],
    }
    return row

# %%
def fit_full_iso(hour_idx, stride, smooth):
    hour_map, time_key = load_hour_map(hour_idx)
    thin_map, thin_grid, _ = thin_hour_map(hour_map, stride)
    n_grid = int(thin_grid.shape[0])
    n_valid = count_valid(thin_map)
    print('\n' + '=' * 90)
    print(f'FULL ISO | hour={hour_idx + 1} | {time_key} | {resolution_label(stride)} | n_grid={n_grid:,} | n_valid={n_valid:,}')

    model = build_model(thin_map, thin_grid, smooth)
    t_pre = time.time()
    model.precompute_conditioning_sets()
    pre_s = time.time() - t_pre
    diag = space_diag(model)

    params = make_full_params()
    opt = model.set_optimizer(params, lr=LBFGS_LR, max_iter=LBFGS_EVAL, max_eval=LBFGS_EVAL, history_size=LBFGS_HIST)
    t_fit = time.time()
    out, fit_iter = model.fit_vecc_lbfgs(params, opt, max_steps=LBFGS_STEPS_FULL, grad_tol=GRAD_TOL)
    fit_s = time.time() - t_fit
    est = backmap_iso(out[:3])
    row = make_base_row(hour_idx, time_key, stride, smooth, 'full', n_grid, n_valid, pre_s, fit_s, out[-1], fit_iter, est, diag)
    print('RESULT:', {k: round(v, 4) if isinstance(v, float) else v for k, v in row.items() if k in ['resolution_label','loss','est_sigmasq','est_range','est_nugget','total_s']})

    del model, params, opt, hour_map, thin_map
    empty_cache()
    return row


def fit_partial_iso(hour_idx, stride, smooth, anchor, fit_type):
    if fit_type == 'sigma_only_x1_anchor':
        free_name = 'sigmasq'
        fixed_names = ['range', 'nugget']
    elif fit_type == 'range_only_x1_anchor':
        free_name = 'range'
        fixed_names = ['sigmasq', 'nugget']
    else:
        raise ValueError(f'unknown fit_type={fit_type}')

    hour_map, time_key = load_hour_map(hour_idx)
    thin_map, thin_grid, _ = thin_hour_map(hour_map, stride)
    n_grid = int(thin_grid.shape[0])
    n_valid = count_valid(thin_map)
    print('\n' + '=' * 90)
    print(f'{fit_type} | hour={hour_idx + 1} | {time_key} | {resolution_label(stride)} | anchor=x1')

    model = build_model(thin_map, thin_grid, smooth)
    t_pre = time.time()
    model.precompute_conditioning_sets()
    pre_s = time.time() - t_pre
    diag = space_diag(model)

    fixed_log = {p: torch.tensor(np.log(anchor[p]), device=DEVICE, dtype=DTYPE) for p in P_LABELS}
    free_param = torch.tensor([np.log(anchor[free_name])], device=DEVICE, dtype=DTYPE, requires_grad=True)
    opt = model.set_optimizer([free_param], lr=LBFGS_LR, max_iter=LBFGS_EVAL, max_eval=LBFGS_EVAL, history_size=LBFGS_HIST)

    def assemble_params():
        pieces = []
        for p in P_LABELS:
            if p == free_name:
                pieces.append(free_param.reshape(()))
            else:
                pieces.append(fixed_log[p].reshape(()))
        return torch.stack(pieces)

    print('--- Starting partial Pure-Space Iso L-BFGS ---')
    t_fit = time.time()
    last_iter = 0
    loss = None
    for i in range(LBFGS_STEPS_PARTIAL):
        last_iter = i
        def closure():
            opt.zero_grad()
            l = model.vecchia_batched_likelihood(assemble_params())
            l.backward()
            return l
        loss = opt.step(closure)
        grad = abs(float(free_param.grad.detach().item())) if free_param.grad is not None else 0.0
        print(f'--- Step {i + 1}/{LBFGS_STEPS_PARTIAL} / Loss: {float(loss.detach().item()):.6f} / {free_name} Grad: {grad:.2e} ---')
        if grad < GRAD_TOL:
            break
    fit_s = time.time() - t_fit

    final_log = [float(x.detach().cpu().item()) for x in assemble_params()]
    est = backmap_iso(final_log)
    row = make_base_row(hour_idx, time_key, stride, smooth, fit_type, n_grid, n_valid, pre_s, fit_s, float(loss.detach().cpu().item()), last_iter, est, diag)
    row.update({
        'free_parameter': free_name,
        'fixed_parameters': ','.join(fixed_names),
        'anchor_resolution_label': 'x1',
        **{f'anchor_{p}': anchor[p] for p in P_LABELS},
    })
    print('RESULT:', {k: round(v, 4) if isinstance(v, float) else v for k, v in row.items() if k in ['resolution_label','loss','est_sigmasq','est_range','est_nugget','total_s']})

    del model, opt, free_param, hour_map, thin_map
    empty_cache()
    return row

# %%
full_rows = []
if RUN_FULL:
    for smooth in FIT_SMOOTHS:
        for hour_idx in HOUR_IDX_LIST:
            for stride in RESOLUTION_STRIDES:
                full_rows.append(fit_full_iso(hour_idx, stride, smooth))
                full_df_tmp = round_df(pd.DataFrame(full_rows))
                full_df_tmp.to_csv(OUT_DIR / f'{OUT_PREFIX}_full.csv', index=False, float_format=f'%.{ROUND_DECIMALS}f')

full_df = pd.DataFrame(full_rows)
full_path = OUT_DIR / f'{OUT_PREFIX}_full.csv'
round_df(full_df).to_csv(full_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
print('Saved full fits:', full_path)
display(round_df(full_df))
# Out:
# ==========================================================================================
# FULL ISO | hour=1 | 2024_07_y24m07day03_hm00:53 | x8 | n_grid=2,266 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.625674 / Max Grad: 7.08e-07 ---
# Converged: max_grad 7.08e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 10.086030739655005, 'range': 0.5287952966384377, 'nugget': 2.9859748617278994}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6257, 'total_s': 0.287, 'est_sigmasq': 10.086, 'est_range': 0.5288, 'est_nugget': 2.986}
#
# ==========================================================================================
# FULL ISO | hour=1 | 2024_07_y24m07day03_hm00:53 | x4 | n_grid=4,532 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.526557 / Max Grad: 6.19e-06 ---
# Converged: max_grad 6.19e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 10.79339069933846, 'range': 0.4469858007305377, 'nugget': 1.9478477854464462}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5266, 'total_s': 0.4504, 'est_sigmasq': 10.7934, 'est_range': 0.447, 'est_nugget': 1.9478}
#
# ==========================================================================================
# FULL ISO | hour=1 | 2024_07_y24m07day03_hm00:53 | x2 | n_grid=9,063 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.539227 / Max Grad: 1.84e-06 ---
# Converged: max_grad 1.84e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 11.98231452033941, 'range': 0.35748470286276124, 'nugget': 2.7318854667703807}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5392, 'total_s': 0.9924, 'est_sigmasq': 11.9823, 'est_range': 0.3575, 'est_nugget': 2.7319}
#
# ==========================================================================================
# FULL ISO | hour=1 | 2024_07_y24m07day03_hm00:53 | x1 | n_grid=18,126 | n_valid=18,067
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18067, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.425960 / Max Grad: 9.32e-07 ---
# Converged: max_grad 9.32e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.06938478858794, 'range': 0.337265728731637, 'nugget': 1.8090552426488693}
# RESULT: {'resolution_label': 'x1', 'loss': 1.426, 'total_s': 2.2463, 'est_sigmasq': 12.0694, 'est_range': 0.3373, 'est_nugget': 1.8091}
#
# ==========================================================================================
# FULL ISO | hour=2 | 2024_07_y24m07day03_hm01:53 | x8 | n_grid=2,266 | n_valid=2,208
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2208, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.662672 / Max Grad: 2.97e-06 ---
# Converged: max_grad 2.97e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.075723586113734, 'range': 0.4395000657824385, 'nugget': 1.9006814650522295}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6627, 'total_s': 0.2145, 'est_sigmasq': 13.0757, 'est_range': 0.4395, 'est_nugget': 1.9007}
#
# ==========================================================================================
# FULL ISO | hour=2 | 2024_07_y24m07day03_hm01:53 | x4 | n_grid=4,532 | n_valid=4,422
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4422, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.550718 / Max Grad: 6.21e-07 ---
# Converged: max_grad 6.21e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.618649986733898, 'range': 0.40763009403254796, 'nugget': 0.5796563713463997}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5507, 'total_s': 0.6361, 'est_sigmasq': 14.6186, 'est_range': 0.4076, 'est_nugget': 0.5797}
#
# ==========================================================================================
# FULL ISO | hour=2 | 2024_07_y24m07day03_hm01:53 | x2 | n_grid=9,063 | n_valid=8,840
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=8840, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.448621 / Max Grad: 6.26e-06 ---
# Converged: max_grad 6.26e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.486083608439797, 'range': 0.3584754910759071, 'nugget': 0.4757850265145225}
# RESULT: {'resolution_label': 'x2', 'loss': 1.4486, 'total_s': 1.3025, 'est_sigmasq': 14.4861, 'est_range': 0.3585, 'est_nugget': 0.4758}
#
# ==========================================================================================
# FULL ISO | hour=2 | 2024_07_y24m07day03_hm01:53 | x1 | n_grid=18,126 | n_valid=17,670
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=17670, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.390133 / Max Grad: 9.80e-07 ---
# Converged: max_grad 9.80e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.14412725632508, 'range': 0.31885191232288657, 'nugget': 0.5996103350012909}
# RESULT: {'resolution_label': 'x1', 'loss': 1.3901, 'total_s': 2.8942, 'est_sigmasq': 14.1441, 'est_range': 0.3189, 'est_nugget': 0.5996}
#
# ==========================================================================================
# FULL ISO | hour=3 | 2024_07_y24m07day03_hm02:53 | x8 | n_grid=2,266 | n_valid=2,082
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2082, m mean/med/max=8.6/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.711815 / Max Grad: 1.17e-06 ---
# Converged: max_grad 1.17e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.928123684709412, 'range': 0.4886626842254137, 'nugget': 2.1906211564009186}
# RESULT: {'resolution_label': 'x8', 'loss': 1.7118, 'total_s': 0.2079, 'est_sigmasq': 14.9281, 'est_range': 0.4887, 'est_nugget': 2.1906}
#
# ==========================================================================================
# FULL ISO | hour=3 | 2024_07_y24m07day03_hm02:53 | x4 | n_grid=4,532 | n_valid=4,176
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4176, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.618131 / Max Grad: 1.23e-06 ---
# Converged: max_grad 1.23e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.61551459213677, 'range': 0.4576311678017649, 'nugget': 1.7235052759202316}
# RESULT: {'resolution_label': 'x4', 'loss': 1.6181, 'total_s': 0.4287, 'est_sigmasq': 15.6155, 'est_range': 0.4576, 'est_nugget': 1.7235}
#
# ==========================================================================================
# FULL ISO | hour=3 | 2024_07_y24m07day03_hm02:53 | x2 | n_grid=9,063 | n_valid=8,353
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=8353, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.487391 / Max Grad: 3.66e-04 ---
# --- Step 2/8 / Loss: 1.459682 / Max Grad: 4.93e-06 ---
# Converged: max_grad 4.93e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 16.64191480077625, 'range': 0.3254216887316489, 'nugget': 8.517618153440796e-05}
# RESULT: {'resolution_label': 'x2', 'loss': 1.4597, 'total_s': 2.0122, 'est_sigmasq': 16.6419, 'est_range': 0.3254, 'est_nugget': 0.0001}
#
# ==========================================================================================
# FULL ISO | hour=3 | 2024_07_y24m07day03_hm02:53 | x1 | n_grid=18,126 | n_valid=16,698
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.7s. grid=114x159, heads=0, tails=16698, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.397929 / Max Grad: 1.14e-03 ---
# --- Step 2/8 / Loss: 1.357006 / Max Grad: 3.66e-06 ---
# Converged: max_grad 3.66e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 17.016188728155132, 'range': 0.340149694280143, 'nugget': 0.0001570097527026209}
# RESULT: {'resolution_label': 'x1', 'loss': 1.357, 'total_s': 3.3049, 'est_sigmasq': 17.0162, 'est_range': 0.3401, 'est_nugget': 0.0002}
#
# ==========================================================================================
# FULL ISO | hour=4 | 2024_07_y24m07day03_hm03:53 | x8 | n_grid=2,266 | n_valid=2,114
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2114, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.748117 / Max Grad: 2.76e-06 ---
# Converged: max_grad 2.76e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 17.232421527545448, 'range': 0.4212046488928591, 'nugget': 1.370344542284056}
# RESULT: {'resolution_label': 'x8', 'loss': 1.7481, 'total_s': 0.2377, 'est_sigmasq': 17.2324, 'est_range': 0.4212, 'est_nugget': 1.3703}
#
# ==========================================================================================
# FULL ISO | hour=4 | 2024_07_y24m07day03_hm03:53 | x4 | n_grid=4,532 | n_valid=4,217
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4217, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.648637 / Max Grad: 9.34e-06 ---
# Converged: max_grad 9.34e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 17.954903654632272, 'range': 0.40098302200597996, 'nugget': 0.8815838491519575}
# RESULT: {'resolution_label': 'x4', 'loss': 1.6486, 'total_s': 0.4811, 'est_sigmasq': 17.9549, 'est_range': 0.401, 'est_nugget': 0.8816}
#
# ==========================================================================================
# FULL ISO | hour=4 | 2024_07_y24m07day03_hm03:53 | x2 | n_grid=9,063 | n_valid=8,428
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=8428, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.507624 / Max Grad: 5.17e-05 ---
# --- Step 2/8 / Loss: 1.481137 / Max Grad: 8.20e-06 ---
# Converged: max_grad 8.20e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 18.427733588813794, 'range': 0.36136067108968833, 'nugget': 0.00013717379926679436}
# RESULT: {'resolution_label': 'x2', 'loss': 1.4811, 'total_s': 1.5872, 'est_sigmasq': 18.4277, 'est_range': 0.3614, 'est_nugget': 0.0001}
#
# ==========================================================================================
# FULL ISO | hour=4 | 2024_07_y24m07day03_hm03:53 | x1 | n_grid=18,126 | n_valid=16,863
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.7s. grid=114x159, heads=0, tails=16863, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.420725 / Max Grad: 3.49e-04 ---
# --- Step 2/8 / Loss: 1.384112 / Max Grad: 6.79e-06 ---
# Converged: max_grad 6.79e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 18.541234588028118, 'range': 0.35929654557460583, 'nugget': 0.0002650800638207786}
# RESULT: {'resolution_label': 'x1', 'loss': 1.3841, 'total_s': 3.2873, 'est_sigmasq': 18.5412, 'est_range': 0.3593, 'est_nugget': 0.0003}
#
# ==========================================================================================
# FULL ISO | hour=5 | 2024_07_y24m07day03_hm04:48 | x8 | n_grid=2,266 | n_valid=2,145
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2145, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.785422 / Max Grad: 1.34e-06 ---
# Converged: max_grad 1.34e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 16.0280285017878, 'range': 0.40737437345237304, 'nugget': 2.7050367201267957}
# RESULT: {'resolution_label': 'x8', 'loss': 1.7854, 'total_s': 0.2509, 'est_sigmasq': 16.028, 'est_range': 0.4074, 'est_nugget': 2.705}
#
# ==========================================================================================
# FULL ISO | hour=5 | 2024_07_y24m07day03_hm04:48 | x4 | n_grid=4,532 | n_valid=4,288
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4288, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.699188 / Max Grad: 3.00e-06 ---
# Converged: max_grad 3.00e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 17.346961303420606, 'range': 0.32718583559272474, 'nugget': 1.3400832990824334}
# RESULT: {'resolution_label': 'x4', 'loss': 1.6992, 'total_s': 0.5869, 'est_sigmasq': 17.347, 'est_range': 0.3272, 'est_nugget': 1.3401}
#
# ==========================================================================================
# FULL ISO | hour=5 | 2024_07_y24m07day03_hm04:48 | x2 | n_grid=9,063 | n_valid=8,552
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=8552, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.549105 / Max Grad: 7.94e-04 ---
# --- Step 2/8 / Loss: 1.532255 / Max Grad: 4.20e-06 ---
# Converged: max_grad 4.20e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 19.465423056098878, 'range': 0.3317070847744377, 'nugget': 4.428467913046425e-05}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5323, 'total_s': 1.7499, 'est_sigmasq': 19.4654, 'est_range': 0.3317, 'est_nugget': 0.0}
#
# ==========================================================================================
# FULL ISO | hour=5 | 2024_07_y24m07day03_hm04:48 | x1 | n_grid=18,126 | n_valid=17,088
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.7s. grid=114x159, heads=0, tails=17088, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.451085 / Max Grad: 1.41e-04 ---
# --- Step 2/8 / Loss: 1.423525 / Max Grad: 3.82e-06 ---
# Converged: max_grad 3.82e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 19.18948107359827, 'range': 0.3323972866177117, 'nugget': 4.97459925465903e-06}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4235, 'total_s': 4.3363, 'est_sigmasq': 19.1895, 'est_range': 0.3324, 'est_nugget': 0.0}
#
# ==========================================================================================
# FULL ISO | hour=6 | 2024_07_y24m07day03_hm05:48 | x8 | n_grid=2,266 | n_valid=2,221
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2221, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.756421 / Max Grad: 9.00e-07 ---
# Converged: max_grad 9.00e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.286469772431953, 'range': 0.3689133386255968, 'nugget': 2.2663900138719995}
# RESULT: {'resolution_label': 'x8', 'loss': 1.7564, 'total_s': 0.2242, 'est_sigmasq': 15.2865, 'est_range': 0.3689, 'est_nugget': 2.2664}
#
# ==========================================================================================
# FULL ISO | hour=6 | 2024_07_y24m07day03_hm05:48 | x4 | n_grid=4,532 | n_valid=4,439
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4439, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.658525 / Max Grad: 2.71e-06 ---
# Converged: max_grad 2.71e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 16.147183884281333, 'range': 0.3287434693391677, 'nugget': 1.2046279598076}
# RESULT: {'resolution_label': 'x4', 'loss': 1.6585, 'total_s': 0.5004, 'est_sigmasq': 16.1472, 'est_range': 0.3287, 'est_nugget': 1.2046}
#
# ==========================================================================================
# FULL ISO | hour=6 | 2024_07_y24m07day03_hm05:48 | x2 | n_grid=9,063 | n_valid=8,881
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=8881, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.531173 / Max Grad: 4.76e-04 ---
# --- Step 2/8 / Loss: 1.516151 / Max Grad: 3.80e-06 ---
# Converged: max_grad 3.80e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 17.22083608602374, 'range': 0.27962621212360345, 'nugget': 8.139565703587993e-05}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5162, 'total_s': 1.8583, 'est_sigmasq': 17.2208, 'est_range': 0.2796, 'est_nugget': 0.0001}
#
# ==========================================================================================
# FULL ISO | hour=6 | 2024_07_y24m07day03_hm05:48 | x1 | n_grid=18,126 | n_valid=17,760
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=17760, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.446916 / Max Grad: 3.10e-05 ---
# --- Step 2/8 / Loss: 1.422028 / Max Grad: 5.70e-07 ---
# Converged: max_grad 5.70e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 17.206029494039836, 'range': 0.2745264588474176, 'nugget': 1.670886295835601e-05}
# RESULT: {'resolution_label': 'x1', 'loss': 1.422, 'total_s': 4.5032, 'est_sigmasq': 17.206, 'est_range': 0.2745, 'est_nugget': 0.0}
#
# ==========================================================================================
# FULL ISO | hour=7 | 2024_07_y24m07day03_hm06:48 | x8 | n_grid=2,266 | n_valid=2,264
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2264, m mean/med/max=8.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.697213 / Max Grad: 3.34e-06 ---
# Converged: max_grad 3.34e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.91910003841192, 'range': 0.34164245504322727, 'nugget': 2.1552117010952387}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6972, 'total_s': 0.2028, 'est_sigmasq': 12.9191, 'est_range': 0.3416, 'est_nugget': 2.1552}
#
# ==========================================================================================
# FULL ISO | hour=7 | 2024_07_y24m07day03_hm06:48 | x4 | n_grid=4,532 | n_valid=4,527
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4527, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.624533 / Max Grad: 4.58e-06 ---
# Converged: max_grad 4.58e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.39694499244301, 'range': 0.384486293335106, 'nugget': 2.3376344855942697}
# RESULT: {'resolution_label': 'x4', 'loss': 1.6245, 'total_s': 0.3877, 'est_sigmasq': 13.3969, 'est_range': 0.3845, 'est_nugget': 2.3376}
#
# ==========================================================================================
# FULL ISO | hour=7 | 2024_07_y24m07day03_hm06:48 | x2 | n_grid=9,063 | n_valid=9,052
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9052, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.505991 / Max Grad: 5.03e-07 ---
# Converged: max_grad 5.03e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.78372570824437, 'range': 0.2644044222759915, 'nugget': 0.4094639590965674}
# RESULT: {'resolution_label': 'x2', 'loss': 1.506, 'total_s': 1.38, 'est_sigmasq': 14.7837, 'est_range': 0.2644, 'est_nugget': 0.4095}
#
# ==========================================================================================
# FULL ISO | hour=7 | 2024_07_y24m07day03_hm06:48 | x1 | n_grid=18,126 | n_valid=18,104
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18104, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.414566 / Max Grad: 1.42e-03 ---
# --- Step 2/8 / Loss: 1.380785 / Max Grad: 8.01e-06 ---
# Converged: max_grad 8.01e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.972905652902542, 'range': 0.24770207951331943, 'nugget': 9.501330826485053e-05}
# RESULT: {'resolution_label': 'x1', 'loss': 1.3808, 'total_s': 4.2315, 'est_sigmasq': 14.9729, 'est_range': 0.2477, 'est_nugget': 0.0001}
#
# ==========================================================================================
# FULL ISO | hour=8 | 2024_07_y24m07day03_hm07:48 | x8 | n_grid=2,266 | n_valid=2,263
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2263, m mean/med/max=8.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.724195 / Max Grad: 2.40e-07 ---
# Converged: max_grad 2.40e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 11.320929610319645, 'range': 0.38387392569663364, 'nugget': 3.8548656452335077}
# RESULT: {'resolution_label': 'x8', 'loss': 1.7242, 'total_s': 0.2859, 'est_sigmasq': 11.3209, 'est_range': 0.3839, 'est_nugget': 3.8549}
#
# ==========================================================================================
# FULL ISO | hour=8 | 2024_07_y24m07day03_hm07:48 | x4 | n_grid=4,532 | n_valid=4,526
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4526, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.612353 / Max Grad: 8.37e-06 ---
# Converged: max_grad 8.37e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.37826443253522, 'range': 0.33745666757675313, 'nugget': 2.1959839204512193}
# RESULT: {'resolution_label': 'x4', 'loss': 1.6124, 'total_s': 0.4393, 'est_sigmasq': 12.3783, 'est_range': 0.3375, 'est_nugget': 2.196}
#
# ==========================================================================================
# FULL ISO | hour=8 | 2024_07_y24m07day03_hm07:48 | x2 | n_grid=9,063 | n_valid=9,051
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9051, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.494666 / Max Grad: 4.49e-04 ---
# --- Step 2/8 / Loss: 1.475349 / Max Grad: 2.76e-06 ---
# Converged: max_grad 2.76e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.175968880287263, 'range': 0.23126941594973946, 'nugget': 0.06668246134041872}
# RESULT: {'resolution_label': 'x2', 'loss': 1.4753, 'total_s': 1.8994, 'est_sigmasq': 14.176, 'est_range': 0.2313, 'est_nugget': 0.0667}
#
# ==========================================================================================
# FULL ISO | hour=8 | 2024_07_y24m07day03_hm07:48 | x1 | n_grid=18,126 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.425008 / Max Grad: 3.07e-04 ---
# --- Step 2/8 / Loss: 1.399223 / Max Grad: 7.59e-06 ---
# Converged: max_grad 7.59e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.797543800611638, 'range': 0.2005081648146049, 'nugget': 1.4664575173760891e-05}
# RESULT: {'resolution_label': 'x1', 'loss': 1.3992, 'total_s': 4.7077, 'est_sigmasq': 13.7975, 'est_range': 0.2005, 'est_nugget': 0.0}
# Saved full fits: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_iso_column_resolution_s03_050826_full.csv
#     date_str  day_idx  hour_idx                     time_key  resolution_stride resolution_label  smooth mean_design fit_type                                  model  \
# 0   20240703        2         0  2024_07_y24m07day03_hm00:53                  8               x8     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 1   20240703        2         0  2024_07_y24m07day03_hm00:53                  4               x4     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 2   20240703        2         0  2024_07_y24m07day03_hm00:53                  2               x2     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 3   20240703        2         0  2024_07_y24m07day03_hm00:53                  1               x1     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 4   20240703        2         1  2024_07_y24m07day03_hm01:53                  8               x8     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 5   20240703        2         1  2024_07_y24m07day03_hm01:53                  4               x4     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 6   20240703        2         1  2024_07_y24m07day03_hm01:53                  2               x2     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 7   20240703        2         1  2024_07_y24m07day03_hm01:53                  1               x1     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 8   20240703        2         2  2024_07_y24m07day03_hm02:53                  8               x8     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 9   20240703        2         2  2024_07_y24m07day03_hm02:53                  4               x4     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 10  20240703        2         2  2024_07_y24m07day03_hm02:53                  2               x2     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 11  20240703        2         2  2024_07_y24m07day03_hm02:53                  1               x1     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 12  20240703        2         3  2024_07_y24m07day03_hm03:53                  8               x8     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 13  20240703        2         3  2024_07_y24m07day03_hm03:53                  4               x4     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 14  20240703        2         3  2024_07_y24m07day03_hm03:53                  2               x2     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 15  20240703        2         3  2024_07_y24m07day03_hm03:53                  1               x1     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 16  20240703        2         4  2024_07_y24m07day03_hm04:48                  8               x8     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 17  20240703        2         4  2024_07_y24m07day03_hm04:48                  4               x4     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 18  20240703        2         4  2024_07_y24m07day03_hm04:48                  2               x2     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 19  20240703        2         4  2024_07_y24m07day03_hm04:48                  1               x1     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 20  20240703        2         5  2024_07_y24m07day03_hm05:48                  8               x8     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 21  20240703        2         5  2024_07_y24m07day03_hm05:48                  4               x4     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 22  20240703        2         5  2024_07_y24m07day03_hm05:48                  2               x2     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 23  20240703        2         5  2024_07_y24m07day03_hm05:48                  1               x1     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 24  20240703        2         6  2024_07_y24m07day03_hm06:48                  8               x8     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 25  20240703        2         6  2024_07_y24m07day03_hm06:48                  4               x4     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 26  20240703        2         6  2024_07_y24m07day03_hm06:48                  2               x2     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 27  20240703        2         6  2024_07_y24m07day03_hm06:48                  1               x1     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 28  20240703        2         7  2024_07_y24m07day03_hm07:48                  8               x8     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 29  20240703        2         7  2024_07_y24m07day03_hm07:48                  4               x4     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 30  20240703        2         7  2024_07_y24m07day03_hm07:48                  2               x2     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
# 31  20240703        2         7  2024_07_y24m07day03_hm07:48                  1               x1     0.3      latlon     full  ColumnSpaceIso_Up2_Right3_M10_realloc
#
#                             kernel                                         coord_mode    loss  fit_iter_raw  fit_steps_reported  precompute_s   fit_s  total_s  n_grid  n_valid  \
# 0   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.6257             0                   1        0.0371  0.2499   0.2870    2266     2259
# 1   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.5266             0                   1        0.0842  0.3663   0.4504    4532     4518
# 2   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.5392             0                   1        0.2348  0.7577   0.9924    9063     9033
# 3   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.4260             0                   1        0.7742  1.4721   2.2463   18126    18067
# 4   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.6627             0                   1        0.0347  0.1798   0.2145    2266     2208
# 5   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.5507             0                   1        0.0827  0.5534   0.6361    4532     4422
# 6   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.4486             0                   1        0.2218  1.0806   1.3025    9063     8840
# 7   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.3901             0                   1        0.7668  2.1273   2.8942   18126    17670
# 8   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.7118             0                   1        0.0330  0.1749   0.2079    2266     2082
# 9   column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.6181             0                   1        0.0782  0.3505   0.4287    4532     4176
# 10  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.4597             1                   2        0.2056  1.8066   2.0122    9063     8353
# 11  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.3570             1                   2        0.7008  2.6041   3.3049   18126    16698
# 12  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.7481             0                   1        0.0327  0.2050   0.2377    2266     2114
# 13  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.6486             0                   1        0.0776  0.4035   0.4811    4532     4217
# 14  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.4811             1                   2        0.2069  1.3803   1.5872    9063     8428
# 15  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.3841             1                   2        0.7129  2.5745   3.2873   18126    16863
# 16  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.7854             0                   1        0.0337  0.2172   0.2509    2266     2145
# 17  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.6992             0                   1        0.0810  0.5058   0.5869    4532     4288
# 18  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.5323             1                   2        0.2107  1.5392   1.7499    9063     8552
# 19  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.4235             1                   2        0.7231  3.6133   4.3363   18126    17088
# 20  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.7564             0                   1        0.0347  0.1895   0.2242    2266     2221
# 21  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.6585             0                   1        0.0831  0.4172   0.5004    4532     4439
# 22  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.5162             1                   2        0.2213  1.6370   1.8583    9063     8881
# 23  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.4220             1                   2        0.7724  3.7308   4.5032   18126    17760
# 24  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.6972             0                   1        0.0355  0.1673   0.2028    2266     2264
# 25  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.6245             0                   1        0.0841  0.3036   0.3877    4532     4527
# 26  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.5060             0                   1        0.2236  1.1563   1.3800    9063     9052
# 27  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.3808             1                   2        0.7792  3.4524   4.2315   18126    18104
# 28  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.7242             0                   1        0.0359  0.2501   0.2859    2266     2263
# 29  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.6124             0                   1        0.0868  0.3525   0.4393    4532     4526
# 30  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.4753             1                   2        0.2255  1.6738   1.8994    9063     9051
# 31  column_space_iso_tonly_realloc  regular-grid every-k thinning; covariance on S...  1.3992             1                   2        0.7885  3.9192   4.7077   18126    18102
#
#     valid_fraction  est_sigmasq  est_range  est_nugget  n_batches  n_tails  mean_m  max_m  largest_batch_n  total_conditioning_nominal  head_right_cols  above_count  \
# 0           0.9969      10.0860     0.5288      2.9860          1     2259    10.0     10             2259                          10                0            2
# 1           0.9969      10.7934     0.4470      1.9478          1     4518    10.0     10             4518                          10                0            2
# 2           0.9967      11.9823     0.3575      2.7319          1     9033    10.0     10             9033                          10                0            2
# 3           0.9967      12.0694     0.3373      1.8091          1    18067    10.0     10            18067                          10                0            2
# 4           0.9744      13.0757     0.4395      1.9007          1     2208    10.0     10             2208                          10                0            2
# 5           0.9757      14.6186     0.4076      0.5797          1     4422    10.0     10             4422                          10                0            2
# 6           0.9754      14.4861     0.3585      0.4758          1     8840    10.0     10             8840                          10                0            2
# 7           0.9748      14.1441     0.3189      0.5996          1    17670    10.0     10            17670                          10                0            2
# 8           0.9188      14.9281     0.4887      2.1906          1     2082    10.0     10             2082                          10                0            2
# 9           0.9214      15.6155     0.4576      1.7235          1     4176    10.0     10             4176                          10                0            2
# 10          0.9217      16.6419     0.3254      0.0001          1     8353    10.0     10             8353                          10                0            2
# 11          0.9212      17.0162     0.3401      0.0002          1    16698    10.0     10            16698                          10                0            2
# 12          0.9329      17.2324     0.4212      1.3703          1     2114    10.0     10             2114                          10                0            2
# 13          0.9305      17.9549     0.4010      0.8816          1     4217    10.0     10             4217                          10                0            2
# 14          0.9299      18.4277     0.3614      0.0001          1     8428    10.0     10             8428                          10                0            2
# 15          0.9303      18.5412     0.3593      0.0003          1    16863    10.0     10            16863                          10                0            2
# 16          0.9466      16.0280     0.4074      2.7050          1     2145    10.0     10             2145                          10                0            2
# 17          0.9462      17.3470     0.3272      1.3401          1     4288    10.0     10             4288                          10                0            2
# 18          0.9436      19.4654     0.3317      0.0000          1     8552    10.0     10             8552                          10                0            2
# 19          0.9427      19.1895     0.3324      0.0000          1    17088    10.0     10            17088                          10                0            2
# 20          0.9801      15.2865     0.3689      2.2664          1     2221    10.0     10             2221                          10                0            2
# 21          0.9795      16.1472     0.3287      1.2046          1     4439    10.0     10             4439                          10                0            2
# 22          0.9799      17.2208     0.2796      0.0001          1     8881    10.0     10             8881                          10                0            2
# 23          0.9798      17.2060     0.2745      0.0000          1    17760    10.0     10            17760                          10                0            2
# 24          0.9991      12.9191     0.3416      2.1552          1     2264    10.0     10             2264                          10                0            2
# 25          0.9989      13.3969     0.3845      2.3376          1     4527    10.0     10             4527                          10                0            2
# 26          0.9988      14.7837     0.2644      0.4095          1     9052    10.0     10             9052                          10                0            2
# 27          0.9988      14.9729     0.2477      0.0001          1    18104    10.0     10            18104                          10                0            2
# 28          0.9987      11.3209     0.3839      3.8549          1     2263    10.0     10             2263                          10                0            2
# 29          0.9987      12.3783     0.3375      2.1960          1     4526    10.0     10             4526                          10                0            2
# 30          0.9987      14.1760     0.2313      0.0667          1     9051    10.0     10             9051                          10                0            2
# 31          0.9987      13.7975     0.2005      0.0000          1    18102    10.0     10            18102                          10                0            2
#
#     right_col_count  per_time_conditioning_count
# 0                 3                           10
# 1                 3                           10
# 2                 3                           10
# 3                 3                           10
# 4                 3                           10
# 5                 3                           10
# 6                 3                           10
# 7                 3                           10
# 8                 3                           10
# 9                 3                           10
# 10                3                           10
# 11                3                           10
# 12                3                           10
# 13                3                           10
# 14                3                           10
# 15                3                           10
# 16                3                           10
# 17                3                           10
# 18                3                           10
# 19                3                           10
# 20                3                           10
# 21                3                           10
# 22                3                           10
# 23                3                           10
# 24                3                           10
# 25                3                           10
# 26                3                           10
# 27                3                           10
# 28                3                           10
# 29                3                           10
# 30                3                           10
# 31                3                           10

# %%
partial_rows = []
if RUN_PARTIAL:
    if 'full_df' not in globals() or full_df.empty:
        full_path = OUT_DIR / f'{OUT_PREFIX}_full.csv'
        full_df = pd.read_csv(full_path)

    anchor_rows = full_df[full_df['resolution_stride'] == 1].copy()
    anchors = {
        (int(r.hour_idx), float(r.smooth)): {
            'sigmasq': float(r.est_sigmasq),
            'range': float(r.est_range),
            'nugget': float(r.est_nugget),
        }
        for r in anchor_rows.itertuples(index=False)
    }
    print('anchors from x1 full fits:', anchors)

    for smooth in FIT_SMOOTHS:
        for hour_idx in HOUR_IDX_LIST:
            anchor = anchors[(int(hour_idx), float(smooth))]
            for fit_type in ['sigma_only_x1_anchor', 'range_only_x1_anchor']:
                for stride in RESOLUTION_STRIDES:
                    partial_rows.append(fit_partial_iso(hour_idx, stride, smooth, anchor, fit_type))
                    partial_df_tmp = round_df(pd.DataFrame(partial_rows))
                    partial_df_tmp.to_csv(OUT_DIR / f'{OUT_PREFIX}_partial.csv', index=False, float_format=f'%.{ROUND_DECIMALS}f')

partial_df = pd.DataFrame(partial_rows)
partial_path = OUT_DIR / f'{OUT_PREFIX}_partial.csv'
round_df(partial_df).to_csv(partial_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
print('Saved partial fits:', partial_path)
display(round_df(partial_df))
# Out:
# Saved partial fits: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_iso_column_resolution_s03_050826_partial.csv
# Empty DataFrame
# Columns: []
# Index: []

# %%
all_df = pd.concat([full_df, partial_df], ignore_index=True, sort=False)
all_path = OUT_DIR / f'{OUT_PREFIX}_all.csv'
round_df(all_df).to_csv(all_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
print('Saved all:', all_path)

param_rows = []
for _, row in all_df.iterrows():
    for p in P_LABELS:
        param_rows.append({
            'date_str': row['date_str'],
            'hour_idx': int(row['hour_idx']),
            'time_key': row['time_key'],
            'resolution_stride': int(row['resolution_stride']),
            'resolution_label': row['resolution_label'],
            'fit_type': row['fit_type'],
            'parameter': p,
            'estimate': row[f'est_{p}'],
            'loss': row['loss'],
            'n_grid': row['n_grid'],
            'n_valid': row['n_valid'],
        })
param_df = pd.DataFrame(param_rows)
param_path = OUT_DIR / f'{OUT_PREFIX}_param_table.csv'
round_df(param_df).to_csv(param_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
print('Saved param table:', param_path)

display_cols = ['hour_idx', 'resolution_stride', 'resolution_label', 'fit_type', 'loss', 'est_sigmasq', 'est_range', 'est_nugget', 'n_grid', 'n_valid', 'total_s']
display(round_df(all_df[display_cols].sort_values(['fit_type', 'hour_idx', 'resolution_stride'])))
# Out:
# Saved all: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_iso_column_resolution_s03_050826_all.csv
# Saved param table: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_iso_column_resolution_s03_050826_param_table.csv
#     hour_idx  resolution_stride resolution_label fit_type    loss  est_sigmasq  est_range  est_nugget  n_grid  n_valid  total_s
# 3          0                  1               x1     full  1.4260      12.0694     0.3373      1.8091   18126    18067   2.2463
# 2          0                  2               x2     full  1.5392      11.9823     0.3575      2.7319    9063     9033   0.9924
# 1          0                  4               x4     full  1.5266      10.7934     0.4470      1.9478    4532     4518   0.4504
# 0          0                  8               x8     full  1.6257      10.0860     0.5288      2.9860    2266     2259   0.2870
# 7          1                  1               x1     full  1.3901      14.1441     0.3189      0.5996   18126    17670   2.8942
# 6          1                  2               x2     full  1.4486      14.4861     0.3585      0.4758    9063     8840   1.3025
# 5          1                  4               x4     full  1.5507      14.6186     0.4076      0.5797    4532     4422   0.6361
# 4          1                  8               x8     full  1.6627      13.0757     0.4395      1.9007    2266     2208   0.2145
# 11         2                  1               x1     full  1.3570      17.0162     0.3401      0.0002   18126    16698   3.3049
# 10         2                  2               x2     full  1.4597      16.6419     0.3254      0.0001    9063     8353   2.0122
# 9          2                  4               x4     full  1.6181      15.6155     0.4576      1.7235    4532     4176   0.4287
# 8          2                  8               x8     full  1.7118      14.9281     0.4887      2.1906    2266     2082   0.2079
# 15         3                  1               x1     full  1.3841      18.5412     0.3593      0.0003   18126    16863   3.2873
# 14         3                  2               x2     full  1.4811      18.4277     0.3614      0.0001    9063     8428   1.5872
# 13         3                  4               x4     full  1.6486      17.9549     0.4010      0.8816    4532     4217   0.4811
# 12         3                  8               x8     full  1.7481      17.2324     0.4212      1.3703    2266     2114   0.2377
# 19         4                  1               x1     full  1.4235      19.1895     0.3324      0.0000   18126    17088   4.3363
# 18         4                  2               x2     full  1.5323      19.4654     0.3317      0.0000    9063     8552   1.7499
# 17         4                  4               x4     full  1.6992      17.3470     0.3272      1.3401    4532     4288   0.5869
# 16         4                  8               x8     full  1.7854      16.0280     0.4074      2.7050    2266     2145   0.2509
# 23         5                  1               x1     full  1.4220      17.2060     0.2745      0.0000   18126    17760   4.5032
# 22         5                  2               x2     full  1.5162      17.2208     0.2796      0.0001    9063     8881   1.8583
# 21         5                  4               x4     full  1.6585      16.1472     0.3287      1.2046    4532     4439   0.5004
# 20         5                  8               x8     full  1.7564      15.2865     0.3689      2.2664    2266     2221   0.2242
# 27         6                  1               x1     full  1.3808      14.9729     0.2477      0.0001   18126    18104   4.2315
# 26         6                  2               x2     full  1.5060      14.7837     0.2644      0.4095    9063     9052   1.3800
# 25         6                  4               x4     full  1.6245      13.3969     0.3845      2.3376    4532     4527   0.3877
# 24         6                  8               x8     full  1.6972      12.9191     0.3416      2.1552    2266     2264   0.2028
# 31         7                  1               x1     full  1.3992      13.7975     0.2005      0.0000   18126    18102   4.7077
# 30         7                  2               x2     full  1.4753      14.1760     0.2313      0.0667    9063     9051   1.8994
# 29         7                  4               x4     full  1.6124      12.3783     0.3375      2.1960    4532     4526   0.4393
# 28         7                  8               x8     full  1.7242      11.3209     0.3839      3.8549    2266     2263   0.2859

# %%
# Full-fit parameter trajectories: one line per hour.
plot_full = full_df.copy()
plot_full['resolution_label'] = pd.Categorical(
    plot_full['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
)
plot_full = plot_full.sort_values(['hour_idx', 'resolution_label'])

fig, axes = plt.subplots(1, 3, figsize=(15, 4), constrained_layout=True)
for ax, p in zip(axes, P_LABELS):
    for hour_idx, sub in plot_full.groupby('hour_idx'):
        ax.plot(sub['resolution_label'].astype(str), sub[f'est_{p}'], marker='o', linewidth=1.6, label=f'h{int(hour_idx)+1}')
    ax.set_title(f'full fit: {p}')
    ax.set_xlabel('resolution thinning')
    ax.set_ylabel('estimate')
    ax.grid(True, alpha=0.3)
axes[-1].legend(ncol=2, fontsize=8, title='hour')
fig.suptitle('Pure-space isotropic Column Vecchia: full-fit parameter trajectories', fontsize=14)
full_plot_path = OUT_DIR / f'{OUT_PREFIX}_full_parameter_trajectories.png'
fig.savefig(full_plot_path, dpi=180, bbox_inches='tight')
print('Saved:', full_plot_path)
plt.show()
# Out:
# Saved: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_iso_column_resolution_s03_050826_full_parameter_trajectories.png

# %%
# Partial-fit trajectories: sigma-only and range-only using x1 full-fit anchor.
if not partial_df.empty:
    plot_partial = partial_df.copy()
    plot_partial['resolution_label'] = pd.Categorical(
        plot_partial['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
    )
    plot_partial = plot_partial.sort_values(['fit_type', 'hour_idx', 'resolution_label'])

    fig, axes = plt.subplots(1, 2, figsize=(12, 4), constrained_layout=True)
    specs = [
        ('sigma_only_x1_anchor', 'sigmasq', 'sigma-only: estimated sigmasq'),
        ('range_only_x1_anchor', 'range', 'range-only: estimated range'),
    ]
    for ax, (fit_type, p, title) in zip(axes, specs):
        sub0 = plot_partial[plot_partial['fit_type'] == fit_type]
        for hour_idx, sub in sub0.groupby('hour_idx'):
            ax.plot(sub['resolution_label'].astype(str), sub[f'est_{p}'], marker='o', linewidth=1.6, label=f'h{int(hour_idx)+1}')
        ax.set_title(title)
        ax.set_xlabel('resolution thinning')
        ax.set_ylabel('estimate')
        ax.grid(True, alpha=0.3)
    axes[-1].legend(ncol=2, fontsize=8, title='hour')
    fig.suptitle('Partial profile checks with same-hour x1 full-fit anchors', fontsize=14)
    partial_plot_path = OUT_DIR / f'{OUT_PREFIX}_partial_parameter_trajectories.png'
    fig.savefig(partial_plot_path, dpi=180, bbox_inches='tight')
    print('Saved:', partial_plot_path)
    plt.show()

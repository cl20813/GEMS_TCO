# %% [markdown]
# # Pure-space spectral diagnostic: smooth=0.5, nugget-free vs nugget=0
#
# This notebook fits each hourly pure-space slice with isotropic Hybrid Vecchia under two variants:
#
# - `nugget_free`: estimate `sigmasq`, `range`, and `nugget`
# - `nugget0`: estimate `sigmasq` and `range`, with nugget fixed at zero
#
# Both use `smooth=0.5`, `mean_design='latlon'`, and the same every-k resolution thinning used in the previous pure-space resolution checks.
#
# The spectral diagnostic compares the detrended empirical residual spectrum against the theoretical fitted Matern spectrum. For `nugget_free`, the theoretical spectrum includes a flat nugget floor before scaling to the empirical spectrum. Because the thinning is every-k over the ordered grid, the empirical spectrum is a masked/zero-filled periodogram and should be read as a shape diagnostic rather than an exact Whittle likelihood.

# %%
import gc
import sys
import time
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch

LOCAL_SRC = '/Users/joonwonlee/Documents/GEMS_TCO-1/src'
AMAREL_SRC = '/home/jl2815/tco'
SRC = AMAREL_SRC if Path(AMAREL_SRC).exists() else LOCAL_SRC
if SRC not in sys.path:
    sys.path.insert(0, SRC)

from GEMS_TCO import configuration as config
from GEMS_TCO import orderings
from GEMS_TCO.data_loader import load_data_dynamic_processed
from GEMS_TCO.kernels_space_iso_050826 import (
    HybridSpaceIsoTrendVecchiaFit,
    HybridSpaceIsoNoNuggetTrendVecchiaFit,
)

DEVICE = torch.device('cpu')
DTYPE = torch.float64
ROUND_DECIMALS = 4

pd.set_option('display.max_columns', 140)
pd.set_option('display.width', 200)
print('SRC:', SRC)
print('device:', DEVICE)
# Out:
# SRC: /Users/joonwonlee/Documents/GEMS_TCO-1/src
# device: cpu

# %%
# Experiment config
YEAR = '2024'
MONTH = 7
DAY_IDX = 2                 # 0-based: 2 -> 2024-07-03
HOUR_IDX_LIST = list(range(8))
LAT_RANGE = [-3, 2]
LON_RANGE = [121, 131]

SMOOTH = 0.5
RESOLUTION_STRIDES = [8, 4, 2, 1]
MEAN_DESIGN = 'latlon'

HYBRID_SPEC = {
    'limit_A': 10,
    'target_chunk_size': 512,
}

VARIANTS = {
    'nugget_free': {
        'class': HybridSpaceIsoTrendVecchiaFit,
        'model': 'HybridSpaceIso_A10_exactloc',
        'kernel': 'hybrid_space_iso_tonly_exactloc',
        'p_labels': ['sigmasq', 'range', 'nugget'],
        'init': {'sigmasq': 13.0, 'range': 0.25, 'nugget': 2.5},
    },
    'nugget0': {
        'class': HybridSpaceIsoNoNuggetTrendVecchiaFit,
        'model': 'HybridSpaceIsoNoNugget_A10_exactloc',
        'kernel': 'hybrid_space_iso_nugget0_tonly_exactloc',
        'p_labels': ['sigmasq', 'range'],
        'init': {'sigmasq': 13.0, 'range': 0.25},
    },
}

LBFGS_LR = 1.0
LBFGS_STEPS_FULL = 8
LBFGS_EVAL = 20
LBFGS_HIST = 10
GRAD_TOL = 1e-5

RUN_FULL = True
RUN_SPECTRUM = True

PURE_SPACE_DIR = Path('/Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space')
OUT_DIR = PURE_SPACE_DIR / 'log'
OUT_DIR.mkdir(parents=True, exist_ok=True)
OUT_PREFIX = 'real_pure_space_spectral_s05_nugget_compare_hybrid_050826'

print('day:', f'{YEAR}{MONTH:02d}{DAY_IDX + 1:02d}')
print('hours:', HOUR_IDX_LIST)
print('strides:', RESOLUTION_STRIDES)
print('smooth:', SMOOTH)
print('variants:', list(VARIANTS))
# Out:
# day: 20240703
# hours: [0, 1, 2, 3, 4, 5, 6, 7]
# strides: [8, 4, 2, 1]
# smooth: 0.5
# variants: ['nugget_free', 'nugget0']

# %%
def phys_to_log(init, p_labels):
    return [np.log(init[p]) for p in p_labels]


def backmap(raw, p_labels, variant):
    est = {p: float(np.exp(raw[i])) for i, p in enumerate(p_labels)}
    if 'nugget' not in est:
        est['nugget'] = 0.0
    return est


def make_full_params(variant):
    spec = VARIANTS[variant]
    return [torch.tensor([v], device=DEVICE, dtype=DTYPE, requires_grad=True) for v in phys_to_log(spec['init'], spec['p_labels'])]


def count_valid(input_map):
    return int(sum(((~torch.isnan(v[:, 2])) & (~torch.isnan(v[:, 0])) & (~torch.isnan(v[:, 1]))).sum().item() for v in input_map.values()))


def space_diag(model):
    groups = getattr(model, 'Batched_Groups', []) or []
    if not groups:
        return {'n_batches': 0, 'n_tails': 0, 'mean_m': 0.0, 'max_m': 0, 'largest_batch_n': 0}
    ns = np.asarray([int(g['target_idx'].shape[0]) for g in groups], dtype=np.int64)
    ms = np.asarray([int(g['max_m']) for g in groups], dtype=np.int64)
    return {
        'n_batches': int(len(groups)),
        'n_tails': int(ns.sum()),
        'mean_m': float(ms.mean()),
        'max_m': int(ms.max()),
        'largest_batch_n': int(ns.max()),
    }


def round_df(df, digits=ROUND_DECIMALS):
    out = df.copy()
    num_cols = out.select_dtypes(include=[np.number]).columns
    out[num_cols] = out[num_cols].round(digits)
    return out


def empty_cache():
    gc.collect()
    if DEVICE.type == 'cuda':
        torch.cuda.empty_cache()


def resolution_label(stride):
    return f'x{int(stride)}'

# %%
loader = load_data_dynamic_processed(config.mac_data_load_path)
df_map, _, _, monthly_mean = loader.load_maxmin_ordered_data_bymonthyear(
    lat_lon_resolution=[1, 1],
    mm_cond_number=10,
    years_=[YEAR],
    months_=[MONTH],
    lat_range=LAT_RANGE,
    lon_range=LON_RANGE,
    is_whittle=True,
)
month_keys = sorted(df_map.keys())
day_keys = month_keys[DAY_IDX * 8:(DAY_IDX + 1) * 8]
if len(day_keys) != 8:
    raise ValueError(f'Day {DAY_IDX} has {len(day_keys)} slices, expected 8')

first_df = df_map[day_keys[0]].reset_index(drop=True)
grid_order = (
    first_df
    .assign(_orig_idx=np.arange(len(first_df)))
    .sort_values(['Longitude', 'Latitude', '_orig_idx'], kind='mergesort')['_orig_idx']
    .to_numpy(dtype=np.int64)
)
grid_coords_full = first_df.iloc[grid_order][['Latitude', 'Longitude']].to_numpy(dtype=np.float64)

print('monthly_mean:', round(monthly_mean, 4))
print('day keys:', day_keys[0], '...', day_keys[-1])
print('full grid:', grid_coords_full.shape)
print('unique lat/lon:', len(np.unique(np.round(grid_coords_full[:,0], 6))), len(np.unique(np.round(grid_coords_full[:,1], 6))))
# Out:
# --- Global Monthly Mean for 2024-7: 257.9726 ---
# monthly_mean: 257.9726
# day keys: 2024_07_y24m07day03_hm00:53 ... 2024_07_y24m07day03_hm07:48
# full grid: (18126, 2)
# unique lat/lon: 114 159

# %%
def load_hour_map(hour_idx):
    key = day_keys[int(hour_idx)]
    hour_df_map = {key: df_map[key]}
    hour_map, _ = loader.load_working_data(
        hour_df_map,
        monthly_mean=monthly_mean,
        idx_for_datamap=[0, 1],
        ord_mm=grid_order,
        dtype=DTYPE,
        keep_ori=True,
    )
    return {k: v.to(DEVICE) for k, v in hour_map.items()}, key


def thin_hour_map(hour_map, stride):
    n_full = grid_coords_full.shape[0]
    thin_idx = np.arange(0, n_full, int(stride), dtype=np.int64)
    thin_map = {k: v[thin_idx].contiguous() for k, v in hour_map.items()}
    thin_grid = np.ascontiguousarray(grid_coords_full[thin_idx])
    return thin_map, thin_grid, thin_idx


def make_hybrid_ordering(grid_coords):
    coords = np.ascontiguousarray(grid_coords.astype(np.float64))
    hybrid_order = orderings.maxmin_cpp(coords).astype(np.int64)
    ordered_coords = np.ascontiguousarray(coords[hybrid_order])
    nns_map = orderings.find_nns_l2(ordered_coords, max_nn=HYBRID_SPEC['limit_A'])
    return hybrid_order, ordered_coords, nns_map


def build_model(variant, input_map, nns_map):
    spec = VARIANTS[variant]
    return spec['class'](
        smooth=SMOOTH,
        input_map=input_map,
        nns_map=nns_map,
        limit_A=HYBRID_SPEC['limit_A'],
        target_chunk_size=HYBRID_SPEC['target_chunk_size'],
        mean_design=MEAN_DESIGN,
    )


def make_base_row(variant, hour_idx, time_key, stride, n_grid, n_valid, pre_s, fit_s, loss, fit_iter, est, diag):
    spec = VARIANTS[variant]
    row = {
        'date_str': f'{YEAR}{MONTH:02d}{DAY_IDX + 1:02d}',
        'day_idx': DAY_IDX,
        'hour_idx': int(hour_idx),
        'time_key': str(time_key),
        'resolution_stride': int(stride),
        'resolution_label': resolution_label(stride),
        'variant': variant,
        'smooth': float(SMOOTH),
        'mean_design': MEAN_DESIGN,
        'fit_type': 'full',
        'model': spec['model'],
        'kernel': spec['kernel'],
        'coord_mode': 'regular-grid every-k thinning, then max-min hybrid ordering; covariance on Source_Latitude/Source_Longitude',
        'loss': float(loss),
        'fit_iter_raw': int(fit_iter),
        'fit_steps_reported': int(fit_iter) + 1,
        'precompute_s': float(pre_s),
        'fit_s': float(fit_s),
        'total_s': float(pre_s + fit_s),
        'n_grid': int(n_grid),
        'n_valid': int(n_valid),
        'valid_fraction': float(n_valid / n_grid) if n_grid else np.nan,
        'est_sigmasq': float(est['sigmasq']),
        'est_range': float(est['range']),
        'est_nugget': float(est.get('nugget', 0.0)),
        **diag,
        'total_conditioning_nominal': HYBRID_SPEC['limit_A'],
        'limit_A': HYBRID_SPEC['limit_A'],
    }
    return row

# %%
def fit_full_variant(variant, hour_idx, stride):
    hour_map, time_key = load_hour_map(hour_idx)
    thin_map_regular, thin_grid_regular, _ = thin_hour_map(hour_map, stride)
    hybrid_order, thin_grid, nns_map = make_hybrid_ordering(thin_grid_regular)
    thin_map = {k: v[hybrid_order].contiguous() for k, v in thin_map_regular.items()}
    n_grid = int(thin_grid.shape[0])
    n_valid = count_valid(thin_map)
    print('\n' + '=' * 100)
    print(f'{variant} | smooth={SMOOTH} | hour={hour_idx + 1} | {time_key} | {resolution_label(stride)} | n_grid={n_grid:,} | n_valid={n_valid:,}')

    model = build_model(variant, thin_map, nns_map)
    t_pre = time.time()
    model.precompute_conditioning_sets()
    pre_s = time.time() - t_pre
    diag = space_diag(model)

    params = make_full_params(variant)
    opt = model.set_optimizer(params, lr=LBFGS_LR, max_iter=LBFGS_EVAL, max_eval=LBFGS_EVAL, history_size=LBFGS_HIST)
    t_fit = time.time()
    out, fit_iter = model.fit_vecc_lbfgs(params, opt, max_steps=LBFGS_STEPS_FULL, grad_tol=GRAD_TOL)
    fit_s = time.time() - t_fit
    p_labels = VARIANTS[variant]['p_labels']
    est = backmap(out[:len(p_labels)], p_labels, variant)
    row = make_base_row(variant, hour_idx, time_key, stride, n_grid, n_valid, pre_s, fit_s, out[-1], fit_iter, est, diag)
    print('RESULT:', {k: round(v, 4) if isinstance(v, float) else v for k, v in row.items() if k in ['variant','resolution_label','loss','est_sigmasq','est_range','est_nugget','total_s']})

    del model, params, opt, hour_map, thin_map
    empty_cache()
    return row

# %%
fit_rows = []
if RUN_FULL:
    for variant in VARIANTS:
        for hour_idx in HOUR_IDX_LIST:
            for stride in RESOLUTION_STRIDES:
                fit_rows.append(fit_full_variant(variant, hour_idx, stride))
                tmp = round_df(pd.DataFrame(fit_rows))
                tmp.to_csv(OUT_DIR / f'{OUT_PREFIX}_full.csv', index=False, float_format=f'%.{ROUND_DECIMALS}f')

fit_df = pd.DataFrame(fit_rows)
full_path = OUT_DIR / f'{OUT_PREFIX}_full.csv'
round_df(fit_df).to_csv(full_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
print('Saved full fits:', full_path)
display(round_df(fit_df))

param_rows = []
for _, row in fit_df.iterrows():
    for p in ['sigmasq', 'range', 'nugget']:
        param_rows.append({
            'date_str': row['date_str'],
            'hour_idx': int(row['hour_idx']),
            'time_key': row['time_key'],
            'resolution_stride': int(row['resolution_stride']),
            'resolution_label': row['resolution_label'],
            'variant': row['variant'],
            'smooth': row['smooth'],
            'parameter': p,
            'estimate': row[f'est_{p}'],
            'loss': row['loss'],
            'n_grid': row['n_grid'],
            'n_valid': row['n_valid'],
        })
param_df = pd.DataFrame(param_rows)
param_path = OUT_DIR / f'{OUT_PREFIX}_param_table.csv'
round_df(param_df).to_csv(param_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
print('Saved param table:', param_path)
# Out:
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=1 | 2024_07_y24m07day03_hm00:53 | x8 | n_grid=2,266 | n_valid=2,259
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2259, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.552323 / Max Grad: 1.31e-06 ---
# Converged: max_grad 1.31e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 8.53546347597883, 'range': 0.5603675365911069, 'nugget': 4.481956129892668}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.5523, 'total_s': 0.2185, 'est_sigmasq': 8.5355, 'est_range': 0.5604, 'est_nugget': 4.482}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=1 | 2024_07_y24m07day03_hm00:53 | x4 | n_grid=4,532 | n_valid=4,518
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4518, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.467198 / Max Grad: 7.09e-06 ---
# Converged: max_grad 7.09e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 9.258879729709726, 'range': 0.43730797612801914, 'nugget': 3.472680106596387}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.4672, 'total_s': 0.5509, 'est_sigmasq': 9.2589, 'est_range': 0.4373, 'est_nugget': 3.4727}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=1 | 2024_07_y24m07day03_hm00:53 | x2 | n_grid=9,063 | n_valid=9,033
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=9033, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.537683 / Max Grad: 4.89e-06 ---
# Converged: max_grad 4.89e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 10.082084346291511, 'range': 0.26234781508515775, 'nugget': 3.980713803371999}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.5377, 'total_s': 0.7742, 'est_sigmasq': 10.0821, 'est_range': 0.2623, 'est_nugget': 3.9807}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=1 | 2024_07_y24m07day03_hm00:53 | x1 | n_grid=18,126 | n_valid=18,067
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=18067, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.408652 / Max Grad: 2.51e-06 ---
# Converged: max_grad 2.51e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 10.191299388911759, 'range': 0.23095905241963757, 'nugget': 2.967365741763184}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.4087, 'total_s': 1.1276, 'est_sigmasq': 10.1913, 'est_range': 0.231, 'est_nugget': 2.9674}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=2 | 2024_07_y24m07day03_hm01:53 | x8 | n_grid=2,266 | n_valid=2,208
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2208, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.587412 / Max Grad: 1.02e-06 ---
# Converged: max_grad 1.02e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 11.140331280263137, 'range': 0.47494247249420024, 'nugget': 4.0516991654048695}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.5874, 'total_s': 0.427, 'est_sigmasq': 11.1403, 'est_range': 0.4749, 'est_nugget': 4.0517}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=2 | 2024_07_y24m07day03_hm01:53 | x4 | n_grid=4,532 | n_valid=4,422
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4422, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.498872 / Max Grad: 8.79e-07 ---
# Converged: max_grad 8.79e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.195313811189905, 'range': 0.4648668978475616, 'nugget': 3.371127830002206}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.4989, 'total_s': 0.561, 'est_sigmasq': 12.1953, 'est_range': 0.4649, 'est_nugget': 3.3711}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=2 | 2024_07_y24m07day03_hm01:53 | x2 | n_grid=9,063 | n_valid=8,840
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=8840, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.415443 / Max Grad: 2.59e-06 ---
# Converged: max_grad 2.59e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.805395156097934, 'range': 0.2851344020235044, 'nugget': 2.0639022584582047}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.4154, 'total_s': 0.7858, 'est_sigmasq': 12.8054, 'est_range': 0.2851, 'est_nugget': 2.0639}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=2 | 2024_07_y24m07day03_hm01:53 | x1 | n_grid=18,126 | n_valid=17,670
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=17670, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.354595 / Max Grad: 9.65e-06 ---
# Converged: max_grad 9.65e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.920721648766245, 'range': 0.259220571342034, 'nugget': 2.10988892902981}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.3546, 'total_s': 0.9551, 'est_sigmasq': 12.9207, 'est_range': 0.2592, 'est_nugget': 2.1099}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=3 | 2024_07_y24m07day03_hm02:53 | x8 | n_grid=2,266 | n_valid=2,082
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2082, m mean/med/max=9.3/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.641822 / Max Grad: 5.51e-06 ---
# Converged: max_grad 5.51e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.991779097098583, 'range': 0.42148104231892314, 'nugget': 4.047331342986995}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.6418, 'total_s': 0.359, 'est_sigmasq': 12.9918, 'est_range': 0.4215, 'est_nugget': 4.0473}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=3 | 2024_07_y24m07day03_hm02:53 | x4 | n_grid=4,532 | n_valid=4,176
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4176, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.564087 / Max Grad: 2.32e-06 ---
# Converged: max_grad 2.32e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.045364336089431, 'range': 0.3947302131561483, 'nugget': 3.419048236209922}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.5641, 'total_s': 0.463, 'est_sigmasq': 14.0454, 'est_range': 0.3947, 'est_nugget': 3.419}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=3 | 2024_07_y24m07day03_hm02:53 | x2 | n_grid=9,063 | n_valid=8,353
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=8353, m mean/med/max=9.6/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.456314 / Max Grad: 5.64e-06 ---
# Converged: max_grad 5.64e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.860521269898788, 'range': 0.27891901585741713, 'nugget': 1.9627501856646952}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.4563, 'total_s': 0.695, 'est_sigmasq': 14.8605, 'est_range': 0.2789, 'est_nugget': 1.9628}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=3 | 2024_07_y24m07day03_hm02:53 | x1 | n_grid=18,126 | n_valid=16,698
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=16698, m mean/med/max=9.6/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.359072 / Max Grad: 4.49e-06 ---
# Converged: max_grad 4.49e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.118276402573352, 'range': 0.2406194276186774, 'nugget': 1.5229633601760437}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.3591, 'total_s': 0.999, 'est_sigmasq': 15.1183, 'est_range': 0.2406, 'est_nugget': 1.523}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=4 | 2024_07_y24m07day03_hm03:53 | x8 | n_grid=2,266 | n_valid=2,114
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2114, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.660871 / Max Grad: 1.51e-06 ---
# Converged: max_grad 1.51e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.563637869326868, 'range': 0.48412147641106595, 'nugget': 4.319520053446033}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.6609, 'total_s': 0.3342, 'est_sigmasq': 14.5636, 'est_range': 0.4841, 'est_nugget': 4.3195}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=4 | 2024_07_y24m07day03_hm03:53 | x4 | n_grid=4,532 | n_valid=4,217
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4217, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.593446 / Max Grad: 2.37e-06 ---
# Converged: max_grad 2.37e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.976074301523315, 'range': 0.406897671583217, 'nugget': 3.6992525327754375}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.5934, 'total_s': 0.4418, 'est_sigmasq': 14.9761, 'est_range': 0.4069, 'est_nugget': 3.6993}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=4 | 2024_07_y24m07day03_hm03:53 | x2 | n_grid=9,063 | n_valid=8,428
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=8428, m mean/med/max=9.6/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.478850 / Max Grad: 3.75e-06 ---
# Converged: max_grad 3.75e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 16.650526007815287, 'range': 0.24962036813533303, 'nugget': 1.406993706304475}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.4788, 'total_s': 0.7413, 'est_sigmasq': 16.6505, 'est_range': 0.2496, 'est_nugget': 1.407}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=4 | 2024_07_y24m07day03_hm03:53 | x1 | n_grid=18,126 | n_valid=16,863
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=16863, m mean/med/max=9.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.384306 / Max Grad: 1.30e-05 ---
# --- Step 2/8 / Loss: 1.379010 / Max Grad: 1.30e-05 ---
# --- Step 3/8 / Loss: 1.379010 / Max Grad: 1.30e-05 ---
# --- Step 4/8 / Loss: 1.379010 / Max Grad: 1.30e-05 ---
# --- Step 5/8 / Loss: 1.379010 / Max Grad: 1.30e-05 ---
# --- Step 6/8 / Loss: 1.379010 / Max Grad: 1.30e-05 ---
# --- Step 7/8 / Loss: 1.379010 / Max Grad: 1.30e-05 ---
# --- Step 8/8 / Loss: 1.379010 / Max Grad: 1.30e-05 ---
# Final Pure-Space Params: {'sigmasq': 16.781733010786798, 'range': 0.23283877562859406, 'nugget': 1.344163689320415}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.379, 'total_s': 1.543, 'est_sigmasq': 16.7817, 'est_range': 0.2328, 'est_nugget': 1.3442}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=5 | 2024_07_y24m07day03_hm04:48 | x8 | n_grid=2,266 | n_valid=2,145
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2145, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.726689 / Max Grad: 1.20e-06 ---
# Converged: max_grad 1.20e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.530053407588532, 'range': 0.4228539956233314, 'nugget': 5.3058614715563985}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.7267, 'total_s': 0.3747, 'est_sigmasq': 13.5301, 'est_range': 0.4229, 'est_nugget': 5.3059}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=5 | 2024_07_y24m07day03_hm04:48 | x4 | n_grid=4,532 | n_valid=4,288
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4288, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.654784 / Max Grad: 9.13e-07 ---
# Converged: max_grad 9.13e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.511843804724855, 'range': 0.32606737644586226, 'nugget': 3.703785001485991}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.6548, 'total_s': 0.516, 'est_sigmasq': 15.5118, 'est_range': 0.3261, 'est_nugget': 3.7038}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=5 | 2024_07_y24m07day03_hm04:48 | x2 | n_grid=9,063 | n_valid=8,552
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=8552, m mean/med/max=9.6/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.531925 / Max Grad: 3.08e-06 ---
# Converged: max_grad 3.08e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 17.0428836432019, 'range': 0.2419071134983827, 'nugget': 1.8120561083667193}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.5319, 'total_s': 0.6966, 'est_sigmasq': 17.0429, 'est_range': 0.2419, 'est_nugget': 1.8121}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=5 | 2024_07_y24m07day03_hm04:48 | x1 | n_grid=18,126 | n_valid=17,088
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=17088, m mean/med/max=9.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.425030 / Max Grad: 4.39e-07 ---
# Converged: max_grad 4.39e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 17.565520019363465, 'range': 0.20861817302436658, 'nugget': 1.220712510614806}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.425, 'total_s': 1.1278, 'est_sigmasq': 17.5655, 'est_range': 0.2086, 'est_nugget': 1.2207}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=6 | 2024_07_y24m07day03_hm05:48 | x8 | n_grid=2,266 | n_valid=2,221
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2221, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.697240 / Max Grad: 7.29e-07 ---
# Converged: max_grad 7.29e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.550903468796685, 'range': 0.41277565159386986, 'nugget': 5.092937377903936}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.6972, 'total_s': 0.378, 'est_sigmasq': 12.5509, 'est_range': 0.4128, 'est_nugget': 5.0929}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=6 | 2024_07_y24m07day03_hm05:48 | x4 | n_grid=4,532 | n_valid=4,439
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4439, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.615745 / Max Grad: 3.18e-06 ---
# Converged: max_grad 3.18e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.85449773889091, 'range': 0.30836459597526766, 'nugget': 3.4719281779854865}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.6157, 'total_s': 0.49, 'est_sigmasq': 13.8545, 'est_range': 0.3084, 'est_nugget': 3.4719}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=6 | 2024_07_y24m07day03_hm05:48 | x2 | n_grid=9,063 | n_valid=8,881
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=8881, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.516282 / Max Grad: 9.65e-06 ---
# Converged: max_grad 9.65e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.057313209466452, 'range': 0.22291456403771048, 'nugget': 1.9016149054052283}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.5163, 'total_s': 0.6565, 'est_sigmasq': 15.0573, 'est_range': 0.2229, 'est_nugget': 1.9016}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=6 | 2024_07_y24m07day03_hm05:48 | x1 | n_grid=18,126 | n_valid=17,760
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=17760, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.424023 / Max Grad: 3.29e-06 ---
# Converged: max_grad 3.29e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.448243352748698, 'range': 0.18434217926566338, 'nugget': 1.3076346782007486}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.424, 'total_s': 1.1139, 'est_sigmasq': 15.4482, 'est_range': 0.1843, 'est_nugget': 1.3076}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=7 | 2024_07_y24m07day03_hm06:48 | x8 | n_grid=2,266 | n_valid=2,264
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2264, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.631212 / Max Grad: 7.16e-06 ---
# Converged: max_grad 7.16e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 10.789753090128317, 'range': 0.4119249107589511, 'nugget': 4.552203848690546}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.6312, 'total_s': 0.3623, 'est_sigmasq': 10.7898, 'est_range': 0.4119, 'est_nugget': 4.5522}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=7 | 2024_07_y24m07day03_hm06:48 | x4 | n_grid=4,532 | n_valid=4,527
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4527, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.587511 / Max Grad: 1.08e-05 ---
# --- Step 2/8 / Loss: 1.583505 / Max Grad: 1.08e-05 ---
# --- Step 3/8 / Loss: 1.583505 / Max Grad: 1.08e-05 ---
# --- Step 4/8 / Loss: 1.583505 / Max Grad: 1.08e-05 ---
# --- Step 5/8 / Loss: 1.583505 / Max Grad: 1.08e-05 ---
# --- Step 6/8 / Loss: 1.583505 / Max Grad: 1.08e-05 ---
# --- Step 7/8 / Loss: 1.583505 / Max Grad: 1.08e-05 ---
# --- Step 8/8 / Loss: 1.583505 / Max Grad: 1.08e-05 ---
# Final Pure-Space Params: {'sigmasq': 11.480441452632384, 'range': 0.37377494524588706, 'nugget': 4.319471618784535}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.5835, 'total_s': 0.5722, 'est_sigmasq': 11.4804, 'est_range': 0.3738, 'est_nugget': 4.3195}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=7 | 2024_07_y24m07day03_hm06:48 | x2 | n_grid=9,063 | n_valid=9,052
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=9052, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.488812 / Max Grad: 3.75e-06 ---
# Converged: max_grad 3.75e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.515859052444185, 'range': 0.2208151711543727, 'nugget': 2.2971066875521937}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.4888, 'total_s': 0.618, 'est_sigmasq': 12.5159, 'est_range': 0.2208, 'est_nugget': 2.2971}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=7 | 2024_07_y24m07day03_hm06:48 | x1 | n_grid=18,126 | n_valid=18,104
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=18104, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.381538 / Max Grad: 2.33e-06 ---
# Converged: max_grad 2.33e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.540151996005122, 'range': 0.16954396835232927, 'nugget': 1.1192723251394572}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.3815, 'total_s': 1.1851, 'est_sigmasq': 13.5402, 'est_range': 0.1695, 'est_nugget': 1.1193}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=8 | 2024_07_y24m07day03_hm07:48 | x8 | n_grid=2,266 | n_valid=2,263
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2263, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.681981 / Max Grad: 8.88e-06 ---
# Converged: max_grad 8.88e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 9.220822942090782, 'range': 0.42453379079240683, 'nugget': 5.953827191977489}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.682, 'total_s': 0.3768, 'est_sigmasq': 9.2208, 'est_range': 0.4245, 'est_nugget': 5.9538}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=8 | 2024_07_y24m07day03_hm07:48 | x4 | n_grid=4,532 | n_valid=4,526
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4526, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.569865 / Max Grad: 5.68e-06 ---
# Converged: max_grad 5.68e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 10.15799412529515, 'range': 0.3319105934821068, 'nugget': 4.1442763032925045}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.5699, 'total_s': 0.4779, 'est_sigmasq': 10.158, 'est_range': 0.3319, 'est_nugget': 4.1443}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=8 | 2024_07_y24m07day03_hm07:48 | x2 | n_grid=9,063 | n_valid=9,051
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=9051, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.474523 / Max Grad: 4.45e-06 ---
# Converged: max_grad 4.45e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 11.796768366942404, 'range': 0.20753201704389104, 'nugget': 2.154041648608075}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.4745, 'total_s': 0.6571, 'est_sigmasq': 11.7968, 'est_range': 0.2075, 'est_nugget': 2.154}
#
# ====================================================================================================
# nugget_free | smooth=0.5 | hour=8 | 2024_07_y24m07day03_hm07:48 | x1 | n_grid=18,126 | n_valid=18,102
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=18102, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.395885 / Max Grad: 5.29e-06 ---
# Converged: max_grad 5.29e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.105695885312052, 'range': 0.1765153894260959, 'nugget': 1.7611391651368316}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.3959, 'total_s': 1.1304, 'est_sigmasq': 12.1057, 'est_range': 0.1765, 'est_nugget': 1.7611}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=1 | 2024_07_y24m07day03_hm00:53 | x8 | n_grid=2,266 | n_valid=2,259
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2259, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.578023 / Max Grad: 1.80e-06 ---
# Converged: max_grad 1.80e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.28641153139413, 'range': 0.1730448937665263, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 1.578, 'total_s': 0.3282, 'est_sigmasq': 12.2864, 'est_range': 0.173, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=1 | 2024_07_y24m07day03_hm00:53 | x4 | n_grid=4,532 | n_valid=4,518
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4518, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.484542 / Max Grad: 2.09e-06 ---
# Converged: max_grad 2.09e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 11.753053211362785, 'range': 0.16519469999469127, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.4845, 'total_s': 0.403, 'est_sigmasq': 11.7531, 'est_range': 0.1652, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=1 | 2024_07_y24m07day03_hm00:53 | x2 | n_grid=9,063 | n_valid=9,033
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=9033, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.758956 / Max Grad: 3.18e-07 ---
# Converged: max_grad 3.18e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.342660815426996, 'range': 0.10535133082630684, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 1.759, 'total_s': 0.674, 'est_sigmasq': 13.3427, 'est_range': 0.1054, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=1 | 2024_07_y24m07day03_hm00:53 | x1 | n_grid=18,126 | n_valid=18,067
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=18067, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.675955 / Max Grad: 1.37e-06 ---
# Converged: max_grad 1.37e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.199320342003492, 'range': 0.09216964285900751, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 1.676, 'total_s': 1.2188, 'est_sigmasq': 12.1993, 'est_range': 0.0922, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=2 | 2024_07_y24m07day03_hm01:53 | x8 | n_grid=2,266 | n_valid=2,208
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2208, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.617546 / Max Grad: 2.72e-06 ---
# Converged: max_grad 2.72e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.235938739514339, 'range': 0.19621442608959594, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 1.6175, 'total_s': 0.3183, 'est_sigmasq': 14.2359, 'est_range': 0.1962, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=2 | 2024_07_y24m07day03_hm01:53 | x4 | n_grid=4,532 | n_valid=4,422
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4422, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.531432 / Max Grad: 3.53e-06 ---
# Converged: max_grad 3.53e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.80364195844178, 'range': 0.185601153374901, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.5314, 'total_s': 0.3827, 'est_sigmasq': 13.8036, 'est_range': 0.1856, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=2 | 2024_07_y24m07day03_hm01:53 | x2 | n_grid=9,063 | n_valid=8,840
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=8840, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.484305 / Max Grad: 6.08e-07 ---
# Converged: max_grad 6.08e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.511144496333218, 'range': 0.15429341335782684, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 1.4843, 'total_s': 0.625, 'est_sigmasq': 13.5111, 'est_range': 0.1543, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=2 | 2024_07_y24m07day03_hm01:53 | x1 | n_grid=18,126 | n_valid=17,670
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=17670, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.525683 / Max Grad: 5.38e-06 ---
# Converged: max_grad 5.38e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.064815272442853, 'range': 0.11776844273722283, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 1.5257, 'total_s': 0.9761, 'est_sigmasq': 13.0648, 'est_range': 0.1178, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=3 | 2024_07_y24m07day03_hm02:53 | x8 | n_grid=2,266 | n_valid=2,082
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2082, m mean/med/max=9.3/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.690452 / Max Grad: 1.01e-05 ---
# --- Step 2/8 / Loss: 1.650534 / Max Grad: 1.01e-05 ---
# --- Step 3/8 / Loss: 1.650534 / Max Grad: 1.01e-05 ---
# --- Step 4/8 / Loss: 1.650534 / Max Grad: 1.01e-05 ---
# --- Step 5/8 / Loss: 1.650534 / Max Grad: 1.01e-05 ---
# --- Step 6/8 / Loss: 1.650534 / Max Grad: 1.01e-05 ---
# --- Step 7/8 / Loss: 1.650534 / Max Grad: 1.01e-05 ---
# --- Step 8/8 / Loss: 1.650534 / Max Grad: 1.01e-05 ---
# Final Pure-Space Params: {'sigmasq': 16.09008741370763, 'range': 0.20222525419453155, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 1.6505, 'total_s': 0.3633, 'est_sigmasq': 16.0901, 'est_range': 0.2022, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=3 | 2024_07_y24m07day03_hm02:53 | x4 | n_grid=4,532 | n_valid=4,176
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4176, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.627327 / Max Grad: 6.07e-06 ---
# Converged: max_grad 6.07e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.8931208752247, 'range': 0.18856194376027388, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.6273, 'total_s': 0.3987, 'est_sigmasq': 15.8931, 'est_range': 0.1886, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=3 | 2024_07_y24m07day03_hm02:53 | x2 | n_grid=9,063 | n_valid=8,353
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=8353, m mean/med/max=9.6/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.551100 / Max Grad: 2.56e-07 ---
# Converged: max_grad 2.56e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.402674399137222, 'range': 0.16439274057315126, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 1.5511, 'total_s': 0.5896, 'est_sigmasq': 15.4027, 'est_range': 0.1644, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=3 | 2024_07_y24m07day03_hm02:53 | x1 | n_grid=18,126 | n_valid=16,698
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=16698, m mean/med/max=9.6/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.507785 / Max Grad: 8.49e-06 ---
# Converged: max_grad 8.49e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.807086993930822, 'range': 0.138846083225642, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 1.5078, 'total_s': 1.0645, 'est_sigmasq': 14.8071, 'est_range': 0.1388, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=4 | 2024_07_y24m07day03_hm03:53 | x8 | n_grid=2,266 | n_valid=2,114
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2114, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.718960 / Max Grad: 2.21e-06 ---
# Converged: max_grad 2.21e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 17.561138247959434, 'range': 0.21662001430739203, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 1.719, 'total_s': 0.3157, 'est_sigmasq': 17.5611, 'est_range': 0.2166, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=4 | 2024_07_y24m07day03_hm03:53 | x4 | n_grid=4,532 | n_valid=4,217
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=4217, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.674708 / Max Grad: 5.21e-06 ---
# Converged: max_grad 5.21e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 17.22033207032816, 'range': 0.1935600645822099, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.6747, 'total_s': 0.3921, 'est_sigmasq': 17.2203, 'est_range': 0.1936, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=4 | 2024_07_y24m07day03_hm03:53 | x2 | n_grid=9,063 | n_valid=8,428
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=8428, m mean/med/max=9.6/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.579465 / Max Grad: 8.13e-06 ---
# Converged: max_grad 8.13e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 17.072928624150137, 'range': 0.17852400087777817, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 1.5795, 'total_s': 0.5724, 'est_sigmasq': 17.0729, 'est_range': 0.1785, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=4 | 2024_07_y24m07day03_hm03:53 | x1 | n_grid=18,126 | n_valid=16,863
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=16863, m mean/med/max=9.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.551228 / Max Grad: 5.12e-06 ---
# Converged: max_grad 5.12e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 16.443699553451307, 'range': 0.14869391813533356, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 1.5512, 'total_s': 0.9716, 'est_sigmasq': 16.4437, 'est_range': 0.1487, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=5 | 2024_07_y24m07day03_hm04:48 | x8 | n_grid=2,266 | n_valid=2,145
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2145, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.829328 / Max Grad: 1.30e-06 ---
# Converged: max_grad 1.30e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 17.939412368264904, 'range': 0.1832996181816007, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 1.8293, 'total_s': 0.3035, 'est_sigmasq': 17.9394, 'est_range': 0.1833, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=5 | 2024_07_y24m07day03_hm04:48 | x4 | n_grid=4,532 | n_valid=4,288
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4288, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.772770 / Max Grad: 3.01e-06 ---
# Converged: max_grad 3.01e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 18.093725864034397, 'range': 0.17814472561587444, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.7728, 'total_s': 0.4232, 'est_sigmasq': 18.0937, 'est_range': 0.1781, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=5 | 2024_07_y24m07day03_hm04:48 | x2 | n_grid=9,063 | n_valid=8,552
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=8552, m mean/med/max=9.6/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.683047 / Max Grad: 7.17e-06 ---
# Converged: max_grad 7.17e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 17.73765179671373, 'range': 0.16388002000532828, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 1.683, 'total_s': 0.571, 'est_sigmasq': 17.7377, 'est_range': 0.1639, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=5 | 2024_07_y24m07day03_hm04:48 | x1 | n_grid=18,126 | n_valid=17,088
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.2s. tails=17088, m mean/med/max=9.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.631014 / Max Grad: 1.79e-07 ---
# Converged: max_grad 1.79e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 17.321536889762108, 'range': 0.14480208310989526, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 1.631, 'total_s': 1.0942, 'est_sigmasq': 17.3215, 'est_range': 0.1448, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=6 | 2024_07_y24m07day03_hm05:48 | x8 | n_grid=2,266 | n_valid=2,221
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2221, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.786679 / Max Grad: 4.34e-06 ---
# Converged: max_grad 4.34e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 16.785878232075063, 'range': 0.1783781822955696, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 1.7867, 'total_s': 0.3157, 'est_sigmasq': 16.7859, 'est_range': 0.1784, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=6 | 2024_07_y24m07day03_hm05:48 | x4 | n_grid=4,532 | n_valid=4,439
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=4439, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.714713 / Max Grad: 1.02e-05 ---
# --- Step 2/8 / Loss: 1.621939 / Max Grad: 1.02e-05 ---
# --- Step 3/8 / Loss: 1.621939 / Max Grad: 1.02e-05 ---
# --- Step 4/8 / Loss: 1.621939 / Max Grad: 1.02e-05 ---
# --- Step 5/8 / Loss: 1.621939 / Max Grad: 1.02e-05 ---
# --- Step 6/8 / Loss: 1.621939 / Max Grad: 1.02e-05 ---
# --- Step 7/8 / Loss: 1.621939 / Max Grad: 1.02e-05 ---
# --- Step 8/8 / Loss: 1.621939 / Max Grad: 1.02e-05 ---
# Final Pure-Space Params: {'sigmasq': 16.311847311480363, 'range': 0.16898340059961198, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.6219, 'total_s': 0.5288, 'est_sigmasq': 16.3118, 'est_range': 0.169, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=6 | 2024_07_y24m07day03_hm05:48 | x2 | n_grid=9,063 | n_valid=8,881
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=8881, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.663311 / Max Grad: 4.06e-06 ---
# Converged: max_grad 4.06e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.986855420711523, 'range': 0.14792847690712863, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 1.6633, 'total_s': 0.6714, 'est_sigmasq': 15.9869, 'est_range': 0.1479, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=6 | 2024_07_y24m07day03_hm05:48 | x1 | n_grid=18,126 | n_valid=17,760
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=17760, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.639179 / Max Grad: 2.43e-06 ---
# Converged: max_grad 2.43e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.697191644105033, 'range': 0.1283458498627337, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 1.6392, 'total_s': 1.1896, 'est_sigmasq': 15.6972, 'est_range': 0.1283, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=7 | 2024_07_y24m07day03_hm06:48 | x8 | n_grid=2,266 | n_valid=2,264
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2264, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.691594 / Max Grad: 9.90e-07 ---
# Converged: max_grad 9.90e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.485336481545291, 'range': 0.1714409263444893, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 1.6916, 'total_s': 0.3143, 'est_sigmasq': 14.4853, 'est_range': 0.1714, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=7 | 2024_07_y24m07day03_hm06:48 | x4 | n_grid=4,532 | n_valid=4,527
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=4527, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.684062 / Max Grad: 2.81e-07 ---
# Converged: max_grad 2.81e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.330942065851376, 'range': 0.14916636788649024, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.6841, 'total_s': 0.441, 'est_sigmasq': 14.3309, 'est_range': 0.1492, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=7 | 2024_07_y24m07day03_hm06:48 | x2 | n_grid=9,063 | n_valid=9,052
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=9052, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.627589 / Max Grad: 1.27e-08 ---
# Converged: max_grad 1.27e-08 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.946423855585804, 'range': 0.13104777724208394, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 1.6276, 'total_s': 0.6539, 'est_sigmasq': 13.9464, 'est_range': 0.131, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=7 | 2024_07_y24m07day03_hm06:48 | x1 | n_grid=18,126 | n_valid=18,104
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=18104, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.549275 / Max Grad: 1.47e-06 ---
# Converged: max_grad 1.47e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.867204742381045, 'range': 0.1225926873113747, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 1.5493, 'total_s': 1.1961, 'est_sigmasq': 13.8672, 'est_range': 0.1226, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=8 | 2024_07_y24m07day03_hm07:48 | x8 | n_grid=2,266 | n_valid=2,263
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2263, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.779911 / Max Grad: 4.24e-06 ---
# Converged: max_grad 4.24e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.6738527517099, 'range': 0.14709713150694964, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 1.7799, 'total_s': 0.3149, 'est_sigmasq': 14.6739, 'est_range': 0.1471, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=8 | 2024_07_y24m07day03_hm07:48 | x4 | n_grid=4,532 | n_valid=4,526
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4526, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.652953 / Max Grad: 2.02e-06 ---
# Converged: max_grad 2.02e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.541393840372075, 'range': 0.14545108195829176, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.653, 'total_s': 0.4385, 'est_sigmasq': 13.5414, 'est_range': 0.1455, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=8 | 2024_07_y24m07day03_hm07:48 | x2 | n_grid=9,063 | n_valid=9,051
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=9051, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.599253 / Max Grad: 1.56e-07 ---
# Converged: max_grad 1.56e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.238869719777618, 'range': 0.1275839611946342, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 1.5993, 'total_s': 0.6964, 'est_sigmasq': 13.2389, 'est_range': 0.1276, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=0.5 | hour=8 | 2024_07_y24m07day03_hm07:48 | x1 | n_grid=18,126 | n_valid=18,102
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=18102, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.602063 / Max Grad: 3.90e-06 ---
# Converged: max_grad 3.90e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.977007291820597, 'range': 0.1071487647678574, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 1.6021, 'total_s': 1.1386, 'est_sigmasq': 12.977, 'est_range': 0.1071, 'est_nugget': 0.0}
# Saved full fits: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_spectral_s05_nugget_compare_hybrid_050826_full.csv
#     date_str  day_idx  hour_idx                     time_key  resolution_stride resolution_label      variant  smooth mean_design fit_type                                model  \
# 0   20240703        2         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     0.5      latlon     full          HybridSpaceIso_A10_exactloc
# 1   20240703        2         0  2024_07_y24m07day03_hm00:53                  4               x4  nugget_free     0.5      latlon     full          HybridSpaceIso_A10_exactloc
# 2   20240703        2         0  2024_07_y24m07day03_hm00:53                  2               x2  nugget_free     0.5      latlon     full          HybridSpaceIso_A10_exactloc
# 3   20240703        2         0  2024_07_y24m07day03_hm00:53                  1               x1  nugget_free     0.5      latlon     full          HybridSpaceIso_A10_exactloc
# 4   20240703        2         1  2024_07_y24m07day03_hm01:53                  8               x8  nugget_free     0.5      latlon     full          HybridSpaceIso_A10_exactloc
# ..       ...      ...       ...                          ...                ...              ...          ...     ...         ...      ...                                  ...
# 59  20240703        2         6  2024_07_y24m07day03_hm06:48                  1               x1      nugget0     0.5      latlon     full  HybridSpaceIsoNoNugget_A10_exactloc
# 60  20240703        2         7  2024_07_y24m07day03_hm07:48                  8               x8      nugget0     0.5      latlon     full  HybridSpaceIsoNoNugget_A10_exactloc
# 61  20240703        2         7  2024_07_y24m07day03_hm07:48                  4               x4      nugget0     0.5      latlon     full  HybridSpaceIsoNoNugget_A10_exactloc
# 62  20240703        2         7  2024_07_y24m07day03_hm07:48                  2               x2      nugget0     0.5      latlon     full  HybridSpaceIsoNoNugget_A10_exactloc
# 63  20240703        2         7  2024_07_y24m07day03_hm07:48                  1               x1      nugget0     0.5      latlon     full  HybridSpaceIsoNoNugget_A10_exactloc
#
#                                      kernel                                         coord_mode    loss  fit_iter_raw  fit_steps_reported  precompute_s   fit_s  total_s  n_grid  n_valid  \
# 0           hybrid_space_iso_tonly_exactloc  regular-grid every-k thinning, then max-min hy...  1.5523             0                   1        0.0483  0.1702   0.2185    2266     2259
# 1           hybrid_space_iso_tonly_exactloc  regular-grid every-k thinning, then max-min hy...  1.4672             0                   1        0.0343  0.5166   0.5509    4532     4518
# 2           hybrid_space_iso_tonly_exactloc  regular-grid every-k thinning, then max-min hy...  1.5377             0                   1        0.0594  0.7148   0.7742    9063     9033
# 3           hybrid_space_iso_tonly_exactloc  regular-grid every-k thinning, then max-min hy...  1.4087             0                   1        0.0871  1.0405   1.1276   18126    18067
# 4           hybrid_space_iso_tonly_exactloc  regular-grid every-k thinning, then max-min hy...  1.5874             0                   1        0.0144  0.4126   0.4270    2266     2208
# ..                                      ...                                                ...     ...           ...                 ...           ...     ...      ...     ...      ...
# 59  hybrid_space_iso_nugget0_tonly_exactloc  regular-grid every-k thinning, then max-min hy...  1.5493             0                   1        0.0773  1.1188   1.1961   18126    18104
# 60  hybrid_space_iso_nugget0_tonly_exactloc  regular-grid every-k thinning, then max-min hy...  1.7799             0                   1        0.0213  0.2936   0.3149    2266     2263
# 61  hybrid_space_iso_nugget0_tonly_exactloc  regular-grid every-k thinning, then max-min hy...  1.6530             0                   1        0.0330  0.4055   0.4385    4532     4526
# 62  hybrid_space_iso_nugget0_tonly_exactloc  regular-grid every-k thinning, then max-min hy...  1.5993             0                   1        0.1357  0.5607   0.6964    9063     9051
# 63  hybrid_space_iso_nugget0_tonly_exactloc  regular-grid every-k thinning, then max-min hy...  1.6021             0                   1        0.1030  1.0356   1.1386   18126    18102
#
#     valid_fraction  est_sigmasq  est_range  est_nugget  n_batches  n_tails  mean_m  max_m  largest_batch_n  total_conditioning_nominal  limit_A
# 0           0.9969       8.5355     0.5604      4.4820          1     2259    10.0     10             2259                          10       10
# 1           0.9969       9.2589     0.4373      3.4727          1     4518    10.0     10             4518                          10       10
# 2           0.9967      10.0821     0.2623      3.9807          1     9033    10.0     10             9033                          10       10
# 3           0.9967      10.1913     0.2310      2.9674          1    18067    10.0     10            18067                          10       10
# 4           0.9744      11.1403     0.4749      4.0517          1     2208    10.0     10             2208                          10       10
# ..             ...          ...        ...         ...        ...      ...     ...    ...              ...                         ...      ...
# 59          0.9988      13.8672     0.1226      0.0000          1    18104    10.0     10            18104                          10       10
# 60          0.9987      14.6739     0.1471      0.0000          1     2263    10.0     10             2263                          10       10
# 61          0.9987      13.5414     0.1455      0.0000          1     4526    10.0     10             4526                          10       10
# 62          0.9987      13.2389     0.1276      0.0000          1     9051    10.0     10             9051                          10       10
# 63          0.9987      12.9770     0.1071      0.0000          1    18102    10.0     10            18102                          10       10
#
# [64 rows x 32 columns]
# Saved param table: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_spectral_s05_nugget_compare_hybrid_050826_param_table.csv

# %%
# Full-fit results table.
plot_df = fit_df.copy()
plot_df['resolution_label'] = pd.Categorical(
    plot_df['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
)
plot_df = plot_df.sort_values(['variant', 'hour_idx', 'resolution_label'])

display(round_df(plot_df[['variant','hour_idx','resolution_stride','resolution_label','loss','est_sigmasq','est_range','est_nugget','n_grid','n_valid','total_s']]))
# Out:
#         variant  hour_idx  resolution_stride resolution_label    loss  est_sigmasq  est_range  est_nugget  n_grid  n_valid  total_s
# 32      nugget0         0                  8               x8  1.5780      12.2864     0.1730      0.0000    2266     2259   0.3282
# 33      nugget0         0                  4               x4  1.4845      11.7531     0.1652      0.0000    4532     4518   0.4030
# 34      nugget0         0                  2               x2  1.7590      13.3427     0.1054      0.0000    9063     9033   0.6740
# 35      nugget0         0                  1               x1  1.6760      12.1993     0.0922      0.0000   18126    18067   1.2188
# 36      nugget0         1                  8               x8  1.6175      14.2359     0.1962      0.0000    2266     2208   0.3183
# ..          ...       ...                ...              ...     ...          ...        ...         ...     ...      ...      ...
# 27  nugget_free         6                  1               x1  1.3815      13.5402     0.1695      1.1193   18126    18104   1.1851
# 28  nugget_free         7                  8               x8  1.6820       9.2208     0.4245      5.9538    2266     2263   0.3768
# 29  nugget_free         7                  4               x4  1.5699      10.1580     0.3319      4.1443    4532     4526   0.4779
# 30  nugget_free         7                  2               x2  1.4745      11.7968     0.2075      2.1540    9063     9051   0.6571
# 31  nugget_free         7                  1               x1  1.3959      12.1057     0.1765      1.7611   18126    18102   1.1304
#
# [64 rows x 11 columns]

# %%
# %%
# Partial-profile fits anchored at the full-fit estimates.
# sigma_only: estimate sigmasq only; keep range and nugget fixed at the full-fit estimates.
# range_only: estimate range only; keep sigmasq and nugget fixed at the full-fit estimates.
RUN_PROFILE_FITS = True
PROFILE_TYPES = ['sigma_only', 'range_only']
PROFILE_LBFGS_STEPS = 8
PROFILE_GRAD_TOL = 1e-5
PROFILE_EPS = 1e-10


def safe_log_value(x, eps=PROFILE_EPS):
    return float(np.log(max(float(x), eps)))


def log_tensor_value(x, like, eps=PROFILE_EPS):
    return torch.as_tensor(np.log(max(float(x), eps)), device=like.device, dtype=like.dtype)


def profile_param_tensor(variant, profile_type, theta, anchor):
    if variant == 'nugget_free':
        vals = {
            'sigmasq': log_tensor_value(anchor['sigmasq'], theta),
            'range': log_tensor_value(anchor['range'], theta),
            'nugget': log_tensor_value(anchor['nugget'], theta),
        }
        vals['sigmasq' if profile_type == 'sigma_only' else 'range'] = theta.reshape(())
        return torch.stack([vals['sigmasq'], vals['range'], vals['nugget']])
    if variant == 'nugget0':
        vals = {
            'sigmasq': log_tensor_value(anchor['sigmasq'], theta),
            'range': log_tensor_value(anchor['range'], theta),
        }
        vals['sigmasq' if profile_type == 'sigma_only' else 'range'] = theta.reshape(())
        return torch.stack([vals['sigmasq'], vals['range']])
    raise ValueError(f'Unknown variant: {variant}')


def profile_estimate_from_theta(profile_type, theta, anchor):
    est = dict(anchor)
    est['sigmasq' if profile_type == 'sigma_only' else 'range'] = float(torch.exp(theta.detach()).cpu().item())
    return est


def optimize_profile(model, variant, profile_type, anchor):
    free_name = 'sigmasq' if profile_type == 'sigma_only' else 'range'
    theta = torch.tensor([safe_log_value(anchor[free_name])], device=DEVICE, dtype=DTYPE, requires_grad=True)
    optimizer = torch.optim.LBFGS(
        [theta],
        lr=LBFGS_LR,
        max_iter=LBFGS_EVAL,
        max_eval=LBFGS_EVAL,
        history_size=LBFGS_HIST,
        line_search_fn='strong_wolfe',
    )

    last_loss = None
    last_iter = 0
    for i in range(PROFILE_LBFGS_STEPS):
        last_iter = i

        def closure():
            optimizer.zero_grad()
            params = profile_param_tensor(variant, profile_type, theta, anchor)
            loss = model.vecchia_batched_likelihood(params)
            loss.backward()
            return loss

        last_loss = optimizer.step(closure)
        with torch.no_grad():
            max_grad = abs(float(theta.grad.detach().item())) if theta.grad is not None else 0.0
            print(f'    {profile_type} step {i + 1}/{PROFILE_LBFGS_STEPS}: loss={float(last_loss.detach().item()):.6f}, grad={max_grad:.2e}')
            if max_grad < PROFILE_GRAD_TOL:
                break

    est = profile_estimate_from_theta(profile_type, theta, anchor)
    loss = float(last_loss.detach().cpu().item()) if isinstance(last_loss, torch.Tensor) else np.nan
    return est, loss, last_iter


def fit_partial_profiles_for_row(row):
    variant = str(row['variant'])
    hour_idx = int(row['hour_idx'])
    stride = int(row['resolution_stride'])
    anchor = {
        'sigmasq': float(row['est_sigmasq']),
        'range': float(row['est_range']),
        'nugget': float(row.get('est_nugget', 0.0)),
    }

    hour_map, time_key = load_hour_map(hour_idx)
    thin_map_regular, thin_grid_regular, _ = thin_hour_map(hour_map, stride)
    hybrid_order, thin_grid, nns_map = make_hybrid_ordering(thin_grid_regular)
    thin_map = {k: v[hybrid_order].contiguous() for k, v in thin_map_regular.items()}
    model = build_model(variant, thin_map, nns_map)
    t_pre = time.time()
    model.precompute_conditioning_sets()
    pre_s = time.time() - t_pre
    diag = space_diag(model)

    out_rows = []
    for profile_type in PROFILE_TYPES:
        print('\n' + '-' * 90)
        print(f"profile={profile_type} | {variant} | hour={hour_idx + 1} | {resolution_label(stride)} | anchor={anchor}")
        t_fit = time.time()
        est, loss, fit_iter = optimize_profile(model, variant, profile_type, anchor)
        fit_s = time.time() - t_fit
        profile_row = dict(row)
        profile_row.update({
            'fit_type': profile_type,
            'profile_type': profile_type,
            'fixed_sigmasq': anchor['sigmasq'] if profile_type == 'range_only' else np.nan,
            'fixed_range': anchor['range'] if profile_type == 'sigma_only' else np.nan,
            'fixed_nugget': anchor['nugget'],
            'loss': float(loss),
            'fit_iter_raw': int(fit_iter),
            'fit_steps_reported': int(fit_iter) + 1,
            'precompute_s': float(pre_s),
            'fit_s': float(fit_s),
            'total_s': float(pre_s + fit_s),
            'est_sigmasq': float(est['sigmasq']),
            'est_range': float(est['range']),
            'est_nugget': float(est.get('nugget', 0.0)),
            **diag,
        })
        out_rows.append(profile_row)

    del model, hour_map, thin_map_regular, thin_map
    empty_cache()
    return out_rows


profile_path = OUT_DIR / f'{OUT_PREFIX}_partial_profile.csv'
if RUN_PROFILE_FITS:
    if 'fit_df' not in globals() or fit_df.empty:
        fit_df = pd.read_csv(OUT_DIR / f'{OUT_PREFIX}_full.csv')

    profile_rows = []
    for _, fit_row in fit_df.iterrows():
        profile_rows.extend(fit_partial_profiles_for_row(fit_row))
        tmp = round_df(pd.DataFrame(profile_rows))
        tmp.to_csv(profile_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')

    profile_df = pd.DataFrame(profile_rows)
    round_df(profile_df).to_csv(profile_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
else:
    profile_df = pd.read_csv(profile_path) if profile_path.exists() else pd.DataFrame()

print('Saved partial-profile fits:', profile_path)
display(round_df(profile_df[['variant','profile_type','hour_idx','resolution_stride','resolution_label','loss','est_sigmasq','est_range','est_nugget','fixed_sigmasq','fixed_range','fixed_nugget','n_grid','n_valid','total_s']]))

# %%
# Combined parameter trajectories:
# row 1: nugget0 full fit
# row 2: nugget_free full fit
# row 3: nugget0 partial profiles anchored at the full-fit estimates
if 'fit_df' not in globals() or fit_df.empty:
    fit_df = pd.read_csv(OUT_DIR / f'{OUT_PREFIX}_full.csv')
if 'profile_df' not in globals() or profile_df.empty:
    profile_df = pd.read_csv(OUT_DIR / f'{OUT_PREFIX}_partial_profile.csv')

full_plot_df = fit_df.copy()
full_plot_df['resolution_label'] = pd.Categorical(
    full_plot_df['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
)
full_plot_df = full_plot_df.sort_values(['variant', 'hour_idx', 'resolution_label'])

prof_plot_df = profile_df.copy()
prof_plot_df['resolution_label'] = pd.Categorical(
    prof_plot_df['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
)
prof_plot_df = prof_plot_df.sort_values(['variant', 'profile_type', 'hour_idx', 'resolution_label'])
prof_anchor_variant = 'nugget0'

combined_param_values = {
    'sigmasq': [full_plot_df['est_sigmasq'], prof_plot_df.loc[prof_plot_df['profile_type'] == 'sigma_only', 'est_sigmasq']],
    'range': [full_plot_df['est_range'], prof_plot_df.loc[prof_plot_df['profile_type'] == 'range_only', 'est_range']],
    'nugget': [full_plot_df['est_nugget'], prof_plot_df['fixed_nugget']],
}
combined_param_ylims = {}
for p, series_list in combined_param_values.items():
    vals = pd.concat([pd.to_numeric(s, errors='coerce') for s in series_list], ignore_index=True)
    vals = vals.replace([np.inf, -np.inf], np.nan).dropna()
    if vals.empty:
        combined_param_ylims[p] = (0.0, 1.0)
        continue
    lo, hi = float(vals.min()), float(vals.max())
    pad = max(abs(hi) * 0.05, 0.05) if np.isclose(lo, hi) else 0.08 * (hi - lo)
    if p == 'nugget':
        lo = min(0.0, lo)
    combined_param_ylims[p] = (lo - pad, hi + pad)

fig, axes = plt.subplots(3, 3, figsize=(15, 10.5), constrained_layout=True, sharex=True)
full_rows = [('nugget0', 'full: nugget fixed 0'), ('nugget_free', 'full: nugget free')]
params_to_plot = ['sigmasq', 'range', 'nugget']
for r, (variant, row_label) in enumerate(full_rows):
    sub_v = full_plot_df[full_plot_df['variant'] == variant]
    for c, p in enumerate(params_to_plot):
        ax = axes[r, c]
        for hour_idx, sub in sub_v.groupby('hour_idx'):
            ax.plot(sub['resolution_label'].astype(str), sub[f'est_{p}'], marker='o', linewidth=1.4, label=f'h{int(hour_idx)+1}')
        ax.set_title(f'{row_label}: {p}')
        ax.set_xlabel('resolution thinning')
        ax.set_ylabel('estimate')
        ax.set_ylim(*combined_param_ylims[p])
        ax.grid(True, alpha=0.3)

sigma_prof = prof_plot_df[(prof_plot_df['variant'] == prof_anchor_variant) & (prof_plot_df['profile_type'] == 'sigma_only')]
range_prof = prof_plot_df[(prof_plot_df['variant'] == prof_anchor_variant) & (prof_plot_df['profile_type'] == 'range_only')]

ax = axes[2, 0]
for hour_idx, sub in sigma_prof.groupby('hour_idx'):
    ax.plot(sub['resolution_label'].astype(str), sub['est_sigmasq'], marker='o', linewidth=1.4, label=f'h{int(hour_idx)+1}')
ax.set_title('profile: estimate sigmasq only\nrange+nugget fixed')
ax.set_xlabel('resolution thinning')
ax.set_ylabel('estimate')
ax.set_ylim(*combined_param_ylims['sigmasq'])
ax.grid(True, alpha=0.3)

ax = axes[2, 1]
for hour_idx, sub in range_prof.groupby('hour_idx'):
    ax.plot(sub['resolution_label'].astype(str), sub['est_range'], marker='o', linewidth=1.4, label=f'h{int(hour_idx)+1}')
ax.set_title('profile: estimate range only\nsigmasq+nugget fixed')
ax.set_xlabel('resolution thinning')
ax.set_ylabel('estimate')
ax.set_ylim(*combined_param_ylims['range'])
ax.grid(True, alpha=0.3)

ax = axes[2, 2]
for hour_idx, sub in sigma_prof.groupby('hour_idx'):
    ax.plot(sub['resolution_label'].astype(str), sub['fixed_nugget'], marker='o', linewidth=1.4, label=f'h{int(hour_idx)+1}')
ax.set_title('profile anchor: fixed nugget')
ax.set_xlabel('resolution thinning')
ax.set_ylabel('estimate')
ax.set_ylim(*combined_param_ylims['nugget'])
ax.grid(True, alpha=0.3)

axes[0, -1].legend(ncol=2, fontsize=8, title='hour')
fig.suptitle(f'Pure-space isotropic Hybrid Vecchia, smooth={SMOOTH}: full and partial-profile parameter trajectories', fontsize=14)
param_plot_path = OUT_DIR / f'{OUT_PREFIX}_parameter_trajectories.png'
fig.savefig(param_plot_path, dpi=180, bbox_inches='tight')
print('Saved combined parameter plot:', param_plot_path)
plt.show()
# Out:
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2259, m mean/med/max=9.9/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=1 | x8 | anchor={'sigmasq': 8.53546347597883, 'range': 0.5603675365911069, 'nugget': 4.481956129892668}
#     sigma_only step 1/8: loss=1.526570, grad=1.31e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=1 | x8 | anchor={'sigmasq': 8.53546347597883, 'range': 0.5603675365911069, 'nugget': 4.481956129892668}
#     range_only step 1/8: loss=1.526570, grad=9.91e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4518, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=1 | x4 | anchor={'sigmasq': 9.258879729709726, 'range': 0.43730797612801914, 'nugget': 3.472680106596387}
#     sigma_only step 1/8: loss=1.447855, grad=3.93e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=1 | x4 | anchor={'sigmasq': 9.258879729709726, 'range': 0.43730797612801914, 'nugget': 3.472680106596387}
#     range_only step 1/8: loss=1.447855, grad=5.30e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=9033, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=1 | x2 | anchor={'sigmasq': 10.082084346291511, 'range': 0.26234781508515775, 'nugget': 3.980713803371999}
#     sigma_only step 1/8: loss=1.530893, grad=2.94e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=1 | x2 | anchor={'sigmasq': 10.082084346291511, 'range': 0.26234781508515775, 'nugget': 3.980713803371999}
#     range_only step 1/8: loss=1.530893, grad=4.42e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.2s. tails=18067, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=1 | x1 | anchor={'sigmasq': 10.191299388911759, 'range': 0.23095905241963757, 'nugget': 2.967365741763184}
#     sigma_only step 1/8: loss=1.407443, grad=1.62e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=1 | x1 | anchor={'sigmasq': 10.191299388911759, 'range': 0.23095905241963757, 'nugget': 2.967365741763184}
#     range_only step 1/8: loss=1.407443, grad=6.46e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2208, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=2 | x8 | anchor={'sigmasq': 11.140331280263137, 'range': 0.47494247249420024, 'nugget': 4.0516991654048695}
#     sigma_only step 1/8: loss=1.575913, grad=4.70e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=2 | x8 | anchor={'sigmasq': 11.140331280263137, 'range': 0.47494247249420024, 'nugget': 4.0516991654048695}
#     range_only step 1/8: loss=1.575913, grad=1.02e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4422, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=2 | x4 | anchor={'sigmasq': 12.195313811189905, 'range': 0.4648668978475616, 'nugget': 3.371127830002206}
#     sigma_only step 1/8: loss=1.487371, grad=3.21e-08
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=2 | x4 | anchor={'sigmasq': 12.195313811189905, 'range': 0.4648668978475616, 'nugget': 3.371127830002206}
#     range_only step 1/8: loss=1.487371, grad=7.74e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=8840, m mean/med/max=9.9/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=2 | x2 | anchor={'sigmasq': 12.805395156097934, 'range': 0.2851344020235044, 'nugget': 2.0639022584582047}
#     sigma_only step 1/8: loss=1.409462, grad=1.15e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=2 | x2 | anchor={'sigmasq': 12.805395156097934, 'range': 0.2851344020235044, 'nugget': 2.0639022584582047}
#     range_only step 1/8: loss=1.409462, grad=2.11e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=17670, m mean/med/max=9.9/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=2 | x1 | anchor={'sigmasq': 12.920721648766245, 'range': 0.259220571342034, 'nugget': 2.10988892902981}
#     sigma_only step 1/8: loss=1.351931, grad=7.23e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=2 | x1 | anchor={'sigmasq': 12.920721648766245, 'range': 0.259220571342034, 'nugget': 2.10988892902981}
#     range_only step 1/8: loss=1.351931, grad=9.65e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2082, m mean/med/max=9.3/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=3 | x8 | anchor={'sigmasq': 12.991779097098583, 'range': 0.42148104231892314, 'nugget': 4.047331342986995}
#     sigma_only step 1/8: loss=1.637766, grad=5.51e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=3 | x8 | anchor={'sigmasq': 12.991779097098583, 'range': 0.42148104231892314, 'nugget': 4.047331342986995}
#     range_only step 1/8: loss=1.637766, grad=3.28e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4176, m mean/med/max=9.5/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=3 | x4 | anchor={'sigmasq': 14.045364336089431, 'range': 0.3947302131561483, 'nugget': 3.419048236209922}
#     sigma_only step 1/8: loss=1.561750, grad=1.70e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=3 | x4 | anchor={'sigmasq': 14.045364336089431, 'range': 0.3947302131561483, 'nugget': 3.419048236209922}
#     range_only step 1/8: loss=1.561750, grad=2.10e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=8353, m mean/med/max=9.6/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=3 | x2 | anchor={'sigmasq': 14.860521269898788, 'range': 0.27891901585741713, 'nugget': 1.9627501856646952}
#     sigma_only step 1/8: loss=1.454249, grad=5.64e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=3 | x2 | anchor={'sigmasq': 14.860521269898788, 'range': 0.27891901585741713, 'nugget': 1.9627501856646952}
#     range_only step 1/8: loss=1.454249, grad=3.19e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=16698, m mean/med/max=9.6/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=3 | x1 | anchor={'sigmasq': 15.118276402573352, 'range': 0.2406194276186774, 'nugget': 1.5229633601760437}
#     sigma_only step 1/8: loss=1.353957, grad=4.49e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=3 | x1 | anchor={'sigmasq': 15.118276402573352, 'range': 0.2406194276186774, 'nugget': 1.5229633601760437}
#     range_only step 1/8: loss=1.353957, grad=3.34e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=2114, m mean/med/max=9.5/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=4 | x8 | anchor={'sigmasq': 14.563637869326868, 'range': 0.48412147641106595, 'nugget': 4.319520053446033}
#     sigma_only step 1/8: loss=1.654496, grad=1.51e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=4 | x8 | anchor={'sigmasq': 14.563637869326868, 'range': 0.48412147641106595, 'nugget': 4.319520053446033}
#     range_only step 1/8: loss=1.654496, grad=1.46e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4217, m mean/med/max=9.5/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=4 | x4 | anchor={'sigmasq': 14.976074301523315, 'range': 0.406897671583217, 'nugget': 3.6992525327754375}
#     sigma_only step 1/8: loss=1.590861, grad=2.37e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=4 | x4 | anchor={'sigmasq': 14.976074301523315, 'range': 0.406897671583217, 'nugget': 3.6992525327754375}
#     range_only step 1/8: loss=1.590861, grad=1.22e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=8428, m mean/med/max=9.6/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=4 | x2 | anchor={'sigmasq': 16.650526007815287, 'range': 0.24962036813533303, 'nugget': 1.406993706304475}
#     sigma_only step 1/8: loss=1.475767, grad=2.67e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=4 | x2 | anchor={'sigmasq': 16.650526007815287, 'range': 0.24962036813533303, 'nugget': 1.406993706304475}
#     range_only step 1/8: loss=1.475767, grad=3.75e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=16863, m mean/med/max=9.7/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=4 | x1 | anchor={'sigmasq': 16.781733010786798, 'range': 0.23283877562859406, 'nugget': 1.344163689320415}
#     sigma_only step 1/8: loss=1.379010, grad=1.30e-05
#     sigma_only step 2/8: loss=1.379010, grad=1.30e-05
#     sigma_only step 3/8: loss=1.379010, grad=1.30e-05
#     sigma_only step 4/8: loss=1.379010, grad=1.30e-05
#     sigma_only step 5/8: loss=1.379010, grad=1.30e-05
#     sigma_only step 6/8: loss=1.379010, grad=1.30e-05
#     sigma_only step 7/8: loss=1.379010, grad=1.30e-05
#     sigma_only step 8/8: loss=1.379010, grad=1.30e-05
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=4 | x1 | anchor={'sigmasq': 16.781733010786798, 'range': 0.23283877562859406, 'nugget': 1.344163689320415}
#     range_only step 1/8: loss=1.379010, grad=1.19e-05
#     range_only step 2/8: loss=1.379010, grad=1.19e-05
#     range_only step 3/8: loss=1.379010, grad=1.19e-05
#     range_only step 4/8: loss=1.379010, grad=1.19e-05
#     range_only step 5/8: loss=1.379010, grad=1.19e-05
#     range_only step 6/8: loss=1.379010, grad=1.19e-05
#     range_only step 7/8: loss=1.379010, grad=1.19e-05
#     range_only step 8/8: loss=1.379010, grad=1.19e-05
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2145, m mean/med/max=9.5/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=5 | x8 | anchor={'sigmasq': 13.530053407588532, 'range': 0.4228539956233314, 'nugget': 5.3058614715563985}
#     sigma_only step 1/8: loss=1.716733, grad=1.20e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=5 | x8 | anchor={'sigmasq': 13.530053407588532, 'range': 0.4228539956233314, 'nugget': 5.3058614715563985}
#     range_only step 1/8: loss=1.716733, grad=1.18e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4288, m mean/med/max=9.5/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=5 | x4 | anchor={'sigmasq': 15.511843804724855, 'range': 0.32606737644586226, 'nugget': 3.703785001485991}
#     sigma_only step 1/8: loss=1.649204, grad=9.13e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=5 | x4 | anchor={'sigmasq': 15.511843804724855, 'range': 0.32606737644586226, 'nugget': 3.703785001485991}
#     range_only step 1/8: loss=1.649204, grad=7.77e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=8552, m mean/med/max=9.6/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=5 | x2 | anchor={'sigmasq': 17.0428836432019, 'range': 0.2419071134983827, 'nugget': 1.8120561083667193}
#     sigma_only step 1/8: loss=1.528486, grad=2.57e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=5 | x2 | anchor={'sigmasq': 17.0428836432019, 'range': 0.2419071134983827, 'nugget': 1.8120561083667193}
#     range_only step 1/8: loss=1.528486, grad=3.08e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=17088, m mean/med/max=9.7/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=5 | x1 | anchor={'sigmasq': 17.565520019363465, 'range': 0.20861817302436658, 'nugget': 1.220712510614806}
#     sigma_only step 1/8: loss=1.418181, grad=7.55e-08
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=5 | x1 | anchor={'sigmasq': 17.565520019363465, 'range': 0.20861817302436658, 'nugget': 1.220712510614806}
#     range_only step 1/8: loss=1.418181, grad=3.12e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2221, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=6 | x8 | anchor={'sigmasq': 12.550903468796685, 'range': 0.41277565159386986, 'nugget': 5.092937377903936}
#     sigma_only step 1/8: loss=1.690493, grad=5.51e-08
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=6 | x8 | anchor={'sigmasq': 12.550903468796685, 'range': 0.41277565159386986, 'nugget': 5.092937377903936}
#     range_only step 1/8: loss=1.690493, grad=6.06e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4439, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=6 | x4 | anchor={'sigmasq': 13.85449773889091, 'range': 0.30836459597526766, 'nugget': 3.4719281779854865}
#     sigma_only step 1/8: loss=1.613895, grad=2.58e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=6 | x4 | anchor={'sigmasq': 13.85449773889091, 'range': 0.30836459597526766, 'nugget': 3.4719281779854865}
#     range_only step 1/8: loss=1.613895, grad=2.65e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=8881, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=6 | x2 | anchor={'sigmasq': 15.057313209466452, 'range': 0.22291456403771048, 'nugget': 1.9016149054052283}
#     sigma_only step 1/8: loss=1.514475, grad=1.27e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=6 | x2 | anchor={'sigmasq': 15.057313209466452, 'range': 0.22291456403771048, 'nugget': 1.9016149054052283}
#     range_only step 1/8: loss=1.514475, grad=9.65e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=17760, m mean/med/max=9.9/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=6 | x1 | anchor={'sigmasq': 15.448243352748698, 'range': 0.18434217926566338, 'nugget': 1.3076346782007486}
#     sigma_only step 1/8: loss=1.418636, grad=1.89e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=6 | x1 | anchor={'sigmasq': 15.448243352748698, 'range': 0.18434217926566338, 'nugget': 1.3076346782007486}
#     range_only step 1/8: loss=1.418636, grad=3.29e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2264, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=7 | x8 | anchor={'sigmasq': 10.789753090128317, 'range': 0.4119249107589511, 'nugget': 4.552203848690546}
#     sigma_only step 1/8: loss=1.624713, grad=7.16e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=7 | x8 | anchor={'sigmasq': 10.789753090128317, 'range': 0.4119249107589511, 'nugget': 4.552203848690546}
#     range_only step 1/8: loss=1.624713, grad=1.93e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4527, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=7 | x4 | anchor={'sigmasq': 11.480441452632384, 'range': 0.37377494524588706, 'nugget': 4.319471618784535}
#     sigma_only step 1/8: loss=1.583505, grad=3.00e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=7 | x4 | anchor={'sigmasq': 11.480441452632384, 'range': 0.37377494524588706, 'nugget': 4.319471618784535}
#     range_only step 1/8: loss=1.583505, grad=3.81e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=9052, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=7 | x2 | anchor={'sigmasq': 12.515859052444185, 'range': 0.2208151711543727, 'nugget': 2.2971066875521937}
#     sigma_only step 1/8: loss=1.488662, grad=2.27e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=7 | x2 | anchor={'sigmasq': 12.515859052444185, 'range': 0.2208151711543727, 'nugget': 2.2971066875521937}
#     range_only step 1/8: loss=1.488662, grad=3.75e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.2s. tails=18104, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=7 | x1 | anchor={'sigmasq': 13.540151996005122, 'range': 0.16954396835232927, 'nugget': 1.1192723251394572}
#     sigma_only step 1/8: loss=1.375890, grad=1.44e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=7 | x1 | anchor={'sigmasq': 13.540151996005122, 'range': 0.16954396835232927, 'nugget': 1.1192723251394572}
#     range_only step 1/8: loss=1.375890, grad=1.78e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2263, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=8 | x8 | anchor={'sigmasq': 9.220822942090782, 'range': 0.42453379079240683, 'nugget': 5.953827191977489}
#     sigma_only step 1/8: loss=1.670248, grad=1.77e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=8 | x8 | anchor={'sigmasq': 9.220822942090782, 'range': 0.42453379079240683, 'nugget': 5.953827191977489}
#     range_only step 1/8: loss=1.670248, grad=3.36e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4526, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=8 | x4 | anchor={'sigmasq': 10.15799412529515, 'range': 0.3319105934821068, 'nugget': 4.1442763032925045}
#     sigma_only step 1/8: loss=1.566353, grad=5.68e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=8 | x4 | anchor={'sigmasq': 10.15799412529515, 'range': 0.3319105934821068, 'nugget': 4.1442763032925045}
#     range_only step 1/8: loss=1.566353, grad=2.01e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=9051, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=8 | x2 | anchor={'sigmasq': 11.796768366942404, 'range': 0.20753201704389104, 'nugget': 2.154041648608075}
#     sigma_only step 1/8: loss=1.474098, grad=3.87e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=8 | x2 | anchor={'sigmasq': 11.796768366942404, 'range': 0.20753201704389104, 'nugget': 2.154041648608075}
#     range_only step 1/8: loss=1.474098, grad=4.45e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=18102, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=8 | x1 | anchor={'sigmasq': 12.105695885312052, 'range': 0.1765153894260959, 'nugget': 1.7611391651368316}
#     sigma_only step 1/8: loss=1.394268, grad=2.97e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=8 | x1 | anchor={'sigmasq': 12.105695885312052, 'range': 0.1765153894260959, 'nugget': 1.7611391651368316}
#     range_only step 1/8: loss=1.394268, grad=1.88e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2259, m mean/med/max=9.9/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=1 | x8 | anchor={'sigmasq': 12.28641153139413, 'range': 0.1730448937665263, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.559517, grad=1.80e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=1 | x8 | anchor={'sigmasq': 12.28641153139413, 'range': 0.1730448937665263, 'nugget': 0.0}
#     range_only step 1/8: loss=1.559517, grad=7.64e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4518, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=1 | x4 | anchor={'sigmasq': 11.753053211362785, 'range': 0.16519469999469127, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.464414, grad=2.09e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=1 | x4 | anchor={'sigmasq': 11.753053211362785, 'range': 0.16519469999469127, 'nugget': 0.0}
#     range_only step 1/8: loss=1.464414, grad=8.97e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=9033, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=1 | x2 | anchor={'sigmasq': 13.342660815426996, 'range': 0.10535133082630684, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.552602, grad=3.18e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=1 | x2 | anchor={'sigmasq': 13.342660815426996, 'range': 0.10535133082630684, 'nugget': 0.0}
#     range_only step 1/8: loss=1.552602, grad=1.69e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=18067, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=1 | x1 | anchor={'sigmasq': 12.199320342003492, 'range': 0.09216964285900751, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.428849, grad=1.37e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=1 | x1 | anchor={'sigmasq': 12.199320342003492, 'range': 0.09216964285900751, 'nugget': 0.0}
#     range_only step 1/8: loss=1.428849, grad=1.16e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2208, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=2 | x8 | anchor={'sigmasq': 14.235938739514339, 'range': 0.19621442608959594, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.595542, grad=2.58e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=2 | x8 | anchor={'sigmasq': 14.235938739514339, 'range': 0.19621442608959594, 'nugget': 0.0}
#     range_only step 1/8: loss=1.595542, grad=2.72e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4422, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=2 | x4 | anchor={'sigmasq': 13.80364195844178, 'range': 0.185601153374901, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.503798, grad=1.49e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=2 | x4 | anchor={'sigmasq': 13.80364195844178, 'range': 0.185601153374901, 'nugget': 0.0}
#     range_only step 1/8: loss=1.503798, grad=3.53e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=8840, m mean/med/max=9.9/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=2 | x2 | anchor={'sigmasq': 13.511144496333218, 'range': 0.15429341335782684, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.418079, grad=5.59e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=2 | x2 | anchor={'sigmasq': 13.511144496333218, 'range': 0.15429341335782684, 'nugget': 0.0}
#     range_only step 1/8: loss=1.418079, grad=6.08e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=17670, m mean/med/max=9.9/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=2 | x1 | anchor={'sigmasq': 13.064815272442853, 'range': 0.11776844273722283, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.366844, grad=5.38e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=2 | x1 | anchor={'sigmasq': 13.064815272442853, 'range': 0.11776844273722283, 'nugget': 0.0}
#     range_only step 1/8: loss=1.366844, grad=2.37e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2082, m mean/med/max=9.3/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=3 | x8 | anchor={'sigmasq': 16.09008741370763, 'range': 0.20222525419453155, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.650534, grad=2.30e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=3 | x8 | anchor={'sigmasq': 16.09008741370763, 'range': 0.20222525419453155, 'nugget': 0.0}
#     range_only step 1/8: loss=1.650534, grad=1.01e-05
#     range_only step 2/8: loss=1.650534, grad=1.01e-05
#     range_only step 3/8: loss=1.650534, grad=1.01e-05
#     range_only step 4/8: loss=1.650534, grad=1.01e-05
#     range_only step 5/8: loss=1.650534, grad=1.01e-05
#     range_only step 6/8: loss=1.650534, grad=1.01e-05
#     range_only step 7/8: loss=1.650534, grad=1.01e-05
#     range_only step 8/8: loss=1.650534, grad=1.01e-05
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4176, m mean/med/max=9.5/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=3 | x4 | anchor={'sigmasq': 15.8931208752247, 'range': 0.18856194376027388, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.571737, grad=6.07e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=3 | x4 | anchor={'sigmasq': 15.8931208752247, 'range': 0.18856194376027388, 'nugget': 0.0}
#     range_only step 1/8: loss=1.571737, grad=6.41e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=8353, m mean/med/max=9.6/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=3 | x2 | anchor={'sigmasq': 15.402674399137222, 'range': 0.16439274057315126, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.461324, grad=2.56e-08
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=3 | x2 | anchor={'sigmasq': 15.402674399137222, 'range': 0.16439274057315126, 'nugget': 0.0}
#     range_only step 1/8: loss=1.461324, grad=2.56e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=16698, m mean/med/max=9.6/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=3 | x1 | anchor={'sigmasq': 14.807086993930822, 'range': 0.138846083225642, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.361959, grad=8.49e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=3 | x1 | anchor={'sigmasq': 14.807086993930822, 'range': 0.138846083225642, 'nugget': 0.0}
#     range_only step 1/8: loss=1.361959, grad=3.12e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2114, m mean/med/max=9.5/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=4 | x8 | anchor={'sigmasq': 17.561138247959434, 'range': 0.21662001430739203, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.671028, grad=2.21e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=4 | x8 | anchor={'sigmasq': 17.561138247959434, 'range': 0.21662001430739203, 'nugget': 0.0}
#     range_only step 1/8: loss=1.671028, grad=3.98e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=4217, m mean/med/max=9.5/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=4 | x4 | anchor={'sigmasq': 17.22033207032816, 'range': 0.1935600645822099, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.602181, grad=5.21e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=4 | x4 | anchor={'sigmasq': 17.22033207032816, 'range': 0.1935600645822099, 'nugget': 0.0}
#     range_only step 1/8: loss=1.602181, grad=4.07e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=8428, m mean/med/max=9.6/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=4 | x2 | anchor={'sigmasq': 17.072928624150137, 'range': 0.17852400087777817, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.478877, grad=5.94e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=4 | x2 | anchor={'sigmasq': 17.072928624150137, 'range': 0.17852400087777817, 'nugget': 0.0}
#     range_only step 1/8: loss=1.478877, grad=8.13e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=16863, m mean/med/max=9.7/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=4 | x1 | anchor={'sigmasq': 16.443699553451307, 'range': 0.14869391813533356, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.384703, grad=5.12e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=4 | x1 | anchor={'sigmasq': 16.443699553451307, 'range': 0.14869391813533356, 'nugget': 0.0}
#     range_only step 1/8: loss=1.384703, grad=1.56e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2145, m mean/med/max=9.5/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=5 | x8 | anchor={'sigmasq': 17.939412368264904, 'range': 0.1832996181816007, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.735764, grad=7.44e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=5 | x8 | anchor={'sigmasq': 17.939412368264904, 'range': 0.1832996181816007, 'nugget': 0.0}
#     range_only step 1/8: loss=1.735764, grad=1.30e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=4288, m mean/med/max=9.5/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=5 | x4 | anchor={'sigmasq': 18.093725864034397, 'range': 0.17814472561587444, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.657185, grad=7.94e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=5 | x4 | anchor={'sigmasq': 18.093725864034397, 'range': 0.17814472561587444, 'nugget': 0.0}
#     range_only step 1/8: loss=1.657185, grad=3.01e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=8552, m mean/med/max=9.6/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=5 | x2 | anchor={'sigmasq': 17.73765179671373, 'range': 0.16388002000532828, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.532830, grad=2.56e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=5 | x2 | anchor={'sigmasq': 17.73765179671373, 'range': 0.16388002000532828, 'nugget': 0.0}
#     range_only step 1/8: loss=1.532830, grad=7.17e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=17088, m mean/med/max=9.7/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=5 | x1 | anchor={'sigmasq': 17.321536889762108, 'range': 0.14480208310989526, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.422042, grad=1.79e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=5 | x1 | anchor={'sigmasq': 17.321536889762108, 'range': 0.14480208310989526, 'nugget': 0.0}
#     range_only step 1/8: loss=1.422042, grad=9.83e-08
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2221, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=6 | x8 | anchor={'sigmasq': 16.785878232075063, 'range': 0.1783781822955696, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.708131, grad=4.34e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=6 | x8 | anchor={'sigmasq': 16.785878232075063, 'range': 0.1783781822955696, 'nugget': 0.0}
#     range_only step 1/8: loss=1.708131, grad=6.03e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=4439, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=6 | x4 | anchor={'sigmasq': 16.311847311480363, 'range': 0.16898340059961198, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.621939, grad=1.02e-05
#     sigma_only step 2/8: loss=1.621939, grad=1.02e-05
#     sigma_only step 3/8: loss=1.621939, grad=1.02e-05
#     sigma_only step 4/8: loss=1.621939, grad=1.02e-05
#     sigma_only step 5/8: loss=1.621939, grad=1.02e-05
#     sigma_only step 6/8: loss=1.621939, grad=1.02e-05
#     sigma_only step 7/8: loss=1.621939, grad=1.02e-05
#     sigma_only step 8/8: loss=1.621939, grad=1.02e-05
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=6 | x4 | anchor={'sigmasq': 16.311847311480363, 'range': 0.16898340059961198, 'nugget': 0.0}
#     range_only step 1/8: loss=1.621939, grad=2.17e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=8881, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=6 | x2 | anchor={'sigmasq': 15.986855420711523, 'range': 0.14792847690712863, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.519180, grad=4.06e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=6 | x2 | anchor={'sigmasq': 15.986855420711523, 'range': 0.14792847690712863, 'nugget': 0.0}
#     range_only step 1/8: loss=1.519180, grad=6.20e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=17760, m mean/med/max=9.9/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=6 | x1 | anchor={'sigmasq': 15.697191644105033, 'range': 0.1283458498627337, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.422710, grad=2.43e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=6 | x1 | anchor={'sigmasq': 15.697191644105033, 'range': 0.1283458498627337, 'nugget': 0.0}
#     range_only step 1/8: loss=1.422710, grad=1.90e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=2264, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=7 | x8 | anchor={'sigmasq': 14.485336481545291, 'range': 0.1714409263444893, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.644554, grad=9.90e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=7 | x8 | anchor={'sigmasq': 14.485336481545291, 'range': 0.1714409263444893, 'nugget': 0.0}
#     range_only step 1/8: loss=1.644554, grad=5.05e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4527, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=7 | x4 | anchor={'sigmasq': 14.330942065851376, 'range': 0.14916636788649024, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.598725, grad=2.81e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=7 | x4 | anchor={'sigmasq': 14.330942065851376, 'range': 0.14916636788649024, 'nugget': 0.0}
#     range_only step 1/8: loss=1.598725, grad=3.10e-08
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=9052, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=7 | x2 | anchor={'sigmasq': 13.946423855585804, 'range': 0.13104777724208394, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.496199, grad=1.79e-09
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=7 | x2 | anchor={'sigmasq': 13.946423855585804, 'range': 0.13104777724208394, 'nugget': 0.0}
#     range_only step 1/8: loss=1.496199, grad=1.27e-08
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.2s. tails=18104, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=7 | x1 | anchor={'sigmasq': 13.867204742381045, 'range': 0.1225926873113747, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.379074, grad=1.47e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=7 | x1 | anchor={'sigmasq': 13.867204742381045, 'range': 0.1225926873113747, 'nugget': 0.0}
#     range_only step 1/8: loss=1.379074, grad=1.09e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=2263, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=8 | x8 | anchor={'sigmasq': 14.6738527517099, 'range': 0.14709713150694964, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.693857, grad=8.95e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=8 | x8 | anchor={'sigmasq': 14.6738527517099, 'range': 0.14709713150694964, 'nugget': 0.0}
#     range_only step 1/8: loss=1.693857, grad=4.24e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4526, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=8 | x4 | anchor={'sigmasq': 13.541393840372075, 'range': 0.14545108195829176, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.578903, grad=7.53e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=8 | x4 | anchor={'sigmasq': 13.541393840372075, 'range': 0.14545108195829176, 'nugget': 0.0}
#     range_only step 1/8: loss=1.578903, grad=2.02e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=9051, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=8 | x2 | anchor={'sigmasq': 13.238869719777618, 'range': 0.1275839611946342, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.480312, grad=1.56e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=8 | x2 | anchor={'sigmasq': 13.238869719777618, 'range': 0.1275839611946342, 'nugget': 0.0}
#     range_only step 1/8: loss=1.480312, grad=1.11e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=18102, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=8 | x1 | anchor={'sigmasq': 12.977007291820597, 'range': 0.1071487647678574, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.401319, grad=3.78e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=8 | x1 | anchor={'sigmasq': 12.977007291820597, 'range': 0.1071487647678574, 'nugget': 0.0}
#     range_only step 1/8: loss=1.401319, grad=3.90e-06
# Saved partial-profile fits: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_spectral_s05_nugget_compare_hybrid_050826_partial_profile.csv
#          variant profile_type  hour_idx  resolution_stride resolution_label    loss  est_sigmasq  est_range  est_nugget  fixed_sigmasq  fixed_range  fixed_nugget  n_grid  n_valid  total_s
# 0    nugget_free   sigma_only         0                  8               x8  1.5266       8.5355     0.5604      4.4820            NaN       0.5604        4.4820    2266     2259   0.2183
# 1    nugget_free   range_only         0                  8               x8  1.5266       8.5355     0.5604      4.4820         8.5355          NaN        4.4820    2266     2259   0.0636
# 2    nugget_free   sigma_only         0                  4               x4  1.4479       9.2589     0.4373      3.4727            NaN       0.4373        3.4727    4532     4518   0.2650
# 3    nugget_free   range_only         0                  4               x4  1.4479       9.2589     0.4373      3.4727         9.2589          NaN        3.4727    4532     4518   0.0528
# 4    nugget_free   sigma_only         0                  2               x2  1.5309      10.0821     0.2623      3.9807            NaN       0.2623        3.9807    9063     9033   0.2634
# ..           ...          ...       ...                ...              ...     ...          ...        ...         ...            ...          ...           ...     ...      ...      ...
# 123      nugget0   range_only         7                  4               x4  1.5789      13.5414     0.1455      0.0000        13.5414          NaN        0.0000    4532     4526   0.0657
# 124      nugget0   sigma_only         7                  2               x2  1.4803      13.2389     0.1276      0.0000            NaN       0.1276        0.0000    9063     9051   0.2837
# 125      nugget0   range_only         7                  2               x2  1.4803      13.2389     0.1276      0.0000        13.2389          NaN        0.0000    9063     9051   0.0991
# 126      nugget0   sigma_only         7                  1               x1  1.4013      12.9770     0.1071      0.0000            NaN       0.1071        0.0000   18126    18102   0.3130
# 127      nugget0   range_only         7                  1               x1  1.4013      12.9770     0.1071      0.0000        12.9770          NaN        0.0000   18126    18102   0.2142
#
# [128 rows x 15 columns]
# Saved combined parameter plot: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_spectral_s05_nugget_compare_hybrid_050826_parameter_trajectories.png

# %% [markdown]
# ## Spectral diagnostic
#
# The empirical spectrum uses the same thinned points as each fit. Residuals are computed after an OLS `intercept + lat + lon` detrend, placed back onto the full grid, tapered, zero-filled, FFTed, and radially averaged. For `nugget_free`, the theoretical spectrum includes the fitted flat nugget component before being scaled to the empirical curve.

# %%
SPECTRAL_SMOOTH = SMOOTH
RADIAL_N_BINS = 70
RADIAL_QMAX = 0.985
APPLY_HANN = True
EPS = 1e-12

_lat_key = np.round(grid_coords_full[:, 0], 10)
_lon_key = np.round(grid_coords_full[:, 1], 10)
lat_vals = np.sort(np.unique(_lat_key))
lon_vals = np.sort(np.unique(_lon_key))
lat_to_row = {float(v): i for i, v in enumerate(lat_vals)}
lon_to_col = {float(v): i for i, v in enumerate(lon_vals)}
local_to_row = np.asarray([lat_to_row[float(v)] for v in _lat_key], dtype=np.int64)
local_to_col = np.asarray([lon_to_col[float(v)] for v in _lon_key], dtype=np.int64)
N_LAT, N_LON = len(lat_vals), len(lon_vals)
LAT_STEP = float(np.median(np.diff(lat_vals))) if N_LAT > 1 else 1.0
LON_STEP = float(np.median(np.diff(lon_vals))) if N_LON > 1 else 1.0
print('spectral full grid:', (N_LAT, N_LON), 'lat/lon step:', LAT_STEP, LON_STEP)


def detrended_residual_grid(hour_idx, stride):
    hour_map, time_key = load_hour_map(hour_idx)
    thin_map, thin_grid, thin_idx = thin_hour_map(hour_map, stride)
    arr = next(iter(thin_map.values())).detach().cpu().numpy()
    y = arr[:, 2].astype(float)
    lat = arr[:, 0].astype(float)
    lon = arr[:, 1].astype(float)
    valid = np.isfinite(y) & np.isfinite(lat) & np.isfinite(lon)
    if valid.sum() < 4:
        raise ValueError(f'Not enough valid points for hour={hour_idx}, stride={stride}')

    X = np.column_stack([
        np.ones(valid.sum()),
        lat[valid] - np.nanmean(lat[valid]),
        lon[valid] - np.nanmean(lon[valid]),
    ])
    beta, *_ = np.linalg.lstsq(X, y[valid], rcond=None)
    X_all = np.column_stack([
        np.ones(len(y)),
        lat - np.nanmean(lat[valid]),
        lon - np.nanmean(lon[valid]),
    ])
    resid = y - X_all @ beta

    grid = np.full((N_LAT, N_LON), np.nan, dtype=float)
    mask = np.zeros((N_LAT, N_LON), dtype=float)
    keep_idx = thin_idx[valid]
    rr = local_to_row[keep_idx]
    cc = local_to_col[keep_idx]
    grid[rr, cc] = resid[valid]
    mask[rr, cc] = 1.0
    return grid, mask, time_key, int(valid.sum())


def masked_periodogram(grid, mask):
    z = np.nan_to_num(grid, nan=0.0).astype(float)
    z = z - (np.sum(z * mask) / max(float(mask.sum()), 1.0))
    win = np.outer(np.hanning(z.shape[0]), np.hanning(z.shape[1])) if APPLY_HANN else np.ones_like(z)
    zw = z * win
    norm = np.sum((mask * win) ** 2)
    norm = norm if norm > EPS else 1.0
    return np.abs(np.fft.fftshift(np.fft.fft2(zw))) ** 2 / norm


def frequency_grid():
    fy = np.fft.fftshift(np.fft.fftfreq(N_LAT, d=LAT_STEP))
    fx = np.fft.fftshift(np.fft.fftfreq(N_LON, d=LON_STEP))
    omega_y = 2.0 * np.pi * fy
    omega_x = 2.0 * np.pi * fx
    OX, OY = np.meshgrid(omega_x, omega_y)
    k = np.sqrt(OX ** 2 + OY ** 2)
    return k, OX ** 2 + OY ** 2

K_RADIAL, OMEGA2 = frequency_grid()
_positive_k = K_RADIAL[np.isfinite(K_RADIAL) & (K_RADIAL > 0)]
K_MAX = float(np.quantile(_positive_k, RADIAL_QMAX))
RADIAL_BINS = np.linspace(0.0, K_MAX, RADIAL_N_BINS + 1)


def matern_spectrum_shape(sigmasq, range_, nugget, smooth):
    nu = float(smooth)
    alpha = 2.0 * nu / max(float(range_) ** 2, EPS)
    matern = float(sigmasq) * (alpha + OMEGA2) ** (-(nu + 1.0))
    return matern + max(float(nugget), 0.0)


def radial_average(surface):
    vals = np.asarray(surface, dtype=float).ravel()
    kk = K_RADIAL.ravel()
    good = np.isfinite(vals) & np.isfinite(kk) & (kk > 0) & (kk <= K_MAX)
    bin_idx = np.digitize(kk[good], RADIAL_BINS) - 1
    rows = []
    vg = vals[good]
    for b in range(RADIAL_N_BINS):
        m = bin_idx == b
        if not np.any(m):
            continue
        rows.append({
            'k_bin': b,
            'k_mid': 0.5 * (RADIAL_BINS[b] + RADIAL_BINS[b + 1]),
            'spectrum': float(np.nanmean(vg[m])),
            'n_freq': int(m.sum()),
        })
    return pd.DataFrame(rows)
# Out:
# spectral full grid: (114, 159) lat/lon step: 0.04400000000000004 0.06300000000000239

# %%
if RUN_SPECTRUM:
    if 'fit_df' not in globals() or fit_df.empty:
        fit_df = pd.read_csv(OUT_DIR / f'{OUT_PREFIX}_full.csv')

    spectral_rows = []
    for r in fit_df.itertuples(index=False):
        grid, mask, time_key, n_valid_spectrum = detrended_residual_grid(int(r.hour_idx), int(r.resolution_stride))
        data_p = masked_periodogram(grid, mask)
        theory_p = matern_spectrum_shape(r.est_sigmasq, r.est_range, r.est_nugget, SPECTRAL_SMOOTH)

        data_rad = radial_average(data_p).rename(columns={'spectrum': 'data_spectrum'})
        theory_rad = radial_average(theory_p).rename(columns={'spectrum': 'theory_spectrum'})
        merged = data_rad.merge(theory_rad[['k_bin', 'theory_spectrum']], on='k_bin', how='inner')

        d = merged['data_spectrum'].to_numpy(dtype=float)
        t = merged['theory_spectrum'].to_numpy(dtype=float)
        good = np.isfinite(d) & np.isfinite(t) & (d > 0) & (t > 0)
        scale = float(np.nanmedian(d[good] / t[good])) if good.any() else 1.0
        merged['theory_spectrum_scaled'] = merged['theory_spectrum'] * scale

        for m in merged.itertuples(index=False):
            spectral_rows.append({
                'date_str': r.date_str,
                'hour_idx': int(r.hour_idx),
                'time_key': time_key,
                'resolution_stride': int(r.resolution_stride),
                'resolution_label': r.resolution_label,
                'variant': r.variant,
                'smooth': float(r.smooth),
                'n_valid_spectrum': n_valid_spectrum,
                'est_sigmasq': float(r.est_sigmasq),
                'est_range': float(r.est_range),
                'est_nugget': float(r.est_nugget),
                'k_bin': int(m.k_bin),
                'k_mid': float(m.k_mid),
                'n_freq': int(m.n_freq),
                'data_spectrum': float(m.data_spectrum),
                'theory_spectrum_raw': float(m.theory_spectrum),
                'theory_spectrum_scaled': float(m.theory_spectrum_scaled),
                'theory_scale_to_data': scale,
            })

    spectral_df = pd.DataFrame(spectral_rows)
    spectral_path = OUT_DIR / f'{OUT_PREFIX}_radial_spectrum.csv'
    spectral_df.to_csv(spectral_path, index=False)
    print('Saved radial spectrum:', spectral_path)
    display(round_df(spectral_df.head(12)))
# Out:
# Saved radial spectrum: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_spectral_s05_nugget_compare_hybrid_050826_radial_spectrum.csv
#     date_str  hour_idx                     time_key  resolution_stride resolution_label      variant  smooth  n_valid_spectrum  est_sigmasq  est_range  est_nugget  k_bin    k_mid  n_freq  \
# 0   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     0.5              2259       8.5355     0.5604       4.482      0   0.5729       2
# 1   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     0.5              2259       8.5355     0.5604       4.482      1   1.7187      18
# 2   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     0.5              2259       8.5355     0.5604       4.482      2   2.8645      26
# 3   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     0.5              2259       8.5355     0.5604       4.482      3   4.0103      42
# 4   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     0.5              2259       8.5355     0.5604       4.482      4   5.1561      42
# 5   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     0.5              2259       8.5355     0.5604       4.482      5   6.3019      60
# 6   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     0.5              2259       8.5355     0.5604       4.482      6   7.4477      66
# 7   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     0.5              2259       8.5355     0.5604       4.482      7   8.5935      86
# 8   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     0.5              2259       8.5355     0.5604       4.482      8   9.7393      86
# 9   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     0.5              2259       8.5355     0.5604       4.482      9  10.8851      98
# 10  20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     0.5              2259       8.5355     0.5604       4.482     10  12.0309     110
# 11  20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     0.5              2259       8.5355     0.5604       4.482     11  13.1767     114
#
#     data_spectrum  theory_spectrum_raw  theory_spectrum_scaled  theory_scale_to_data
# 0          0.5687               5.7431                  8.5073                1.4813
# 1        525.2061               5.0802                  7.5254                1.4813
# 2        122.2696               4.7066                  6.9719                1.4813
# 3         48.2301               4.5799                  6.7843                1.4813
# 4         19.2596               4.5327                  6.7143                1.4813
# 5         14.9271               4.5123                  6.6841                1.4813
# 6         12.0839               4.5009                  6.6672                1.4813
# 7         10.7305               4.4945                  6.6577                1.4813
# 8         10.0378               4.4906                  6.6519                1.4813
# 9          7.5220               4.4883                  6.6485                1.4813
# 10         6.8599               4.4867                  6.6462                1.4813
# 11         5.5823               4.4856                  6.6446                1.4813

# %%
# %%
# Resolution-aware spectrum summaries.
# Data spectrum is retained only below each thinning's effective Nyquist.
# Fitted theoretical spectrum is retained on the full-grid frequency axis.
if 'spectral_df' not in globals():
    spectral_df = pd.read_csv(OUT_DIR / f'{OUT_PREFIX}_radial_spectrum.csv')

plot_spec = spectral_df.copy()
plot_spec['resolution_label'] = pd.Categorical(
    plot_spec['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
)

FULL_K_PLOT_MAX = float(plot_spec['k_mid'].max())
plot_spec['effective_k_max'] = FULL_K_PLOT_MAX / plot_spec['resolution_stride'].astype(float)
plot_spec_low = plot_spec[plot_spec['k_mid'] <= plot_spec['effective_k_max']].copy()

avg_low_data = (
    plot_spec_low
    .groupby(['variant', 'resolution_label', 'resolution_stride', 'k_bin'], observed=False)
    .agg(
        k_mid=('k_mid', 'mean'),
        data_spectrum=('data_spectrum', 'mean'),
        n_hours=('hour_idx', 'nunique'),
        effective_k_max=('effective_k_max', 'mean'),
    )
    .reset_index()
)
low_path = OUT_DIR / f'{OUT_PREFIX}_radial_spectrum_lowfreq_only_avg.csv'
avg_low_data.to_csv(low_path, index=False)
print('Saved low-frequency data spectrum:', low_path)

avg_theory_full = (
    plot_spec
    .groupby(['variant', 'resolution_label', 'k_bin'], observed=False)
    .agg(
        k_mid=('k_mid', 'mean'),
        theory_spectrum_scaled=('theory_spectrum_scaled', 'mean'),
    )
    .reset_index()
)
# Out:
# Saved low-frequency data spectrum: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_spectral_s05_nugget_compare_hybrid_050826_radial_spectrum_lowfreq_only_avg.csv

# %%
# %%
# Spectral diagnostics for partial-profile fits.
if 'profile_df' not in globals() or profile_df.empty:
    profile_df = pd.read_csv(OUT_DIR / f'{OUT_PREFIX}_partial_profile.csv')

if RUN_SPECTRUM and not profile_df.empty:
    profile_spectral_rows = []
    for r in profile_df.itertuples(index=False):
        grid, mask, time_key, n_valid_spectrum = detrended_residual_grid(int(r.hour_idx), int(r.resolution_stride))
        data_p = masked_periodogram(grid, mask)
        theory_p = matern_spectrum_shape(r.est_sigmasq, r.est_range, r.est_nugget, SPECTRAL_SMOOTH)

        data_rad = radial_average(data_p).rename(columns={'spectrum': 'data_spectrum'})
        theory_rad = radial_average(theory_p).rename(columns={'spectrum': 'theory_spectrum'})
        merged = data_rad.merge(theory_rad[['k_bin', 'theory_spectrum']], on='k_bin', how='inner')

        d = merged['data_spectrum'].to_numpy(dtype=float)
        t = merged['theory_spectrum'].to_numpy(dtype=float)
        good = np.isfinite(d) & np.isfinite(t) & (d > 0) & (t > 0)
        scale = float(np.exp(np.mean(np.log(d[good]) - np.log(t[good])))) if good.any() else 1.0
        merged['theory_spectrum_scaled'] = merged['theory_spectrum'] * scale

        for m in merged.itertuples(index=False):
            profile_spectral_rows.append({
                'date_str': str(r.date_str),
                'hour_idx': int(r.hour_idx),
                'time_key': str(r.time_key),
                'resolution_stride': int(r.resolution_stride),
                'resolution_label': str(r.resolution_label),
                'variant': str(r.variant),
                'profile_type': str(r.profile_type),
                'smooth': float(SMOOTH),
                'n_valid_spectrum': int(n_valid_spectrum),
                'est_sigmasq': float(r.est_sigmasq),
                'est_range': float(r.est_range),
                'est_nugget': float(r.est_nugget),
                'k_bin': int(m.k_bin),
                'k_mid': float(m.k_mid),
                'n_freq': int(m.n_freq),
                'data_spectrum': float(m.data_spectrum),
                'theory_spectrum_raw': float(m.theory_spectrum),
                'theory_spectrum_scaled': float(m.theory_spectrum_scaled),
                'theory_scale_to_data': scale,
            })

    profile_spectral_df = pd.DataFrame(profile_spectral_rows)
    profile_spectral_path = OUT_DIR / f'{OUT_PREFIX}_partial_profile_radial_spectrum.csv'
    profile_spectral_df.to_csv(profile_spectral_path, index=False)
    print('Saved partial-profile radial spectrum:', profile_spectral_path)

    plot_prof = profile_spectral_df.copy()
    plot_prof['resolution_label'] = pd.Categorical(
        plot_prof['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
    )
    if 'FULL_K_PLOT_MAX' not in globals():
        FULL_K_PLOT_MAX = float(plot_prof['k_mid'].max())
    plot_prof['effective_k_max'] = FULL_K_PLOT_MAX / plot_prof['resolution_stride'].astype(float)
    plot_prof_low = plot_prof[plot_prof['k_mid'] <= plot_prof['effective_k_max']].copy()

    avg_prof_low = (
        plot_prof_low
        .groupby(['variant', 'profile_type', 'resolution_label', 'resolution_stride', 'k_bin'], observed=False)
        .agg(
            k_mid=('k_mid', 'mean'),
            data_spectrum=('data_spectrum', 'mean'),
            n_hours=('hour_idx', 'nunique'),
            effective_k_max=('effective_k_max', 'mean'),
        )
        .reset_index()
    )
    avg_prof_theory = (
        plot_prof
        .groupby(['variant', 'profile_type', 'resolution_label', 'k_bin'], observed=False)
        .agg(
            k_mid=('k_mid', 'mean'),
            theory_spectrum_scaled=('theory_spectrum_scaled', 'mean'),
        )
        .reset_index()
    )
    avg_prof_low_path = OUT_DIR / f'{OUT_PREFIX}_partial_profile_radial_spectrum_lowfreq_only_avg.csv'
    avg_prof_low.to_csv(avg_prof_low_path, index=False)
    print('Saved partial-profile low-frequency data spectrum:', avg_prof_low_path)

    positive_spectrum_vals = pd.concat(
        [
            pd.to_numeric(avg_low_data['data_spectrum'], errors='coerce'),
            pd.to_numeric(avg_theory_full['theory_spectrum_scaled'], errors='coerce'),
            pd.to_numeric(avg_prof_low['data_spectrum'], errors='coerce'),
            pd.to_numeric(avg_prof_theory['theory_spectrum_scaled'], errors='coerce'),
        ],
        ignore_index=True,
    ).replace([np.inf, -np.inf], np.nan).dropna()
    positive_spectrum_vals = positive_spectrum_vals[positive_spectrum_vals > 0]
    if positive_spectrum_vals.empty:
        SPECTRUM_YLIM = (1e-1, 1e4)
    else:
        SPECTRUM_YLIM = (
            10 ** np.floor(np.log10(float(positive_spectrum_vals.min()))),
            10 ** np.ceil(np.log10(float(positive_spectrum_vals.max()))),
        )
    print('Fixed combined spectrum y-limits:', SPECTRUM_YLIM)

    labels_order = [f'x{s}' for s in RESOLUTION_STRIDES]
    row_specs = [
        ('nugget0', 'full: nugget fixed 0'),
        ('nugget_free', 'full: nugget free'),
        ('profiles', 'nugget0 partial profiles'),
    ]
    fig, axes = plt.subplots(len(row_specs), len(labels_order), figsize=(18, 10.5), constrained_layout=True, sharex=True, sharey=True)
    for i, (row_key, row_title) in enumerate(row_specs):
        for j, label in enumerate(labels_order):
            ax = axes[i, j]
            if row_key == 'profiles':
                sub_data = avg_prof_low[
                    (avg_prof_low['variant'] == 'nugget0')
                    & (avg_prof_low['profile_type'] == 'sigma_only')
                    & (avg_prof_low['resolution_label'].astype(str) == label)
                    & (avg_prof_low['k_mid'] > 0)
                ].copy()
                sub_sigma = avg_prof_theory[
                    (avg_prof_theory['variant'] == 'nugget0')
                    & (avg_prof_theory['profile_type'] == 'sigma_only')
                    & (avg_prof_theory['resolution_label'].astype(str) == label)
                    & (avg_prof_theory['k_mid'] > 0)
                ].copy()
                sub_range = avg_prof_theory[
                    (avg_prof_theory['variant'] == 'nugget0')
                    & (avg_prof_theory['profile_type'] == 'range_only')
                    & (avg_prof_theory['resolution_label'].astype(str) == label)
                    & (avg_prof_theory['k_mid'] > 0)
                ].copy()
                hour_sub = plot_prof_low[
                    (plot_prof_low['variant'] == 'nugget0')
                    & (plot_prof_low['profile_type'] == 'sigma_only')
                    & (plot_prof_low['resolution_label'].astype(str) == label)
                    & (plot_prof_low['k_mid'] > 0)
                ]
                if sub_data.empty or sub_sigma.empty or sub_range.empty:
                    ax.set_visible(False)
                    continue
                k_cut = float(sub_data['effective_k_max'].iloc[0])
                for _, hs in hour_sub.groupby('hour_idx'):
                    ax.plot(hs['k_mid'], hs['data_spectrum'], color='0.7', alpha=0.20, linewidth=0.7)
                ax.plot(sub_data['k_mid'], sub_data['data_spectrum'], color='black', linewidth=2.0, label='data residual spectrum')
                ax.plot(sub_sigma['k_mid'], sub_sigma['theory_spectrum_scaled'], color='tab:blue', linewidth=1.8, linestyle='--', label='sigma-only theory')
                ax.plot(sub_range['k_mid'], sub_range['theory_spectrum_scaled'], color='tab:green', linewidth=1.8, linestyle='--', label='range-only theory')
            else:
                sub_data = avg_low_data[
                    (avg_low_data['variant'] == row_key)
                    & (avg_low_data['resolution_label'].astype(str) == label)
                    & (avg_low_data['k_mid'] > 0)
                ].copy()
                sub_theory = avg_theory_full[
                    (avg_theory_full['variant'] == row_key)
                    & (avg_theory_full['resolution_label'].astype(str) == label)
                    & (avg_theory_full['k_mid'] > 0)
                ].copy()
                hour_sub = plot_spec_low[
                    (plot_spec_low['variant'] == row_key)
                    & (plot_spec_low['resolution_label'].astype(str) == label)
                    & (plot_spec_low['k_mid'] > 0)
                ]
                if sub_data.empty or sub_theory.empty:
                    ax.set_visible(False)
                    continue
                k_cut = float(sub_data['effective_k_max'].iloc[0])
                ax.plot(sub_theory['k_mid'], sub_theory['theory_spectrum_scaled'], color='tab:red', linewidth=1.8, linestyle='--', label='full-fit theory')
                for _, hs in hour_sub.groupby('hour_idx'):
                    ax.plot(hs['k_mid'], hs['data_spectrum'], color='0.7', alpha=0.22, linewidth=0.7)
                ax.plot(sub_data['k_mid'], sub_data['data_spectrum'], color='black', linewidth=2.0, label='data residual spectrum')

            ax.axvline(k_cut, color='0.55', linewidth=1.0, linestyle=':', alpha=0.9)
            ax.set_xlim(0, FULL_K_PLOT_MAX)
            ax.set_ylim(*SPECTRUM_YLIM)
            ax.set_title(f'{row_title}, {label}  (data k <= {k_cut:.1f})')
            ax.set_xlabel('radial frequency on full-grid scale')
            if j == 0:
                ax.set_ylabel('spectrum')
            ax.set_yscale('log')
            ax.grid(True, alpha=0.25)
    axes[0, 0].legend(fontsize=8)
    axes[2, 0].legend(fontsize=8)
    fig.suptitle(f'smooth={SMOOTH}: full-fit and partial-profile spectra', fontsize=14)
    combined_spectrum_plot_path = OUT_DIR / f'{OUT_PREFIX}_data_lowfreq_theory_full_by_variant_resolution.png'
    fig.savefig(combined_spectrum_plot_path, dpi=180, bbox_inches='tight')
    print('Saved combined spectrum plot:', combined_spectrum_plot_path)
    plt.show()
# Out:
# Saved partial-profile radial spectrum: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_spectral_s05_nugget_compare_hybrid_050826_partial_profile_radial_spectrum.csv
# Saved partial-profile low-frequency data spectrum: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_spectral_s05_nugget_compare_hybrid_050826_partial_profile_radial_spectrum_lowfreq_only_avg.csv
# Fixed combined spectrum y-limits: (0.1, 10000.0)
# Saved combined spectrum plot: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_spectral_s05_nugget_compare_hybrid_050826_data_lowfreq_theory_full_by_variant_resolution.png

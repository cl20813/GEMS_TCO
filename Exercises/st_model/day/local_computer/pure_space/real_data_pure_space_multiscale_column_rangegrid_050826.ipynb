# %% [markdown]
# # Pure-space two-scale Column Vecchia diagnostic
#
# This notebook tests a multiscale spatial covariance without making all two-Matern parameters free.
#
# For each hour and resolution, it grid-searches fixed `(range_short, range_long)` pairs and estimates only two variance weights:
#
# ```text
# Cov(h) = sigmasq_short * Matern(h; range_short, smooth_short)
#        + sigmasq_long  * Matern(h; range_long,  smooth_long)
#        + nugget_fixed
# ```
#
# Default diagnostic:
#
# - Column reverse-L pure-space geometry: `Up2_Right3_M10`, real source coordinates for covariance
# - each time slot fitted independently
# - `x8, x4, x2, x1` regular-grid thinning
# - `nugget_fixed = 0`
# - `smooth_short = smooth_long = 0.5`
# - estimate only `sigmasq_short`, `sigmasq_long`
#
# Interpretation target:
#
# - If fine resolution prefers larger `sigmasq_short` or smaller selected `range_short`, that supports multiscale/fine-scale structure.
# - If best range pair and variance split are stable across resolution, single-scale misspecification is less likely.

# %%
import gc
import sys
import time
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch

LOCAL_SRC = '/Users/joonwonlee/Documents/GEMS_TCO-1/src'
AMAREL_SRC = '/home/jl2815/tco'
SRC = AMAREL_SRC if Path(AMAREL_SRC).exists() else LOCAL_SRC
if SRC not in sys.path:
    sys.path.insert(0, SRC)

from GEMS_TCO import configuration as config
from GEMS_TCO.data_loader import load_data_dynamic_processed
from GEMS_TCO.kernels_space_multiscale_050826 import ColumnSpaceTwoScaleFixedRangeTrendVecchiaFit

DEVICE = torch.device('cpu')
DTYPE = torch.float64
ROUND_DECIMALS = 4

pd.set_option('display.max_columns', 160)
pd.set_option('display.width', 220)
print('SRC:', SRC)
print('device:', DEVICE)
# Out:
# SRC: /Users/joonwonlee/Documents/GEMS_TCO-1/src
# device: cpu

# %%
# Experiment config
YEAR = '2024'
MONTH = 7
DAY_IDX = 2                 # 0-based: 2 -> 2024-07-03
HOUR_IDX_LIST = list(range(8))
LAT_RANGE = [-3, 2]
LON_RANGE = [121, 131]

RESOLUTION_STRIDES = [8, 4, 2, 1]
MEAN_DESIGN = 'latlon'

# Start modest; widen after a smoke run if useful.
RANGE_SHORT_GRID = [0.035, 0.060, 0.090, 0.120]
RANGE_LONG_GRID = [0.180, 0.280, 0.400, 0.600]
NUGGET_FIXED = 0.0
SMOOTH_SHORT = 0.5
SMOOTH_LONG = 0.5
MODEL_SMOOTH_FOR_CLASS = 0.5

COLUMN_SPEC = {
    'model': 'ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_realloc',
    'head_right_cols': 0,
    'above_count': 2,
    'right_col_count': 3,
    'per_time_conditioning_count': 10,
    'target_chunk_size': 512,
}

LBFGS_LR = 1.0
LBFGS_STEPS = 6
LBFGS_EVAL = 18
LBFGS_HIST = 10
GRAD_TOL = 1e-5

INIT_SIGMASQ_SHORT = 3.0
INIT_SIGMASQ_LONG = 10.0

PURE_SPACE_DIR = Path('/Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space')
OUT_DIR = PURE_SPACE_DIR / 'log'
OUT_DIR.mkdir(parents=True, exist_ok=True)
OUT_PREFIX = 'real_pure_space_multiscale_column_rangegrid_050826'

range_pairs = [(rs, rl) for rs in RANGE_SHORT_GRID for rl in RANGE_LONG_GRID if rl > rs]
print('day:', f'{YEAR}{MONTH:02d}{DAY_IDX + 1:02d}')
print('hours:', HOUR_IDX_LIST)
print('strides:', RESOLUTION_STRIDES)
print('range pairs:', range_pairs)
print('nugget_fixed:', NUGGET_FIXED, 'smooth_short/long:', SMOOTH_SHORT, SMOOTH_LONG)
# Out:
# day: 20240703
# hours: [0, 1, 2, 3, 4, 5, 6, 7]
# strides: [8, 4, 2, 1]
# range pairs: [(0.035, 0.18), (0.035, 0.28), (0.035, 0.4), (0.035, 0.6), (0.06, 0.18), (0.06, 0.28), (0.06, 0.4), (0.06, 0.6), (0.09, 0.18), (0.09, 0.28), (0.09, 0.4), (0.09, 0.6), (0.12, 0.18), (0.12, 0.28), (0.12, 0.4), (0.12, 0.6)]
# nugget_fixed: 0.0 smooth_short/long: 0.5 0.5

# %%
def make_sigma_params(sig_short=INIT_SIGMASQ_SHORT, sig_long=INIT_SIGMASQ_LONG):
    return [
        torch.tensor([np.log(sig_short)], device=DEVICE, dtype=DTYPE, requires_grad=True),
        torch.tensor([np.log(sig_long)], device=DEVICE, dtype=DTYPE, requires_grad=True),
    ]


def backmap_two(raw, range_short, range_long):
    sig_short = float(np.exp(raw[0]))
    sig_long = float(np.exp(raw[1]))
    total = sig_short + sig_long
    return {
        'sigmasq_short': sig_short,
        'sigmasq_long': sig_long,
        'sigmasq_total': total,
        'short_fraction': sig_short / total if total > 0 else np.nan,
        'range_short': float(range_short),
        'range_long': float(range_long),
        'nugget': float(NUGGET_FIXED),
    }


def count_valid(input_map):
    return int(sum(((~torch.isnan(v[:, 2])) & (~torch.isnan(v[:, 0])) & (~torch.isnan(v[:, 1]))).sum().item() for v in input_map.values()))


def space_diag(model):
    groups = getattr(model, 'Batched_Groups', []) or []
    if not groups:
        return {'n_batches': 0, 'n_tails': 0, 'mean_m': 0.0, 'max_m': 0, 'largest_batch_n': 0}
    ns = np.asarray([int(g['target_idx'].shape[0]) for g in groups], dtype=np.int64)
    ms = np.asarray([int(g['max_m']) for g in groups], dtype=np.int64)
    return {
        'n_batches': int(len(groups)),
        'n_tails': int(ns.sum()),
        'mean_m': float(ms.mean()),
        'max_m': int(ms.max()),
        'largest_batch_n': int(ns.max()),
    }


def round_df(df, digits=ROUND_DECIMALS):
    out = df.copy()
    num_cols = out.select_dtypes(include=[np.number]).columns
    out[num_cols] = out[num_cols].round(digits)
    return out


def empty_cache():
    gc.collect()
    if DEVICE.type == 'cuda':
        torch.cuda.empty_cache()


def resolution_label(stride):
    return f'x{int(stride)}'

# %%
loader = load_data_dynamic_processed(config.mac_data_load_path)
df_map, _, _, monthly_mean = loader.load_maxmin_ordered_data_bymonthyear(
    lat_lon_resolution=[1, 1],
    mm_cond_number=10,
    years_=[YEAR],
    months_=[MONTH],
    lat_range=LAT_RANGE,
    lon_range=LON_RANGE,
    is_whittle=True,
)
month_keys = sorted(df_map.keys())
day_keys = month_keys[DAY_IDX * 8:(DAY_IDX + 1) * 8]
if len(day_keys) != 8:
    raise ValueError(f'Day {DAY_IDX} has {len(day_keys)} slices, expected 8')

first_df = df_map[day_keys[0]].reset_index(drop=True)
grid_order = (
    first_df
    .assign(_orig_idx=np.arange(len(first_df)))
    .sort_values(['Longitude', 'Latitude', '_orig_idx'], kind='mergesort')['_orig_idx']
    .to_numpy(dtype=np.int64)
)
grid_coords_full = first_df.iloc[grid_order][['Latitude', 'Longitude']].to_numpy(dtype=np.float64)

print('monthly_mean:', round(monthly_mean, 4))
print('day keys:', day_keys[0], '...', day_keys[-1])
print('full grid:', grid_coords_full.shape)
print('unique lat/lon:', len(np.unique(np.round(grid_coords_full[:,0], 6))), len(np.unique(np.round(grid_coords_full[:,1], 6))))
# Out:
# --- Global Monthly Mean for 2024-7: 257.9726 ---
# monthly_mean: 257.9726
# day keys: 2024_07_y24m07day03_hm00:53 ... 2024_07_y24m07day03_hm07:48
# full grid: (18126, 2)
# unique lat/lon: 114 159

# %%
def load_hour_map(hour_idx):
    key = day_keys[int(hour_idx)]
    hour_df_map = {key: df_map[key]}
    hour_map, _ = loader.load_working_data(
        hour_df_map,
        monthly_mean=monthly_mean,
        idx_for_datamap=[0, 1],
        ord_mm=grid_order,
        dtype=DTYPE,
        keep_ori=True,
    )
    return {k: v.to(DEVICE) for k, v in hour_map.items()}, key


def thin_hour_map(hour_map, stride):
    n_full = grid_coords_full.shape[0]
    thin_idx = np.arange(0, n_full, int(stride), dtype=np.int64)
    thin_map = {k: v[thin_idx].contiguous() for k, v in hour_map.items()}
    thin_grid = np.ascontiguousarray(grid_coords_full[thin_idx])
    return thin_map, thin_grid, thin_idx


def build_model(input_map, grid_coords, range_short, range_long):
    return ColumnSpaceTwoScaleFixedRangeTrendVecchiaFit(
        smooth=MODEL_SMOOTH_FOR_CLASS,
        input_map=input_map,
        grid_coords=grid_coords,
        head_right_cols=COLUMN_SPEC['head_right_cols'],
        above_count=COLUMN_SPEC['above_count'],
        right_col_count=COLUMN_SPEC['right_col_count'],
        per_time_conditioning_count=COLUMN_SPEC['per_time_conditioning_count'],
        target_chunk_size=COLUMN_SPEC['target_chunk_size'],
        range_short=range_short,
        range_long=range_long,
        nugget_fixed=NUGGET_FIXED,
        smooth_short=SMOOTH_SHORT,
        smooth_long=SMOOTH_LONG,
        mean_design=MEAN_DESIGN,
    )


def make_row(hour_idx, time_key, stride, range_short, range_long, n_grid, n_valid, pre_s, fit_s, loss, fit_iter, est, diag):
    return {
        'date_str': f'{YEAR}{MONTH:02d}{DAY_IDX + 1:02d}',
        'day_idx': DAY_IDX,
        'hour_idx': int(hour_idx),
        'time_key': str(time_key),
        'resolution_stride': int(stride),
        'resolution_label': resolution_label(stride),
        'mean_design': MEAN_DESIGN,
        'model': COLUMN_SPEC['model'],
        'kernel': 'column_space_twoscale_fixedrange_tonly_realloc',
        'coord_mode': 'regular-grid every-k thinning; covariance on Source_Latitude/Source_Longitude',
        'smooth_short': float(SMOOTH_SHORT),
        'smooth_long': float(SMOOTH_LONG),
        'range_short_fixed': float(range_short),
        'range_long_fixed': float(range_long),
        'nugget_fixed': float(NUGGET_FIXED),
        'loss': float(loss),
        'fit_iter_raw': int(fit_iter),
        'fit_steps_reported': int(fit_iter) + 1,
        'precompute_s': float(pre_s),
        'fit_s': float(fit_s),
        'total_s': float(pre_s + fit_s),
        'n_grid': int(n_grid),
        'n_valid': int(n_valid),
        'valid_fraction': float(n_valid / n_grid) if n_grid else np.nan,
        **{f'est_{k}': v for k, v in est.items()},
        **diag,
        'total_conditioning_nominal': COLUMN_SPEC['per_time_conditioning_count'],
        'head_right_cols': COLUMN_SPEC['head_right_cols'],
        'above_count': COLUMN_SPEC['above_count'],
        'right_col_count': COLUMN_SPEC['right_col_count'],
        'per_time_conditioning_count': COLUMN_SPEC['per_time_conditioning_count'],
    }

# %%
def fit_range_pair(hour_idx, stride, range_short, range_long):
    hour_map, time_key = load_hour_map(hour_idx)
    thin_map, thin_grid, _ = thin_hour_map(hour_map, stride)
    n_grid = int(thin_grid.shape[0])
    n_valid = count_valid(thin_map)
    print('\n' + '=' * 100)
    print(
        f'TWO-SCALE | h{hour_idx + 1} | {time_key} | {resolution_label(stride)} | '
        f'rs={range_short:.3f}, rl={range_long:.3f} | n_valid={n_valid:,}'
    )

    model = build_model(thin_map, thin_grid, range_short, range_long)
    t_pre = time.time()
    model.precompute_conditioning_sets()
    pre_s = time.time() - t_pre
    diag = space_diag(model)

    params = make_sigma_params()
    opt = model.set_optimizer(params, lr=LBFGS_LR, max_iter=LBFGS_EVAL, max_eval=LBFGS_EVAL, history_size=LBFGS_HIST)
    t_fit = time.time()
    out, fit_iter = model.fit_vecc_lbfgs(params, opt, max_steps=LBFGS_STEPS, grad_tol=GRAD_TOL)
    fit_s = time.time() - t_fit
    est = backmap_two(out[:2], range_short, range_long)
    row = make_row(hour_idx, time_key, stride, range_short, range_long, n_grid, n_valid, pre_s, fit_s, out[-1], fit_iter, est, diag)
    print('RESULT:', {k: round(v, 4) if isinstance(v, float) else v for k, v in row.items() if k in ['resolution_label','loss','est_sigmasq_short','est_sigmasq_long','est_short_fraction','est_sigmasq_total']})

    del model, params, opt, hour_map, thin_map
    empty_cache()
    return row

# %%
rows = []
for hour_idx in HOUR_IDX_LIST:
    for stride in RESOLUTION_STRIDES:
        for range_short, range_long in range_pairs:
            rows.append(fit_range_pair(hour_idx, stride, range_short, range_long))
            tmp = round_df(pd.DataFrame(rows))
            tmp.to_csv(OUT_DIR / f'{OUT_PREFIX}_all.csv', index=False, float_format=f'%.{ROUND_DECIMALS}f')

all_df = pd.DataFrame(rows)
all_path = OUT_DIR / f'{OUT_PREFIX}_all.csv'
round_df(all_df).to_csv(all_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
print('Saved all grid results:', all_path)
display(round_df(all_df))
# Out:
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.035, rl=0.180 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.621168 / Max Grad: 8.95e-06 ---
# Converged: max_grad 8.95e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 1.7612647055715296, 'sigmasq_long': 10.220929012642317, 'sigmasq_total': 11.982193718213846, 'range_short': 0.035, 'range_long': 0.18, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6212, 'est_sigmasq_short': 1.7613, 'est_sigmasq_long': 10.2209, 'est_sigmasq_total': 11.9822, 'est_short_fraction': 0.147}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.035, rl=0.280 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.605200 / Max Grad: 2.45e-06 ---
# Converged: max_grad 2.45e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.476331169802949, 'sigmasq_long': 8.724876575003524, 'sigmasq_total': 12.201207744806473, 'range_short': 0.035, 'range_long': 0.28, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6052, 'est_sigmasq_short': 3.4763, 'est_sigmasq_long': 8.7249, 'est_sigmasq_total': 12.2012, 'est_short_fraction': 0.2849}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.035, rl=0.400 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.605688 / Max Grad: 1.18e-06 ---
# Converged: max_grad 1.18e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.316486009916361, 'sigmasq_long': 8.264667399765859, 'sigmasq_total': 12.58115340968222, 'range_short': 0.035, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6057, 'est_sigmasq_short': 4.3165, 'est_sigmasq_long': 8.2647, 'est_sigmasq_total': 12.5812, 'est_short_fraction': 0.3431}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.035, rl=0.600 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.619242 / Max Grad: 9.41e-07 ---
# Converged: max_grad 9.41e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.982357695165281, 'sigmasq_long': 8.315109233242827, 'sigmasq_total': 13.29746692840811, 'range_short': 0.035, 'range_long': 0.6, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6192, 'est_sigmasq_short': 4.9824, 'est_sigmasq_long': 8.3151, 'est_sigmasq_total': 13.2975, 'est_short_fraction': 0.3747}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.060, rl=0.180 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.620251 / Max Grad: 6.27e-07 ---
# Converged: max_grad 6.27e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.008703016479937, 'sigmasq_long': 10.155809180426862, 'sigmasq_total': 12.164512196906799, 'range_short': 0.06, 'range_long': 0.18, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6203, 'est_sigmasq_short': 2.0087, 'est_sigmasq_long': 10.1558, 'est_sigmasq_total': 12.1645, 'est_short_fraction': 0.1651}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.060, rl=0.280 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.609555 / Max Grad: 4.76e-07 ---
# Converged: max_grad 4.76e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.177641424254536, 'sigmasq_long': 8.118172823061784, 'sigmasq_total': 12.295814247316319, 'range_short': 0.06, 'range_long': 0.28, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6096, 'est_sigmasq_short': 4.1776, 'est_sigmasq_long': 8.1182, 'est_sigmasq_total': 12.2958, 'est_short_fraction': 0.3398}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.060, rl=0.400 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.615220 / Max Grad: 1.86e-07 ---
# Converged: max_grad 1.86e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 5.137151599751219, 'sigmasq_long': 7.370107698443378, 'sigmasq_total': 12.507259298194597, 'range_short': 0.06, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6152, 'est_sigmasq_short': 5.1372, 'est_sigmasq_long': 7.3701, 'est_sigmasq_total': 12.5073, 'est_short_fraction': 0.4107}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.060, rl=0.600 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.634905 / Max Grad: 4.32e-08 ---
# Converged: max_grad 4.32e-08 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 5.851822412497067, 'sigmasq_long': 7.058759286640085, 'sigmasq_total': 12.910581699137152, 'range_short': 0.06, 'range_long': 0.6, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6349, 'est_sigmasq_short': 5.8518, 'est_sigmasq_long': 7.0588, 'est_sigmasq_total': 12.9106, 'est_short_fraction': 0.4533}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.090, rl=0.180 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.620079 / Max Grad: 3.42e-07 ---
# Converged: max_grad 3.42e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.3880400452810386, 'sigmasq_long': 10.059828743340727, 'sigmasq_total': 12.447868788621765, 'range_short': 0.09, 'range_long': 0.18, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6201, 'est_sigmasq_short': 2.388, 'est_sigmasq_long': 10.0598, 'est_sigmasq_total': 12.4479, 'est_short_fraction': 0.1918}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.090, rl=0.280 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.617898 / Max Grad: 4.42e-06 ---
# Converged: max_grad 4.42e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 5.356809691005389, 'sigmasq_long': 7.215600656212744, 'sigmasq_total': 12.572410347218133, 'range_short': 0.09, 'range_long': 0.28, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6179, 'est_sigmasq_short': 5.3568, 'est_sigmasq_long': 7.2156, 'est_sigmasq_total': 12.5724, 'est_short_fraction': 0.4261}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.090, rl=0.400 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.632836 / Max Grad: 8.01e-06 ---
# Converged: max_grad 8.01e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 6.451576174612872, 'sigmasq_long': 6.236067960637678, 'sigmasq_total': 12.687644135250551, 'range_short': 0.09, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6328, 'est_sigmasq_short': 6.4516, 'est_sigmasq_long': 6.2361, 'est_sigmasq_total': 12.6876, 'est_short_fraction': 0.5085}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.090, rl=0.600 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.664933 / Max Grad: 1.62e-06 ---
# Converged: max_grad 1.62e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 7.194863546379422, 'sigmasq_long': 5.676217028264364, 'sigmasq_total': 12.871080574643786, 'range_short': 0.09, 'range_long': 0.6, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6649, 'est_sigmasq_short': 7.1949, 'est_sigmasq_long': 5.6762, 'est_sigmasq_total': 12.8711, 'est_short_fraction': 0.559}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.120, rl=0.180 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.620501 / Max Grad: 1.84e-06 ---
# Converged: max_grad 1.84e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.9145854121142247, 'sigmasq_long': 9.81180631352382, 'sigmasq_total': 12.726391725638043, 'range_short': 0.12, 'range_long': 0.18, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6205, 'est_sigmasq_short': 2.9146, 'est_sigmasq_long': 9.8118, 'est_sigmasq_total': 12.7264, 'est_short_fraction': 0.229}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.120, rl=0.280 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.627086 / Max Grad: 1.48e-06 ---
# Converged: max_grad 1.48e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 6.886910484405271, 'sigmasq_long': 6.046966427127884, 'sigmasq_total': 12.933876911533154, 'range_short': 0.12, 'range_long': 0.28, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6271, 'est_sigmasq_short': 6.8869, 'est_sigmasq_long': 6.047, 'est_sigmasq_total': 12.9339, 'est_short_fraction': 0.5325}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.120, rl=0.400 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.652353 / Max Grad: 9.18e-06 ---
# Converged: max_grad 9.18e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 8.00640127837663, 'sigmasq_long': 5.0580000679055415, 'sigmasq_total': 13.064401346282171, 'range_short': 0.12, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6524, 'est_sigmasq_short': 8.0064, 'est_sigmasq_long': 5.058, 'est_sigmasq_total': 13.0644, 'est_short_fraction': 0.6128}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x8 | rs=0.120, rl=0.600 | n_valid=2,259
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.0s. grid=57x159, heads=0, tails=2259, m mean/med/max=8.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.699521 / Max Grad: 2.38e-06 ---
# Converged: max_grad 2.38e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 8.705402409814868, 'sigmasq_long': 4.485431472554944, 'sigmasq_total': 13.190833882369812, 'range_short': 0.12, 'range_long': 0.6, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'loss': 1.6995, 'est_sigmasq_short': 8.7054, 'est_sigmasq_long': 4.4854, 'est_sigmasq_total': 13.1908, 'est_short_fraction': 0.66}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.035, rl=0.180 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.512449 / Max Grad: 7.53e-06 ---
# Converged: max_grad 7.53e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 1.5197433401493108, 'sigmasq_long': 9.204290839420871, 'sigmasq_total': 10.724034179570182, 'range_short': 0.035, 'range_long': 0.18, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5124, 'est_sigmasq_short': 1.5197, 'est_sigmasq_long': 9.2043, 'est_sigmasq_total': 10.724, 'est_short_fraction': 0.1417}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.035, rl=0.280 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.490980 / Max Grad: 4.44e-06 ---
# Converged: max_grad 4.44e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.028220278703432, 'sigmasq_long': 8.390114228287777, 'sigmasq_total': 11.418334506991208, 'range_short': 0.035, 'range_long': 0.28, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.491, 'est_sigmasq_short': 3.0282, 'est_sigmasq_long': 8.3901, 'est_sigmasq_total': 11.4183, 'est_short_fraction': 0.2652}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.035, rl=0.400 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.489196 / Max Grad: 4.68e-06 ---
# Converged: max_grad 4.68e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.723569753729068, 'sigmasq_long': 8.62467295748104, 'sigmasq_total': 12.348242711210109, 'range_short': 0.035, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.4892, 'est_sigmasq_short': 3.7236, 'est_sigmasq_long': 8.6247, 'est_sigmasq_total': 12.3482, 'est_short_fraction': 0.3015}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.035, rl=0.600 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.500662 / Max Grad: 5.90e-06 ---
# Converged: max_grad 5.90e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.202660565142866, 'sigmasq_long': 9.828532845009025, 'sigmasq_total': 14.031193410151891, 'range_short': 0.035, 'range_long': 0.6, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5007, 'est_sigmasq_short': 4.2027, 'est_sigmasq_long': 9.8285, 'est_sigmasq_total': 14.0312, 'est_short_fraction': 0.2995}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.060, rl=0.180 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.508958 / Max Grad: 5.12e-06 ---
# Converged: max_grad 5.12e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 1.7143673395544061, 'sigmasq_long': 9.206288891637508, 'sigmasq_total': 10.920656231191913, 'range_short': 0.06, 'range_long': 0.18, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.509, 'est_sigmasq_short': 1.7144, 'est_sigmasq_long': 9.2063, 'est_sigmasq_total': 10.9207, 'est_short_fraction': 0.157}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.060, rl=0.280 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.492272 / Max Grad: 8.33e-06 ---
# Converged: max_grad 8.33e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 3.6792980846864225, 'sigmasq_long': 7.688518971504609, 'sigmasq_total': 11.367817056191033, 'range_short': 0.06, 'range_long': 0.28, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.4923, 'est_sigmasq_short': 3.6793, 'est_sigmasq_long': 7.6885, 'est_sigmasq_total': 11.3678, 'est_short_fraction': 0.3237}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.060, rl=0.400 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.495336 / Max Grad: 1.65e-06 ---
# Converged: max_grad 1.65e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.51453266228566, 'sigmasq_long': 7.408106119052101, 'sigmasq_total': 11.92263878133776, 'range_short': 0.06, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.4953, 'est_sigmasq_short': 4.5145, 'est_sigmasq_long': 7.4081, 'est_sigmasq_total': 11.9226, 'est_short_fraction': 0.3787}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.060, rl=0.600 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.512683 / Max Grad: 1.43e-06 ---
# Converged: max_grad 1.43e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 5.0842653596071, 'sigmasq_long': 7.790711621686454, 'sigmasq_total': 12.874976981293553, 'range_short': 0.06, 'range_long': 0.6, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5127, 'est_sigmasq_short': 5.0843, 'est_sigmasq_long': 7.7907, 'est_sigmasq_total': 12.875, 'est_short_fraction': 0.3949}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.090, rl=0.180 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.505177 / Max Grad: 7.20e-07 ---
# Converged: max_grad 7.20e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.0905416280544524, 'sigmasq_long': 9.121025664161069, 'sigmasq_total': 11.211567292215522, 'range_short': 0.09, 'range_long': 0.18, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5052, 'est_sigmasq_short': 2.0905, 'est_sigmasq_long': 9.121, 'est_sigmasq_total': 11.2116, 'est_short_fraction': 0.1865}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.090, rl=0.280 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.497005 / Max Grad: 9.07e-06 ---
# Converged: max_grad 9.07e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.822587908051659, 'sigmasq_long': 6.71299699961625, 'sigmasq_total': 11.535584907667909, 'range_short': 0.09, 'range_long': 0.28, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.497, 'est_sigmasq_short': 4.8226, 'est_sigmasq_long': 6.713, 'est_sigmasq_total': 11.5356, 'est_short_fraction': 0.4181}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.090, rl=0.400 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.509677 / Max Grad: 6.13e-08 ---
# Converged: max_grad 6.13e-08 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 5.80952551694766, 'sigmasq_long': 6.045220410573296, 'sigmasq_total': 11.854745927520955, 'range_short': 0.09, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5097, 'est_sigmasq_short': 5.8095, 'est_sigmasq_long': 6.0452, 'est_sigmasq_total': 11.8547, 'est_short_fraction': 0.4901}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.090, rl=0.600 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.540364 / Max Grad: 1.78e-07 ---
# Converged: max_grad 1.78e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 6.450535136084484, 'sigmasq_long': 5.857672561070079, 'sigmasq_total': 12.308207697154563, 'range_short': 0.09, 'range_long': 0.6, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5404, 'est_sigmasq_short': 6.4505, 'est_sigmasq_long': 5.8577, 'est_sigmasq_total': 12.3082, 'est_short_fraction': 0.5241}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.120, rl=0.180 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.502844 / Max Grad: 5.23e-07 ---
# Converged: max_grad 5.23e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 2.7315291560371664, 'sigmasq_long': 8.759406962522478, 'sigmasq_total': 11.490936118559645, 'range_short': 0.12, 'range_long': 0.18, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5028, 'est_sigmasq_short': 2.7315, 'est_sigmasq_long': 8.7594, 'est_sigmasq_total': 11.4909, 'est_short_fraction': 0.2377}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.120, rl=0.280 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.503661 / Max Grad: 2.70e-07 ---
# Converged: max_grad 2.70e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 6.377158150271306, 'sigmasq_long': 5.448412046867515, 'sigmasq_total': 11.82557019713882, 'range_short': 0.12, 'range_long': 0.28, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5037, 'est_sigmasq_short': 6.3772, 'est_sigmasq_long': 5.4484, 'est_sigmasq_total': 11.8256, 'est_short_fraction': 0.5393}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.120, rl=0.400 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.527316 / Max Grad: 1.42e-06 ---
# Converged: max_grad 1.42e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 7.392862488545023, 'sigmasq_long': 4.699989773195146, 'sigmasq_total': 12.09285226174017, 'range_short': 0.12, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5273, 'est_sigmasq_short': 7.3929, 'est_sigmasq_long': 4.7, 'est_sigmasq_total': 12.0929, 'est_short_fraction': 0.6113}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x4 | rs=0.120, rl=0.600 | n_valid=4,518
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.1s. grid=57x159, heads=0, tails=4518, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.574544 / Max Grad: 1.43e-06 ---
# Converged: max_grad 1.43e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 8.005870512579378, 'sigmasq_long': 4.395215799569897, 'sigmasq_total': 12.401086312149275, 'range_short': 0.12, 'range_long': 0.6, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'loss': 1.5745, 'est_sigmasq_short': 8.0059, 'est_sigmasq_long': 4.3952, 'est_sigmasq_total': 12.4011, 'est_short_fraction': 0.6456}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.035, rl=0.180 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.543844 / Max Grad: 7.42e-07 ---
# Converged: max_grad 7.42e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.407735959800526, 'sigmasq_long': 7.856142880959721, 'sigmasq_total': 12.263878840760247, 'range_short': 0.035, 'range_long': 0.18, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5438, 'est_sigmasq_short': 4.4077, 'est_sigmasq_long': 7.8561, 'est_sigmasq_total': 12.2639, 'est_short_fraction': 0.3594}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.035, rl=0.280 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.559371 / Max Grad: 4.95e-06 ---
# Converged: max_grad 4.95e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 5.320267363136162, 'sigmasq_long': 7.705660183457449, 'sigmasq_total': 13.02592754659361, 'range_short': 0.035, 'range_long': 0.28, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5594, 'est_sigmasq_short': 5.3203, 'est_sigmasq_long': 7.7057, 'est_sigmasq_total': 13.0259, 'est_short_fraction': 0.4084}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.035, rl=0.400 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.583899 / Max Grad: 6.71e-06 ---
# Converged: max_grad 6.71e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 5.766090114227339, 'sigmasq_long': 8.227641097698253, 'sigmasq_total': 13.993731211925592, 'range_short': 0.035, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5839, 'est_sigmasq_short': 5.7661, 'est_sigmasq_long': 8.2276, 'est_sigmasq_total': 13.9937, 'est_short_fraction': 0.412}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.035, rl=0.600 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.619464 / Max Grad: 1.19e-06 ---
# Converged: max_grad 1.19e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 6.0993233771690845, 'sigmasq_long': 9.52654843454795, 'sigmasq_total': 15.625871811717033, 'range_short': 0.035, 'range_long': 0.6, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.6195, 'est_sigmasq_short': 6.0993, 'est_sigmasq_long': 9.5265, 'est_sigmasq_total': 15.6259, 'est_short_fraction': 0.3903}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.060, rl=0.180 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.560485 / Max Grad: 4.96e-06 ---
# Converged: max_grad 4.96e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 6.061735513788187, 'sigmasq_long': 6.8373586587112065, 'sigmasq_total': 12.899094172499392, 'range_short': 0.06, 'range_long': 0.18, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5605, 'est_sigmasq_short': 6.0617, 'est_sigmasq_long': 6.8374, 'est_sigmasq_total': 12.8991, 'est_short_fraction': 0.4699}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.060, rl=0.280 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.596775 / Max Grad: 3.18e-07 ---
# Converged: max_grad 3.18e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 7.198627457437254, 'sigmasq_long': 6.10431930398011, 'sigmasq_total': 13.302946761417363, 'range_short': 0.06, 'range_long': 0.28, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5968, 'est_sigmasq_short': 7.1986, 'est_sigmasq_long': 6.1043, 'est_sigmasq_total': 13.3029, 'est_short_fraction': 0.5411}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.060, rl=0.400 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.640937 / Max Grad: 3.40e-06 ---
# Converged: max_grad 3.40e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 7.717090588350273, 'sigmasq_long': 5.976000297666373, 'sigmasq_total': 13.693090886016646, 'range_short': 0.06, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.6409, 'est_sigmasq_short': 7.7171, 'est_sigmasq_long': 5.976, 'est_sigmasq_total': 13.6931, 'est_short_fraction': 0.5636}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.060, rl=0.600 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.698971 / Max Grad: 9.65e-06 ---
# Converged: max_grad 9.65e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 8.103448053167163, 'sigmasq_long': 6.0909636668464024, 'sigmasq_total': 14.194411720013566, 'range_short': 0.06, 'range_long': 0.6, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.699, 'est_sigmasq_short': 8.1034, 'est_sigmasq_long': 6.091, 'est_sigmasq_total': 14.1944, 'est_short_fraction': 0.5709}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.090, rl=0.180 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.582013 / Max Grad: 1.51e-06 ---
# Converged: max_grad 1.51e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 8.993682624222028, 'sigmasq_long': 4.928585164241036, 'sigmasq_total': 13.922267788463063, 'range_short': 0.09, 'range_long': 0.18, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.582, 'est_sigmasq_short': 8.9937, 'est_sigmasq_long': 4.9286, 'est_sigmasq_total': 13.9223, 'est_short_fraction': 0.646}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.090, rl=0.280 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.646930 / Max Grad: 5.57e-07 ---
# Converged: max_grad 5.57e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 10.018828423859775, 'sigmasq_long': 4.4427380179162705, 'sigmasq_total': 14.461566441776046, 'range_short': 0.09, 'range_long': 0.28, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.6469, 'est_sigmasq_short': 10.0188, 'est_sigmasq_long': 4.4427, 'est_sigmasq_total': 14.4616, 'est_short_fraction': 0.6928}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.090, rl=0.400 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.721525 / Max Grad: 4.75e-06 ---
# Converged: max_grad 4.75e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 10.462148613010257, 'sigmasq_long': 4.417193737008601, 'sigmasq_total': 14.879342350018858, 'range_short': 0.09, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.7215, 'est_sigmasq_short': 10.4621, 'est_sigmasq_long': 4.4172, 'est_sigmasq_total': 14.8793, 'est_short_fraction': 0.7031}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.090, rl=0.600 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.819028 / Max Grad: 2.67e-06 ---
# Converged: max_grad 2.67e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 10.789832258629485, 'sigmasq_long': 4.5533794719328355, 'sigmasq_total': 15.34321173056232, 'range_short': 0.09, 'range_long': 0.6, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.819, 'est_sigmasq_short': 10.7898, 'est_sigmasq_long': 4.5534, 'est_sigmasq_total': 15.3432, 'est_short_fraction': 0.7032}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.120, rl=0.180 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.600491 / Max Grad: 1.80e-03 ---
# --- Step 2/6 / Loss: 1.556793 / Max Grad: 1.06e-05 ---
# --- Step 3/6 / Loss: 1.556550 / Max Grad: 1.06e-05 ---
# --- Step 4/6 / Loss: 1.556550 / Max Grad: 1.06e-05 ---
# --- Step 5/6 / Loss: 1.556550 / Max Grad: 1.06e-05 ---
# --- Step 6/6 / Loss: 1.556550 / Max Grad: 1.06e-05 ---
# Final Pure-Space Params: {'sigmasq_short': 14.505690452101003, 'sigmasq_long': 0.3031226892075189, 'sigmasq_total': 14.808813141308523, 'range_short': 0.12, 'range_long': 0.18, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5565, 'est_sigmasq_short': 14.5057, 'est_sigmasq_long': 0.3031, 'est_sigmasq_total': 14.8088, 'est_short_fraction': 0.9795}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.120, rl=0.280 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.691839 / Max Grad: 4.33e-04 ---
# --- Step 2/6 / Loss: 1.556098 / Max Grad: 2.17e-08 ---
# Converged: max_grad 2.17e-08 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 13.773875535428873, 'sigmasq_long': 1.831580754006447, 'sigmasq_total': 15.60545628943532, 'range_short': 0.12, 'range_long': 0.28, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5561, 'est_sigmasq_short': 13.7739, 'est_sigmasq_long': 1.8316, 'est_sigmasq_total': 15.6055, 'est_short_fraction': 0.8826}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.120, rl=0.400 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.797006 / Max Grad: 1.63e-06 ---
# Converged: max_grad 1.63e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 13.777597154175675, 'sigmasq_long': 2.4058237115236434, 'sigmasq_total': 16.18342086569932, 'range_short': 0.12, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.797, 'est_sigmasq_short': 13.7776, 'est_sigmasq_long': 2.4058, 'est_sigmasq_total': 16.1834, 'est_short_fraction': 0.8513}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x2 | rs=0.120, rl=0.600 | n_valid=9,033
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.2s. grid=57x159, heads=0, tails=9033, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.937599 / Max Grad: 1.14e-05 ---
# --- Step 2/6 / Loss: 1.554710 / Max Grad: 1.14e-05 ---
# --- Step 3/6 / Loss: 1.554710 / Max Grad: 1.14e-05 ---
# --- Step 4/6 / Loss: 1.554710 / Max Grad: 1.14e-05 ---
# --- Step 5/6 / Loss: 1.554710 / Max Grad: 1.14e-05 ---
# --- Step 6/6 / Loss: 1.554710 / Max Grad: 1.14e-05 ---
# Final Pure-Space Params: {'sigmasq_short': 13.884209280015417, 'sigmasq_long': 2.900144504244834, 'sigmasq_total': 16.78435378426025, 'range_short': 0.12, 'range_long': 0.6, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'loss': 1.5547, 'est_sigmasq_short': 13.8842, 'est_sigmasq_long': 2.9001, 'est_sigmasq_total': 16.7844, 'est_short_fraction': 0.8272}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x1 | rs=0.035, rl=0.180 | n_valid=18,067
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18067, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.418646 / Max Grad: 6.61e-06 ---
# Converged: max_grad 6.61e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.1985459215435865, 'sigmasq_long': 7.168234099007565, 'sigmasq_total': 11.36678002055115, 'range_short': 0.035, 'range_long': 0.18, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4186, 'est_sigmasq_short': 4.1985, 'est_sigmasq_long': 7.1682, 'est_sigmasq_total': 11.3668, 'est_short_fraction': 0.3694}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x1 | rs=0.035, rl=0.280 | n_valid=18,067
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18067, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.429463 / Max Grad: 4.11e-07 ---
# Converged: max_grad 4.11e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 4.890483620665389, 'sigmasq_long': 7.1562026718023235, 'sigmasq_total': 12.046686292467712, 'range_short': 0.035, 'range_long': 0.28, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4295, 'est_sigmasq_short': 4.8905, 'est_sigmasq_long': 7.1562, 'est_sigmasq_total': 12.0467, 'est_short_fraction': 0.406}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x1 | rs=0.035, rl=0.400 | n_valid=18,067
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18067, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.447435 / Max Grad: 8.75e-06 ---
# Converged: max_grad 8.75e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 5.240147259015508, 'sigmasq_long': 7.5647546633552105, 'sigmasq_total': 12.804901922370718, 'range_short': 0.035, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4474, 'est_sigmasq_short': 5.2401, 'est_sigmasq_long': 7.5648, 'est_sigmasq_total': 12.8049, 'est_short_fraction': 0.4092}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x1 | rs=0.035, rl=0.600 | n_valid=18,067
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18067, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.472628 / Max Grad: 8.92e-07 ---
# Converged: max_grad 8.92e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 5.511490412404881, 'sigmasq_long': 8.466580379722041, 'sigmasq_total': 13.978070792126921, 'range_short': 0.035, 'range_long': 0.6, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4726, 'est_sigmasq_short': 5.5115, 'est_sigmasq_long': 8.4666, 'est_sigmasq_total': 13.9781, 'est_short_fraction': 0.3943}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x1 | rs=0.060, rl=0.180 | n_valid=18,067
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18067, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.439767 / Max Grad: 1.78e-06 ---
# Converged: max_grad 1.78e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 6.323914411762152, 'sigmasq_long': 5.921891523845886, 'sigmasq_total': 12.245805935608038, 'range_short': 0.06, 'range_long': 0.18, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4398, 'est_sigmasq_short': 6.3239, 'est_sigmasq_long': 5.9219, 'est_sigmasq_total': 12.2458, 'est_short_fraction': 0.5164}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x1 | rs=0.060, rl=0.280 | n_valid=18,067
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18067, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.478703 / Max Grad: 2.52e-07 ---
# Converged: max_grad 2.52e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 7.173366015187664, 'sigmasq_long': 5.557317091761537, 'sigmasq_total': 12.7306831069492, 'range_short': 0.06, 'range_long': 0.28, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4787, 'est_sigmasq_short': 7.1734, 'est_sigmasq_long': 5.5573, 'est_sigmasq_total': 12.7307, 'est_short_fraction': 0.5635}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x1 | rs=0.060, rl=0.400 | n_valid=18,067
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18067, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.523097 / Max Grad: 1.16e-08 ---
# Converged: max_grad 1.16e-08 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 7.575299373668818, 'sigmasq_long': 5.563974956651984, 'sigmasq_total': 13.139274330320802, 'range_short': 0.06, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.5231, 'est_sigmasq_short': 7.5753, 'est_sigmasq_long': 5.564, 'est_sigmasq_total': 13.1393, 'est_short_fraction': 0.5765}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x1 | rs=0.060, rl=0.600 | n_valid=18,067
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18067, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.578809 / Max Grad: 2.11e-06 ---
# Converged: max_grad 2.11e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 7.8802093483693785, 'sigmasq_long': 5.738096884342382, 'sigmasq_total': 13.61830623271176, 'range_short': 0.06, 'range_long': 0.6, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.5788, 'est_sigmasq_short': 7.8802, 'est_sigmasq_long': 5.7381, 'est_sigmasq_total': 13.6183, 'est_short_fraction': 0.5786}
#
# ====================================================================================================
# TWO-SCALE | h1 | 2024_07_y24m07day03_hm00:53 | x1 | rs=0.090, rl=0.180 | n_valid=18,067
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18067, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.466463 / Max Grad: 3.57e-04 ---
# --- Step 2/6 / Loss: 1.429232 / Max Grad: 3.64e-06 ---
# Converged: max_grad 3.64e-06 < 1.00e-05
# ...
# RESULT: {'resolution_label': 'x1', 'loss': 1.4031, 'est_sigmasq_short': 8.6965, 'est_sigmasq_long': 4.6647, 'est_sigmasq_total': 13.3612, 'est_short_fraction': 0.6509}
#
# ====================================================================================================
# TWO-SCALE | h8 | 2024_07_y24m07day03_hm07:48 | x1 | rs=0.090, rl=0.280 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.490927 / Max Grad: 6.41e-06 ---
# Converged: max_grad 6.41e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 9.697020881631119, 'sigmasq_long': 4.186412440987037, 'sigmasq_total': 13.883433322618156, 'range_short': 0.09, 'range_long': 0.28, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4909, 'est_sigmasq_short': 9.697, 'est_sigmasq_long': 4.1864, 'est_sigmasq_total': 13.8834, 'est_short_fraction': 0.6985}
#
# ====================================================================================================
# TWO-SCALE | h8 | 2024_07_y24m07day03_hm07:48 | x1 | rs=0.090, rl=0.400 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.564037 / Max Grad: 8.72e-06 ---
# Converged: max_grad 8.72e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 10.124368402042876, 'sigmasq_long': 4.149597740149085, 'sigmasq_total': 14.273966142191961, 'range_short': 0.09, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.564, 'est_sigmasq_short': 10.1244, 'est_sigmasq_long': 4.1496, 'est_sigmasq_total': 14.274, 'est_short_fraction': 0.7093}
#
# ====================================================================================================
# TWO-SCALE | h8 | 2024_07_y24m07day03_hm07:48 | x1 | rs=0.090, rl=0.600 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.658832 / Max Grad: 1.63e-05 ---
# --- Step 2/6 / Loss: 1.400777 / Max Grad: 1.63e-05 ---
# --- Step 3/6 / Loss: 1.400777 / Max Grad: 1.63e-05 ---
# --- Step 4/6 / Loss: 1.400777 / Max Grad: 1.63e-05 ---
# --- Step 5/6 / Loss: 1.400777 / Max Grad: 1.63e-05 ---
# --- Step 6/6 / Loss: 1.400777 / Max Grad: 1.63e-05 ---
# Final Pure-Space Params: {'sigmasq_short': 10.440504694159365, 'sigmasq_long': 4.231601911178313, 'sigmasq_total': 14.672106605337678, 'range_short': 0.09, 'range_long': 0.6, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4008, 'est_sigmasq_short': 10.4405, 'est_sigmasq_long': 4.2316, 'est_sigmasq_total': 14.6721, 'est_short_fraction': 0.7116}
#
# ====================================================================================================
# TWO-SCALE | h8 | 2024_07_y24m07day03_hm07:48 | x1 | rs=0.120, rl=0.180 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.445145 / Max Grad: 6.58e-03 ---
# --- Step 2/6 / Loss: 1.405610 / Max Grad: 6.16e-04 ---
# --- Step 3/6 / Loss: 1.404932 / Max Grad: 5.54e-06 ---
# Converged: max_grad 5.54e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 14.317982805531116, 'sigmasq_long': 0.0003063272280162944, 'sigmasq_total': 14.318289132759132, 'range_short': 0.12, 'range_long': 0.18, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4049, 'est_sigmasq_short': 14.318, 'est_sigmasq_long': 0.0003, 'est_sigmasq_total': 14.3183, 'est_short_fraction': 1.0}
#
# ====================================================================================================
# TWO-SCALE | h8 | 2024_07_y24m07day03_hm07:48 | x1 | rs=0.120, rl=0.280 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.536515 / Max Grad: 3.55e-03 ---
# --- Step 2/6 / Loss: 1.405094 / Max Grad: 1.67e-05 ---
# --- Step 3/6 / Loss: 1.404888 / Max Grad: 1.67e-05 ---
# --- Step 4/6 / Loss: 1.404888 / Max Grad: 1.67e-05 ---
# --- Step 5/6 / Loss: 1.404888 / Max Grad: 1.67e-05 ---
# --- Step 6/6 / Loss: 1.404888 / Max Grad: 1.67e-05 ---
# Final Pure-Space Params: {'sigmasq_short': 13.9588619518599, 'sigmasq_long': 0.7466004868226602, 'sigmasq_total': 14.70546243868256, 'range_short': 0.12, 'range_long': 0.28, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4049, 'est_sigmasq_short': 13.9589, 'est_sigmasq_long': 0.7466, 'est_sigmasq_total': 14.7055, 'est_short_fraction': 0.9492}
#
# ====================================================================================================
# TWO-SCALE | h8 | 2024_07_y24m07day03_hm07:48 | x1 | rs=0.120, rl=0.400 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.642143 / Max Grad: 4.91e-05 ---
# --- Step 2/6 / Loss: 1.404744 / Max Grad: 5.39e-06 ---
# Converged: max_grad 5.39e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 13.833387949584614, 'sigmasq_long': 1.3698847628035007, 'sigmasq_total': 15.203272712388115, 'range_short': 0.12, 'range_long': 0.4, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.4047, 'est_sigmasq_short': 13.8334, 'est_sigmasq_long': 1.3699, 'est_sigmasq_total': 15.2033, 'est_short_fraction': 0.9099}
#
# ====================================================================================================
# TWO-SCALE | h8 | 2024_07_y24m07day03_hm07:48 | x1 | rs=0.120, rl=0.600 | n_valid=18,102
# Pre-computing ColumnSpaceVecchia [head_right=0, above=2, right_cols=3, m=10]... Done in 0.8s. grid=114x159, heads=0, tails=18102, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/6 / Loss: 1.782637 / Max Grad: 1.26e-06 ---
# Converged: max_grad 1.26e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq_short': 13.8548257798765, 'sigmasq_long': 1.84740484483789, 'sigmasq_total': 15.702230624714389, 'range_short': 0.12, 'range_long': 0.6, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'loss': 1.7826, 'est_sigmasq_short': 13.8548, 'est_sigmasq_long': 1.8474, 'est_sigmasq_total': 15.7022, 'est_short_fraction': 0.8823}
# Saved all grid results: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_multiscale_column_rangegrid_050826_all.csv
#      date_str  day_idx  hour_idx                     time_key  resolution_stride resolution_label mean_design                                              model                                          kernel  \
# 0    20240703        2         0  2024_07_y24m07day03_hm00:53                  8               x8      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 1    20240703        2         0  2024_07_y24m07day03_hm00:53                  8               x8      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 2    20240703        2         0  2024_07_y24m07day03_hm00:53                  8               x8      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 3    20240703        2         0  2024_07_y24m07day03_hm00:53                  8               x8      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 4    20240703        2         0  2024_07_y24m07day03_hm00:53                  8               x8      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# ..        ...      ...       ...                          ...                ...              ...         ...                                                ...                                             ...
# 507  20240703        2         7  2024_07_y24m07day03_hm07:48                  1               x1      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 508  20240703        2         7  2024_07_y24m07day03_hm07:48                  1               x1      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 509  20240703        2         7  2024_07_y24m07day03_hm07:48                  1               x1      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 510  20240703        2         7  2024_07_y24m07day03_hm07:48                  1               x1      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
# 511  20240703        2         7  2024_07_y24m07day03_hm07:48                  1               x1      latlon  ColumnSpaceTwoScaleFixedRange_Up2_Right3_M10_r...  column_space_twoscale_fixedrange_tonly_realloc
#
#                                             coord_mode  smooth_short  smooth_long  range_short_fixed  range_long_fixed  nugget_fixed    loss  fit_iter_raw  fit_steps_reported  precompute_s   fit_s  total_s  n_grid  \
# 0    regular-grid every-k thinning; covariance on S...           0.5          0.5              0.035              0.18           0.0  1.6212             0                   1        0.0400  0.1253   0.1653    2266
# 1    regular-grid every-k thinning; covariance on S...           0.5          0.5              0.035              0.28           0.0  1.6052             0                   1        0.0398  0.0929   0.1327    2266
# 2    regular-grid every-k thinning; covariance on S...           0.5          0.5              0.035              0.40           0.0  1.6057             0                   1        0.0384  0.1043   0.1427    2266
# 3    regular-grid every-k thinning; covariance on S...           0.5          0.5              0.035              0.60           0.0  1.6192             0                   1        0.0378  0.0931   0.1309    2266
# 4    regular-grid every-k thinning; covariance on S...           0.5          0.5              0.060              0.18           0.0  1.6203             0                   1        0.0392  0.1232   0.1623    2266
# ..                                                 ...           ...          ...                ...               ...           ...     ...           ...                 ...           ...     ...      ...     ...
# 507  regular-grid every-k thinning; covariance on S...           0.5          0.5              0.090              0.60           0.0  1.4008             5                   6        0.8075  1.6040   2.4116   18126
# 508  regular-grid every-k thinning; covariance on S...           0.5          0.5              0.120              0.18           0.0  1.4049             2                   3        0.8088  4.0201   4.8289   18126
# 509  regular-grid every-k thinning; covariance on S...           0.5          0.5              0.120              0.28           0.0  1.4049             5                   6        0.8113  2.6892   3.5005   18126
# 510  regular-grid every-k thinning; covariance on S...           0.5          0.5              0.120              0.40           0.0  1.4047             1                   2        0.8070  1.7908   2.5978   18126
# 511  regular-grid every-k thinning; covariance on S...           0.5          0.5              0.120              0.60           0.0  1.7826             0                   1        0.8050  1.4084   2.2135   18126
#
#      n_valid  valid_fraction  est_sigmasq_short  est_sigmasq_long  est_sigmasq_total  est_short_fraction  est_range_short  est_range_long  est_nugget  n_batches  n_tails  mean_m  max_m  largest_batch_n  \
# 0       2259          0.9969             1.7613           10.2209            11.9822              0.1470            0.035            0.18         0.0          1     2259    10.0     10             2259
# 1       2259          0.9969             3.4763            8.7249            12.2012              0.2849            0.035            0.28         0.0          1     2259    10.0     10             2259
# 2       2259          0.9969             4.3165            8.2647            12.5812              0.3431            0.035            0.40         0.0          1     2259    10.0     10             2259
# 3       2259          0.9969             4.9824            8.3151            13.2975              0.3747            0.035            0.60         0.0          1     2259    10.0     10             2259
# 4       2259          0.9969             2.0087           10.1558            12.1645              0.1651            0.060            0.18         0.0          1     2259    10.0     10             2259
# ..       ...             ...                ...               ...                ...                 ...              ...             ...         ...        ...      ...     ...    ...              ...
# 507    18102          0.9987            10.4405            4.2316            14.6721              0.7116            0.090            0.60         0.0          1    18102    10.0     10            18102
# 508    18102          0.9987            14.3180            0.0003            14.3183              1.0000            0.120            0.18         0.0          1    18102    10.0     10            18102
# 509    18102          0.9987            13.9589            0.7466            14.7055              0.9492            0.120            0.28         0.0          1    18102    10.0     10            18102
# 510    18102          0.9987            13.8334            1.3699            15.2033              0.9099            0.120            0.40         0.0          1    18102    10.0     10            18102
# 511    18102          0.9987            13.8548            1.8474            15.7022              0.8823            0.120            0.60         0.0          1    18102    10.0     10            18102
#
#      total_conditioning_nominal  head_right_cols  above_count  right_col_count  per_time_conditioning_count
# 0                            10                0            2                3                           10
# 1                            10                0            2                3                           10
# 2                            10                0            2                3                           10
# 3                            10                0            2                3                           10
# 4                            10                0            2                3                           10
# ..                          ...              ...          ...              ...                          ...
# 507                          10                0            2                3                           10
# 508                          10                0            2                3                           10
# 509                          10                0            2                3                           10
# 510                          10                0            2                3                           10
# 511                          10                0            2                3                           10
#
# [512 rows x 41 columns]

# %%
# Best range pair by hour and resolution.
if 'all_df' not in globals() or all_df.empty:
    all_df = pd.read_csv(OUT_DIR / f'{OUT_PREFIX}_all.csv')

idx = all_df.groupby(['hour_idx', 'resolution_stride'])['loss'].idxmin()
best_df = all_df.loc[idx].copy().sort_values(['hour_idx', 'resolution_stride'])
best_path = OUT_DIR / f'{OUT_PREFIX}_best_by_hour_resolution.csv'
round_df(best_df).to_csv(best_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
print('Saved best table:', best_path)

display_cols = [
    'hour_idx', 'resolution_stride', 'resolution_label', 'loss',
    'range_short_fixed', 'range_long_fixed',
    'est_sigmasq_short', 'est_sigmasq_long', 'est_sigmasq_total', 'est_short_fraction',
    'n_grid', 'n_valid', 'total_s'
]
display(round_df(best_df[display_cols]))
# Out:
# Saved best table: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_multiscale_column_rangegrid_050826_best_by_hour_resolution.csv
#      hour_idx  resolution_stride resolution_label    loss  range_short_fixed  range_long_fixed  est_sigmasq_short  est_sigmasq_long  est_sigmasq_total  est_short_fraction  n_grid  n_valid  total_s
# 48          0                  1               x1  1.4186              0.035              0.18             4.1985            7.1682            11.3668              0.3694   18126    18067   1.5710
# 32          0                  2               x2  1.5438              0.035              0.18             4.4077            7.8561            12.2639              0.3594    9063     9033   0.6050
# 18          0                  4               x4  1.4892              0.035              0.40             3.7236            8.6247            12.3482              0.3015    4532     4518   0.2455
# 1           0                  8               x8  1.6052              0.035              0.28             3.4763            8.7249            12.2012              0.2849    2266     2259   0.1327
# 113         1                  1               x1  1.3589              0.035              0.28             3.8133            8.8390            12.6524              0.3014   18126    17670   1.4890
# 97          1                  2               x2  1.4102              0.035              0.28             3.0617            9.8549            12.9166              0.2370    9063     8840   0.4561
# 85          1                  4               x4  1.5180              0.060              0.28             2.8267           10.6342            13.4609              0.2100    4532     4422   0.2362
# 65          1                  8               x8  1.6474              0.035              0.28             2.9922           11.1124            14.1047              0.2121    2266     2208   0.1647
# 177         2                  1               x1  1.3599              0.035              0.28             3.0924           12.1866            15.2790              0.2024   18126    16698   1.3392
# 161         2                  2               x2  1.4623              0.035              0.28             2.8854           12.5976            15.4830              0.1864    9063     8353   0.5291
# 145         2                  4               x4  1.6116              0.035              0.28             3.1700           12.1743            15.3443              0.2066    4532     4176   0.2548
# 131         2                  8               x8  1.6981              0.035              0.60             5.3447           12.1906            17.5353              0.3048    2266     2082   0.1592
# 249         3                  1               x1  1.3850              0.090              0.28             7.3663            9.1976            16.5639              0.4447   18126    16863   2.2411
# 228         3                  2               x2  1.4824              0.060              0.18             1.8386           13.2729            15.1115              0.1217    9063     8428   0.8414
# 216         3                  4               x4  1.6449              0.090              0.18             0.1998           15.9803            16.1801              0.0123    4532     4217   0.5051
# 192         3                  8               x8  1.7474              0.035              0.18             0.0726           16.9098            16.9823              0.0043    2266     2114   0.2704
# 318         4                  1               x1  1.4248              0.120              0.40            12.7716            5.9368            18.7083              0.6827   18126    17088   2.8102
# 288         4                  2               x2  1.5372              0.035              0.18             1.7232           14.4051            16.1283              0.1068    9063     8552   0.7071
# 283         4                  4               x4  1.6953              0.090              0.60             9.5453            9.2295            18.7748              0.5084    4532     4288   0.4073
# 256         4                  8               x8  1.8066              0.035              0.18             1.7174           15.6206            17.3380              0.0991    2266     2145   0.1687
# 368         5                  1               x1  1.4224              0.035              0.18             2.6231           12.2914            14.9145              0.1759   18126    17760   1.5271
# 361         5                  2               x2  1.5176              0.090              0.28             7.6712            8.2246            15.8958              0.4826    9063     8881   0.9281
# 347         5                  4               x4  1.6535              0.090              0.60             8.7884            8.6555            17.4439              0.5038    4532     4439   0.4287
# 320         5                  8               x8  1.7712              0.035              0.18             1.7157           14.6543            16.3700              0.1048    2266     2221   0.1720
# 432         6                  1               x1  1.3795              0.035              0.18             2.5396           10.9145            13.4541              0.1888   18126    18104   1.5198
# 416         6                  2               x2  1.4920              0.035              0.18             2.8303           10.1146            12.9448              0.2186    9063     9052   0.4898
# 411         6                  4               x4  1.6200              0.090              0.60             8.5414            7.0120            15.5534              0.5492    4532     4527   0.4433
# 389         6                  8               x8  1.6933              0.060              0.28             4.9687            9.6419            14.6107              0.3401    2266     2264   0.1913
# 496         7                  1               x1  1.3989              0.035              0.18             3.2073            9.5570            12.7643              0.2513   18126    18102   1.4052
# 480         7                  2               x2  1.4768              0.035              0.18             2.7210            9.8554            12.5764              0.2164    9063     9051   0.5242
# 464         7                  4               x4  1.6093              0.035              0.18             2.4704           10.4643            12.9347              0.1910    4532     4526   0.2837
# 454         7                  8               x8  1.7225              0.060              0.40             7.3828            7.5732            14.9560              0.4936    2266     2263   0.1921

# %%
# Plot best variance split and selected ranges across resolution.
plot_df = best_df.copy()
plot_df['resolution_label'] = pd.Categorical(
    plot_df['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
)
plot_df = plot_df.sort_values(['hour_idx', 'resolution_label'])

fig, axes = plt.subplots(2, 2, figsize=(13, 8), constrained_layout=True)
plot_specs = [
    ('est_sigmasq_short', 'estimated short-scale variance'),
    ('est_sigmasq_long', 'estimated long-scale variance'),
    ('est_short_fraction', 'short-scale variance fraction'),
    ('loss', 'best Vecchia loss'),
]
for ax, (col, title) in zip(axes.ravel(), plot_specs):
    for hour_idx, sub in plot_df.groupby('hour_idx'):
        ax.plot(sub['resolution_label'].astype(str), sub[col], marker='o', linewidth=1.5, label=f'h{int(hour_idx)+1}')
    ax.set_title(title)
    ax.set_xlabel('resolution thinning')
    ax.grid(True, alpha=0.3)
axes.ravel()[-1].legend(ncol=2, fontsize=8, title='hour')
fig.suptitle('Two-scale fixed-range Column Vecchia: best grid-search fits', fontsize=14)
plot_path = OUT_DIR / f'{OUT_PREFIX}_best_variance_trajectories.png'
fig.savefig(plot_path, dpi=180, bbox_inches='tight')
print('Saved:', plot_path)
plt.show()

fig, axes = plt.subplots(1, 2, figsize=(12, 4), constrained_layout=True)
for ax, col, title in [
    (axes[0], 'range_short_fixed', 'selected short range'),
    (axes[1], 'range_long_fixed', 'selected long range'),
]:
    for hour_idx, sub in plot_df.groupby('hour_idx'):
        ax.plot(sub['resolution_label'].astype(str), sub[col], marker='o', linewidth=1.5, label=f'h{int(hour_idx)+1}')
    ax.set_title(title)
    ax.set_xlabel('resolution thinning')
    ax.grid(True, alpha=0.3)
axes[-1].legend(ncol=2, fontsize=8, title='hour')
fig.suptitle('Selected fixed range pair by resolution', fontsize=14)
range_plot_path = OUT_DIR / f'{OUT_PREFIX}_best_range_pair_trajectories.png'
fig.savefig(range_plot_path, dpi=180, bbox_inches='tight')
print('Saved:', range_plot_path)
plt.show()
# Out:
# Saved: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_multiscale_column_rangegrid_050826_best_variance_trajectories.png
# Saved: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_multiscale_column_rangegrid_050826_best_range_pair_trajectories.png

# %%
# Optional: loss table for one hour/resolution to inspect the range grid surface.
INSPECT_HOUR_IDX = HOUR_IDX_LIST[2]
INSPECT_STRIDE = 1
surf = all_df[(all_df['hour_idx'] == INSPECT_HOUR_IDX) & (all_df['resolution_stride'] == INSPECT_STRIDE)].copy()
if len(surf):
    loss_pivot = surf.pivot(index='range_short_fixed', columns='range_long_fixed', values='loss')
    shortfrac_pivot = surf.pivot(index='range_short_fixed', columns='range_long_fixed', values='est_short_fraction')
    print(f'Loss surface: hour={INSPECT_HOUR_IDX + 1}, resolution=x{INSPECT_STRIDE}')
    display(round_df(loss_pivot))
    print('Short variance fraction surface')
    display(round_df(shortfrac_pivot))
# Out:
# Loss surface: hour=3, resolution=x1
# range_long_fixed     0.18    0.28    0.40    0.60
# range_short_fixed
# 0.035              1.3613  1.3599  1.3707  1.3907
# 0.060              1.3626  1.3805  1.4099  1.4514
# 0.090              1.3730  1.4171  1.4747  1.5530
# 0.120              1.3642  1.3633  1.5380  1.6561
# Short variance fraction surface
# range_long_fixed     0.18    0.28    0.40    0.60
# range_short_fixed
# 0.035              0.1647  0.2024  0.1996  0.1744
# 0.060              0.2511  0.3418  0.3700  0.3779
# 0.090              0.3632  0.4896  0.5271  0.5443
# 0.120              0.5483  0.6563  0.6760  0.6808

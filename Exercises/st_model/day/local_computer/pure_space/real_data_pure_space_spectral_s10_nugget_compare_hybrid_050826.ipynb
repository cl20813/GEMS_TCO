# %% [markdown]
# # Pure-space spectral diagnostic: smooth=1.0, nugget-free vs nugget=0
#
# This notebook fits each hourly pure-space slice with isotropic Hybrid Vecchia under two variants:
#
# - `nugget_free`: estimate `sigmasq`, `range`, and `nugget`
# - `nugget0`: estimate `sigmasq` and `range`, with nugget fixed at zero
#
# Both use `smooth=1.0`, `mean_design='lat'`, and the same every-k resolution thinning used in the previous pure-space resolution checks.
#
# The spectral diagnostic compares the detrended empirical residual spectrum against a DW-style finite-sample expected periodogram from the fitted Matérn covariance plus nugget. The expected curve uses the same regular 2D thinning, mask, taper, zero-fill FFT normalization, and radial binning as the empirical periodogram; no median rescaling is used in the main diagnostic.

# %%
import gc
import importlib
import sys
import time
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
from scipy.special import gamma, kv

LOCAL_SRC = '/Users/joonwonlee/Documents/GEMS_TCO-1/src'
AMAREL_SRC = '/home/jl2815/tco'
SRC = AMAREL_SRC if Path(AMAREL_SRC).exists() else LOCAL_SRC
if SRC not in sys.path:
    sys.path.insert(0, SRC)

from GEMS_TCO import configuration as config
from GEMS_TCO import orderings
from GEMS_TCO.data_loader import load_data_dynamic_processed
import GEMS_TCO.kernels_space_trend_050726 as kernels_space_trend_050726
import GEMS_TCO.kernels_space_iso_050826 as kernels_space_iso_050826

importlib.reload(kernels_space_trend_050726)
importlib.reload(kernels_space_iso_050826)

from GEMS_TCO.kernels_space_iso_050826 import (
    HybridSpaceIsoTrendVecchiaFit,
    HybridSpaceIsoNoNuggetTrendVecchiaFit,
)

DEVICE = torch.device('cpu')
DTYPE = torch.float64
ROUND_DECIMALS = 4

pd.set_option('display.max_columns', 140)
pd.set_option('display.width', 200)
print('SRC:', SRC)
print('device:', DEVICE)
# Out:
# SRC: /Users/joonwonlee/Documents/GEMS_TCO-1/src
# device: cpu

# %%
# Experiment config
YEAR = '2024'
MONTH = 7
DAY_IDX = 2                 # 0-based: 2 -> 2024-07-03
HOUR_IDX_LIST = list(range(8))
LAT_RANGE = [-3, 2]
LON_RANGE = [121, 131]

SMOOTH = 1.0
RESOLUTION_STRIDES = [8, 4, 2, 1]
MEAN_DESIGN = 'lat'

HYBRID_SPEC = {
    'limit_A': 10,
    'target_chunk_size': 512,
}

VARIANTS = {
    'nugget_free': {
        'class': HybridSpaceIsoTrendVecchiaFit,
        'model': 'HybridSpaceIso_A10_exactloc',
        'kernel': 'hybrid_space_iso_tonly_exactloc',
        'p_labels': ['sigmasq', 'range', 'nugget'],
        'init': {'sigmasq': 13.0, 'range': 0.25, 'nugget': 2.5},
    },
    'nugget0': {
        'class': HybridSpaceIsoNoNuggetTrendVecchiaFit,
        'model': 'HybridSpaceIsoNoNugget_A10_exactloc',
        'kernel': 'hybrid_space_iso_nugget0_tonly_exactloc',
        'p_labels': ['sigmasq', 'range'],
        'init': {'sigmasq': 13.0, 'range': 0.25},
    },
}

LBFGS_LR = 1.0
LBFGS_STEPS_FULL = 8
LBFGS_EVAL = 20
LBFGS_HIST = 10
GRAD_TOL = 1e-5

RUN_FULL = True
RUN_SPECTRUM = True

PURE_SPACE_DIR = Path('/Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space')
OUT_DIR = PURE_SPACE_DIR / 'log'
OUT_DIR.mkdir(parents=True, exist_ok=True)
OUT_PREFIX = 'real_pure_space_spectral_s10_nugget_compare_hybrid_050826'

print('day:', f'{YEAR}{MONTH:02d}{DAY_IDX + 1:02d}')
print('hours:', HOUR_IDX_LIST)
print('strides:', RESOLUTION_STRIDES)
print('smooth:', SMOOTH)
print('variants:', list(VARIANTS))
# Out:
# day: 20240703
# hours: [0, 1, 2, 3, 4, 5, 6, 7]
# strides: [8, 4, 2, 1]
# smooth: 1.0
# variants: ['nugget_free', 'nugget0']

# %%
def phys_to_log(init, p_labels):
    return [np.log(init[p]) for p in p_labels]


def backmap(raw, p_labels, variant):
    est = {p: float(np.exp(raw[i])) for i, p in enumerate(p_labels)}
    if 'nugget' not in est:
        est['nugget'] = 0.0
    return est


def make_full_params(variant):
    spec = VARIANTS[variant]
    return [torch.tensor([v], device=DEVICE, dtype=DTYPE, requires_grad=True) for v in phys_to_log(spec['init'], spec['p_labels'])]


def count_valid(input_map):
    return int(sum(((~torch.isnan(v[:, 2])) & (~torch.isnan(v[:, 0])) & (~torch.isnan(v[:, 1]))).sum().item() for v in input_map.values()))


def space_diag(model):
    groups = getattr(model, 'Batched_Groups', []) or []
    if not groups:
        return {'n_batches': 0, 'n_tails': 0, 'mean_m': 0.0, 'max_m': 0, 'largest_batch_n': 0}
    ns = np.asarray([int(g['target_idx'].shape[0]) for g in groups], dtype=np.int64)
    ms = np.asarray([int(g['max_m']) for g in groups], dtype=np.int64)
    return {
        'n_batches': int(len(groups)),
        'n_tails': int(ns.sum()),
        'mean_m': float(ms.mean()),
        'max_m': int(ms.max()),
        'largest_batch_n': int(ns.max()),
    }


def round_df(df, digits=ROUND_DECIMALS):
    out = df.copy()
    num_cols = out.select_dtypes(include=[np.number]).columns
    out[num_cols] = out[num_cols].round(digits)
    return out


def empty_cache():
    gc.collect()
    if DEVICE.type == 'cuda':
        torch.cuda.empty_cache()


def resolution_label(stride):
    return f'x{int(stride)}'

# %%
loader = load_data_dynamic_processed(config.mac_data_load_path)
df_map, _, _, raw_monthly_mean = loader.load_maxmin_ordered_data_bymonthyear(
    lat_lon_resolution=[1, 1],
    mm_cond_number=10,
    years_=[YEAR],
    months_=[MONTH],
    lat_range=LAT_RANGE,
    lon_range=LON_RANGE,
    is_whittle=True,
)
month_keys = sorted(df_map.keys())
day_keys = month_keys[DAY_IDX * 8:(DAY_IDX + 1) * 8]
if len(day_keys) != 8:
    raise ValueError(f'Day {DAY_IDX} has {len(day_keys)} slices, expected 8')

first_df = df_map[day_keys[0]].reset_index(drop=True)
grid_order = (
    first_df
    .assign(_orig_idx=np.arange(len(first_df)))
    .sort_values(['Longitude', 'Latitude', '_orig_idx'], kind='mergesort')['_orig_idx']
    .to_numpy(dtype=np.int64)
)
grid_coords_full = first_df.iloc[grid_order][['Latitude', 'Longitude']].to_numpy(dtype=np.float64)

# Full-grid topology used by both fitting thins and spectral diagnostics.
_lat_key = np.round(grid_coords_full[:, 0], 10)
_lon_key = np.round(grid_coords_full[:, 1], 10)
lat_vals = np.sort(np.unique(_lat_key))
lon_vals = np.sort(np.unique(_lon_key))
lat_to_row = {float(v): i for i, v in enumerate(lat_vals)}
lon_to_col = {float(v): i for i, v in enumerate(lon_vals)}
local_to_row = np.asarray([lat_to_row[float(v)] for v in _lat_key], dtype=np.int64)
local_to_col = np.asarray([lon_to_col[float(v)] for v in _lon_key], dtype=np.int64)
N_LAT, N_LON = len(lat_vals), len(lon_vals)
LAT_STEP = float(np.median(np.diff(lat_vals))) if N_LAT > 1 else 1.0
LON_STEP = float(np.median(np.diff(lon_vals))) if N_LON > 1 else 1.0

ANALYSIS_MONTHLY_MEAN = 0.0
print('raw monthly_mean:', round(raw_monthly_mean, 4), '(not subtracted; intercept handles the level)')
print('day keys:', day_keys[0], '...', day_keys[-1])
print('full grid:', grid_coords_full.shape)
print('unique lat/lon:', N_LAT, N_LON)
print('lat/lon step:', LAT_STEP, LON_STEP)
# Out:
# --- Global Monthly Mean for 2024-7: 257.9726 ---
# raw monthly_mean: 257.9726 (not subtracted; intercept handles the level)
# day keys: 2024_07_y24m07day03_hm00:53 ... 2024_07_y24m07day03_hm07:48
# full grid: (18126, 2)
# unique lat/lon: 114 159
# lat/lon step: 0.04400000000000004 0.06300000000000239

# %%
def load_hour_map(hour_idx):
    key = day_keys[int(hour_idx)]
    hour_df_map = {key: df_map[key]}
    hour_map, _ = loader.load_working_data(
        hour_df_map,
        monthly_mean=ANALYSIS_MONTHLY_MEAN,
        idx_for_datamap=[0, 1],
        ord_mm=grid_order,
        dtype=DTYPE,
        keep_ori=True,
    )
    return {k: v.to(DEVICE) for k, v in hour_map.items()}, key


def thin_hour_map(hour_map, stride):
    """Thin on the 2D regular grid, not by 1D every-k flattening.

    A stride of 8 means both latitude and longitude grid spacings are multiplied
    by 8. This makes the effective Nyquist interpretation coherent for spectra.
    """
    stride = int(stride)
    if stride <= 0:
        raise ValueError(f'stride must be positive, got {stride}')
    keep = (local_to_row % stride == 0) & (local_to_col % stride == 0)
    thin_idx = np.flatnonzero(keep).astype(np.int64)
    thin_map = {k: v[thin_idx].contiguous() for k, v in hour_map.items()}
    thin_grid = np.ascontiguousarray(grid_coords_full[thin_idx])
    return thin_map, thin_grid, thin_idx


def make_hybrid_ordering(grid_coords):
    coords = np.ascontiguousarray(grid_coords.astype(np.float64))
    hybrid_order = orderings.maxmin_cpp(coords).astype(np.int64)
    ordered_coords = np.ascontiguousarray(coords[hybrid_order])
    nns_map = orderings.find_nns_l2(ordered_coords, max_nn=HYBRID_SPEC['limit_A'])
    return hybrid_order, ordered_coords, nns_map


def build_model(variant, input_map, nns_map):
    spec = VARIANTS[variant]
    return spec['class'](
        smooth=SMOOTH,
        input_map=input_map,
        nns_map=nns_map,
        limit_A=HYBRID_SPEC['limit_A'],
        target_chunk_size=HYBRID_SPEC['target_chunk_size'],
        mean_design=MEAN_DESIGN,
    )


def make_base_row(variant, hour_idx, time_key, stride, n_grid, n_valid, pre_s, fit_s, loss, fit_iter, est, diag):
    spec = VARIANTS[variant]
    row = {
        'date_str': f'{YEAR}{MONTH:02d}{DAY_IDX + 1:02d}',
        'day_idx': DAY_IDX,
        'hour_idx': int(hour_idx),
        'time_key': str(time_key),
        'resolution_stride': int(stride),
        'resolution_label': resolution_label(stride),
        'variant': variant,
        'smooth': float(SMOOTH),
        'mean_design': MEAN_DESIGN,
        'fit_type': 'full',
        'model': spec['model'],
        'kernel': spec['kernel'],
        'coord_mode': '2D grid thinning by stride in both lat/lon, then max-min hybrid ordering; covariance on Source_Latitude/Source_Longitude',
        'loss': float(loss),
        'fit_iter_raw': int(fit_iter),
        'fit_steps_reported': int(fit_iter) + 1,
        'precompute_s': float(pre_s),
        'fit_s': float(fit_s),
        'total_s': float(pre_s + fit_s),
        'n_grid': int(n_grid),
        'n_valid': int(n_valid),
        'valid_fraction': float(n_valid / n_grid) if n_grid else np.nan,
        'est_sigmasq': float(est['sigmasq']),
        'est_range': float(est['range']),
        'est_nugget': float(est.get('nugget', 0.0)),
        **diag,
        'total_conditioning_nominal': HYBRID_SPEC['limit_A'],
        'limit_A': HYBRID_SPEC['limit_A'],
    }
    return row

# %%
def fit_full_variant(variant, hour_idx, stride):
    hour_map, time_key = load_hour_map(hour_idx)
    thin_map_regular, thin_grid_regular, _ = thin_hour_map(hour_map, stride)
    hybrid_order, thin_grid, nns_map = make_hybrid_ordering(thin_grid_regular)
    thin_map = {k: v[hybrid_order].contiguous() for k, v in thin_map_regular.items()}
    n_grid = int(thin_grid.shape[0])
    n_valid = count_valid(thin_map)
    print('\n' + '=' * 100)
    print(f'{variant} | smooth={SMOOTH} | hour={hour_idx + 1} | {time_key} | {resolution_label(stride)} | n_grid={n_grid:,} | n_valid={n_valid:,}')

    model = build_model(variant, thin_map, nns_map)
    t_pre = time.time()
    model.precompute_conditioning_sets()
    pre_s = time.time() - t_pre
    diag = space_diag(model)

    params = make_full_params(variant)
    opt = model.set_optimizer(params, lr=LBFGS_LR, max_iter=LBFGS_EVAL, max_eval=LBFGS_EVAL, history_size=LBFGS_HIST)
    t_fit = time.time()
    out, fit_iter = model.fit_vecc_lbfgs(params, opt, max_steps=LBFGS_STEPS_FULL, grad_tol=GRAD_TOL)
    fit_s = time.time() - t_fit
    p_labels = VARIANTS[variant]['p_labels']
    est = backmap(out[:len(p_labels)], p_labels, variant)
    row = make_base_row(variant, hour_idx, time_key, stride, n_grid, n_valid, pre_s, fit_s, out[-1], fit_iter, est, diag)
    print('RESULT:', {k: round(v, 4) if isinstance(v, float) else v for k, v in row.items() if k in ['variant','resolution_label','loss','est_sigmasq','est_range','est_nugget','total_s']})

    del model, params, opt, hour_map, thin_map
    empty_cache()
    return row

# %%
fit_rows = []
if RUN_FULL:
    for variant in VARIANTS:
        for hour_idx in HOUR_IDX_LIST:
            for stride in RESOLUTION_STRIDES:
                fit_rows.append(fit_full_variant(variant, hour_idx, stride))
                tmp = round_df(pd.DataFrame(fit_rows))
                tmp.to_csv(OUT_DIR / f'{OUT_PREFIX}_full.csv', index=False, float_format=f'%.{ROUND_DECIMALS}f')

fit_df = pd.DataFrame(fit_rows)
full_path = OUT_DIR / f'{OUT_PREFIX}_full.csv'
round_df(fit_df).to_csv(full_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
print('Saved full fits:', full_path)
display(round_df(fit_df))

param_rows = []
for _, row in fit_df.iterrows():
    for p in ['sigmasq', 'range', 'nugget']:
        param_rows.append({
            'date_str': row['date_str'],
            'hour_idx': int(row['hour_idx']),
            'time_key': row['time_key'],
            'resolution_stride': int(row['resolution_stride']),
            'resolution_label': row['resolution_label'],
            'variant': row['variant'],
            'smooth': row['smooth'],
            'parameter': p,
            'estimate': row[f'est_{p}'],
            'loss': row['loss'],
            'n_grid': row['n_grid'],
            'n_valid': row['n_valid'],
        })
param_df = pd.DataFrame(param_rows)
param_path = OUT_DIR / f'{OUT_PREFIX}_param_table.csv'
round_df(param_df).to_csv(param_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
print('Saved param table:', param_path)
# Out:
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=1 | 2024_07_y24m07day03_hm00:53 | x8 | n_grid=300 | n_valid=300
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=300, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.759038 / Max Grad: 3.24e-06 ---
# Converged: max_grad 3.24e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 6.133978292917969, 'range': 1.180362690359259, 'nugget': 8.456146583114561}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.759, 'total_s': 0.0627, 'est_sigmasq': 6.134, 'est_range': 1.1804, 'est_nugget': 8.4561}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=1 | 2024_07_y24m07day03_hm00:53 | x4 | n_grid=1,160 | n_valid=1,160
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1160, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.617819 / Max Grad: 1.14e-05 ---
# --- Step 2/8 / Loss: 1.590121 / Max Grad: 1.14e-05 ---
# --- Step 3/8 / Loss: 1.590121 / Max Grad: 1.14e-05 ---
# --- Step 4/8 / Loss: 1.590121 / Max Grad: 1.14e-05 ---
# --- Step 5/8 / Loss: 1.590121 / Max Grad: 1.14e-05 ---
# --- Step 6/8 / Loss: 1.590121 / Max Grad: 1.14e-05 ---
# --- Step 7/8 / Loss: 1.590121 / Max Grad: 1.14e-05 ---
# --- Step 8/8 / Loss: 1.590121 / Max Grad: 1.14e-05 ---
# Final Pure-Space Params: {'sigmasq': 8.752185650588642, 'range': 0.5366153914254487, 'nugget': 5.512335429971483}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.5901, 'total_s': 0.3827, 'est_sigmasq': 8.7522, 'est_range': 0.5366, 'est_nugget': 5.5123}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=1 | 2024_07_y24m07day03_hm00:53 | x2 | n_grid=4,560 | n_valid=4,531
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4531, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.867049 / Max Grad: 8.01e-06 ---
# Converged: max_grad 8.01e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 10.481949863618212, 'range': 0.7169154223009512, 'nugget': 9.05204532133251}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.867, 'total_s': 0.6589, 'est_sigmasq': 10.4819, 'est_range': 0.7169, 'est_nugget': 9.052}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=1 | 2024_07_y24m07day03_hm00:53 | x1 | n_grid=18,126 | n_valid=18,067
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=18067, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.455865 / Max Grad: 1.61e-06 ---
# Converged: max_grad 1.61e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 9.609032709079017, 'range': 0.19906548584774852, 'nugget': 4.020240470815816}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.4559, 'total_s': 1.5774, 'est_sigmasq': 9.609, 'est_range': 0.1991, 'est_nugget': 4.0202}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=2 | 2024_07_y24m07day03_hm01:53 | x8 | n_grid=300 | n_valid=293
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=293, m mean/med/max=9.6/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.796753 / Max Grad: 4.39e-06 ---
# Converged: max_grad 4.39e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 7.596580120635862, 'range': 1.3866223392736632, 'nugget': 8.97215668438753}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.7968, 'total_s': 0.0344, 'est_sigmasq': 7.5966, 'est_range': 1.3866, 'est_nugget': 8.9722}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=2 | 2024_07_y24m07day03_hm01:53 | x4 | n_grid=1,160 | n_valid=1,134
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1134, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.666413 / Max Grad: 1.98e-06 ---
# Converged: max_grad 1.98e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 9.55715827400941, 'range': 0.7685998252325253, 'nugget': 6.868354872260568}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.6664, 'total_s': 0.3453, 'est_sigmasq': 9.5572, 'est_range': 0.7686, 'est_nugget': 6.8684}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=2 | 2024_07_y24m07day03_hm01:53 | x2 | n_grid=4,560 | n_valid=4,437
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4437, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.540279 / Max Grad: 1.17e-05 ---
# --- Step 2/8 / Loss: 1.511144 / Max Grad: 1.17e-05 ---
# --- Step 3/8 / Loss: 1.511144 / Max Grad: 1.17e-05 ---
# --- Step 4/8 / Loss: 1.511144 / Max Grad: 1.17e-05 ---
# --- Step 5/8 / Loss: 1.511144 / Max Grad: 1.17e-05 ---
# --- Step 6/8 / Loss: 1.511144 / Max Grad: 1.17e-05 ---
# --- Step 7/8 / Loss: 1.511144 / Max Grad: 1.17e-05 ---
# --- Step 8/8 / Loss: 1.511144 / Max Grad: 1.17e-05 ---
# Final Pure-Space Params: {'sigmasq': 10.745528253589676, 'range': 0.3820279330444561, 'nugget': 4.901521586588485}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.5111, 'total_s': 0.7481, 'est_sigmasq': 10.7455, 'est_range': 0.382, 'est_nugget': 4.9015}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=2 | 2024_07_y24m07day03_hm01:53 | x1 | n_grid=18,126 | n_valid=17,670
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=17670, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.375130 / Max Grad: 5.32e-06 ---
# Converged: max_grad 5.32e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 11.511391136116794, 'range': 0.19294243136426026, 'nugget': 3.1725570846614977}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.3751, 'total_s': 1.3604, 'est_sigmasq': 11.5114, 'est_range': 0.1929, 'est_nugget': 3.1726}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=3 | 2024_07_y24m07day03_hm02:53 | x8 | n_grid=300 | n_valid=272
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=272, m mean/med/max=9.2/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.887731 / Max Grad: 1.19e-06 ---
# Converged: max_grad 1.19e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 8.502249105149977, 'range': 0.950373339181908, 'nugget': 10.265603229227969}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.8877, 'total_s': 0.0375, 'est_sigmasq': 8.5022, 'est_range': 0.9504, 'est_nugget': 10.2656}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=3 | 2024_07_y24m07day03_hm02:53 | x4 | n_grid=1,160 | n_valid=1,064
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1064, m mean/med/max=9.3/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.757608 / Max Grad: 1.29e-06 ---
# Converged: max_grad 1.29e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 9.919399285236436, 'range': 0.6760050271602925, 'nugget': 8.189807282560048}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.7576, 'total_s': 0.3443, 'est_sigmasq': 9.9194, 'est_range': 0.676, 'est_nugget': 8.1898}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=3 | 2024_07_y24m07day03_hm02:53 | x2 | n_grid=4,560 | n_valid=4,183
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4183, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.611181 / Max Grad: 2.46e-06 ---
# Converged: max_grad 2.46e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.099158724785523, 'range': 0.3528575904740055, 'nugget': 5.3169978149875865}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.6112, 'total_s': 0.5534, 'est_sigmasq': 12.0992, 'est_range': 0.3529, 'est_nugget': 5.317}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=3 | 2024_07_y24m07day03_hm02:53 | x1 | n_grid=18,126 | n_valid=16,698
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=16698, m mean/med/max=9.6/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.379250 / Max Grad: 2.95e-07 ---
# Converged: max_grad 2.95e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.231450335304148, 'range': 0.175799940672354, 'nugget': 2.7522791175496795}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.3792, 'total_s': 1.3675, 'est_sigmasq': 13.2315, 'est_range': 0.1758, 'est_nugget': 2.7523}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=4 | 2024_07_y24m07day03_hm03:53 | x8 | n_grid=300 | n_valid=279
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=279, m mean/med/max=9.3/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.908105 / Max Grad: 3.55e-05 ---
# --- Step 2/8 / Loss: 1.863805 / Max Grad: 5.14e-06 ---
# Converged: max_grad 5.14e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 9.514304795034844, 'range': 0.958240267876532, 'nugget': 10.473475489935273}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.8638, 'total_s': 0.045, 'est_sigmasq': 9.5143, 'est_range': 0.9582, 'est_nugget': 10.4735}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=4 | 2024_07_y24m07day03_hm03:53 | x4 | n_grid=1,160 | n_valid=1,080
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1080, m mean/med/max=9.4/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.766329 / Max Grad: 5.97e-07 ---
# Converged: max_grad 5.97e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 11.622686804759, 'range': 0.5063907218576968, 'nugget': 7.271430328441412}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.7663, 'total_s': 0.3345, 'est_sigmasq': 11.6227, 'est_range': 0.5064, 'est_nugget': 7.2714}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=4 | 2024_07_y24m07day03_hm03:53 | x2 | n_grid=4,560 | n_valid=4,231
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4231, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.601925 / Max Grad: 1.81e-06 ---
# Converged: max_grad 1.81e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.156958277870595, 'range': 0.33593331536777676, 'nugget': 4.974207345899679}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.6019, 'total_s': 0.5427, 'est_sigmasq': 13.157, 'est_range': 0.3359, 'est_nugget': 4.9742}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=4 | 2024_07_y24m07day03_hm03:53 | x1 | n_grid=18,126 | n_valid=16,863
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=16863, m mean/med/max=9.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.414779 / Max Grad: 4.96e-06 ---
# Converged: max_grad 4.96e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.764222621557353, 'range': 0.1720617061251759, 'nugget': 2.735427240571549}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.4148, 'total_s': 1.3629, 'est_sigmasq': 14.7642, 'est_range': 0.1721, 'est_nugget': 2.7354}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=5 | 2024_07_y24m07day03_hm04:48 | x8 | n_grid=300 | n_valid=284
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=284, m mean/med/max=9.2/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.960835 / Max Grad: 3.02e-04 ---
# --- Step 2/8 / Loss: 1.924000 / Max Grad: 1.27e-06 ---
# Converged: max_grad 1.27e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 7.921902216394235, 'range': 0.9508568446081727, 'nugget': 12.83765437144648}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.924, 'total_s': 0.0494, 'est_sigmasq': 7.9219, 'est_range': 0.9509, 'est_nugget': 12.8377}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=5 | 2024_07_y24m07day03_hm04:48 | x4 | n_grid=1,160 | n_valid=1,093
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1093, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.830515 / Max Grad: 3.57e-06 ---
# Converged: max_grad 3.57e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 10.6831483129806, 'range': 0.5555162576471865, 'nugget': 8.979452493874637}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.8305, 'total_s': 0.3616, 'est_sigmasq': 10.6831, 'est_range': 0.5555, 'est_nugget': 8.9795}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=5 | 2024_07_y24m07day03_hm04:48 | x2 | n_grid=4,560 | n_valid=4,289
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4289, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.714870 / Max Grad: 3.60e-06 ---
# Converged: max_grad 3.60e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.409483184132252, 'range': 0.2827295184426088, 'nugget': 5.580779319032416}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.7149, 'total_s': 0.5264, 'est_sigmasq': 13.4095, 'est_range': 0.2827, 'est_nugget': 5.5808}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=5 | 2024_07_y24m07day03_hm04:48 | x1 | n_grid=18,126 | n_valid=17,088
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=17088, m mean/med/max=9.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.472100 / Max Grad: 2.35e-06 ---
# Converged: max_grad 2.35e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.15701237388679, 'range': 0.15665928592122738, 'nugget': 2.7739908562491826}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.4721, 'total_s': 1.37, 'est_sigmasq': 15.157, 'est_range': 0.1567, 'est_nugget': 2.774}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=6 | 2024_07_y24m07day03_hm05:48 | x8 | n_grid=300 | n_valid=293
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=293, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.879174 / Max Grad: 3.35e-03 ---
# --- Step 2/8 / Loss: 1.871683 / Max Grad: 4.80e-07 ---
# Converged: max_grad 4.80e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 6.224357589730732, 'range': 0.5243364770121048, 'nugget': 10.696053345913215}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.8717, 'total_s': 0.0551, 'est_sigmasq': 6.2244, 'est_range': 0.5243, 'est_nugget': 10.6961}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=6 | 2024_07_y24m07day03_hm05:48 | x4 | n_grid=1,160 | n_valid=1,134
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1134, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.795487 / Max Grad: 3.47e-07 ---
# Converged: max_grad 3.47e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 10.434225158236043, 'range': 0.42251427061913305, 'nugget': 7.6481646289450955}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.7955, 'total_s': 0.3525, 'est_sigmasq': 10.4342, 'est_range': 0.4225, 'est_nugget': 7.6482}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=6 | 2024_07_y24m07day03_hm05:48 | x2 | n_grid=4,560 | n_valid=4,468
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4468, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.661614 / Max Grad: 5.36e-07 ---
# Converged: max_grad 5.36e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.36186836381057, 'range': 0.2564942407836698, 'nugget': 4.956200287691821}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.6616, 'total_s': 0.5575, 'est_sigmasq': 12.3619, 'est_range': 0.2565, 'est_nugget': 4.9562}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=6 | 2024_07_y24m07day03_hm05:48 | x1 | n_grid=18,126 | n_valid=17,760
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=17760, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.474542 / Max Grad: 2.53e-07 ---
# Converged: max_grad 2.53e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.259911293589427, 'range': 0.14383424261843827, 'nugget': 2.824550118274083}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.4745, 'total_s': 1.4177, 'est_sigmasq': 13.2599, 'est_range': 0.1438, 'est_nugget': 2.8246}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=7 | 2024_07_y24m07day03_hm06:48 | x8 | n_grid=300 | n_valid=298
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=298, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.831200 / Max Grad: 2.03e-04 ---
# --- Step 2/8 / Loss: 1.823187 / Max Grad: 1.16e-05 ---
# --- Step 3/8 / Loss: 1.823187 / Max Grad: 1.16e-05 ---
# --- Step 4/8 / Loss: 1.823187 / Max Grad: 1.16e-05 ---
# --- Step 5/8 / Loss: 1.823187 / Max Grad: 1.16e-05 ---
# --- Step 6/8 / Loss: 1.823187 / Max Grad: 1.16e-05 ---
# --- Step 7/8 / Loss: 1.823187 / Max Grad: 1.16e-05 ---
# --- Step 8/8 / Loss: 1.823187 / Max Grad: 1.16e-05 ---
# Final Pure-Space Params: {'sigmasq': 4.457942296819841, 'range': 0.5789690070327396, 'nugget': 10.647859838362637}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.8232, 'total_s': 0.0654, 'est_sigmasq': 4.4579, 'est_range': 0.579, 'est_nugget': 10.6479}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=7 | 2024_07_y24m07day03_hm06:48 | x4 | n_grid=1,160 | n_valid=1,156
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1156, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.810701 / Max Grad: 7.40e-07 ---
# Converged: max_grad 7.40e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 9.292792684735081, 'range': 0.3707544642839697, 'nugget': 7.819116845298447}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.8107, 'total_s': 0.326, 'est_sigmasq': 9.2928, 'est_range': 0.3708, 'est_nugget': 7.8191}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=7 | 2024_07_y24m07day03_hm06:48 | x2 | n_grid=4,560 | n_valid=4,549
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4549, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.656933 / Max Grad: 5.01e-06 ---
# Converged: max_grad 5.01e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 9.678309530893467, 'range': 0.3158337159792131, 'nugget': 5.871889716640704}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.6569, 'total_s': 0.5738, 'est_sigmasq': 9.6783, 'est_range': 0.3158, 'est_nugget': 5.8719}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=7 | 2024_07_y24m07day03_hm06:48 | x1 | n_grid=18,126 | n_valid=18,104
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=18104, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.414934 / Max Grad: 1.73e-07 ---
# Converged: max_grad 1.73e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 11.41147864791637, 'range': 0.134331512924695, 'nugget': 2.537978601274098}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.4149, 'total_s': 1.5879, 'est_sigmasq': 11.4115, 'est_range': 0.1343, 'est_nugget': 2.538}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=8 | 2024_07_y24m07day03_hm07:48 | x8 | n_grid=300 | n_valid=297
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=297, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.761510 / Max Grad: 7.20e-04 ---
# --- Step 2/8 / Loss: 1.744727 / Max Grad: 2.91e-06 ---
# Converged: max_grad 2.91e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 6.807245503965707, 'range': 0.5338213862253618, 'nugget': 7.147833205631692}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget_free', 'loss': 1.7447, 'total_s': 0.0513, 'est_sigmasq': 6.8072, 'est_range': 0.5338, 'est_nugget': 7.1478}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=8 | 2024_07_y24m07day03_hm07:48 | x4 | n_grid=1,160 | n_valid=1,154
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1154, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.636191 / Max Grad: 9.66e-06 ---
# Converged: max_grad 9.66e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 8.231134295427365, 'range': 0.4287719711170394, 'nugget': 5.5579188998164275}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget_free', 'loss': 1.6362, 'total_s': 0.346, 'est_sigmasq': 8.2311, 'est_range': 0.4288, 'est_nugget': 5.5579}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=8 | 2024_07_y24m07day03_hm07:48 | x2 | n_grid=4,560 | n_valid=4,548
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4548, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.541787 / Max Grad: 6.59e-06 ---
# Converged: max_grad 6.59e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 8.88731882298955, 'range': 0.2748858116514915, 'nugget': 4.566902031095952}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget_free', 'loss': 1.5418, 'total_s': 0.5149, 'est_sigmasq': 8.8873, 'est_range': 0.2749, 'est_nugget': 4.5669}
#
# ====================================================================================================
# nugget_free | smooth=1.0 | hour=8 | 2024_07_y24m07day03_hm07:48 | x1 | n_grid=18,126 | n_valid=18,102
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=18102, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.435958 / Max Grad: 5.57e-07 ---
# Converged: max_grad 5.57e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 10.243325413673222, 'range': 0.14117336909963765, 'nugget': 3.0411656342160396}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget_free', 'loss': 1.436, 'total_s': 1.6183, 'est_sigmasq': 10.2433, 'est_range': 0.1412, 'est_nugget': 3.0412}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=1 | 2024_07_y24m07day03_hm00:53 | x8 | n_grid=300 | n_valid=300
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=300, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.747578 / Max Grad: 1.71e-06 ---
# Converged: max_grad 1.71e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.293974384593922, 'range': 0.3052913547044564, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 1.7476, 'total_s': 0.0132, 'est_sigmasq': 14.294, 'est_range': 0.3053, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=1 | 2024_07_y24m07day03_hm00:53 | x4 | n_grid=1,160 | n_valid=1,160
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1160, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.674169 / Max Grad: 5.05e-07 ---
# Converged: max_grad 5.05e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.5981532250624, 'range': 0.19266400049139057, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.6742, 'total_s': 0.2921, 'est_sigmasq': 13.5982, 'est_range': 0.1927, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=1 | 2024_07_y24m07day03_hm00:53 | x2 | n_grid=4,560 | n_valid=4,531
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4531, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 3.354018 / Max Grad: 2.01e-06 ---
# Converged: max_grad 2.01e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 16.961645507126786, 'range': 0.08922847266231397, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 3.354, 'total_s': 0.4618, 'est_sigmasq': 16.9616, 'est_range': 0.0892, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=1 | 2024_07_y24m07day03_hm00:53 | x1 | n_grid=18,126 | n_valid=18,067
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=18067, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 5.107688 / Max Grad: 7.69e-06 ---
# Converged: max_grad 7.69e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.907224959161347, 'range': 0.06254060654447491, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 5.1077, 'total_s': 1.7012, 'est_sigmasq': 12.9072, 'est_range': 0.0625, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=2 | 2024_07_y24m07day03_hm01:53 | x8 | n_grid=300 | n_valid=293
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=293, m mean/med/max=9.6/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.792571 / Max Grad: 7.86e-07 ---
# Converged: max_grad 7.86e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.60615930377575, 'range': 0.3107720762439051, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 1.7926, 'total_s': 0.0147, 'est_sigmasq': 15.6062, 'est_range': 0.3108, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=2 | 2024_07_y24m07day03_hm01:53 | x4 | n_grid=1,160 | n_valid=1,134
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1134, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.742735 / Max Grad: 5.02e-06 ---
# Converged: max_grad 5.02e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.233556314475667, 'range': 0.19656908128225972, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.7427, 'total_s': 0.3056, 'est_sigmasq': 15.2336, 'est_range': 0.1966, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=2 | 2024_07_y24m07day03_hm01:53 | x2 | n_grid=4,560 | n_valid=4,437
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4437, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 2.269757 / Max Grad: 3.84e-06 ---
# Converged: max_grad 3.84e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.038246622855416, 'range': 0.11298318128502315, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 2.2698, 'total_s': 0.4696, 'est_sigmasq': 14.0382, 'est_range': 0.113, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=2 | 2024_07_y24m07day03_hm01:53 | x1 | n_grid=18,126 | n_valid=17,670
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=17670, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 4.317871 / Max Grad: 4.16e-06 ---
# Converged: max_grad 4.16e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.901101498460756, 'range': 0.06998820082288382, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 4.3179, 'total_s': 1.6234, 'est_sigmasq': 12.9011, 'est_range': 0.07, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=3 | 2024_07_y24m07day03_hm02:53 | x8 | n_grid=300 | n_valid=272
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=272, m mean/med/max=9.2/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.910088 / Max Grad: 1.01e-05 ---
# --- Step 2/8 / Loss: 1.884372 / Max Grad: 1.01e-05 ---
# --- Step 3/8 / Loss: 1.884372 / Max Grad: 1.01e-05 ---
# --- Step 4/8 / Loss: 1.884372 / Max Grad: 1.01e-05 ---
# --- Step 5/8 / Loss: 1.884372 / Max Grad: 1.01e-05 ---
# --- Step 6/8 / Loss: 1.884372 / Max Grad: 1.01e-05 ---
# --- Step 7/8 / Loss: 1.884372 / Max Grad: 1.01e-05 ---
# --- Step 8/8 / Loss: 1.884372 / Max Grad: 1.01e-05 ---
# Final Pure-Space Params: {'sigmasq': 18.042159691112687, 'range': 0.27521476641263826, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 1.8844, 'total_s': 0.0273, 'est_sigmasq': 18.0422, 'est_range': 0.2752, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=3 | 2024_07_y24m07day03_hm02:53 | x4 | n_grid=1,160 | n_valid=1,064
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1064, m mean/med/max=9.3/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.880617 / Max Grad: 2.01e-05 ---
# --- Step 2/8 / Loss: 1.768747 / Max Grad: 2.01e-05 ---
# --- Step 3/8 / Loss: 1.768747 / Max Grad: 2.01e-05 ---
# --- Step 4/8 / Loss: 1.768747 / Max Grad: 2.01e-05 ---
# --- Step 5/8 / Loss: 1.768747 / Max Grad: 2.01e-05 ---
# --- Step 6/8 / Loss: 1.768747 / Max Grad: 2.01e-05 ---
# --- Step 7/8 / Loss: 1.768747 / Max Grad: 2.01e-05 ---
# --- Step 8/8 / Loss: 1.768747 / Max Grad: 2.01e-05 ---
# Final Pure-Space Params: {'sigmasq': 17.296850116873102, 'range': 0.18836145190565629, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.7687, 'total_s': 0.3459, 'est_sigmasq': 17.2969, 'est_range': 0.1884, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=3 | 2024_07_y24m07day03_hm02:53 | x2 | n_grid=4,560 | n_valid=4,183
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4183, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 2.385634 / Max Grad: 1.76e-06 ---
# Converged: max_grad 1.76e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.651591756439716, 'range': 0.11597353317667627, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 2.3856, 'total_s': 0.4494, 'est_sigmasq': 15.6516, 'est_range': 0.116, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=3 | 2024_07_y24m07day03_hm02:53 | x1 | n_grid=18,126 | n_valid=16,698
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=16698, m mean/med/max=9.6/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 4.104701 / Max Grad: 2.53e-06 ---
# Converged: max_grad 2.53e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.884261440626362, 'range': 0.07569704319584603, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 4.1047, 'total_s': 1.5489, 'est_sigmasq': 13.8843, 'est_range': 0.0757, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=4 | 2024_07_y24m07day03_hm03:53 | x8 | n_grid=300 | n_valid=279
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=279, m mean/med/max=9.3/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.928437 / Max Grad: 8.86e-07 ---
# Converged: max_grad 8.86e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 19.200448391302448, 'range': 0.30493322427943703, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 1.9284, 'total_s': 0.015, 'est_sigmasq': 19.2004, 'est_range': 0.3049, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=4 | 2024_07_y24m07day03_hm03:53 | x4 | n_grid=1,160 | n_valid=1,080
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1080, m mean/med/max=9.4/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.886697 / Max Grad: 4.12e-06 ---
# Converged: max_grad 4.12e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 18.141230965213854, 'range': 0.19670837960680537, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.8867, 'total_s': 0.307, 'est_sigmasq': 18.1412, 'est_range': 0.1967, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=4 | 2024_07_y24m07day03_hm03:53 | x2 | n_grid=4,560 | n_valid=4,231
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4231, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 2.335789 / Max Grad: 1.98e-05 ---
# --- Step 2/8 / Loss: 1.617175 / Max Grad: 1.98e-05 ---
# --- Step 3/8 / Loss: 1.617175 / Max Grad: 1.98e-05 ---
# --- Step 4/8 / Loss: 1.617175 / Max Grad: 1.98e-05 ---
# --- Step 5/8 / Loss: 1.617175 / Max Grad: 1.98e-05 ---
# --- Step 6/8 / Loss: 1.617175 / Max Grad: 1.98e-05 ---
# --- Step 7/8 / Loss: 1.617175 / Max Grad: 1.98e-05 ---
# --- Step 8/8 / Loss: 1.617175 / Max Grad: 1.98e-05 ---
# Final Pure-Space Params: {'sigmasq': 16.304993168762095, 'range': 0.1223128178425107, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 1.6172, 'total_s': 0.592, 'est_sigmasq': 16.305, 'est_range': 0.1223, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=4 | 2024_07_y24m07day03_hm03:53 | x1 | n_grid=18,126 | n_valid=16,863
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=16863, m mean/med/max=9.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 4.240447 / Max Grad: 9.97e-06 ---
# Converged: max_grad 9.97e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.081227769175289, 'range': 0.07820852046098156, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 4.2404, 'total_s': 1.5298, 'est_sigmasq': 15.0812, 'est_range': 0.0782, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=5 | 2024_07_y24m07day03_hm04:48 | x8 | n_grid=300 | n_valid=284
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=284, m mean/med/max=9.2/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.998958 / Max Grad: 1.01e-07 ---
# Converged: max_grad 1.01e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 20.230849907580843, 'range': 0.26627344440355416, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 1.999, 'total_s': 0.0157, 'est_sigmasq': 20.2308, 'est_range': 0.2663, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=5 | 2024_07_y24m07day03_hm04:48 | x4 | n_grid=1,160 | n_valid=1,093
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1093, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.988546 / Max Grad: 2.23e-05 ---
# --- Step 2/8 / Loss: 1.822579 / Max Grad: 2.23e-05 ---
# --- Step 3/8 / Loss: 1.822579 / Max Grad: 2.23e-05 ---
# --- Step 4/8 / Loss: 1.822579 / Max Grad: 2.23e-05 ---
# --- Step 5/8 / Loss: 1.822579 / Max Grad: 2.23e-05 ---
# --- Step 6/8 / Loss: 1.822579 / Max Grad: 2.23e-05 ---
# --- Step 7/8 / Loss: 1.822579 / Max Grad: 2.23e-05 ---
# --- Step 8/8 / Loss: 1.822579 / Max Grad: 2.23e-05 ---
# Final Pure-Space Params: {'sigmasq': 18.70288356857463, 'range': 0.18081841738732257, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.8226, 'total_s': 0.3572, 'est_sigmasq': 18.7029, 'est_range': 0.1808, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=5 | 2024_07_y24m07day03_hm04:48 | x2 | n_grid=4,560 | n_valid=4,289
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4289, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 2.681462 / Max Grad: 6.79e-06 ---
# Converged: max_grad 6.79e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 17.4783265273062, 'range': 0.11282715196620668, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 2.6815, 'total_s': 0.4945, 'est_sigmasq': 17.4783, 'est_range': 0.1128, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=5 | 2024_07_y24m07day03_hm04:48 | x1 | n_grid=18,126 | n_valid=17,088
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=17088, m mean/med/max=9.7/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 4.531201 / Max Grad: 5.21e-06 ---
# Converged: max_grad 5.21e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.525046235559678, 'range': 0.07612414704676403, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 4.5312, 'total_s': 1.5573, 'est_sigmasq': 15.525, 'est_range': 0.0761, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=6 | 2024_07_y24m07day03_hm05:48 | x8 | n_grid=300 | n_valid=293
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=293, m mean/med/max=9.5/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.902578 / Max Grad: 2.19e-05 ---
# --- Step 2/8 / Loss: 1.879076 / Max Grad: 2.19e-05 ---
# --- Step 3/8 / Loss: 1.879076 / Max Grad: 2.19e-05 ---
# --- Step 4/8 / Loss: 1.879076 / Max Grad: 2.19e-05 ---
# --- Step 5/8 / Loss: 1.879076 / Max Grad: 2.19e-05 ---
# --- Step 6/8 / Loss: 1.879076 / Max Grad: 2.19e-05 ---
# --- Step 7/8 / Loss: 1.879076 / Max Grad: 2.19e-05 ---
# --- Step 8/8 / Loss: 1.879076 / Max Grad: 2.19e-05 ---
# Final Pure-Space Params: {'sigmasq': 16.937697239247207, 'range': 0.23282159658743387, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 1.8791, 'total_s': 0.03, 'est_sigmasq': 16.9377, 'est_range': 0.2328, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=6 | 2024_07_y24m07day03_hm05:48 | x4 | n_grid=1,160 | n_valid=1,134
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1134, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.940763 / Max Grad: 7.34e-06 ---
# Converged: max_grad 7.34e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 17.306574683425165, 'range': 0.17498044823730874, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.9408, 'total_s': 0.2997, 'est_sigmasq': 17.3066, 'est_range': 0.175, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=6 | 2024_07_y24m07day03_hm05:48 | x2 | n_grid=4,560 | n_valid=4,468
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4468, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 2.515576 / Max Grad: 2.85e-06 ---
# Converged: max_grad 2.85e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 15.940950999324913, 'range': 0.11152001595966546, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 2.5156, 'total_s': 0.4744, 'est_sigmasq': 15.941, 'est_range': 0.1115, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=6 | 2024_07_y24m07day03_hm05:48 | x1 | n_grid=18,126 | n_valid=17,760
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=17760, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 4.618529 / Max Grad: 4.67e-06 ---
# Converged: max_grad 4.67e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.369820934223451, 'range': 0.07152886940319354, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 4.6185, 'total_s': 1.709, 'est_sigmasq': 14.3698, 'est_range': 0.0715, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=7 | 2024_07_y24m07day03_hm06:48 | x8 | n_grid=300 | n_valid=298
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=298, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.847426 / Max Grad: 6.52e-06 ---
# Converged: max_grad 6.52e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 14.982117690919639, 'range': 0.20514509367190167, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 1.8474, 'total_s': 0.0176, 'est_sigmasq': 14.9821, 'est_range': 0.2051, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=7 | 2024_07_y24m07day03_hm06:48 | x4 | n_grid=1,160 | n_valid=1,156
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1156, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.983325 / Max Grad: 4.47e-06 ---
# Converged: max_grad 4.47e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 16.427280974228413, 'range': 0.15664489676113877, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.9833, 'total_s': 0.2908, 'est_sigmasq': 16.4273, 'est_range': 0.1566, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=7 | 2024_07_y24m07day03_hm06:48 | x2 | n_grid=4,560 | n_valid=4,549
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4549, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 2.605513 / Max Grad: 2.09e-05 ---
# --- Step 2/8 / Loss: 1.642873 / Max Grad: 2.09e-05 ---
# --- Step 3/8 / Loss: 1.642873 / Max Grad: 2.09e-05 ---
# --- Step 4/8 / Loss: 1.642873 / Max Grad: 2.09e-05 ---
# --- Step 5/8 / Loss: 1.642873 / Max Grad: 2.09e-05 ---
# --- Step 6/8 / Loss: 1.642873 / Max Grad: 2.09e-05 ---
# --- Step 7/8 / Loss: 1.642873 / Max Grad: 2.09e-05 ---
# --- Step 8/8 / Loss: 1.642873 / Max Grad: 2.09e-05 ---
# Final Pure-Space Params: {'sigmasq': 14.131318543006058, 'range': 0.09817793903729548, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 1.6429, 'total_s': 0.675, 'est_sigmasq': 14.1313, 'est_range': 0.0982, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=7 | 2024_07_y24m07day03_hm06:48 | x1 | n_grid=18,126 | n_valid=18,104
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=18104, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 4.241527 / Max Grad: 7.85e-06 ---
# Converged: max_grad 7.85e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.637974637532137, 'range': 0.06950021471024247, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 4.2415, 'total_s': 1.7496, 'est_sigmasq': 12.638, 'est_range': 0.0695, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=8 | 2024_07_y24m07day03_hm07:48 | x8 | n_grid=300 | n_valid=297
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=297, m mean/med/max=9.8/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.753636 / Max Grad: 6.46e-07 ---
# Converged: max_grad 6.46e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.799656023887641, 'range': 0.26784703780229674, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x8', 'variant': 'nugget0', 'loss': 1.7536, 'total_s': 0.0137, 'est_sigmasq': 13.7997, 'est_range': 0.2678, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=8 | 2024_07_y24m07day03_hm07:48 | x4 | n_grid=1,160 | n_valid=1,154
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1154, m mean/med/max=9.9/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 1.699505 / Max Grad: 9.00e-07 ---
# Converged: max_grad 9.00e-07 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 13.118645090069561, 'range': 0.17820002608333807, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x4', 'variant': 'nugget0', 'loss': 1.6995, 'total_s': 0.2921, 'est_sigmasq': 13.1186, 'est_range': 0.1782, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=8 | 2024_07_y24m07day03_hm07:48 | x2 | n_grid=4,560 | n_valid=4,548
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4548, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 2.236803 / Max Grad: 2.22e-05 ---
# --- Step 2/8 / Loss: 1.557089 / Max Grad: 2.22e-05 ---
# --- Step 3/8 / Loss: 1.557089 / Max Grad: 2.22e-05 ---
# --- Step 4/8 / Loss: 1.557089 / Max Grad: 2.22e-05 ---
# --- Step 5/8 / Loss: 1.557089 / Max Grad: 2.22e-05 ---
# --- Step 6/8 / Loss: 1.557089 / Max Grad: 2.22e-05 ---
# --- Step 7/8 / Loss: 1.557089 / Max Grad: 2.22e-05 ---
# --- Step 8/8 / Loss: 1.557089 / Max Grad: 2.22e-05 ---
# Final Pure-Space Params: {'sigmasq': 12.486992804746532, 'range': 0.10389080541188617, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x2', 'variant': 'nugget0', 'loss': 1.5571, 'total_s': 0.668, 'est_sigmasq': 12.487, 'est_range': 0.1039, 'est_nugget': 0.0}
#
# ====================================================================================================
# nugget0 | smooth=1.0 | hour=8 | 2024_07_y24m07day03_hm07:48 | x1 | n_grid=18,126 | n_valid=18,102
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=18102, m mean/med/max=10.0/10/10
# --- Starting Pure-Space Vecchia L-BFGS ---
# --- Step 1/8 / Loss: 4.567437 / Max Grad: 7.40e-06 ---
# Converged: max_grad 7.40e-06 < 1.00e-05
# Final Pure-Space Params: {'sigmasq': 12.132272281463587, 'range': 0.06430166980320116, 'nugget': 0.0}
# RESULT: {'resolution_label': 'x1', 'variant': 'nugget0', 'loss': 4.5674, 'total_s': 1.6032, 'est_sigmasq': 12.1323, 'est_range': 0.0643, 'est_nugget': 0.0}
# Saved full fits: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_spectral_s10_nugget_compare_hybrid_050826_full.csv
#     date_str  day_idx  hour_idx                     time_key  resolution_stride resolution_label      variant  smooth mean_design fit_type                                model  \
# 0   20240703        2         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     1.0         lat     full          HybridSpaceIso_A10_exactloc
# 1   20240703        2         0  2024_07_y24m07day03_hm00:53                  4               x4  nugget_free     1.0         lat     full          HybridSpaceIso_A10_exactloc
# 2   20240703        2         0  2024_07_y24m07day03_hm00:53                  2               x2  nugget_free     1.0         lat     full          HybridSpaceIso_A10_exactloc
# 3   20240703        2         0  2024_07_y24m07day03_hm00:53                  1               x1  nugget_free     1.0         lat     full          HybridSpaceIso_A10_exactloc
# 4   20240703        2         1  2024_07_y24m07day03_hm01:53                  8               x8  nugget_free     1.0         lat     full          HybridSpaceIso_A10_exactloc
# ..       ...      ...       ...                          ...                ...              ...          ...     ...         ...      ...                                  ...
# 59  20240703        2         6  2024_07_y24m07day03_hm06:48                  1               x1      nugget0     1.0         lat     full  HybridSpaceIsoNoNugget_A10_exactloc
# 60  20240703        2         7  2024_07_y24m07day03_hm07:48                  8               x8      nugget0     1.0         lat     full  HybridSpaceIsoNoNugget_A10_exactloc
# 61  20240703        2         7  2024_07_y24m07day03_hm07:48                  4               x4      nugget0     1.0         lat     full  HybridSpaceIsoNoNugget_A10_exactloc
# 62  20240703        2         7  2024_07_y24m07day03_hm07:48                  2               x2      nugget0     1.0         lat     full  HybridSpaceIsoNoNugget_A10_exactloc
# 63  20240703        2         7  2024_07_y24m07day03_hm07:48                  1               x1      nugget0     1.0         lat     full  HybridSpaceIsoNoNugget_A10_exactloc
#
#                                      kernel                                         coord_mode    loss  fit_iter_raw  fit_steps_reported  precompute_s   fit_s  total_s  n_grid  n_valid  \
# 0           hybrid_space_iso_tonly_exactloc  2D grid thinning by stride in both lat/lon, th...  1.7590             0                   1        0.0019  0.0608   0.0627     300      300
# 1           hybrid_space_iso_tonly_exactloc  2D grid thinning by stride in both lat/lon, th...  1.5901             7                   8        0.0094  0.3733   0.3827    1160     1160
# 2           hybrid_space_iso_tonly_exactloc  2D grid thinning by stride in both lat/lon, th...  1.8670             0                   1        0.0262  0.6326   0.6589    4560     4531
# 3           hybrid_space_iso_tonly_exactloc  2D grid thinning by stride in both lat/lon, th...  1.4559             0                   1        0.0840  1.4935   1.5774   18126    18067
# 4           hybrid_space_iso_tonly_exactloc  2D grid thinning by stride in both lat/lon, th...  1.7968             0                   1        0.0011  0.0334   0.0344     300      293
# ..                                      ...                                                ...     ...           ...                 ...           ...     ...      ...     ...      ...
# 59  hybrid_space_iso_nugget0_tonly_exactloc  2D grid thinning by stride in both lat/lon, th...  4.2415             0                   1        0.1074  1.6422   1.7496   18126    18104
# 60  hybrid_space_iso_nugget0_tonly_exactloc  2D grid thinning by stride in both lat/lon, th...  1.7536             0                   1        0.0011  0.0127   0.0137     300      297
# 61  hybrid_space_iso_nugget0_tonly_exactloc  2D grid thinning by stride in both lat/lon, th...  1.6995             0                   1        0.0068  0.2853   0.2921    1160     1154
# 62  hybrid_space_iso_nugget0_tonly_exactloc  2D grid thinning by stride in both lat/lon, th...  1.5571             7                   8        0.0260  0.6419   0.6680    4560     4548
# 63  hybrid_space_iso_nugget0_tonly_exactloc  2D grid thinning by stride in both lat/lon, th...  4.5674             0                   1        0.0950  1.5081   1.6032   18126    18102
#
#     valid_fraction  est_sigmasq  est_range  est_nugget  n_batches  n_tails  mean_m  max_m  largest_batch_n  total_conditioning_nominal  limit_A
# 0           1.0000       6.1340     1.1804      8.4561          1      300    10.0     10              300                          10       10
# 1           1.0000       8.7522     0.5366      5.5123          1     1160    10.0     10             1160                          10       10
# 2           0.9936      10.4819     0.7169      9.0520          1     4531    10.0     10             4531                          10       10
# 3           0.9967       9.6090     0.1991      4.0202          1    18067    10.0     10            18067                          10       10
# 4           0.9767       7.5966     1.3866      8.9722          1      293    10.0     10              293                          10       10
# ..             ...          ...        ...         ...        ...      ...     ...    ...              ...                         ...      ...
# 59          0.9988      12.6380     0.0695      0.0000          1    18104    10.0     10            18104                          10       10
# 60          0.9900      13.7997     0.2678      0.0000          1      297    10.0     10              297                          10       10
# 61          0.9948      13.1186     0.1782      0.0000          1     1154    10.0     10             1154                          10       10
# 62          0.9974      12.4870     0.1039      0.0000          1     4548    10.0     10             4548                          10       10
# 63          0.9987      12.1323     0.0643      0.0000          1    18102    10.0     10            18102                          10       10
#
# [64 rows x 32 columns]
# Saved param table: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_spectral_s10_nugget_compare_hybrid_050826_param_table.csv

# %%
# Full-fit results table.
plot_df = fit_df.copy()
plot_df['resolution_label'] = pd.Categorical(
    plot_df['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
)
plot_df = plot_df.sort_values(['variant', 'hour_idx', 'resolution_label'])

display(round_df(plot_df[['variant','hour_idx','resolution_stride','resolution_label','loss','est_sigmasq','est_range','est_nugget','n_grid','n_valid','total_s']]))
# Out:
#         variant  hour_idx  resolution_stride resolution_label    loss  est_sigmasq  est_range  est_nugget  n_grid  n_valid  total_s
# 32      nugget0         0                  8               x8  1.7476      14.2940     0.3053      0.0000     300      300   0.0132
# 33      nugget0         0                  4               x4  1.6742      13.5982     0.1927      0.0000    1160     1160   0.2921
# 34      nugget0         0                  2               x2  3.3540      16.9616     0.0892      0.0000    4560     4531   0.4618
# 35      nugget0         0                  1               x1  5.1077      12.9072     0.0625      0.0000   18126    18067   1.7012
# 36      nugget0         1                  8               x8  1.7926      15.6062     0.3108      0.0000     300      293   0.0147
# ..          ...       ...                ...              ...     ...          ...        ...         ...     ...      ...      ...
# 27  nugget_free         6                  1               x1  1.4149      11.4115     0.1343      2.5380   18126    18104   1.5879
# 28  nugget_free         7                  8               x8  1.7447       6.8072     0.5338      7.1478     300      297   0.0513
# 29  nugget_free         7                  4               x4  1.6362       8.2311     0.4288      5.5579    1160     1154   0.3460
# 30  nugget_free         7                  2               x2  1.5418       8.8873     0.2749      4.5669    4560     4548   0.5149
# 31  nugget_free         7                  1               x1  1.4360      10.2433     0.1412      3.0412   18126    18102   1.6183
#
# [64 rows x 11 columns]

# %%
# %%
# Partial-profile fits anchored at the full-fit estimates.
# sigma_only: estimate sigmasq only; keep range and nugget fixed at the full-fit estimates.
# range_only: estimate range only; keep sigmasq and nugget fixed at the full-fit estimates.
RUN_PROFILE_FITS = True
PROFILE_TYPES = ['sigma_only', 'range_only']
PROFILE_LBFGS_STEPS = 8
PROFILE_GRAD_TOL = 1e-5
PROFILE_EPS = 1e-10


def safe_log_value(x, eps=PROFILE_EPS):
    return float(np.log(max(float(x), eps)))


def log_tensor_value(x, like, eps=PROFILE_EPS):
    return torch.as_tensor(np.log(max(float(x), eps)), device=like.device, dtype=like.dtype)


def profile_param_tensor(variant, profile_type, theta, anchor):
    if variant == 'nugget_free':
        vals = {
            'sigmasq': log_tensor_value(anchor['sigmasq'], theta),
            'range': log_tensor_value(anchor['range'], theta),
            'nugget': log_tensor_value(anchor['nugget'], theta),
        }
        vals['sigmasq' if profile_type == 'sigma_only' else 'range'] = theta.reshape(())
        return torch.stack([vals['sigmasq'], vals['range'], vals['nugget']])
    if variant == 'nugget0':
        vals = {
            'sigmasq': log_tensor_value(anchor['sigmasq'], theta),
            'range': log_tensor_value(anchor['range'], theta),
        }
        vals['sigmasq' if profile_type == 'sigma_only' else 'range'] = theta.reshape(())
        return torch.stack([vals['sigmasq'], vals['range']])
    raise ValueError(f'Unknown variant: {variant}')


def profile_estimate_from_theta(profile_type, theta, anchor):
    est = dict(anchor)
    est['sigmasq' if profile_type == 'sigma_only' else 'range'] = float(torch.exp(theta.detach()).cpu().item())
    return est


def optimize_profile(model, variant, profile_type, anchor):
    free_name = 'sigmasq' if profile_type == 'sigma_only' else 'range'
    theta = torch.tensor([safe_log_value(anchor[free_name])], device=DEVICE, dtype=DTYPE, requires_grad=True)
    optimizer = torch.optim.LBFGS(
        [theta],
        lr=LBFGS_LR,
        max_iter=LBFGS_EVAL,
        max_eval=LBFGS_EVAL,
        history_size=LBFGS_HIST,
        line_search_fn='strong_wolfe',
    )

    last_loss = None
    last_iter = 0
    for i in range(PROFILE_LBFGS_STEPS):
        last_iter = i

        def closure():
            optimizer.zero_grad()
            params = profile_param_tensor(variant, profile_type, theta, anchor)
            loss = model.vecchia_batched_likelihood(params)
            loss.backward()
            return loss

        last_loss = optimizer.step(closure)
        with torch.no_grad():
            max_grad = abs(float(theta.grad.detach().item())) if theta.grad is not None else 0.0
            print(f'    {profile_type} step {i + 1}/{PROFILE_LBFGS_STEPS}: loss={float(last_loss.detach().item()):.6f}, grad={max_grad:.2e}')
            if max_grad < PROFILE_GRAD_TOL:
                break

    est = profile_estimate_from_theta(profile_type, theta, anchor)
    loss = float(last_loss.detach().cpu().item()) if isinstance(last_loss, torch.Tensor) else np.nan
    return est, loss, last_iter


def fit_partial_profiles_for_row(row):
    variant = str(row['variant'])
    hour_idx = int(row['hour_idx'])
    stride = int(row['resolution_stride'])
    anchor = {
        'sigmasq': float(row['est_sigmasq']),
        'range': float(row['est_range']),
        'nugget': float(row.get('est_nugget', 0.0)),
    }

    hour_map, time_key = load_hour_map(hour_idx)
    thin_map_regular, thin_grid_regular, _ = thin_hour_map(hour_map, stride)
    hybrid_order, thin_grid, nns_map = make_hybrid_ordering(thin_grid_regular)
    thin_map = {k: v[hybrid_order].contiguous() for k, v in thin_map_regular.items()}
    model = build_model(variant, thin_map, nns_map)
    t_pre = time.time()
    model.precompute_conditioning_sets()
    pre_s = time.time() - t_pre
    diag = space_diag(model)

    out_rows = []
    for profile_type in PROFILE_TYPES:
        print('\n' + '-' * 90)
        print(f"profile={profile_type} | {variant} | hour={hour_idx + 1} | {resolution_label(stride)} | anchor={anchor}")
        t_fit = time.time()
        est, loss, fit_iter = optimize_profile(model, variant, profile_type, anchor)
        fit_s = time.time() - t_fit
        profile_row = dict(row)
        profile_row.update({
            'fit_type': profile_type,
            'profile_type': profile_type,
            'fixed_sigmasq': anchor['sigmasq'] if profile_type == 'range_only' else np.nan,
            'fixed_range': anchor['range'] if profile_type == 'sigma_only' else np.nan,
            'fixed_nugget': anchor['nugget'],
            'loss': float(loss),
            'fit_iter_raw': int(fit_iter),
            'fit_steps_reported': int(fit_iter) + 1,
            'precompute_s': float(pre_s),
            'fit_s': float(fit_s),
            'total_s': float(pre_s + fit_s),
            'est_sigmasq': float(est['sigmasq']),
            'est_range': float(est['range']),
            'est_nugget': float(est.get('nugget', 0.0)),
            **diag,
        })
        out_rows.append(profile_row)

    del model, hour_map, thin_map_regular, thin_map
    empty_cache()
    return out_rows


profile_path = OUT_DIR / f'{OUT_PREFIX}_partial_profile.csv'
if RUN_PROFILE_FITS:
    if 'fit_df' not in globals() or fit_df.empty:
        fit_df = pd.read_csv(OUT_DIR / f'{OUT_PREFIX}_full.csv')

    profile_rows = []
    for _, fit_row in fit_df.iterrows():
        profile_rows.extend(fit_partial_profiles_for_row(fit_row))
        tmp = round_df(pd.DataFrame(profile_rows))
        tmp.to_csv(profile_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')

    profile_df = pd.DataFrame(profile_rows)
    round_df(profile_df).to_csv(profile_path, index=False, float_format=f'%.{ROUND_DECIMALS}f')
else:
    profile_df = pd.read_csv(profile_path) if profile_path.exists() else pd.DataFrame()

print('Saved partial-profile fits:', profile_path)
display(round_df(profile_df[['variant','profile_type','hour_idx','resolution_stride','resolution_label','loss','est_sigmasq','est_range','est_nugget','fixed_sigmasq','fixed_range','fixed_nugget','n_grid','n_valid','total_s']]))

# %%
# Combined parameter trajectories:
# row 1: nugget0 full fit
# row 2: nugget_free full fit
# row 3: nugget0 partial profiles anchored at the full-fit estimates
if 'fit_df' not in globals() or fit_df.empty:
    fit_df = pd.read_csv(OUT_DIR / f'{OUT_PREFIX}_full.csv')
if 'profile_df' not in globals() or profile_df.empty:
    profile_df = pd.read_csv(OUT_DIR / f'{OUT_PREFIX}_partial_profile.csv')

full_plot_df = fit_df.copy()
full_plot_df['resolution_label'] = pd.Categorical(
    full_plot_df['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
)
full_plot_df = full_plot_df.sort_values(['variant', 'hour_idx', 'resolution_label'])

prof_plot_df = profile_df.copy()
prof_plot_df['resolution_label'] = pd.Categorical(
    prof_plot_df['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
)
prof_plot_df = prof_plot_df.sort_values(['variant', 'profile_type', 'hour_idx', 'resolution_label'])
prof_anchor_variant = 'nugget0'

combined_param_values = {
    'sigmasq': [full_plot_df['est_sigmasq'], prof_plot_df.loc[prof_plot_df['profile_type'] == 'sigma_only', 'est_sigmasq']],
    'range': [full_plot_df['est_range'], prof_plot_df.loc[prof_plot_df['profile_type'] == 'range_only', 'est_range']],
    'nugget': [full_plot_df['est_nugget'], prof_plot_df['fixed_nugget']],
}
combined_param_ylims = {}
for p, series_list in combined_param_values.items():
    vals = pd.concat([pd.to_numeric(s, errors='coerce') for s in series_list], ignore_index=True)
    vals = vals.replace([np.inf, -np.inf], np.nan).dropna()
    if vals.empty:
        combined_param_ylims[p] = (0.0, 1.0)
        continue
    lo, hi = float(vals.min()), float(vals.max())
    pad = max(abs(hi) * 0.05, 0.05) if np.isclose(lo, hi) else 0.08 * (hi - lo)
    if p == 'nugget':
        lo = min(0.0, lo)
    combined_param_ylims[p] = (lo - pad, hi + pad)

fig, axes = plt.subplots(3, 3, figsize=(15, 10.5), constrained_layout=True, sharex=True)
full_rows = [('nugget0', 'full: nugget fixed 0'), ('nugget_free', 'full: nugget free')]
params_to_plot = ['sigmasq', 'range', 'nugget']
for r, (variant, row_label) in enumerate(full_rows):
    sub_v = full_plot_df[full_plot_df['variant'] == variant]
    for c, p in enumerate(params_to_plot):
        ax = axes[r, c]
        for hour_idx, sub in sub_v.groupby('hour_idx'):
            ax.plot(sub['resolution_label'].astype(str), sub[f'est_{p}'], marker='o', linewidth=1.4, label=f'h{int(hour_idx)+1}')
        ax.set_title(f'{row_label}: {p}')
        ax.set_xlabel('resolution thinning')
        ax.set_ylabel('estimate')
        ax.set_ylim(*combined_param_ylims[p])
        ax.grid(True, alpha=0.3)

sigma_prof = prof_plot_df[(prof_plot_df['variant'] == prof_anchor_variant) & (prof_plot_df['profile_type'] == 'sigma_only')]
range_prof = prof_plot_df[(prof_plot_df['variant'] == prof_anchor_variant) & (prof_plot_df['profile_type'] == 'range_only')]

ax = axes[2, 0]
for hour_idx, sub in sigma_prof.groupby('hour_idx'):
    ax.plot(sub['resolution_label'].astype(str), sub['est_sigmasq'], marker='o', linewidth=1.4, label=f'h{int(hour_idx)+1}')
ax.set_title('profile: estimate sigmasq only\nrange+nugget fixed')
ax.set_xlabel('resolution thinning')
ax.set_ylabel('estimate')
ax.set_ylim(*combined_param_ylims['sigmasq'])
ax.grid(True, alpha=0.3)

ax = axes[2, 1]
for hour_idx, sub in range_prof.groupby('hour_idx'):
    ax.plot(sub['resolution_label'].astype(str), sub['est_range'], marker='o', linewidth=1.4, label=f'h{int(hour_idx)+1}')
ax.set_title('profile: estimate range only\nsigmasq+nugget fixed')
ax.set_xlabel('resolution thinning')
ax.set_ylabel('estimate')
ax.set_ylim(*combined_param_ylims['range'])
ax.grid(True, alpha=0.3)

ax = axes[2, 2]
for hour_idx, sub in sigma_prof.groupby('hour_idx'):
    ax.plot(sub['resolution_label'].astype(str), sub['fixed_nugget'], marker='o', linewidth=1.4, label=f'h{int(hour_idx)+1}')
ax.set_title('profile anchor: fixed nugget')
ax.set_xlabel('resolution thinning')
ax.set_ylabel('estimate')
ax.set_ylim(*combined_param_ylims['nugget'])
ax.grid(True, alpha=0.3)

axes[0, -1].legend(ncol=2, fontsize=8, title='hour')
fig.suptitle(f'Pure-space isotropic Hybrid Vecchia, smooth={SMOOTH}: full and partial-profile parameter trajectories', fontsize=14)
param_plot_path = OUT_DIR / f'{OUT_PREFIX}_parameter_trajectories.png'
fig.savefig(param_plot_path, dpi=180, bbox_inches='tight')
print('Saved combined parameter plot:', param_plot_path)
plt.show()
# Out:
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=300, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=1 | x8 | anchor={'sigmasq': 6.133978292917969, 'range': 1.180362690359259, 'nugget': 8.456146583114561}
#     sigma_only step 1/8: loss=1.710077, grad=1.41e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=1 | x8 | anchor={'sigmasq': 6.133978292917969, 'range': 1.180362690359259, 'nugget': 8.456146583114561}
#     range_only step 1/8: loss=1.710077, grad=9.50e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1160, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=1 | x4 | anchor={'sigmasq': 8.752185650588642, 'range': 0.5366153914254487, 'nugget': 5.512335429971483}
#     sigma_only step 1/8: loss=1.590121, grad=6.61e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=1 | x4 | anchor={'sigmasq': 8.752185650588642, 'range': 0.5366153914254487, 'nugget': 5.512335429971483}
#     range_only step 1/8: loss=1.590121, grad=1.14e-05
#     range_only step 2/8: loss=1.590121, grad=1.14e-05
#     range_only step 3/8: loss=1.590121, grad=1.14e-05
#     range_only step 4/8: loss=1.590121, grad=1.14e-05
#     range_only step 5/8: loss=1.590121, grad=1.14e-05
#     range_only step 6/8: loss=1.590121, grad=1.14e-05
#     range_only step 7/8: loss=1.590121, grad=1.14e-05
#     range_only step 8/8: loss=1.590121, grad=1.14e-05
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4531, m mean/med/max=9.9/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=1 | x2 | anchor={'sigmasq': 10.481949863618212, 'range': 0.7169154223009512, 'nugget': 9.05204532133251}
#     sigma_only step 1/8: loss=1.698644, grad=1.10e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=1 | x2 | anchor={'sigmasq': 10.481949863618212, 'range': 0.7169154223009512, 'nugget': 9.05204532133251}
#     range_only step 1/8: loss=1.698644, grad=2.33e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=18067, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=1 | x1 | anchor={'sigmasq': 9.609032709079017, 'range': 0.19906548584774852, 'nugget': 4.020240470815816}
#     sigma_only step 1/8: loss=1.411762, grad=6.41e-08
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=1 | x1 | anchor={'sigmasq': 9.609032709079017, 'range': 0.19906548584774852, 'nugget': 4.020240470815816}
#     range_only step 1/8: loss=1.411762, grad=9.64e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=293, m mean/med/max=9.6/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=2 | x8 | anchor={'sigmasq': 7.596580120635862, 'range': 1.3866223392736632, 'nugget': 8.97215668438753}
#     sigma_only step 1/8: loss=1.739766, grad=4.30e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=2 | x8 | anchor={'sigmasq': 7.596580120635862, 'range': 1.3866223392736632, 'nugget': 8.97215668438753}
#     range_only step 1/8: loss=1.739766, grad=3.48e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1134, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=2 | x4 | anchor={'sigmasq': 9.55715827400941, 'range': 0.7685998252325253, 'nugget': 6.868354872260568}
#     sigma_only step 1/8: loss=1.634356, grad=6.87e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=2 | x4 | anchor={'sigmasq': 9.55715827400941, 'range': 0.7685998252325253, 'nugget': 6.868354872260568}
#     range_only step 1/8: loss=1.634356, grad=2.65e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4437, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=2 | x2 | anchor={'sigmasq': 10.745528253589676, 'range': 0.3820279330444561, 'nugget': 4.901521586588485}
#     sigma_only step 1/8: loss=1.511144, grad=4.81e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=2 | x2 | anchor={'sigmasq': 10.745528253589676, 'range': 0.3820279330444561, 'nugget': 4.901521586588485}
#     range_only step 1/8: loss=1.511144, grad=8.89e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=17670, m mean/med/max=9.9/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=2 | x1 | anchor={'sigmasq': 11.511391136116794, 'range': 0.19294243136426026, 'nugget': 3.1725570846614977}
#     sigma_only step 1/8: loss=1.356562, grad=2.43e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=2 | x1 | anchor={'sigmasq': 11.511391136116794, 'range': 0.19294243136426026, 'nugget': 3.1725570846614977}
#     range_only step 1/8: loss=1.356562, grad=5.32e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=272, m mean/med/max=9.2/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=3 | x8 | anchor={'sigmasq': 8.502249105149977, 'range': 0.950373339181908, 'nugget': 10.265603229227969}
#     sigma_only step 1/8: loss=1.844563, grad=1.44e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=3 | x8 | anchor={'sigmasq': 8.502249105149977, 'range': 0.950373339181908, 'nugget': 10.265603229227969}
#     range_only step 1/8: loss=1.844563, grad=1.10e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1064, m mean/med/max=9.3/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=3 | x4 | anchor={'sigmasq': 9.919399285236436, 'range': 0.6760050271602925, 'nugget': 8.189807282560048}
#     sigma_only step 1/8: loss=1.727381, grad=5.98e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=3 | x4 | anchor={'sigmasq': 9.919399285236436, 'range': 0.6760050271602925, 'nugget': 8.189807282560048}
#     range_only step 1/8: loss=1.727381, grad=8.26e-08
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4183, m mean/med/max=9.5/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=3 | x2 | anchor={'sigmasq': 12.099158724785523, 'range': 0.3528575904740055, 'nugget': 5.3169978149875865}
#     sigma_only step 1/8: loss=1.573556, grad=3.37e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=3 | x2 | anchor={'sigmasq': 12.099158724785523, 'range': 0.3528575904740055, 'nugget': 5.3169978149875865}
#     range_only step 1/8: loss=1.573556, grad=1.75e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=16698, m mean/med/max=9.6/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=3 | x1 | anchor={'sigmasq': 13.231450335304148, 'range': 0.175799940672354, 'nugget': 2.7522791175496795}
#     sigma_only step 1/8: loss=1.358866, grad=2.58e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=3 | x1 | anchor={'sigmasq': 13.231450335304148, 'range': 0.175799940672354, 'nugget': 2.7522791175496795}
#     range_only step 1/8: loss=1.358866, grad=2.69e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=279, m mean/med/max=9.3/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=4 | x8 | anchor={'sigmasq': 9.514304795034844, 'range': 0.958240267876532, 'nugget': 10.473475489935273}
#     sigma_only step 1/8: loss=1.863805, grad=1.63e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=4 | x8 | anchor={'sigmasq': 9.514304795034844, 'range': 0.958240267876532, 'nugget': 10.473475489935273}
#     range_only step 1/8: loss=1.863805, grad=5.14e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1080, m mean/med/max=9.4/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=4 | x4 | anchor={'sigmasq': 11.622686804759, 'range': 0.5063907218576968, 'nugget': 7.271430328441412}
#     sigma_only step 1/8: loss=1.743590, grad=2.94e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=4 | x4 | anchor={'sigmasq': 11.622686804759, 'range': 0.5063907218576968, 'nugget': 7.271430328441412}
#     range_only step 1/8: loss=1.743590, grad=7.81e-08
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4231, m mean/med/max=9.5/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=4 | x2 | anchor={'sigmasq': 13.156958277870595, 'range': 0.33593331536777676, 'nugget': 4.974207345899679}
#     sigma_only step 1/8: loss=1.570680, grad=2.62e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=4 | x2 | anchor={'sigmasq': 13.156958277870595, 'range': 0.33593331536777676, 'nugget': 4.974207345899679}
#     range_only step 1/8: loss=1.570680, grad=1.30e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=16863, m mean/med/max=9.7/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=4 | x1 | anchor={'sigmasq': 14.764222621557353, 'range': 0.1720617061251759, 'nugget': 2.735427240571549}
#     sigma_only step 1/8: loss=1.384287, grad=7.28e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=4 | x1 | anchor={'sigmasq': 14.764222621557353, 'range': 0.1720617061251759, 'nugget': 2.735427240571549}
#     range_only step 1/8: loss=1.384287, grad=4.96e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=284, m mean/med/max=9.2/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=5 | x8 | anchor={'sigmasq': 7.921902216394235, 'range': 0.9508568446081727, 'nugget': 12.83765437144648}
#     sigma_only step 1/8: loss=1.923999, grad=8.03e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=5 | x8 | anchor={'sigmasq': 7.921902216394235, 'range': 0.9508568446081727, 'nugget': 12.83765437144648}
#     range_only step 1/8: loss=1.923999, grad=1.27e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1093, m mean/med/max=9.5/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=5 | x4 | anchor={'sigmasq': 10.6831483129806, 'range': 0.5555162576471865, 'nugget': 8.979452493874637}
#     sigma_only step 1/8: loss=1.795604, grad=2.20e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=5 | x4 | anchor={'sigmasq': 10.6831483129806, 'range': 0.5555162576471865, 'nugget': 8.979452493874637}
#     range_only step 1/8: loss=1.795604, grad=1.43e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4289, m mean/med/max=9.5/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=5 | x2 | anchor={'sigmasq': 13.409483184132252, 'range': 0.2827295184426088, 'nugget': 5.580779319032416}
#     sigma_only step 1/8: loss=1.649073, grad=3.60e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=5 | x2 | anchor={'sigmasq': 13.409483184132252, 'range': 0.2827295184426088, 'nugget': 5.580779319032416}
#     range_only step 1/8: loss=1.649073, grad=2.72e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=17088, m mean/med/max=9.7/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=5 | x1 | anchor={'sigmasq': 15.15701237388679, 'range': 0.15665928592122738, 'nugget': 2.7739908562491826}
#     sigma_only step 1/8: loss=1.422559, grad=1.90e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=5 | x1 | anchor={'sigmasq': 15.15701237388679, 'range': 0.15665928592122738, 'nugget': 2.7739908562491826}
#     range_only step 1/8: loss=1.422559, grad=2.21e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=293, m mean/med/max=9.5/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=6 | x8 | anchor={'sigmasq': 6.224357589730732, 'range': 0.5243364770121048, 'nugget': 10.696053345913215}
#     sigma_only step 1/8: loss=1.871526, grad=1.16e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=6 | x8 | anchor={'sigmasq': 6.224357589730732, 'range': 0.5243364770121048, 'nugget': 10.696053345913215}
#     range_only step 1/8: loss=1.871526, grad=1.08e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1134, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=6 | x4 | anchor={'sigmasq': 10.434225158236043, 'range': 0.42251427061913305, 'nugget': 7.6481646289450955}
#     sigma_only step 1/8: loss=1.771998, grad=3.47e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=6 | x4 | anchor={'sigmasq': 10.434225158236043, 'range': 0.42251427061913305, 'nugget': 7.6481646289450955}
#     range_only step 1/8: loss=1.771998, grad=3.39e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4468, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=6 | x2 | anchor={'sigmasq': 12.36186836381057, 'range': 0.2564942407836698, 'nugget': 4.956200287691821}
#     sigma_only step 1/8: loss=1.614660, grad=2.79e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=6 | x2 | anchor={'sigmasq': 12.36186836381057, 'range': 0.2564942407836698, 'nugget': 4.956200287691821}
#     range_only step 1/8: loss=1.614660, grad=4.12e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=17760, m mean/med/max=9.9/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=6 | x1 | anchor={'sigmasq': 13.259911293589427, 'range': 0.14383424261843827, 'nugget': 2.824550118274083}
#     sigma_only step 1/8: loss=1.423469, grad=2.53e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=6 | x1 | anchor={'sigmasq': 13.259911293589427, 'range': 0.14383424261843827, 'nugget': 2.824550118274083}
#     range_only step 1/8: loss=1.423469, grad=2.45e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=298, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=7 | x8 | anchor={'sigmasq': 4.457942296819841, 'range': 0.5789690070327396, 'nugget': 10.647859838362637}
#     sigma_only step 1/8: loss=1.823187, grad=3.17e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=7 | x8 | anchor={'sigmasq': 4.457942296819841, 'range': 0.5789690070327396, 'nugget': 10.647859838362637}
#     range_only step 1/8: loss=1.823187, grad=2.62e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1156, m mean/med/max=9.9/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=7 | x4 | anchor={'sigmasq': 9.292792684735081, 'range': 0.3707544642839697, 'nugget': 7.819116845298447}
#     sigma_only step 1/8: loss=1.780250, grad=7.08e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=7 | x4 | anchor={'sigmasq': 9.292792684735081, 'range': 0.3707544642839697, 'nugget': 7.819116845298447}
#     range_only step 1/8: loss=1.780250, grad=7.40e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4549, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=7 | x2 | anchor={'sigmasq': 9.678309530893467, 'range': 0.3158337159792131, 'nugget': 5.871889716640704}
#     sigma_only step 1/8: loss=1.596978, grad=1.01e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=7 | x2 | anchor={'sigmasq': 9.678309530893467, 'range': 0.3158337159792131, 'nugget': 5.871889716640704}
#     range_only step 1/8: loss=1.596978, grad=8.15e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=18104, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=7 | x1 | anchor={'sigmasq': 11.41147864791637, 'range': 0.134331512924695, 'nugget': 2.537978601274098}
#     sigma_only step 1/8: loss=1.380338, grad=5.40e-09
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=7 | x1 | anchor={'sigmasq': 11.41147864791637, 'range': 0.134331512924695, 'nugget': 2.537978601274098}
#     range_only step 1/8: loss=1.380338, grad=1.73e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=297, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=8 | x8 | anchor={'sigmasq': 6.807245503965707, 'range': 0.5338213862253618, 'nugget': 7.147833205631692}
#     sigma_only step 1/8: loss=1.744723, grad=1.28e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=8 | x8 | anchor={'sigmasq': 6.807245503965707, 'range': 0.5338213862253618, 'nugget': 7.147833205631692}
#     range_only step 1/8: loss=1.744723, grad=1.48e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1154, m mean/med/max=9.9/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=8 | x4 | anchor={'sigmasq': 8.231134295427365, 'range': 0.4287719711170394, 'nugget': 5.5579188998164275}
#     sigma_only step 1/8: loss=1.621551, grad=2.71e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=8 | x4 | anchor={'sigmasq': 8.231134295427365, 'range': 0.4287719711170394, 'nugget': 5.5579188998164275}
#     range_only step 1/8: loss=1.621551, grad=9.66e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4548, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=8 | x2 | anchor={'sigmasq': 8.88731882298955, 'range': 0.2748858116514915, 'nugget': 4.566902031095952}
#     sigma_only step 1/8: loss=1.517708, grad=5.38e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=8 | x2 | anchor={'sigmasq': 8.88731882298955, 'range': 0.2748858116514915, 'nugget': 4.566902031095952}
#     range_only step 1/8: loss=1.517708, grad=6.59e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=18102, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget_free | hour=8 | x1 | anchor={'sigmasq': 10.243325413673222, 'range': 0.14117336909963765, 'nugget': 3.0411656342160396}
#     sigma_only step 1/8: loss=1.398041, grad=5.76e-10
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget_free | hour=8 | x1 | anchor={'sigmasq': 10.243325413673222, 'range': 0.14117336909963765, 'nugget': 3.0411656342160396}
#     range_only step 1/8: loss=1.398041, grad=5.57e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=300, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=1 | x8 | anchor={'sigmasq': 14.293974384593922, 'range': 0.3052913547044564, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.739871, grad=1.08e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=1 | x8 | anchor={'sigmasq': 14.293974384593922, 'range': 0.3052913547044564, 'nugget': 0.0}
#     range_only step 1/8: loss=1.739871, grad=1.71e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1160, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=1 | x4 | anchor={'sigmasq': 13.5981532250624, 'range': 0.19266400049139057, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.634467, grad=1.94e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=1 | x4 | anchor={'sigmasq': 13.5981532250624, 'range': 0.19266400049139057, 'nugget': 0.0}
#     range_only step 1/8: loss=1.634467, grad=5.05e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4531, m mean/med/max=9.9/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=1 | x2 | anchor={'sigmasq': 16.961645507126786, 'range': 0.08922847266231397, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.771034, grad=4.55e-08
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=1 | x2 | anchor={'sigmasq': 16.961645507126786, 'range': 0.08922847266231397, 'nugget': 0.0}
#     range_only step 1/8: loss=1.771034, grad=2.01e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=18067, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=1 | x1 | anchor={'sigmasq': 12.907224959161347, 'range': 0.06254060654447491, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.478156, grad=5.45e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=1 | x1 | anchor={'sigmasq': 12.907224959161347, 'range': 0.06254060654447491, 'nugget': 0.0}
#     range_only step 1/8: loss=1.478156, grad=7.69e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=293, m mean/med/max=9.6/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=2 | x8 | anchor={'sigmasq': 15.60615930377575, 'range': 0.3107720762439051, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.780311, grad=7.86e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=2 | x8 | anchor={'sigmasq': 15.60615930377575, 'range': 0.3107720762439051, 'nugget': 0.0}
#     range_only step 1/8: loss=1.780311, grad=2.10e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1134, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=2 | x4 | anchor={'sigmasq': 15.233556314475667, 'range': 0.19656908128225972, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.685109, grad=3.36e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=2 | x4 | anchor={'sigmasq': 15.233556314475667, 'range': 0.19656908128225972, 'nugget': 0.0}
#     range_only step 1/8: loss=1.685109, grad=5.02e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4437, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=2 | x2 | anchor={'sigmasq': 14.038246622855416, 'range': 0.11298318128502315, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.577982, grad=3.84e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=2 | x2 | anchor={'sigmasq': 14.038246622855416, 'range': 0.11298318128502315, 'nugget': 0.0}
#     range_only step 1/8: loss=1.577982, grad=2.61e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=17670, m mean/med/max=9.9/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=2 | x1 | anchor={'sigmasq': 12.901101498460756, 'range': 0.06998820082288382, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.414840, grad=2.92e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=2 | x1 | anchor={'sigmasq': 12.901101498460756, 'range': 0.06998820082288382, 'nugget': 0.0}
#     range_only step 1/8: loss=1.414840, grad=4.16e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=272, m mean/med/max=9.2/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=3 | x8 | anchor={'sigmasq': 18.042159691112687, 'range': 0.27521476641263826, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.884372, grad=7.11e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=3 | x8 | anchor={'sigmasq': 18.042159691112687, 'range': 0.27521476641263826, 'nugget': 0.0}
#     range_only step 1/8: loss=1.884372, grad=1.01e-05
#     range_only step 2/8: loss=1.884372, grad=1.01e-05
#     range_only step 3/8: loss=1.884372, grad=1.01e-05
#     range_only step 4/8: loss=1.884372, grad=1.01e-05
#     range_only step 5/8: loss=1.884372, grad=1.01e-05
#     range_only step 6/8: loss=1.884372, grad=1.01e-05
#     range_only step 7/8: loss=1.884372, grad=1.01e-05
#     range_only step 8/8: loss=1.884372, grad=1.01e-05
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1064, m mean/med/max=9.3/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=3 | x4 | anchor={'sigmasq': 17.296850116873102, 'range': 0.18836145190565629, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.768747, grad=2.01e-05
#     sigma_only step 2/8: loss=1.768747, grad=2.01e-05
#     sigma_only step 3/8: loss=1.768747, grad=2.01e-05
#     sigma_only step 4/8: loss=1.768747, grad=2.01e-05
#     sigma_only step 5/8: loss=1.768747, grad=2.01e-05
#     sigma_only step 6/8: loss=1.768747, grad=2.01e-05
#     sigma_only step 7/8: loss=1.768747, grad=2.01e-05
#     sigma_only step 8/8: loss=1.768747, grad=2.01e-05
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=3 | x4 | anchor={'sigmasq': 17.296850116873102, 'range': 0.18836145190565629, 'nugget': 0.0}
#     range_only step 1/8: loss=1.768747, grad=9.26e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4183, m mean/med/max=9.5/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=3 | x2 | anchor={'sigmasq': 15.651591756439716, 'range': 0.11597353317667627, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.623436, grad=3.81e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=3 | x2 | anchor={'sigmasq': 15.651591756439716, 'range': 0.11597353317667627, 'nugget': 0.0}
#     range_only step 1/8: loss=1.623436, grad=1.76e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=16698, m mean/med/max=9.6/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=3 | x1 | anchor={'sigmasq': 13.884261440626362, 'range': 0.07569704319584603, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.405215, grad=1.46e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=3 | x1 | anchor={'sigmasq': 13.884261440626362, 'range': 0.07569704319584603, 'nugget': 0.0}
#     range_only step 1/8: loss=1.405215, grad=2.53e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=279, m mean/med/max=9.3/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=4 | x8 | anchor={'sigmasq': 19.200448391302448, 'range': 0.30493322427943703, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.892087, grad=8.86e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=4 | x8 | anchor={'sigmasq': 19.200448391302448, 'range': 0.30493322427943703, 'nugget': 0.0}
#     range_only step 1/8: loss=1.892087, grad=4.25e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1080, m mean/med/max=9.4/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=4 | x4 | anchor={'sigmasq': 18.141230965213854, 'range': 0.19670837960680537, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.775980, grad=6.07e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=4 | x4 | anchor={'sigmasq': 18.141230965213854, 'range': 0.19670837960680537, 'nugget': 0.0}
#     range_only step 1/8: loss=1.775980, grad=4.12e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4231, m mean/med/max=9.5/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=4 | x2 | anchor={'sigmasq': 16.304993168762095, 'range': 0.1223128178425107, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.617175, grad=5.98e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=4 | x2 | anchor={'sigmasq': 16.304993168762095, 'range': 0.1223128178425107, 'nugget': 0.0}
#     range_only step 1/8: loss=1.617175, grad=1.98e-05
#     range_only step 2/8: loss=1.617175, grad=1.98e-05
#     range_only step 3/8: loss=1.617175, grad=1.98e-05
#     range_only step 4/8: loss=1.617175, grad=1.98e-05
#     range_only step 5/8: loss=1.617175, grad=1.98e-05
#     range_only step 6/8: loss=1.617175, grad=1.98e-05
#     range_only step 7/8: loss=1.617175, grad=1.98e-05
#     range_only step 8/8: loss=1.617175, grad=1.98e-05
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=16863, m mean/med/max=9.7/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=4 | x1 | anchor={'sigmasq': 15.081227769175289, 'range': 0.07820852046098156, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.425988, grad=9.36e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=4 | x1 | anchor={'sigmasq': 15.081227769175289, 'range': 0.07820852046098156, 'nugget': 0.0}
#     range_only step 1/8: loss=1.425988, grad=9.97e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=284, m mean/med/max=9.2/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=5 | x8 | anchor={'sigmasq': 20.230849907580843, 'range': 0.26627344440355416, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.947022, grad=5.03e-08
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=5 | x8 | anchor={'sigmasq': 20.230849907580843, 'range': 0.26627344440355416, 'nugget': 0.0}
#     range_only step 1/8: loss=1.947022, grad=1.01e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1093, m mean/med/max=9.5/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=5 | x4 | anchor={'sigmasq': 18.70288356857463, 'range': 0.18081841738732257, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.822579, grad=1.41e-05
#     sigma_only step 2/8: loss=1.822579, grad=1.41e-05
#     sigma_only step 3/8: loss=1.822579, grad=1.41e-05
#     sigma_only step 4/8: loss=1.822579, grad=1.41e-05
#     sigma_only step 5/8: loss=1.822579, grad=1.41e-05
#     sigma_only step 6/8: loss=1.822579, grad=1.41e-05
#     sigma_only step 7/8: loss=1.822579, grad=1.41e-05
#     sigma_only step 8/8: loss=1.822579, grad=1.41e-05
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=5 | x4 | anchor={'sigmasq': 18.70288356857463, 'range': 0.18081841738732257, 'nugget': 0.0}
#     range_only step 1/8: loss=1.822579, grad=2.23e-05
#     range_only step 2/8: loss=1.822579, grad=2.23e-05
#     range_only step 3/8: loss=1.822579, grad=2.23e-05
#     range_only step 4/8: loss=1.822579, grad=2.23e-05
#     range_only step 5/8: loss=1.822579, grad=2.23e-05
#     range_only step 6/8: loss=1.822579, grad=2.23e-05
#     range_only step 7/8: loss=1.822579, grad=2.23e-05
#     range_only step 8/8: loss=1.822579, grad=2.23e-05
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4289, m mean/med/max=9.5/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=5 | x2 | anchor={'sigmasq': 17.4783265273062, 'range': 0.11282715196620668, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.691576, grad=6.79e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=5 | x2 | anchor={'sigmasq': 17.4783265273062, 'range': 0.11282715196620668, 'nugget': 0.0}
#     range_only step 1/8: loss=1.691576, grad=6.69e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=17088, m mean/med/max=9.7/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=5 | x1 | anchor={'sigmasq': 15.525046235559678, 'range': 0.07612414704676403, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.457370, grad=5.21e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=5 | x1 | anchor={'sigmasq': 15.525046235559678, 'range': 0.07612414704676403, 'nugget': 0.0}
#     range_only step 1/8: loss=1.457370, grad=4.81e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=293, m mean/med/max=9.5/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=6 | x8 | anchor={'sigmasq': 16.937697239247207, 'range': 0.23282159658743387, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.879076, grad=2.19e-05
#     sigma_only step 2/8: loss=1.879076, grad=2.19e-05
#     sigma_only step 3/8: loss=1.879076, grad=2.19e-05
#     sigma_only step 4/8: loss=1.879076, grad=2.19e-05
#     sigma_only step 5/8: loss=1.879076, grad=2.19e-05
#     sigma_only step 6/8: loss=1.879076, grad=2.19e-05
#     sigma_only step 7/8: loss=1.879076, grad=2.19e-05
#     sigma_only step 8/8: loss=1.879076, grad=2.19e-05
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=6 | x8 | anchor={'sigmasq': 16.937697239247207, 'range': 0.23282159658743387, 'nugget': 0.0}
#     range_only step 1/8: loss=1.879076, grad=2.35e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1134, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=6 | x4 | anchor={'sigmasq': 17.306574683425165, 'range': 0.17498044823730874, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.792502, grad=7.34e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=6 | x4 | anchor={'sigmasq': 17.306574683425165, 'range': 0.17498044823730874, 'nugget': 0.0}
#     range_only step 1/8: loss=1.792502, grad=2.73e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4468, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=6 | x2 | anchor={'sigmasq': 15.940950999324913, 'range': 0.11152001595966546, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.648188, grad=2.85e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=6 | x2 | anchor={'sigmasq': 15.940950999324913, 'range': 0.11152001595966546, 'nugget': 0.0}
#     range_only step 1/8: loss=1.648188, grad=7.03e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=17760, m mean/med/max=9.9/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=6 | x1 | anchor={'sigmasq': 14.369820934223451, 'range': 0.07152886940319354, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.455641, grad=2.68e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=6 | x1 | anchor={'sigmasq': 14.369820934223451, 'range': 0.07152886940319354, 'nugget': 0.0}
#     range_only step 1/8: loss=1.455641, grad=4.67e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=298, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=7 | x8 | anchor={'sigmasq': 14.982117690919639, 'range': 0.20514509367190167, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.831957, grad=6.52e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=7 | x8 | anchor={'sigmasq': 14.982117690919639, 'range': 0.20514509367190167, 'nugget': 0.0}
#     range_only step 1/8: loss=1.831957, grad=5.68e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1156, m mean/med/max=9.9/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=7 | x4 | anchor={'sigmasq': 16.427280974228413, 'range': 0.15664489676113877, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.799177, grad=4.36e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=7 | x4 | anchor={'sigmasq': 16.427280974228413, 'range': 0.15664489676113877, 'nugget': 0.0}
#     range_only step 1/8: loss=1.799177, grad=4.47e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=4549, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=7 | x2 | anchor={'sigmasq': 14.131318543006058, 'range': 0.09817793903729548, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.642873, grad=2.09e-05
#     sigma_only step 2/8: loss=1.642873, grad=2.09e-05
#     sigma_only step 3/8: loss=1.642873, grad=2.09e-05
#     sigma_only step 4/8: loss=1.642873, grad=2.09e-05
#     sigma_only step 5/8: loss=1.642873, grad=2.09e-05
#     sigma_only step 6/8: loss=1.642873, grad=2.09e-05
#     sigma_only step 7/8: loss=1.642873, grad=2.09e-05
#     sigma_only step 8/8: loss=1.642873, grad=2.09e-05
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=7 | x2 | anchor={'sigmasq': 14.131318543006058, 'range': 0.09817793903729548, 'nugget': 0.0}
#     range_only step 1/8: loss=1.642873, grad=1.47e-05
#     range_only step 2/8: loss=1.642873, grad=1.47e-05
#     range_only step 3/8: loss=1.642873, grad=1.47e-05
#     range_only step 4/8: loss=1.642873, grad=1.47e-05
#     range_only step 5/8: loss=1.642873, grad=1.47e-05
#     range_only step 6/8: loss=1.642873, grad=1.47e-05
#     range_only step 7/8: loss=1.642873, grad=1.47e-05
#     range_only step 8/8: loss=1.642873, grad=1.47e-05
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=18104, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=7 | x1 | anchor={'sigmasq': 12.637974637532137, 'range': 0.06950021471024247, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.407915, grad=5.93e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=7 | x1 | anchor={'sigmasq': 12.637974637532137, 'range': 0.06950021471024247, 'nugget': 0.0}
#     range_only step 1/8: loss=1.407915, grad=7.85e-06
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=297, m mean/med/max=9.8/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=8 | x8 | anchor={'sigmasq': 13.799656023887641, 'range': 0.26784703780229674, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.752541, grad=6.46e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=8 | x8 | anchor={'sigmasq': 13.799656023887641, 'range': 0.26784703780229674, 'nugget': 0.0}
#     range_only step 1/8: loss=1.752541, grad=3.58e-08
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=1154, m mean/med/max=9.9/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=8 | x4 | anchor={'sigmasq': 13.118645090069561, 'range': 0.17820002608333807, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.645740, grad=1.02e-07
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=8 | x4 | anchor={'sigmasq': 13.118645090069561, 'range': 0.17820002608333807, 'nugget': 0.0}
#     range_only step 1/8: loss=1.645740, grad=9.00e-07
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.0s. tails=4548, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=8 | x2 | anchor={'sigmasq': 12.486992804746532, 'range': 0.10389080541188617, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.557089, grad=7.19e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=8 | x2 | anchor={'sigmasq': 12.486992804746532, 'range': 0.10389080541188617, 'nugget': 0.0}
#     range_only step 1/8: loss=1.557089, grad=2.22e-05
#     range_only step 2/8: loss=1.557089, grad=2.22e-05
#     range_only step 3/8: loss=1.557089, grad=2.22e-05
#     range_only step 4/8: loss=1.557089, grad=2.22e-05
#     range_only step 5/8: loss=1.557089, grad=2.22e-05
#     range_only step 6/8: loss=1.557089, grad=2.22e-05
#     range_only step 7/8: loss=1.557089, grad=2.22e-05
#     range_only step 8/8: loss=1.557089, grad=2.22e-05
# Pre-computing HybridSpaceVecchia [A=10]... Done in 0.1s. tails=18102, m mean/med/max=10.0/10/10
#
# ------------------------------------------------------------------------------------------
# profile=sigma_only | nugget0 | hour=8 | x1 | anchor={'sigmasq': 12.132272281463587, 'range': 0.06430166980320116, 'nugget': 0.0}
#     sigma_only step 1/8: loss=1.432415, grad=7.40e-06
#
# ------------------------------------------------------------------------------------------
# profile=range_only | nugget0 | hour=8 | x1 | anchor={'sigmasq': 12.132272281463587, 'range': 0.06430166980320116, 'nugget': 0.0}
#     range_only step 1/8: loss=1.432415, grad=5.69e-07
# Saved partial-profile fits: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_spectral_s10_nugget_compare_hybrid_050826_partial_profile.csv
#          variant profile_type  hour_idx  resolution_stride resolution_label    loss  est_sigmasq  est_range  est_nugget  fixed_sigmasq  fixed_range  fixed_nugget  n_grid  n_valid  total_s
# 0    nugget_free   sigma_only         0                  8               x8  1.7101       6.1340     1.1804      8.4561            NaN       1.1804        8.4561     300      300   0.0042
# 1    nugget_free   range_only         0                  8               x8  1.7101       6.1340     1.1804      8.4561         6.1340          NaN        8.4561     300      300   0.0038
# 2    nugget_free   sigma_only         0                  4               x4  1.5901       8.7522     0.5366      5.5123            NaN       0.5366        5.5123    1160     1160   0.1123
# 3    nugget_free   range_only         0                  4               x4  1.5901       8.7522     0.5366      5.5123         8.7522          NaN        5.5123    1160     1160   0.2035
# 4    nugget_free   sigma_only         0                  2               x2  1.6986      10.4819     0.7169      9.0520            NaN       0.7169        9.0520    4560     4531   0.2545
# ..           ...          ...       ...                ...              ...     ...          ...        ...         ...            ...          ...           ...     ...      ...      ...
# 123      nugget0   range_only         7                  4               x4  1.6457      13.1186     0.1782      0.0000        13.1186          NaN        0.0000    1160     1154   0.0241
# 124      nugget0   sigma_only         7                  2               x2  1.5571      12.4870     0.1039      0.0000            NaN       0.1039        0.0000    4560     4548   0.2788
# 125      nugget0   range_only         7                  2               x2  1.5571      12.4870     0.1039      0.0000        12.4870          NaN        0.0000    4560     4548   0.3082
# 126      nugget0   sigma_only         7                  1               x1  1.4324      12.1323     0.0643      0.0000            NaN       0.0643        0.0000   18126    18102   0.3712
# 127      nugget0   range_only         7                  1               x1  1.4324      12.1323     0.0643      0.0000        12.1323          NaN        0.0000   18126    18102   0.1860
#
# [128 rows x 15 columns]
# Saved combined parameter plot: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_spectral_s10_nugget_compare_hybrid_050826_parameter_trajectories.png

# %% [markdown]
# ## Spectral diagnostic
#
# The empirical spectrum uses the same thinned points as each fit. Residuals are computed after an OLS `intercept + lat` detrend, placed back onto the thinned 2D grid, tapered, zero-filled, FFTed, and radially averaged. The main theory curve is now a DW-style finite-sample expected periodogram: the fitted Matérn covariance plus nugget is passed through the same mask/taper/FFT normalization before radial averaging, without median scaling.
#
# The primary radial figure compares data to this expected periodogram. The median-matched Matérn curve is saved separately with `shape_diagnostic` in the filename for shape-only comparison. Raw continuous `f(omega)` is used only internally to form that scaled shape curve; raw `f(omega)` plots and CSV columns are not part of the output.

# %%
SPECTRAL_SMOOTH = SMOOTH
RADIAL_N_BINS = 70
RADIAL_QMAX = 0.985
APPLY_HANN = True
EPS = 1e-12

print('spectral full grid:', (N_LAT, N_LON), 'lat/lon step:', LAT_STEP, LON_STEP)


def trend_design(lat, lon, lat_center=None, lon_center=None):
    lat_center = np.nanmean(lat) if lat_center is None else float(lat_center)
    lon_center = np.nanmean(lon) if lon_center is None else float(lon_center)
    lat_c = lat - lat_center
    lon_c = lon - lon_center
    if MEAN_DESIGN in ('base', 'lat'):
        return np.column_stack([np.ones(len(lat)), lat_c])
    # Keep the residual trend matched to the fitted mean design.
    return np.column_stack([np.ones(len(lat)), lat_c, lon_c])


def detrended_residual_grid(hour_idx, stride):
    hour_map, time_key = load_hour_map(hour_idx)
    thin_map, thin_grid, thin_idx = thin_hour_map(hour_map, stride)
    arr = next(iter(thin_map.values())).detach().cpu().numpy()
    y = arr[:, 2].astype(float)
    lat = arr[:, 0].astype(float)
    lon = arr[:, 1].astype(float)
    valid = np.isfinite(y) & np.isfinite(lat) & np.isfinite(lon)
    if valid.sum() < 4:
        raise ValueError(f'Not enough valid points for hour={hour_idx}, stride={stride}')

    lat_center = np.nanmean(lat[valid])
    lon_center = np.nanmean(lon[valid])
    X = trend_design(lat[valid], lon[valid], lat_center=lat_center, lon_center=lon_center)
    beta, *_ = np.linalg.lstsq(X, y[valid], rcond=None)
    X_all = trend_design(lat, lon, lat_center=lat_center, lon_center=lon_center)
    resid = y - X_all @ beta

    rows_full = local_to_row[thin_idx]
    cols_full = local_to_col[thin_idx]
    row_keep = np.sort(np.unique(rows_full))
    col_keep = np.sort(np.unique(cols_full))
    row_pos = {int(r): i for i, r in enumerate(row_keep)}
    col_pos = {int(c): i for i, c in enumerate(col_keep)}

    grid = np.full((len(row_keep), len(col_keep)), np.nan, dtype=float)
    mask = np.zeros_like(grid, dtype=float)
    rr = np.asarray([row_pos[int(r)] for r in rows_full[valid]], dtype=np.int64)
    cc = np.asarray([col_pos[int(c)] for c in cols_full[valid]], dtype=np.int64)
    grid[rr, cc] = resid[valid]
    mask[rr, cc] = 1.0

    lat_axis = lat_vals[row_keep].astype(float)
    lon_axis = lon_vals[col_keep].astype(float)
    return grid, mask, time_key, int(valid.sum()), lat_axis, lon_axis


def masked_periodogram(grid, mask):
    obs = mask > 0
    if not np.any(obs):
        raise ValueError('No observed cells in spectral grid.')
    z = np.zeros_like(grid, dtype=float)
    z[obs] = grid[obs]
    win = np.outer(np.hanning(z.shape[0]), np.hanning(z.shape[1])) if APPLY_HANN else np.ones_like(z)
    zw = z * win
    norm = np.sum((mask * win) ** 2)
    norm = norm if norm > EPS else 1.0
    return np.abs(np.fft.fftshift(np.fft.fft2(zw))) ** 2 / norm


def matern_covariance_lag(sigmasq, range_, nugget, smooth, lag_lat, lag_lon):
    lag_lat = np.asarray(lag_lat, dtype=float)
    lag_lon = np.asarray(lag_lon, dtype=float)
    r = np.sqrt(lag_lat ** 2 + lag_lon ** 2) / max(float(range_), EPS)
    nu = float(smooth)
    if np.isclose(nu, 0.5):
        corr = np.exp(-r)
    elif np.isclose(nu, 1.5):
        corr = (1.0 + r) * np.exp(-r)
    else:
        corr = np.ones_like(r, dtype=float)
        positive = r > EPS
        if np.any(positive):
            scaled = np.sqrt(2.0 * nu) * r[positive]
            corr[positive] = (2.0 ** (1.0 - nu) / gamma(nu)) * (scaled ** nu) * kv(nu, scaled)
        corr = np.nan_to_num(corr, nan=0.0, posinf=0.0, neginf=0.0)
    cov = float(sigmasq) * corr
    zero_lag = (np.abs(lag_lat) < EPS) & (np.abs(lag_lon) < EPS)
    return cov + max(float(nugget), 0.0) * zero_lag


def taper_mask_autocorrelation(mask):
    mask = np.asarray(mask, dtype=float)
    win = np.outer(np.hanning(mask.shape[0]), np.hanning(mask.shape[1])) if APPLY_HANN else np.ones_like(mask)
    g = mask * win
    H = float(np.sum(g ** 2))
    if H <= EPS:
        raise ValueError('Taper/mask normalization is zero.')
    n1, n2 = g.shape
    G = np.fft.fft2(g, s=(2 * n1 - 1, 2 * n2 - 1))
    ac = np.fft.fftshift(np.fft.ifft2(G * np.conj(G)).real) / H
    return ac, H


def _autocorr_for_lags(ac, lag1, lag2, n1, n2):
    out = np.zeros_like(lag1, dtype=float)
    valid = (np.abs(lag1) <= n1 - 1) & (np.abs(lag2) <= n2 - 1)
    if np.any(valid):
        out[valid] = ac[(n1 - 1 + lag1[valid]).astype(int), (n2 - 1 + lag2[valid]).astype(int)]
    return out


def covariance_lag_kernel(sigmasq, range_, nugget, smooth, n1, n2, dlat, dlon):
    lag1_vals = np.arange(-(n1 - 1), n1, dtype=int)
    lag2_vals = np.arange(-(n2 - 1), n2, dtype=int)
    lag1, lag2 = np.meshgrid(lag1_vals, lag2_vals, indexing='ij')
    return matern_covariance_lag(sigmasq, range_, nugget, smooth, lag1 * dlat, lag2 * dlon)


def fft_convolve_same(values, kernel):
    values = np.asarray(values, dtype=float)
    kernel = np.asarray(kernel, dtype=float)
    out_shape = (values.shape[0] + kernel.shape[0] - 1, values.shape[1] + kernel.shape[1] - 1)
    conv = np.fft.ifft2(np.fft.fft2(values, s=out_shape) * np.fft.fft2(kernel, s=out_shape)).real
    start0 = kernel.shape[0] // 2
    start1 = kernel.shape[1] // 2
    return conv[start0:start0 + values.shape[0], start1:start1 + values.shape[1]]


def expected_periodogram_dw_style(sigmasq, range_, nugget, smooth, mask, lat_axis, lon_axis, project_mean=True):
    """Finite-sample expected periodogram for the same mask/taper/FFT normalization.

    This mirrors the debiased-Whittle idea on the regular FFT grid: multiply
    the fitted covariance at each grid lag by the taper/mask autocorrelation,
    then FFT the lag surface.
    It intentionally avoids median scaling and treats the nugget in covariance
    space before the periodogram operator is applied.  When project_mean=True,
    it also applies the same finite-sample OLS mean projection used to form the
    empirical residual grid, via a low-rank correction rather than an n x n C.
    """
    n1, n2 = mask.shape
    ac, _ = taper_mask_autocorrelation(mask)
    dlat = axis_step(lat_axis)
    dlon = axis_step(lon_axis)
    u1, u2 = np.meshgrid(np.arange(n1, dtype=int), np.arange(n2, dtype=int), indexing='ij')
    tilde_cov = np.zeros((n1, n2), dtype=float)
    for shift1 in (0, -n1):
        for shift2 in (0, -n2):
            lag1 = u1 + shift1
            lag2 = u2 + shift2
            ac_lag = _autocorr_for_lags(ac, lag1, lag2, n1, n2)
            if not np.any(ac_lag):
                continue
            cov_lag = matern_covariance_lag(sigmasq, range_, nugget, smooth, lag1 * dlat, lag2 * dlon)
            tilde_cov += cov_lag * ac_lag
    expected_no_projection = np.fft.fftshift(np.fft.fft2(tilde_cov).real)
    if not project_mean:
        return np.maximum(expected_no_projection, EPS)

    obs = mask > 0
    if obs.sum() <= 2:
        return np.maximum(expected_no_projection, EPS)
    win = np.outer(np.hanning(n1), np.hanning(n2)) if APPLY_HANN else np.ones((n1, n2), dtype=float)
    g = mask * win
    H = float(np.sum(g ** 2))
    lat_grid = np.repeat(np.asarray(lat_axis, dtype=float)[:, None], n2, axis=1)
    lon_grid = np.repeat(np.asarray(lon_axis, dtype=float)[None, :], n1, axis=0)
    X_flat = trend_design(lat_grid.ravel(), lon_grid.ravel(), lat_center=float(np.nanmean(lat_grid[obs])), lon_center=float(np.nanmean(lon_grid[obs])))
    X = X_flat.reshape(n1, n2, X_flat.shape[1])
    U = X * mask[..., None]
    XtX = np.einsum('ijp,ijq->pq', U, X)
    B = np.linalg.pinv(XtX)

    kernel = covariance_lag_kernel(sigmasq, range_, nugget, smooth, n1, n2, dlat, dlon)
    CU = np.empty_like(U, dtype=float)
    for p_idx in range(U.shape[2]):
        CU[..., p_idx] = fft_convolve_same(U[..., p_idx], kernel)
    S = np.einsum('ijp,ijq->pq', U, CU)

    h_fft = []
    c_fft = []
    for p_idx in range(U.shape[2]):
        h_fft.append(np.fft.fftshift(np.fft.fft2(g * X[..., p_idx])))
        c_fft.append(np.fft.fftshift(np.fft.fft2(g * CU[..., p_idx])))
    h_fft = np.stack(h_fft, axis=-1)
    c_fft = np.stack(c_fft, axis=-1)

    A_raw = expected_no_projection * H
    cross = np.einsum('...p,pq,...q->...', c_fft, B, np.conj(h_fft))
    mean_quad = np.einsum('...p,pq,...q->...', h_fft, B @ S @ B, np.conj(h_fft))
    expected_projected = (A_raw - 2.0 * np.real(cross) + np.real(mean_quad)) / H
    return np.maximum(expected_projected, EPS)


def axis_step(axis_vals):
    axis_vals = np.asarray(axis_vals, dtype=float)
    return float(np.median(np.diff(axis_vals))) if len(axis_vals) > 1 else 1.0


def frequency_grid_for_axes(lat_axis, lon_axis):
    dlat = axis_step(lat_axis)
    dlon = axis_step(lon_axis)
    fy = np.fft.fftshift(np.fft.fftfreq(len(lat_axis), d=dlat))
    fx = np.fft.fftshift(np.fft.fftfreq(len(lon_axis), d=dlon))
    omega_y = 2.0 * np.pi * fy
    omega_x = 2.0 * np.pi * fx
    OX, OY = np.meshgrid(omega_x, omega_y)
    k = np.sqrt(OX ** 2 + OY ** 2)
    return k, OX ** 2 + OY ** 2, omega_y, omega_x


K_FULL_RADIAL, OMEGA2_FULL, OMEGA_LAT_FULL, OMEGA_LON_FULL = frequency_grid_for_axes(lat_vals, lon_vals)
_positive_k = K_FULL_RADIAL[np.isfinite(K_FULL_RADIAL) & (K_FULL_RADIAL > 0)]
K_MAX_FULL = float(np.quantile(_positive_k, RADIAL_QMAX))
RADIAL_BINS = np.linspace(0.0, K_MAX_FULL, RADIAL_N_BINS + 1)
FULL_K_PLOT_MAX = K_MAX_FULL


def matern_spectrum_shape(sigmasq, range_, nugget, smooth, omega2):
    nu = float(smooth)
    alpha = 2.0 * nu / max(float(range_) ** 2, EPS)
    # Shape of the 2D Matérn spectral density. The missing normalizing constant
    # is harmless here because each theory curve is scaled to the empirical spectrum.
    matern = float(sigmasq) * (alpha + omega2) ** (-(nu + 1.0))
    return matern + max(float(nugget), 0.0)


def matern_directional_spectrum_shape(sigmasq, range_, nugget, smooth, omega):
    nu = float(smooth)
    alpha = 2.0 * nu / max(float(range_) ** 2, EPS)
    # A 1D lat/lon slice of a 2D Matérn field has spectral shape obtained by
    # integrating the 2D spectrum over the orthogonal frequency: exponent nu+1/2.
    matern = float(sigmasq) * (alpha + omega ** 2) ** (-(nu + 0.5))
    return matern + max(float(nugget), 0.0)


def radial_average(surface, k_radial, bins=RADIAL_BINS, k_max=K_MAX_FULL):
    vals = np.asarray(surface, dtype=float).ravel()
    kk = np.asarray(k_radial, dtype=float).ravel()
    good = np.isfinite(vals) & np.isfinite(kk) & (kk > 0) & (kk <= k_max)
    bin_idx = np.digitize(kk[good], bins) - 1
    rows = []
    vg = vals[good]
    kg = kk[good]
    for b in range(len(bins) - 1):
        m = bin_idx == b
        if not np.any(m):
            continue
        rows.append({
            'k_bin': b,
            'k_mid': 0.5 * (bins[b] + bins[b + 1]),
            'k_mean': float(np.nanmean(kg[m])),
            'spectrum': float(np.nanmean(vg[m])),
            'n_freq': int(m.sum()),
        })
    return pd.DataFrame(rows)


def directional_average_surface(surface, omega_lat, omega_lon, direction):
    vals = np.asarray(surface, dtype=float)
    if direction == 'lon':
        k_abs = np.broadcast_to(np.abs(np.asarray(omega_lon, dtype=float))[None, :], vals.shape)
    elif direction == 'lat':
        k_abs = np.broadcast_to(np.abs(np.asarray(omega_lat, dtype=float))[:, None], vals.shape)
    else:
        raise ValueError(direction)

    good = np.isfinite(vals) & np.isfinite(k_abs) & (k_abs > 0)
    rows = []
    for kval in np.sort(np.unique(np.round(k_abs[good], 12))):
        m = good & np.isclose(k_abs, kval)
        if not np.any(m):
            continue
        rows.append({
            'direction': direction,
            'k_mid': float(kval),
            'spectrum': float(np.nanmean(vals[m])),
            'n_freq': int(m.sum()),
        })
    return pd.DataFrame(rows)


def directional_periodogram(grid, mask, lat_axis, lon_axis, direction):
    obs = mask > 0
    z = np.zeros_like(grid, dtype=float)
    z[obs] = grid[obs]

    if direction == 'lon':
        n = grid.shape[1]
        omega = 2.0 * np.pi * np.fft.fftshift(np.fft.fftfreq(n, d=axis_step(lon_axis)))
        win = np.hanning(n) if APPLY_HANN else np.ones(n)
        powers = []
        for i in range(grid.shape[0]):
            m = mask[i, :]
            if m.sum() < 4:
                continue
            norm = np.sum((m * win) ** 2)
            if norm <= EPS:
                continue
            powers.append(np.abs(np.fft.fftshift(np.fft.fft(z[i, :] * win))) ** 2 / norm)
    elif direction == 'lat':
        n = grid.shape[0]
        omega = 2.0 * np.pi * np.fft.fftshift(np.fft.fftfreq(n, d=axis_step(lat_axis)))
        win = np.hanning(n) if APPLY_HANN else np.ones(n)
        powers = []
        for j in range(grid.shape[1]):
            m = mask[:, j]
            if m.sum() < 4:
                continue
            norm = np.sum((m * win) ** 2)
            if norm <= EPS:
                continue
            powers.append(np.abs(np.fft.fftshift(np.fft.fft(z[:, j] * win))) ** 2 / norm)
    else:
        raise ValueError(direction)

    if not powers:
        return pd.DataFrame(columns=['direction', 'k_mid', 'spectrum', 'n_freq'])
    p = np.nanmean(np.vstack(powers), axis=0)
    k_abs = np.abs(omega)
    rows = []
    for kval in np.sort(np.unique(np.round(k_abs[k_abs > 0], 12))):
        m = np.isclose(k_abs, kval)
        rows.append({
            'direction': direction,
            'k_mid': float(kval),
            'spectrum': float(np.nanmean(p[m])),
            'n_freq': int(m.sum() * len(powers)),
        })
    return pd.DataFrame(rows)


def scale_theory_to_data(data_vals, theory_vals, method='median'):
    d = np.asarray(data_vals, dtype=float)
    t = np.asarray(theory_vals, dtype=float)
    good = np.isfinite(d) & np.isfinite(t) & (d > 0) & (t > 0)
    if not good.any():
        return 1.0
    if method == 'geomean':
        return float(np.exp(np.mean(np.log(d[good]) - np.log(t[good]))))
    return float(np.nanmedian(d[good] / t[good]))
# Out:
# spectral full grid: (114, 159) lat/lon step: 0.04400000000000004 0.06300000000000239

# %%
if RUN_SPECTRUM:
    if 'fit_df' not in globals() or fit_df.empty:
        fit_df = pd.read_csv(OUT_DIR / f'{OUT_PREFIX}_full.csv')

    spectral_rows = []
    directional_rows = []
    for r in fit_df.itertuples(index=False):
        grid, mask, time_key, n_valid_spectrum, lat_axis, lon_axis = detrended_residual_grid(
            int(r.hour_idx), int(r.resolution_stride)
        )
        data_p = masked_periodogram(grid, mask)
        k_data, omega2_data, omega_lat_data, omega_lon_data = frequency_grid_for_axes(lat_axis, lon_axis)
        data_rad = radial_average(data_p, k_data).rename(columns={'spectrum': 'data_spectrum'})

        # Continuous Matérn shape, used only to form the scaled radial shape diagnostic.
        theory_p = matern_spectrum_shape(r.est_sigmasq, r.est_range, r.est_nugget, SPECTRAL_SMOOTH, OMEGA2_FULL)
        theory_rad = radial_average(theory_p, K_FULL_RADIAL).rename(columns={'spectrum': 'theory_spectrum_shape'})

        # DW-style finite-sample expected periodogram in the same FFT convention as data_p.
        theory_expected_p = expected_periodogram_dw_style(
            r.est_sigmasq, r.est_range, r.est_nugget, SPECTRAL_SMOOTH, mask, lat_axis, lon_axis
        )
        theory_expected_rad = radial_average(theory_expected_p, k_data).rename(columns={'spectrum': 'theory_spectrum_expected'})

        merged = theory_rad.merge(theory_expected_rad[['k_bin', 'theory_spectrum_expected']], on='k_bin', how='left')
        merged = merged.merge(data_rad[['k_bin', 'data_spectrum', 'n_freq']], on='k_bin', how='left', suffixes=('', '_data'))
        scale = scale_theory_to_data(merged['data_spectrum'], merged['theory_spectrum_shape'], method='median')
        merged['theory_spectrum_scaled'] = merged['theory_spectrum_shape'] * scale
        data_k_max = float(data_rad['k_mid'].max()) if not data_rad.empty else np.nan

        for m in merged.itertuples(index=False):
            spectral_rows.append({
                'date_str': r.date_str,
                'hour_idx': int(r.hour_idx),
                'time_key': time_key,
                'resolution_stride': int(r.resolution_stride),
                'resolution_label': r.resolution_label,
                'variant': r.variant,
                'fit_type': 'full',
                'smooth': float(r.smooth),
                'n_valid_spectrum': n_valid_spectrum,
                'est_sigmasq': float(r.est_sigmasq),
                'est_range': float(r.est_range),
                'est_nugget': float(r.est_nugget),
                'k_bin': int(m.k_bin),
                'k_mid': float(m.k_mid),
                'k_mean': float(m.k_mean),
                'n_freq': int(getattr(m, 'n_freq_data')) if pd.notna(getattr(m, 'n_freq_data', np.nan)) else 0,
                'data_k_max': data_k_max,
                'data_spectrum': float(m.data_spectrum) if pd.notna(m.data_spectrum) else np.nan,
                'theory_spectrum_expected': float(m.theory_spectrum_expected) if pd.notna(m.theory_spectrum_expected) else np.nan,
                'theory_spectrum_scaled': float(m.theory_spectrum_scaled),
                'theory_scale_to_data': scale,
            })

        for direction in ['lat', 'lon']:
            data_dir = directional_average_surface(data_p, omega_lat_data, omega_lon_data, direction).rename(columns={'spectrum': 'data_spectrum'})
            expected_dir = directional_average_surface(theory_expected_p, omega_lat_data, omega_lon_data, direction).rename(columns={'spectrum': 'theory_spectrum_expected'})
            data_dir['k_key'] = data_dir['k_mid'].round(10)
            expected_dir['k_key'] = expected_dir['k_mid'].round(10)
            merged_dir = data_dir.merge(
                expected_dir[['direction', 'k_key', 'theory_spectrum_expected']],
                on=['direction', 'k_key'], how='left',
            )
            merged_dir['theory_spectrum_shape'] = matern_directional_spectrum_shape(
                r.est_sigmasq, r.est_range, r.est_nugget, SPECTRAL_SMOOTH, merged_dir['k_mid'].to_numpy(dtype=float)
            )
            scale_dir = scale_theory_to_data(merged_dir['data_spectrum'], merged_dir['theory_spectrum_shape'], method='median')
            merged_dir['theory_spectrum_scaled'] = merged_dir['theory_spectrum_shape'] * scale_dir
            data_k_max_dir = float(data_dir['k_mid'].max()) if not data_dir.empty else np.nan
            for m in merged_dir.itertuples(index=False):
                directional_rows.append({
                    'date_str': r.date_str,
                    'hour_idx': int(r.hour_idx),
                    'time_key': time_key,
                    'resolution_stride': int(r.resolution_stride),
                    'resolution_label': r.resolution_label,
                    'variant': r.variant,
                    'fit_type': 'full',
                    'smooth': float(r.smooth),
                    'direction': direction,
                    'k_mid': float(m.k_mid),
                    'data_k_max': data_k_max_dir,
                    'data_spectrum': float(m.data_spectrum) if pd.notna(m.data_spectrum) else np.nan,
                    'theory_spectrum_expected': float(m.theory_spectrum_expected) if pd.notna(m.theory_spectrum_expected) else np.nan,
                    'theory_spectrum_scaled': float(m.theory_spectrum_scaled),
                    'theory_scale_to_data': scale_dir,
                })

    spectral_df = pd.DataFrame(spectral_rows)
    spectral_path = OUT_DIR / f'{OUT_PREFIX}_radial_spectrum.csv'
    spectral_df.to_csv(spectral_path, index=False)
    print('Saved radial spectrum:', spectral_path)
    display(round_df(spectral_df.head(12)))

    directional_spectral_df = pd.DataFrame(directional_rows)
    directional_spectral_path = OUT_DIR / f'{OUT_PREFIX}_directional_spectrum_lat_lon.csv'
    directional_spectral_df.to_csv(directional_spectral_path, index=False)
    print('Saved directional spectrum:', directional_spectral_path)
    display(round_df(directional_spectral_df.head(12)))
# Out:
# Saved radial spectrum: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_spectral_s10_nugget_compare_hybrid_050826_radial_spectrum.csv
#     date_str  hour_idx                     time_key  resolution_stride resolution_label      variant fit_type  smooth  n_valid_spectrum  est_sigmasq  est_range  est_nugget  k_bin    k_mid   k_mean  \
# 0   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0               300        6.134     1.1804      8.4561      0   0.5729   0.6273
# 1   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0               300        6.134     1.1804      8.4561      1   1.7187   1.6953
# 2   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0               300        6.134     1.1804      8.4561      2   2.8645   2.8884
# 3   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0               300        6.134     1.1804      8.4561      3   4.0103   4.1012
# 4   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0               300        6.134     1.1804      8.4561      4   5.1561   5.2435
# 5   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0               300        6.134     1.1804      8.4561      5   6.3019   6.3344
# 6   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0               300        6.134     1.1804      8.4561      6   7.4477   7.4842
# 7   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0               300        6.134     1.1804      8.4561      7   8.5935   8.6499
# 8   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0               300        6.134     1.1804      8.4561      8   9.7393   9.8290
# 9   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0               300        6.134     1.1804      8.4561      9  10.8851  10.9321
# 10  20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0               300        6.134     1.1804      8.4561     10  12.0309  12.0639
# 11  20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0               300        6.134     1.1804      8.4561     11  13.1767  13.1664
#
#     n_freq  data_k_max  data_spectrum  theory_spectrum_expected  theory_spectrum_scaled  theory_scale_to_data
# 0        2     10.8851        34.4698                  102.9507                  9.3640                  0.91
# 1       18     10.8851        76.2141                   49.0012                  8.0531                  0.91
# 2       26     10.8851        19.8104                   18.7865                  7.7580                  0.91
# 3       42     10.8851         7.5662                   11.2144                  7.7130                  0.91
# 4       50     10.8851         7.5557                    9.5058                  7.7021                  0.91
# 5       51     10.8851         7.8449                    9.0546                  7.6986                  0.91
# 6       46     10.8851         6.4382                    8.8161                  7.6970                  0.91
# 7       48     10.8851         9.3930                    8.7167                  7.6962                  0.91
# 8       14     10.8851         3.4678                    8.6756                  7.6959                  0.91
# 9        2     10.8851         0.1611                    8.6663                  7.6957                  0.91
# 10       0     10.8851            NaN                       NaN                  7.6955                  0.91
# 11       0     10.8851            NaN                       NaN                  7.6955                  0.91
# Saved directional spectrum: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_spectral_s10_nugget_compare_hybrid_050826_directional_spectrum_lat_lon.csv
#     date_str  hour_idx                     time_key  resolution_stride resolution_label      variant fit_type  smooth direction   k_mid  data_k_max  data_spectrum  theory_spectrum_expected  \
# 0   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0       lat  1.1900      8.3300        32.9132                   24.1914
# 1   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0       lat  2.3800      8.3300        15.2086                   14.2402
# 2   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0       lat  3.5700      8.3300         4.5972                   10.3341
# 3   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0       lat  4.7600      8.3300         7.1233                    9.2656
# 4   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0       lat  5.9500      8.3300         8.4708                    8.8997
# 5   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0       lat  7.1400      8.3300         6.9824                    8.7529
# 6   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0       lat  8.3300      8.3300         7.8166                    8.6979
# 7   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0       lon  0.6233      6.2333        12.0322                   25.8853
# 8   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0       lon  1.2467      6.2333        29.3972                   20.2326
# 9   20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0       lon  1.8700      6.2333        31.9065                   14.1263
# 10  20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0       lon  2.4933      6.2333        11.9160                   11.3721
# 11  20240703         0  2024_07_y24m07day03_hm00:53                  8               x8  nugget_free     full     1.0       lon  3.1167      6.2333         5.3393                   10.1254
#
#     theory_spectrum_scaled  theory_scale_to_data
# 0                   8.9832                0.9233
# 1                   8.1065                0.9233
# 2                   7.9132                0.9233
# 3                   7.8550                0.9233
# 4                   7.8325                0.9233
# 5                   7.8221                0.9233
# 6                   7.8166                0.9233
# 7                  10.5855                0.9671
# 8                   9.3251                0.9671
# 9                   8.7191                0.9671
# 10                  8.4578                0.9671
# 11                  8.3369                0.9671

# %%
# %%
# Resolution-aware radial spectrum summaries.
# Data spectra are computed on the actual 2D thinned grid for each stride.
# Main theory curves use a DW-style finite-sample expected periodogram:
# fitted covariance + nugget, same mask/taper/FFT normalization, no median scaling.
if 'spectral_df' not in globals():
    spectral_df = pd.read_csv(OUT_DIR / f'{OUT_PREFIX}_radial_spectrum.csv')
required_spectrum_cols = {'theory_spectrum_expected', 'theory_spectrum_scaled'}
missing_spectrum_cols = required_spectrum_cols.difference(spectral_df.columns)
if missing_spectrum_cols:
    raise ValueError(f'spectral_df lacks {sorted(missing_spectrum_cols)}; rerun the RUN_SPECTRUM cell after this update.')

plot_spec = spectral_df.copy()
plot_spec['resolution_label'] = pd.Categorical(
    plot_spec['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
)

avg_low_data = (
    plot_spec.dropna(subset=['data_spectrum'])
    .groupby(['variant', 'resolution_label', 'resolution_stride', 'k_bin'], observed=False)
    .agg(
        k_mid=('k_mid', 'mean'),
        data_spectrum=('data_spectrum', 'mean'),
        n_hours=('hour_idx', 'nunique'),
        data_k_max=('data_k_max', 'mean'),
    )
    .reset_index()
)
low_path = OUT_DIR / f'{OUT_PREFIX}_radial_spectrum_lowfreq_only_avg.csv'
avg_low_data.to_csv(low_path, index=False)
print('Saved low-frequency data spectrum:', low_path)

avg_theory_full = (
    plot_spec
    .groupby(['variant', 'resolution_label', 'k_bin'], observed=False)
    .agg(
        k_mid=('k_mid', 'mean'),
        theory_spectrum_expected=('theory_spectrum_expected', 'mean'),
        theory_spectrum_scaled=('theory_spectrum_scaled', 'mean'),
    )
    .reset_index()
)

positive_spectrum_vals = pd.concat(
    [
        pd.to_numeric(avg_low_data['data_spectrum'], errors='coerce'),
        pd.to_numeric(avg_theory_full['theory_spectrum_expected'], errors='coerce'),
    ],
    ignore_index=True,
).replace([np.inf, -np.inf], np.nan).dropna()
positive_spectrum_vals = positive_spectrum_vals[positive_spectrum_vals > 0]
SPECTRUM_YLIM = (1e-1, 1e4) if positive_spectrum_vals.empty else (
    10 ** np.floor(np.log10(float(positive_spectrum_vals.min()))),
    10 ** np.ceil(np.log10(float(positive_spectrum_vals.max()))),
)
print('Radial spectrum y-limits:', SPECTRUM_YLIM)

labels_order = [f'x{s}' for s in RESOLUTION_STRIDES]
row_specs = [('nugget0', 'full: nugget fixed 0'), ('nugget_free', 'full: nugget free')]
fig, axes = plt.subplots(len(row_specs), len(labels_order), figsize=(4.4 * len(labels_order), 3.4 * len(row_specs)), sharey=True)
if len(row_specs) == 1:
    axes = np.asarray([axes])

for i, (variant, row_title) in enumerate(row_specs):
    for j, label in enumerate(labels_order):
        ax = axes[i, j]
        sub_data = avg_low_data[
            (avg_low_data['variant'] == variant)
            & (avg_low_data['resolution_label'].astype(str) == label)
            & (avg_low_data['k_mid'] > 0)
        ]
        sub_theory = avg_theory_full[
            (avg_theory_full['variant'] == variant)
            & (avg_theory_full['resolution_label'].astype(str) == label)
            & (avg_theory_full['k_mid'] > 0)
        ]
        hour_sub = plot_spec[
            (plot_spec['variant'] == variant)
            & (plot_spec['resolution_label'].astype(str) == label)
            & (plot_spec['k_mid'] > 0)
            & plot_spec['data_spectrum'].notna()
        ]
        if sub_data.empty or sub_theory.empty:
            ax.set_visible(False)
            continue
        k_cut = float(sub_data['data_k_max'].dropna().iloc[0]) if sub_data['data_k_max'].notna().any() else float(sub_data['k_mid'].max())
        ax.plot(sub_theory['k_mid'], sub_theory['theory_spectrum_expected'], color='tab:red', linewidth=1.9, linestyle='--', label='expected periodogram', zorder=3)
        for h_i, (_, hs) in enumerate(hour_sub.groupby('hour_idx')):
            hour_label = 'hourly data spectra' if (i == 0 and j == 0 and h_i == 0) else None
            ax.plot(hs['k_mid'], hs['data_spectrum'], color='0.35', alpha=0.55, linewidth=1.05, label=hour_label, zorder=1)
        ax.plot(sub_data['k_mid'], sub_data['data_spectrum'], color='black', linewidth=2.2, label='data residual spectrum', zorder=4)
        ax.axvline(k_cut, color='0.45', linewidth=1.0, linestyle=':', alpha=0.95, zorder=2)
        ax.set_xlim(0, FULL_K_PLOT_MAX)
        ax.set_ylim(*SPECTRUM_YLIM)
        ax.set_title(f'{row_title}, {label}  (data k <= {k_cut:.1f})')
        ax.set_xlabel('radial frequency on full-grid scale')
        if j == 0:
            ax.set_ylabel('spectrum')
        ax.set_yscale('log')
        ax.grid(alpha=0.2)
        if i == 0 and j == 0:
            ax.legend(fontsize=8)

fig.suptitle(f'smooth={SMOOTH}: radial residual spectrum vs fitted expected periodogram')
fig.tight_layout()
combined_spectrum_plot_path = OUT_DIR / f'{OUT_PREFIX}_data_vs_expected_periodogram_by_variant_resolution.png'
fig.savefig(combined_spectrum_plot_path, dpi=180, bbox_inches='tight')
print('Saved radial spectrum plot:', combined_spectrum_plot_path)
plt.show()


# Shape diagnostic: median-matched Matérn+nugget spectral shape.
# This is useful for comparing curvature only; do not read its vertical scale or nugget floor literally.
fig_shape, axes_shape = plt.subplots(len(row_specs), len(labels_order), figsize=(4.4 * len(labels_order), 3.4 * len(row_specs)), sharey=True)
if len(row_specs) == 1:
    axes_shape = np.asarray([axes_shape])

for i, (variant, row_title) in enumerate(row_specs):
    for j, label in enumerate(labels_order):
        ax = axes_shape[i, j]
        sub_data = avg_low_data[
            (avg_low_data['variant'] == variant)
            & (avg_low_data['resolution_label'].astype(str) == label)
            & (avg_low_data['k_mid'] > 0)
        ]
        sub_theory = avg_theory_full[
            (avg_theory_full['variant'] == variant)
            & (avg_theory_full['resolution_label'].astype(str) == label)
            & (avg_theory_full['k_mid'] > 0)
        ]
        hour_sub = plot_spec[
            (plot_spec['variant'] == variant)
            & (plot_spec['resolution_label'].astype(str) == label)
            & (plot_spec['k_mid'] > 0)
            & plot_spec['data_spectrum'].notna()
        ]
        if sub_data.empty or sub_theory.empty:
            ax.set_visible(False)
            continue
        k_cut = float(sub_data['data_k_max'].dropna().iloc[0]) if sub_data['data_k_max'].notna().any() else float(sub_data['k_mid'].max())
        ax.plot(sub_theory['k_mid'], sub_theory['theory_spectrum_scaled'], color='tab:red', linewidth=1.8, linestyle='--', label='median-matched theory shape', zorder=3)
        for h_i, (_, hs) in enumerate(hour_sub.groupby('hour_idx')):
            hour_label = 'hourly data spectra' if (i == 0 and j == 0 and h_i == 0) else None
            ax.plot(hs['k_mid'], hs['data_spectrum'], color='0.35', alpha=0.55, linewidth=1.05, label=hour_label, zorder=1)
        ax.plot(sub_data['k_mid'], sub_data['data_spectrum'], color='black', linewidth=2.2, label='data residual spectrum', zorder=4)
        ax.axvline(k_cut, color='0.45', linewidth=1.0, linestyle=':', alpha=0.95, zorder=2)
        ax.set_xlim(0, FULL_K_PLOT_MAX)
        ax.set_ylim(*SPECTRUM_YLIM)
        ax.set_title(f'{row_title}, {label}  (data k <= {k_cut:.1f})')
        ax.set_xlabel('radial frequency on full-grid scale')
        if j == 0:
            ax.set_ylabel('spectrum')
        ax.set_yscale('log')
        ax.grid(alpha=0.2)
        if i == 0 and j == 0:
            ax.legend(fontsize=8)

fig_shape.suptitle(f'smooth={SMOOTH}: radial shape diagnostic, median-matched Matérn+nugget theory')
fig_shape.tight_layout()
shape_diagnostic_plot_path = OUT_DIR / f'{OUT_PREFIX}_shape_diagnostic_median_matched_theory_by_variant_resolution.png'
fig_shape.savefig(shape_diagnostic_plot_path, dpi=180, bbox_inches='tight')
print('Saved shape diagnostic radial spectrum plot:', shape_diagnostic_plot_path)
plt.show()
# Out:
# Saved low-frequency data spectrum: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_spectral_s10_nugget_compare_hybrid_050826_radial_spectrum_lowfreq_only_avg.csv
# Radial spectrum y-limits: (1.0, 10000.0)
# Saved radial spectrum plot: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_spectral_s10_nugget_compare_hybrid_050826_data_vs_expected_periodogram_by_variant_resolution.png
# Saved shape diagnostic radial spectrum plot: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_spectral_s10_nugget_compare_hybrid_050826_shape_diagnostic_median_matched_theory_by_variant_resolution.png

# %%
# %%
# Directional lat/lon spectrum diagnostics.
# These are directional summaries of the same 2D masked/tapered/projected FFT
# periodogram used by the radial diagnostic, so empirical and expected curves
# share the same finite-grid convention.
if 'directional_spectral_df' not in globals():
    directional_spectral_df = pd.read_csv(OUT_DIR / f'{OUT_PREFIX}_directional_spectrum_lat_lon.csv')
required_dir_cols = {'theory_spectrum_expected', 'theory_spectrum_scaled'}
missing_dir_cols = required_dir_cols.difference(directional_spectral_df.columns)
if missing_dir_cols:
    raise ValueError(f'directional_spectral_df lacks {sorted(missing_dir_cols)}; rerun the RUN_SPECTRUM cell after this update.')

plot_dir = directional_spectral_df.copy()
plot_dir['resolution_label'] = pd.Categorical(
    plot_dir['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
)

avg_dir_data = (
    plot_dir.dropna(subset=['data_spectrum'])
    .groupby(['variant', 'direction', 'resolution_label', 'resolution_stride', 'k_mid'], observed=False)
    .agg(
        data_spectrum=('data_spectrum', 'mean'),
        n_hours=('hour_idx', 'nunique'),
        data_k_max=('data_k_max', 'mean'),
    )
    .reset_index()
)
avg_dir_theory = (
    plot_dir
    .groupby(['variant', 'direction', 'resolution_label', 'k_mid'], observed=False)
    .agg(
        theory_spectrum_expected=('theory_spectrum_expected', 'mean'),
        theory_spectrum_scaled=('theory_spectrum_scaled', 'mean'),
    )
    .reset_index()
)

dir_expected_vals = pd.concat(
    [
        pd.to_numeric(avg_dir_data['data_spectrum'], errors='coerce'),
        pd.to_numeric(avg_dir_theory['theory_spectrum_expected'], errors='coerce'),
    ],
    ignore_index=True,
).replace([np.inf, -np.inf], np.nan).dropna()
dir_expected_vals = dir_expected_vals[dir_expected_vals > 0]
DIR_EXPECTED_SPECTRUM_YLIM = SPECTRUM_YLIM if dir_expected_vals.empty else (
    10 ** np.floor(np.log10(float(dir_expected_vals.min()))),
    10 ** np.ceil(np.log10(float(dir_expected_vals.max()))),
)
print('Directional expected-periodogram y-limits:', DIR_EXPECTED_SPECTRUM_YLIM)

row_specs = [
    ('nugget0', 'lat', 'nugget fixed 0: latitude direction'),
    ('nugget0', 'lon', 'nugget fixed 0: longitude direction'),
    ('nugget_free', 'lat', 'nugget free: latitude direction'),
    ('nugget_free', 'lon', 'nugget free: longitude direction'),
]
labels_order = [f'x{s}' for s in RESOLUTION_STRIDES]
fig, axes = plt.subplots(len(row_specs), len(labels_order), figsize=(4.4 * len(labels_order), 3.0 * len(row_specs)), sharey=True)

for i, (variant, direction, row_title) in enumerate(row_specs):
    for j, label in enumerate(labels_order):
        ax = axes[i, j]
        sub_data = avg_dir_data[
            (avg_dir_data['variant'] == variant)
            & (avg_dir_data['direction'] == direction)
            & (avg_dir_data['resolution_label'].astype(str) == label)
            & (avg_dir_data['k_mid'] > 0)
        ]
        sub_theory = avg_dir_theory[
            (avg_dir_theory['variant'] == variant)
            & (avg_dir_theory['direction'] == direction)
            & (avg_dir_theory['resolution_label'].astype(str) == label)
            & (avg_dir_theory['k_mid'] > 0)
        ]
        hour_sub = plot_dir[
            (plot_dir['variant'] == variant)
            & (plot_dir['direction'] == direction)
            & (plot_dir['resolution_label'].astype(str) == label)
            & (plot_dir['k_mid'] > 0)
            & plot_dir['data_spectrum'].notna()
        ]
        if sub_data.empty or sub_theory.empty:
            ax.set_visible(False)
            continue
        k_cut = float(sub_data['data_k_max'].dropna().iloc[0]) if sub_data['data_k_max'].notna().any() else float(sub_data['k_mid'].max())
        ax.plot(sub_theory['k_mid'], sub_theory['theory_spectrum_expected'], color='tab:red', linewidth=2.2, linestyle='--', marker='o', markersize=3.0, markerfacecolor='tab:red', markeredgewidth=0.0, label='expected periodogram', zorder=6)
        for h_i, (_, hs) in enumerate(hour_sub.groupby('hour_idx')):
            hour_label = 'hourly data spectra' if (i == 0 and j == 0 and h_i == 0) else None
            ax.plot(hs['k_mid'], hs['data_spectrum'], color='0.35', alpha=0.55, linewidth=1.05, label=hour_label, zorder=1)
        ax.plot(sub_data['k_mid'], sub_data['data_spectrum'], color='black', linewidth=2.2, label='data residual spectrum', zorder=4)
        ax.axvline(k_cut, color='0.45', linewidth=1.0, linestyle=':', alpha=0.95, zorder=2)
        ax.set_xlim(0, max(float(sub_theory['k_mid'].max()), float(sub_data['k_mid'].max())))
        ax.set_ylim(*DIR_EXPECTED_SPECTRUM_YLIM)
        ax.set_title(f'{row_title}, {label}')
        ax.set_xlabel(f'{direction} frequency')
        if j == 0:
            ax.set_ylabel('directional spectrum')
        ax.set_yscale('log')
        ax.grid(alpha=0.2)
        if i == 0 and j == 0:
            ax.legend(fontsize=8)

fig.suptitle(f'smooth={SMOOTH}: directional residual spectrum vs fitted expected periodogram')
fig.tight_layout()
directional_expected_plot_path = OUT_DIR / f'{OUT_PREFIX}_directional_data_vs_expected_periodogram_by_variant_resolution.png'
fig.savefig(directional_expected_plot_path, dpi=180, bbox_inches='tight')
print('Saved directional expected-periodogram plot:', directional_expected_plot_path)
plt.show()


dir_shape_vals = pd.concat(
    [
        pd.to_numeric(avg_dir_data['data_spectrum'], errors='coerce'),
        pd.to_numeric(avg_dir_theory['theory_spectrum_scaled'], errors='coerce'),
    ],
    ignore_index=True,
).replace([np.inf, -np.inf], np.nan).dropna()
dir_shape_vals = dir_shape_vals[dir_shape_vals > 0]
DIR_SHAPE_SPECTRUM_YLIM = SPECTRUM_YLIM if dir_shape_vals.empty else (
    10 ** np.floor(np.log10(float(dir_shape_vals.min()))),
    10 ** np.ceil(np.log10(float(dir_shape_vals.max()))),
)
print('Directional scaled-shape y-limits:', DIR_SHAPE_SPECTRUM_YLIM)

fig_shape, axes_shape = plt.subplots(len(row_specs), len(labels_order), figsize=(4.4 * len(labels_order), 3.0 * len(row_specs)), sharey=True)
for i, (variant, direction, row_title) in enumerate(row_specs):
    for j, label in enumerate(labels_order):
        ax = axes_shape[i, j]
        sub_data = avg_dir_data[
            (avg_dir_data['variant'] == variant)
            & (avg_dir_data['direction'] == direction)
            & (avg_dir_data['resolution_label'].astype(str) == label)
            & (avg_dir_data['k_mid'] > 0)
        ]
        sub_theory = avg_dir_theory[
            (avg_dir_theory['variant'] == variant)
            & (avg_dir_theory['direction'] == direction)
            & (avg_dir_theory['resolution_label'].astype(str) == label)
            & (avg_dir_theory['k_mid'] > 0)
        ]
        hour_sub = plot_dir[
            (plot_dir['variant'] == variant)
            & (plot_dir['direction'] == direction)
            & (plot_dir['resolution_label'].astype(str) == label)
            & (plot_dir['k_mid'] > 0)
            & plot_dir['data_spectrum'].notna()
        ]
        if sub_data.empty or sub_theory.empty:
            ax.set_visible(False)
            continue
        k_cut = float(sub_data['data_k_max'].dropna().iloc[0]) if sub_data['data_k_max'].notna().any() else float(sub_data['k_mid'].max())
        ax.plot(sub_theory['k_mid'], sub_theory['theory_spectrum_scaled'], color='tab:red', linewidth=2.2, linestyle='--', marker='o', markersize=3.0, markerfacecolor='tab:red', markeredgewidth=0.0, label='scaled Matérn shape', zorder=6)
        for h_i, (_, hs) in enumerate(hour_sub.groupby('hour_idx')):
            hour_label = 'hourly data spectra' if (i == 0 and j == 0 and h_i == 0) else None
            ax.plot(hs['k_mid'], hs['data_spectrum'], color='0.35', alpha=0.55, linewidth=1.05, label=hour_label, zorder=1)
        ax.plot(sub_data['k_mid'], sub_data['data_spectrum'], color='black', linewidth=2.2, label='data residual spectrum', zorder=4)
        ax.axvline(k_cut, color='0.45', linewidth=1.0, linestyle=':', alpha=0.95, zorder=2)
        ax.set_xlim(0, max(float(sub_theory['k_mid'].max()), float(sub_data['k_mid'].max())))
        ax.set_ylim(*DIR_SHAPE_SPECTRUM_YLIM)
        ax.set_title(f'{row_title}, {label}')
        ax.set_xlabel(f'{direction} frequency')
        if j == 0:
            ax.set_ylabel('directional spectrum')
        ax.set_yscale('log')
        ax.grid(alpha=0.2)
        if i == 0 and j == 0:
            ax.legend(fontsize=8)

fig_shape.suptitle(f'smooth={SMOOTH}: directional scaled Matérn shape diagnostic')
fig_shape.tight_layout()
directional_shape_plot_path = OUT_DIR / f'{OUT_PREFIX}_shape_diagnostic_directional_scaled_matern_by_variant_resolution.png'
fig_shape.savefig(directional_shape_plot_path, dpi=180, bbox_inches='tight')
print('Saved directional scaled-shape plot:', directional_shape_plot_path)
plt.show()
# Out:
# Directional expected-periodogram y-limits: (1.0, 1000.0)
# Saved directional expected-periodogram plot: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_spectral_s10_nugget_compare_hybrid_050826_directional_data_vs_expected_periodogram_by_variant_resolution.png
# Directional scaled-shape y-limits: (0.1, 1000.0)
# Saved directional scaled-shape plot: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_spectral_s10_nugget_compare_hybrid_050826_shape_diagnostic_directional_scaled_matern_by_variant_resolution.png

# %%
# %%
# Scaled Matérn shape diagnostics for partial-profile fits.
# This keeps the original partial-profile spectral comparison, but writes only
# the median-matched shape curves rather than raw continuous f(omega) output.
if 'profile_df' not in globals() or profile_df.empty:
    profile_path = OUT_DIR / f'{OUT_PREFIX}_partial_profile.csv'
    profile_df = pd.read_csv(profile_path) if profile_path.exists() else pd.DataFrame()

if RUN_SPECTRUM and not profile_df.empty:
    profile_spectral_rows = []
    for r in profile_df.itertuples(index=False):
        grid, mask, time_key, n_valid_spectrum, lat_axis, lon_axis = detrended_residual_grid(
            int(r.hour_idx), int(r.resolution_stride)
        )
        data_p = masked_periodogram(grid, mask)
        k_data, omega2_data, _, _ = frequency_grid_for_axes(lat_axis, lon_axis)
        data_rad = radial_average(data_p, k_data).rename(columns={'spectrum': 'data_spectrum'})

        theory_p = matern_spectrum_shape(r.est_sigmasq, r.est_range, r.est_nugget, SPECTRAL_SMOOTH, OMEGA2_FULL)
        theory_rad = radial_average(theory_p, K_FULL_RADIAL).rename(columns={'spectrum': 'theory_spectrum'})
        merged = theory_rad.merge(data_rad[['k_bin', 'data_spectrum', 'n_freq']], on='k_bin', how='left', suffixes=('', '_data'))
        scale = scale_theory_to_data(merged['data_spectrum'], merged['theory_spectrum'], method='geomean')
        merged['theory_spectrum_scaled'] = merged['theory_spectrum'] * scale
        data_k_max = float(data_rad['k_mid'].max()) if not data_rad.empty else np.nan

        for m in merged.itertuples(index=False):
            profile_spectral_rows.append({
                'date_str': str(r.date_str),
                'hour_idx': int(r.hour_idx),
                'time_key': str(r.time_key),
                'resolution_stride': int(r.resolution_stride),
                'resolution_label': str(r.resolution_label),
                'variant': str(r.variant),
                'profile_type': str(r.profile_type),
                'fit_type': str(r.profile_type),
                'smooth': float(SMOOTH),
                'n_valid_spectrum': int(n_valid_spectrum),
                'est_sigmasq': float(r.est_sigmasq),
                'est_range': float(r.est_range),
                'est_nugget': float(r.est_nugget),
                'k_bin': int(m.k_bin),
                'k_mid': float(m.k_mid),
                'k_mean': float(m.k_mean),
                'n_freq': int(getattr(m, 'n_freq_data')) if pd.notna(getattr(m, 'n_freq_data', np.nan)) else 0,
                'data_k_max': data_k_max,
                'data_spectrum': float(m.data_spectrum) if pd.notna(m.data_spectrum) else np.nan,
                'theory_spectrum_scaled': float(m.theory_spectrum_scaled),
                'theory_scale_to_data': scale,
            })

    profile_spectral_df = pd.DataFrame(profile_spectral_rows)
    profile_spectral_path = OUT_DIR / f'{OUT_PREFIX}_partial_profile_radial_spectrum.csv'
    profile_spectral_df.to_csv(profile_spectral_path, index=False)
    print('Saved partial-profile scaled Matérn shape spectrum:', profile_spectral_path)

    plot_prof = profile_spectral_df.copy()
    plot_prof['resolution_label'] = pd.Categorical(
        plot_prof['resolution_label'], categories=[f'x{s}' for s in RESOLUTION_STRIDES], ordered=True
    )
    avg_prof_data = (
        plot_prof.dropna(subset=['data_spectrum'])
        .groupby(['variant', 'profile_type', 'resolution_label', 'resolution_stride', 'k_bin'], observed=False)
        .agg(k_mid=('k_mid', 'mean'), data_spectrum=('data_spectrum', 'mean'), data_k_max=('data_k_max', 'mean'))
        .reset_index()
    )
    avg_prof_theory = (
        plot_prof
        .groupby(['variant', 'profile_type', 'resolution_label', 'k_bin'], observed=False)
        .agg(
            k_mid=('k_mid', 'mean'),
            theory_spectrum_scaled=('theory_spectrum_scaled', 'mean'),
        )
        .reset_index()
    )

    labels_order = [f'x{s}' for s in RESOLUTION_STRIDES]
    fig, axes = plt.subplots(1, len(labels_order), figsize=(4.4 * len(labels_order), 3.5), sharey=True)
    for j, label in enumerate(labels_order):
        ax = axes[j]
        sub_data = avg_prof_data[
            (avg_prof_data['variant'] == 'nugget0')
            & (avg_prof_data['profile_type'] == 'sigma_only')
            & (avg_prof_data['resolution_label'].astype(str) == label)
            & (avg_prof_data['k_mid'] > 0)
        ]
        sub_sigma = avg_prof_theory[
            (avg_prof_theory['variant'] == 'nugget0')
            & (avg_prof_theory['profile_type'] == 'sigma_only')
            & (avg_prof_theory['resolution_label'].astype(str) == label)
            & (avg_prof_theory['k_mid'] > 0)
        ]
        sub_range = avg_prof_theory[
            (avg_prof_theory['variant'] == 'nugget0')
            & (avg_prof_theory['profile_type'] == 'range_only')
            & (avg_prof_theory['resolution_label'].astype(str) == label)
            & (avg_prof_theory['k_mid'] > 0)
        ]
        if sub_data.empty or sub_sigma.empty or sub_range.empty:
            ax.set_visible(False)
            continue
        k_cut = float(sub_data['data_k_max'].dropna().iloc[0]) if sub_data['data_k_max'].notna().any() else float(sub_data['k_mid'].max())
        ax.plot(sub_data['k_mid'], sub_data['data_spectrum'], color='black', linewidth=2.0, label='data residual spectrum')
        ax.plot(sub_sigma['k_mid'], sub_sigma['theory_spectrum_scaled'], color='tab:blue', linewidth=1.8, linestyle='--', label='scaled sigma-only Matérn shape')
        ax.plot(sub_range['k_mid'], sub_range['theory_spectrum_scaled'], color='tab:green', linewidth=1.8, linestyle='--', label='scaled range-only Matérn shape')
        ax.axvline(k_cut, color='0.55', linewidth=1.0, linestyle=':', alpha=0.9)
        ax.set_xlim(0, FULL_K_PLOT_MAX)
        ax.set_ylim(*SPECTRUM_YLIM)
        ax.set_yscale('log')
        ax.grid(alpha=0.2)
        ax.set_title(f'nugget0 partial profiles, {label}')
        ax.set_xlabel('radial frequency on full-grid scale')
        if j == 0:
            ax.set_ylabel('spectrum')
            ax.legend(fontsize=8)

    fig.suptitle(f'smooth={SMOOTH}: partial-profile scaled Matérn shape diagnostics')
    fig.tight_layout()
    partial_profile_plot_path = OUT_DIR / f'{OUT_PREFIX}_partial_profile_shape_diagnostic_scaled_matern.png'
    fig.savefig(partial_profile_plot_path, dpi=180, bbox_inches='tight')
    print('Saved partial-profile scaled Matérn shape diagnostic plot:', partial_profile_plot_path)
    plt.show()

else:
    print('No partial-profile spectra: profile_df is empty or RUN_SPECTRUM is False.')
# Out:
# Saved partial-profile scaled Matérn shape spectrum: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_spectral_s10_nugget_compare_hybrid_050826_partial_profile_radial_spectrum.csv
# Saved partial-profile scaled Matérn shape diagnostic plot: /Users/joonwonlee/Documents/GEMS_TCO-1/Exercises/st_model/day/local_computer/pure_space/log/real_pure_space_spectral_s10_nugget_compare_hybrid_050826_partial_profile_shape_diagnostic_scaled_matern.png

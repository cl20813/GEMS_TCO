# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\joonw\\tco\\GEMS_TCO-2\\Exercises\\from_amarel\\hyper_parm_opt_1250.0.csv")

dd=df[['lr', 'stepsize' ,'loss', 'time']].groupby([ 'lr', 'stepsize']).mean().reset_index()

# %%
df
# Out:
#            day cov_name  lat_lon_resolution     lr  stepsize      sigma  \
# 0   2025-07-13  Vecc_b2                1250  0.015        20  25.787260
# 1   2025-07-13  Vecc_b2                1250  0.020        20  24.374969
# 2   2025-07-13  Vecc_b2                1250  0.025        20  25.709127
# 3   2025-07-13  Vecc_b2                1250  0.030        20  26.733228
# 4   2025-07-13  Vecc_b2                1250  0.015        40  28.740805
# 5   2025-07-13  Vecc_b2                1250  0.020        40  25.697980
# 6   2025-07-13  Vecc_b2                1250  0.025        40  27.647202
# 7   2025-07-13  Vecc_b2                1250  0.030        40  28.595813
# 8   2025-07-13  Vecc_b2                1250  0.015        60  23.587078
# 9   2025-07-13  Vecc_b2                1250  0.020        60  29.069482
# 10  2025-07-13  Vecc_b2                1250  0.025        60  26.324028
# 11  2025-07-13  Vecc_b2                1250  0.030        60  36.896250
# ...

# %%
dd.sort_values(by=['loss','time'], ascending=[True, True], inplace=True)
dd
# Out:
#        lr  stepsize          loss          time
# 14  0.030        60  11350.100495  12687.505533
# 15  0.030        80  11351.126890   7899.374456
# 6   0.020        60  11351.612100   8264.464523
# 7   0.020        80  11352.009205   6833.633431
# 11  0.025        80  11352.016890   7307.704588
# 9   0.025        40  11352.275790   5059.983358
# 13  0.030        40  11352.281710   4205.460899
# 10  0.025        60  11352.377685   4455.162716
# 8   0.025        20  11352.783565  11054.961296
# 1   0.015        40  11353.148750  17020.805267
# 5   0.020        40  11353.199715   3942.871825
# 12  0.030        20  11353.225910   3292.397189
# 0   0.015        20  11353.312595  17864.708670
# 4   0.020        20  11353.540240  10281.718025
# 3   0.015        80  11353.807950   3923.981473
# 2   0.015        60  11354.976955   1215.077893

# %%
# Standard libraries
import sys
# Add your custom path
gems_tco_path = "/Users/joonwonlee/Documents/GEMS_TCO-1/src"
sys.path.append(gems_tco_path)
import logging
import argparse # Argument parsing

# Data manipulation and analysis
import pandas as pd
import numpy as np
import pickle
import torch
import torch.optim as optim
import copy                    # clone tensor
import time

# Custom imports
import GEMS_TCO
from GEMS_TCO import kernels
from GEMS_TCO import data_preprocess 
from GEMS_TCO import kernels_new 
from GEMS_TCO import orderings as _orderings 
from GEMS_TCO import load_data
from GEMS_TCO import alg_optimization, alg_opt_Encoder
from GEMS_TCO import configuration as config

from typing import Optional, List, Tuple
from pathlib import Path
import typer
import json
from json import JSONEncoder

from GEMS_TCO.data_loader import load_data2

# %%
from pathlib import Path
# Assuming 'config' and 'load_data' class are defined and imported elsewhere

# --- Parameters derived from your framework ---
v: float = 0.5
space: List[str] = ['4', '4']
days: List[str] = ['0', '31']
mm_cond_number: int = 20
# --- End of framework parameters ---

lat_lon_resolution = [int(s) for s in space]
days_s_e = [int(d) for d in days]
days_list = list(range(days_s_e[0], days_s_e[1]))

# These values were not in the framework, so they remain as set in your snippet
years = ['2024']
month_range = [7] 

# Assuming 'config' is available in your environment
output_path = input_path = Path(config.mac_estimates_day_path)

## load ozone data from amarel
data_load_instance = load_data2(config.mac_data_load_path)

# Call the function using the variables from the framework
df_map, ord_mm, nns_map = data_load_instance.load_maxmin_ordered_data_bymonthyear(
lat_lon_resolution=lat_lon_resolution, 
mm_cond_number=mm_cond_number,
years_=years, 
months_=month_range,
lat_range=[0.0, 5.0],      # <-- Add this
lon_range=[123.0, 133.0]   # <-- Add this
)
# Out:
# Subsetting data to lat: [0.0, 5.0], lon: [123.0, 133.0]

# %%
# List to hold the aggregated tensor for each day
daily_aggregated_tensors = [] 

# List to hold the map (dict) of hourly data for each day
daily_hourly_maps = []        

for day_index in range(31):
    # Calculate the start and end indices for the 8 hours of data
    hour_start_index = day_index * 8
    #hour_end_index = (day_index + 1) * 8
    hour_end_index = day_index*8 + 1
    hour_indices = [hour_start_index, hour_end_index]
    
    # Load the data for the current day
    day_hourly_map, day_aggregated_tensor = data_load_instance.load_working_data(
        df_map, 
        hour_indices, 
        ord_mm=None,  
        dtype=torch.float 
    )
    
    # Append the day's data to their respective lists
    daily_aggregated_tensors.append(day_aggregated_tensor)
    daily_hourly_maps.append(day_hourly_map) 

print(daily_aggregated_tensors[0].shape)
#print(daily_hourly_maps[0])
# Out:
# torch.Size([1120, 4])

# %%
instance1 = kernels.vecchia_experiment(0.5, daily_hourly_maps[0], daily_aggregated_tensors[0], nns_map, mm_cond_number, nheads=10)

a = [21.303, 1.307, 1.563, 0.022, -0.144, 0.198, 4.769]

early_stop_vecc_5000= [2.8770e+01, 9.6e-01, 1.08e+00, 6.6789e-07, 1.13e-06, 00,1.91e+00]
scheduler_vecc_5000= [30.823, 1.325, 2.30, 5.191e-06, -9.755e-07, 0.0, 3.17]

a = early_stop_vecc_5000 #  2174.9120
a = [2.9527e+01, 1.3223e+00, 2.2772e+00, 1.3499e-05, 5.9777e-06, 0.0000e+00,
        3.2343e+00] # 2108.4802


params = torch.tensor(a, dtype=torch.float64, requires_grad=True)
cov_map = instance1.cov_structure_saver(params, instance1.matern_cov_anisotropy_v05)  
instance1.vecchia_oct22( params, instance1.matern_cov_anisotropy_v05, cov_map )
# Out:
# tensor(2108.4801, dtype=torch.float64, grad_fn=<AddBackward0>)

# %%
v = 0.5 # smooth
mm_cond_number = 20
nheads = 1120
#nheads = 1230
lr = 0.01
step = 30
gamma_par = 0.5
epochs = 1000

# %% [markdown]
# # Optimization adams

# %%
import torch
import numpy as np
import time
# (Import your fit_vecchia_adams class and other dependencies here)
# from kernels_new import fit_vecchia_adams 

# --- 1. Load Data (Assumed to be done) ---
# daily_hourly_maps = ...
# daily_aggregated_tensors = ...
# nns_map = ...
# v, mm_cond_number, nheads = 0.5, 20, 10
# lat_lon_resolution = [1.0, 1.0] # Example
# lr, step, gamma_par, epochs = 0.01, 40, 0.5, 100 # Example
# device = 'cuda' if torch.cuda.is_available() else 'cpu'


# --- 2. Run optimization loop over pre-loaded data ---
day_indices = [0] 
for day_idx in day_indices:  

    daily_hourly_map = daily_hourly_maps[day_idx]
    daily_aggregated_tensor = daily_aggregated_tensors[day_idx]

    # --- Correct Parameter Initialization ---
    # This block maps your model's physical parameters (sigmasq, range)
    # to the 'phi' parameterization used by your 'log_reparam' covariance function.
    
    # Define initial *model* parameters
    init_sigmasq   = 30.0
    init_range_lat = 0.66 
    init_range_lon = 0.7 
    init_advec_lat = 0
    init_advec_lon = 0
    init_beta      = 0
    init_nugget    = 1.5
    
    # Map model parameters to the 'phi' reparameterization
    init_phi2 = 1.0 / init_range_lon                # [1] phi2 = 1 / range_lon
    init_phi1 = init_sigmasq * init_phi2            # [0] phi1 = sigmasq * phi2 = sigmasq / range_lon
    init_phi3 = (init_range_lon / init_range_lat)**2  # [2] phi3 = (range_lon / range_lat)^2
    init_phi4 = init_beta**2                      # [3] phi4 = beta^2
    
    # Initialize the parameter list by taking the log(),
    # because the covariance function uses torch.exp().
    # 
    device_str = 'cuda' if torch.cuda.is_available() else 'cpu'

    # 💥 CRITICAL FIX: Use dtype=torch.float64 to match your model's internal type.
    params_list = [
        torch.tensor([np.log(init_phi1)],      requires_grad=True, dtype=torch.float64, device=device_str ), # [0] log(phi1)
        torch.tensor([np.log(init_phi2)],      requires_grad=True, dtype=torch.float64, device=device_str ), # [1] log(phi2)
        torch.tensor([np.log(init_phi3)],      requires_grad=True, dtype=torch.float64, device=device_str ), # [2] log(phi3)
        torch.tensor([np.log(init_phi4)],      requires_grad=True, dtype=torch.float64, device=device_str ), # [3] log(phi4)
        torch.tensor([init_advec_lat],         requires_grad=True, dtype=torch.float64, device=device_str ), # [4] advec_lat (linear)
        torch.tensor([init_advec_lon],         requires_grad=True, dtype=torch.float64, device=device_str ), # [5] advec_lon (linear)
        torch.tensor([np.log(init_nugget)],    requires_grad=True, dtype=torch.float64, device=device_str )  # [6] log(nugget)
    ]

    # --- Define learning rates and parameter groups ---
    lr_slow, lr_fast = 0.005, 0.01 
    slow_indices = [ 3, 4, 5] # ranges, anisotropy, advection, beta, nugget
    fast_indices = [0,1,2,6]                 # sigmasq (via phi1)
    
    param_groups = [
        {'params': [params_list[idx] for idx in slow_indices], 'lr': lr_slow, 'name': 'slow_group'},
        {'params': [params_list[idx] for idx in fast_indices], 'lr': lr_fast, 'name': 'fast_group'}
    ]

    # --- Print Job Info ---
    # 💥 FIX: Changed 'day' to 'day_idx'
    res_calc = (113 // lat_lon_resolution[0]) * (158 // lat_lon_resolution[0]) 
    print(f'\n--- Starting Day {day_idx+1} (2024-07-{day_idx+1}) ---')
    print(f'Data size per day: { res_calc }, smooth: {v}')
    print(f'mm_cond_number: {mm_cond_number},\ninitial parameters: \n {params_list}')
            
    # --- Instantiate the Correct Class ---
    # 💥 FIX: Use the 'fit_vecchia_adams' class you provided
    model_instance = kernels_new.fit_vecchia_adams(
            smooth = v,
            input_map = daily_hourly_map,        # 💥 FIX: Use correct loop variable
            aggregated_data = daily_aggregated_tensor, # 💥 FIX: Use correct loop variable
            nns_map = nns_map,
            mm_cond_number = mm_cond_number,
            nheads = nheads
        )

    start_time = time.time()
    
    # --- Call the Correct Optimizer Method ---
    # 💥 FIX: Method name is 'set_optimizer'
    optimizer, scheduler = model_instance.set_optimizer(
            param_groups,     
            lr=lr,            
            betas=(0.9, 0.99), 
            eps=1e-8, 
            step_size=step, 
            gamma=gamma_par
        )

    # --- Call the Correct Fit Method ---
    # 💥 FIX: Method name is 'fit_vecc_scheduler_oct23'
    # 💥 FIX: Pass the model's *actual* covariance function.
    # (This assumes you've fixed the 'raw_params' -> 'params' TypeError 
    # in the 'SpatioTemporalModel' base class, as recommended previously).
    out, epoch_ran = model_instance.fit_vecc_scheduler_oct23(
            params_list,
            optimizer,
            scheduler, 
            model_instance.matern_cov_aniso_STABLE_log_reparam, # Pass the *actual* method
            epochs=epochs
        )

    end_time = time.time()
    epoch_time = end_time - start_time
    
    # 💥 FIX: Changed 'day' to 'day_idx'
    print(f"Day {day_idx+1} optimization finished in {epoch_time:.2f}s over {epoch_ran+1} epochs.")
    print(f"Day {day_idx+1} final results: {out}")
# Out:
# /var/folders/9p/53hd4c7d2fl193h4jwp194wc0000gn/T/ipykernel_21442/1517456120.py:53: RuntimeWarning: divide by zero encountered in log
#   torch.tensor([np.log(init_phi4)],      requires_grad=True, dtype=torch.float64, device=device_str ), # [3] log(phi4)
# --- Starting Day 1 (2024-07-1) ---
# Data size per day: 1092, smooth: 0.5
# mm_cond_number: 20,
# initial parameters:
#  [tensor([3.7579], dtype=torch.float64, requires_grad=True), tensor([0.3567], dtype=torch.float64, requires_grad=True), tensor([0.1177], dtype=torch.float64, requires_grad=True), tensor([-inf], dtype=torch.float64, requires_grad=True), tensor([1.0000e-08], dtype=torch.float64, requires_grad=True), tensor([0.], dtype=torch.float64, requires_grad=True), tensor([0.4055], dtype=torch.float64, requires_grad=True)]
# --- Epoch 1 / Loss: 1814.081401 ---
#   Param 0: Value=3.7579, Grad=113.39924778492197
#   Param 1: Value=0.3567, Grad=-27.078598333934362
#   Param 2: Value=0.1177, Grad=2.1541809744317857
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=0.0000, Grad=5.684341886080801e-13
#   Param 5: Value=0.0000, Grad=1.1937117960769683e-12
#   Param 6: Value=0.4055, Grad=11.37839477560694
#   Max Abs Grad: 1.133992e+02
# ------------------------------
# --- Epoch 11 / Loss: 1801.280129 ---
#   Param 0: Value=3.6593, Grad=76.30135507146834
#   Param 1: Value=0.4564, Grad=-24.499045901603655
#   Param 2: Value=0.1478, Grad=-8.973585357995717
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=3.410605131648481e-13
#   Param 5: Value=-0.0000, Grad=6.252776074688882e-13
#   Param 6: Value=0.3101, Grad=3.5312523878611937
#   Max Abs Grad: 7.630136e+01
# ------------------------------
# --- Epoch 21 / Loss: 1792.180078 ---
#   Param 0: Value=3.5683, Grad=46.32692784499226
#   Param 1: Value=0.5540, Grad=-19.809526353051687
#   Param 2: Value=0.2522, Grad=-14.526166134922791
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-1.7621459846850485e-12
#   Param 5: Value=-0.0000, Grad=-5.684341886080801e-13
#   Param 6: Value=0.2449, Grad=-1.6183885801745403
#   Max Abs Grad: 4.632693e+01
# ------------------------------
# --- Epoch 31 / Loss: 1786.315840 ---
#   Param 0: Value=3.4930, Grad=24.250511763499954
#   Param 1: Value=0.6439, Grad=-12.117149604275335
#   Param 2: Value=0.3665, Grad=-15.289006752029323
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=0.0000, Grad=1.3642420526593924e-12
#   Param 5: Value=-0.0000, Grad=1.5347723092418164e-12
#   Param 6: Value=0.2455, Grad=-4.5224712405235685
#   Max Abs Grad: 2.425051e+01
# ------------------------------
# --- Epoch 41 / Loss: 1784.370592 ---
#   Param 0: Value=3.4647, Grad=18.503319610053776
#   Param 1: Value=0.6808, Grad=-7.819582071637534
#   Param 2: Value=0.4236, Grad=-13.62695552891116
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.410605131648481e-13
#   Param 5: Value=-0.0000, Grad=1.1368683772161603e-13
#   Param 6: Value=0.2762, Grad=-4.769330668866714
#   Max Abs Grad: 1.850332e+01
# ------------------------------
# --- Epoch 51 / Loss: 1782.958639 ---
#   Param 0: Value=3.4424, Grad=15.944727481999339
#   Param 1: Value=0.7089, Grad=-3.898465841052433
#   Param 2: Value=0.4771, Grad=-11.19753840250109
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-1.1937117960769683e-12
#   Param 5: Value=-0.0000, Grad=1.7053025658242404e-13
#   Param 6: Value=0.3193, Grad=-4.343313869323036
#   Max Abs Grad: 1.594473e+01
# ------------------------------
# --- Epoch 61 / Loss: 1781.957675 ---
#   Param 0: Value=3.4229, Grad=14.78235038597185
#   Param 1: Value=0.7273, Grad=-0.5669922005630491
#   Param 2: Value=0.5249, Grad=-8.760215688772742
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-2.2737367544323206e-13
#   Param 5: Value=-0.0000, Grad=-5.684341886080802e-14
#   Param 6: Value=0.3646, Grad=-3.7052872186077774
#   Max Abs Grad: 1.478235e+01
# ------------------------------
# --- Epoch 71 / Loss: 1781.572962 ---
#   Param 0: Value=3.4137, Grad=14.495477026193292
#   Param 1: Value=0.7316, Grad=0.6889372559665045
#   Param 2: Value=0.5458, Grad=-7.697820157287275
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-1.3073986337985843e-12
#   Param 5: Value=-0.0000, Grad=1.1368683772161603e-13
#   Param 6: Value=0.3863, Grad=-3.4066807377740664
#   Max Abs Grad: 1.449548e+01
# ------------------------------
# --- Epoch 81 / Loss: 1781.234084 ---
#   Param 0: Value=3.4042, Grad=14.292670112453719
#   Param 1: Value=0.7323, Grad=1.6130380404763183
#   Param 2: Value=0.5646, Grad=-6.788958294831998
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-4.547473508864641e-13
#   Param 5: Value=-0.0000, Grad=-3.410605131648481e-13
#   Param 6: Value=0.4069, Grad=-3.168071701962744
#   Max Abs Grad: 1.429267e+01
# ------------------------------
# --- Epoch 91 / Loss: 1780.918729 ---
#   Param 0: Value=3.3944, Grad=14.078487211837668
#   Param 1: Value=0.7302, Grad=2.296147537675485
#   Param 2: Value=0.5818, Grad=-6.010505477835241
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=1.4210854715202004e-12
#   Param 5: Value=-0.0000, Grad=-3.979039320256561e-13
#   Param 6: Value=0.4268, Grad=-2.995906785522606
#   Max Abs Grad: 1.407849e+01
# ------------------------------
# --- Epoch 101 / Loss: 1780.765137 ---
#   Param 0: Value=3.3892, Grad=13.951901744386664
#   Param 1: Value=0.7281, Grad=2.5464104218890506
#   Param 2: Value=0.5899, Grad=-5.672895488128674
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-2.8421709430404007e-13
#   Param 5: Value=-0.0000, Grad=-7.958078640513122e-13
#   Param 6: Value=0.4365, Grad=-2.940812001366018
#   Max Abs Grad: 1.395190e+01
# ------------------------------
# --- Epoch 111 / Loss: 1780.610578 ---
#   Param 0: Value=3.3837, Grad=13.803011225299796
#   Param 1: Value=0.7253, Grad=2.7388881856127556
#   Param 2: Value=0.5977, Grad=-5.367263762784958
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=1.1368683772161603e-13
#   Param 5: Value=-0.0000, Grad=-1.1937117960769683e-12
#   Param 6: Value=0.4462, Grad=-2.9089924940133303
#   Max Abs Grad: 1.380301e+01
# ------------------------------
# --- Epoch 121 / Loss: 1780.453923 ---
#   Param 0: Value=3.3780, Grad=13.635841660993387
#   Param 1: Value=0.7219, Grad=2.891060998395946
#   Param 2: Value=0.6053, Grad=-5.082366939097924
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=1.5916157281026244e-12
#   Param 5: Value=-0.0000, Grad=0.0
#   Param 6: Value=0.4561, Grad=-2.8942785944993714
#   Max Abs Grad: 1.363584e+01
# ------------------------------
# --- Epoch 131 / Loss: 1780.374008 ---
#   Param 0: Value=3.3750, Grad=13.54404879678921
#   Param 1: Value=0.7199, Grad=2.95171299912593
#   Param 2: Value=0.6091, Grad=-4.94725809319799
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=1.1937117960769683e-12
#   Param 5: Value=-0.0000, Grad=5.684341886080802e-14
#   Param 6: Value=0.4611, Grad=-2.8939471007548785
#   Max Abs Grad: 1.354405e+01
# ------------------------------
# --- Epoch 141 / Loss: 1780.291940 ---
#   Param 0: Value=3.3719, Grad=13.44283700623253
#   Param 1: Value=0.7177, Grad=3.0020604806406923
#   Param 2: Value=0.6129, Grad=-4.816556680599285
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-6.252776074688882e-13
#   Param 5: Value=-0.0000, Grad=-5.684341886080801e-13
#   Param 6: Value=0.4662, Grad=-2.8996387217289508
#   Max Abs Grad: 1.344284e+01
# ------------------------------
# --- Epoch 151 / Loss: 1780.207698 ---
#   Param 0: Value=3.3686, Grad=13.332706693685209
#   Param 1: Value=0.7153, Grad=3.044350818313657
#   Param 2: Value=0.6168, Grad=-4.688734483271879
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=1.1368683772161603e-12
#   Param 5: Value=-0.0000, Grad=5.684341886080801e-13
#   Param 6: Value=0.4714, Grad=-2.9105615478601083
#   Max Abs Grad: 1.333271e+01
# ------------------------------
# --- Epoch 161 / Loss: 1780.164430 ---
#   Param 0: Value=3.3670, Grad=13.273081645035901
#   Param 1: Value=0.7141, Grad=3.062048183401306
#   Param 2: Value=0.6188, Grad=-4.625935989550518
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.410605131648481e-13
#   Param 5: Value=-0.0000, Grad=-3.410605131648481e-13
#   Param 6: Value=0.4740, Grad=-2.9185248825347365
#   Max Abs Grad: 1.327308e+01
# ------------------------------
# --- Epoch 171 / Loss: 1780.119907 ---
#   Param 0: Value=3.3652, Grad=13.208034360777884
#   Param 1: Value=0.7127, Grad=3.07716925666187
#   Param 2: Value=0.6208, Grad=-4.5638914470875855
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-1.2505552149377763e-12
#   Param 5: Value=-0.0000, Grad=1.1368683772161603e-13
#   Param 6: Value=0.4768, Grad=-2.929044541091181
#   Max Abs Grad: 1.320803e+01
# ------------------------------
# --- Epoch 181 / Loss: 1780.074156 ---
#   Param 0: Value=3.3634, Grad=13.137506674391743
#   Param 1: Value=0.7113, Grad=3.0900250937356417
#   Param 2: Value=0.6228, Grad=-4.502406885111149
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=1.0231815394945443e-12
#   Param 5: Value=-0.0000, Grad=5.684341886080802e-14
#   Param 6: Value=0.4795, Grad=-2.9420679490833925
#   Max Abs Grad: 1.313751e+01
# ------------------------------
# --- Epoch 191 / Loss: 1780.050662 ---
#   Param 0: Value=3.3624, Grad=13.099432980851939
#   Param 1: Value=0.7106, Grad=3.0953872102257596
#   Param 2: Value=0.6238, Grad=-4.4719223461279425
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=3.410605131648481e-13
#   Param 5: Value=-0.0000, Grad=1.7053025658242404e-13
#   Param 6: Value=0.4809, Grad=-2.9498398600818225
#   Max Abs Grad: 1.309943e+01
# ------------------------------
# --- Epoch 201 / Loss: 1780.026528 ---
#   Param 0: Value=3.3615, Grad=13.058222000860203
#   Param 1: Value=0.7098, Grad=3.0998545951574976
#   Param 2: Value=0.6249, Grad=-4.441668320973539
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=2.8421709430404007e-13
#   Param 5: Value=-0.0000, Grad=5.684341886080802e-14
#   Param 6: Value=0.4823, Grad=-2.958937833080857
#   Max Abs Grad: 1.305822e+01
# ------------------------------
# --- Epoch 211 / Loss: 1780.001772 ---
#   Param 0: Value=3.3605, Grad=13.013855350454786
#   Param 1: Value=0.7089, Grad=3.1034662608721444
#   Param 2: Value=0.6260, Grad=-4.41162697306835
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=9.663381206337363e-13
#   Param 5: Value=-0.0000, Grad=0.0
#   Param 6: Value=0.4838, Grad=-2.969364593026033
#   Max Abs Grad: 1.301386e+01
# ------------------------------
# --- Epoch 221 / Loss: 1779.989087 ---
#   Param 0: Value=3.3599, Grad=12.99008912368927
#   Param 1: Value=0.7085, Grad=3.104845089345307
#   Param 2: Value=0.6266, Grad=-4.396718043042275
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-1.1368683772161603e-12
#   Param 5: Value=-0.0000, Grad=-1.1368683772161603e-13
#   Param 6: Value=0.4845, Grad=-2.975244171495269
#   Max Abs Grad: 1.299009e+01
# ------------------------------
# --- Epoch 231 / Loss: 1779.976094 ---
#   Param 0: Value=3.3594, Grad=12.9646482579483
#   Param 1: Value=0.7081, Grad=3.105830463191873
#   Param 2: Value=0.6271, Grad=-4.381928991438083
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.979039320256561e-13
#   Param 5: Value=-0.0000, Grad=-1.0231815394945443e-12
#   Param 6: Value=0.4852, Grad=-2.9818123579128026
#   Max Abs Grad: 1.296465e+01
# ------------------------------
# --- Epoch 241 / Loss: 1779.962803 ---
#   Param 0: Value=3.3589, Grad=12.937550423474658
#   Param 1: Value=0.7076, Grad=3.106422106297865
#   Param 2: Value=0.6277, Grad=-4.3672623239702215
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=4.547473508864641e-13
#   Param 5: Value=-0.0000, Grad=1.1368683772161603e-13
#   Param 6: Value=0.4860, Grad=-2.9890658486611534
#   Max Abs Grad: 1.293755e+01
# ------------------------------
# --- Epoch 251 / Loss: 1779.956012 ---
#   Param 0: Value=3.3586, Grad=12.923187815582947
#   Param 1: Value=0.7074, Grad=3.106516632604156
#   Param 2: Value=0.6280, Grad=-4.359993882262239
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-8.526512829121202e-13
#   Param 5: Value=-0.0000, Grad=-5.684341886080802e-14
#   Param 6: Value=0.4864, Grad=-2.9930311956150746
#   Max Abs Grad: 1.292319e+01
# ------------------------------
# --- Epoch 261 / Loss: 1779.949078 ---
#   Param 0: Value=3.3583, Grad=12.907998612460833
#   Param 1: Value=0.7071, Grad=3.1064154308404643
#   Param 2: Value=0.6283, Grad=-4.352795904879809
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-1.5347723092418164e-12
#   Param 5: Value=-0.0000, Grad=7.958078640513122e-13
#   Param 6: Value=0.4867, Grad=-2.997337955203761
#   Max Abs Grad: 1.290800e+01
# ------------------------------
# --- Epoch 271 / Loss: 1779.942007 ---
#   Param 0: Value=3.3580, Grad=12.892006126258499
#   Param 1: Value=0.7069, Grad=3.106115596680353
#   Param 2: Value=0.6286, Grad=-4.34567018225123
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=5.684341886080801e-13
#   Param 5: Value=-0.0000, Grad=-3.410605131648481e-13
#   Param 6: Value=0.4871, Grad=-3.0019797228455474
#   Max Abs Grad: 1.289201e+01
# ------------------------------
# --- Epoch 281 / Loss: 1779.938406 ---
#   Param 0: Value=3.3578, Grad=12.883622743688198
#   Param 1: Value=0.7067, Grad=3.1058640789210377
#   Param 2: Value=0.6288, Grad=-4.342144556734814
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-2.2737367544323206e-13
#   Param 5: Value=-0.0000, Grad=1.1368683772161603e-13
#   Param 6: Value=0.4873, Grad=-3.0044635788458325
#   Max Abs Grad: 1.288362e+01
# ------------------------------
# --- Epoch 291 / Loss: 1779.934741 ---
#   Param 0: Value=3.3577, Grad=12.87485812082136
#   Param 1: Value=0.7066, Grad=3.1055117888150297
#   Param 2: Value=0.6289, Grad=-4.338658005739376
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-5.684341886080802e-14
#   Param 5: Value=-0.0000, Grad=-5.684341886080801e-13
#   Param 6: Value=0.4875, Grad=-3.007108040211561
#   Max Abs Grad: 1.287486e+01
# ------------------------------
# --- Epoch 301 / Loss: 1779.931014 ---
#   Param 0: Value=3.3575, Grad=12.86572920679047
#   Param 1: Value=0.7065, Grad=3.1050576844524285
#   Param 2: Value=0.6291, Grad=-4.3352107333746766
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=1.1368683772161603e-13
#   Param 5: Value=-0.0000, Grad=-1.0231815394945443e-12
#   Param 6: Value=0.4877, Grad=-3.0099077522679862
#   Max Abs Grad: 1.286573e+01
# ------------------------------
# --- Epoch 311 / Loss: 1779.929122 ---
#   Param 0: Value=3.3574, Grad=12.860991987975934
#   Param 1: Value=0.7064, Grad=3.1047791590738454
#   Param 2: Value=0.6292, Grad=-4.333506764153924
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-2.8421709430404007e-13
#   Param 5: Value=-0.0000, Grad=0.0
#   Param 6: Value=0.4878, Grad=-3.011382062286933
#   Max Abs Grad: 1.286099e+01
# ------------------------------
# --- Epoch 321 / Loss: 1779.927202 ---
#   Param 0: Value=3.3574, Grad=12.856088669389484
#   Param 1: Value=0.7063, Grad=3.104449597970049
#   Param 2: Value=0.6293, Grad=-4.331822723529062
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-1.9895196601282805e-12
#   Param 5: Value=-0.0000, Grad=5.684341886080801e-13
#   Param 6: Value=0.4879, Grad=-3.01292834288159
#   Max Abs Grad: 1.285609e+01
# ------------------------------
# --- Epoch 331 / Loss: 1779.925256 ---
#   Param 0: Value=3.3573, Grad=12.851028939247287
#   Param 1: Value=0.7062, Grad=3.104069134958601
#   Param 2: Value=0.6293, Grad=-4.330158284794146
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=5.684341886080801e-13
#   Param 5: Value=-0.0000, Grad=5.684341886080802e-14
#   Param 6: Value=0.4880, Grad=-3.0145432475852814
#   Max Abs Grad: 1.285103e+01
# ------------------------------
# --- Epoch 341 / Loss: 1779.924271 ---
#   Param 0: Value=3.3572, Grad=12.848425881184214
#   Param 1: Value=0.7062, Grad=3.1038535844764126
#   Param 2: Value=0.6294, Grad=-4.329335651948577
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-1.0231815394945443e-12
#   Param 5: Value=-0.0000, Grad=-3.979039320256561e-13
#   Param 6: Value=0.4880, Grad=-3.015383203895375
#   Max Abs Grad: 1.284843e+01
# ------------------------------
# --- Epoch 351 / Loss: 1779.923274 ---
#   Param 0: Value=3.3572, Grad=12.845753728094737
#   Param 1: Value=0.7062, Grad=3.1036131742505995
#   Param 2: Value=0.6294, Grad=-4.328522463190189
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-7.389644451905042e-13
#   Param 5: Value=-0.0000, Grad=2.8421709430404007e-13
#   Param 6: Value=0.4881, Grad=-3.016254091612532
#   Max Abs Grad: 1.284575e+01
# ------------------------------
# --- Epoch 361 / Loss: 1779.922265 ---
#   Param 0: Value=3.3572, Grad=12.84301728154447
#   Param 1: Value=0.7061, Grad=3.1033483529769335
#   Param 2: Value=0.6295, Grad=-4.3277183906372665
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=1.7053025658242404e-12
#   Param 5: Value=-0.0000, Grad=1.1937117960769683e-12
#   Param 6: Value=0.4881, Grad=-3.0171541284239183
#   Max Abs Grad: 1.284302e+01
# ------------------------------
# --- Epoch 371 / Loss: 1779.921756 ---
#   Param 0: Value=3.3571, Grad=12.841619288475329
#   Param 1: Value=0.7061, Grad=3.1032040026660894
#   Param 2: Value=0.6295, Grad=-4.32732073098984
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-1.9895196601282805e-12
#   Param 5: Value=-0.0000, Grad=3.979039320256561e-13
#   Param 6: Value=0.4881, Grad=-3.017617810429767
#   Max Abs Grad: 1.284162e+01
# ------------------------------
# --- Epoch 381 / Loss: 1779.921242 ---
#   Param 0: Value=3.3571, Grad=12.840193573116677
#   Param 1: Value=0.7061, Grad=3.103048080215809
#   Param 2: Value=0.6295, Grad=-4.326927290839349
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=7.389644451905042e-13
#   Param 5: Value=-0.0000, Grad=5.115907697472721e-13
#   Param 6: Value=0.4882, Grad=-3.0180943345053564
#   Max Abs Grad: 1.284019e+01
# ------------------------------
# --- Epoch 391 / Loss: 1779.920724 ---
#   Param 0: Value=3.3571, Grad=12.838742298296621
#   Param 1: Value=0.7061, Grad=3.1028809673436797
#   Param 2: Value=0.6295, Grad=-4.326537862042446
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=9.094947017729282e-13
#   Param 5: Value=-0.0000, Grad=-7.958078640513122e-13
#   Param 6: Value=0.4882, Grad=-3.0185828446403526
#   Max Abs Grad: 1.283874e+01
# ------------------------------
# --- Epoch 401 / Loss: 1779.920463 ---
#   Param 0: Value=3.3571, Grad=12.838004920029984
#   Param 1: Value=0.7061, Grad=3.102792021717798
#   Param 2: Value=0.6296, Grad=-4.326345045919096
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=7.958078640513122e-13
#   Param 5: Value=-0.0000, Grad=-1.1368683772161603e-13
#   Param 6: Value=0.4882, Grad=-3.0188326708550246
#   Max Abs Grad: 1.283800e+01
# ------------------------------
# --- Epoch 411 / Loss: 1779.920199 ---
#   Param 0: Value=3.3571, Grad=12.83725671572147
#   Param 1: Value=0.7060, Grad=3.1026979203966776
#   Param 2: Value=0.6296, Grad=-4.326154030296301
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=8.526512829121202e-13
#   Param 5: Value=-0.0000, Grad=-5.115907697472721e-13
#   Param 6: Value=0.4882, Grad=-3.019087682925423
#   Max Abs Grad: 1.283726e+01
# ------------------------------
# --- Epoch 421 / Loss: 1779.919934 ---
#   Param 0: Value=3.3571, Grad=12.836498597037705
#   Param 1: Value=0.7060, Grad=3.1025989014198396
#   Param 2: Value=0.6296, Grad=-4.325964705885443
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-6.252776074688882e-13
#   Param 5: Value=-0.0000, Grad=7.389644451905042e-13
#   Param 6: Value=0.4882, Grad=-3.0193474981955863
#   Max Abs Grad: 1.283650e+01
# ------------------------------
# --- Epoch 431 / Loss: 1779.919801 ---
#   Param 0: Value=3.3571, Grad=12.836115009420865
#   Param 1: Value=0.7060, Grad=3.102547055152111
#   Param 2: Value=0.6296, Grad=-4.325870835141677
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-1.5916157281026244e-12
#   Param 5: Value=-0.0000, Grad=1.0231815394945443e-12
#   Param 6: Value=0.4882, Grad=-3.0194796234691452
#   Max Abs Grad: 1.283612e+01
# ------------------------------
# --- Epoch 441 / Loss: 1779.919667 ---
#   Param 0: Value=3.3570, Grad=12.835727275031429
#   Param 1: Value=0.7060, Grad=3.1024929993463326
#   Param 2: Value=0.6296, Grad=-4.325777705945826
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=6.252776074688882e-13
#   Param 5: Value=-0.0000, Grad=6.821210263296962e-13
#   Param 6: Value=0.4882, Grad=-3.0196137978164277
#   Max Abs Grad: 1.283573e+01
# ------------------------------
# --- Epoch 451 / Loss: 1779.919532 ---
#   Param 0: Value=3.3570, Grad=12.835335760864057
#   Param 1: Value=0.7060, Grad=3.102436860411927
#   Param 2: Value=0.6296, Grad=-4.325685266813967
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-1.1368683772161603e-12
#   Param 5: Value=-0.0000, Grad=-5.684341886080802e-14
#   Param 6: Value=0.4882, Grad=-3.0197498587484892
#   Max Abs Grad: 1.283534e+01
# ------------------------------
# --- Epoch 461 / Loss: 1779.919464 ---
#   Param 0: Value=3.3570, Grad=12.835138284126698
#   Param 1: Value=0.7060, Grad=3.102407812024534
#   Param 2: Value=0.6296, Grad=-4.325639367441445
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=1.1937117960769683e-12
#   Param 5: Value=-0.0000, Grad=-3.410605131648481e-13
#   Param 6: Value=0.4882, Grad=-3.0198187557375973
#   Max Abs Grad: 1.283514e+01
# ------------------------------
# --- Epoch 471 / Loss: 1779.919396 ---
#   Param 0: Value=3.3570, Grad=12.834939239923507
#   Param 1: Value=0.7060, Grad=3.1023778471211534
#   Param 2: Value=0.6296, Grad=-4.325593765328378
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=1.1368683772161603e-13
#   Param 5: Value=-0.0000, Grad=-4.547473508864641e-13
#   Param 6: Value=0.4882, Grad=-3.01988844892897
#   Max Abs Grad: 1.283494e+01
# ------------------------------
# --- Epoch 481 / Loss: 1779.919328 ---
#   Param 0: Value=3.3570, Grad=12.834738771434024
#   Param 1: Value=0.7060, Grad=3.102347026326307
#   Param 2: Value=0.6296, Grad=-4.325548437865058
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=3.979039320256561e-13
#   Param 5: Value=-0.0000, Grad=-7.389644451905042e-13
#   Param 6: Value=0.4882, Grad=-3.0199588718487598
#   Max Abs Grad: 1.283474e+01
# ------------------------------
# --- Epoch 491 / Loss: 1779.919294 ---
#   Param 0: Value=3.3570, Grad=12.834637890838145
#   Param 1: Value=0.7060, Grad=3.1023312173106024
#   Param 2: Value=0.6296, Grad=-4.325525900746263
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-5.684341886080801e-13
#   Param 5: Value=-0.0000, Grad=-1.1368683772161603e-13
#   Param 6: Value=0.4882, Grad=-3.0199944171508615
#   Max Abs Grad: 1.283464e+01
# ------------------------------
# --- Epoch 501 / Loss: 1779.919259 ---
#   Param 0: Value=3.3570, Grad=12.834536422880024
#   Param 1: Value=0.7060, Grad=3.10231503807548
#   Param 2: Value=0.6296, Grad=-4.325503480370555
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-1.2505552149377763e-12
#   Param 5: Value=-0.0000, Grad=-1.7053025658242404e-13
#   Param 6: Value=0.4882, Grad=-3.020030267926401
#   Max Abs Grad: 1.283454e+01
# ------------------------------
# --- Epoch 511 / Loss: 1779.919225 ---
#   Param 0: Value=3.3570, Grad=12.83443442227595
#   Param 1: Value=0.7060, Grad=3.1022985157225405
#   Param 2: Value=0.6296, Grad=-4.32548116727381
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-8.526512829121202e-13
#   Param 5: Value=-0.0000, Grad=-3.410605131648481e-13
#   Param 6: Value=0.4883, Grad=-3.020066397708743
#   Max Abs Grad: 1.283443e+01
# ------------------------------
# --- Epoch 521 / Loss: 1779.919208 ---
#   Param 0: Value=3.3570, Grad=12.834383180637863
#   Param 1: Value=0.7060, Grad=3.1022900958712314
#   Param 2: Value=0.6296, Grad=-4.3254700599386675
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=9.094947017729282e-13
#   Param 5: Value=-0.0000, Grad=5.115907697472721e-13
#   Param 6: Value=0.4883, Grad=-3.0200845898606197
#   Max Abs Grad: 1.283438e+01
# ------------------------------
# --- Epoch 531 / Loss: 1779.919190 ---
#   Param 0: Value=3.3570, Grad=12.834331720111594
#   Param 1: Value=0.7060, Grad=3.102281529584383
#   Param 2: Value=0.6296, Grad=-4.325458997750137
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=3.410605131648481e-13
#   Param 5: Value=-0.0000, Grad=-5.115907697472721e-13
#   Param 6: Value=0.4883, Grad=-3.020102898099328
#   Max Abs Grad: 1.283433e+01
# ------------------------------
# --- Epoch 541 / Loss: 1779.919173 ---
#   Param 0: Value=3.3570, Grad=12.834280061332603
#   Param 1: Value=0.7060, Grad=3.102272828385203
#   Param 2: Value=0.6296, Grad=-4.325447976878388
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-1.1368683772161603e-12
#   Param 5: Value=-0.0000, Grad=4.547473508864641e-13
#   Param 6: Value=0.4883, Grad=-3.0201213120934725
#   Max Abs Grad: 1.283428e+01
# ------------------------------
# --- Epoch 551 / Loss: 1779.919164 ---
#   Param 0: Value=3.3570, Grad=12.834254142200237
#   Param 1: Value=0.7060, Grad=3.1022684157382656
#   Param 2: Value=0.6296, Grad=-4.325442485326842
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-1.0231815394945443e-12
#   Param 5: Value=-0.0000, Grad=5.684341886080802e-14
#   Param 6: Value=0.4883, Grad=-3.0201305672201246
#   Max Abs Grad: 1.283425e+01
# ------------------------------
# --- Epoch 561 / Loss: 1779.919156 ---
#   Param 0: Value=3.3570, Grad=12.834228141771886
#   Param 1: Value=0.7060, Grad=3.102263946110597
#   Param 2: Value=0.6296, Grad=-4.325437011033947
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-7.389644451905042e-13
#   Param 5: Value=-0.0000, Grad=7.389644451905042e-13
#   Param 6: Value=0.4883, Grad=-3.0201398661496452
#   Max Abs Grad: 1.283423e+01
# ------------------------------
# --- Epoch 571 / Loss: 1779.919147 ---
#   Param 0: Value=3.3570, Grad=12.834202067764116
#   Param 1: Value=0.7060, Grad=3.1022594242277903
#   Param 2: Value=0.6296, Grad=-4.3254315524868066
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=5.684341886080802e-14
#   Param 5: Value=-0.0000, Grad=9.663381206337363e-13
#   Param 6: Value=0.4883, Grad=-3.0201492049075527
#   Max Abs Grad: 1.283420e+01
# ------------------------------
# --- Epoch 581 / Loss: 1779.919142 ---
#   Param 0: Value=3.3570, Grad=12.834188997470394
#   Param 1: Value=0.7060, Grad=3.1022571393543457
#   Param 2: Value=0.6296, Grad=-4.325428830390287
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-1.4210854715202004e-12
#   Param 5: Value=-0.0000, Grad=-6.821210263296962e-13
#   Param 6: Value=0.4883, Grad=-3.0201538923823716
#   Max Abs Grad: 1.283419e+01
# ------------------------------
# --- Epoch 591 / Loss: 1779.919138 ---
#   Param 0: Value=3.3570, Grad=12.834175897043915
#   Param 1: Value=0.7060, Grad=3.1022548325868824
#   Param 2: Value=0.6296, Grad=-4.325426114834925
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=0.0
#   Param 5: Value=-0.0000, Grad=3.979039320256561e-13
#   Param 6: Value=0.4883, Grad=-3.0201585962982587
#   Max Abs Grad: 1.283418e+01
# ------------------------------
# --- Epoch 601 / Loss: 1779.919134 ---
#   Param 0: Value=3.3570, Grad=12.834162769353929
#   Param 1: Value=0.7060, Grad=3.1022525058108177
#   Param 2: Value=0.6296, Grad=-4.3254234052336304
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.410605131648481e-13
#   Param 5: Value=-0.0000, Grad=0.0
#   Param 6: Value=0.4883, Grad=-3.0201633151427623
#   Max Abs Grad: 1.283416e+01
# ------------------------------
# --- Epoch 611 / Loss: 1779.919131 ---
#   Param 0: Value=3.3570, Grad=12.834156193178194
#   Param 1: Value=0.7060, Grad=3.10225133328875
#   Param 2: Value=0.6296, Grad=-4.325422053141242
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=1.1937117960769683e-12
#   Param 5: Value=-0.0000, Grad=-9.663381206337363e-13
#   Param 6: Value=0.4883, Grad=-3.0201656813392863
#   Max Abs Grad: 1.283416e+01
# ------------------------------
# --- Epoch 621 / Loss: 1779.919129 ---
#   Param 0: Value=3.3570, Grad=12.83414960584564
#   Param 1: Value=0.7060, Grad=3.1022501524344297
#   Param 2: Value=0.6296, Grad=-4.3254207035123775
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-1.1368683772161603e-13
#   Param 5: Value=-0.0000, Grad=-1.7053025658242404e-13
#   Param 6: Value=0.4883, Grad=-3.0201680536830158
#   Max Abs Grad: 1.283415e+01
# ------------------------------
# --- Epoch 631 / Loss: 1779.919127 ---
#   Param 0: Value=3.3570, Grad=12.834143008421421
#   Param 1: Value=0.7060, Grad=3.102248963985079
#   Param 2: Value=0.6296, Grad=-4.325419356121708
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-6.252776074688882e-13
#   Param 5: Value=-0.0000, Grad=-5.684341886080801e-13
#   Param 6: Value=0.4883, Grad=-3.0201704316024283
#   Max Abs Grad: 1.283414e+01
# ------------------------------
# --- Epoch 641 / Loss: 1779.919126 ---
#   Param 0: Value=3.3570, Grad=12.834139705145388
#   Param 1: Value=0.7060, Grad=3.1022483663018154
#   Param 2: Value=0.6296, Grad=-4.325418683443012
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-9.094947017729282e-13
#   Param 5: Value=-0.0000, Grad=1.1937117960769683e-12
#   Param 6: Value=0.4883, Grad=-3.020171623090037
#   Max Abs Grad: 1.283414e+01
# ------------------------------
# --- Epoch 651 / Loss: 1779.919125 ---
#   Param 0: Value=3.3570, Grad=12.834136397741634
#   Param 1: Value=0.7060, Grad=3.1022477654708562
#   Param 2: Value=0.6296, Grad=-4.325418011687653
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-7.389644451905042e-13
#   Param 5: Value=-0.0000, Grad=0.0
#   Param 6: Value=0.4883, Grad=-3.0201728168693487
#   Max Abs Grad: 1.283414e+01
# ------------------------------
# --- Epoch 661 / Loss: 1779.919124 ---
#   Param 0: Value=3.3570, Grad=12.83413308660409
#   Param 1: Value=0.7060, Grad=3.102247161775646
#   Param 2: Value=0.6296, Grad=-4.325417340769997
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-1.1937117960769683e-12
#   Param 5: Value=-0.0000, Grad=0.0
#   Param 6: Value=0.4883, Grad=-3.020174012725804
#   Max Abs Grad: 1.283413e+01
# ------------------------------
# --- Epoch 671 / Loss: 1779.919123 ---
#   Param 0: Value=3.3570, Grad=12.834131429346957
#   Param 1: Value=0.7060, Grad=3.102246858625881
#   Param 2: Value=0.6296, Grad=-4.325417005691806
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-6.252776074688882e-13
#   Param 5: Value=-0.0000, Grad=1.3642420526593924e-12
#   Param 6: Value=0.4883, Grad=-3.0201746115951478
#   Max Abs Grad: 1.283413e+01
# ------------------------------
# --- Epoch 681 / Loss: 1779.919123 ---
#   Param 0: Value=3.3570, Grad=12.834129770562589
#   Param 1: Value=0.7060, Grad=3.1022465542935937
#   Param 2: Value=0.6296, Grad=-4.325416670957953
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=1.4210854715202004e-12
#   Param 5: Value=-0.0000, Grad=9.663381206337363e-13
#   Param 6: Value=0.4883, Grad=-3.0201752113171816
#   Max Abs Grad: 1.283413e+01
# ------------------------------
# --- Epoch 691 / Loss: 1779.919122 ---
#   Param 0: Value=3.3570, Grad=12.834128110398154
#   Param 1: Value=0.7060, Grad=3.102246248886987
#   Param 2: Value=0.6296, Grad=-4.325416336536694
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=2.8421709430404007e-13
#   Param 5: Value=-0.0000, Grad=-7.958078640513122e-13
#   Param 6: Value=0.4883, Grad=-3.02017581181118
#   Max Abs Grad: 1.283413e+01
# ------------------------------
# --- Epoch 701 / Loss: 1779.919122 ---
#   Param 0: Value=3.3570, Grad=12.83412727969121
#   Param 1: Value=0.7060, Grad=3.1022460956959312
#   Param 2: Value=0.6296, Grad=-4.325416169467844
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=1.1368683772161603e-13
#   Param 5: Value=-0.0000, Grad=0.0
#   Param 6: Value=0.4883, Grad=-3.0201761124079307
#   Max Abs Grad: 1.283413e+01
# ------------------------------
# --- Epoch 711 / Loss: 1779.919122 ---
#   Param 0: Value=3.3570, Grad=12.834126448418697
#   Param 1: Value=0.7060, Grad=3.1022459420619874
#   Param 2: Value=0.6296, Grad=-4.325416002527742
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-2.2737367544323206e-13
#   Param 5: Value=-0.0000, Grad=-8.526512829121202e-13
#   Param 6: Value=0.4883, Grad=-3.020176413321768
#   Max Abs Grad: 1.283413e+01
# ------------------------------
# --- Epoch 721 / Loss: 1779.919121 ---
#   Param 0: Value=3.3570, Grad=12.834125616636323
#   Param 1: Value=0.7060, Grad=3.102245788026399
#   Param 2: Value=0.6296, Grad=-4.325415835703753
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=6.252776074688882e-13
#   Param 5: Value=-0.0000, Grad=1.4779288903810084e-12
#   Param 6: Value=0.4883, Grad=-3.0201767145220937
#   Max Abs Grad: 1.283413e+01
# ------------------------------
# --- Epoch 731 / Loss: 1779.919121 ---
#   Param 0: Value=3.3570, Grad=12.834125200513826
#   Param 1: Value=0.7060, Grad=3.10224571082669
#   Param 2: Value=0.6296, Grad=-4.32541575234451
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-6.821210263296962e-13
#   Param 5: Value=-0.0000, Grad=-1.3642420526593924e-12
#   Param 6: Value=0.4883, Grad=-3.0201768652522176
#   Max Abs Grad: 1.283413e+01
# ------------------------------
# --- Epoch 741 / Loss: 1779.919121 ---
#   Param 0: Value=3.3570, Grad=12.834124784182574
#   Param 1: Value=0.7060, Grad=3.1022456334612287
#   Param 2: Value=0.6296, Grad=-4.325415669032991
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-7.389644451905042e-13
#   Param 5: Value=-0.0000, Grad=-3.410605131648481e-13
#   Param 6: Value=0.4883, Grad=-3.0201770160998165
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 751 / Loss: 1779.919121 ---
#   Param 0: Value=3.3570, Grad=12.834124367663254
#   Param 1: Value=0.7060, Grad=3.102245555946519
#   Param 2: Value=0.6296, Grad=-4.325415585764982
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=5.684341886080802e-14
#   Param 5: Value=-0.0000, Grad=8.526512829121202e-13
#   Param 6: Value=0.4883, Grad=-3.0201771670534545
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 761 / Loss: 1779.919121 ---
#   Param 0: Value=3.3570, Grad=12.834124159318407
#   Param 1: Value=0.7060, Grad=3.1022455171205143
#   Param 2: Value=0.6296, Grad=-4.32541554415036
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=6.252776074688882e-13
#   Param 5: Value=-0.0000, Grad=2.8421709430404007e-13
#   Param 6: Value=0.4883, Grad=-3.020177242578275
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 771 / Loss: 1779.919121 ---
#   Param 0: Value=3.3570, Grad=12.83412395089467
#   Param 1: Value=0.7060, Grad=3.102245478234196
#   Param 2: Value=0.6296, Grad=-4.325415502553644
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=7.389644451905042e-13
#   Param 5: Value=-0.0000, Grad=1.3073986337985843e-12
#   Param 6: Value=0.4883, Grad=-3.0201773181472866
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 781 / Loss: 1779.919121 ---
#   Param 0: Value=3.3570, Grad=12.834123742402133
#   Param 1: Value=0.7060, Grad=3.1022454392916647
#   Param 2: Value=0.6296, Grad=-4.325415460972894
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=1.1937117960769683e-12
#   Param 5: Value=-0.0000, Grad=5.684341886080802e-14
#   Param 6: Value=0.4883, Grad=-3.0201773937553353
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 791 / Loss: 1779.919121 ---
#   Param 0: Value=3.3570, Grad=12.834123638124618
#   Param 1: Value=0.7060, Grad=3.1022454197950893
#   Param 2: Value=0.6296, Grad=-4.325415440189885
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.979039320256561e-13
#   Param 5: Value=-0.0000, Grad=-9.094947017729282e-13
#   Param 6: Value=0.4883, Grad=-3.02017743157713
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 801 / Loss: 1779.919121 ---
#   Param 0: Value=3.3570, Grad=12.834123533818465
#   Param 1: Value=0.7060, Grad=3.102245400275262
#   Param 2: Value=0.6296, Grad=-4.325415419413453
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=1.4779288903810084e-12
#   Param 5: Value=-0.0000, Grad=4.547473508864641e-13
#   Param 6: Value=0.4883, Grad=-3.020177469415109
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 811 / Loss: 1779.919121 ---
#   Param 0: Value=3.3570, Grad=12.834123429485945
#   Param 1: Value=0.7060, Grad=3.102245380735739
#   Param 2: Value=0.6296, Grad=-4.325415398642817
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-5.684341886080801e-13
#   Param 5: Value=-0.0000, Grad=5.684341886080801e-13
#   Param 6: Value=0.4883, Grad=-3.0201775072678876
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 821 / Loss: 1779.919120 ---
#   Param 0: Value=3.3570, Grad=12.834123377307773
#   Param 1: Value=0.7060, Grad=3.1022453709564237
#   Param 2: Value=0.6296, Grad=-4.325415388260076
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=1.9895196601282805e-12
#   Param 5: Value=-0.0000, Grad=3.979039320256561e-13
#   Param 6: Value=0.4883, Grad=-3.020177526200844
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 831 / Loss: 1779.919120 ---
#   Param 0: Value=3.3570, Grad=12.834123325119648
#   Param 1: Value=0.7060, Grad=3.102245361168455
#   Param 2: Value=0.6296, Grad=-4.325415377879966
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-6.821210263296962e-13
#   Param 5: Value=-0.0000, Grad=-1.7053025658242404e-12
#   Param 6: Value=0.4883, Grad=-3.0201775451396933
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 841 / Loss: 1779.919120 ---
#   Param 0: Value=3.3570, Grad=12.834123272922016
#   Param 1: Value=0.7060, Grad=3.102245351372822
#   Param 2: Value=0.6296, Grad=-4.32541536750217
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=8.526512829121202e-13
#   Param 5: Value=-0.0000, Grad=-1.1368683772161603e-13
#   Param 6: Value=0.4883, Grad=-3.020177564083889
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 851 / Loss: 1779.919120 ---
#   Param 0: Value=3.3570, Grad=12.834123246819017
#   Param 1: Value=0.7060, Grad=3.102245346471839
#   Param 2: Value=0.6296, Grad=-4.325415362313996
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=1.0800249583553523e-12
#   Param 5: Value=-0.0000, Grad=-1.1368683772161603e-13
#   Param 6: Value=0.4883, Grad=-3.0201775735583936
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 861 / Loss: 1779.919120 ---
#   Param 0: Value=3.3570, Grad=12.834123220712005
#   Param 1: Value=0.7060, Grad=3.102245341566898
#   Param 2: Value=0.6296, Grad=-4.3254153571269836
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-5.115907697472721e-13
#   Param 5: Value=-0.0000, Grad=-6.252776074688882e-13
#   Param 6: Value=0.4883, Grad=-3.0201775830351782
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 871 / Loss: 1779.919120 ---
#   Param 0: Value=3.3570, Grad=12.834123194601247
#   Param 1: Value=0.7060, Grad=3.1022453366597404
#   Param 2: Value=0.6296, Grad=-4.325415351940649
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=9.663381206337363e-13
#   Param 5: Value=-0.0000, Grad=5.684341886080802e-14
#   Param 6: Value=0.4883, Grad=-3.0201775925139933
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 881 / Loss: 1779.919120 ---
#   Param 0: Value=3.3570, Grad=12.834123181544644
#   Param 1: Value=0.7060, Grad=3.1022453342050538
#   Param 2: Value=0.6296, Grad=-4.325415349347434
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=9.663381206337363e-13
#   Param 5: Value=-0.0000, Grad=2.2737367544323206e-13
#   Param 6: Value=0.4883, Grad=-3.0201775972541567
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 891 / Loss: 1779.919120 ---
#   Param 0: Value=3.3570, Grad=12.834123168485345
#   Param 1: Value=0.7060, Grad=3.1022453317492964
#   Param 2: Value=0.6296, Grad=-4.325415346755591
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-2.0463630789890885e-12
#   Param 5: Value=-0.0000, Grad=4.547473508864641e-13
#   Param 6: Value=0.4883, Grad=-3.0201776019954716
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 901 / Loss: 1779.919120 ---
#   Param 0: Value=3.3570, Grad=12.83412315542602
#   Param 1: Value=0.7060, Grad=3.1022453292921734
#   Param 2: Value=0.6296, Grad=-4.325415344163231
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-1.6484591469634324e-12
#   Param 5: Value=-0.0000, Grad=-2.2737367544323206e-13
#   Param 6: Value=0.4883, Grad=-3.0201776067373216
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 911 / Loss: 1779.919120 ---
#   Param 0: Value=3.3570, Grad=12.834123148895493
#   Param 1: Value=0.7060, Grad=3.102245328062905
#   Param 2: Value=0.6296, Grad=-4.32541534286737
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-2.2737367544323206e-13
#   Param 5: Value=-0.0000, Grad=-5.115907697472721e-13
#   Param 6: Value=0.4883, Grad=-3.020177609108664
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 921 / Loss: 1779.919120 ---
#   Param 0: Value=3.3570, Grad=12.834123142364739
#   Param 1: Value=0.7060, Grad=3.1022453268334473
#   Param 2: Value=0.6296, Grad=-4.325415341571748
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=1.3073986337985843e-12
#   Param 5: Value=-0.0000, Grad=-6.821210263296962e-13
#   Param 6: Value=0.4883, Grad=-3.0201776114801486
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 931 / Loss: 1779.919120 ---
#   Param 0: Value=3.3570, Grad=12.8341231358324
#   Param 1: Value=0.7060, Grad=3.1022453256035636
#   Param 2: Value=0.6296, Grad=-4.325415340276295
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-1.5347723092418164e-12
#   Param 5: Value=-0.0000, Grad=-1.4779288903810084e-12
#   Param 6: Value=0.4883, Grad=-3.0201776138522125
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 941 / Loss: 1779.919120 ---
#   Param 0: Value=3.3570, Grad=12.83412313256691
#   Param 1: Value=0.7060, Grad=3.102245324988562
#   Param 2: Value=0.6296, Grad=-4.325415339628283
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=0.0
#   Param 5: Value=-0.0000, Grad=5.684341886080801e-13
#   Param 6: Value=0.4883, Grad=-3.020177615038177
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 951 / Loss: 1779.919120 ---
#   Param 0: Value=3.3570, Grad=12.83412312930077
#   Param 1: Value=0.7060, Grad=3.1022453243734964
#   Param 2: Value=0.6296, Grad=-4.325415338980558
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-5.684341886080802e-14
#   Param 5: Value=-0.0000, Grad=1.2505552149377763e-12
#   Param 6: Value=0.4883, Grad=-3.020177616224309
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 961 / Loss: 1779.919120 ---
#   Param 0: Value=3.3570, Grad=12.834123126034791
#   Param 1: Value=0.7060, Grad=3.1022453237576233
#   Param 2: Value=0.6296, Grad=-4.325415338332791
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=3.979039320256561e-13
#   Param 5: Value=-0.0000, Grad=-7.958078640513122e-13
#   Param 6: Value=0.4883, Grad=-3.020177617410469
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 971 / Loss: 1779.919120 ---
#   Param 0: Value=3.3570, Grad=12.834123124400806
#   Param 1: Value=0.7060, Grad=3.1022453234500245
#   Param 2: Value=0.6296, Grad=-4.325415338009086
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=2.8421709430404007e-13
#   Param 5: Value=-0.0000, Grad=-5.684341886080802e-14
#   Param 6: Value=0.4883, Grad=-3.020177618003857
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 981 / Loss: 1779.919120 ---
#   Param 0: Value=3.3570, Grad=12.834123122768144
#   Param 1: Value=0.7060, Grad=3.1022453231419242
#   Param 2: Value=0.6296, Grad=-4.325415337685416
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=6.252776074688882e-13
#   Param 5: Value=-0.0000, Grad=-8.526512829121202e-13
#   Param 6: Value=0.4883, Grad=-3.020177618596864
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# --- Epoch 991 / Loss: 1779.919120 ---
#   Param 0: Value=3.3570, Grad=12.834123121135102
#   Param 1: Value=0.7060, Grad=3.102245322834114
#   Param 2: Value=0.6296, Grad=-4.325415337361284
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-1.0800249583553523e-12
#   Param 5: Value=-0.0000, Grad=1.1368683772161603e-13
#   Param 6: Value=0.4883, Grad=-3.0201776191900436
#   Max Abs Grad: 1.283412e+01
# ------------------------------
# FINAL STATE: Epoch 1000, Loss: 1779.9191204075962,
#  vecc Parameters: [3.3570243666454123, 0.7059960074175937, 0.6296135066755064, -inf, -9.65072669686697e-07, -2.9337593169557848e-06, 0.48825588183811414]
# Day 1 optimization finished in 41.44s over 1000 epochs.
# Day 1 final results: [3.3570243666454123, 0.7059960074175937, 0.6296135066755064, -inf, -9.65072669686697e-07, -2.9337593169557848e-06, 0.48825588183811414, 1779.9191204075962]

# %%
a = [3.3570243666454123, 0.7059960074175937, 0.6296135066755064, 0, -9.65072669686697e-07, -2.9337593169557848e-06, 0.48825588183811414 ]

def cal(a):
    day_indices = [0] 
    for day_idx in day_indices:  

        daily_hourly_map = daily_hourly_maps[day_idx]
        daily_aggregated_tensor = daily_aggregated_tensors[day_idx]


        # Initial parameters (full vector 'a' is for reference)

        # NEW: Define params as a list of 1-element tensors (one per parameter)
        params_list = [
            torch.tensor([val], dtype=torch.float64, requires_grad=True) for val in a
        ]

        model_instance = kernels_new.fit_vecchia_adams(
                smooth = v,
                input_map = daily_hourly_map,        # 💥 FIX: Use correct loop variable
                aggregated_data = daily_aggregated_tensor, # 💥 FIX: Use correct loop variable
                nns_map = nns_map,
                mm_cond_number = mm_cond_number,
                nheads = nheads
            )
        
        bb= model_instance.full_likelihood( params_list, daily_aggregated_tensor,daily_aggregated_tensor[:,2], model_instance.matern_cov_aniso_STABLE_log_reparam)
        return bb

cal(a)
# Out:
# tensor(1779.9191, dtype=torch.float64, grad_fn=<MulBackward0>)

# %% [markdown]
# # LBFGS

# %%
from kernels_new import fit_vecchia_lbfgs 


max_lbfgs_steps = 50 # Max steps for the L-BFGS optimizer
device = 'cuda' if torch.cuda.is_available() else 'cpu'


# --- 2. Run optimization loop over pre-loaded data ---
day_indices = [0] 
for day_idx in day_indices:  

    daily_hourly_map = daily_hourly_maps[day_idx]
    daily_aggregated_tensor = daily_aggregated_tensors[day_idx]

    # --- Correct Parameter Initialization ---
    # ... (Parameter initialization code remains the same) ...
    init_sigmasq   = 30.0
    init_range_lat = 0.66 
    init_range_lon = 0.7 
    init_advec_lat = 0
    init_advec_lon = 0
    init_beta      = 0
    init_nugget    = 1.5
    
    init_phi2 = 1.0 / init_range_lon
    init_phi1 = init_sigmasq * init_phi2
    init_phi3 = (init_range_lon / init_range_lat)**2
    init_phi4 = init_beta**2
    
    device_str = 'cuda' if torch.cuda.is_available() else 'cpu'

    params_list = [
        torch.tensor([np.log(init_phi1)],      requires_grad=True, dtype=torch.float64, device=device_str ),
        torch.tensor([np.log(init_phi2)],      requires_grad=True, dtype=torch.float64, device=device_str ),
        torch.tensor([np.log(init_phi3)],      requires_grad=True, dtype=torch.float64, device=device_str ),
        torch.tensor([np.log(init_phi4)],      requires_grad=True, dtype=torch.float64, device=device_str ),
        torch.tensor([init_advec_lat],         requires_grad=True, dtype=torch.float64, device=device_str ),
        torch.tensor([init_advec_lon],         requires_grad=True, dtype=torch.float64, device=device_str ),
        torch.tensor([np.log(init_nugget)],    requires_grad=True, dtype=torch.float64, device=device_str )
    ]

    # --- 💥 FIX: Define a SINGLE parameter group for L-BFGS ---
    # L-BFGS does not support per-parameter options or different LRs.
    # Pass all parameters in one list.
    param_groups = [{'params': params_list}]
    # --- End Fix ---

    # --- Print Job Info ---
    res_calc = (113 // lat_lon_resolution[0]) * (158 // lat_lon_resolution[0]) 
    print(f'\n--- Starting Day {day_idx+1} (2024-07-{day_idx+1}) ---')
    print(f'Data size per day: { res_calc }, smooth: {v}')
    print(f'mm_cond_number: {mm_cond_number},\ninitial parameters: \n {params_list}')
            
    # --- 1. Instantiate the L-BFGS Class ---
    model_instance = kernels_new.fit_vecchia_lbfgs(
            smooth = v,
            input_map = daily_hourly_map,
            aggregated_data = daily_aggregated_tensor, 
            nns_map = nns_map,
            mm_cond_number = mm_cond_number,
            nheads = nheads
        )

    start_time = time.time()
    
    # --- 2. Call the L-BFGS Optimizer Method ---
    # The 'param_groups' variable now correctly contains only one group.
    optimizer = model_instance.set_optimizer(
            param_groups,     
            lr=1.0,            # Standard initial step length for L-BFGS
            max_iter=10,       # Line search iterations per step
            tolerance_grad=1e-4
        )

    # --- 3. Call the L-BFGS Fit Method ---
    out, steps_ran = model_instance.fit_vecc_lbfgs(
            params_list,
            optimizer,
            model_instance.matern_cov_aniso_STABLE_log_reparam, # Pass the *actual* method
            max_steps=max_lbfgs_steps
        )

    end_time = time.time()
    epoch_time = end_time - start_time
    
    # --- 4. Updated Print Statement ---
    print(f"Day {day_idx+1} optimization finished in {epoch_time:.2f}s over {steps_ran+1} steps.")
    print(f"Day {day_idx+1} final results: {out}")
# Out:
# /var/folders/9p/53hd4c7d2fl193h4jwp194wc0000gn/T/ipykernel_20699/3953601393.py:36: RuntimeWarning: divide by zero encountered in log
#   torch.tensor([np.log(init_phi4)],      requires_grad=True, dtype=torch.float64, device=device_str ),
# --- Starting Day 1 (2024-07-1) ---
# Data size per day: 1092, smooth: 0.5
# mm_cond_number: 20,
# initial parameters:
#  [tensor([3.7579], dtype=torch.float64, requires_grad=True), tensor([0.3567], dtype=torch.float64, requires_grad=True), tensor([0.1177], dtype=torch.float64, requires_grad=True), tensor([-inf], dtype=torch.float64, requires_grad=True), tensor([0.], dtype=torch.float64, requires_grad=True), tensor([0.], dtype=torch.float64, requires_grad=True), tensor([0.4055], dtype=torch.float64, requires_grad=True)]
# --- Starting L-BFGS Optimization ---
# --- Step 1/50 / Loss: 2203.453133 ---
#   Param 0: Value=2.3953, Grad=29.797448955188386
#   Param 1: Value=-1.1863, Grad=6.795424181454637
#   Param 2: Value=-0.2210, Grad=13.80491538480854
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=4.3834380569762743e-13
#   Param 5: Value=0.0000, Grad=4.4221570849600766e-13
#   Param 6: Value=1.5276, Grad=-4.824017268116008
#   Max Abs Grad: 2.979745e+01
# ------------------------------
# --- Step 2/50 / Loss: 1999.779320 ---
#   Param 0: Value=1.2974, Grad=-1.2427750920893712
#   Param 1: Value=-2.4871, Grad=1.9007826234724141
#   Param 2: Value=-2.6373, Grad=-0.14034528285359782
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=5.559788740505667e-14
#   Param 5: Value=0.0000, Grad=1.1714240688576183e-13
#   Param 6: Value=2.1928, Grad=2.742704648704188
#   Max Abs Grad: 2.742705e+00
# ------------------------------
# --- Step 3/50 / Loss: 1983.872995 ---
#   Param 0: Value=1.0485, Grad=0.2461001490471757
#   Param 1: Value=-4.6050, Grad=0.06132709611900857
#   Param 2: Value=-3.4234, Grad=-0.011363356503614959
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=2.160771561676711e-14
#   Param 5: Value=0.0000, Grad=-4.583833312921115e-14
#   Param 6: Value=2.2582, Grad=0.4244705750498227
#   Max Abs Grad: 4.244706e-01
# ------------------------------
# --- Step 4/50 / Loss: 1983.170238 ---
#   Param 0: Value=0.7352, Grad=7.430949223990321
#   Param 1: Value=-8.6239, Grad=-0.9737233728798649
#   Param 2: Value=-4.4073, Grad=-0.43420288365983895
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=3.616898447411643e-15
#   Param 5: Value=0.0000, Grad=-1.2147921557570385e-13
#   Param 6: Value=2.3033, Grad=-2.2558084514262484
#   Max Abs Grad: 7.430949e+00
# ------------------------------
# --- Step 5/50 / Loss: 1976.683477 ---
#   Param 0: Value=0.5771, Grad=0.2228300600084595
#   Param 1: Value=-8.6959, Grad=-0.012453687517534895
#   Param 2: Value=-3.8574, Grad=0.004451562791697412
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=4.2500725161431774e-17
#   Param 5: Value=0.0000, Grad=-3.614469834545275e-14
#   Param 6: Value=2.3066, Grad=-3.7664732577735514
#   Max Abs Grad: 3.766473e+00
# ------------------------------
# --- Step 6/50 / Loss: 1976.108940 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 7/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 8/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 9/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 10/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 11/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 12/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 13/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 14/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 15/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 16/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 17/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 18/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 19/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 20/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 21/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 22/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 23/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 24/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 25/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 26/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 27/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 28/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 29/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 30/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 31/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 32/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 33/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 34/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 35/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 36/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 37/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 38/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 39/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 40/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 41/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 42/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 43/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 44/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 45/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 46/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 47/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 48/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 49/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# --- Step 50/50 / Loss: 1976.090422 ---
#   Param 0: Value=0.5519, Grad=-1.0715848755005197e-05
#   Param 1: Value=-8.7258, Grad=1.6001072269608563e-07
#   Param 2: Value=-3.9542, Grad=6.483631545552669e-07
#   Param 3: Value=-inf, Grad=0.0
#   Param 4: Value=-0.0000, Grad=-3.3072503069497827e-15
#   Param 5: Value=0.0000, Grad=-1.453420717112408e-13
#   Param 6: Value=2.3156, Grad=-3.824161518228841e-06
#   Max Abs Grad: 1.071585e-05
# ------------------------------
# FINAL STATE: Step 50, Loss: 1976.090421982742
#   Raw (vecc) Parameters: [0.551873128756271, -8.725799865516372, -3.9541904920273176, -inf, -1.7373916527110193e-12, 1.435265126041059e-12, 2.3155991513089855]
#   Interpretable Parameters:
#     sigma_sq  : 10696.512089
#     range_lon : 6159.801707
#     range_lat : 44484.456346
#     beta      : 0.000000
#     advec_lat : -0.000000
#     advec_lon : 0.000000
#     nugget    : 10.130991
# Day 1 optimization finished in 47.69s over 50 steps.
# Day 1 final results: [0.551873128756271, -8.725799865516372, -3.9541904920273176, -inf, -1.7373916527110193e-12, 1.435265126041059e-12, 2.3155991513089855, 1976.090421982742]

# %%
a = [53.56, 17.09, 8.19, 0, 0, 0, 6.08]

# %% [markdown]
# # fix time only

# %% [markdown]
# adam

# %%
import torch
import numpy as np
import time
# (Import your fit_vecchia_adams class and other dependencies here)
# from kernels_new import fit_vecchia_adams 

# --- 1. Load Data (Assumed to be done) ---
# daily_hourly_maps = ...
# daily_aggregated_tensors = ...
# nns_map = ...
# v, mm_cond_number, nheads = 0.5, 20, 10
# lat_lon_resolution = [1.0, 1.0] # Example
# lr, step, gamma_par, epochs = 0.01, 40, 0.5, 100 # Example
# device = 'cuda' if torch.cuda.is_available() else 'cpu'


nheads=300
# --- 2. Run optimization loop over pre-loaded data ---
day_indices = [0] 
for day_idx in day_indices:  

    daily_hourly_map = daily_hourly_maps[day_idx]
    daily_aggregated_tensor = daily_aggregated_tensors[day_idx]

    # --- Correct Parameter Initialization ---
    init_sigmasq   = 25
    init_range_lat = 0.66 
    init_range_lon = 0.7 
    init_advec_lat = 0  # Will be fixed
    init_advec_lon = 0      # Will be fixed
    init_beta      = 0      # Will be fixed
    init_nugget    = 1.5
    
    # Map model parameters to the 'phi' reparameterization
    init_phi2 = 1.0 / init_range_lon                # [1] phi2 = 1 / range_lon
    init_phi1 = init_sigmasq * init_phi2            # [0] phi1 = sigmasq * phi2 = sigmasq / range_lon
    init_phi3 = (init_range_lon / init_range_lat)**2  # [2] phi3 = (range_lon / range_lat)^2
    
    # 💥 FIX: Add epsilon to prevent log(0) since init_beta is 0
    init_phi4 = init_beta**2 # + 1e-9                 # [3] phi4 = beta^2
    
    device_str = 'cuda' if torch.cuda.is_available() else 'cpu'

    # 💥 FIX: Set requires_grad=False for fixed temporal parameters
    params_list = [
        # --- Spatial & Nugget Parameters (Optimized) ---
        torch.tensor([np.log(init_phi1)],      requires_grad=True,  dtype=torch.float64, device=device_str ), # [0] log(phi1)
        torch.tensor([np.log(init_phi2)],      requires_grad=True,  dtype=torch.float64, device=device_str ), # [1] log(phi2)
        torch.tensor([np.log(init_phi3)],      requires_grad=True,  dtype=torch.float64, device=device_str ), # [2] log(phi3)
        
        # --- Temporal Parameters (Fixed) ---
        torch.tensor([np.log(init_phi4)],      requires_grad=False, dtype=torch.float64, device=device_str ), # [3] log(phi4)
        torch.tensor([init_advec_lat],         requires_grad=False, dtype=torch.float64, device=device_str ), # [4] advec_lat (linear)
        torch.tensor([init_advec_lon],         requires_grad=False, dtype=torch.float64, device=device_str ), # [5] advec_lon (linear)
        
        # --- Spatial & Nugget Parameters (Optimized) ---
        torch.tensor([np.log(init_nugget)],    requires_grad=True,  dtype=torch.float64, device=device_str )  # [6] log(nugget)
    ]

    # --- 💥 FIX: Define parameter groups for *optimizable* parameters only ---
    lr_slow, lr_fast = 0.005, 0.02
    
    # These are the indices of the parameters we still want to optimize
    fast_indices = [0, 1, 2, 6] 
    
    param_groups = [
        # The 'slow_group' is removed as it only contained fixed parameters
        {'params': [params_list[idx] for idx in fast_indices], 'lr': lr_fast, 'name': 'fast_group'}
    ]
    # --- End Fix ---

    # --- Print Job Info ---
    res_calc = (113 // lat_lon_resolution[0]) * (158 // lat_lon_resolution[0]) 
    print(f'\n--- Starting Day {day_idx+1} (2024-07-{day_idx+1}) ---')
    print(f'Data size per day: { res_calc }, smooth: {v}')
    print(f'mm_cond_number: {mm_cond_number},\ninitial parameters: \n {params_list}')
            
    # --- Instantiate the Correct Class ---
    model_instance = kernels_new.fit_vecchia_adams(
            smooth = v,
            input_map = daily_hourly_map,
            aggregated_data = daily_aggregated_tensor,
            nns_map = nns_map,
            mm_cond_number = mm_cond_number,
            nheads = nheads
        )

    start_time = time.time()
    
    # --- Call the Correct Optimizer Method ---
    # 'param_groups' now correctly contains only the 4 optimizable parameters
    optimizer, scheduler = model_instance.set_optimizer(
            param_groups,     
            lr=lr,            
            betas=(0.9, 0.99), 
            eps=1e-8, 
            step_size=step, 
            gamma=gamma_par
        )

    # --- Call the Correct Fit Method ---
    # We still pass the *full* params_list, as the NLL function
    # needs all 7 values (even the fixed ones).
    out, epoch_ran = model_instance.fit_vecc_scheduler_oct23(
            params_list,
            optimizer,
            scheduler, 
            model_instance.matern_cov_aniso_STABLE_log_reparam, 
            epochs=epochs
        )

    end_time = time.time()
    epoch_time = end_time - start_time
    
    print(f"Day {day_idx+1} optimization finished in {epoch_time:.2f}s over {epoch_ran+1} epochs.")
    print(f"Day {day_idx+1} final results: {out}")

    # --- 💥 START: Print Original Parameter Values 💥 ---
    
    # 'out' is the list returned from the fit function: [raw_param_0, ..., raw_param_6, final_loss]
    # We extract just the raw parameters by slicing off the last element (the loss).
    final_raw_params_list = out[:-1] 
    
    # Use the helper function to convert them
    interpretable_params = model_instance._convert_raw_params_to_interpretable(final_raw_params_list)
    
    # Print the raw list first
    print(f"Day {day_idx+1} final raw results (params + loss): {out}")
    
    # Pretty-print the interpretable dictionary
    print(f"Day {day_idx+1} final interpretable parameters:")
    if interpretable_params:
        for key, val in interpretable_params.items():
            # The :10s aligns the keys for readability
            print(f'    {key:10s}: {val:.6f}')
    # --- 💥 END 💥 ---
# Out:
# /var/folders/9p/53hd4c7d2fl193h4jwp194wc0000gn/T/ipykernel_23845/1091173347.py:52: RuntimeWarning: divide by zero encountered in log
#   torch.tensor([np.log(init_phi4)],      requires_grad=False, dtype=torch.float64, device=device_str ), # [3] log(phi4)
# --- Starting Day 1 (2024-07-1) ---
# Data size per day: 1092, smooth: 0.5
# mm_cond_number: 20,
# initial parameters:
#  [tensor([3.5756], dtype=torch.float64, requires_grad=True), tensor([0.3567], dtype=torch.float64, requires_grad=True), tensor([0.1177], dtype=torch.float64, requires_grad=True), tensor([-inf], dtype=torch.float64), tensor([0.], dtype=torch.float64), tensor([0.], dtype=torch.float64), tensor([0.4055], dtype=torch.float64, requires_grad=True)]
# --- Epoch 1 / Loss: 1955.397753 ---
#   Param 0: Value=3.5756, Grad=194.8455366654497
#   Param 1: Value=0.3567, Grad=-146.05639413948617
#   Param 2: Value=0.1177, Grad=5.137603578596103
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.4055, Grad=16.35748364033666
#   Max Abs Grad: 1.948455e+02
# ------------------------------
# --- Epoch 11 / Loss: 1900.151211 ---
#   Param 0: Value=3.3803, Grad=95.30642370266075
#   Param 1: Value=0.5542, Grad=-94.57488273295881
#   Param 2: Value=0.0576, Grad=-8.01682905585453
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2146, Grad=4.339629401741366
#   Max Abs Grad: 9.530642e+01
# ------------------------------
# --- Epoch 21 / Loss: 1881.000849 ---
#   Param 0: Value=3.2249, Grad=-3.6373999487618858
#   Param 1: Value=0.7250, Grad=-12.296770584624067
#   Param 2: Value=0.2441, Grad=-10.998836667876272
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.1024, Grad=-5.380984717810574
#   Max Abs Grad: 1.229677e+01
# ------------------------------
# --- Epoch 31 / Loss: 1880.795514 ---
#   Param 0: Value=3.1724, Grad=-40.16492653292797
#   Param 1: Value=0.8033, Grad=35.06699292252887
#   Param 2: Value=0.4566, Grad=-5.965977437271262
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.1575, Grad=-7.53406085563968
#   Max Abs Grad: 4.016493e+01
# ------------------------------
# --- Epoch 41 / Loss: 1879.087170 ---
#   Param 0: Value=3.1905, Grad=-20.656585276207203
#   Param 1: Value=0.7907, Grad=23.11355473913789
#   Param 2: Value=0.5448, Grad=-2.983070772401659
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2284, Grad=-3.826421450053777
#   Max Abs Grad: 2.311355e+01
# ------------------------------
# --- Epoch 51 / Loss: 1878.290636 ---
#   Param 0: Value=3.2137, Grad=2.918098526201604
#   Param 1: Value=0.7643, Grad=4.697726611906434
#   Param 2: Value=0.6054, Grad=-0.9748525208846258
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2878, Grad=0.15222826730181963
#   Max Abs Grad: 4.697727e+00
# ------------------------------
# --- Epoch 61 / Loss: 1878.321066 ---
#   Param 0: Value=3.2196, Grad=12.133857884566716
#   Param 1: Value=0.7488, Grad=-2.887084877017361
#   Param 2: Value=0.6391, Grad=-0.20406990899928423
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.3090, Grad=1.6924886372610997
#   Max Abs Grad: 1.213386e+01
# ------------------------------
# --- Epoch 71 / Loss: 1878.256048 ---
#   Param 0: Value=3.2144, Grad=10.346187873244576
#   Param 1: Value=0.7473, Grad=-1.6348788814621509
#   Param 2: Value=0.6472, Grad=-0.2574254194166634
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.3038, Grad=1.403946474871732
#   Max Abs Grad: 1.034619e+01
# ------------------------------
# --- Epoch 81 / Loss: 1878.175167 ---
#   Param 0: Value=3.2063, Grad=6.412961941528776
#   Param 1: Value=0.7476, Grad=1.2693562345031244
#   Param 2: Value=0.6521, Grad=-0.4661590170837312
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2932, Grad=0.7565932834334439
#   Max Abs Grad: 6.412962e+00
# ------------------------------
# --- Epoch 91 / Loss: 1878.130370 ---
#   Param 0: Value=3.1991, Grad=3.306404339795245
#   Param 1: Value=0.7466, Grad=3.416955971084168
#   Param 2: Value=0.6574, Grad=-0.6493333459798576
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2841, Grad=0.22956663240026154
#   Max Abs Grad: 3.416956e+00
# ------------------------------
# --- Epoch 101 / Loss: 1878.114128 ---
#   Param 0: Value=3.1965, Grad=2.61864538482795
#   Param 1: Value=0.7450, Grad=3.754824078814001
#   Param 2: Value=0.6609, Grad=-0.6975575892830106
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2814, Grad=0.0993807960645068
#   Max Abs Grad: 3.754824e+00
# ------------------------------
# --- Epoch 111 / Loss: 1878.097387 ---
#   Param 0: Value=3.1945, Grad=2.4897748817681378
#   Param 1: Value=0.7427, Grad=3.623403655004802
#   Param 2: Value=0.6650, Grad=-0.714285881173777
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2800, Grad=0.0563111510820299
#   Max Abs Grad: 3.623404e+00
# ------------------------------
# --- Epoch 121 / Loss: 1878.080198 ---
#   Param 0: Value=3.1926, Grad=2.5958166099328315
#   Param 1: Value=0.7401, Grad=3.3002742961810116
#   Param 2: Value=0.6698, Grad=-0.713643211564175
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2792, Grad=0.05140460836481467
#   Max Abs Grad: 3.300274e+00
# ------------------------------
# --- Epoch 131 / Loss: 1878.071494 ---
#   Param 0: Value=3.1917, Grad=2.6686559034986024
#   Param 1: Value=0.7387, Grad=3.12567283951358
#   Param 2: Value=0.6724, Grad=-0.7092078025178989
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2789, Grad=0.05319813506477254
#   Max Abs Grad: 3.125673e+00
# ------------------------------
# --- Epoch 141 / Loss: 1878.062589 ---
#   Param 0: Value=3.1907, Grad=2.727306490511271
#   Param 1: Value=0.7373, Grad=2.9641699250390303
#   Param 2: Value=0.6751, Grad=-0.703011425185966
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2787, Grad=0.05363962091858457
#   Max Abs Grad: 2.964170e+00
# ------------------------------
# --- Epoch 151 / Loss: 1878.053465 ---
#   Param 0: Value=3.1896, Grad=2.761398970088566
#   Param 1: Value=0.7359, Grad=2.8230243443083047
#   Param 2: Value=0.6781, Grad=-0.6959695701880869
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2785, Grad=0.05089782793790383
#   Max Abs Grad: 2.823024e+00
# ------------------------------
# --- Epoch 161 / Loss: 1878.048764 ---
#   Param 0: Value=3.1890, Grad=2.7662682899273405
#   Param 1: Value=0.7352, Grad=2.762091804409382
#   Param 2: Value=0.6796, Grad=-0.6921529297591372
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2783, Grad=0.04787892699829804
#   Max Abs Grad: 2.766268e+00
# ------------------------------
# --- Epoch 171 / Loss: 1878.043881 ---
#   Param 0: Value=3.1884, Grad=2.762627859539631
#   Param 1: Value=0.7344, Grad=2.706885693438158
#   Param 2: Value=0.6812, Grad=-0.6880620031977428
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2782, Grad=0.043644536484336985
#   Max Abs Grad: 2.762628e+00
# ------------------------------
# --- Epoch 181 / Loss: 1878.038810 ---
#   Param 0: Value=3.1877, Grad=2.752870080436017
#   Param 1: Value=0.7337, Grad=2.6549531386419076
#   Param 2: Value=0.6829, Grad=-0.6836738557759696
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2781, Grad=0.03849202494426404
#   Max Abs Grad: 2.752870e+00
# ------------------------------
# --- Epoch 191 / Loss: 1878.036170 ---
#   Param 0: Value=3.1874, Grad=2.745648400795367
#   Param 1: Value=0.7333, Grad=2.629889830707413
#   Param 2: Value=0.6838, Grad=-0.6813213793721513
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2780, Grad=0.035548468415185025
#   Max Abs Grad: 2.745648e+00
# ------------------------------
# --- Epoch 201 / Loss: 1878.033413 ---
#   Param 0: Value=3.1870, Grad=2.7367158077941323
#   Param 1: Value=0.7329, Grad=2.6049493208841588
#   Param 2: Value=0.6848, Grad=-0.6788228822630995
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2780, Grad=0.03230079195283889
#   Max Abs Grad: 2.736716e+00
# ------------------------------
# --- Epoch 211 / Loss: 1878.030533 ---
#   Param 0: Value=3.1866, Grad=2.7263705657140807
#   Param 1: Value=0.7324, Grad=2.579730350026905
#   Param 2: Value=0.6858, Grad=-0.676183142849954
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2779, Grad=0.028775270560484126
#   Max Abs Grad: 2.726371e+00
# ------------------------------
# --- Epoch 221 / Loss: 1878.029028 ---
#   Param 0: Value=3.1864, Grad=2.720559401116016
#   Param 1: Value=0.7322, Grad=2.5668693071712974
#   Param 2: Value=0.6863, Grad=-0.6747952863612237
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2779, Grad=0.02687794283490399
#   Max Abs Grad: 2.720559e+00
# ------------------------------
# --- Epoch 231 / Loss: 1878.027451 ---
#   Param 0: Value=3.1862, Grad=2.714166691691904
#   Param 1: Value=0.7320, Grad=2.5536098211834126
#   Param 2: Value=0.6868, Grad=-0.6733499763716339
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2779, Grad=0.024842733605118426
#   Max Abs Grad: 2.714167e+00
# ------------------------------
# --- Epoch 241 / Loss: 1878.025801 ---
#   Param 0: Value=3.1859, Grad=2.7072036913217485
#   Param 1: Value=0.7317, Grad=2.5398709912872652
#   Param 2: Value=0.6874, Grad=-0.6718540671905393
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2779, Grad=0.02266296594240968
#   Max Abs Grad: 2.707204e+00
# ------------------------------
# --- Epoch 251 / Loss: 1878.024937 ---
#   Param 0: Value=3.1858, Grad=2.7034327611214946
#   Param 1: Value=0.7316, Grad=2.532734490876927
#   Param 2: Value=0.6877, Grad=-0.6710841808424738
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2779, Grad=0.021496799423030958
#   Max Abs Grad: 2.703433e+00
# ------------------------------
# --- Epoch 261 / Loss: 1878.024031 ---
#   Param 0: Value=3.1857, Grad=2.699367310289277
#   Param 1: Value=0.7314, Grad=2.525287721510168
#   Param 2: Value=0.6880, Grad=-0.6702988456552972
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.020247874946458782
#   Max Abs Grad: 2.699367e+00
# ------------------------------
# --- Epoch 271 / Loss: 1878.023082 ---
#   Param 0: Value=3.1856, Grad=2.6949942427904783
#   Param 1: Value=0.7313, Grad=2.5175023495868567
#   Param 2: Value=0.6884, Grad=-0.6695033817214092
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.018909494662655013
#   Max Abs Grad: 2.694994e+00
# ------------------------------
# --- Epoch 281 / Loss: 1878.022585 ---
#   Param 0: Value=3.1855, Grad=2.6926455158170577
#   Param 1: Value=0.7312, Grad=2.513428719078659
#   Param 2: Value=0.6885, Grad=-0.6691033706186551
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.018192119801886286
#   Max Abs Grad: 2.692646e+00
# ------------------------------
# --- Epoch 291 / Loss: 1878.022064 ---
#   Param 0: Value=3.1854, Grad=2.6901252015854276
#   Param 1: Value=0.7311, Grad=2.509156977414344
#   Param 2: Value=0.6887, Grad=-0.6687052570600762
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.017422000573098968
#   Max Abs Grad: 2.690125e+00
# ------------------------------
# --- Epoch 301 / Loss: 1878.021518 ---
#   Param 0: Value=3.1853, Grad=2.6874219397562986
#   Param 1: Value=0.7311, Grad=2.5046739415641377
#   Param 2: Value=0.6889, Grad=-0.6683129522163959
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.01659453676079074
#   Max Abs Grad: 2.687422e+00
# ------------------------------
# --- Epoch 311 / Loss: 1878.021232 ---
#   Param 0: Value=3.1853, Grad=2.68597254993605
#   Param 1: Value=0.7310, Grad=2.5023207680859483
#   Param 2: Value=0.6890, Grad=-0.668121801691963
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.01614974844374025
#   Max Abs Grad: 2.685973e+00
# ------------------------------
# --- Epoch 321 / Loss: 1878.020933 ---
#   Param 0: Value=3.1852, Grad=2.6844182812220763
#   Param 1: Value=0.7310, Grad=2.499848105947981
#   Param 2: Value=0.6891, Grad=-0.667938396439276
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.015670997054043644
#   Max Abs Grad: 2.684418e+00
# ------------------------------
# --- Epoch 331 / Loss: 1878.020620 ---
#   Param 0: Value=3.1852, Grad=2.6827513783033856
#   Param 1: Value=0.7309, Grad=2.4972492718600394
#   Param 2: Value=0.6892, Grad=-0.6677654667497134
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.015155331770103617
#   Max Abs Grad: 2.682751e+00
# ------------------------------
# --- Epoch 341 / Loss: 1878.020456 ---
#   Param 0: Value=3.1852, Grad=2.6818574553316106
#   Param 1: Value=0.7309, Grad=2.4958835804438104
#   Param 2: Value=0.6892, Grad=-0.6676857037507067
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.01487750518104098
#   Max Abs Grad: 2.681857e+00
# ------------------------------
# --- Epoch 351 / Loss: 1878.020285 ---
#   Param 0: Value=3.1852, Grad=2.680898394439258
#   Param 1: Value=0.7309, Grad=2.494447857519558
#   Param 2: Value=0.6893, Grad=-0.6676144031576374
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.0145779047334052
#   Max Abs Grad: 2.680898e+00
# ------------------------------
# --- Epoch 361 / Loss: 1878.020106 ---
#   Param 0: Value=3.1851, Grad=2.679869283167411
#   Param 1: Value=0.7308, Grad=2.492938707551062
#   Param 2: Value=0.6894, Grad=-0.6675533558894238
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.014254717653252546
#   Max Abs Grad: 2.679869e+00
# ------------------------------
# --- Epoch 371 / Loss: 1878.020013 ---
#   Param 0: Value=3.1851, Grad=2.6793171111184577
#   Param 1: Value=0.7308, Grad=2.4921457796420086
#   Param 2: Value=0.6894, Grad=-0.6675289081432471
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.01408038971773411
#   Max Abs Grad: 2.679317e+00
# ------------------------------
# --- Epoch 381 / Loss: 1878.019915 ---
#   Param 0: Value=3.1851, Grad=2.678724464341946
#   Param 1: Value=0.7308, Grad=2.4913127101162758
#   Param 2: Value=0.6894, Grad=-0.667511613818773
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.013892280132437342
#   Max Abs Grad: 2.678724e+00
# ------------------------------
# --- Epoch 391 / Loss: 1878.019813 ---
#   Param 0: Value=3.1851, Grad=2.6780883862686093
#   Param 1: Value=0.7308, Grad=2.4904378505150087
#   Param 2: Value=0.6894, Grad=-0.6675025699873179
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.01368932653071555
#   Max Abs Grad: 2.678088e+00
# ------------------------------
# --- Epoch 401 / Loss: 1878.019760 ---
#   Param 0: Value=3.1851, Grad=2.677747093175928
#   Param 1: Value=0.7308, Grad=2.489978739511211
#   Param 2: Value=0.6895, Grad=-0.667502744356576
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.01357988207204382
#   Max Abs Grad: 2.677747e+00
# ------------------------------
# --- Epoch 411 / Loss: 1878.019705 ---
#   Param 0: Value=3.1851, Grad=2.677380886367741
#   Param 1: Value=0.7308, Grad=2.489497145132597
#   Param 2: Value=0.6895, Grad=-0.6675082348913202
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.013461883240269201
#   Max Abs Grad: 2.677381e+00
# ------------------------------
# --- Epoch 421 / Loss: 1878.019647 ---
#   Param 0: Value=3.1851, Grad=2.6769880741046848
#   Param 1: Value=0.7308, Grad=2.4889923385492922
#   Param 2: Value=0.6895, Grad=-0.6675196654861818
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.013334741420086917
#   Max Abs Grad: 2.676988e+00
# ------------------------------
# --- Epoch 431 / Loss: 1878.019617 ---
#   Param 0: Value=3.1851, Grad=2.6767774985906714
#   Param 1: Value=0.7308, Grad=2.4887279950610353
#   Param 2: Value=0.6895, Grad=-0.6675286681933207
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.01326630177251054
#   Max Abs Grad: 2.676777e+00
# ------------------------------
# --- Epoch 441 / Loss: 1878.019586 ---
#   Param 0: Value=3.1850, Grad=2.67655184136278
#   Param 1: Value=0.7308, Grad=2.488451396204793
#   Param 2: Value=0.6895, Grad=-0.6675412895747151
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.013192684025682144
#   Max Abs Grad: 2.676552e+00
# ------------------------------
# --- Epoch 451 / Loss: 1878.019554 ---
#   Param 0: Value=3.1850, Grad=2.676310187800101
#   Param 1: Value=0.7308, Grad=2.48816227274495
#   Param 2: Value=0.6895, Grad=-0.6675578563349909
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.013113583408928875
#   Max Abs Grad: 2.676310e+00
# ------------------------------
# --- Epoch 461 / Loss: 1878.019537 ---
#   Param 0: Value=3.1850, Grad=2.6761809032076638
#   Param 1: Value=0.7307, Grad=2.4880113368346906
#   Param 2: Value=0.6895, Grad=-0.667568273998999
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.013071141306235719
#   Max Abs Grad: 2.676181e+00
# ------------------------------
# --- Epoch 471 / Loss: 1878.019519 ---
#   Param 0: Value=3.1850, Grad=2.6760426899904806
#   Param 1: Value=0.7307, Grad=2.487853936164922
#   Param 2: Value=0.6895, Grad=-0.6675809881691261
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.01302565621323443
#   Max Abs Grad: 2.676043e+00
# ------------------------------
# --- Epoch 481 / Loss: 1878.019501 ---
#   Param 0: Value=3.1850, Grad=2.6758950860763107
#   Param 1: Value=0.7307, Grad=2.4876900092890906
#   Param 2: Value=0.6895, Grad=-0.6675961542527356
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012976983089830009
#   Max Abs Grad: 2.675895e+00
# ------------------------------
# --- Epoch 491 / Loss: 1878.019492 ---
#   Param 0: Value=3.1850, Grad=2.675816362375462
#   Param 1: Value=0.7307, Grad=2.4876047669235404
#   Param 2: Value=0.6895, Grad=-0.6676050374087955
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012950983227401194
#   Max Abs Grad: 2.675816e+00
# ------------------------------
# --- Epoch 501 / Loss: 1878.019482 ---
#   Param 0: Value=3.1850, Grad=2.6757324923507286
#   Param 1: Value=0.7307, Grad=2.487516244963686
#   Param 2: Value=0.6895, Grad=-0.6676152919146715
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.01292325320535459
#   Max Abs Grad: 2.675732e+00
# ------------------------------
# --- Epoch 511 / Loss: 1878.019472 ---
#   Param 0: Value=3.1850, Grad=2.675643262206407
#   Param 1: Value=0.7307, Grad=2.4874244595043358
#   Param 2: Value=0.6895, Grad=-0.667626983152196
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012893731434507765
#   Max Abs Grad: 2.675643e+00
# ------------------------------
# --- Epoch 521 / Loss: 1878.019467 ---
#   Param 0: Value=3.1850, Grad=2.6755958659577272
#   Param 1: Value=0.7307, Grad=2.4873769515516626
#   Param 2: Value=0.6895, Grad=-0.6676335768052485
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012878046653943973
#   Max Abs Grad: 2.675596e+00
# ------------------------------
# --- Epoch 531 / Loss: 1878.019462 ---
#   Param 0: Value=3.1850, Grad=2.675545592486995
#   Param 1: Value=0.7307, Grad=2.4873278534919523
#   Param 2: Value=0.6895, Grad=-0.6676409452576032
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012861412514689474
#   Max Abs Grad: 2.675546e+00
# ------------------------------
# --- Epoch 541 / Loss: 1878.019456 ---
#   Param 0: Value=3.1850, Grad=2.675492354596661
#   Param 1: Value=0.7307, Grad=2.487277198851063
#   Param 2: Value=0.6896, Grad=-0.667649111388901
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012843807191031807
#   Max Abs Grad: 2.675492e+00
# ------------------------------
# --- Epoch 551 / Loss: 1878.019453 ---
#   Param 0: Value=3.1850, Grad=2.6754642145254803
#   Param 1: Value=0.7307, Grad=2.4872511141032327
#   Param 2: Value=0.6896, Grad=-0.6676536027389666
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.01283450989666918
#   Max Abs Grad: 2.675464e+00
# ------------------------------
# --- Epoch 561 / Loss: 1878.019450 ---
#   Param 0: Value=3.1850, Grad=2.675434518891559
#   Param 1: Value=0.7307, Grad=2.487224296742115
#   Param 2: Value=0.6896, Grad=-0.6676585099220755
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.01282471071881824
#   Max Abs Grad: 2.675435e+00
# ------------------------------
# --- Epoch 571 / Loss: 1878.019447 ---
#   Param 0: Value=3.1850, Grad=2.67540323921609
#   Param 1: Value=0.7307, Grad=2.4871967751408883
#   Param 2: Value=0.6896, Grad=-0.6676638382700146
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012814404558917445
#   Max Abs Grad: 2.675403e+00
# ------------------------------
# --- Epoch 581 / Loss: 1878.019446 ---
#   Param 0: Value=3.1850, Grad=2.6753867961628304
#   Param 1: Value=0.7307, Grad=2.4871826780024944
#   Param 2: Value=0.6896, Grad=-0.6676667146050906
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012808996506411017
#   Max Abs Grad: 2.675387e+00
# ------------------------------
# --- Epoch 591 / Loss: 1878.019444 ---
#   Param 0: Value=3.1850, Grad=2.67536954162547
#   Param 1: Value=0.7307, Grad=2.487168261780247
#   Param 2: Value=0.6896, Grad=-0.667669803660836
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012803333017328826
#   Max Abs Grad: 2.675370e+00
# ------------------------------
# --- Epoch 601 / Loss: 1878.019443 ---
#   Param 0: Value=3.1850, Grad=2.67535147076315
#   Param 1: Value=0.7307, Grad=2.487153544838022
#   Param 2: Value=0.6896, Grad=-0.6676731049136189
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.01279741473005198
#   Max Abs Grad: 2.675351e+00
# ------------------------------
# --- Epoch 611 / Loss: 1878.019442 ---
#   Param 0: Value=3.1850, Grad=2.6753420264441257
#   Param 1: Value=0.7307, Grad=2.4871460455904844
#   Param 2: Value=0.6896, Grad=-0.6676748608754316
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.01279432903442176
#   Max Abs Grad: 2.675342e+00
# ------------------------------
# --- Epoch 621 / Loss: 1878.019441 ---
#   Param 0: Value=3.1850, Grad=2.6753321740368237
#   Param 1: Value=0.7307, Grad=2.487138415597907
#   Param 2: Value=0.6896, Grad=-0.6676767209407868
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.01279111811626581
#   Max Abs Grad: 2.675332e+00
# ------------------------------
# --- Epoch 631 / Loss: 1878.019440 ---
#   Param 0: Value=3.1850, Grad=2.675321916046638
#   Param 1: Value=0.7307, Grad=2.4871306650270815
#   Param 2: Value=0.6896, Grad=-0.6676786834210146
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012787783792770829
#   Max Abs Grad: 2.675322e+00
# ------------------------------
# --- Epoch 641 / Loss: 1878.019440 ---
#   Param 0: Value=3.1850, Grad=2.6753165863159474
#   Param 1: Value=0.7307, Grad=2.4871267344946304
#   Param 2: Value=0.6896, Grad=-0.6676797148408239
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012786056057863066
#   Max Abs Grad: 2.675317e+00
# ------------------------------
# --- Epoch 651 / Loss: 1878.019439 ---
#   Param 0: Value=3.1850, Grad=2.675311058562291
#   Param 1: Value=0.7307, Grad=2.4871227538868856
#   Param 2: Value=0.6896, Grad=-0.6676807952168504
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012784269072657839
#   Max Abs Grad: 2.675311e+00
# ------------------------------
# --- Epoch 661 / Loss: 1878.019439 ---
#   Param 0: Value=3.1850, Grad=2.6753053362382744
#   Param 1: Value=0.7307, Grad=2.487118728127741
#   Param 2: Value=0.6896, Grad=-0.6676819231860651
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012782424335589338
#   Max Abs Grad: 2.675305e+00
# ------------------------------
# --- Epoch 671 / Loss: 1878.019439 ---
#   Param 0: Value=3.1850, Grad=2.6753023797838322
#   Param 1: Value=0.7307, Grad=2.4871166951672286
#   Param 2: Value=0.6896, Grad=-0.6676825102155483
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.01278147391643462
#   Max Abs Grad: 2.675302e+00
# ------------------------------
# --- Epoch 681 / Loss: 1878.019438 ---
#   Param 0: Value=3.1850, Grad=2.6752993303214865
#   Param 1: Value=0.7307, Grad=2.487114644430232
#   Param 2: Value=0.6896, Grad=-0.6676831195053246
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012780496329484116
#   Max Abs Grad: 2.675299e+00
# ------------------------------
# --- Epoch 691 / Loss: 1878.019438 ---
#   Param 0: Value=3.1850, Grad=2.6752961903242287
#   Param 1: Value=0.7307, Grad=2.4871125782043597
#   Param 2: Value=0.6896, Grad=-0.6676837502228143
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012779492504700129
#   Max Abs Grad: 2.675296e+00
# ------------------------------
# --- Epoch 701 / Loss: 1878.019438 ---
#   Param 0: Value=3.1850, Grad=2.6752945763771576
#   Param 1: Value=0.7307, Grad=2.487111538462864
#   Param 2: Value=0.6896, Grad=-0.6676840758564502
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012778977957044899
#   Max Abs Grad: 2.675295e+00
# ------------------------------
# --- Epoch 711 / Loss: 1878.019438 ---
#   Param 0: Value=3.1850, Grad=2.6752929198935935
#   Param 1: Value=0.7307, Grad=2.487110493050829
#   Param 2: Value=0.6896, Grad=-0.6676844113450485
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012778451264563527
#   Max Abs Grad: 2.675293e+00
# ------------------------------
# --- Epoch 721 / Loss: 1878.019438 ---
#   Param 0: Value=3.1850, Grad=2.6752912222682514
#   Param 1: Value=0.7307, Grad=2.4871094430347886
#   Param 2: Value=0.6896, Grad=-0.6676847562361061
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012777912924397117
#   Max Abs Grad: 2.675291e+00
# ------------------------------
# --- Epoch 731 / Loss: 1878.019438 ---
#   Param 0: Value=3.1850, Grad=2.675290353636055
#   Param 1: Value=0.7307, Grad=2.4871089161105346
#   Param 2: Value=0.6896, Grad=-0.6676849331803577
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012777638176188502
#   Max Abs Grad: 2.675290e+00
# ------------------------------
# --- Epoch 741 / Loss: 1878.019438 ---
#   Param 0: Value=3.1850, Grad=2.675289465874976
#   Param 1: Value=0.7307, Grad=2.4871083877663223
#   Param 2: Value=0.6896, Grad=-0.6676851143977641
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.01277735809293212
#   Max Abs Grad: 2.675289e+00
# ------------------------------
# --- Epoch 751 / Loss: 1878.019438 ---
#   Param 0: Value=3.1850, Grad=2.675288559717038
#   Param 1: Value=0.7307, Grad=2.487107858365256
#   Param 2: Value=0.6896, Grad=-0.6676852996875653
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012777072909880803
#   Max Abs Grad: 2.675289e+00
# ------------------------------
# --- Epoch 761 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.675288097789304
#   Param 1: Value=0.7307, Grad=2.4871075933264475
#   Param 2: Value=0.6896, Grad=-0.6676853942720822
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.01277692788486744
#   Max Abs Grad: 2.675288e+00
# ------------------------------
# --- Epoch 771 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.675287627333638
#   Param 1: Value=0.7307, Grad=2.487107328138129
#   Param 2: Value=0.6896, Grad=-0.6676854906952416
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012776780531264718
#   Max Abs Grad: 2.675288e+00
# ------------------------------
# --- Epoch 781 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.67528714869764
#   Param 1: Value=0.7307, Grad=2.4871070629176963
#   Param 2: Value=0.6896, Grad=-0.6676855888805531
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.01277663095829587
#   Max Abs Grad: 2.675287e+00
# ------------------------------
# --- Epoch 791 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.6752869054285715
#   Param 1: Value=0.7307, Grad=2.4871069303986664
#   Param 2: Value=0.6896, Grad=-0.667685638804781
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012776555108496533
#   Max Abs Grad: 2.675287e+00
# ------------------------------
# --- Epoch 801 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.675286658344115
#   Param 1: Value=0.7307, Grad=2.4871067980245685
#   Param 2: Value=0.6896, Grad=-0.6676856895282668
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012776478240405294
#   Max Abs Grad: 2.675287e+00
# ------------------------------
# --- Epoch 811 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.6752864075872784
#   Param 1: Value=0.7307, Grad=2.4871066658586476
#   Param 2: Value=0.6896, Grad=-0.6676857410166591
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012776400397751079
#   Max Abs Grad: 2.675286e+00
# ------------------------------
# --- Epoch 821 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.6752862804225734
#   Param 1: Value=0.7307, Grad=2.487106599930713
#   Param 2: Value=0.6896, Grad=-0.6676857671215163
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012776361006730325
#   Max Abs Grad: 2.675286e+00
# ------------------------------
# --- Epoch 831 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.6752861515321498
#   Param 1: Value=0.7307, Grad=2.487106534156652
#   Param 2: Value=0.6896, Grad=-0.6676857935786109
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012776321163364544
#   Max Abs Grad: 2.675286e+00
# ------------------------------
# --- Epoch 841 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.6752860209549456
#   Param 1: Value=0.7307, Grad=2.4871064686004036
#   Param 2: Value=0.6896, Grad=-0.6676858203662972
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012776280885618718
#   Max Abs Grad: 2.675286e+00
# ------------------------------
# --- Epoch 851 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.6752859548590395
#   Param 1: Value=0.7307, Grad=2.487106435915883
#   Param 2: Value=0.6896, Grad=-0.6676858339273877
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012776260536157349
#   Max Abs Grad: 2.675286e+00
# ------------------------------
# --- Epoch 861 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.6752858879417327
#   Param 1: Value=0.7307, Grad=2.4871064033793076
#   Param 2: Value=0.6896, Grad=-0.6676858476411726
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012776239978863728
#   Max Abs Grad: 2.675286e+00
# ------------------------------
# --- Epoch 871 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.675285820241325
#   Param 1: Value=0.7307, Grad=2.487106370987363
#   Param 2: Value=0.6896, Grad=-0.6676858615060165
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012776219223258122
#   Max Abs Grad: 2.675286e+00
# ------------------------------
# --- Epoch 881 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.675285785998878
#   Param 1: Value=0.7307, Grad=2.487106354862628
#   Param 2: Value=0.6896, Grad=-0.6676858685168285
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012776208745861963
#   Max Abs Grad: 2.675286e+00
# ------------------------------
# --- Epoch 891 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.6752857513756196
#   Param 1: Value=0.7307, Grad=2.4871063388304706
#   Param 2: Value=0.6896, Grad=-0.6676858755937372
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012776198173678279
#   Max Abs Grad: 2.675286e+00
# ------------------------------
# --- Epoch 901 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.6752857163744266
#   Param 1: Value=0.7307, Grad=2.4871063228681396
#   Param 2: Value=0.6896, Grad=-0.6676858827475423
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.01277618750597604
#   Max Abs Grad: 2.675286e+00
# ------------------------------
# --- Epoch 911 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.675285698673053
#   Param 1: Value=0.7307, Grad=2.4871063149467303
#   Param 2: Value=0.6896, Grad=-0.6676858863588571
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012776182124019618
#   Max Abs Grad: 2.675286e+00
# ------------------------------
# --- Epoch 921 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.67528568078061
#   Param 1: Value=0.7307, Grad=2.4871063070840274
#   Param 2: Value=0.6896, Grad=-0.667685890002857
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012776176695456862
#   Max Abs Grad: 2.675286e+00
# ------------------------------
# --- Epoch 931 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.675285662711491
#   Param 1: Value=0.7307, Grad=2.487106299260965
#   Param 2: Value=0.6896, Grad=-0.667685893683819
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.01277617122249895
#   Max Abs Grad: 2.675286e+00
# ------------------------------
# --- Epoch 941 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.6752856535784124
#   Param 1: Value=0.7307, Grad=2.4871062953719907
#   Param 2: Value=0.6896, Grad=-0.6676858955424465
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012776168461426447
#   Max Abs Grad: 2.675286e+00
# ------------------------------
# --- Epoch 951 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.675285644344104
#   Param 1: Value=0.7307, Grad=2.487106291527258
#   Param 2: Value=0.6896, Grad=-0.6676858974161136
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012776165676880537
#   Max Abs Grad: 2.675286e+00
# ------------------------------
# --- Epoch 961 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.675285635018428
#   Param 1: Value=0.7307, Grad=2.4871062876998984
#   Param 2: Value=0.6896, Grad=-0.6676858993096064
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012776162870119654
#   Max Abs Grad: 2.675286e+00
# ------------------------------
# --- Epoch 971 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.675285630296288
#   Param 1: Value=0.7307, Grad=2.4871062858271684
#   Param 2: Value=0.6896, Grad=-0.6676859002615723
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012776161454226193
#   Max Abs Grad: 2.675286e+00
# ------------------------------
# --- Epoch 981 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.675285625525347
#   Param 1: Value=0.7307, Grad=2.487106283956928
#   Param 2: Value=0.6896, Grad=-0.6676859012259344
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012776160025582451
#   Max Abs Grad: 2.675286e+00
# ------------------------------
# --- Epoch 991 / Loss: 1878.019437 ---
#   Param 0: Value=3.1850, Grad=2.675285620721538
#   Param 1: Value=0.7307, Grad=2.4871062820743326
#   Param 2: Value=0.6896, Grad=-0.6676859021999936
#   Param 3: Value=-inf, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.2778, Grad=0.012776158586616088
#   Max Abs Grad: 2.675286e+00
# ------------------------------
# FINAL STATE: Epoch 1000, Loss: 1878.0194373226614,
#  vecc Parameters: [3.1850261248518965, 0.7307329198588871, 0.6895547147699365, -inf, 0.0, 0.0, 0.27780223854803404]
# Day 1 optimization finished in 491.25s over 1000 epochs.
# Day 1 final results: [3.1850261248518965, 0.7307329198588871, 0.6895547147699365, -inf, 0.0, 0.0, 0.27780223854803404, 1878.0194373226614]
# Day 1 final raw results (params + loss): [3.1850261248518965, 0.7307329198588871, 0.6895547147699365, -inf, 0.0, 0.0, 0.27780223854803404, 1878.0194373226614]
# Day 1 final interpretable parameters:
#     sigma_sq  : 11.638205
#     range_lon : 0.481556
#     range_lat : 0.341124
#     beta      : 0.000000
#     advec_lat : 0.000000
#     advec_lon : 0.000000
#     nugget    : 1.320225

# %%
from kernels_new import fit_vecchia_lbfgs 
import numpy as np # Make sure numpy is imported
import torch # Make sure torch is imported

max_lbfgs_steps = 10 # Max steps for the L-BFGS optimizer
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# (Assuming other variables like lat_lon_resolution, v, mm_cond_number, nheads are defined)

# --- 2. Run optimization loop over pre-loaded data ---
day_indices = [0] 
for day_idx in day_indices:  

    daily_hourly_map = daily_hourly_maps[day_idx]
    daily_aggregated_tensor = daily_aggregated_tensors[day_idx]

    # --- Correct Parameter Initialization ---
    init_sigmasq   = 30.0
    init_range_lat = 1
    init_range_lon = 1.5 
    init_advec_lat = 0.0 # Will be fixed
    init_advec_lon = 0.0 # Will be fixed
    init_beta      = 0.0 # Will be fixed
    init_nugget    = 1.5
    
    init_phi2 = 1.0 / init_range_lon
    init_phi1 = init_sigmasq * init_phi2
    init_phi3 = (init_range_lon / init_range_lat)**2
    
    # 💥 1. Add epsilon to prevent log(0) when init_beta is 0
    init_phi4 = init_beta**2 + 1e-9 
    
    device_str = 'cuda' if torch.cuda.is_available() else 'cpu'

    # 💥 2. Fix temporal parameters by setting requires_grad=False
    params_list = [
        # --- Spatial Parameters (Optimized) ---
        torch.tensor([np.log(init_phi1)],      requires_grad=True,  dtype=torch.float64, device=device_str ), # [0] log(phi1)
        torch.tensor([np.log(init_phi2)],      requires_grad=True,  dtype=torch.float64, device=device_str ), # [1] log(phi2)
        torch.tensor([np.log(init_phi3)],      requires_grad=True,  dtype=torch.float64, device=device_str ), # [2] log(phi3)
        
        # --- Temporal Parameters (Fixed) ---
        torch.tensor([np.log(init_phi4)],      requires_grad=False, dtype=torch.float64, device=device_str ), # [3] log(phi4)
        torch.tensor([init_advec_lat],         requires_grad=False, dtype=torch.float64, device=device_str ), # [4] advec_lat
        torch.tensor([init_advec_lon],         requires_grad=False, dtype=torch.float64, device=device_str ), # [5] advec_lon
        
        # --- Nugget (Optimized) ---
        torch.tensor([np.log(init_nugget)],    requires_grad=True,  dtype=torch.float64, device=device_str )  # [6] log(nugget)
    ]

    # --- 💥 3. Create a list of *only* the parameters to be optimized ---
    params_to_optimize = [p for p in params_list if p.requires_grad]
    
    # Pass only the optimizable parameters to L-BFGS
    param_groups = [{'params': params_to_optimize}]
    # --- End Fix ---

    # --- Print Job Info ---
    res_calc = (113 // lat_lon_resolution[0]) * (158 // lat_lon_resolution[0]) 
    print(f'\n--- Starting Day {day_idx+1} (2024-07-{day_idx+1}) ---')
    print(f'Data size per day: { res_calc }, smooth: {v}')
    print(f'mm_cond_number: {mm_cond_number},\ninitial parameters: \n {params_list}')
            
    # --- 1. Instantiate the L-BFGS Class ---
    model_instance = kernels_new.fit_vecchia_lbfgs(
            smooth = v,
            input_map = daily_hourly_map,
            aggregated_data = daily_aggregated_tensor, 
            nns_map = nns_map,
            mm_cond_number = mm_cond_number,
            nheads = nheads
        )

    start_time = time.time()
    
    # --- 2. Call the L-BFGS Optimizer Method ---
    # The 'param_groups' variable now correctly contains only the 4 active parameters.
    optimizer = model_instance.set_optimizer(
            param_groups,     
            lr=1.0,            # Standard initial step length for L-BFGS
            max_iter=10,       # Line search iterations per step
            tolerance_grad=1e-4
        )

    # --- 3. Call the L-BFGS Fit Method ---
    # We still pass the *full* params_list here, because the NLL function
    # (matern_cov_aniso_STABLE_log_reparam) needs all 7 values.
    out, steps_ran = model_instance.fit_vecc_lbfgs(
            params_list,
            optimizer,
            model_instance.matern_cov_aniso_STABLE_log_reparam, # Pass the *actual* method
            max_steps=max_lbfgs_steps
        )

    end_time = time.time()
    epoch_time = end_time - start_time
    
    # --- 4. Updated Print Statement ---
    print(f"Day {day_idx+1} optimization finished in {epoch_time:.2f}s over {steps_ran+1} steps.")
    print(f"Day {day_idx+1} final results: {out}")
# Out:
# --- Starting Day 1 (2024-07-1) ---
# Data size per day: 1092, smooth: 0.5
# mm_cond_number: 20,
# initial parameters:
#  [tensor([2.9957], dtype=torch.float64, requires_grad=True), tensor([-0.4055], dtype=torch.float64, requires_grad=True), tensor([0.8109], dtype=torch.float64, requires_grad=True), tensor([-20.7233], dtype=torch.float64), tensor([0.], dtype=torch.float64), tensor([0.], dtype=torch.float64), tensor([0.4055], dtype=torch.float64, requires_grad=True)]
# --- Starting L-BFGS Optimization ---
# --- Step 1/10 / Loss: 1962.098613 ---
#   Param 0: Value=3.0123, Grad=0.12637566556945573
#   Param 1: Value=0.6197, Grad=-0.030526065336653363
#   Param 2: Value=0.7247, Grad=0.030299899082774542
#   Param 3: Value=-20.7233, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.6786, Grad=-0.04972887213368495
#   Max Abs Grad: 1.263757e-01
# ------------------------------
# --- Step 2/10 / Loss: 1877.625261 ---
#   Param 0: Value=3.0000, Grad=2.2874680952827964e-05
#   Param 1: Value=0.6151, Grad=-5.963060384805985e-06
#   Param 2: Value=0.7039, Grad=-6.813706206115766e-06
#   Param 3: Value=-20.7233, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.7167, Grad=5.395006915091816e-06
#   Max Abs Grad: 2.287468e-05
# ------------------------------
# --- Step 3/10 / Loss: 1877.623287 ---
#   Param 0: Value=3.0000, Grad=2.2874680952827964e-05
#   Param 1: Value=0.6151, Grad=-5.963060384805985e-06
#   Param 2: Value=0.7039, Grad=-6.813706206115766e-06
#   Param 3: Value=-20.7233, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.7167, Grad=5.395006915091816e-06
#   Max Abs Grad: 2.287468e-05
# ------------------------------
# --- Step 4/10 / Loss: 1877.623287 ---
#   Param 0: Value=3.0000, Grad=2.2874680952827964e-05
#   Param 1: Value=0.6151, Grad=-5.963060384805985e-06
#   Param 2: Value=0.7039, Grad=-6.813706206115766e-06
#   Param 3: Value=-20.7233, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.7167, Grad=5.395006915091816e-06
#   Max Abs Grad: 2.287468e-05
# ------------------------------
# --- Step 5/10 / Loss: 1877.623287 ---
#   Param 0: Value=3.0000, Grad=2.2874680952827964e-05
#   Param 1: Value=0.6151, Grad=-5.963060384805985e-06
#   Param 2: Value=0.7039, Grad=-6.813706206115766e-06
#   Param 3: Value=-20.7233, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.7167, Grad=5.395006915091816e-06
#   Max Abs Grad: 2.287468e-05
# ------------------------------
# --- Step 6/10 / Loss: 1877.623287 ---
#   Param 0: Value=3.0000, Grad=2.2874680952827964e-05
#   Param 1: Value=0.6151, Grad=-5.963060384805985e-06
#   Param 2: Value=0.7039, Grad=-6.813706206115766e-06
#   Param 3: Value=-20.7233, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.7167, Grad=5.395006915091816e-06
#   Max Abs Grad: 2.287468e-05
# ------------------------------
# --- Step 7/10 / Loss: 1877.623287 ---
#   Param 0: Value=3.0000, Grad=2.2874680952827964e-05
#   Param 1: Value=0.6151, Grad=-5.963060384805985e-06
#   Param 2: Value=0.7039, Grad=-6.813706206115766e-06
#   Param 3: Value=-20.7233, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.7167, Grad=5.395006915091816e-06
#   Max Abs Grad: 2.287468e-05
# ------------------------------
# --- Step 8/10 / Loss: 1877.623287 ---
#   Param 0: Value=3.0000, Grad=2.2874680952827964e-05
#   Param 1: Value=0.6151, Grad=-5.963060384805985e-06
#   Param 2: Value=0.7039, Grad=-6.813706206115766e-06
#   Param 3: Value=-20.7233, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.7167, Grad=5.395006915091816e-06
#   Max Abs Grad: 2.287468e-05
# ------------------------------
# --- Step 9/10 / Loss: 1877.623287 ---
#   Param 0: Value=3.0000, Grad=2.2874680952827964e-05
#   Param 1: Value=0.6151, Grad=-5.963060384805985e-06
#   Param 2: Value=0.7039, Grad=-6.813706206115766e-06
#   Param 3: Value=-20.7233, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.7167, Grad=5.395006915091816e-06
#   Max Abs Grad: 2.287468e-05
# ------------------------------
# --- Step 10/10 / Loss: 1877.623287 ---
#   Param 0: Value=3.0000, Grad=2.2874680952827964e-05
#   Param 1: Value=0.6151, Grad=-5.963060384805985e-06
#   Param 2: Value=0.7039, Grad=-6.813706206115766e-06
#   Param 3: Value=-20.7233, Grad=N/A
#   Param 4: Value=0.0000, Grad=N/A
#   Param 5: Value=0.0000, Grad=N/A
#   Param 6: Value=0.7167, Grad=5.395006915091816e-06
#   Max Abs Grad: 2.287468e-05
# ------------------------------
# FINAL STATE: Step 10, Loss: 1877.6232871480117
#   Raw (vecc) Parameters: [2.9999559388023678, 0.6150577787926361, 0.7039117855445436, -20.72326583694641, 0.0, 0.0, 0.7166534901520966]
#   Interpretable Parameters:
#     sigma_sq  : 10.857957
#     range_lon : 0.540610
#     range_lat : 0.380217
#     beta      : 0.000032
#     advec_lat : 0.000000
#     advec_lon : 0.000000
#     nugget    : 2.047570
# Day 1 optimization finished in 13.42s over 10 steps.
# Day 1 final results: [2.9999559388023678, 0.6150577787926361, 0.7039117855445436, -20.72326583694641, 0.0, 0.0, 0.7166534901520966, 1877.6232871480117]

# %%
a = [2.9999559388023678, 0.6150577787926361, 0.8039117855445436, 0, 0.0, 0.0, 0.7166534901520966]

#a = [3.1850261248518965, 0.7307329198588871, 0.7895547147699365, 0, 0.0, 0.0, 0.27780223854803404]
cal(a)
# Out:
# tensor(1781.4919, dtype=torch.float64, grad_fn=<MulBackward0>)
